# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
ground_truth_json_dir = "/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/"
#   
predict_json_dir = "/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static_stripped/"  #'/home/raisul/ANALYSED_DATA/prob_disasm_x86_pe_msvc_O2_static/'
BIN_FILE_TYPE = "PE"
BIN_PATH = "/home/raisul/DATA/x86_pe_msvc_O2_static_stripped/"

# %%
def get_offsets(json_file_path):
    with open(json_file_path, "r") as file:
        data = json.load(file)
    return list(map(int,list(data.keys())))



def get_instructions(bin_file_path  ):
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    with open(bin_file_path, 'rb') as f:
        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":
        
                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
        except Exception as e:
                print("An error occurred:", e ,bin_file_path)
                return
    
        for byte_index in range(len(textSection)):
            try:    
    
                instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
                offset_inst[text_section_offset+byte_index] = instruction
                
                # if instruction:
                #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                # else:
                #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
    
            except Exception as e:
                print(traceback.print_exc() )
                print(e)
    return offset_inst

ground_truth__jsons  =  os.listdir(ground_truth_json_dir) 
ghidra_predict_jsons    =  os.listdir(predict_json_dir)


common_json_files = list(set(ground_truth__jsons) & set(ghidra_predict_jsons))
print(len(common_json_files))
common_json_files = common_json_files[0:1000]
# common_json_files =['370cf902ac71f426c14725a24959e8de.json']
all_TP= all_FP= all_FN= all_TN = 0

for json_file_name in common_json_files:
    print('\n\n\n',json_file_name)
    ground_truth_json_path =  os.path.join(ground_truth_json_dir, json_file_name)
    ghidra_predict_json_path =  os.path.join(predict_json_dir, json_file_name)
    ground_truth_offsets = get_offsets(ground_truth_json_path)
    predict_offsets = get_offsets(ghidra_predict_json_path)
    
    ground_truth_offsets_set = set(ground_truth_offsets)
    predict_offsets_set = set(predict_offsets)

    
    superset = set(range( min(ground_truth_offsets) , max(ground_truth_offsets) ) )
    
    true_positive = len(ground_truth_offsets_set&predict_offsets_set)
    false_positive = len(predict_offsets_set - ground_truth_offsets_set)
    false_negative = len( ground_truth_offsets_set -predict_offsets_set )
    true_negative = len( superset - ( ground_truth_offsets_set|predict_offsets_set)  )
    
    all_TP+=true_positive
    all_FP+=false_positive
    all_FN+=false_negative
    all_TN+=true_negative
    
    print('\ntrue_positive: ',true_positive , '\n false_positive: ',false_positive ,'\nfalse_negative:', false_negative , '\ntrue_negative: ',true_negative)

    continue
    bin_file_path = os.path.join(os.path.join(BIN_PATH ,  json_file_name.split('.')[0] ),  (json_file_name.split('.')[0]+ ('.exe' if BIN_FILE_TYPE == "PE" else '' )))
    exhaustive_disasm = get_instructions(bin_file_path)
    # print(exhaustive_disasm)
    if exhaustive_disasm:
      for offset in exhaustive_disasm:
          hash = '#' if offset in ground_truth_offsets else ' '
          dollar = '$' if offset in predict_offsets else ' '

          if hash=='#' or dollar=='$':
              if exhaustive_disasm[offset].mnemonic!= 'int3':
                  print( hash , dollar , hex(offset), exhaustive_disasm[offset].mnemonic+ exhaustive_disasm[offset].op_str) #insn.mnemonic} {insn.op_str
          
    else:
        print('exhaustive diasm none')
    # print(len(ground_truth_offsets) , len(predict_offsets))
    # false_negatives = list(set(ground_truth_offsets) - set(predict_offsets))
# Out:
# 38525
#
#
#
#  25cdd7da32f926c6a988c4dbb2e22911.json
#
# true_positive:  1261
#  false_positive:  3
# false_negative: 202
# true_negative:  14715
#
#
#
#  16890c91025a1b89d058fcc8adf9f559.json
#
# true_positive:  1327
#  false_positive:  17
# false_negative: 196
# true_negative:  15137
#
#
#
#  052abec53d10f11d8272dc44c0d85ab2.json
#
# true_positive:  1368
#  false_positive:  3
# false_negative: 191
# true_negative:  15179
#
#
#
#  2ac5757c29d0eed2e14918f43085a44a.json
#
# true_positive:  1342
#  false_positive:  3
# false_negative: 219
# true_negative:  14953
#
#
#
#  0c209057f6f9c9b8b06404189d265750.json
#
# true_positive:  1223
#  false_positive:  3
# false_negative: 192
# true_negative:  14523
#
#
#
#  1ff039c2edeebb0f1fa1e33826ddd514.json
#
# true_positive:  1852
#  false_positive:  29
# false_negative: 201
# true_negative:  17507
#
#
#
#  109716b17ebe7f14472e4bef79c940b3.json
#
# true_positive:  1162
#  false_positive:  3
# false_negative: 189
# true_negative:  14267
#
#
#
#  3001c10ddd90ceff241f35476d2546fc.json
#
# true_positive:  1236
#  false_positive:  3
# false_negative: 199
# true_negative:  14647
#
#
#
#  014fe3f6f0ba718b2d598ada8f26e60d.json
#
# true_positive:  1191
#  false_positive:  3
# false_negative: 193
# true_negative:  14426
#
#
#
#  12912c787a0c8cae6b2ef82a4e349058.json
#
# true_positive:  1188
#  false_positive:  3
# false_negative: 190
# true_negative:  14400
#
#
#
#  3a4a54da5e85a717c6ef4c853461f7db.json
#
# true_positive:  1371
#  false_positive:  3
# false_negative: 195
# true_negative:  15092
#
#
#
#  0df9a801a76739b7f0c136fbf0739fae.json
#
# true_positive:  1700
#  false_positive:  15
# false_negative: 195
# true_negative:  16719
#
#
#
#  3ebd6a9131f20231bcd3e6d8b93d544e.json
#
# true_positive:  1418
#  false_positive:  3
# false_negative: 195
# true_negative:  15253
#
#
#
#  0a4db3241fb398d3bb92d461aa875f67.json
#
# true_positive:  1168
#  false_positive:  3
# false_negative: 190
# true_negative:  14308
#
#
#
#  03f097894c9f786a6fea95fc3a6be151.json
#
# true_positive:  1198
#  false_positive:  3
# false_negative: 189
# true_negative:  14407
#
#
#
#  2207097ce68a9804ca09aab0abecaef1.json
#
# true_positive:  1231
#  false_positive:  3
# false_negative: 191
# true_negative:  14516
#
#
#
#  2a282781283a36d64e7c6da122adf6ae.json
#
# true_positive:  1167
#  false_positive:  3
# false_negative: 189
# true_negative:  14278
#
#
#
#  37a4e4963ba72c3fa8ebb076a210de10.json
#
# true_positive:  1539
#  false_positive:  15
# false_negative: 196
# true_negative:  16255
#
#
#
#  37a02523b9680e3341b413ba6a3317e9.json
#
# true_positive:  1285
#  false_positive:  3
# false_negative: 207
# true_negative:  14782
#
#
#
#  1f77e2109b05daa3c828c389de365c63.json
#
# true_positive:  1169
#  false_positive:  3
# false_negative: 189
# true_negative:  14308
#
#
#
#  0f6697896a2d1059e3f6d9dcbe6b8101.json
#
# true_positive:  1221
#  false_positive:  3
# false_negative: 191
# true_negative:  14510
#
#
#
#  1c31c1f0fe085d4c05710f2a44ca7231.json
#
# true_positive:  2163
#  false_positive:  15
# false_negative: 204
# true_negative:  18407
#
#
#
#  0ad477cb3844ed928d489f3394e3e2c1.json
#
# true_positive:  1901
#  false_positive:  15
# false_negative: 200
# true_negative:  18065
#
#
#
#  2cbe7a06c7fca6d0465d2a778a344af6.json
#
# true_positive:  1174
#  false_positive:  3
# false_negative: 190
# true_negative:  14318
#
#
#
#  128e7368cc4c9d017bb125542106e29c.json
#
# true_positive:  1359
#  false_positive:  3
# false_negative: 196
# true_negative:  15119
#
#
#
#  2ea038b37d70d4482d309d4be89f4e85.json
#
# true_positive:  1538
#  false_positive:  15
# false_negative: 214
# true_negative:  16366
#
#
#
#  11f72d058d5fae259b36e029a50346de.json
#
# true_positive:  1356
#  false_positive:  3
# false_negative: 194
# true_negative:  15124
#
#
#
#  379fafdc04ebd267eba02d6fbc12671f.json
#
# true_positive:  1282
#  false_positive:  3
# false_negative: 194
# true_negative:  14814
#
#
#
#  1ff50236adbb348ef7a008351df34de2.json
#
# true_positive:  1169
#  false_positive:  3
# false_negative: 189
# true_negative:  14292
#
#
#
#  1d8fab79f9f92ee109b635e2784b2578.json
#
# true_positive:  1883
#  false_positive:  15
# false_negative: 204
# true_negative:  17599
#
#
#
#  309d728b5fa240a6ff3274a1162088cd.json
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 189
# true_negative:  14266
#
#
#
#  00c7db5c45cbb0e6f47fb505b4dec3b7.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14571
#
#
#
#  052e0527a78974ea838beeb88c45be62.json
#
# true_positive:  1213
#  false_positive:  3
# false_negative: 191
# true_negative:  14454
#
#
#
#  209608ac0de8d8cc96d9e3e6e7074824.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 189
# true_negative:  14280
#
#
#
#  2ad0f491bf7d6c8d98543c26340d388b.json
#
# true_positive:  1220
#  false_positive:  3
# false_negative: 191
# true_negative:  14527
#
#
#
#  1c4423064af54987cd1557f6e5fd868e.json
#
# true_positive:  1433
#  false_positive:  15
# false_negative: 193
# true_negative:  15644
#
#
#
#  39935c5ce5838cad71003f94aecbb1b4.json
#
# true_positive:  1740
#  false_positive:  15
# false_negative: 285
# true_negative:  17389
#
#
#
#  0861215aafc1ec6fe01571092b72f2ce.json
#
# true_positive:  1329
#  false_positive:  3
# false_negative: 305
# true_negative:  15424
#
#
#
#  1013c052ed48c6959b635fc921e6d94e.json
#
# true_positive:  1666
#  false_positive:  15
# false_negative: 196
# true_negative:  16560
#
#
#
#  215d7341dd5a6e3ff026914595e4a793.json
#
# true_positive:  1305
#  false_positive:  3
# false_negative: 201
# true_negative:  14928
#
#
#
#  2484b80e27a492657971bb06effbabec.json
#
# true_positive:  1578
#  false_positive:  15
# false_negative: 195
# true_negative:  16121
#
#
#
#  02b249c9f187add672b69f76229a27f5.json
#
# true_positive:  1558
#  false_positive:  15
# false_negative: 242
# true_negative:  16190
#
#
#
#  3ed146ab02b54464de21bac7429a8f92.json
#
# true_positive:  1174
#  false_positive:  3
# false_negative: 189
# true_negative:  14335
#
#
#
#  2d65e091edfaf117b25bd20d60125b5b.json
#
# true_positive:  1460
#  false_positive:  15
# false_negative: 193
# true_negative:  15761
#
#
#
#  2e092430427981ece7d08649d0eaeedc.json
#
# true_positive:  1553
#  false_positive:  15
# false_negative: 195
# true_negative:  16050
#
#
#
#  0eb929712a8b53eb5d8f92d34bfd9acb.json
#
# true_positive:  1512
#  false_positive:  15
# false_negative: 195
# true_negative:  15899
#
#
#
#  3319cdf7c4888a0ba6bc9e7ee69e5c09.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 188
# true_negative:  14236
#
#
#
#  368b0555d8be4ad49f9f4e98ae8fa4b7.json
#
# true_positive:  1272
#  false_positive:  3
# false_negative: 192
# true_negative:  14698
#
#
#
#  03576ecc6397e0c32b37c7da70f57d95.json
#
# true_positive:  1540
#  false_positive:  15
# false_negative: 195
# true_negative:  16031
#
#
#
#  05c3870099d790fb56e3c134707c1e04.json
#
# true_positive:  1544
#  false_positive:  15
# false_negative: 195
# true_negative:  16219
#
#
#
#  048d2bbdbdf7b6cce62427e37fb87c79.json
#
# true_positive:  1224
#  false_positive:  3
# false_negative: 191
# true_negative:  14507
#
#
#
#  1134613e65cdb027c1abde823c143864.json
#
# true_positive:  1223
#  false_positive:  3
# false_negative: 192
# true_negative:  14555
#
#
#
#  1c4550493643f112c687b72bb8dc7f3f.json
#
# true_positive:  1436
#  false_positive:  15
# false_negative: 193
# true_negative:  15657
#
#
#
#  0ea56eda701da8866a04977339be5637.json
#
# true_positive:  1257
#  false_positive:  3
# false_negative: 253
# true_negative:  15100
#
#
#
#  0523c3c5bf933ef099208d612103e500.json
#
# true_positive:  1175
#  false_positive:  3
# false_negative: 192
# true_negative:  14379
#
#
#
#  08ebe3f0996cb0d3e669d6c23ec88af7.json
#
# true_positive:  1202
#  false_positive:  3
# false_negative: 190
# true_negative:  14402
#
#
#
#  2fdf17e30577e3efec4b8a7915452292.json
#
# true_positive:  1629
#  false_positive:  17
# false_negative: 202
# true_negative:  16749
#
#
#
#  3d8981d28148e44fbbddb7c6100c5b4e.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  0e08f874bc8c6e2134053f52c9eb844b.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  3af958eced71edf32ab36e5d46c98981.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 217
# true_negative:  14353
#
#
#
#  3140a111069737e2adfbfb06b7284ca7.json
#
# true_positive:  1507
#  false_positive:  15
# false_negative: 199
# true_negative:  15980
#
#
#
#  07937ac51210054cf4062496081c5cfa.json
#
# true_positive:  1445
#  false_positive:  3
# false_negative: 195
# true_negative:  15610
#
#
#
#  27a06254d32248fc9be1e003c7a6c0f1.json
#
# true_positive:  1440
#  false_positive:  15
# false_negative: 215
# true_negative:  15711
#
#
#
#  02a2429672ae7632447a1f6388d3c3db.json
#
# true_positive:  1296
#  false_positive:  3
# false_negative: 193
# true_negative:  14801
#
#
#
#  191a472e9bd320e74d76e4b268ce5f3a.json
#
# true_positive:  1518
#  false_positive:  15
# false_negative: 195
# true_negative:  15973
#
#
#
#  3718b609b12e1ff1185af227a18049af.json
#
# true_positive:  1452
#  false_positive:  3
# false_negative: 214
# true_negative:  15504
#
#
#
#  22a26629ee388f3544f886f6f940ca37.json
#
# true_positive:  1455
#  false_positive:  3
# false_negative: 197
# true_negative:  15502
#
#
#
#  1b0565cfb619b6889d4d095e2ae0c7bf.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  153fdb3d47129f3c72fa6bfe0c9dd0d5.json
#
# true_positive:  1227
#  false_positive:  3
# false_negative: 191
# true_negative:  14584
#
#
#
#  0d7b4a9a2b8217f8aa9363ce7b168da9.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14538
#
#
#
#  1a5b4c2e693e7e3ff43486144ea0115f.json
#
# true_positive:  1518
#  false_positive:  15
# false_negative: 195
# true_negative:  15957
#
#
#
#  19c715b2832b3554fdbfc472997339b2.json
#
# true_positive:  1459
#  false_positive:  15
# false_negative: 194
# true_negative:  15681
#
#
#
#  2289d34612536c5986cc53fbae0838f0.json
#
# true_positive:  1201
#  false_positive:  3
# false_negative: 202
# true_negative:  14471
#
#
#
#  2d6750fcc1cffaa5224a03b218133cf4.json
#
# true_positive:  1267
#  false_positive:  3
# false_negative: 193
# true_negative:  14830
#
#
#
#  31443ea504a0d022bf0e7b87888c5d85.json
#
# true_positive:  1263
#  false_positive:  3
# false_negative: 191
# true_negative:  14628
#
#
#
#  08dc043474782fa01775d2bf2ebb1d25.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  234e2d661cd57e21c1de4f4405a215f2.json
#
# true_positive:  1550
#  false_positive:  15
# false_negative: 200
# true_negative:  16128
#
#
#
#  1b9da1893f5619ba2b59bef013943fda.json
#
# true_positive:  1341
#  false_positive:  3
# false_negative: 191
# true_negative:  14982
#
#
#
#  1712c35179b5815caacbe44a80272e60.json
#
# true_positive:  1344
#  false_positive:  3
# false_negative: 195
# true_negative:  15055
#
#
#
#  285f60fe0b6a332d45074dc7e501528d.json
#
# true_positive:  1184
#  false_positive:  3
# false_negative: 212
# true_negative:  14446
#
#
#
#  24997420b4e3c75d97faacbfc9e62ae4.json
#
# true_positive:  1218
#  false_positive:  3
# false_negative: 191
# true_negative:  14481
#
#
#
#  17c5e7d5bd2d339102698583296068bc.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  033a6bcacb6b5e09fbede432e2ce54d1.json
#
# true_positive:  1635
#  false_positive:  15
# false_negative: 196
# true_negative:  16271
#
#
#
#  1688b5d00e6b5b96e50da3ea31f9c359.json
#
# true_positive:  1448
#  false_positive:  15
# false_negative: 193
# true_negative:  15693
#
#
#
#  072211b2fe0e2851602844f70fccfdbe.json
#
# true_positive:  1268
#  false_positive:  3
# false_negative: 191
# true_negative:  14703
#
#
#
#  0216733b68f7b22d76ce1460c3f20c2f.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  19265c0234ad1d65520fa5bff34c0e12.json
#
# true_positive:  1233
#  false_positive:  3
# false_negative: 191
# true_negative:  14530
#
#
#
#  0eb8afffb0b64bd3aa9fd101900e7d24.json
#
# true_positive:  1585
#  false_positive:  15
# false_negative: 232
# true_negative:  16365
#
#
#
#  2a39d8f5b1aa2efd035f9246d38cbca3.json
#
# true_positive:  1273
#  false_positive:  3
# false_negative: 191
# true_negative:  14682
#
#
#
#  28482effc0d11e29f5a64206f56e2e23.json
#
# true_positive:  1221
#  false_positive:  3
# false_negative: 191
# true_negative:  14542
#
#
#
#  35dbd32c155ef704e423841c992e9bb9.json
#
# true_positive:  1473
#  false_positive:  3
# false_negative: 197
# true_negative:  15580
#
#
#
#  1c360bf9ba126c5fe23dac174905c239.json
#
# true_positive:  1233
#  false_positive:  3
# false_negative: 191
# true_negative:  14546
#
#
#
#  1686835f22a9eb8a380d7424c8b11f38.json
#
# true_positive:  1237
#  false_positive:  3
# false_negative: 191
# true_negative:  14558
#
#
#
#  3845f1f7516aee245aa198a45805e34f.json
#
# true_positive:  1314
#  false_positive:  3
# false_negative: 198
# true_negative:  14922
#
#
#
#  2ffbe8789e6b0229703c522b9a9b5dfb.json
#
# true_positive:  1557
#  false_positive:  15
# false_negative: 197
# true_negative:  16236
#
#
#
#  133e0bf9a2fe7dfc2011efd23e5dbe26.json
#
# true_positive:  1257
#  false_positive:  3
# false_negative: 193
# true_negative:  14616
#
#
#
#  3272519209346797a7a34692e8bad08a.json
#
# true_positive:  1329
#  false_positive:  3
# false_negative: 191
# true_negative:  14946
#
#
#
#  0a4776e3361414db996beab4e967dbe0.json
#
# true_positive:  1341
#  false_positive:  3
# false_negative: 204
# true_negative:  15161
#
#
#
#  02b06770daacc1a546d4fee7d9689398.json
#
# true_positive:  1294
#  false_positive:  3
# false_negative: 193
# true_negative:  14787
#
#
#
#  1668f9decf4125322364e56f1430c57a.json
#
# true_positive:  1454
#  false_positive:  3
# false_negative: 215
# true_negative:  15517
#
#
#
#  1ea6fa884bba716e5a6609157290ac78.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 189
# true_negative:  14331
#
#
#
#  220af18402f5b3212264a655b902f639.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  13e1425383028f6af415d0f5c73f7c44.json
#
# true_positive:  1232
#  false_positive:  3
# false_negative: 191
# true_negative:  14547
#
#
#
#  1743f59073599a67cc8d4db06412d100.json
#
# true_positive:  2096
#  false_positive:  15
# false_negative: 225
# true_negative:  18885
#
#
#
#  39137e8e4a34c495d0f38650c844b4cf.json
#
# true_positive:  1676
#  false_positive:  15
# false_negative: 194
# true_negative:  16504
#
#
#
#  28ed592239528948c44d91f0b5bf1214.json
#
# true_positive:  1246
#  false_positive:  3
# false_negative: 191
# true_negative:  14581
#
#
#
#  33e5e08a146589ca376e75bb1877d034.json
#
# true_positive:  1658
#  false_positive:  15
# false_negative: 215
# true_negative:  16581
#
#
#
#  2c0f8c728d79196e48e6a1148763f33c.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14554
#
#
#
#  234cd85cdb1529322de7352fd978e82f.json
#
# true_positive:  1431
#  false_positive:  15
# false_negative: 206
# true_negative:  15633
#
#
#
#  32a69aa97d17a57d7b9e51ce4aff0e42.json
#
# true_positive:  1220
#  false_positive:  3
# false_negative: 189
# true_negative:  14497
#
#
#
#  1a5393d9ba3dccd30bef5952f25d2deb.json
#
# true_positive:  1541
#  false_positive:  15
# false_negative: 195
# true_negative:  16078
#
#
#
#  3cc2202a64ddec422cfe67223561911a.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  39b3dae3a075860937f3f255dd46e1ca.json
#
# true_positive:  1162
#  false_positive:  3
# false_negative: 189
# true_negative:  14267
#
#
#
#  13ecde5ab7d0a86c69e43f46eb4a5d73.json
#
# true_positive:  1481
#  false_positive:  15
# false_negative: 225
# true_negative:  15948
#
#
#
#  02b4bb5022734a7a28d88c2238451ccf.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  1d6cfbdb4e761bfc204332e23c004106.json
#
# true_positive:  1338
#  false_positive:  3
# false_negative: 193
# true_negative:  14983
#
#
#
#  0531641522a35725d5873608914027cd.json
#
# true_positive:  1170
#  false_positive:  3
# false_negative: 190
# true_negative:  14290
#
#
#
#  25193dd487b2a2de1fc2a9fc379be588.json
#
# true_positive:  1232
#  false_positive:  3
# false_negative: 191
# true_negative:  14547
#
#
#
#  3ad469f12240abfed416d301c582f5e9.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 199
# true_negative:  14307
#
#
#
#  0c2e5568ce7f1442ca52f5231d66cb88.json
#
# true_positive:  1213
#  false_positive:  3
# false_negative: 195
# true_negative:  14546
#
#
#
#  0e2981915b04d3b7e59bebf64adf8be4.json
#
# true_positive:  1622
#  false_positive:  3
# false_negative: 212
# true_negative:  16232
#
#
#
#  11f8d55349a604e8d036e1f2e73c44c8.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14619
#
#
#
#  3146c21a37980f4977f4a26c1d06b480.json
#
# true_positive:  1525
#  false_positive:  15
# false_negative: 197
# true_negative:  16172
#
#
#
#  2ccf860e3cc79064904c69b26fe97b9f.json
#
# true_positive:  1544
#  false_positive:  3
# false_negative: 201
# true_negative:  16289
#
#
#
#  1aedce48a796f0474408f63d2f4acaad.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 191
# true_negative:  14545
#
#
#
#  05d021033fd2617b13e2b041219e074b.json
#
# true_positive:  1510
#  false_positive:  15
# false_negative: 195
# true_negative:  15949
#
#
#
#  3ae15b174a1ce15436e267d3ea985dea.json
#
# true_positive:  1519
#  false_positive:  15
# false_negative: 195
# true_negative:  15972
#
#
#
#  1423c10f5e06914cd43c37b3d1a7a1ef.json
#
# true_positive:  1600
#  false_positive:  15
# false_negative: 196
# true_negative:  16258
#
#
#
#  15ebf5cfadace6ce86530edf142dcb2f.json
#
# true_positive:  1502
#  false_positive:  15
# false_negative: 217
# true_negative:  16015
#
#
#
#  167f48fc1cab26a55b5cabf36734f87c.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  11444d55de86a7bbc11c8e8ae91bb1a6.json
#
# true_positive:  1785
#  false_positive:  15
# false_negative: 204
# true_negative:  17025
#
#
#
#  1ccef5df0b57ad3bb7e4ea33e59d869c.json
#
# true_positive:  1511
#  false_positive:  15
# false_negative: 208
# true_negative:  15919
#
#
#
#  2fde3d8d1bb6466ac50336d02fcb3247.json
#
# true_positive:  1162
#  false_positive:  3
# false_negative: 189
# true_negative:  14267
#
#
#
#  14942f916ea5a5269e6386bbfd6985a2.json
#
# true_positive:  1167
#  false_positive:  3
# false_negative: 189
# true_negative:  14294
#
#
#
#  09a4dfa2829545700717f1c764bfc586.json
#
# true_positive:  1376
#  false_positive:  3
# false_negative: 193
# true_negative:  15137
#
#
#
#  19042effb9ec87746f5d15f1e8cc7488.json
#
# true_positive:  1264
#  false_positive:  3
# false_negative: 191
# true_negative:  14723
#
#
#
#  372e71f03fae1746159da32f973808b1.json
#
# true_positive:  1252
#  false_positive:  3
# false_negative: 191
# true_negative:  14623
#
#
#
#  174796b62c0bbec2c28cace587214e3b.json
#
# true_positive:  2129
#  false_positive:  3
# false_negative: 207
# true_negative:  18002
#
#
#
#  1677f9b6cc2d107d2e219c21e1459412.json
#
# true_positive:  1525
#  false_positive:  15
# false_negative: 195
# true_negative:  15982
#
#
#
#  2af106a9a38538446b134042cd1ac3dd.json
#
# true_positive:  1223
#  false_positive:  3
# false_negative: 195
# true_negative:  14600
#
#
#
#  051b083af76e26a044f0a492cabb61f3.json
#
# true_positive:  1220
#  false_positive:  3
# false_negative: 191
# true_negative:  14479
#
#
#
#  19b865ce6c894cfa97b47ecb76e6289e.json
#
# true_positive:  1177
#  false_positive:  3
# false_negative: 189
# true_negative:  14348
#
#
#
#  0ec7e6fdec9f5107282f17288aef6dd0.json
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 198
# true_negative:  14353
#
#
#
#  065e0e5d22c21039c31097be391951b1.json
#
# true_positive:  1849
#  false_positive:  3
# false_negative: 191
# true_negative:  16650
#
#
#
#  28ebd66aecba3e6b0bf1db0a92b84ab6.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 189
# true_negative:  14280
#
#
#
#  3b8ec2e25a92279dd0cae864036ff56e.json
#
# true_positive:  1247
#  false_positive:  3
# false_negative: 191
# true_negative:  14612
#
#
#
#  299f0adf308b5fae8af2e2ae43b99054.json
#
# true_positive:  1243
#  false_positive:  3
# false_negative: 192
# true_negative:  14583
#
#
#
#  07b94ecf39e07c09aae9c4a0dd08c558.json
#
# true_positive:  1164
#  false_positive:  3
# false_negative: 197
# true_negative:  14321
#
#
#
#  39a013308c2cb8d8a08db6fee2887120.json
#
# true_positive:  1758
#  false_positive:  29
# false_negative: 197
# true_negative:  17173
#
#
#
#  3e19cb972997b84fbf601e3947b0e275.json
#
# true_positive:  1296
#  false_positive:  3
# false_negative: 191
# true_negative:  14803
#
#
#
#  2c27dfd3b89d96a59512a4fe451af41e.json
#
# true_positive:  1419
#  false_positive:  15
# false_negative: 193
# true_negative:  15546
#
#
#
#  3485acbb62260ea49ec490de834e5012.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 189
# true_negative:  14299
#
#
#
#  0e1a0a56b7d56bdb5f5f227adbe21451.json
#
# true_positive:  1241
#  false_positive:  3
# false_negative: 191
# true_negative:  14602
#
#
#
#  38ebec4334e1c05bb6eb6d1f403a338a.json
#
# true_positive:  1256
#  false_positive:  3
# false_negative: 191
# true_negative:  14619
#
#
#
#  22aa6cebbf7963faa44f4cda3c0a3785.json
#
# true_positive:  1244
#  false_positive:  3
# false_negative: 194
# true_negative:  14692
#
#
#
#  168e5fd87e5359b19407d6eff0f47b6a.json
#
# true_positive:  1222
#  false_positive:  3
# false_negative: 191
# true_negative:  14493
#
#
#
#  0ea40a712a9d09983798faff100a55a2.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14506
#
#
#
#  28fa737b29f9607b6dc863f80dc6ef26.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  11ff283d61bce0eab5876ea888989b11.json
#
# true_positive:  1214
#  false_positive:  3
# false_negative: 191
# true_negative:  14469
#
#
#
#  2a493f637a2f9298911c99c7ad313828.json
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 193
# true_negative:  14326
#
#
#
#  0b7fe82a159e842e104a39791b752991.json
#
# true_positive:  1173
#  false_positive:  3
# false_negative: 189
# true_negative:  14336
#
#
#
#  27d5b8e70a8895364da4c9e2cf5bf9e5.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 189
# true_negative:  14280
#
#
#
#  05c2001b37d31611b4327dccfdb75bfa.json
#
# true_positive:  1242
#  false_positive:  17
# false_negative: 195
# true_negative:  14695
#
#
#
#  071e94e6383aa750861cfd983d600aff.json
#
# true_positive:  1228
#  false_positive:  3
# false_negative: 191
# true_negative:  14551
#
#
#
#  2cd8be417f1cdf31fda1fc198e2edb0f.json
#
# true_positive:  1188
#  false_positive:  3
# false_negative: 189
# true_negative:  14417
#
#
#
#  3c1b12ddcd6f700a38a43b65f8b97fcb.json
#
# true_positive:  1226
#  false_positive:  3
# false_negative: 191
# true_negative:  14553
#
#
#
#  27a44316db689375f1473504c68a4052.json
#
# true_positive:  1235
#  false_positive:  3
# false_negative: 192
# true_negative:  14559
#
#
#
#  17d2f72c65071213e59a64dacf1afcf2.json
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 189
# true_negative:  14266
#
#
#
#  25140844882204f5bcca41a752e79bb1.json
#
# true_positive:  1227
#  false_positive:  3
# false_negative: 191
# true_negative:  14536
#
#
#
#  05489f2ee5030a6d7d94f9e26d362e48.json
#
# true_positive:  1168
#  false_positive:  3
# false_negative: 191
# true_negative:  14291
#
#
#
#  2353aedc852d3ded49d61eb6f11e674c.json
#
# true_positive:  1107
#  false_positive:  3
# false_negative: 186
# true_negative:  14005
#
#
#
#  21737512d299bf69100d6ebe48eb7e2a.json
#
# true_positive:  4289
#  false_positive:  15
# false_negative: 213
# true_negative:  29072
#
#
#
#  03dffa9e893e35dedb58f4128dfc5000.json
#
# true_positive:  1239
#  false_positive:  3
# false_negative: 191
# true_negative:  14588
#
#
#
#  0c38ac80ded81cb3f2c8dd51fd5af6e9.json
#
# true_positive:  1107
#  false_positive:  3
# false_negative: 186
# true_negative:  14005
#
#
#
#  312876ed7d8a701fdec92433b13748a3.json
#
# true_positive:  1263
#  false_positive:  3
# false_negative: 193
# true_negative:  14658
#
#
#
#  15d494fe865edcd7e80f05ae3d880afe.json
#
# true_positive:  1254
#  false_positive:  3
# false_negative: 191
# true_negative:  14573
#
#
#
#  3a480f1f90b3d35af4c55acd22ea32b7.json
#
# true_positive:  1503
#  false_positive:  15
# false_negative: 195
# true_negative:  15892
#
#
#
#  2c222586e3476b58b4b67c4080d33251.json
#
# true_positive:  1212
#  false_positive:  3
# false_negative: 191
# true_negative:  14471
#
#
#
#  10b03a917b2af5186c0a343d94653903.json
#
# true_positive:  1657
#  false_positive:  29
# false_negative: 204
# true_negative:  16739
#
#
#
#  0f75975660f9e36adeeb47462d6d2cea.json
#
# true_positive:  1226
#  false_positive:  3
# false_negative: 191
# true_negative:  14537
#
#
#
#  27bf258226c8f34002ea7354f9c10682.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 193
# true_negative:  14297
#
#
#
#  1c483dbefb107e0715488a11226c4dd9.json
#
# true_positive:  1168
#  false_positive:  3
# false_negative: 189
# true_negative:  14261
#
#
#
#  2a29c176ba14c019e05182e7946558bd.json
#
# true_positive:  1256
#  false_positive:  3
# false_negative: 191
# true_negative:  14651
#
#
#
#  3eb389716013562edce130e644dd7560.json
#
# true_positive:  1839
#  false_positive:  3
# false_negative: 278
# true_negative:  17741
#
#
#
#  07a8670095317b2486e570a1a26ab307.json
#
# true_positive:  1168
#  false_positive:  3
# false_negative: 189
# true_negative:  14293
#
#
#
#  166a6cebaafe0e89c64fb361bb0b0b26.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 192
# true_negative:  14298
#
#
#
#  128f0f9da6763d83bbe9c709f0b4f4f5.json
#
# true_positive:  1487
#  false_positive:  3
# false_negative: 198
# true_negative:  15709
#
#
#
#  25b869ca8eab488600d25fdc1cba2e59.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 199
# true_negative:  14649
#
#
#
#  029c92846c21f454338eeae2af26e292.json
#
# true_positive:  1633
#  false_positive:  15
# false_negative: 196
# true_negative:  16433
#
#
#
#  13c65a41bf397b4b62425811c8485d95.json
#
# true_positive:  1486
#  false_positive:  15
# false_negative: 196
# true_negative:  15844
#
#
#
#  2515006cfdef8e0e55cb54001cab60e9.json
#
# true_positive:  1796
#  false_positive:  3
# false_negative: 246
# true_negative:  17448
#
#
#
#  06655dabdc0446f176f1ce464c328d26.json
#
# true_positive:  1184
#  false_positive:  3
# false_negative: 189
# true_negative:  14405
#
#
#
#  2096261ffd04e863333810725e88fb11.json
#
# true_positive:  1543
#  false_positive:  3
# false_negative: 218
# true_negative:  15665
#
#
#
#  2853f139a696eefce045670b8eaa12d9.json
#
# true_positive:  1416
#  false_positive:  3
# false_negative: 201
# true_negative:  15409
#
#
#
#  00a205de509b857f52cf13ddb93317d3.json
#
# true_positive:  1289
#  false_positive:  3
# false_negative: 194
# true_negative:  14839
#
#
#
#  1279d6573c9ec1f4b417004d09432f6a.json
#
# true_positive:  1329
#  false_positive:  17
# false_negative: 197
# true_negative:  15118
#
#
#
#  3b9fc51c3ae09cbcd087ca35ce56b3ba.json
#
# true_positive:  1181
#  false_positive:  3
# false_negative: 190
# true_negative:  14343
#
#
#
#  0c2ece31bb6d8778bf942c1fd8113ad3.json
#
# true_positive:  1451
#  false_positive:  15
# false_negative: 194
# true_negative:  15753
#
#
#
#  33da998945370387205ba62476d99bbe.json
#
# true_positive:  2702
#  false_positive:  29
# false_negative: 221
# true_negative:  22461
#
#
#
#  309d3903c795b63dfe7299b8563c32f0.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 189
# true_negative:  14280
#
#
#
#  0f54cf5fbb6ad0b7976ab0e46a00006a.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  3516df60eef2f6b70d9481289c024d1a.json
#
# true_positive:  1250
#  false_positive:  3
# false_negative: 191
# true_negative:  14593
#
#
#
#  0ea53486b04cfa3ce822bfe8305103f7.json
#
# true_positive:  1254
#  false_positive:  3
# false_negative: 191
# true_negative:  14621
#
#
#
#  271ddee5c226e2fb9689e74bbb9c96fd.json
#
# true_positive:  1242
#  false_positive:  3
# false_negative: 191
# true_negative:  14585
#
#
#
#  28589deeb57507c3c36cd1eb9cc5a4c8.json
#
# true_positive:  1297
#  false_positive:  3
# false_negative: 191
# true_negative:  14738
#
#
#
#  37b5db4ddb7e3ffc7cf4246dd0c933ce.json
#
# true_positive:  1799
#  false_positive:  15
# false_negative: 202
# true_negative:  17221
#
#
#
#  0c2eec858de3173b6c4afae26ce1adfb.json
#
# true_positive:  1315
#  false_positive:  3
# false_negative: 217
# true_negative:  14966
#
#
#
#  2ecb3077527838ee56f8e10673c38f3d.json
#
# true_positive:  1720
#  false_positive:  15
# false_negative: 200
# true_negative:  16774
#
#
#
#  3ece3a040ff4c433d2a1133dd344d673.json
#
# true_positive:  1242
#  false_positive:  3
# false_negative: 191
# true_negative:  14617
#
#
#
#  00b8bd22b21b9e46e00cda53dc285663.json
#
# true_positive:  1233
#  false_positive:  3
# false_negative: 191
# true_negative:  14562
#
#
#
#  228a8be7cc3e5bb287d407739ee3a568.json
#
# true_positive:  1585
#  false_positive:  3
# false_negative: 192
# true_negative:  15601
#
#
#
#  067bfac2b5e98d8067ad6072f2b0c869.json
#
# true_positive:  1796
#  false_positive:  15
# false_negative: 196
# true_negative:  17166
#
#
#
#  1f4c53cd503feb52c0869970f27852b0.json
#
# true_positive:  1247
#  false_positive:  3
# false_negative: 190
# true_negative:  14501
#
#
#
#  07baf90d6c755f486a8cdf6d718cd01f.json
#
# true_positive:  1233
#  false_positive:  3
# false_negative: 192
# true_negative:  14609
#
#
#
#  1b9827ffcde7a428de4f91e8fe9edf61.json
#
# true_positive:  1241
#  false_positive:  3
# false_negative: 191
# true_negative:  14570
#
#
#
#  007f94e458a2ec55ecb9e78a90090509.json
#
# true_positive:  1201
#  false_positive:  3
# false_negative: 189
# true_negative:  14356
#
#
#
#  028e07cfcceee009b8b9bfde10c48960.json
#
# true_positive:  1299
#  false_positive:  3
# false_negative: 192
# true_negative:  14927
#
#
#
#  1b0bf6254424e61246394ecc91a39299.json
#
# true_positive:  1192
#  false_positive:  3
# false_negative: 190
# true_negative:  14332
#
#
#
#  3cb2812ef308c506122f18e2dc58a08c.json
#
# true_positive:  1430
#  false_positive:  15
# false_negative: 194
# true_negative:  15582
#
#
#
#  03e683f7f5d31c43d40f66eb8d39958e.json
#
# true_positive:  1603
#  false_positive:  3
# false_negative: 199
# true_negative:  16184
#
#
#
#  070dc5216d91c5903d28dc3fb80ac121.json
#
# true_positive:  1217
#  false_positive:  3
# false_negative: 194
# true_negative:  14543
#
#
#
#  0f6ff62fd1200ca18755efa02bfaecd3.json
#
# true_positive:  1489
#  false_positive:  17
# false_negative: 195
# true_negative:  15728
#
#
#
#  1cc8d2b728be8d4ad60041a5bc7d81a1.json
#
# true_positive:  1245
#  false_positive:  3
# false_negative: 191
# true_negative:  14646
#
#
#
#  329616b9c9c7e97e2f75f9bb6bcfc41b.json
#
# true_positive:  1273
#  false_positive:  3
# false_negative: 217
# true_negative:  14768
#
#
#
#  252588c9008f8ce9b2ddd31d12e41fe7.json
#
# true_positive:  1548
#  false_positive:  15
# false_negative: 199
# true_negative:  16195
#
#
#
#  0d85bc64260b6e8b2349b4c1f45d759b.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  22064be970cfdfb3ae80f9fca6c92e5d.json
#
# true_positive:  1216
#  false_positive:  3
# false_negative: 191
# true_negative:  14499
#
#
#
#  049091e4b00607a69638c0602d4f7af1.json
#
# true_positive:  1189
#  false_positive:  3
# false_negative: 210
# true_negative:  14443
#
#
#
#  3a2d627e537147939d6a073f44445714.json
#
# true_positive:  1244
#  false_positive:  3
# false_negative: 191
# true_negative:  14615
#
#
#
#  3c36f64fc31a4466e537b5d3eb782b64.json
#
# true_positive:  1176
#  false_positive:  3
# false_negative: 189
# true_negative:  14365
#
#
#
#  2835be2b6a3849842a15b8843baeb3e6.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  187939d56a68fc48f526b00cb612fb04.json
#
# true_positive:  2632
#  false_positive:  15
# false_negative: 240
# true_negative:  20094
#
#
#
#  1695f5bb13bed050348374b833b42a4a.json
#
# true_positive:  1841
#  false_positive:  15
# false_negative: 212
# true_negative:  17377
#
#
#
#  188cd9338e4a75f5c40a5e7a021b6448.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 192
# true_negative:  14569
#
#
#
#  33c109c70047ab31c54838b7fabfdfd6.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 199
# true_negative:  14307
#
#
#
#  1c28a47c8c066d4f7e2ac801bf887f07.json
#
# true_positive:  1537
#  false_positive:  15
# false_negative: 201
# true_negative:  16012
#
#
#
#  229e1d4ce5bceb8bd6de9ae480cd7b1e.json
#
# true_positive:  1231
#  false_positive:  3
# false_negative: 191
# true_negative:  14532
#
#
#
#  0200e99db57718136209a3c7554857a1.json
#
# true_positive:  1325
#  false_positive:  3
# false_negative: 192
# true_negative:  14901
#
#
#
#  03f7943e1aa768c503651c9cebcdb291.json
#
# true_positive:  1167
#  false_positive:  3
# false_negative: 189
# true_negative:  14278
#
#
#
#  215439a5b1545d450a393701274f9328.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 191
# true_negative:  14593
#
#
#
#  1280c1ecfbfc219f3b12e8a864d173e1.json
#
# true_positive:  1227
#  false_positive:  3
# false_negative: 191
# true_negative:  14504
#
#
#
#  31ccccc450bc8790ac986153584de315.json
#
# true_positive:  1553
#  false_positive:  15
# false_negative: 195
# true_negative:  16146
#
#
#
#  03f9c744268f523874609823916bf8b9.json
#
# true_positive:  1258
#  false_positive:  3
# false_negative: 192
# true_negative:  14632
#
#
#
#  0acc3c6c3f06ea6828cc82d4ee224b36.json
#
# true_positive:  1501
#  false_positive:  15
# false_negative: 196
# true_negative:  15909
#
#
#
#  02035f86f1a493b837b421e6e342a6aa.json
#
# true_positive:  1695
#  false_positive:  15
# false_negative: 195
# true_negative:  16676
#
#
#
#  37169b5bfd1b6c895b2eb069d1b5dfc5.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 191
# true_negative:  14529
#
#
#
#  2816533a8e4f29e2297d76989d2e08ab.json
#
# true_positive:  1509
#  false_positive:  15
# false_negative: 200
# true_negative:  15913
#
#
#
#  383eed88fc302de228dfaf00cd3dcb71.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  39a9df4bf503428ed099a2151999a9f5.json
#
# true_positive:  1167
#  false_positive:  3
# false_negative: 190
# true_negative:  14277
#
#
#
#  0d5aedec6f89c6a4800b54e302fb5a36.json
#
# true_positive:  1529
#  false_positive:  15
# false_negative: 196
# true_negative:  16089
#
#
#
#  17422e9bf1837b61bfa364432626ab2d.json
#
# true_positive:  2122
#  false_positive:  3
# false_negative: 211
# true_negative:  18165
#
#
#
#  021199f8f35064dfe7be5816d12c8a74.json
#
# true_positive:  1217
#  false_positive:  3
# false_negative: 220
# true_negative:  14613
#
#
#
#  3487a2d4b3c2632b162a585911d4278e.json
#
# true_positive:  1313
#  false_positive:  3
# false_negative: 215
# true_negative:  14858
#
#
#
#  1a449534946a406405ba113e01cf8a9f.json
#
# true_positive:  1372
#  false_positive:  3
# false_negative: 196
# true_negative:  15186
#
#
#
#  2e1c62cf223a2f57037dd209af7e18c8.json
#
# true_positive:  1231
#  false_positive:  3
# false_negative: 191
# true_negative:  14564
#
#
#
#  3a2a2cae49814905712a65d26757a6e2.json
#
# true_positive:  1945
#  false_positive:  15
# false_negative: 227
# true_negative:  17658
#
#
#
#  17d3daf4117af0f170ad66aa0e719850.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14506
#
#
#
#  13e6cc060d1b481cd999f6240e624c54.json
#
# true_positive:  1223
#  false_positive:  3
# false_negative: 191
# true_negative:  14508
#
#
#
#  170fa3d82a085d75ca370b104bf1eab2.json
#
# true_positive:  1307
#  false_positive:  3
# false_negative: 191
# true_negative:  14840
#
#
#
#  2ea91cd11f3484729716c2ef3582cc35.json
#
# true_positive:  1244
#  false_positive:  3
# false_negative: 193
# true_negative:  14613
#
#
#
#  19b21c0c14efca683e867e09d43b2901.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 190
# true_negative:  14279
#
#
#
#  3d6f431791cbecdd929d54f242302dca.json
#
# true_positive:  1250
#  false_positive:  3
# false_negative: 191
# true_negative:  14609
#
#
#
#  188d515210a9b7ae906a9c77fc19d64d.json
#
# true_positive:  1215
#  false_positive:  3
# false_negative: 191
# true_negative:  14484
#
#
#
#  129c6cdd7603b93eb88fca68819b3da8.json
#
# true_positive:  1430
#  false_positive:  3
# false_negative: 191
# true_negative:  15325
#
#
#
#  1ec6c7d9cb2c0c675a4093dbac870a06.json
#
# true_positive:  1691
#  false_positive:  15
# false_negative: 207
# true_negative:  16812
#
#
#
#  099af7a6c2649c2ff44a48cafdd888e3.json
#
# true_positive:  1679
#  false_positive:  15
# false_negative: 230
# true_negative:  16801
#
#
#
#  0f608b92b874854fb7615d8a008bf00c.json
#
# true_positive:  1235
#  false_positive:  3
# false_negative: 195
# true_negative:  14620
#
#
#
#  3cb6d7728c7101f5d639b30754dce9ea.json
#
# true_positive:  1270
#  false_positive:  3
# false_negative: 191
# true_negative:  14685
#
#
#
#  2aed0506290105533d52bc17bde6b05c.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  2df706de6056dca904f1c18ea57191d9.json
#
# true_positive:  1249
#  false_positive:  3
# false_negative: 191
# true_negative:  14578
#
#
#
#  08488b9cee30c189bb5c8da32f213c98.json
#
# true_positive:  1446
#  false_positive:  15
# false_negative: 194
# true_negative:  15678
#
#
#
#  3cd4ad85daf88dd3972ac8ee0d57799a.json
#
# true_positive:  1247
#  false_positive:  3
# false_negative: 191
# true_negative:  14660
#
#
#
#  11441d3f955e584da57b2413e3343e44.json
#
# true_positive:  1474
#  false_positive:  3
# false_negative: 199
# true_negative:  15401
#
#
#
#  12900986585d9d58f965bf66318dd9e0.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 191
# true_negative:  14561
#
#
#
#  27c4a50ed731e612c966353480fa76b2.json
#
# true_positive:  1231
#  false_positive:  3
# false_negative: 191
# true_negative:  14548
#
#
#
#  327bd860e7e708a8520b9e14474a5be2.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 192
# true_negative:  14576
#
#
#
#  2b63a3a5a13a7b9c1a85444612ee5ddc.json
#
# true_positive:  1239
#  false_positive:  3
# false_negative: 191
# true_negative:  14620
#
#
#
#  2cc683effffd463269d049c733f7eb0e.json
#
# true_positive:  1222
#  false_positive:  3
# false_negative: 191
# true_negative:  14509
#
#
#
#  2c271cbd6a695c2641b7d2ec9aad2aff.json
#
# true_positive:  1676
#  false_positive:  15
# false_negative: 195
# true_negative:  16551
#
#
#
#  23fa4fa5c446e01aa3cfa8899a23d649.json
#
# true_positive:  2148
#  false_positive:  15
# false_negative: 209
# true_negative:  19281
#
#
#
#  23d7092e5f8e8a24d9b470c5d519be6e.json
#
# true_positive:  1278
#  false_positive:  3
# false_negative: 192
# true_negative:  14756
#
#
#
#  0017202155c1007cab68751f3648b538.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14571
#
#
#
#  372c4eba2a198e5576802fcd161407da.json
#
# true_positive:  1357
#  false_positive:  3
# false_negative: 191
# true_negative:  15110
#
#
#
#  2c162c6681c5e45dda61e0ed1e40763e.json
#
# true_positive:  1241
#  false_positive:  3
# false_negative: 191
# true_negative:  14570
#
#
#
#  3aee71ac0d49467e473bd1a344165153.json
#
# true_positive:  1162
#  false_positive:  3
# false_negative: 189
# true_negative:  14251
#
#
#
#  33228ca7274d1221d481828e415fa88b.json
#
# true_positive:  1174
#  false_positive:  3
# false_negative: 191
# true_negative:  14301
#
#
#
#  07128f778aefbd1b286e2c22ad85b530.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 192
# true_negative:  14618
#
#
#
#  1142cb1329f19c8fc45c8b29fc86e8e5.json
#
# true_positive:  1580
#  false_positive:  15
# false_negative: 196
# true_negative:  16246
#
#
#
#  2a9d1bbc3e6c81c0ff2ff499aea85843.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14587
#
#
#
#  2841568dc88449f84c988882ac6cc54e.json
#
# true_positive:  1508
#  false_positive:  15
# false_negative: 195
# true_negative:  15919
#
#
#
#  03e9522eaf6d3ab31870bf3a45d24072.json
#
# true_positive:  1250
#  false_positive:  3
# false_negative: 197
# true_negative:  14731
#
#
#
#  3c158932b72f20b9ad03f7b4d87ce8e5.json
#
# true_positive:  1248
#  false_positive:  3
# false_negative: 191
# true_negative:  14643
#
#
#
#  3a3fcd207a6c917d30e8338965ae177b.json
#
# true_positive:  1261
#  false_positive:  3
# false_negative: 192
# true_negative:  14661
#
#
#
#  1afa41bb4aede85bf4a5aab955cb8898.json
#
# true_positive:  1666
#  false_positive:  15
# false_negative: 223
# true_negative:  16677
#
#
#
#  28e138c7cc96e9af4d8d940e8c111ed7.json
#
# true_positive:  1366
#  false_positive:  15
# false_negative: 190
# true_negative:  15298
#
#
#
#  3cb74fdb3d23e6d147003a4caa7c9ffb.json
#
# true_positive:  1445
#  false_positive:  15
# false_negative: 193
# true_negative:  15712
#
#
#
#  233b846c0a2cbd4445d45af2b9529087.json
#
# true_positive:  1165
#  false_positive:  3
# false_negative: 191
# true_negative:  14278
#
#
#
#  24724398dc27b4f88d4613a4ad3e8ec5.json
#
# true_positive:  1111
#  false_positive:  3
# false_negative: 187
# true_negative:  14032
#
#
#
#  03d47e836ef9c980b82db1a4e0ce1138.json
#
# true_positive:  1445
#  false_positive:  15
# false_negative: 212
# true_negative:  15741
#
#
#
#  1e30a1244428587e1b405b417e909f0c.json
#
# true_positive:  1219
#  false_positive:  3
# false_negative: 191
# true_negative:  14512
#
#
#
#  2e193ebaa7185990593f596c27f63f9e.json
#
# true_positive:  1169
#  false_positive:  3
# false_negative: 193
# true_negative:  14352
#
#
#
#  2cd6aba9217cc8a885f64e362654908d.json
#
# true_positive:  1175
#  false_positive:  3
# false_negative: 189
# true_negative:  14286
#
#
#
#  052ab8cb4c4484242acde5b6085b2b7a.json
#
# true_positive:  1244
#  false_positive:  3
# false_negative: 192
# true_negative:  14630
#
#
#
#  015eb6dde221f7244e387f0f563a3da7.json
#
# true_positive:  1504
#  false_positive:  15
# false_negative: 195
# true_negative:  15875
#
#
#
#  3d895295f26cdc8e299417caa5ec66f1.json
#
# true_positive:  1184
#  false_positive:  3
# false_negative: 194
# true_negative:  14400
#
#
#
#  0980e7e7416cfb2a4e97d3b38deffa0c.json
#
# true_positive:  1143
#  false_positive:  3
# false_negative: 187
# true_negative:  14128
#
#
#
#  3c386f00336837725888eb87e2d83e23.json
#
# true_positive:  1207
#  false_positive:  3
# false_negative: 189
# true_negative:  14430
#
#
#
#  19c358bfb71cc669fb95a0ef16da2b18.json
#
# true_positive:  1619
#  false_positive:  3
# false_negative: 196
# true_negative:  16107
#
#
#
#  2d7f18fb2293d2c9f769fc9afebc01fd.json
#
# true_positive:  1348
#  false_positive:  3
# false_negative: 193
# true_negative:  15037
#
#
#
#  1e67d82cf8de7de9084cd38b428d76bb.json
#
# true_positive:  1520
#  false_positive:  15
# false_negative: 194
# true_negative:  15956
#
#
#
#  2fe1213d8cfd9cd87c9157858839cb1d.json
#
# true_positive:  1166
#  false_positive:  3
# false_negative: 189
# true_negative:  14295
#
#
#
#  34751376827ecf64db09eeec3e3aa06c.json
#
# true_positive:  1232
#  false_positive:  3
# false_negative: 192
# true_negative:  14562
#
#
#
#  314ea54cb5bcda0a32f7a243a74f737a.json
#
# true_positive:  1499
#  false_positive:  15
# false_negative: 213
# true_negative:  15878
#
#
#
#  091032a57a5232d70a0a5705abdfd328.json
#
# true_positive:  1244
#  false_positive:  3
# false_negative: 191
# true_negative:  14647
#
#
#
#  25e02c3dfa470eccd9ba576718a096ea.json
#
# true_positive:  1169
#  false_positive:  3
# false_negative: 189
# true_negative:  14308
#
#
#
#  35b1593cb22c3472150c2a931903bae1.json
#
# true_positive:  1352
#  false_positive:  3
# false_negative: 253
# true_negative:  15021
#
#
#
#  21eee6adbeaff54d3e874bf24e9d4b3d.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 190
# true_negative:  14267
#
#
#
#  07049fb190cf95d630f2cbac5217b3dc.json
#
# true_positive:  1197
#  false_positive:  3
# false_negative: 189
# true_negative:  14472
#
#
#
#  33cd16669103e51b531fb6f73de6c41c.json
#
# true_positive:  1812
#  false_positive:  15
# false_negative: 233
# true_negative:  17481
#
#
#
#  08637fdec1f05e2d839025c6e8baa2a4.json
#
# true_positive:  1461
#  false_positive:  15
# false_negative: 193
# true_negative:  15712
#
#
#
#  15bc195d038734563f0b9bf8941a540d.json
#
# true_positive:  1524
#  false_positive:  15
# false_negative: 237
# true_negative:  16037
#
#
#
#  35c9b404bfe79df9e80d9ad0136265bc.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  11dec9abc469c7bec646b39d6e1f0832.json
#
# true_positive:  1273
#  false_positive:  3
# false_negative: 194
# true_negative:  14727
#
#
#
#  2cb39fe8c0666444b80a679eef72099f.json
#
# true_positive:  1273
#  false_positive:  3
# false_negative: 191
# true_negative:  14714
#
#
#
#  370736d57cb0987f98c7876c661678df.json
#
# true_positive:  2456
#  false_positive:  15
# false_negative: 206
# true_negative:  19968
#
#
#
#  3d681aefdf75938ed3b83b25f853c2e9.json
#
# true_positive:  1238
#  false_positive:  3
# false_negative: 191
# true_negative:  14573
#
#
#
#  1ed0989e1783bb1824e16e2a1b16e115.json
#
# true_positive:  1321
#  false_positive:  3
# false_negative: 213
# true_negative:  15028
#
#
#
#  371f05c8cf0c8237207350fd2e5ca22e.json
#
# true_positive:  1615
#  false_positive:  15
# false_negative: 196
# true_negative:  16323
#
#
#
#  01573d7014bf5cb38ba179f553609824.json
#
# true_positive:  1245
#  false_positive:  3
# false_negative: 191
# true_negative:  14582
#
#
#
#  19abc28e6c736d4dd025d6c37b3b87bf.json
#
# true_positive:  1261
#  false_positive:  3
# false_negative: 191
# true_negative:  14646
#
#
#
#  2a48ea88cf1d210b28ddb5eed370485d.json
#
# true_positive:  1213
#  false_positive:  3
# false_negative: 189
# true_negative:  14424
#
#
#
#  200aba2555a777533aa06bb16a73c8c1.json
#
# true_positive:  1482
#  false_positive:  3
# false_negative: 198
# true_negative:  16098
#
#
#
#  234ac8594b4801b7fd06a2fa77e1db0d.json
#
# true_positive:  1365
#  false_positive:  3
# false_negative: 191
# true_negative:  14974
#
#
#
#  13ef89465eed7c0c9075ad43483848dd.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  3a41da5c689ab756f3a331727d7272c2.json
#
# true_positive:  1204
#  false_positive:  3
# false_negative: 191
# true_negative:  14447
#
#
#
#  2cd2ae9c0823e3fc346d7b918779eb8d.json
#
# true_positive:  1452
#  false_positive:  3
# false_negative: 194
# true_negative:  15268
#
#
#
#  28648ff640d69f442d43dc9660b0ecfe.json
#
# true_positive:  1440
#  false_positive:  15
# false_negative: 193
# true_negative:  15669
#
#
#
#  0d836e18fddecd2d6e0eb7177d304f78.json
#
# true_positive:  1235
#  false_positive:  3
# false_negative: 189
# true_negative:  14674
#
#
#
#  31d274eb1adb0a7721d6e47109ddee09.json
#
# true_positive:  1259
#  false_positive:  3
# false_negative: 191
# true_negative:  14632
#
#
#
#  0b712fbbef0e5d87dc832887c2b6f7b3.json
#
# true_positive:  1162
#  false_positive:  3
# false_negative: 189
# true_negative:  14267
#
#
#
#  2492bfcba22d20654c458191d1fb3a0e.json
#
# true_positive:  1232
#  false_positive:  3
# false_negative: 191
# true_negative:  14531
#
#
#
#  270c4e63b8a9a72f504f3e3c5e54d5a4.json
#
# true_positive:  1548
#  false_positive:  15
# false_negative: 195
# true_negative:  15975
#
#
#
#  0010ab8aa396a8b6fb626fc8b342952c.json
#
# true_positive:  1224
#  false_positive:  3
# false_negative: 191
# true_negative:  14491
#
#
#
#  267852ed22e6745a0689612613b2cd74.json
#
# true_positive:  1654
#  false_positive:  15
# false_negative: 204
# true_negative:  16532
#
#
#
#  1f54415bda95e8f06bb81fd927aa080b.json
#
# true_positive:  1239
#  false_positive:  3
# false_negative: 191
# true_negative:  14572
#
#
#
#  29001abcae83eb482c9221a075e69c72.json
#
# true_positive:  1288
#  false_positive:  3
# false_negative: 192
# true_negative:  14730
#
#
#
#  12867154e8941ec358803c0f115b6431.json
#
# true_positive:  1217
#  false_positive:  3
# false_negative: 191
# true_negative:  14498
#
#
#
#  3465c5e3e1fad33634da35b20d248520.json
#
# true_positive:  1614
#  false_positive:  15
# false_negative: 195
# true_negative:  16325
#
#
#
#  21e93775e311e91e768dcc2dc0d15e7d.json
#
# true_positive:  1207
#  false_positive:  3
# false_negative: 192
# true_negative:  14459
#
#
#
#  2c37c96f76d6a8ac507c0da54d299ee3.json
#
# true_positive:  1191
#  false_positive:  3
# false_negative: 193
# true_negative:  14410
#
#
#
#  3675b2a2036882666e3ce13685dc4f9e.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  0345e1e1a88be136caabc83e0179b3e6.json
#
# true_positive:  1605
#  false_positive:  15
# false_negative: 198
# true_negative:  16283
#
#
#
#  2f638681674b2b4b0c9301eac451793d.json
#
# true_positive:  1505
#  false_positive:  15
# false_negative: 195
# true_negative:  15906
#
#
#
#  3720ffa11b196d3c54a24e2865533c8b.json
#
# true_positive:  1485
#  false_positive:  15
# false_negative: 195
# true_negative:  15782
#
#
#
#  1529abf2ef2981cdf247e9fa644b4a27.json
#
# true_positive:  1220
#  false_positive:  3
# false_negative: 191
# true_negative:  14495
#
#
#
#  27b80bccc01caaecbf3b11ee24341f0b.json
#
# true_positive:  1477
#  false_positive:  15
# false_negative: 195
# true_negative:  15806
#
#
#
#  1201d4e7a2272d1d4f601ca58c8151c9.json
#
# true_positive:  1176
#  false_positive:  3
# false_negative: 191
# true_negative:  14315
#
#
#
#  3afb4142b522ed46ae9bb9a3c3c0666a.json
#
# true_positive:  1532
#  false_positive:  15
# false_negative: 196
# true_negative:  16038
#
#
#
#  03d7f537a0e7578ef3d785774ed36d70.json
#
# true_positive:  1179
#  false_positive:  3
# false_negative: 189
# true_negative:  14314
#
#
#
#  24725a22ec765aff8570ddf3c2e87cc1.json
#
# true_positive:  1317
#  false_positive:  3
# false_negative: 191
# true_negative:  14926
#
#
#
#  1e1c44aa5ab93d2538d7e06c08719e1e.json
#
# true_positive:  1747
#  false_positive:  15
# false_negative: 196
# true_negative:  16911
#
#
#
#  33d0bfc92c0f2e9b2ff3636c013ed730.json
#
# true_positive:  1474
#  false_positive:  15
# false_negative: 193
# true_negative:  15731
#
#
#
#  248656b605e4a73eebadaea97df78fc5.json
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 189
# true_negative:  14266
#
#
#
#  3f4c383ec63039cc17290ad3ff1da7ab.json
#
# true_positive:  1179
#  false_positive:  3
# false_negative: 192
# true_negative:  14407
#
#
#
#  312c4156ac5071634df92ebf149b4d47.json
#
# true_positive:  1272
#  false_positive:  3
# false_negative: 192
# true_negative:  14682
#
#
#
#  1741f73e5f344824d4e596efe7ec68b4.json
#
# true_positive:  1846
#  false_positive:  15
# false_negative: 208
# true_negative:  17488
#
#
#
#  307fd6a4d047515a3eebfd7686f8e66f.json
#
# true_positive:  1247
#  false_positive:  3
# false_negative: 190
# true_negative:  14789
#
#
#
#  2adc29d9e7a1ce090ada6f0d49020eff.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  3b98fcb4d65b81f5576ee22212d09efa.json
#
# true_positive:  1527
#  false_positive:  15
# false_negative: 232
# true_negative:  16119
#
#
#
#  0ea0344deeefadbe03cce96af8d3d0e7.json
#
# true_positive:  1549
#  false_positive:  15
# false_negative: 195
# true_negative:  16086
#
#
#
#  3c3e364acc548320a5b3a01ebc33586a.json
#
# true_positive:  1550
#  false_positive:  3
# false_negative: 226
# true_negative:  16178
#
#
#
# ...
#
# true_positive:  1163
#  false_positive:  3
# false_negative: 195
# true_negative:  14324
#
#
#
#  25dc440a9d9ba7759c0fd1bbd653b132.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 212
# true_negative:  14468
#
#
#
#  11e9b84f470a3a688dc79489ee10508a.json
#
# true_positive:  2154
#  false_positive:  15
# false_negative: 210
# true_negative:  19034
#
#
#
#  17cfcf89ffcd43c615b2b1d5176d54f3.json
#
# true_positive:  1567
#  false_positive:  15
# false_negative: 210
# true_negative:  16229
#
#
#
#  33e38489f49a0198f31f87fa10272355.json
#
# true_positive:  1218
#  false_positive:  3
# false_negative: 191
# true_negative:  14497
#
#
#
#  07b75863dff5383871db88d59a862ddc.json
#
# true_positive:  1223
#  false_positive:  3
# false_negative: 193
# true_negative:  14538
#
#
#
#  000af41691133a1dd4bdb2e77167adb6.json
#
# true_positive:  1246
#  false_positive:  3
# false_negative: 191
# true_negative:  14661
#
#
#
#  23401cbd329b4a1eabeb7398765e41d4.json
#
# true_positive:  1179
#  false_positive:  3
# false_negative: 189
# true_negative:  14362
#
#
#
#  1746e2d733e7ff9d70b15e8037ea4fe7.json
#
# true_positive:  1528
#  false_positive:  15
# false_negative: 197
# true_negative:  15977
#
#
#
#  0006bad00fcb2abffdc97d71b8151979.json
#
# true_positive:  1164
#  false_positive:  3
# false_negative: 189
# true_negative:  14281
#
#
#
#  08ecc6c4ff4e2d2bb1522aea44f609ed.json
#
# true_positive:  1248
#  false_positive:  3
# false_negative: 191
# true_negative:  14643
#
#
#
#  2cd2c88423dba5dbca284fd1682d9c4d.json
#
# true_positive:  1789
#  false_positive:  15
# false_negative: 201
# true_negative:  17232
#
#
#
#  1a64384760fade4d6eadc55594cb08c5.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 209
# true_negative:  14649
#
#
#
#  1ffb94b820fc9ce9cb6d83979d3486c3.json
#
# true_positive:  1217
#  false_positive:  3
# false_negative: 191
# true_negative:  14514
#
#
#
#  0ffecf6123babb02f302094269f16417.json
#
# true_positive:  1231
#  false_positive:  3
# false_negative: 191
# true_negative:  14532
#
#
#
#  3ce28b98f7cdc9ee871a31a0037d4909.json
#
# true_positive:  1604
#  false_positive:  15
# false_negative: 203
# true_negative:  16391
#
#
#
#  1275851878f70d317bc24f6f80517859.json
#
# true_positive:  1176
#  false_positive:  3
# false_negative: 189
# true_negative:  14301
#
#
#
#  3ece35ee4a10f15264a1fbb1479b2270.json
#
# true_positive:  1628
#  false_positive:  15
# false_negative: 197
# true_negative:  16437
#
#
#
#  2141a0a82f9d137376447135453386e7.json
#
# true_positive:  1444
#  false_positive:  15
# false_negative: 193
# true_negative:  15729
#
#
#
#  3aece3856b826e332e7b2fedc07e3cde.json
#
# true_positive:  1215
#  false_positive:  3
# false_negative: 191
# true_negative:  14500
#
#
#
#  23ec675214cf8bd127337e58679f20f9.json
#
# true_positive:  1181
#  false_positive:  3
# false_negative: 189
# true_negative:  14328
#
#
#
#  25e43ee267e0f8569f6381e0b485ed08.json
#
# true_positive:  1167
#  false_positive:  3
# false_negative: 189
# true_negative:  14294
#
#
#
#  29ad2b271fce91b243fd1d36ee73d15f.json
#
# true_positive:  1258
#  false_positive:  3
# false_negative: 191
# true_negative:  14633
#
#
#
#  15d7c7628e87b6ebb0e0f410a3533353.json
#
# true_positive:  1213
#  false_positive:  3
# false_negative: 191
# true_negative:  14486
#
#
#
#  2e0a8e1bfbc8e939a9309e92df5f4404.json
#
# true_positive:  1748
#  false_positive:  15
# false_negative: 228
# true_negative:  16958
#
#
#
#  13ca352289da83497351387d0da3305f.json
#
# true_positive:  1303
#  false_positive:  3
# false_negative: 192
# true_negative:  14859
#
#
#
#  266870753af0f4cbc3d7bafa25708240.json
#
# true_positive:  1198
#  false_positive:  3
# false_negative: 190
# true_negative:  14470
#
#
#
#  2cbdd23441953377d9ea7e897d587905.json
#
# true_positive:  1218
#  false_positive:  3
# false_negative: 191
# true_negative:  14513
#
#
#
#  2f41cced46f094f08ef8e046a83f3814.json
#
# true_positive:  1134
#  false_positive:  3
# false_negative: 187
# true_negative:  14105
#
#
#
#  13ed2d32290c4aee6f438bb37e56d12b.json
#
# true_positive:  1715
#  false_positive:  15
# false_negative: 229
# true_negative:  16830
#
#
#
#  1ae798fb042f8bc16478eeea9ca6c466.json
#
# true_positive:  1430
#  false_positive:  15
# false_negative: 194
# true_negative:  15614
#
#
#
#  35d6c77dfe009940d0794380c0f4efa7.json
#
# true_positive:  1176
#  false_positive:  3
# false_negative: 189
# true_negative:  14301
#
#
#
#  11f2380df8016a8d5593cac051a55255.json
#
# true_positive:  1599
#  false_positive:  15
# false_negative: 195
# true_negative:  16228
#
#
#
#  21fcc10898d5e550f5af3340fa4b42af.json
#
# true_positive:  1208
#  false_positive:  3
# false_negative: 192
# true_negative:  14426
#
#
#
#  0b80261682320ef872dea79eb60c2c91.json
#
# true_positive:  1154
#  false_positive:  3
# false_negative: 190
# true_negative:  14226
#
#
#
#  17e235177f81831745c2e84595f5e5f9.json
#
# true_positive:  1506
#  false_positive:  15
# false_negative: 200
# true_negative:  15852
#
#
#
#  0662297d71391c96234d2c217a5db588.json
#
# true_positive:  1259
#  false_positive:  3
# false_negative: 195
# true_negative:  14708
#
#
#
#  14672b5eb995ab92d0e7b37c097d03a9.json
#
# true_positive:  1229
#  false_positive:  3
# false_negative: 207
# true_negative:  14566
#
#
#
#  1279af8945863d158fdea68286af3ea1.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 189
# true_negative:  14347
#
#
#
#  0ac712a24f12976a545cf4708f4bbebf.json
#
# true_positive:  1187
#  false_positive:  3
# false_negative: 230
# true_negative:  14457
#
#
#
#  35119c4c17b6e24b82316b729687dd1a.json
#
# true_positive:  1442
#  false_positive:  15
# false_negative: 193
# true_negative:  15683
#
#
#
#  2c0722e1bbd10cf669bb32f8220bdd06.json
#
# true_positive:  1345
#  false_positive:  17
# false_negative: 197
# true_negative:  15374
#
#
#
#  2f692f8a8501a657e37e54046ea372f4.json
#
# true_positive:  1159
#  false_positive:  3
# false_negative: 189
# true_negative:  14238
#
#
#
#  25ca6e663995765c8f65d2ace5791ba2.json
#
# true_positive:  1536
#  false_positive:  15
# false_negative: 201
# true_negative:  16077
#
#
#
#  1017d25f109c3412240bf582123bc8be.json
#
# true_positive:  1327
#  false_positive:  3
# false_negative: 191
# true_negative:  15156
#
#
#
#  2e9e7d2d868d21395ffb830b011063b2.json
#
# true_positive:  1591
#  false_positive:  15
# false_negative: 193
# true_negative:  16286
#
#
#
#  2854b054258f0586febb7ca875d7e10b.json
#
# true_positive:  1226
#  false_positive:  3
# false_negative: 192
# true_negative:  14536
#
#
#
#  07015c277eadc443f8ef1e337d17ae0a.json
#
# true_positive:  1630
#  false_positive:  15
# false_negative: 195
# true_negative:  16357
#
#
#
#  3c3bfd2f8bf976be5a15f5fc7e78914d.json
#
# true_positive:  1527
#  false_positive:  15
# false_negative: 196
# true_negative:  15995
#
#
#
#  07aab8a052822b4f50b88509fb141592.json
#
# true_positive:  1369
#  false_positive:  3
# false_negative: 199
# true_negative:  15282
#
#
#
#  3b96e0b2d54a9df181d5bb00fc2853db.json
#
# true_positive:  1177
#  false_positive:  3
# false_negative: 189
# true_negative:  14364
#
#
#
#  1909d87b051e2a435c673f13ed0b8541.json
#
# true_positive:  1251
#  false_positive:  3
# false_negative: 191
# true_negative:  14624
#
#
#
#  313e76655c7bf4d58a8934502ca028b0.json
#
# true_positive:  1199
#  false_positive:  3
# false_negative: 189
# true_negative:  14422
#
#
#
#  1539a798785d62344f75abecc1185fa2.json
#
# true_positive:  1161
#  false_positive:  3
# false_negative: 189
# true_negative:  14252
#
#
#
#  21e1e0abfdd070fe64eebfefd0864dea.json
#
# true_positive:  1638
#  false_positive:  15
# false_negative: 196
# true_negative:  16524
#
#
#
#  38661ef68a18396f385ee1410449b631.json
#
# true_positive:  1241
#  false_positive:  3
# false_negative: 191
# true_negative:  14570
#
#
#
#  22afb6c84a56d8fe620b74b017d74b42.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14555
#
#
#
#  014eccc95796cd16fe59fd18a2c866f0.json
#
# true_positive:  1181
#  false_positive:  3
# false_negative: 191
# true_negative:  14310
#
#
#
#  1e155496d9123e1b2e570cb18746bbc8.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14506
#
#
#
#  1685a2351b0d0a0b8159d63d9dd2f8dd.json
#
# true_positive:  1160
#  false_positive:  3
# false_negative: 189
# true_negative:  14253
#
#
#
#  192ee76a2fd6583e6dc6c9e895fe0b85.json
#
# true_positive:  1243
#  false_positive:  3
# false_negative: 191
# true_negative:  14568
#
#
#
#  014e43440e6cbe4b622d59ab104ab32c.json
#
# true_positive:  1225
#  false_positive:  3
# false_negative: 191
# true_negative:  14506
#
#
#
#  06fe7f3e6918c2f4f51781ba3857a458.json
#
# true_positive:  1512
#  false_positive:  15
# false_negative: 195
# true_negative:  15947
#
#
#
#  2a3f98b4c6c72ca9d45ca63f23318b41.json
#
# true_positive:  1564
#  false_positive:  3
# false_negative: 191
# true_negative:  15687
#
#
#
#  0d6f0b0ae068debf0d4a2a8a6d029d0b.json
#
# true_positive:  1186
#  false_positive:  3
# false_negative: 217
# true_negative:  14471
#
#
#
#  0ccfc73d2a769cd4fb138fd47adfac42.json
#
# true_positive:  1216
#  false_positive:  3
# false_negative: 249
# true_negative:  14729
#
#
#
#  099dd9fdcde698cf5c1fcd859162128a.json
#
# true_positive:  1219
#  false_positive:  3
# false_negative: 191
# true_negative:  14496
#
#
#
#  3003f69b2fbee5a2da751afe5487850f.json
#
# true_positive:  1271
#  false_positive:  3
# false_negative: 192
# true_negative:  14731
#
#
#
#  28d8dc86cdeb8d705c9e822b6e9b5171.json
#
# true_positive:  1502
#  false_positive:  15
# false_negative: 195
# true_negative:  16005
#
#
#
#  2c266cb4cf80fd1c970cc801d1e0342f.json
#
# true_positive:  1170
#  false_positive:  3
# false_negative: 190
# true_negative:  14290
#
#
#
#  0ce87e7c7e31401cc4ef0fe37a505f1d.json
#
# true_positive:  1275
#  false_positive:  3
# false_negative: 191
# true_negative:  14696
#
#
#
#  3b87c8e4151951096bc759eb3a9694ba.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 189
# true_negative:  14299
#
#
#
#  0c3b7ad6960f15a4a351838092bb07ed.json
#
# true_positive:  1564
#  false_positive:  15
# false_negative: 211
# true_negative:  16151
#
#
#
#  17e7d0262f7b498aa5385db17c43d78a.json
#
# true_positive:  1533
#  false_positive:  3
# false_negative: 221
# true_negative:  16360
#
#
#
#  31201c7b24b4499051db85e9cc979724.json
#
# true_positive:  1133
#  false_positive:  3
# false_negative: 188
# true_negative:  14105
#
#
#
#  2a480f27e1abff2ea25ac47dbd48d8a0.json
#
# true_positive:  1344
#  false_positive:  3
# false_negative: 193
# true_negative:  14977
#
#
#
#  2903a7b5f8a825a7ee70380372a4ffc6.json
#
# true_positive:  1181
#  false_positive:  3
# false_negative: 241
# true_negative:  14484
#
#
#
#  3a55bf9734120e1ff207a3a3d60469b8.json
#
# true_positive:  1510
#  false_positive:  15
# false_negative: 218
# true_negative:  16086
#
#
#
#  332e9aae658e34fc9f0baaeded0c3091.json
#
# true_positive:  1293
#  false_positive:  3
# false_negative: 192
# true_negative:  14789
#
#
#
#  052518315e8d1095a4d15f9643715943.json
#
# true_positive:  1491
#  false_positive:  15
# false_negative: 197
# true_negative:  15902
#
#
#
#  390b9c9cf1b627ca358d00daf58b730e.json
#
# true_positive:  1843
#  false_positive:  15
# false_negative: 223
# true_negative:  17364
#
#
#
#  0b75882f77ac6505ef4b0a953c6d4155.json
#
# true_positive:  1436
#  false_positive:  15
# false_negative: 193
# true_negative:  15593
#
#
#
#  399d1abbf3fefbb008aef1ebca414f8e.json
#
# true_positive:  1232
#  false_positive:  3
# false_negative: 191
# true_negative:  14531
#
#
#
#  2c2953474eb6e798e04fa2347cbbb2f5.json
#
# true_positive:  1224
#  false_positive:  3
# false_negative: 191
# true_negative:  14523
#
#
#
#  2e986e261a63cc5a5803f3cbb3f44392.json
#
# true_positive:  1328
#  false_positive:  3
# false_negative: 218
# true_negative:  15064
#
#
#
#  21f6ce96a3c38c480cddc8f06d719dcc.json
#
# true_positive:  1675
#  false_positive:  15
# false_negative: 197
# true_negative:  16502
#
#
#
#  08ecbab171a0e3907055f44736c0b5d0.json
#
# true_positive:  1201
#  false_positive:  3
# false_negative: 190
# true_negative:  14387
#
#
#
#  329610e4ebca70996b8eceee238377f6.json
#
# true_positive:  1829
#  false_positive:  15
# false_negative: 238
# true_negative:  17379
#
#
#
#  2a1ef23aea2ed28b7f23875c2e7d336e.json
#
# true_positive:  1487
#  false_positive:  15
# false_negative: 195
# true_negative:  15828
#
#
#
#  1897a3aaba220382437538ecd583161c.json
#
# true_positive:  1239
#  false_positive:  3
# false_negative: 191
# true_negative:  14572
#
#
#
#  29917781c14db7dc6e1ba266568d784c.json
#
# true_positive:  1689
#  false_positive:  3
# false_negative: 194
# true_negative:  16935
#
#
#
#  23394aed7550c1e1d9ce4d0fdc1f6494.json
#
# true_positive:  1484
#  false_positive:  15
# false_negative: 195
# true_negative:  15863
#
#
#
#  3d65f0a12aab236e2c00872d30fa8f0f.json
#
# true_positive:  1196
#  false_positive:  3
# false_negative: 190
# true_negative:  14456
#
#
#
#  2c297e66b97ae54c0763b682f5c5d316.json
#
# true_positive:  1749
#  false_positive:  15
# false_negative: 257
# true_negative:  17072
#
#
#
#  3664b6282f134f184bb198ad1383b536.json
#
# true_positive:  1513
#  false_positive:  3
# false_negative: 246
# true_negative:  15635
#
#
#
#  2498b1ec776caa21b3eb1670dc3256af.json
#
# true_positive:  1529
#  false_positive:  15
# false_negative: 195
# true_negative:  16026
#
#
#
#  097dabc2ad9eb19e1177f5f52941892d.json
#
# true_positive:  1341
#  false_positive:  3
# false_negative: 191
# true_negative:  14838
#
#
#
#  2fedadb0342a7f19aabcb360f1455330.json
#
# true_positive:  1309
#  false_positive:  3
# false_negative: 190
# true_negative:  14759
#
#
#
#  25b663b59f0722e58c6ad4d0d9ee9f03.json
#
# true_positive:  1518
#  false_positive:  15
# false_negative: 195
# true_negative:  15973
#
#
#
#  1cdd892a467e9e41ac16544a083e0ecd.json
#
# true_positive:  1164
#  false_positive:  3
# false_negative: 192
# true_negative:  14326
#
#
#
#  015fc12919b38eda6a074e19a1e9b7c1.json
#
# true_positive:  1189
#  false_positive:  3
# false_negative: 189
# true_negative:  14400
#
#
#
#  37b951ee1505eb65af86a20dcb3dcd81.json
#
# true_positive:  1220
#  false_positive:  3
# false_negative: 191
# true_negative:  14495
#
#
#
#  35d3c2377d7dece63cff8cd6cb0eb94e.json
#
# true_positive:  1680
#  false_positive:  15
# false_negative: 237
# true_negative:  16377
#
#
#
#  32a060e412f3191aa7152e8e7b5c7638.json
#
# true_positive:  1240
#  false_positive:  3
# false_negative: 191
# true_negative:  14571
#
#
#
#  2ad275c6766b5b22f2d0d4289248a289.json
#
# true_positive:  1490
#  false_positive:  3
# false_negative: 196
# true_negative:  15772
#
#
#
#  00c4fb43a41c7ad9fbcb93d9571d4f61.json
#
# true_positive:  1137
#  false_positive:  3
# false_negative: 190
# true_negative:  14115
#
#
#
#  17dee8f75b6d438b2a04bb4782293c5b.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 191
# true_negative:  14529
#
#
#
#  1161c6d6e98d0cfccb2bd7f38b35f1ae.json
#
# true_positive:  1496
#  false_positive:  15
# false_negative: 195
# true_negative:  15899
#
#
#
#  3f7271e056924efcce6a0159fa2c1590.json
#
# true_positive:  1183
#  false_positive:  3
# false_negative: 190
# true_negative:  14405
#
#
#
#  05283e6245d309f8306647f595499113.json
#
# true_positive:  1573
#  false_positive:  15
# false_negative: 196
# true_negative:  16173
#
#
#
#  35de6514a379883337123ba3d4b684a6.json
#
# true_positive:  1234
#  false_positive:  3
# false_negative: 190
# true_negative:  14626
#
#
#
#  3325935c7e7a04404ce295a3917f8a8e.json
#
# true_positive:  1702
#  false_positive:  15
# false_negative: 198
# true_negative:  16698
#
#
#
#  0eaaf4b8d4eb4ec4a95d0d8a2330946b.json
#
# true_positive:  1245
#  false_positive:  3
# false_negative: 191
# true_negative:  14598
#
#
#
#  267faf5ba951afec4b404c7e6a4ad0fb.json
#
# true_positive:  1121
#  false_positive:  3
# false_negative: 189
# true_negative:  14084
#
#
#
#  149bf31482750833adc3cff29a30fe38.json
#
# true_positive:  1324
#  false_positive:  3
# false_negative: 193
# true_negative:  15045
#
#
#
#  248ca720bf14f03b4b10fcc45fdc3674.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 241
# true_negative:  14583
#
#
#
#  03e1aa846fd404f549c0d2b9784e3172.json
#
# true_positive:  1447
#  false_positive:  15
# false_negative: 193
# true_negative:  15694
#
#
#
#  3c153556cdf5a4045ba89b0c176a0abc.json
#
# true_positive:  1596
#  false_positive:  15
# false_negative: 195
# true_negative:  16343
#
#
#
#  14651edd53530621a27ee5343d67a088.json
#
# true_positive:  1173
#  false_positive:  3
# false_negative: 189
# true_negative:  14288
#
#
#
#  35bbfa53227712a4bfc1c23b5f94c400.json
#
# true_positive:  2258
#  false_positive:  3
# false_negative: 234
# true_negative:  17814
#
#
#
#  35301764a912801ccfdd774c25a8ab42.json
#
# true_positive:  1228
#  false_positive:  3
# false_negative: 191
# true_negative:  14535
#
#
#
#  267bbdd33bd077b0280cee4f48e662c9.json
#
# true_positive:  1291
#  false_positive:  3
# false_negative: 191
# true_negative:  14920
#
#
#
#  2e0184fa1882abfbd5fa7d3966a021b1.json
#
# true_positive:  1493
#  false_positive:  3
# false_negative: 221
# true_negative:  15696
#
#
#
#  1d79441d55405d425963341d6dcf9147.json
#
# true_positive:  1178
#  false_positive:  3
# false_negative: 189
# true_negative:  14347
