# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
ground_truth_json_dir = "/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/"
#   
predict_json_dir = "/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static_stripped/"  #'/home/raisul/ANALYSED_DATA/prob_disasm_x86_pe_msvc_O2_static/'
BIN_FILE_TYPE = "PE"
BIN_PATH = "/home/raisul/DATA/x86_pe_msvc_O2_static_stripped/"

# %%
def get_offsets(json_file_path):
    with open(json_file_path, "r") as file:
        data = json.load(file)
    return list(map(int,list(data.keys())))



def get_instructions(bin_file_path  ):
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    with open(bin_file_path, 'rb') as f:
        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":
        
                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
        except Exception as e:
                print("An error occurred:", e ,bin_file_path)
                return
    
        for byte_index in range(len(textSection)):
            try:    
    
                instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
                offset_inst[text_section_offset+byte_index] = instruction
                
                # if instruction:
                #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                # else:
                #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
    
            except Exception as e:
                print(traceback.print_exc() )
                print(e)
    return offset_inst

ground_truth__jsons  =  os.listdir(ground_truth_json_dir) 
ghidra_predict_jsons    =  os.listdir(predict_json_dir)


common_json_files = list(set(ground_truth__jsons) & set(ghidra_predict_jsons))
print(len(common_json_files))
common_json_files = common_json_files[0:1]
# common_json_files =['370cf902ac71f426c14725a24959e8de.json']
all_TP= all_FP= all_FN= all_TN = 0

for json_file_name in common_json_files:
    # print('\n\n\n',json_file_name)
    ground_truth_json_path =  os.path.join(ground_truth_json_dir, json_file_name)
    ghidra_predict_json_path =  os.path.join(predict_json_dir, json_file_name)
    ground_truth_offsets = get_offsets(ground_truth_json_path)
    predict_offsets = get_offsets(ghidra_predict_json_path)
    
    ground_truth_offsets_set = set(ground_truth_offsets)
    predict_offsets_set = set(predict_offsets)

    
    superset = set(range( min(ground_truth_offsets) , max(ground_truth_offsets) ) )
    
    true_positive = len(ground_truth_offsets_set&predict_offsets_set)
    false_positive = len(predict_offsets_set - ground_truth_offsets_set)
    false_negative = len( ground_truth_offsets_set -predict_offsets_set )
    true_negative = len( superset - ( ground_truth_offsets_set|predict_offsets_set)  )
    
    all_TP+=true_positive
    all_FP+=false_positive
    all_FN+=false_negative
    all_TN+=true_negative
    
    print('\ntrue_positive: ',true_positive , '\n false_positive: ',false_positive ,'\nfalse_negative:', false_negative , '\ntrue_negative: ',true_negative)

    
    bin_file_path = os.path.join(os.path.join(BIN_PATH ,  json_file_name.split('.')[0] ),  (json_file_name.split('.')[0]+ ('.exe' if BIN_FILE_TYPE == "PE" else '' )))
    exhaustive_disasm = get_instructions(bin_file_path)
    # print(exhaustive_disasm)
    if exhaustive_disasm:
      for offset in exhaustive_disasm:
          hash = '#' if offset in ground_truth_offsets else ' '
          dollar = '$' if offset in predict_offsets else ' '

          # if hash=='#' or dollar=='$':
          #     if exhaustive_disasm[offset].mnemonic!= 'int3':
          #         # pass
          #         print( hash , dollar , hex(offset), exhaustive_disasm[offset].mnemonic+ exhaustive_disasm[offset].op_str) #insn.mnemonic} {insn.op_str
          # if offset in predict_offsets and offset not in ground_truth_offsets :
          #     print('_'*130 , '>>')

          if(exhaustive_disasm[offset]):
              print(  hex(offset), " : ", exhaustive_disasm[offset].mnemonic+ " "+exhaustive_disasm[offset].op_str ,exhaustive_disasm[offset].size  ,hash , dollar, ) #insn.mnemonic} {insn.op_str
          else: 
              print(  hex(offset), " : ", 'Invalid ' ,hash , dollar, )
    else:
        print('exhaustive diasm none')
    # print(len(ground_truth_offsets) , len(predict_offsets))
    # false_negatives = list(set(ground_truth_offsets) - set(predict_offsets))
# Out:
# 456962
#
# true_positive:  1173
#  false_positive:  3
# false_negative: 190
# true_negative:  14303
#     0x400 int3  1
#     0x401 int3  1
#     0x402 int3  1
#     0x403 int3  1
#     0x404 int3  1
# #   0x405 jmp 0xc7c 5
#     0x406 jb 0x410 2
#     0x407 or byte ptr [rax], al 2
#     0x408 add byte ptr [rax], al 2
#     0x409 add cl, ch 2
# # $ 0x40a jmp 0x1660 5
#     0x40b push rcx 1
#     0x40c adc al, byte ptr [rax] 2
#     0x40d add byte ptr [rax], al 2
#     0x40e add cl, ch 2
# # $ 0x40f jmp 0x7b0 5
#     0x410 pushfq  1
#     0x411 add eax, dword ptr [rax] 2
#     0x412 add byte ptr [rax], al 2
#     0x413 add cl, ch 2
# # $ 0x414 jmp 0x1770 5
#     0x415 push rdi 1
#     0x416 adc eax, dword ptr [rax] 2
#     0x417 add byte ptr [rax], al 2
#     0x418 add cl, ch 2
# #   0x419 jmp 0xe00 5
#     0x41a loop 0x425 2
#     0x41b or dword ptr [rax], eax 2
#     0x41c add byte ptr [rax], al 2
#     0x41d add cl, ch 2
# # $ 0x41e jmp 0x1390 5
#     0x41f insd dword ptr [rdi], dx 1
#     0x420 sldt word ptr [rax] 3
#     0x421 add byte ptr [rax], al 2
#     0x422 add cl, ch 2
# #   0x423 jmp 0x1f18 5
#     0x424 None
#     0x425 sbb al, byte ptr [rax] 2
#     0x426 add byte ptr [rax], al 2
#     0x427 add cl, ch 2
# #   0x428 jmp 0x1774 5
#     0x429 adc r8d, dword ptr [r8] 3
#     0x42a adc eax, dword ptr [rax] 2
#     0x42b add byte ptr [rax], al 2
#     0x42c add cl, ch 2
# # $ 0x42d jmp 0x135c 5
#     0x42e sub cl, byte ptr [rdi] 2
#     0x42f sldt word ptr [rax] 3
#     0x430 add byte ptr [rax], al 2
#     0x431 add cl, ch 2
# # $ 0x432 jmp 0x1358 5
#     0x433 and dword ptr [rdi], ecx 2
#     0x434 sldt word ptr [rax] 3
#     0x435 add byte ptr [rax], al 2
#     0x436 add cl, ch 2
# # $ 0x437 jmp 0x1f10 5
#     0x438 None
#     0x439 sbb al, byte ptr [rax] 2
#     0x43a add byte ptr [rax], al 2
#     0x43b add cl, ch 2
# # $ 0x43c jmp 0x1f24 5
#     0x43d jrcxz 0x459 2
#     0x43e sbb al, byte ptr [rax] 2
#     0x43f add byte ptr [rax], al 2
#     0x440 add cl, ch 2
# #   0x441 jmp 0x30f0 5
#     0x442 stosb byte ptr [rdi], al 1
#     0x443 sub al, 0 2
#     0x444 add byte ptr [rax], al 2
#     0x445 add cl, ch 2
# # $ 0x446 jmp 0x1158 5
#     0x447 or eax, 0xe900000d 5
#     0x448 or eax, 0xf0e90000 5
#     0x449 add byte ptr [rax], al 2
#     0x44a add cl, ch 2
# # $ 0x44b jmp 0x1340 5
#     0x44c None
#     0x44d None
#     0x44e add byte ptr [rax], al 2
#     0x44f add cl, ch 2
# # $ 0x450 jmp 0x1360 5
#     0x451 or ecx, dword ptr [rdi] 2
#     0x452 sldt word ptr [rax] 3
#     0x453 add byte ptr [rax], al 2
#     0x454 add cl, ch 2
# # $ 0x455 jmp 0x1f1c 5
#     0x456 ret 0x1a 3
#     0x457 sbb al, byte ptr [rax] 2
#     0x458 add byte ptr [rax], al 2
#     0x459 add cl, ch 2
# #   0x45a jmp 0x1954 5
#     0x45b cmc  1
#     0x45c adc al, 0 2
#     0x45d add byte ptr [rax], al 2
#     0x45e add cl, ch 2
# #   0x45f jmp 0xc70 5
#     0x460 or al, 8 2
#     0x461 or byte ptr [rax], al 2
#     0x462 add byte ptr [rax], al 2
#     0x463 add cl, ch 2
# #   0x464 jmp 0x19b8 5
#     0x465 adc rax, 0x62e90000 6
#     0x466 adc eax, 0x62e90000 5
#     0x467 add byte ptr [rax], al 2
#     0x468 add cl, ch 2
# # $ 0x469 jmp 0x30d0 5
#     0x46a None
#     0x46b sub al, 0 2
#     0x46c add byte ptr [rax], al 2
#     0x46d add cl, ch 2
# # $ 0x46e jmp 0x1f14 5
#     0x46f movabs eax, dword ptr [0xb0ce900001a] 9
#     0x470 sbb al, byte ptr [rax] 2
#     0x471 add byte ptr [rax], al 2
#     0x472 add cl, ch 2
# # $ 0x473 jmp 0xf84 5
#     0x474 or al, 0xb 2
#     0x475 or eax, dword ptr [rax] 2
#     0x476 add byte ptr [rax], al 2
#     0x477 add cl, ch 2
# #   0x478 jmp 0x1f20 5
#     0x479 movabs dword ptr [0x11e2e900001a], eax 9
#     0x47a sbb al, byte ptr [rax] 2
#     0x47b add byte ptr [rax], al 2
#     0x47c add cl, ch 2
# #   0x47d jmp 0x1664 5
#     0x47e loop 0x491 2
#     0x47f adc dword ptr [rax], eax 2
#     0x480 add byte ptr [rax], al 2
#     0x481 add cl, ch 2
# #   0x482 jmp 0x182c 5
#     0x483 movsd dword ptr [rdi], dword ptr [rsi] 1
#     0x484 adc eax, dword ptr [rax] 2
#     0x485 add byte ptr [rax], al 2
#     0x486 add cl, ch 2
# #   0x487 jmp 0x1660 5
#     0x488 None
#     0x489 adc dword ptr [rax], eax 2
#     0x48a add byte ptr [rax], al 2
#     0x48b add cl, ch 2
# #   0x48c jmp 0x1a3c 5
#     0x48d stosd dword ptr [rdi], eax 1
#     0x48e adc eax, 0xf6e90000 5
#     0x48f add byte ptr [rax], al 2
#     0x490 add cl, ch 2
# # $ 0x491 jmp 0x138c 5
#     0x492 test byte ptr [rsi], 0 3
#     0x493 None
#     0x494 add byte ptr [rax], al 2
#     0x495 add cl, ch 2
# #   0x496 jmp 0x177c 5
#     0x497 loope 0x4ab 2
#     0x498 adc al, byte ptr [rax] 2
#     0x499 add byte ptr [rax], al 2
#     0x49a add cl, ch 2
# #   0x49b jmp 0xc24 5
#     0x49c test byte ptr [rdi], al 2
#     0x49d None
#     0x49e add byte ptr [rax], al 2
#     0x49f add cl, ch 2
# # $ 0x4a0 jmp 0x1124 5
#     0x4a1 jg 0x4af 2
#     0x4a2 or al, 0 2
#     0x4a3 add byte ptr [rax], al 2
#     0x4a4 add cl, ch 2
# # $ 0x4a5 jmp 0x1dd8 5
#     0x4a6 sbb dword ptr cs:[rax], eax 3
#     0x4a7 sbb dword ptr [rax], eax 2
#     0x4a8 add byte ptr [rax], al 2
#     0x4a9 add cl, ch 2
# # $ 0x4aa jmp 0x1034 5
#     0x4ab test dword ptr [rbx], ecx 2
#     0x4ac or eax, dword ptr [rax] 2
#     0x4ad add byte ptr [rax], al 2
#     0x4ae add cl, ch 2
# # $ 0x4af jmp 0x11c4 5
#     0x4b0 adc byte ptr [rip + 0x5fe90000], cl 6
#     0x4b1 or eax, 0x5fe90000 5
#     0x4b2 add byte ptr [rax], al 2
#     0x4b3 add cl, ch 2
# # $ 0x4b4 jmp 0x1f18 5
#     0x4b5 pop rdi 1
#     0x4b6 sbb al, byte ptr [rax] 2
#     0x4b7 add byte ptr [rax], al 2
#     0x4b8 add cl, ch 2
# #   0x4b9 jmp 0x7c0 5
#     0x4ba add al, byte ptr [rbx] 2
#     0x4bb add eax, dword ptr [rax] 2
#     0x4bc add byte ptr [rax], al 2
#     0x4bd add cl, ch 2
# #   0x4be jmp 0x1778 5
#     0x4bf mov ch, 0x12 2
#     0x4c0 adc al, byte ptr [rax] 2
#     0x4c1 add byte ptr [rax], al 2
#     0x4c2 add cl, ch 2
# #   0x4c3 jmp 0x1f1c 5
#     0x4c4 push rsp 1
#     0x4c5 sbb al, byte ptr [rax] 2
#     0x4c6 add byte ptr [rax], al 2
#     0x4c7 add cl, ch 2
# # $ 0x4c8 jmp 0x1f20 5
#     0x4c9 push rbx 1
#     0x4ca sbb al, byte ptr [rax] 2
#     0x4cb add byte ptr [rax], al 2
#     0x4cc add cl, ch 2
# # $ 0x4cd jmp 0x134c 5
#     0x4ce jp 0x4de 2
#     0x4cf None
#     0x4d0 add byte ptr [rax], al 2
#     0x4d1 add cl, ch 2
# # $ 0x4d2 jmp 0x1f14 5
#     0x4d3 cmp eax, 0xe900001a 5
#     0x4d4 sbb al, byte ptr [rax] 2
#     0x4d5 add byte ptr [rax], al 2
#     0x4d6 add cl, ch 2
# # $ 0x4d7 jmp 0x890 5
#     0x4d8 mov ah, 3 2
#     0x4d9 add eax, dword ptr [rax] 2
#     0x4da add byte ptr [rax], al 2
#     0x4db add cl, ch 2
# #   0x4dc jmp 0x11a0 5
#     0x4dd mov edi, 0xe900000c 5
#     0x4de or al, 0 2
#     0x4df add byte ptr [rax], al 2
#     0x4e0 add cl, ch 2
# # $ 0x4e1 jmp 0x1384 5
#     0x4e2 sahf  1
#     0x4e3 None
#     0x4e4 add byte ptr [rax], al 2
#     0x4e5 add cl, ch 2
# #   0x4e6 jmp 0x190c 5
#     0x4e7 and dword ptr [rax + rax], edx 3
#     0x4e8 adc al, 0 2
#     0x4e9 add byte ptr [rax], al 2
#     0x4ea add cl, ch 2
# # $ 0x4eb jmp 0x1350 5
#     0x4ec None
#     0x4ed None
#     0x4ee add byte ptr [rax], al 2
#     0x4ef add cl, ch 2
# #   0x4f0 jmp 0x1f24 5
#     0x4f1 None
#     0x4f2 sbb al, byte ptr [rax] 2
#     0x4f3 add byte ptr [rax], al 2
#     0x4f4 add cl, ch 2
# # $ 0x4f5 jmp 0x1344 5
#     0x4f6 None
#     0x4f7 None
#     0x4f8 add byte ptr [rax], al 2
#     0x4f9 add cl, ch 2
# # $ 0x4fa jmp 0x15e0 5
#     0x4fb loope 0x50d 2
#     0x4fc adc byte ptr [rax], al 2
#     0x4fd add byte ptr [rax], al 2
#     0x4fe add cl, ch 2
# # $ 0x4ff jmp 0x16d8 5
#     0x500 None
#     0x501 adc dword ptr [rax], eax 2
#     0x502 add byte ptr [rax], al 2
#     0x503 add cl, ch 2
# #   0x504 jmp 0xc08 5
#     0x505 inc dword ptr [rsi] 2
#     0x506 None
#     0x507 add byte ptr [rax], al 2
#     0x508 add cl, ch 2
# # $ 0x509 jmp 0x1724 5
#     0x50a None
#     0x50b adc al, byte ptr [rax] 2
#     0x50c add byte ptr [rax], al 2
#     0x50d add cl, ch 2
# # $ 0x50e jmp 0x13c0 5
#     0x50f lodsd eax, dword ptr [rsi] 1
#     0x510 None
#     0x511 add byte ptr [rax], al 2
#     0x512 add cl, ch 2
# # $ 0x513 jmp 0x164c 5
#     0x514 xor al, 0x11 2
#     0x515 adc dword ptr [rax], eax 2
#     0x516 add byte ptr [rax], al 2
#     0x517 add cl, ch 2
# # $ 0x518 jmp 0x1f18 5
#     0x519 sti  1
#     0x51a sbb dword ptr [rax], eax 2
#     0x51b add byte ptr [rax], al 2
#     0x51c add cl, ch 2
# # $ 0x51d jmp 0x1f1c 5
#     0x51e cli  1
#     0x51f sbb dword ptr [rax], eax 2
#     0x520 add byte ptr [rax], al 2
#     0x521 add cl, ch 2
# #   0x522 jmp 0x1f14 5
#     0x523 in eax, dx 1
#     0x524 sbb dword ptr [rax], eax 2
#     0x525 add byte ptr [rax], al 2
#     0x526 add cl, ch 2
# # $ 0x527 jmp 0x830 5
#     0x528 add al, 3 2
#     0x529 add eax, dword ptr [rax] 2
#     0x52a add byte ptr [rax], al 2
#     0x52b add cl, ch 2
# # $ 0x52c jmp 0xcb8 5
#     0x52d xchg dword ptr [rdi], eax 2
#     0x52e None
#     0x52f add byte ptr [rax], al 2
#     0x530 add cl, ch 2
# # $ 0x531 jmp 0x15e4 5
#     0x532 scasb al, byte ptr [rdi] 1
#     0x533 adc byte ptr [rax], al 2
#     0x534 add byte ptr [rax], al 2
#     0x535 add cl, ch 2
# #   0x536 jmp 0x18b8 5
#     0x537 jge 0x54c 2
#     0x538 adc eax, dword ptr [rax] 2
#     0x539 add byte ptr [rax], al 2
#     0x53a add cl, ch 2
# # $ 0x53b jmp 0x1f20 5
#     0x53c loopne 0x557 2
#     0x53d sbb dword ptr [rax], eax 2
#     0x53e add byte ptr [rax], al 2
#     0x53f add cl, ch 2
# # $ 0x540 jmp 0x1268 5
#     0x541 and ecx, dword ptr [rip + 0xee90000] 6
#     0x542 or eax, 0xee90000 5
#     0x543 add byte ptr [rax], al 2
#     0x544 add cl, ch 2
# #   0x545 jmp 0x1958 5
#     0x546 None
#     0x547 adc al, 0 2
#     0x548 add byte ptr [rax], al 2
#     0x549 add cl, ch 2
# #   0x54a jmp 0x1f10 5
#     0x54b rcr dword ptr [rcx], 0 3
#     0x54c sbb dword ptr [rax], eax 2
#     0x54d add byte ptr [rax], al 2
#     0x54e add cl, ch 2
# # $ 0x54f jmp 0x13d0 5
#     0x550 jl 0x560 2
#     0x551 None
#     0x552 add byte ptr [rax], al 2
#     0x553 add cl, ch 2
# #   0x554 jmp 0x1374 5
#     0x555 sbb ecx, dword ptr [rsi] 2
#     0x556 None
#     0x557 add byte ptr [rax], al 2
#     0x558 add cl, ch 2
# #   0x559 jmp 0x1a58 5
#     0x55a cli  1
#     0x55b adc al, 0 2
#     0x55c add byte ptr [rax], al 2
#     0x55d add cl, ch 2
# #   0x55e jmp 0xf20 5
#     0x55f mov ebp, 0xe9000009 5
#     0x560 or dword ptr [rax], eax 2
#     0x561 add byte ptr [rax], al 2
#     0x562 add cl, ch 2
# #   0x563 jmp 0xe1c 5
#     0x564 mov ah, 8 2
#     0x565 or byte ptr [rax], al 2
#     0x566 add byte ptr [rax], al 2
#     0x567 add cl, ch 2
# # $ 0x568 jmp 0x13dc 5
#     0x569 outsd dx, dword ptr [rsi] 1
#     0x56a None
#     0x56b add byte ptr [rax], al 2
#     0x56c add cl, ch 2
# # $ 0x56d jmp 0x1f10 5
#     0x56e sahf  1
#     0x56f sbb dword ptr [rax], eax 2
#     0x570 add byte ptr [rax], al 2
#     0x571 add cl, ch 2
# # $ 0x572 jmp 0x139c 5
#     0x573 and eax, 0xe900000e 5
#     0x574 None
#     0x575 add byte ptr [rax], al 2
#     0x576 add cl, ch 2
# # $ 0x577 jmp 0x13e8 5
#     0x578 insb byte ptr [rdi], dx 1
#     0x579 None
#     0x57a add byte ptr [rax], al 2
#     0x57b add cl, ch 2
# #   0x57c jmp 0x18c8 5
#     0x57d adc r8d, dword ptr [r8] 3
#     0x57e adc eax, dword ptr [rax] 2
#     0x57f add byte ptr [rax], al 2
#     0x580 add cl, ch 2
# #   0x581 jmp 0x17cc 5
#     0x582 adc r8b, byte ptr [rax] 3
#     0x583 adc al, byte ptr [rax] 2
#     0x584 add byte ptr [rax], al 2
#     0x585 add cl, ch 2
# #   0x586 jmp 0xdbc 5
#     0x587 xor dword ptr [rax], ecx 2
#     0x588 or byte ptr [rax], al 2
#     0x589 add byte ptr [rax], al 2
#     0x58a add cl, ch 2
# # $ 0x58b jmp 0x10f4 5
#     0x58c or eax, dword ptr fs:[rax] 3
#     0x58d or eax, dword ptr [rax] 2
#     0x58e add byte ptr [rax], al 2
#     0x58f add cl, ch 2
# # $ 0x590 jmp 0x1a5c 5
#     0x591 None
#     0x592 adc al, 0 2
#     0x593 add byte ptr [rax], al 2
#     0x594 add cl, ch 2
# # $ 0x595 jmp 0x13f4 5
#     0x596 pop rdx 1
#     0x597 None
#     0x598 add byte ptr [rax], al 2
#     0x599 add cl, ch 2
# #   0x59a jmp 0xd68 5
#     0x59b leave  1
#     0x59c None
#     0x59d add byte ptr [rax], al 2
#     0x59e add cl, ch 2
# # $ 0x59f jmp 0xd74 5
#     0x5a0 rol byte ptr [rdi], 1 2
#     0x5a1 None
#     0x5a2 add byte ptr [rax], al 2
#     0x5a3 add cl, ch 2
# #   0x5a4 jmp 0xc9c 5
#     0x5a5 None
#     0x5a6 None
#     0x5a7 add byte ptr [rax], al 2
#     0x5a8 add cl, ch 2
# #   0x5a9 jmp 0x17d0 5
#     0x5aa and dl, byte ptr [rdx] 2
#     0x5ab adc al, byte ptr [rax] 2
#     0x5ac add byte ptr [rax], al 2
#     0x5ad add cl, ch 2
# # $ 0x5ae jmp 0x1388 5
#     0x5af None
#     0x5b0 or eax, 0x20e90000 5
#     0x5b1 add byte ptr [rax], al 2
#     0x5b2 add cl, ch 2
# # $ 0x5b3 jmp 0x15d8 5
#     0x5b4 and byte ptr [rax], dl 2
#     0x5b5 adc byte ptr [rax], al 2
#     0x5b6 add byte ptr [rax], al 2
#     0x5b7 add cl, ch 2
# #   0x5b8 jmp 0xe6c 5
#     0x5b9 scasd eax, dword ptr [rdi] 1
#     0x5ba or byte ptr [rax], al 2
#     0x5bb add byte ptr [rax], al 2
#     0x5bc add cl, ch 2
# # $ 0x5bd jmp 0xf3c 5
#     0x5be jp 0x5c9 2
#     0x5bf or dword ptr [rax], eax 2
#     0x5c0 add byte ptr [rax], al 2
#     0x5c1 add cl, ch 2
# #   0x5c2 jmp 0x17a0 5
#     0x5c3 fst dword ptr [rcx] 2
#     0x5c4 adc dword ptr [rax], eax 2
#     0x5c5 add byte ptr [rax], al 2
# # $ 0x7c5 mov qword ptr [rsp + 0x10], rbp 5
#     0x7c6 mov dword ptr [rsp + 0x10], ebp 4
#     0x7c7 insb byte ptr [rdi], dx 1
#     0x7c8 and al, 0x10 2
#     0x7c9 adc byte ptr [rax - 0x77], cl 3
# # $ 0x7ca mov qword ptr [rsp + 0x18], rsi 5
#     0x7cb mov dword ptr [rsp + 0x18], esi 4
#     0x7cc je 0x7f2 2
#     0x7cd and al, 0x18 2
#     0x7ce sbb byte ptr [rdi + 0x48], dl 3
# # $ 0x7cf push rdi 1
# # $ 0x7d0 sub rsp, 0x30 4
#     0x7d1 sub esp, 0x30 3
#     0x7d2 in al, dx 1
#     0x7d3 xor byte ptr [rcx - 0x75], cl 3
# # $ 0x7d4 mov rbx, r9 3
#     0x7d5 mov ebx, ecx 2
#     0x7d6 None
# # $ 0x7d7 mov rdi, r8 3
#     0x7d8 mov edi, eax 2
#     0x7d9 clc  1
# # $ 0x7da mov rsi, rdx 3
#     0x7db mov esi, edx 2
#     0x7dc mov rbp, rcx 4
# # $ 0x7dd mov rbp, rcx 3
#     0x7de mov ebp, ecx 2
#     0x7df jmp 0xfffffffffffc32cc 5
# # $ 0x7e0 call 0x40f 5
#     0x7e1 sub bh, ah 2
#     0x7e2 cld  1
#     0x7e3 None
#     0x7e4 dec dword ptr [rbx + rcx*4 - 0x31] 4
# # $ 0x7e5 mov r9, rdi 3
#     0x7e6 mov ecx, edi 2
#     0x7e7 iretd  1
# # $ 0x7e8 mov qword ptr [rsp + 0x20], rbx 5
#     0x7e9 mov dword ptr [rsp + 0x20], ebx 4
#     0x7ea pop rsp 1
#     0x7eb and al, 0x20 2
#     0x7ec and byte ptr [rbx + rcx*4 - 0x3a], cl 4
# # $ 0x7ed mov r8, rsi 3
#     0x7ee mov eax, esi 2
#     0x7ef None
# # $ 0x7f0 mov rdx, rbp 3
#     0x7f1 mov edx, ebp 2
#     0x7f2 None
# # $ 0x7f3 mov rcx, qword ptr [rax] 3
#     0x7f4 mov ecx, dword ptr [rax] 2
#     0x7f5 or bh, bh 2
# # $ 0x7f6 call qword ptr [rip + 0x8fbc] 6
#     0x7f7 adc eax, 0x8fbc 5
#     0x7f8 mov esp, 0x4800008f 5
#     0x7f9 pop qword ptr [rax] 2
#     0x7fa add byte ptr [rax], al 2
#     0x7fb add byte ptr [rax - 0x75], cl 3
# # $ 0x7fc mov rbx, qword ptr [rsp + 0x40] 5
#     0x7fd mov ebx, dword ptr [rsp + 0x40] 4
#     0x7fe pop rsp 1
#     0x7ff and al, 0x40 2
#     0x800 mov rbp, qword ptr [rsp + 0x48] 6
# # $ 0x801 mov rbp, qword ptr [rsp + 0x48] 5
#     0x802 mov ebp, dword ptr [rsp + 0x48] 4
#     0x803 insb byte ptr [rdi], dx 1
#     0x804 and al, 0x48 2
#     0x805 mov rsi, qword ptr [rsp + 0x50] 6
# # $ 0x806 mov rsi, qword ptr [rsp + 0x50] 5
#     0x807 mov esi, dword ptr [rsp + 0x50] 4
#     0x808 je 0x82e 2
#     0x809 and al, 0x50 2
#     0x80a push rax 1
# # $ 0x80b add rsp, 0x30 4
#     0x80c add esp, 0x30 3
#     0x80d None
#     0x80e xor byte ptr [rdi - 0x3d], bl 3
# # $ 0x80f pop rdi 1
# # $ 0x810 ret  1
#     0x811 int3  1
#     0x812 int3  1
#     0x813 int3  1
#     0x814 int3  1
#     0x815 int3  1
#     0x816 int3  1
#     0x817 int3  1
#     0x818 int3  1
#     0x819 int3  1
#     0x81a int3  1
#     0x81b int3  1
#     0x81c int3  1
#     0x81d int3  1
#     0x81e int3  1
#     0x81f int3  1
#     0x820 int3  1
#     0x821 int3  1
#     0x822 int3  1
#     0x823 int3  1
#     0x824 int3  1
#     0x825 int3  1
#     0x826 int3  1
#     0x827 int3  1
#     0x828 int3  1
#     0x829 int3  1
#     0x82a int3  1
#     0x82b int3  1
#     0x82c int3  1
#     0x82d int3  1
#     0x82e int3  1
#     0x82f int3  1
# # $ 0x830 sub rsp, 0x28 4
#     0x831 sub esp, 0x28 3
#     0x832 in al, dx 1
#     0x833 sub bh, bh 2
# # $ 0x834 call qword ptr [rip + 0x8f86] 6
#     0x835 adc eax, 0x8f86 5
#     0x836 xchg byte ptr [rdi - 0x2dcd0000], cl 6
#     0x837 pop qword ptr [rax] 2
#     0x838 add byte ptr [rax], al 2
#     0x839 add byte ptr [rbx], dh 2
# # $ 0x83a xor edx, edx 2
#     0x83b rol byte ptr [rbx - 0x6af00008], cl 6
# # $ 0x83c cmp eax, -1 3
#     0x83d clc  1
#     0x83e dec dword ptr [rdi] 2
# # $ 0x83f setne dl 3
#     0x840 xchg ebp, eax 1
#     0x841 ret 0x2174 3
# # $ 0x842 je 0x865 2
#     0x843 and dword ptr [rbx + 0xc740af8], eax 6
# # $ 0x844 cmp eax, 0xa 3
#     0x845 clc  1
#     0x846 or dh, byte ptr [rsp + rcx + 0x48] 4
# # $ 0x847 je 0x855 2
#     0x848 or al, 0x48 2
# # $ 0x849 lea rcx, [rip + 0x5760] 7
#     0x84a lea ecx, [rip + 0x5760] 6
#     0x84b or eax, 0x5760 5
#     0x84c None
#     0x84d push rdi 1
#     0x84e add byte ptr [rax], al 2
#     0x84f add al, ch 2
# # $ 0x850 call 0x4d7 5
#     0x851 None
#     0x852 cld  1
#     0x853 None
#     0x854 None
# # $ 0x855 call qword ptr [rip + 0x8f65] 6
#     0x856 adc eax, 0x8f65 5
#     0x857 pop qword ptr gs:[rax] 3
#     0x858 pop qword ptr [rax] 2
#     0x859 add byte ptr [rax], al 2
#     0x85a add byte ptr [rbx], dh 2
# # $ 0x85b xor edx, edx 2
#     0x85c rol byte ptr [rbx - 0x6af00008], cl 6
# # $ 0x85d cmp eax, -1 3
#     0x85e clc  1
#     0x85f dec dword ptr [rdi] 2
# # $ 0x860 setne dl 3
#     0x861 xchg ebp, eax 1
#     0x862 ret 0xdf75 3
# # $ 0x863 jne 0x844 2
#     0x864 fisttp word ptr [rax - 0x73] 3
# # $ 0x865 lea rcx, [rip + 0x5744] 7
#     0x866 lea ecx, [rip + 0x5744] 6
#     0x867 or eax, 0x5744 5
#     0x868 push rdi 2
#     0x869 push rdi 1
#     0x86a add byte ptr [rax], al 2
#     0x86b add al, ch 2
# # $ 0x86c call 0x4d7 5
#     0x86d cld  2
#     0x86e cld  1
#     0x86f None
#     0x870 push qword ptr [rbx] 2
# # $ 0x871 xor eax, eax 2
#     0x872 ror byte ptr [rax - 0x7d], 0xc4 4
# # $ 0x873 add rsp, 0x28 4
#     0x874 add esp, 0x28 3
#     0x875 None
#     0x876 sub bl, al 2
# # $ 0x877 ret  1
#     0x878 int3  1
#     0x879 int3  1
#     0x87a int3  1
#     0x87b int3  1
#     0x87c int3  1
#     0x87d int3  1
#     0x87e int3  1
#     0x87f int3  1
#     0x880 int3  1
#     0x881 int3  1
#     0x882 int3  1
#     0x883 int3  1
#     0x884 int3  1
#     0x885 int3  1
#     0x886 int3  1
#     0x887 int3  1
#     0x888 int3  1
#     0x889 int3  1
#     0x88a int3  1
#     0x88b int3  1
#     0x88c int3  1
#     0x88d int3  1
#     0x88e int3  1
#     0x88f int3  1
# # $ 0x890 mov qword ptr [rsp + 8], rcx 5
#     0x891 mov dword ptr [rsp + 8], ecx 4
#     0x892 and al, 8 3
#     0x893 and al, 8 2
#     0x894 or byte ptr [rax - 0x77], cl 3
# # $ 0x895 mov qword ptr [rsp + 0x10], rdx 5
#     0x896 mov dword ptr [rsp + 0x10], edx 4
#     0x897 push rsp 1
#     0x898 and al, 0x10 2
#     0x899 adc byte ptr [rcx + rcx*4 + 0x44], cl 4
# # $ 0x89a mov qword ptr [rsp + 0x18], r8 5
#     0x89b mov dword ptr [rsp + 0x18], eax 4
#     0x89c and al, 0x18 3
#     0x89d and al, 0x18 2
#     0x89e sbb byte ptr [rcx + rcx*4 + 0x4c], cl 4
# # $ 0x89f mov qword ptr [rsp + 0x20], r9 5
#     0x8a0 mov dword ptr [rsp + 0x20], ecx 4
#     0x8a1 and al, 0x20 3
#     0x8a2 and al, 0x20 2
#     0x8a3 and byte ptr [rbx + 0x56], dl 3
# # $ 0x8a4 push rbx 1
# # $ 0x8a5 push rsi 1
# # $ 0x8a6 push rdi 1
# # $ 0x8a7 sub rsp, 0x30 4
#     0x8a8 sub esp, 0x30 3
#     0x8a9 in al, dx 1
#     0x8aa xor byte ptr [rax - 0x75], cl 3
# # $ 0x8ab mov rdi, rcx 3
#     0x8ac mov edi, ecx 2
#     0x8ad stc  1
# # $ 0x8ae lea rsi, [rsp + 0x58] 5
#     0x8af lea esi, [rsp + 0x58] 4
#     0x8b0 je 0x8d6 2
#     0x8b1 and al, 0x58 2
#     0x8b2 pop rax 1
# # $ 0x8b3 mov ecx, 1 5
#     0x8b4 add dword ptr [rax], eax 2
#     0x8b5 add byte ptr [rax], al 2
#     0x8b6 add byte ptr [rax], al 2
#     0x8b7 add bh, bh 2
# # $ 0x8b8 call qword ptr [rip + 0x8eea] 6
#     0x8b9 adc eax, 0x8eea 5
#     0x8ba None
#     0x8bb mov es, word ptr [rax] 2
#     0x8bc add byte ptr [rax], al 2
#     0x8bd add byte ptr [rax - 0x75], cl 3
# # $ 0x8be mov rbx, rax 3
#     0x8bf mov ebx, eax 2
#     0x8c0 fsubr st(0) 2
# # $ 0x8c1 call 0x40f 5
#     0x8c2 sti  2
#     0x8c3 sti  1
#     0x8c4 None
#     0x8c5 inc dword ptr [rbp + 0x33] 3
# # $ 0x8c6 xor r9d, r9d 3
#     0x8c7 xor ecx, ecx 2
#     0x8c8 leave  1
# # $ 0x8c9 mov qword ptr [rsp + 0x20], rsi 5
#     0x8ca mov dword ptr [rsp + 0x20], esi 4
#     0x8cb je 0x8f1 2
#     0x8cc and al, 0x20 2
#     0x8cd and byte ptr [rbx + rcx*4 - 0x39], cl 4
# # $ 0x8ce mov r8, rdi 3
#     0x8cf mov eax, edi 2
#     0x8d0 None
# # $ 0x8d1 mov rdx, rbx 3
#     0x8d2 mov edx, ebx 2
#     0x8d3 ror dword ptr [rax - 0x75], cl 3
# # $ 0x8d4 mov rcx, qword ptr [rax] 3
#     0x8d5 mov ecx, dword ptr [rax] 2
#     0x8d6 or bh, bh 2
# # $ 0x8d7 call qword ptr [rip + 0x8edb] 6
#     0x8d8 adc eax, 0x8edb 5
#     0x8d9 fisttp dword ptr [rsi - 0x7cb80000] 6
#     0x8da mov es, word ptr [rax] 2
#     0x8db add byte ptr [rax], al 2
#     0x8dc add byte ptr [rax - 0x7d], cl 3
# # $ 0x8dd add rsp, 0x30 4
#     0x8de add esp, 0x30 3
#     0x8df None
#     0x8e0 xor byte ptr [rdi + 0x5e], bl 3
# # $ 0x8e1 pop rdi 1
# # $ 0x8e2 pop rsi 1
# # $ 0x8e3 pop rbx 1
# # $ 0x8e4 ret  1
#     0x8e5 int3  1
#     0x8e6 int3  1
#     0x8e7 int3  1
#     0x8e8 int3  1
#     0x8e9 int3  1
#     0x8ea int3  1
#     0x8eb int3  1
#     0x8ec int3  1
#     0x8ed int3  1
#     0x8ee int3  1
#     0x8ef int3  1
#     0x8f0 int3  1
#     0x8f1 int3  1
#     0x8f2 int3  1
#     0x8f3 int3  1
#     0x8f4 int3  1
#     0x8f5 int3  1
#     0x8f6 int3  1
#     0x8f7 int3  1
#     0x8f8 int3  1
#     0x8f9 int3  1
#     0x8fa int3  1
#     0x8fb int3  1
# # $ 0x8fc push rbx 2
#     0x8fd push rbx 1
# # $ 0x8fe sub rsp, 0x20 4
#     0x8ff sub esp, 0x20 3
#     0x900 in al, dx 1
#     0x901 and byte ptr [rcx + 1], bh 6
# # $ 0x902 mov ecx, 1 5
#     0x903 add dword ptr [rax], eax 2
#     0x904 add byte ptr [rax], al 2
#     0x905 add byte ptr [rax], al 2
#     0x906 add al, ch 2
# # $ 0x907 call 0x1e7a 5
#     0x908 outsb dx, byte ptr [rsi] 1
#     0x909 adc eax, 0xdae80000 5
#     0x90a add byte ptr [rax], al 2
#     0x90b add al, ch 2
# # $ 0x90c call 0x4eb 5
#     0x90d None
#     0x90e sti  1
#     0x90f None
#     0x910 dec dword ptr [rbx + 0x1598e8c8] 6
# # $ 0x911 mov ecx, eax 2
#     0x912 enter -0x6718, 0x15 4
# # $ 0x913 call 0x1eb0 5
#     0x914 cwde  1
#     0x915 adc eax, 0xb0e80000 5
#     0x916 add byte ptr [rax], al 2
#     0x917 add al, ch 2
# # $ 0x918 call 0x4cd 5
#     0x919 mov al, 0xfb 2
#     0x91a sti  1
#     0x91b None
#     0x91c dec dword ptr [rbx + 0x15bce8d8] 6
# # $ 0x91d mov ebx, eax 2
#     0x91e fsubr st(0) 2
# # $ 0x91f call 0x1ee0 5
#     0x920 mov esp, 0xb9000015 5
#     0x921 adc eax, 0x1b90000 5
#     0x922 add byte ptr [rax], al 2
#     0x923 add byte ptr [rcx + 1], bh 6
# # $ 0x924 mov ecx, 1 5
#     0x925 add dword ptr [rax], eax 2
#     0x926 add byte ptr [rax], al 2
#     0x927 add byte ptr [rax], al 2
#     0x928 add byte ptr [rcx - 0x4bc17e8], cl 6
# # $ 0x929 mov dword ptr [rax], ebx 2
#     0x92a sbb al, ch 2
# # $ 0x92b call 0x473 5
#     0x92c sti  2
#     0x92d sti  1
#     0x92e None
#     0x92f inc dword ptr [rax + rax*8 - 0x39178c8c] 7
# # $ 0x930 test al, al 2
#     0x931 sal byte ptr [rbx + rsi*2 - 0x18], 0xc6 5
# # $ 0x932 je 0x9a7 2
#     0x933 jae 0x91d 2
# # $ 0x934 call 0x4ff 5
#     0x935 None
#     0x936 sti  1
#     0x937 None
#     0x938 dec dword ptr [rax - 0x73] 3
# # $ 0x939 lea rcx, [rip - 0x437] 7
#     0x93a lea ecx, [rip - 0x437] 6
#     0x93b or eax, 0xfffffbc9 5
#     0x93c leave  1
#     0x93d sti  1
#     0x93e None
#     0x93f None
# # $ 0x940 call 0x4af 5
#     0x941 push -5 2
#     0x942 sti  1
#     0x943 None
#     0x944 None
# # $ 0x945 call 0x4f5 5
#     0x946 stosd dword ptr [rdi], eax 1
#     0x947 sti  1
#     0x948 None
#     0x949 dec dword ptr [rbx + 0x1535e8c8] 6
# # $ 0x94a mov ecx, eax 2
#     0x94b enter 0x35e8, 0x15 4
# # $ 0x94c call 0x1e86 5
#     0x94d xor eax, 0x85000015 5
#     0x94e adc eax, 0xc0850000 5
#     0x94f add byte ptr [rax], al 2
#     0x950 add byte ptr [rbp - 0x17ad8a40], al 6
# # $ 0x951 test eax, eax 2
#     0x952 sal byte ptr [rbp + 0x52], 0xe8 4
# # $ 0x953 jne 0x9a7 2
#     0x954 push rdx 1
# # $ 0x955 call 0x450 5
#     0x956 idiv dl 2
#     0x957 cli  1
#     0x958 None
#     0x959 None
# # $ 0x95a call 0x50e 5
#     0x95b scasd eax, dword ptr [rdi] 1
#     0x95c sti  1
#     0x95d None
#     0x95e inc dword ptr [rbp + 0x480c74c0] 6
# # $ 0x95f test eax, eax 2
#     0x960 sal byte ptr [rsp + rcx + 0x48], 0x8d 5
# # $ 0x961 je 0x96f 2
#     0x962 or al, 0x48 2
# # $ 0x963 lea rcx, [rip - 0x51f] 7
#     0x964 lea ecx, [rip - 0x51f] 6
#     0x965 or eax, 0xfffffae1 5
#     0x966 loope 0x962 2
#     0x967 cli  1
#     0x968 None
#     0x969 None
# # $ 0x96a call 0x1e80 5
#     0x96b adc dword ptr [rip + 0x3ae80000], edx 6
#     0x96c adc eax, 0x3ae80000 5
#     0x96d add byte ptr [rax], al 2
#     0x96e add al, ch 2
# # $ 0x96f call 0x5ae 5
#     0x970 cmp bh, ah 2
#     0x971 cld  1
#     0x972 None
#     0x973 None
# # $ 0x974 call 0x491 5
#     0x975 sbb bl, bh 2
#     0x976 sti  1
#     0x977 None
#     0x978 None
# # $ 0x979 call 0x42d 5
#     0x97a scasd eax, dword ptr [rdi] 1
#     0x97b cli  1
#     0x97c None
#     0x97d dec dword ptr [rbx + 0x154fe8c8] 6
# # $ 0x97e mov ecx, eax 2
#     0x97f enter 0x4fe8, 0x15 4
# # $ 0x980 call 0x1ed4 5
#     0x981 adc rax, 0x57e80000 6
#     0x982 adc eax, 0x57e80000 5
#     0x983 add byte ptr [rax], al 2
#     0x984 add al, ch 2
# # $ 0x985 call 0x4e1 5
#     0x986 push rdi 1
#     0x987 sti  1
#     0x988 None
#     0x989 inc dword ptr [rax + rax*8 - 0x617fa8c] 7
# # $ 0x98a test al, al 2
#     0x98b sal byte ptr [rbp + rax - 0x18], 0xf9 5
# # $ 0x98c je 0x993 2
#     0x98d add eax, 0x14f9e8 5
# # $ 0x98e call 0x1e8c 5
#     0x98f stc  1
#     0x990 adc al, 0 2
#     0x991 add byte ptr [rax], al 2
#     0x992 add al, ch 2
# # $ 0x993 call 0x4fa 5
#     0x994 None
#     0x995 sti  1
#     0x996 None
#     0x997 None
# # $ 0x998 call 0x5b3 5
#     0x999 None
#     0x99a cld  1
#     0x99b None
#     0x99c inc dword ptr [rbp + 0x480675c0] 6
# # $ 0x99d test eax, eax 2
#     0x99e sal byte ptr [rbp + 6], 0x48 4
# # $ 0x99f jne 0x9a7 2
#     0x9a0 None
# # $ 0x9a1 add rsp, 0x20 4
#     0x9a2 add esp, 0x20 3
#     0x9a3 None
#     0x9a4 and byte ptr [rbx - 0x3d], bl 3
# # $ 0x9a5 pop rbx 1
# # $ 0x9a6 ret  1
# # $ 0x9a7 mov ecx, 7 5
#     0x9a8 None
#     0x9a9 add byte ptr [rax], al 2
#     0x9aa add byte ptr [rax], al 2
#     0x9ab add al, ch 2
# # $ 0x9ac call 0x595 5
#     0x9ad in al, 0xfb 2
#     0x9ae sti  1
#     0x9af None
#     0x9b0 dec esp 2
#     0x9b1 int3  1
#     0x9b2 int3  1
#     0x9b3 int3  1
#     0x9b4 int3  1
#     0x9b5 int3  1
#     0x9b6 int3  1
#     0x9b7 int3  1
#     0x9b8 int3  1
#     0x9b9 int3  1
#     0x9ba int3  1
#     0x9bb int3  1
#     0x9bc int3  1
#     0x9bd int3  1
#     0x9be int3  1
#     0x9bf int3  1
#     0x9c0 int3  1
#     0x9c1 int3  1
#     0x9c2 int3  1
#     0x9c3 int3  1
#     0x9c4 int3  1
#     0x9c5 int3  1
#     0x9c6 int3  1
#     0x9c7 int3  1
#     0x9c8 int3  1
#     0x9c9 int3  1
#     0x9ca int3  1
#     0x9cb int3  1
#     0x9cc int3  1
#     0x9cd int3  1
#     0x9ce int3  1
#     0x9cf int3  1
#     0x9d0 int3  1
#     0x9d1 int3  1
#     0x9d2 int3  1
#     0x9d3 int3  1
#     0x9d4 int3  1
#     0x9d5 int3  1
#     0x9d6 int3  1
#     0x9d7 int3  1
#     0x9d8 int3  1
#     0x9d9 int3  1
#     0x9da int3  1
#     0x9db int3  1
#     0x9dc int3  1
#     0x9dd int3  1
#     0x9de int3  1
#     0x9df int3  1
# # $ 0x9e0 sub rsp, 0x28 4
#     0x9e1 sub esp, 0x28 3
#     0x9e2 in al, dx 1
#     0x9e3 sub al, ch 2
# # $ 0x9e4 call 0x572 5
#     0x9e5 mov ebx, edi 2
#     0x9e6 sti  1
#     0x9e7 None
#     0x9e8 push qword ptr [rbx] 2
# # $ 0x9e9 xor eax, eax 2
#     0x9ea ror byte ptr [rax - 0x7d], 0xc4 4
# # $ 0x9eb add rsp, 0x28 4
#     0x9ec add esp, 0x28 3
#     0x9ed None
#     0x9ee sub bl, al 2
# # $ 0x9ef ret  1
#     0x9f0 int3  1
#     0x9f1 int3  1
#     0x9f2 int3  1
#     0x9f3 int3  1
# # $ 0x9f4 sub rsp, 0x28 4
#     0x9f5 sub esp, 0x28 3
#     0x9f6 in al, dx 1
#     0x9f7 sub al, ch 2
# # $ 0x9f8 call 0x513 5
#     0x9f9 None
#     0x9fa sti  1
#     0x9fb None
#     0x9fc None
# # $ 0x9fd call 0x432 5
#     0x9fe xor dl, bh 2
#     0x9ff cli  1
#     0xa00 None
#     0xa01 dec dword ptr [rbx - 0x3b7cb738] 6
# # $ 0xa02 mov ecx, eax 2
#     0xa03 enter -0x7cb8, -0x3c 4
# # $ 0xa04 add rsp, 0x28 4
#     0xa05 add esp, 0x28 3
#     0xa06 None
#     0xa07 sub cl, ch 2
# # $ 0xa08 jmp 0x1eda 5
#     0xa09 int 0x14 2
#     0xa0a adc al, 0 2
#     0xa0b add byte ptr [rax], al 2
#     0xa0c add ah, cl 2
#     0xa0d int3  1
#     0xa0e int3  1
#     0xa0f int3  1
#     0xa10 int3  1
#     0xa11 int3  1
#     0xa12 int3  1
#     0xa13 int3  1
# # $ 0xa14 sub rsp, 0x28 4
#     0xa15 sub esp, 0x28 3
#     0xa16 in al, dx 1
#     0xa17 sub al, ch 2
# # $ 0xa18 call 0x540 5
#     0xa19 and edi, ebx 2
#     0xa1a sti  1
#     0xa1b None
#     0xa1c dec dword ptr [rax - 0x7d] 3
# # $ 0xa1d add rsp, 0x28 4
#     0xa1e add esp, 0x28 3
#     0xa1f None
#     0xa20 sub cl, ch 2
# # $ 0xa21 jmp 0xa2c 5
#     0xa22 None
#     0xa23 add byte ptr [rax], al 2
#     0xa24 add byte ptr [rax], al 2
#     0xa25 add ah, cl 2
#     0xa26 int3  1
#     0xa27 int3  1
#     0xa28 int3  1
#     0xa29 int3  1
#     0xa2a int3  1
#     0xa2b int3  1
# # $ 0xa2c mov qword ptr [rsp + 8], rbx 5
#     0xa2d mov dword ptr [rsp + 8], ebx 4
#     0xa2e pop rsp 1
#     0xa2f and al, 8 2
#     0xa30 or byte ptr [rax - 0x77], cl 3
# # $ 0xa31 mov qword ptr [rsp + 0x10], rsi 5
#     0xa32 mov dword ptr [rsp + 0x10], esi 4
#     0xa33 je 0xa59 2
#     0xa34 and al, 0x10 2
#     0xa35 adc byte ptr [rdi + 0x48], dl 3
# # $ 0xa36 push rdi 1
# # $ 0xa37 sub rsp, 0x30 4
#     0xa38 sub esp, 0x30 3
#     0xa39 in al, dx 1
#     0xa3a xor byte ptr [rcx + 1], bh 6
# # $ 0xa3b mov ecx, 1 5
#     0xa3c add dword ptr [rax], eax 2
#     0xa3d add byte ptr [rax], al 2
#     0xa3e add byte ptr [rax], al 2
#     0xa3f add al, ch 2
# # $ 0xa40 call 0x5bd 5
#     0xa41 js 0xa3e 2
#     0xa42 sti  1
#     0xa43 None
#     0xa44 inc dword ptr [rax + rax*8 + 0x136840f] 7
# # $ 0xa45 test al, al 2
#     0xa46 ror byte ptr [rdi], 0x84 3
# # $ 0xa47 je 0xb83 6
#     0xa48 test byte ptr [rsi], dh 2
#     0xa49 add dword ptr ss:[rax], eax 3
#     0xa4a add dword ptr [rax], eax 2
#     0xa4b add byte ptr [rax], al 2
#     0xa4c add byte ptr [rax + 0x32], al 3
# # $ 0xa4d xor sil, sil 3
#     0xa4e xor dh, dh 2
#     0xa4f test byte ptr [rax - 0x78], 0x74 4
# # $ 0xa50 mov byte ptr [rsp + 0x20], sil 5
#     0xa51 mov byte ptr [rsp + 0x20], dh 4
#     0xa52 je 0xa78 2
#     0xa53 and al, 0x20 2
#     0xa54 and al, ch 2
# # $ 0xa55 call 0x59f 5
#     0xa56 sti  2
#     0xa57 sti  1
#     0xa58 None
#     0xa59 dec dword ptr [rdx + 0x4e0d8bd8] 6
# # $ 0xa5a mov bl, al 2
#     0xa5b fmul dword ptr [rbx + 0x6b4e0d] 6
# # $ 0xa5c mov ecx, dword ptr [rip + 0x6b4e] 6
#     0xa5d or eax, 0x6b4e 5
#     0xa5e imul r8, qword ptr [rax], 0 4
#     0xa5f imul eax, dword ptr [rax], 0 3
#     0xa60 add byte ptr [rax], al 2
#     0xa61 add byte ptr [rbx - 0x7bf0fe07], al 6
# # $ 0xa62 cmp ecx, 1 3
#     0xa63 stc  1
#     0xa64 add dword ptr [rdi], ecx 2
# # $ 0xa65 je 0xb8e 6
#     0xa66 test byte ptr [rbx], ah 2
#     0xa67 and eax, dword ptr [rcx] 2
#     0xa68 add dword ptr [rax], eax 2
#     0xa69 add byte ptr [rax], al 2
#     0xa6a add byte ptr [rbp - 0x38b58a37], al 6
# # $ 0xa6b test ecx, ecx 2
#     0xa6c leave  1
# # $ 0xa6d jne 0xab9 2
#     0xa6e mov qword ptr [rip + 0x6b37], 1 11
# # $ 0xa6f mov dword ptr [rip + 0x6b37], 1 10
#     0xa70 add eax, 0x6b37 5
#     0xa71 None
#     0xa72 imul eax, dword ptr [rax], 0 3
#     0xa73 add byte ptr [rax], al 2
#     0xa74 add byte ptr [rcx], al 2
#     0xa75 add dword ptr [rax], eax 2
#     0xa76 add byte ptr [rax], al 2
#     0xa77 add byte ptr [rax], al 2
#     0xa78 add byte ptr [rax - 0x73], cl 3
# # $ 0xa79 lea rdx, [rip + 0x4fe0] 7
#     0xa7a lea edx, [rip + 0x4fe0] 6
#     0xa7b adc eax, 0x4fe0 5
#     0xa7c loopne 0xacd 2
#     0xa7d add byte ptr [r8], r8b 3
#     0xa7e add byte ptr [rax], al 2
#     0xa7f add byte ptr [rax - 0x73], cl 3
# # $ 0xa80 lea rcx, [rip + 0x4ca9] 7
#     0xa81 lea ecx, [rip + 0x4ca9] 6
#     0xa82 or eax, 0x4ca9 5
#     0xa83 test eax, 0xe800004c 5
#     0xa84 add byte ptr [rax], r8b 3
#     0xa85 add byte ptr [rax], al 2
#     0xa86 add al, ch 2
# # $ 0xa87 call 0x1e9e 5
#     0xa88 adc dl, byte ptr [rax + rax] 3
#     0xa89 adc al, 0 2
#     0xa8a add byte ptr [rax], al 2
#     0xa8b add byte ptr [rbp - 0x47f58b40], al 6
# # $ 0xa8c test eax, eax 2
#     0xa8d sal byte ptr [rdx + rcx - 0x48], 0xff 5
# # $ 0xa8e je 0xa9a 2
#     0xa8f or bh, byte ptr [rax + 0xff] 6
# # $ 0xa90 mov eax, 0xff 5
#     0xa91 inc dword ptr [rax] 2
#     0xa92 add byte ptr [rax], al 2
#     0xa93 add byte ptr [rax], al 2
#     0xa94 add cl, ch 2
# # $ 0xa95 jmp 0xb73 5
#     0xa96 fld dword ptr [rax] 2
#     0xa97 add byte ptr [rax], al 2
#     0xa98 add byte ptr [rax], al 2
#     0xa99 add byte ptr [rax - 0x73], cl 3
# # $ 0xa9a lea rdx, [rip + 0x4b7f] 7
#     0xa9b lea edx, [rip + 0x4b7f] 6
#     0xa9c adc eax, 0x4b7f 5
#     0xa9d jg 0xaea 2
#     0xa9e add byte ptr [r8], al 3
#     0xa9f add byte ptr [rax], al 2
#     0xaa0 add byte ptr [rax - 0x73], cl 3
# # $ 0xaa1 lea rcx, [rip + 0x4958] 7
#     0xaa2 lea ecx, [rip + 0x4958] 6
#     0xaa3 or eax, 0x4958 5
#     0xaa4 pop rax 1
#     0xaa5 add byte ptr [r8], al 3
#     0xaa6 add byte ptr [rax], al 2
#     0xaa7 add al, ch 2
# # $ 0xaa8 call 0x1e98 5
#     0xaa9 jmp 0xabe 2
#     0xaaa adc eax, dword ptr [rax] 2
#     0xaab add byte ptr [rax], al 2
#     0xaac add bh, al 2
# # $ 0xaad mov dword ptr [rip + 0x6af9], 2 10
#     0xaae add eax, 0x6af9 5
#     0xaaf stc  1
#     0xab0 push 0 2
#     0xab1 add byte ptr [rax], al 2
#     0xab2 add byte ptr [rdx], al 2
#     0xab3 add al, byte ptr [rax] 2
#     0xab4 add byte ptr [rax], al 2
#     0xab5 add byte ptr [rax], al 2
#     0xab6 add bl, ch 2
# # $ 0xab7 jmp 0xac1 2
#     0xab8 or byte ptr [rax - 0x4a], al 3
# # $ 0xab9 mov sil, 1 3
#     0xaba mov dh, 1 2
#     0xabb add dword ptr [rax - 0x78], eax 3
# # $ 0xabc mov byte ptr [rsp + 0x20], sil 5
#     0xabd mov byte ptr [rsp + 0x20], dh 4
#     0xabe je 0xae4 2
#     0xabf and al, 0x20 2
#     0xac0 and byte ptr [rdx - 0x53c1735], cl 6
# # $ 0xac1 mov cl, bl 2
#     0xac2 retf  1
# # $ 0xac3 call 0x58b 5
#     0xac4 ret  1
#     0xac5 cli  1
#     0xac6 None
#     0xac7 None
# # $ 0xac8 call 0x54f 5
#     0xac9 None
#     0xaca cli  1
#     0xacb None
#     0xacc dec dword ptr [rax - 0x75] 3
# # $ 0xacd mov rbx, rax 3
#     0xace mov ebx, eax 2
#     0xacf fmul dword ptr [rax - 0x7d] 3
# # $ 0xad0 cmp qword ptr [rax], 0 4
#     0xad1 cmp dword ptr [rax], 0 3
#     0xad2 cmp byte ptr [rax], al 2
#     0xad3 add byte ptr [rsi + rbx + 0x48], dh 4
# # $ 0xad4 je 0xaf4 2
#     0xad5 None
# # $ 0xad6 mov rcx, rax 3
#     0xad7 mov ecx, eax 2
#     0xad8 enter -0x3318, -7 4
# # $ 0xad9 call 0x4aa 5
#     0xada int3  1
#     0xadb stc  1
#     0xadc None
#     0xadd inc dword ptr [rax + rax*8 + 0x33451274] 7
# # $ 0xade test al, al 2
#     0xadf sal byte ptr [rdx + rdx + 0x45], 0x33 5
# # $ 0xae0 je 0xaf4 2
#     0xae1 adc al, byte ptr [rbp + 0x33] 3
# # $ 0xae2 xor r8d, r8d 3
#     0xae3 xor eax, eax 2
#     0xae4 rol byte ptr [rcx - 0x73], 0x50 4
# # $ 0xae5 lea edx, [r8 + 2] 4
#     0xae6 lea edx, [rax + 2] 3
#     0xae7 push rax 1
#     0xae8 add dh, byte ptr [rbx] 2
# # $ 0xae9 xor ecx, ecx 2
#     0xaea leave  1
# # $ 0xaeb mov rax, qword ptr [rbx] 3
#     0xaec mov eax, dword ptr [rbx] 2
#     0xaed add edi, edi 2
# # $ 0xaee call qword ptr [rip + 0x992c] 6
#     0xaef adc eax, 0x992c 5
#     0xaf0 sub al, 0x99 2
#     0xaf1 cdq  1
#     0xaf2 add byte ptr [rax], al 2
#     0xaf3 add al, ch 2
# # $ 0xaf4 call 0x568 5
#     0xaf5 outsd dx, dword ptr [rsi] 1
#     0xaf6 cli  1
#     0xaf7 None
#     0xaf8 dec dword ptr [rax - 0x75] 3
# # $ 0xaf9 mov rbx, rax 3
#     0xafa mov ebx, eax 2
#     0xafb fmul dword ptr [rax - 0x7d] 3
# # $ 0xafc cmp qword ptr [rax], 0 4
#     0xafd cmp dword ptr [rax], 0 3
#     0xafe cmp byte ptr [rax], al 2
#     0xaff add byte ptr [rsp + rdx + 0x48], dh 4
# # $ 0xb00 je 0xb16 2
#     0xb01 adc al, 0x48 2
# # $ 0xb02 mov rcx, rax 3
#     0xb03 mov ecx, eax 2
#     0xb04 enter -0x5f18, -7 4
# # $ 0xb05 call 0x4aa 5
#     0xb06 movabs al, byte ptr [0x480874c084fffff9] 9
#     0xb07 stc  1
#     0xb08 None
#     0xb09 inc dword ptr [rax + rax*8 - 0x74b7f78c] 7
# # $ 0xb0a test al, al 2
#     0xb0b sal byte ptr [rax + rcx + 0x48], 0x8b 5
# # $ 0xb0c je 0xb16 2
#     0xb0d or byte ptr [rax - 0x75], cl 3
# # $ 0xb0e mov rcx, qword ptr [rbx] 3
#     0xb0f mov ecx, dword ptr [rbx] 2
#     0xb10 or ebp, eax 2
# # $ 0xb11 call 0x1ece 5
#     0xb12 mov eax, 0xe8000013 5
#     0xb13 adc eax, dword ptr [rax] 2
#     0xb14 add byte ptr [rax], al 2
#     0xb15 add al, ch 2
# # $ 0xb16 call 0x1e92 5
#     0xb17 ja 0xb2c 2
#     0xb18 adc eax, dword ptr [rax] 2
#     0xb19 add byte ptr [rax], al 2
#     0xb1a add byte ptr [rax - 0x75], cl 3
# # $ 0xb1b mov rdi, rax 3
#     0xb1c mov edi, eax 2
#     0xb1d clc  1
# # $ 0xb1e call 0x1ebc 5
#     0xb1f cdq  1
#     0xb20 adc eax, dword ptr [rax] 2
#     0xb21 add byte ptr [rax], al 2
#     0xb22 add byte ptr [rax - 0x75], cl 3
# # $ 0xb23 mov rbx, qword ptr [rax] 3
#     0xb24 mov ebx, dword ptr [rax] 2
#     0xb25 sbb al, ch 2
# # $ 0xb26 call 0x1eb6 5
#     0xb27 mov edx, dword ptr [rbx] 2
#     0xb28 adc eax, dword ptr [rax] 2
#     0xb29 add byte ptr [rax], al 2
#     0xb2a add byte ptr [rbx + rcx*4 - 0x39], cl 4
# # $ 0xb2b mov r8, rdi 3
#     0xb2c mov eax, edi 2
#     0xb2d None
# # $ 0xb2e mov rdx, rbx 3
#     0xb2f mov edx, ebx 2
#     0xb30 ror dword ptr [rbx - 0x61017f8], cl 6
# # $ 0xb31 mov ecx, dword ptr [rax] 2
#     0xb32 or al, ch 2
# # $ 0xb33 call 0x527 5
#     0xb34 out dx, eax 1
#     0xb35 stc  1
#     0xb36 None
#     0xb37 dec dword ptr [rbx - 0x60d1728] 6
# # $ 0xb38 mov ebx, eax 2
#     0xb39 fsubr st(0) 2
# # $ 0xb3a call 0x531 5
#     0xb3b stc  2
#     0xb3c stc  1
#     0xb3d None
#     0xb3e inc dword ptr [rax + rax*8 - 0x7bbfaa8c] 7
# # $ 0xb3f test al, al 2
#     0xb40 sal byte ptr [rbp + rdx*2 + 0x40], 0x84 5
# # $ 0xb41 je 0xb98 2
#     0xb42 push rbp 1
# # $ 0xb43 test sil, sil 3
#     0xb44 test dh, dh 2
#     0xb45 div byte ptr [rbp + 5] 3
# # $ 0xb46 jne 0xb4d 2
#     0xb47 add eax, 0x1375e8 5
# # $ 0xb48 call 0x1ec2 5
#     0xb49 jne 0xb5e 2
#     0xb4a adc eax, dword ptr [rax] 2
#     0xb4b add byte ptr [rax], al 2
#     0xb4c add byte ptr [rbx], dh 2
# # $ 0xb4d xor edx, edx 2
#     0xb4e sal byte ptr [rcx - 0x6b517ff], cl 6
# # $ 0xb4f mov cl, 1 2
#     0xb50 add eax, ebp 2
# # $ 0xb51 call 0x4a0 5
#     0xb52 stc  2
#     0xb53 stc  1
#     0xb54 None
#     0xb55 dec dword ptr [rbx - 0x74e6143d] 6
# # $ 0xb56 mov eax, ebx 2
#     0xb57 ret  1
# # $ 0xb58 jmp 0xb73 2
#     0xb59 sbb dword ptr [rbx - 0x62f1728], ecx 6
#     0xb5a mov ebx, eax 2
#     0xb5b fsubr st(0) 2
#     0xb5c call 0x531 5
#     0xb5d sar cl, 1 2
#     0xb5e stc  1
#     0xb5f None
#     0xb60 inc dword ptr [rax + rax*8 + 0x7c803b74] 7
#     0xb61 test al, al 2
#     0xb62 sal byte ptr [rbx + rdi - 0x80], 0x7c 5
#     0xb63 je 0xba0 2
#     0xb64 cmp eax, dword ptr [rax + 0x20247c] 6
#     0xb65 cmp byte ptr [rsp + 0x20], 0 5
#     0xb66 jl 0xb8c 2
#     0xb67 and al, 0x20 2
#     0xb68 and byte ptr [rax], al 2
#     0xb69 add byte ptr [rbp + 5], dh 3
#     0xb6a jne 0xb71 2
#     0xb6b add eax, 0x1357e8 5
#     0xb6c call 0x1ec8 5
#     0xb6d push rdi 1
#     0xb6e adc eax, dword ptr [rax] 2
#     0xb6f add byte ptr [rax], al 2
#     0xb70 add byte ptr [rbx + 0x5c8b48c3], cl 6
#     0xb71 mov eax, ebx 2
#     0xb72 ret  1
# # $ 0xb73 mov rbx, qword ptr [rsp + 0x40] 5
#     0xb74 mov ebx, dword ptr [rsp + 0x40] 4
#     0xb75 pop rsp 1
#     0xb76 and al, 0x40 2
#     0xb77 mov rsi, qword ptr [rsp + 0x48] 6
# # $ 0xb78 mov rsi, qword ptr [rsp + 0x48] 5
#     0xb79 mov esi, dword ptr [rsp + 0x48] 4
#     0xb7a je 0xba0 2
#     0xb7b and al, 0x48 2
#     0xb7c add rsp, 0x30 5
# # $ 0xb7d add rsp, 0x30 4
#     0xb7e add esp, 0x30 3
#     0xb7f None
#     0xb80 xor byte ptr [rdi - 0x3d], bl 3
# # $ 0xb81 pop rdi 1
# # $ 0xb82 ret  1
# # $ 0xb83 mov ecx, 7 5
#     0xb84 None
#     0xb85 add byte ptr [rax], al 2
#     0xb86 add byte ptr [rax], al 2
# ...
#     0x4df7 int3  1
#     0x4df8 int3  1
#     0x4df9 int3  1
#     0x4dfa int3  1
#     0x4dfb int3  1
#     0x4dfc int3  1
#     0x4dfd int3  1
#     0x4dfe int3  1
#     0x4dff int3  1
#     0x4e00 int3  1
#     0x4e01 int3  1
#     0x4e02 int3  1
#     0x4e03 int3  1
#     0x4e04 int3  1
#     0x4e05 int3  1
#     0x4e06 int3  1
#     0x4e07 int3  1
#     0x4e08 int3  1
#     0x4e09 int3  1
#     0x4e0a int3  1
#     0x4e0b int3  1
#     0x50de int3  1
#     0x50df int3  1
#     0x50e0 int3  1
#     0x50e1 int3  1
#     0x50e2 int3  1
#     0x50e3 int3  1
#     0x50e4 int3  1
#     0x50e5 int3  1
#     0x50e6 int3  1
#     0x50e7 int3  1
#     0x50e8 int3  1
#     0x50e9 int3  1
#     0x50ea int3  1
#     0x50eb int3  1
#     0x50ec int3  1
#     0x50ed int3  1
#     0x50ee int3  1
#     0x50ef int3  1
#     0x50f0 int3  1
#     0x50f1 int3  1
#     0x50f2 int3  1
#     0x50f3 int3  1
#     0x50f4 int3  1
#     0x50f5 int3  1
#     0x50f6 int3  1
#     0x50f7 int3  1
#     0x50f8 int3  1
#     0x50f9 int3  1
#     0x50fa int3  1
#     0x50fb int3  1
#     0x50fc int3  1
#     0x50fd int3  1
#     0x50fe int3  1
#     0x50ff int3  1
#     0x5100 int3  1
#     0x5101 int3  1
#     0x5102 int3  1
#     0x5103 int3  1
#     0x5104 int3  1
#     0x5105 int3  1
#     0x5106 int3  1
#     0x5107 int3  1
#     0x5108 int3  1
#     0x5109 int3  1
#     0x510a int3  1
#     0x510b int3  1
#     0x510c int3  1
#     0x510d int3  1
#     0x510e int3  1
#     0x510f int3  1
#     0x5110 int3  1
#     0x5111 int3  1
#     0x5112 int3  1
#     0x5113 int3  1
#     0x5114 int3  1
#     0x5115 int3  1
#     0x5116 int3  1
#     0x5117 int3  1
#     0x5118 int3  1
#     0x5119 int3  1
#     0x511a int3  1
#     0x511b int3  1
#     0x511c int3  1
#     0x511d int3  1
#     0x511e int3  1
#     0x511f int3  1
#     0x5120 int3  1
#     0x5121 int3  1
#     0x5122 int3  1
#     0x5123 int3  1
#     0x5124 int3  1
#     0x5125 int3  1
#     0x5126 int3  1
#     0x5127 int3  1
#     0x5128 int3  1
#     0x5129 int3  1
#     0x512a int3  1
#     0x512b int3  1
#     0x512c int3  1
#     0x512d int3  1
#     0x512e int3  1
#     0x512f int3  1
#     0x5130 int3  1
#     0x5131 int3  1
#     0x5132 int3  1
#     0x5133 int3  1
#     0x5134 int3  1
#     0x5135 int3  1
#     0x5136 int3  1
#     0x5137 int3  1
#     0x5138 int3  1
#     0x5139 int3  1
#     0x513a int3  1
#     0x513b int3  1
#     0x513c int3  1
#     0x513d int3  1
#     0x513e int3  1
#     0x513f int3  1
#     0x5140 int3  1

# %%
print(f"TP: {all_TP}, FP: {all_FP}, FN: {all_FN}, TN: {all_TN}")

# %%
accuracy = (all_TP + all_TN) / (all_TP + all_TN + all_FP + all_FN)
precision = all_TP / (all_TP + all_FP) if (all_TP + all_FP) > 0 else 0
recall = all_TP / (all_TP + all_FN) if (all_TP + all_FN) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1_score:.4f}")

# %%
def clip_to_unit_range(x):
    return max(0.0, min(1.0, x))

# Example usage
inputs = [-0.01, 0.0, 0.5, 1.0, 1.1]
outputs = [ 1-clip_to_unit_range(x) for x in inputs]
outputs2 = [ 1-x for x in inputs]
print(inputs)
print(outputs)  
print(outputs2)

# %%
for j in outputs2:
    print(j,.8*j)
