# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
ground_truth_json_dir = "/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/"
#   
predict_json_dir = "/home/raisul/ANALYSED_DATA/test/x86_pe_msvc_O2_static_1k_prob_disasm/"  #'/home/raisul/ANALYSED_DATA/prob_disasm_x86_pe_msvc_O2_static/'
BIN_FILE_TYPE = "PE"
BIN_PATH = "/home/raisul/DATA/x86_pe_msvc_O2_static_stripped/"

# %%
def get_offsets(json_file_path):
    with open(json_file_path, "r") as file:
        data = json.load(file)
        temp = []
        for key,val in data.items():
            if 'int3' not in val:
                temp.append(key)
    return temp



def get_instructions(bin_file_path  ):
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    with open(bin_file_path, 'rb') as f:
        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":
        
                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
        except Exception as e:
                print("An error occurred:", e ,bin_file_path)
                return
    
        for byte_index in range(len(textSection)):
            try:    
    
                instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
                offset_inst[text_section_offset+byte_index] = instruction
                
                # if instruction:
                #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                # else:
                #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
    
            except Exception as e:
                print(traceback.print_exc() )
                print(e)
    return offset_inst

ground_truth__jsons  =  os.listdir(ground_truth_json_dir) 
ghidra_predict_jsons    =  os.listdir(predict_json_dir)


common_json_files = list(set(ground_truth__jsons) & set(ghidra_predict_jsons))
print(len(common_json_files))
common_json_files = common_json_files[0:1]
# common_json_files =['370cf902ac71f426c14725a24959e8de.json']
all_TP= all_FP= all_FN= all_TN = 0

for json_file_name in common_json_files:
    # print('\n\n\n',json_file_name)
    ground_truth_json_path =  os.path.join(ground_truth_json_dir, json_file_name)
    ghidra_predict_json_path =  os.path.join(predict_json_dir, json_file_name)
    ground_truth_offsets = get_offsets(ground_truth_json_path)
    predict_offsets = get_offsets(ghidra_predict_json_path)
    
    ground_truth_offsets_set = set(ground_truth_offsets)
    predict_offsets_set = set(predict_offsets)

    
    superset = set(range( min(ground_truth_offsets) , max(ground_truth_offsets) ) )
    
    true_positive = len(ground_truth_offsets_set&predict_offsets_set)
    false_positive = len(predict_offsets_set - ground_truth_offsets_set)
    false_negative = len( ground_truth_offsets_set -predict_offsets_set )
    true_negative = len( superset - ( ground_truth_offsets_set|predict_offsets_set)  )
    
    all_TP+=true_positive
    all_FP+=false_positive
    all_FN+=false_negative
    all_TN+=true_negative
    
    print('\ntrue_positive: ',true_positive , '\n false_positive: ',false_positive ,'\nfalse_negative:', false_negative , '\ntrue_negative: ',true_negative)

    # continue
    
    bin_file_path = os.path.join(os.path.join(BIN_PATH ,  json_file_name.split('.')[0] ),  (json_file_name.split('.')[0]+ ('.exe' if BIN_FILE_TYPE == "PE" else '' )))
    exhaustive_disasm = get_instructions(bin_file_path)
    # print(exhaustive_disasm)
    if exhaustive_disasm:
      for offset in exhaustive_disasm:
          if exhaustive_disasm[offset] is None:
              continue
          hash = '#' if offset in ground_truth_offsets else ' '
          dollar = '$' if offset in predict_offsets else ' '

          if hash=='#' or dollar=='$':
              # if exhaustive_disasm[offset].mnemonic!= 'int3':
              print( hash , dollar , hex(offset), exhaustive_disasm[offset].mnemonic+ exhaustive_disasm[offset].op_str) #insn.mnemonic} {insn.op_str
          if offset in predict_offsets and offset not in ground_truth_offsets :
              print('_'*30 , '>>')
    else:
        print('exhaustive diasm none')
    # print(len(ground_truth_offsets) , len(predict_offsets))
    # false_negatives = list(set(ground_truth_offsets) - set(predict_offsets))
# Out:
# 367
#
# true_positive:  1425
#  false_positive:  5040
# false_negative: 0
# true_negative:  10738
#   $ 0x400 int3
# ______________________________ >>
#   $ 0x401 int3
# ______________________________ >>
#   $ 0x402 int3
# ______________________________ >>
#   $ 0x403 int3
# ______________________________ >>
#   $ 0x404 int3
# ______________________________ >>
# # $ 0x405 jmp0xdd8
# # $ 0x40a jmp0x17b0
# # $ 0x40f jmp0x7e0
# # $ 0x414 jmp0x18c0
# # $ 0x419 jmp0xf5c
# # $ 0x41e jmp0x7f0
# # $ 0x423 jmp0x2068
# # $ 0x428 jmp0x18c4
# # $ 0x42d jmp0x14b8
# # $ 0x432 jmp0x14b4
# # $ 0x437 jmp0x2060
# # $ 0x43c jmp0x2074
# # $ 0x441 jmp0x9f0
# # $ 0x446 jmp0x3250
# # $ 0x44b jmp0x12b4
# # $ 0x450 jmp0x149c
# # $ 0x455 jmp0x14bc
# # $ 0x45a jmp0x206c
# # $ 0x45f jmp0x1aa4
# # $ 0x464 jmp0xdcc
# # $ 0x469 jmp0x1b08
# # $ 0x46e jmp0x870
# # $ 0x473 jmp0x3230
# # $ 0x478 jmp0x2064
# # $ 0x47d jmp0x10e0
# # $ 0x482 jmp0x2070
# # $ 0x487 jmp0x17b4
# # $ 0x48c jmp0x197c
# # $ 0x491 jmp0x17b0
# # $ 0x496 jmp0x1b8c
# # $ 0x49b jmp0x14e8
# # $ 0x4a0 jmp0x18cc
# # $ 0x4a5 jmp0xd80
# # $ 0x4aa jmp0x1280
# # $ 0x4af jmp0x1f28
# # $ 0x4b4 jmp0x1190
# # $ 0x4b9 jmp0x1320
# # $ 0x4be jmp0x2068
# # $ 0x4c3 jmp0x800
# # $ 0x4c8 jmp0x18c8
# # $ 0x4cd jmp0x206c
# # $ 0x4d2 jmp0x2070
# # $ 0x4d7 jmp0x7d0
# # $ 0x4dc jmp0x14a8
# # $ 0x4e1 jmp0x2064
# # $ 0x4e6 jmp0x980
# # $ 0x4eb jmp0x12fc
# # $ 0x4f0 jmp0x14e0
# # $ 0x4f5 jmp0x1a5c
# # $ 0x4fa jmp0x14ac
# # $ 0x4ff jmp0x2074
# # $ 0x504 jmp0x14a0
# # $ 0x509 jmp0x1730
# # $ 0x50e jmp0x1828
# # $ 0x513 jmp0xd64
# # $ 0x518 jmp0x1874
# # $ 0x51d jmp0x1510
# # $ 0x522 jmp0x179c
# # $ 0x527 jmp0x2068
# # $ 0x52c jmp0x206c
# # $ 0x531 jmp0x2064
# # $ 0x536 jmp0x8e0
# # $ 0x53b jmp0xe14
# # $ 0x540 jmp0x1734
# # $ 0x545 jmp0x1a08
# # $ 0x54a jmp0x2070
# # $ 0x54f jmp0x13c4
# # $ 0x554 jmp0x1aa8
# # $ 0x559 jmp0x2060
# # $ 0x55e jmp0x1520
# # $ 0x563 jmp0x14d0
# # $ 0x568 jmp0x1ba8
# # $ 0x56d jmp0x107c
# # $ 0x572 jmp0xf78
# # $ 0x577 jmp0x152c
# # $ 0x57c jmp0x2060
# # $ 0x581 jmp0x14ec
# # $ 0x586 jmp0x1538
# # $ 0x58b jmp0x1a18
# # $ 0x590 jmp0x191c
# # $ 0x595 jmp0xf18
# # $ 0x59a jmp0x1250
# # $ 0x59f jmp0x1bac
# # $ 0x5a4 jmp0x1544
# # $ 0x5a9 jmp0xec4
# # $ 0x5ae jmp0xed0
# # $ 0x5b3 jmp0xdf8
# # $ 0x5b8 jmp0x1920
# # $ 0x5bd jmp0x14e4
# # $ 0x5c2 jmp0x1728
# # $ 0x5c7 jmp0xfc8
# # $ 0x5cc jmp0x1098
# # $ 0x5d1 jmp0x18f0
# # $ 0x5d6 jmp0x16e0
# # $ 0x5db jmp0xfac
# # $ 0x5e0 jmp0x1040
#   $ 0x5e5 int3
# ______________________________ >>
#   $ 0x5e6 int3
# ______________________________ >>
#   $ 0x5e7 int3
# ______________________________ >>
#   $ 0x5e8 int3
# ______________________________ >>
#   $ 0x5e9 int3
# ______________________________ >>
#   $ 0x5ea int3
# ______________________________ >>
#   $ 0x5eb int3
# ______________________________ >>
#   $ 0x5ec int3
# ______________________________ >>
#   $ 0x5ed int3
# ______________________________ >>
#   $ 0x5ee int3
# ______________________________ >>
#   $ 0x5ef int3
# ______________________________ >>
#   $ 0x5f0 int3
# ______________________________ >>
#   $ 0x5f1 int3
# ______________________________ >>
#   $ 0x5f2 int3
# ______________________________ >>
#   $ 0x5f3 int3
# ______________________________ >>
#   $ 0x5f4 int3
# ______________________________ >>
#   $ 0x5f5 int3
# ______________________________ >>
#   $ 0x5f6 int3
# ______________________________ >>
#   $ 0x5f7 int3
# ______________________________ >>
#   $ 0x5f8 int3
# ______________________________ >>
#   $ 0x5f9 int3
# ______________________________ >>
#   $ 0x5fa int3
# ______________________________ >>
#   $ 0x5fb int3
# ______________________________ >>
#   $ 0x5fc int3
# ______________________________ >>
#   $ 0x5fd int3
# ______________________________ >>
#   $ 0x5fe int3
# ______________________________ >>
#   $ 0x5ff int3
# ______________________________ >>
#   $ 0x600 int3
# ______________________________ >>
#   $ 0x601 int3
# ______________________________ >>
#   $ 0x602 int3
# ______________________________ >>
#   $ 0x603 int3
# ______________________________ >>
#   $ 0x604 int3
# ______________________________ >>
#   $ 0x605 int3
# ______________________________ >>
#   $ 0x606 int3
# ______________________________ >>
#   $ 0x607 int3
# ______________________________ >>
#   $ 0x608 int3
# ______________________________ >>
#   $ 0x609 int3
# ______________________________ >>
#   $ 0x60a int3
# ______________________________ >>
#   $ 0x60b int3
# ______________________________ >>
#   $ 0x60c int3
# ______________________________ >>
#   $ 0x60d int3
# ______________________________ >>
#   $ 0x60e int3
# ______________________________ >>
#   $ 0x60f int3
# ______________________________ >>
#   $ 0x610 int3
# ______________________________ >>
#   $ 0x611 int3
# ______________________________ >>
#   $ 0x612 int3
# ______________________________ >>
#   $ 0x613 int3
# ______________________________ >>
#   $ 0x614 int3
# ______________________________ >>
#   $ 0x615 int3
# ______________________________ >>
#   $ 0x616 int3
# ______________________________ >>
#   $ 0x617 int3
# ______________________________ >>
#   $ 0x618 int3
# ______________________________ >>
#   $ 0x619 int3
# ______________________________ >>
#   $ 0x61a int3
# ______________________________ >>
#   $ 0x61b int3
# ______________________________ >>
#   $ 0x61c int3
# ______________________________ >>
#   $ 0x61d int3
# ______________________________ >>
#   $ 0x61e int3
# ______________________________ >>
#   $ 0x61f int3
# ______________________________ >>
#   $ 0x620 int3
# ______________________________ >>
#   $ 0x621 int3
# ______________________________ >>
#   $ 0x622 int3
# ______________________________ >>
#   $ 0x623 int3
# ______________________________ >>
#   $ 0x624 int3
# ______________________________ >>
#   $ 0x625 int3
# ______________________________ >>
#   $ 0x626 int3
# ______________________________ >>
#   $ 0x627 int3
# ______________________________ >>
#   $ 0x628 int3
# ______________________________ >>
#   $ 0x629 int3
# ______________________________ >>
#   $ 0x62a int3
# ______________________________ >>
#   $ 0x62b int3
# ______________________________ >>
#   $ 0x62c int3
# ______________________________ >>
#   $ 0x62d int3
# ______________________________ >>
#   $ 0x62e int3
# ______________________________ >>
#   $ 0x62f int3
# ______________________________ >>
#   $ 0x630 int3
# ______________________________ >>
#   $ 0x631 int3
# ______________________________ >>
#   $ 0x632 int3
# ______________________________ >>
#   $ 0x633 int3
# ______________________________ >>
#   $ 0x634 int3
# ______________________________ >>
#   $ 0x635 int3
# ______________________________ >>
#   $ 0x636 int3
# ______________________________ >>
#   $ 0x637 int3
# ______________________________ >>
#   $ 0x638 int3
# ______________________________ >>
#   $ 0x639 int3
# ______________________________ >>
#   $ 0x63a int3
# ______________________________ >>
#   $ 0x63b int3
# ______________________________ >>
#   $ 0x63c int3
# ______________________________ >>
#   $ 0x63d int3
# ______________________________ >>
#   $ 0x63e int3
# ______________________________ >>
#   $ 0x63f int3
# ______________________________ >>
#   $ 0x640 int3
# ______________________________ >>
#   $ 0x641 int3
# ______________________________ >>
#   $ 0x642 int3
# ______________________________ >>
#   $ 0x643 int3
# ______________________________ >>
#   $ 0x644 int3
# ______________________________ >>
#   $ 0x645 int3
# ______________________________ >>
#   $ 0x646 int3
# ______________________________ >>
#   $ 0x647 int3
# ______________________________ >>
#   $ 0x648 int3
# ______________________________ >>
#   $ 0x649 int3
# ______________________________ >>
#   $ 0x64a int3
# ______________________________ >>
#   $ 0x64b int3
# ______________________________ >>
#   $ 0x64c int3
# ______________________________ >>
#   $ 0x64d int3
# ______________________________ >>
#   $ 0x64e int3
# ______________________________ >>
#   $ 0x64f int3
# ______________________________ >>
#   $ 0x650 int3
# ______________________________ >>
#   $ 0x651 int3
# ______________________________ >>
#   $ 0x652 int3
# ______________________________ >>
#   $ 0x653 int3
# ______________________________ >>
#   $ 0x654 int3
# ______________________________ >>
#   $ 0x655 int3
# ______________________________ >>
#   $ 0x656 int3
# ______________________________ >>
#   $ 0x657 int3
# ______________________________ >>
#   $ 0x658 int3
# ______________________________ >>
#   $ 0x659 int3
# ______________________________ >>
#   $ 0x65a int3
# ______________________________ >>
#   $ 0x65b int3
# ______________________________ >>
#   $ 0x65c int3
# ______________________________ >>
#   $ 0x65d int3
# ______________________________ >>
#   $ 0x65e int3
# ______________________________ >>
#   $ 0x65f int3
# ______________________________ >>
#   $ 0x660 int3
# ______________________________ >>
#   $ 0x661 int3
# ______________________________ >>
#   $ 0x662 int3
# ______________________________ >>
#   $ 0x663 int3
# ______________________________ >>
#   $ 0x664 int3
# ______________________________ >>
#   $ 0x665 int3
# ______________________________ >>
#   $ 0x666 int3
# ______________________________ >>
#   $ 0x667 int3
# ______________________________ >>
#   $ 0x668 int3
# ______________________________ >>
#   $ 0x669 int3
# ______________________________ >>
#   $ 0x66a int3
# ______________________________ >>
#   $ 0x66b int3
# ______________________________ >>
#   $ 0x66c int3
# ______________________________ >>
#   $ 0x66d int3
# ______________________________ >>
#   $ 0x66e int3
# ______________________________ >>
#   $ 0x66f int3
# ______________________________ >>
#   $ 0x670 int3
# ______________________________ >>
#   $ 0x671 int3
# ______________________________ >>
#   $ 0x672 int3
# ______________________________ >>
#   $ 0x673 int3
# ______________________________ >>
#   $ 0x674 int3
# ______________________________ >>
#   $ 0x675 int3
# ______________________________ >>
#   $ 0x676 int3
# ______________________________ >>
#   $ 0x677 int3
# ______________________________ >>
#   $ 0x678 int3
# ______________________________ >>
#   $ 0x679 int3
# ______________________________ >>
#   $ 0x67a int3
# ______________________________ >>
#   $ 0x67b int3
# ______________________________ >>
#   $ 0x67c int3
# ______________________________ >>
#   $ 0x67d int3
# ______________________________ >>
#   $ 0x67e int3
# ______________________________ >>
#   $ 0x67f int3
# ______________________________ >>
#   $ 0x680 int3
# ______________________________ >>
#   $ 0x681 int3
# ______________________________ >>
#   $ 0x682 int3
# ______________________________ >>
#   $ 0x683 int3
# ______________________________ >>
#   $ 0x684 int3
# ______________________________ >>
#   $ 0x685 int3
# ______________________________ >>
#   $ 0x686 int3
# ______________________________ >>
#   $ 0x687 int3
# ______________________________ >>
#   $ 0x688 int3
# ______________________________ >>
#   $ 0x689 int3
# ______________________________ >>
#   $ 0x68a int3
# ______________________________ >>
#   $ 0x68b int3
# ______________________________ >>
#   $ 0x68c int3
# ______________________________ >>
#   $ 0x68d int3
# ______________________________ >>
#   $ 0x68e int3
# ______________________________ >>
#   $ 0x68f int3
# ______________________________ >>
#   $ 0x690 int3
# ______________________________ >>
#   $ 0x691 int3
# ______________________________ >>
#   $ 0x692 int3
# ______________________________ >>
#   $ 0x693 int3
# ______________________________ >>
#   $ 0x694 int3
# ______________________________ >>
#   $ 0x695 int3
# ______________________________ >>
#   $ 0x696 int3
# ______________________________ >>
#   $ 0x697 int3
# ______________________________ >>
#   $ 0x698 int3
# ______________________________ >>
#   $ 0x699 int3
# ______________________________ >>
#   $ 0x69a int3
# ______________________________ >>
#   $ 0x69b int3
# ______________________________ >>
#   $ 0x69c int3
# ______________________________ >>
#   $ 0x69d int3
# ______________________________ >>
#   $ 0x69e int3
# ______________________________ >>
#   $ 0x69f int3
# ______________________________ >>
#   $ 0x6a0 int3
# ______________________________ >>
#   $ 0x6a1 int3
# ______________________________ >>
#   $ 0x6a2 int3
# ______________________________ >>
#   $ 0x6a3 int3
# ______________________________ >>
#   $ 0x6a4 int3
# ______________________________ >>
#   $ 0x6a5 int3
# ______________________________ >>
#   $ 0x6a6 int3
# ______________________________ >>
#   $ 0x6a7 int3
# ______________________________ >>
#   $ 0x6a8 int3
# ______________________________ >>
#   $ 0x6a9 int3
# ______________________________ >>
#   $ 0x6aa int3
# ______________________________ >>
#   $ 0x6ab int3
# ______________________________ >>
#   $ 0x6ac int3
# ______________________________ >>
#   $ 0x6ad int3
# ______________________________ >>
#   $ 0x6ae int3
# ______________________________ >>
#   $ 0x6af int3
# ______________________________ >>
#   $ 0x6b0 int3
# ______________________________ >>
#   $ 0x6b1 int3
# ______________________________ >>
#   $ 0x6b2 int3
# ______________________________ >>
#   $ 0x6b3 int3
# ______________________________ >>
#   $ 0x6b4 int3
# ______________________________ >>
#   $ 0x6b5 int3
# ______________________________ >>
#   $ 0x6b6 int3
# ______________________________ >>
#   $ 0x6b7 int3
# ______________________________ >>
#   $ 0x6b8 int3
# ______________________________ >>
#   $ 0x6b9 int3
# ______________________________ >>
#   $ 0x6ba int3
# ______________________________ >>
#   $ 0x6bb int3
# ______________________________ >>
#   $ 0x6bc int3
# ______________________________ >>
#   $ 0x6bd int3
# ______________________________ >>
#   $ 0x6be int3
# ______________________________ >>
#   $ 0x6bf int3
# ______________________________ >>
#   $ 0x6c0 int3
# ______________________________ >>
#   $ 0x6c1 int3
# ______________________________ >>
#   $ 0x6c2 int3
# ______________________________ >>
#   $ 0x6c3 int3
# ______________________________ >>
#   $ 0x6c4 int3
# ______________________________ >>
#   $ 0x6c5 int3
# ______________________________ >>
#   $ 0x6c6 int3
# ______________________________ >>
#   $ 0x6c7 int3
# ______________________________ >>
#   $ 0x6c8 int3
# ______________________________ >>
#   $ 0x6c9 int3
# ______________________________ >>
#   $ 0x6ca int3
# ______________________________ >>
#   $ 0x6cb int3
# ______________________________ >>
#   $ 0x6cc int3
# ______________________________ >>
#   $ 0x6cd int3
# ______________________________ >>
#   $ 0x6ce int3
# ______________________________ >>
#   $ 0x6cf int3
# ______________________________ >>
#   $ 0x6d0 int3
# ______________________________ >>
#   $ 0x6d1 int3
# ______________________________ >>
#   $ 0x6d2 int3
# ______________________________ >>
#   $ 0x6d3 int3
# ______________________________ >>
#   $ 0x6d4 int3
# ______________________________ >>
#   $ 0x6d5 int3
# ______________________________ >>
#   $ 0x6d6 int3
# ______________________________ >>
#   $ 0x6d7 int3
# ______________________________ >>
#   $ 0x6d8 int3
# ______________________________ >>
#   $ 0x6d9 int3
# ______________________________ >>
#   $ 0x6da int3
# ______________________________ >>
#   $ 0x6db int3
# ______________________________ >>
#   $ 0x6dc int3
# ______________________________ >>
#   $ 0x6dd int3
# ______________________________ >>
#   $ 0x6de int3
# ______________________________ >>
#   $ 0x6df int3
# ______________________________ >>
#   $ 0x6e0 int3
# ______________________________ >>
#   $ 0x6e1 int3
# ______________________________ >>
#   $ 0x6e2 int3
# ______________________________ >>
#   $ 0x6e3 int3
# ______________________________ >>
#   $ 0x6e4 int3
# ______________________________ >>
#   $ 0x6e5 int3
# ______________________________ >>
#   $ 0x6e6 int3
# ______________________________ >>
#   $ 0x6e7 int3
# ______________________________ >>
#   $ 0x6e8 int3
# ______________________________ >>
#   $ 0x6e9 int3
# ______________________________ >>
#   $ 0x6ea int3
# ______________________________ >>
#   $ 0x6eb int3
# ______________________________ >>
#   $ 0x6ec int3
# ______________________________ >>
#   $ 0x6ed int3
# ______________________________ >>
#   $ 0x6ee int3
# ______________________________ >>
#   $ 0x6ef int3
# ______________________________ >>
#   $ 0x6f0 int3
# ______________________________ >>
#   $ 0x6f1 int3
# ______________________________ >>
#   $ 0x6f2 int3
# ______________________________ >>
#   $ 0x6f3 int3
# ______________________________ >>
#   $ 0x6f4 int3
# ______________________________ >>
#   $ 0x6f5 int3
# ______________________________ >>
#   $ 0x6f6 int3
# ______________________________ >>
#   $ 0x6f7 int3
# ______________________________ >>
#   $ 0x6f8 int3
# ______________________________ >>
#   $ 0x6f9 int3
# ______________________________ >>
#   $ 0x6fa int3
# ______________________________ >>
#   $ 0x6fb int3
# ______________________________ >>
#   $ 0x6fc int3
# ______________________________ >>
#   $ 0x6fd int3
# ______________________________ >>
#   $ 0x6fe int3
# ______________________________ >>
#   $ 0x6ff int3
# ______________________________ >>
#   $ 0x700 int3
# ______________________________ >>
#   $ 0x701 int3
# ______________________________ >>
#   $ 0x702 int3
# ______________________________ >>
#   $ 0x703 int3
# ______________________________ >>
#   $ 0x704 int3
# ______________________________ >>
#   $ 0x705 int3
# ______________________________ >>
#   $ 0x706 int3
# ______________________________ >>
#   $ 0x707 int3
# ______________________________ >>
#   $ 0x708 int3
# ______________________________ >>
#   $ 0x709 int3
# ______________________________ >>
#   $ 0x70a int3
# ______________________________ >>
#   $ 0x70b int3
# ______________________________ >>
#   $ 0x70c int3
# ______________________________ >>
#   $ 0x70d int3
# ______________________________ >>
#   $ 0x70e int3
# ______________________________ >>
#   $ 0x70f int3
# ______________________________ >>
#   $ 0x710 int3
# ______________________________ >>
#   $ 0x711 int3
# ______________________________ >>
#   $ 0x712 int3
# ______________________________ >>
#   $ 0x713 int3
# ______________________________ >>
#   $ 0x714 int3
# ______________________________ >>
#   $ 0x715 int3
# ______________________________ >>
#   $ 0x716 int3
# ______________________________ >>
#   $ 0x717 int3
# ______________________________ >>
#   $ 0x718 int3
# ______________________________ >>
#   $ 0x719 int3
# ______________________________ >>
#   $ 0x71a int3
# ______________________________ >>
#   $ 0x71b int3
# ______________________________ >>
#   $ 0x71c int3
# ______________________________ >>
#   $ 0x71d int3
# ______________________________ >>
#   $ 0x71e int3
# ______________________________ >>
#   $ 0x71f int3
# ______________________________ >>
#   $ 0x720 int3
# ______________________________ >>
#   $ 0x721 int3
# ______________________________ >>
#   $ 0x722 int3
# ______________________________ >>
#   $ 0x723 int3
# ______________________________ >>
#   $ 0x724 int3
# ______________________________ >>
#   $ 0x725 int3
# ______________________________ >>
#   $ 0x726 int3
# ______________________________ >>
#   $ 0x727 int3
# ______________________________ >>
#   $ 0x728 int3
# ______________________________ >>
#   $ 0x729 int3
# ______________________________ >>
#   $ 0x72a int3
# ______________________________ >>
#   $ 0x72b int3
# ______________________________ >>
#   $ 0x72c int3
# ______________________________ >>
#   $ 0x72d int3
# ______________________________ >>
#   $ 0x72e int3
# ______________________________ >>
#   $ 0x72f int3
# ______________________________ >>
#   $ 0x730 int3
# ______________________________ >>
#   $ 0x731 int3
# ______________________________ >>
#   $ 0x732 int3
# ______________________________ >>
#   $ 0x733 int3
# ______________________________ >>
#   $ 0x734 int3
# ______________________________ >>
#   $ 0x735 int3
# ______________________________ >>
#   $ 0x736 int3
# ______________________________ >>
#   $ 0x737 int3
# ______________________________ >>
#   $ 0x738 int3
# ______________________________ >>
#   $ 0x739 int3
# ______________________________ >>
#   $ 0x73a int3
# ______________________________ >>
#   $ 0x73b int3
# ______________________________ >>
#   $ 0x73c int3
# ______________________________ >>
#   $ 0x73d int3
# ______________________________ >>
#   $ 0x73e int3
# ______________________________ >>
#   $ 0x73f int3
# ______________________________ >>
#   $ 0x740 int3
# ______________________________ >>
#   $ 0x741 int3
# ______________________________ >>
#   $ 0x742 int3
# ______________________________ >>
#   $ 0x743 int3
# ______________________________ >>
#   $ 0x744 int3
# ______________________________ >>
#   $ 0x745 int3
# ______________________________ >>
#   $ 0x746 int3
# ______________________________ >>
#   $ 0x747 int3
# ______________________________ >>
#   $ 0x748 int3
# ______________________________ >>
#   $ 0x749 int3
# ______________________________ >>
#   $ 0x74a int3
# ______________________________ >>
#   $ 0x74b int3
# ______________________________ >>
#   $ 0x74c int3
# ______________________________ >>
#   $ 0x74d int3
# ______________________________ >>
#   $ 0x74e int3
# ______________________________ >>
#   $ 0x74f int3
# ______________________________ >>
#   $ 0x750 int3
# ______________________________ >>
#   $ 0x751 int3
# ______________________________ >>
#   $ 0x752 int3
# ______________________________ >>
#   $ 0x753 int3
# ______________________________ >>
#   $ 0x754 int3
# ______________________________ >>
#   $ 0x755 int3
# ______________________________ >>
#   $ 0x756 int3
# ______________________________ >>
#   $ 0x757 int3
# ______________________________ >>
#   $ 0x758 int3
# ______________________________ >>
#   $ 0x759 int3
# ______________________________ >>
#   $ 0x75a int3
# ______________________________ >>
#   $ 0x75b int3
# ______________________________ >>
#   $ 0x75c int3
# ______________________________ >>
#   $ 0x75d int3
# ______________________________ >>
#   $ 0x75e int3
# ______________________________ >>
#   $ 0x75f int3
# ______________________________ >>
#   $ 0x760 int3
# ______________________________ >>
#   $ 0x761 int3
# ______________________________ >>
#   $ 0x762 int3
# ______________________________ >>
#   $ 0x763 int3
# ______________________________ >>
#   $ 0x764 int3
# ______________________________ >>
#   $ 0x765 int3
# ______________________________ >>
#   $ 0x766 int3
# ______________________________ >>
#   $ 0x767 int3
# ______________________________ >>
#   $ 0x768 int3
# ______________________________ >>
#   $ 0x769 int3
# ______________________________ >>
#   $ 0x76a int3
# ______________________________ >>
#   $ 0x76b int3
# ______________________________ >>
#   $ 0x76c int3
# ______________________________ >>
#   $ 0x76d int3
# ______________________________ >>
#   $ 0x76e int3
# ______________________________ >>
#   $ 0x76f int3
# ______________________________ >>
#   $ 0x770 int3
# ______________________________ >>
#   $ 0x771 int3
# ______________________________ >>
#   $ 0x772 int3
# ______________________________ >>
#   $ 0x773 int3
# ______________________________ >>
#   $ 0x774 int3
# ______________________________ >>
#   $ 0x775 int3
# ______________________________ >>
#   $ 0x776 int3
# ______________________________ >>
#   $ 0x777 int3
# ______________________________ >>
#   $ 0x778 int3
# ______________________________ >>
#   $ 0x779 int3
# ______________________________ >>
#   $ 0x77a int3
# ______________________________ >>
#   $ 0x77b int3
# ______________________________ >>
#   $ 0x77c int3
# ______________________________ >>
#   $ 0x77d int3
# ______________________________ >>
#   $ 0x77e int3
# ______________________________ >>
#   $ 0x77f int3
# ______________________________ >>
#   $ 0x780 int3
# ______________________________ >>
#   $ 0x781 int3
# ______________________________ >>
#   $ 0x782 int3
# ______________________________ >>
#   $ 0x783 int3
# ______________________________ >>
#   $ 0x784 int3
# ______________________________ >>
#   $ 0x785 int3
# ______________________________ >>
#   $ 0x786 int3
# ______________________________ >>
#   $ 0x787 int3
# ______________________________ >>
#   $ 0x788 int3
# ______________________________ >>
#   $ 0x789 int3
# ______________________________ >>
#   $ 0x78a int3
# ______________________________ >>
#   $ 0x78b int3
# ______________________________ >>
#   $ 0x78c int3
# ______________________________ >>
#   $ 0x78d int3
# ______________________________ >>
#   $ 0x78e int3
# ______________________________ >>
#   $ 0x78f int3
# ______________________________ >>
#   $ 0x790 int3
# ______________________________ >>
#   $ 0x791 int3
# ______________________________ >>
#   $ 0x792 int3
# ______________________________ >>
#   $ 0x793 int3
# ______________________________ >>
#   $ 0x794 int3
# ______________________________ >>
#   $ 0x795 int3
# ______________________________ >>
#   $ 0x796 int3
# ______________________________ >>
#   $ 0x797 int3
# ______________________________ >>
#   $ 0x798 int3
# ______________________________ >>
#   $ 0x799 int3
# ______________________________ >>
#   $ 0x79a int3
# ______________________________ >>
#   $ 0x79b int3
# ______________________________ >>
#   $ 0x79c int3
# ______________________________ >>
#   $ 0x79d int3
# ______________________________ >>
#   $ 0x79e int3
# ______________________________ >>
#   $ 0x79f int3
# ______________________________ >>
#   $ 0x7a0 int3
# ______________________________ >>
#   $ 0x7a1 int3
# ______________________________ >>
#   $ 0x7a2 int3
# ______________________________ >>
#   $ 0x7a3 int3
# ______________________________ >>
#   $ 0x7a4 int3
# ______________________________ >>
#   $ 0x7a5 int3
# ______________________________ >>
#   $ 0x7a6 int3
# ______________________________ >>
#   $ 0x7a7 int3
# ______________________________ >>
#   $ 0x7a8 int3
# ______________________________ >>
#   $ 0x7a9 int3
# ______________________________ >>
#   $ 0x7aa int3
# ______________________________ >>
#   $ 0x7ab int3
# ______________________________ >>
#   $ 0x7ac int3
# ______________________________ >>
#   $ 0x7ad int3
# ______________________________ >>
#   $ 0x7ae int3
# ______________________________ >>
#   $ 0x7af int3
# ______________________________ >>
#   $ 0x7b0 int3
# ______________________________ >>
#   $ 0x7b1 int3
# ______________________________ >>
#   $ 0x7b2 int3
# ______________________________ >>
#   $ 0x7b3 int3
# ______________________________ >>
#   $ 0x7b4 int3
# ______________________________ >>
#   $ 0x7b5 int3
# ______________________________ >>
#   $ 0x7b6 int3
# ______________________________ >>
#   $ 0x7b7 int3
# ______________________________ >>
#   $ 0x7b8 int3
# ______________________________ >>
#   $ 0x7b9 int3
# ______________________________ >>
#   $ 0x7ba int3
# ______________________________ >>
#   $ 0x7bb int3
# ______________________________ >>
#   $ 0x7bc int3
# ______________________________ >>
#   $ 0x7bd int3
# ______________________________ >>
#   $ 0x7be int3
# ______________________________ >>
#   $ 0x7bf int3
# ______________________________ >>
#   $ 0x7c0 int3
# ______________________________ >>
#   $ 0x7c1 int3
# ______________________________ >>
#   $ 0x7c2 int3
# ______________________________ >>
#   $ 0x7c3 int3
# ______________________________ >>
#   $ 0x7c4 int3
# ______________________________ >>
#   $ 0x7c5 int3
# ______________________________ >>
#   $ 0x7c6 int3
# ______________________________ >>
#   $ 0x7c7 int3
# ______________________________ >>
#   $ 0x7c8 int3
# ______________________________ >>
#   $ 0x7c9 int3
# ______________________________ >>
#   $ 0x7ca int3
# ______________________________ >>
#   $ 0x7cb int3
# ______________________________ >>
#   $ 0x7cc int3
# ______________________________ >>
#   $ 0x7cd int3
# ______________________________ >>
#   $ 0x7ce int3
# ______________________________ >>
#   $ 0x7cf int3
# ______________________________ >>
# # $ 0x7d0 movr8d, dword ptr [rdx]
# # $ 0x7d3 moveax, dword ptr [rcx]
# # $ 0x7d5 movdword ptr [rdx], eax
# # $ 0x7d7 movdword ptr [rcx], r8d
# # $ 0x7da ret
#   $ 0x7db int3
# ______________________________ >>
#   $ 0x7dc int3
# ______________________________ >>
#   $ 0x7dd int3
# ______________________________ >>
#   $ 0x7de int3
# ______________________________ >>
#   $ 0x7df int3
# ______________________________ >>
# # $ 0x7e0 learax, [rip + 0x6e91]
# # $ 0x7e7 ret
#   $ 0x7e8 int3
# ______________________________ >>
#   $ 0x7e9 int3
# ______________________________ >>
#   $ 0x7ea int3
# ______________________________ >>
#   $ 0x7eb int3
# ______________________________ >>
#   $ 0x7ec int3
# ______________________________ >>
#   $ 0x7ed int3
# ______________________________ >>
#   $ 0x7ee int3
# ______________________________ >>
#   $ 0x7ef int3
# ______________________________ >>
# # $ 0x7f0 learax, [rip + 0x6e69]
# # $ 0x7f7 ret
#   $ 0x7f8 int3
# ______________________________ >>
#   $ 0x7f9 int3
# ______________________________ >>
#   $ 0x7fa int3
# ______________________________ >>
#   $ 0x7fb int3
# ______________________________ >>
#   $ 0x7fc int3
# ______________________________ >>
#   $ 0x7fd int3
# ______________________________ >>
#   $ 0x7fe int3
# ______________________________ >>
#   $ 0x7ff int3
# ______________________________ >>
# # $ 0x800 movqword ptr [rsp + 8], rbx
# # $ 0x805 movqword ptr [rsp + 0x10], rbp
# # $ 0x80a movqword ptr [rsp + 0x18], rsi
# # $ 0x80f pushrdi
# # $ 0x810 subrsp, 0x30
# # $ 0x814 movrbx, r9
# # $ 0x817 movrdi, r8
# # $ 0x81a movrsi, rdx
# # $ 0x81d movrbp, rcx
# # $ 0x820 call0x40f
# # $ 0x825 movr9, rdi
# # $ 0x828 movqword ptr [rsp + 0x20], rbx
# # $ 0x82d movr8, rsi
# # $ 0x830 movrdx, rbp
# # $ 0x833 movrcx, qword ptr [rax]
# # $ 0x836 callqword ptr [rip + 0x8f84]
# # $ 0x83c movrbx, qword ptr [rsp + 0x40]
# # $ 0x841 movrbp, qword ptr [rsp + 0x48]
# # $ 0x846 movrsi, qword ptr [rsp + 0x50]
# # $ 0x84b addrsp, 0x30
# # $ 0x84f poprdi
# # $ 0x850 ret
#   $ 0x851 int3
# ______________________________ >>
#   $ 0x852 int3
# ______________________________ >>
#   $ 0x853 int3
# ______________________________ >>
#   $ 0x854 int3
# ______________________________ >>
#   $ 0x855 int3
# ______________________________ >>
#   $ 0x856 int3
# ______________________________ >>
#   $ 0x857 int3
# ______________________________ >>
#   $ 0x858 int3
# ______________________________ >>
#   $ 0x859 int3
# ______________________________ >>
#   $ 0x85a int3
# ______________________________ >>
#   $ 0x85b int3
# ______________________________ >>
#   $ 0x85c int3
# ______________________________ >>
#   $ 0x85d int3
# ______________________________ >>
#   $ 0x85e int3
# ______________________________ >>
#   $ 0x85f int3
# ______________________________ >>
#   $ 0x860 int3
# ______________________________ >>
#   $ 0x861 int3
# ______________________________ >>
#   $ 0x862 int3
# ______________________________ >>
#   $ 0x863 int3
# ______________________________ >>
#   $ 0x864 int3
# ______________________________ >>
#   $ 0x865 int3
# ______________________________ >>
#   $ 0x866 int3
# ______________________________ >>
#   $ 0x867 int3
# ______________________________ >>
#   $ 0x868 int3
# ______________________________ >>
#   $ 0x869 int3
# ______________________________ >>
#   $ 0x86a int3
# ______________________________ >>
#   $ 0x86b int3
# ______________________________ >>
#   $ 0x86c int3
# ______________________________ >>
#   $ 0x86d int3
# ______________________________ >>
#   $ 0x86e int3
# ______________________________ >>
#   $ 0x86f int3
# ______________________________ >>
# # $ 0x870 movqword ptr [rsp + 8], rbx
# # $ 0x875 movqword ptr [rsp + 0x10], rbp
# # $ 0x87a movqword ptr [rsp + 0x18], rsi
# # $ 0x87f pushrdi
# # $ 0x880 subrsp, 0x30
# # $ 0x884 movrbx, r9
# # $ 0x887 movrdi, r8
# # $ 0x88a movrsi, rdx
# # $ 0x88d movrbp, rcx
# # $ 0x890 call0x41e
# # $ 0x895 movr9, rdi
# # $ 0x898 movqword ptr [rsp + 0x20], rbx
# # $ 0x89d movr8, rsi
# # $ 0x8a0 movrdx, rbp
# # $ 0x8a3 movrcx, qword ptr [rax]
# # $ 0x8a6 callqword ptr [rip + 0x8f0c]
# # $ 0x8ac movrbx, qword ptr [rsp + 0x40]
# # $ 0x8b1 movrbp, qword ptr [rsp + 0x48]
# # $ 0x8b6 movrsi, qword ptr [rsp + 0x50]
# # $ 0x8bb addrsp, 0x30
# # $ 0x8bf poprdi
# # $ 0x8c0 ret
#   $ 0x8c1 int3
# ______________________________ >>
#   $ 0x8c2 int3
# ______________________________ >>
#   $ 0x8c3 int3
# ______________________________ >>
#   $ 0x8c4 int3
# ______________________________ >>
#   $ 0x8c5 int3
# ______________________________ >>
#   $ 0x8c6 int3
# ______________________________ >>
#   $ 0x8c7 int3
# ______________________________ >>
#   $ 0x8c8 int3
# ______________________________ >>
#   $ 0x8c9 int3
# ______________________________ >>
#   $ 0x8ca int3
# ______________________________ >>
#   $ 0x8cb int3
# ______________________________ >>
#   $ 0x8cc int3
# ______________________________ >>
#   $ 0x8cd int3
# ______________________________ >>
#   $ 0x8ce int3
# ______________________________ >>
#   $ 0x8cf int3
# ______________________________ >>
#   $ 0x8d0 int3
# ______________________________ >>
#   $ 0x8d1 int3
# ______________________________ >>
#   $ 0x8d2 int3
# ______________________________ >>
#   $ 0x8d3 int3
# ______________________________ >>
#   $ 0x8d4 int3
# ______________________________ >>
#   $ 0x8d5 int3
# ______________________________ >>
#   $ 0x8d6 int3
# ______________________________ >>
#   $ 0x8d7 int3
# ______________________________ >>
#   $ 0x8d8 int3
# ______________________________ >>
#   $ 0x8d9 int3
# ______________________________ >>
#   $ 0x8da int3
# ______________________________ >>
#   $ 0x8db int3
# ______________________________ >>
#   $ 0x8dc int3
# ______________________________ >>
#   $ 0x8dd int3
# ______________________________ >>
#   $ 0x8de int3
# ______________________________ >>
#   $ 0x8df int3
# ______________________________ >>
# # $ 0x8e0 subrsp, 0x28
# # $ 0x8e4 lear8, [rsp + 0x30]
# # $ 0x8e9 leardx, [rsp + 0x38]
# # $ 0x8ee learcx, [rip + 0x56bb]
# # $ 0x8f5 call0x441
# # $ 0x8fa cmpeax, -1
# # $ 0x8fd je0x94e
# # $ 0x8ff nop
# # $ 0x900 movr8d, dword ptr [rsp + 0x30]
# # $ 0x905 learcx, [rip + 0x56ac]
# # $ 0x90c movedx, dword ptr [rsp + 0x38]
# # $ 0x910 call0x4e6
# # $ 0x915 movedx, dword ptr [rsp + 0x30]
# # $ 0x919 learcx, [rip + 0x56a0]
# # $ 0x920 movr8d, dword ptr [rsp + 0x38]
# # $ 0x925 movdword ptr [rsp + 0x30], r8d
# # $ 0x92a movdword ptr [rsp + 0x38], edx
# # $ 0x92e call0x4e6
# # $ 0x933 lear8, [rsp + 0x30]
# # $ 0x938 leardx, [rsp + 0x38]
# # $ 0x93d learcx, [rip + 0x566c]
# # $ 0x944 call0x441
# # $ 0x949 cmpeax, -1
# # $ 0x94c jne0x900
# # $ 0x94e xoreax, eax
# # $ 0x950 addrsp, 0x28
# # $ 0x954 ret
#   $ 0x955 int3
# ______________________________ >>
#   $ 0x956 int3
# ______________________________ >>
#   $ 0x957 int3
# ______________________________ >>
#   $ 0x958 int3
# ______________________________ >>
#   $ 0x959 int3
# ______________________________ >>
#   $ 0x95a int3
# ______________________________ >>
#   $ 0x95b int3
# ______________________________ >>
#   $ 0x95c int3
# ______________________________ >>
#   $ 0x95d int3
# ______________________________ >>
#   $ 0x95e int3
# ______________________________ >>
#   $ 0x95f int3
# ______________________________ >>
#   $ 0x960 int3
# ______________________________ >>
#   $ 0x961 int3
# ______________________________ >>
#   $ 0x962 int3
# ______________________________ >>
#   $ 0x963 int3
# ______________________________ >>
#   $ 0x964 int3
# ______________________________ >>
#   $ 0x965 int3
# ______________________________ >>
#   $ 0x966 int3
# ______________________________ >>
#   $ 0x967 int3
# ______________________________ >>
#   $ 0x968 int3
# ______________________________ >>
#   $ 0x969 int3
# ______________________________ >>
#   $ 0x96a int3
# ______________________________ >>
#   $ 0x96b int3
# ______________________________ >>
#   $ 0x96c int3
# ______________________________ >>
#   $ 0x96d int3
# ______________________________ >>
#   $ 0x96e int3
# ______________________________ >>
#   $ 0x96f int3
# ______________________________ >>
#   $ 0x970 int3
# ______________________________ >>
#   $ 0x971 int3
# ______________________________ >>
#   $ 0x972 int3
# ______________________________ >>
#   $ 0x973 int3
# ______________________________ >>
#   $ 0x974 int3
# ______________________________ >>
#   $ 0x975 int3
# ______________________________ >>
#   $ 0x976 int3
# ______________________________ >>
#   $ 0x977 int3
# ______________________________ >>
#   $ 0x978 int3
# ______________________________ >>
#   $ 0x979 int3
# ______________________________ >>
#   $ 0x97a int3
# ______________________________ >>
#   $ 0x97b int3
# ______________________________ >>
#   $ 0x97c int3
# ______________________________ >>
#   $ 0x97d int3
# ______________________________ >>
#   $ 0x97e int3
# ______________________________ >>
#   $ 0x97f int3
# ______________________________ >>
# # $ 0x980 movqword ptr [rsp + 8], rcx
# # $ 0x985 movqword ptr [rsp + 0x10], rdx
# # $ 0x98a movqword ptr [rsp + 0x18], r8
# # $ 0x98f movqword ptr [rsp + 0x20], r9
# # $ 0x994 pushrbx
# # $ 0x995 pushrsi
# # $ 0x996 pushrdi
# # $ 0x997 subrsp, 0x30
# # $ 0x99b movrdi, rcx
# # $ 0x99e learsi, [rsp + 0x58]
# # $ 0x9a3 movecx, 1
# # $ 0x9a8 callqword ptr [rip + 0x8dfa]
# # $ 0x9ae movrbx, rax
# # $ 0x9b1 call0x40f
# # $ 0x9b6 xorr9d, r9d
# # $ 0x9b9 movqword ptr [rsp + 0x20], rsi
# # $ 0x9be movr8, rdi
# # $ 0x9c1 movrdx, rbx
# # $ 0x9c4 movrcx, qword ptr [rax]
# # $ 0x9c7 callqword ptr [rip + 0x8df3]
# # $ 0x9cd addrsp, 0x30
# # $ 0x9d1 poprdi
# # $ 0x9d2 poprsi
# # $ 0x9d3 poprbx
# # $ 0x9d4 ret
#   $ 0x9d5 int3
# ______________________________ >>
#   $ 0x9d6 int3
# ______________________________ >>
#   $ 0x9d7 int3
# ______________________________ >>
#   $ 0x9d8 int3
# ______________________________ >>
#   $ 0x9d9 int3
# ______________________________ >>
#   $ 0x9da int3
# ______________________________ >>
#   $ 0x9db int3
# ______________________________ >>
#   $ 0x9dc int3
# ______________________________ >>
#   $ 0x9dd int3
# ______________________________ >>
#   $ 0x9de int3
# ______________________________ >>
#   $ 0x9df int3
# ______________________________ >>
#   $ 0x9e0 int3
# ______________________________ >>
#   $ 0x9e1 int3
# ______________________________ >>
#   $ 0x9e2 int3
# ______________________________ >>
#   $ 0x9e3 int3
# ______________________________ >>
#   $ 0x9e4 int3
# ______________________________ >>
#   $ 0x9e5 int3
# ______________________________ >>
#   $ 0x9e6 int3
# ______________________________ >>
#   $ 0x9e7 int3
# ______________________________ >>
#   $ 0x9e8 int3
# ______________________________ >>
#   $ 0x9e9 int3
# ______________________________ >>
#   $ 0x9ea int3
# ______________________________ >>
#   $ 0x9eb int3
# ______________________________ >>
#   $ 0x9ec int3
# ______________________________ >>
#   $ 0x9ed int3
# ______________________________ >>
#   $ 0x9ee int3
# ______________________________ >>
#   $ 0x9ef int3
# ______________________________ >>
# # $ 0x9f0 movqword ptr [rsp + 8], rcx
# # $ 0x9f5 movqword ptr [rsp + 0x10], rdx
# # $ 0x9fa movqword ptr [rsp + 0x18], r8
# # $ 0x9ff movqword ptr [rsp + 0x20], r9
# # $ 0xa04 pushrbx
# # $ 0xa05 pushrsi
# # $ 0xa06 pushrdi
# # $ 0xa07 subrsp, 0x30
# # $ 0xa0b movrdi, rcx
# # $ 0xa0e learsi, [rsp + 0x58]
# # $ 0xa13 xorecx, ecx
# # $ 0xa15 callqword ptr [rip + 0x8d8d]
# # $ 0xa1b movrbx, rax
# # $ 0xa1e call0x41e
# # $ 0xa23 xorr9d, r9d
# # $ 0xa26 movqword ptr [rsp + 0x20], rsi
# # $ 0xa2b movr8, rdi
# # $ 0xa2e movrdx, rbx
# # $ 0xa31 movrcx, qword ptr [rax]
# # $ 0xa34 callqword ptr [rip + 0x8d7e]
# # $ 0xa3a addrsp, 0x30
# # $ 0xa3e poprdi
# # $ 0xa3f poprsi
# # $ 0xa40 poprbx
# # $ 0xa41 ret
#   $ 0xa42 int3
# ______________________________ >>
#   $ 0xa43 int3
# ______________________________ >>
#   $ 0xa44 int3
# ______________________________ >>
#   $ 0xa45 int3
# ______________________________ >>
#   $ 0xa46 int3
# ______________________________ >>
#   $ 0xa47 int3
# ______________________________ >>
#   $ 0xa48 int3
# ______________________________ >>
#   $ 0xa49 int3
# ______________________________ >>
#   $ 0xa4a int3
# ______________________________ >>
#   $ 0xa4b int3
# ______________________________ >>
#   $ 0xa4c int3
# ______________________________ >>
#   $ 0xa4d int3
# ______________________________ >>
#   $ 0xa4e int3
# ______________________________ >>
#   $ 0xa4f int3
# ______________________________ >>
#   $ 0xa50 int3
# ______________________________ >>
#   $ 0xa51 int3
# ______________________________ >>
#   $ 0xa52 int3
# ______________________________ >>
#   $ 0xa53 int3
# ______________________________ >>
#   $ 0xa54 int3
# ______________________________ >>
#   $ 0xa55 int3
# ______________________________ >>
#   $ 0xa56 int3
# ______________________________ >>
#   $ 0xa57 int3
# ______________________________ >>
# # $ 0xa58 pushrbx
# # $ 0xa5a subrsp, 0x20
# # $ 0xa5e movecx, 1
# # $ 0xa63 call0x1fca
# # $ 0xa68 call0x4fa
# # $ 0xa6d movecx, eax
# # $ 0xa6f call0x2000
# # $ 0xa74 call0x4dc
# # $ 0xa79 movebx, eax
# # $ 0xa7b call0x2030
# # $ 0xa80 movecx, 1
# # $ 0xa85 movdword ptr [rax], ebx
# # $ 0xa87 call0x47d
# # $ 0xa8c testal, al
# # $ 0xa8e je0xb03
# # $ 0xa90 call0x50e
# # $ 0xa95 learcx, [rip - 0x584]
# # $ 0xa9c call0x4b9
# # $ 0xaa1 call0x504
# # $ 0xaa6 movecx, eax
# # $ 0xaa8 call0x1fd6
# # $ 0xaad testeax, eax
# # $ 0xaaf jne0xb03
# # $ 0xab1 call0x455
# # $ 0xab6 call0x51d
# # $ 0xabb testeax, eax
# # $ 0xabd je0xacb
# # $ 0xabf learcx, [rip - 0x676]
# # $ 0xac6 call0x1fd0
# # $ 0xacb call0x5bd
# # $ 0xad0 call0x49b
# # $ 0xad5 call0x42d
# # $ 0xada movecx, eax
# # $ 0xadc call0x2024
# # $ 0xae1 call0x4f0
# # $ 0xae6 testal, al
# # $ 0xae8 je0xaef
# # $ 0xaea call0x1fdc
# # $ 0xaef call0x509
# # $ 0xaf4 call0x5c2
# # $ 0xaf9 testeax, eax
# # $ 0xafb jne0xb03
# # $ 0xafd addrsp, 0x20
# # $ 0xb01 poprbx
# # $ 0xb02 ret
# # $ 0xb03 movecx, 7
# # $ 0xb08 call0x5a4
#   $ 0xb0d int3
# ______________________________ >>
#   $ 0xb0e int3
# ______________________________ >>
#   $ 0xb0f int3
# ______________________________ >>
#   $ 0xb10 int3
# ______________________________ >>
#   $ 0xb11 int3
# ______________________________ >>
#   $ 0xb12 int3
# ______________________________ >>
#   $ 0xb13 int3
# ______________________________ >>
#   $ 0xb14 int3
# ______________________________ >>
#   $ 0xb15 int3
# ______________________________ >>
#   $ 0xb16 int3
# ______________________________ >>
#   $ 0xb17 int3
# ______________________________ >>
#   $ 0xb18 int3
# ______________________________ >>
#   $ 0xb19 int3
# ______________________________ >>
#   $ 0xb1a int3
# ______________________________ >>
#   $ 0xb1b int3
# ______________________________ >>
#   $ 0xb1c int3
# ______________________________ >>
#   $ 0xb1d int3
# ______________________________ >>
#   $ 0xb1e int3
# ______________________________ >>
#   $ 0xb1f int3
# ______________________________ >>
#   $ 0xb20 int3
# ______________________________ >>
#   $ 0xb21 int3
# ______________________________ >>
#   $ 0xb22 int3
# ______________________________ >>
#   $ 0xb23 int3
# ______________________________ >>
#   $ 0xb24 int3
# ______________________________ >>
#   $ 0xb25 int3
# ______________________________ >>
#   $ 0xb26 int3
# ______________________________ >>
#   $ 0xb27 int3
# ______________________________ >>
#   $ 0xb28 int3
# ______________________________ >>
#   $ 0xb29 int3
# ______________________________ >>
#   $ 0xb2a int3
# ______________________________ >>
#   $ 0xb2b int3
# ______________________________ >>
#   $ 0xb2c int3
# ______________________________ >>
#   $ 0xb2d int3
# ______________________________ >>
#   $ 0xb2e int3
# ______________________________ >>
#   $ 0xb2f int3
# ______________________________ >>
#   $ 0xb30 int3
# ______________________________ >>
#   $ 0xb31 int3
# ______________________________ >>
#   $ 0xb32 int3
# ______________________________ >>
#   $ 0xb33 int3
# ______________________________ >>
#   $ 0xb34 int3
# ______________________________ >>
#   $ 0xb35 int3
# ______________________________ >>
#   $ 0xb36 int3
# ______________________________ >>
#   $ 0xb37 int3
# ______________________________ >>
#   $ 0xb38 int3
# ______________________________ >>
#   $ 0xb39 int3
# ______________________________ >>
#   $ 0xb3a int3
# ______________________________ >>
#   $ 0xb3b int3
# ______________________________ >>
# # $ 0xb3c subrsp, 0x28
# # $ 0xb40 call0x581
# # $ 0xb45 xoreax, eax
# # $ 0xb47 addrsp, 0x28
# # $ 0xb4b ret
#   $ 0xb4c int3
# ______________________________ >>
#   $ 0xb4d int3
# ______________________________ >>
#   $ 0xb4e int3
# ______________________________ >>
#   $ 0xb4f int3
# ______________________________ >>
# # $ 0xb50 subrsp, 0x28
# # $ 0xb54 call0x522
# # $ 0xb59 call0x432
# # $ 0xb5e movecx, eax
# # $ 0xb60 addrsp, 0x28
# # $ 0xb64 jmp0x202a
#   $ 0xb69 int3
# ______________________________ >>
#   $ 0xb6a int3
# ______________________________ >>
#   $ 0xb6b int3
# ______________________________ >>
#   $ 0xb6c int3
# ______________________________ >>
#   $ 0xb6d int3
# ______________________________ >>
#   $ 0xb6e int3
# ______________________________ >>
#   $ 0xb6f int3
# ______________________________ >>
# # $ 0xb70 subrsp, 0x28
# # $ 0xb74 call0x54f
# # $ 0xb79 addrsp, 0x28
# # $ 0xb7d jmp0xb88
#   $ 0xb82 int3
# ______________________________ >>
#   $ 0xb83 int3
# ______________________________ >>
#   $ 0xb84 int3
# ______________________________ >>
#   $ 0xb85 int3
# ______________________________ >>
#   $ 0xb86 int3
# ______________________________ >>
#   $ 0xb87 int3
# ______________________________ >>
# # $ 0xb88 movqword ptr [rsp + 8], rbx
# # $ 0xb8d movqword ptr [rsp + 0x10], rsi
# # $ 0xb92 pushrdi
# # $ 0xb93 subrsp, 0x30
# # $ 0xb97 movecx, 1
# # $ 0xb9c call0x5cc
# # $ 0xba1 testal, al
# # $ 0xba3 je0xcdf
# # $ 0xba9 xorsil, sil
# # $ 0xbac movbyte ptr [rsp + 0x20], sil
# # $ 0xbb1 call0x5ae
# # $ 0xbb6 movbl, al
# # $ 0xbb8 movecx, dword ptr [rip + 0x69f2]
# # $ 0xbbe cmpecx, 1
# # $ 0xbc1 je0xcea
# # $ 0xbc7 testecx, ecx
# # $ 0xbc9 jne0xc15
# # $ 0xbcb movdword ptr [rip + 0x69db], 1
# # $ 0xbd5 leardx, [rip + 0x4e84]
# # $ 0xbdc learcx, [rip + 0x4b4d]
# # $ 0xbe3 call0x1fee
# # $ 0xbe8 testeax, eax
# # $ 0xbea je0xbf6
# # $ 0xbec moveax, 0xff
# # $ 0xbf1 jmp0xccf
# # $ 0xbf6 leardx, [rip + 0x4a23]
# # $ 0xbfd learcx, [rip + 0x47fc]
# # $ 0xc04 call0x1fe8
# # $ 0xc09 movdword ptr [rip + 0x699d], 2
# # $ 0xc13 jmp0xc1d
# # $ 0xc15 movsil, 1
# # $ 0xc18 movbyte ptr [rsp + 0x20], sil
# # $ 0xc1d movcl, bl
# # $ 0xc1f call0x59a
# # $ 0xc24 call0x55e
# # $ 0xc29 movrbx, rax
# # $ 0xc2c cmpqword ptr [rax], 0
# # $ 0xc30 je0xc50
# # $ 0xc32 movrcx, rax
# # $ 0xc35 call0x4b4
# # $ 0xc3a testal, al
# # $ 0xc3c je0xc50
# # $ 0xc3e xorr8d, r8d
# # $ 0xc41 leaedx, [r8 + 2]
# # $ 0xc45 xorecx, ecx
# # $ 0xc47 movrax, qword ptr [rbx]
# # $ 0xc4a callqword ptr [rip + 0x97d0]
# # $ 0xc50 call0x577
# # $ 0xc55 movrbx, rax
# # $ 0xc58 cmpqword ptr [rax], 0
# # $ 0xc5c je0xc72
# # $ 0xc5e movrcx, rax
# # $ 0xc61 call0x4b4
# # $ 0xc66 testal, al
# # $ 0xc68 je0xc72
# # $ 0xc6a movrcx, qword ptr [rbx]
# # $ 0xc6d call0x201e
# # $ 0xc72 call0x1fe2
# # $ 0xc77 movrdi, rax
# # $ 0xc7a call0x200c
# # $ 0xc7f movrbx, qword ptr [rax]
# # $ 0xc82 call0x2006
# # $ 0xc87 movr8, rdi
# # $ 0xc8a movrdx, rbx
# # $ 0xc8d movecx, dword ptr [rax]
# # $ 0xc8f call0x536
# # $ 0xc94 movebx, eax
# # $ 0xc96 call0x540
# # $ 0xc9b testal, al
# # $ 0xc9d je0xcf4
# # $ 0xc9f testsil, sil
# # $ 0xca2 jne0xca9
# # $ 0xca4 call0x2012
# # $ 0xca9 xoredx, edx
# # $ 0xcab movcl, 1
# # $ 0xcad call0x4aa
# # $ 0xcb2 moveax, ebx
# # $ 0xcb4 jmp0xccf
#   $ 0xcb6 movebx, eax
# ______________________________ >>
#   $ 0xcb8 call0x540
# ______________________________ >>
#   $ 0xcbd testal, al
# ______________________________ >>
#   $ 0xcbf je0xcfc
# ______________________________ >>
#   $ 0xcc1 cmpbyte ptr [rsp + 0x20], 0
# ______________________________ >>
#   $ 0xcc6 jne0xccd
# ______________________________ >>
#   $ 0xcc8 call0x2018
# ______________________________ >>
#   $ 0xccd moveax, ebx
# ______________________________ >>
# # $ 0xccf movrbx, qword ptr [rsp + 0x40]
# # $ 0xcd4 movrsi, qword ptr [rsp + 0x48]
# # $ 0xcd9 addrsp, 0x30
# # $ 0xcdd poprdi
# # $ 0xcde ret
# # $ 0xcdf movecx, 7
# # $ 0xce4 call0x5a4
#   $ 0xce9 nop
# ______________________________ >>
# # $ 0xcea movecx, 7
# # $ 0xcef call0x5a4
# # $ 0xcf4 movecx, ebx
# # $ 0xcf6 call0x1ff4
#   $ 0xcfb nop
# ______________________________ >>
#   $ 0xcfc movecx, ebx
# ______________________________ >>
#   $ 0xcfe call0x1ffa
# ______________________________ >>
#   $ 0xd03 nop
# ______________________________ >>
#   $ 0xd04 int3
# ______________________________ >>
#   $ 0xd05 int3
# ______________________________ >>
#   $ 0xd06 int3
# ______________________________ >>
#   $ 0xd07 int3
# ______________________________ >>
#   $ 0xd08 int3
# ______________________________ >>
#   $ 0xd09 int3
# ______________________________ >>
#   $ 0xd0a int3
# ______________________________ >>
#   $ 0xd0b int3
# ______________________________ >>
#   $ 0xd0c int3
# ______________________________ >>
#   $ 0xd0d int3
# ______________________________ >>
#   $ 0xd0e int3
# ______________________________ >>
#   $ 0xd0f int3
# ______________________________ >>
#   $ 0xd10 int3
# ______________________________ >>
#   $ 0xd11 int3
# ______________________________ >>
#   $ 0xd12 int3
# ______________________________ >>
#   $ 0xd13 int3
# ______________________________ >>
#   $ 0xd14 int3
# ______________________________ >>
#   $ 0xd15 int3
# ______________________________ >>
#   $ 0xd16 int3
# ______________________________ >>
#   $ 0xd17 int3
# ______________________________ >>
#   $ 0xd18 int3
# ______________________________ >>
#   $ 0xd19 int3
# ______________________________ >>
#   $ 0xd1a int3
# ______________________________ >>
#   $ 0xd1b int3
# ______________________________ >>
#   $ 0xd1c int3
# ______________________________ >>
#   $ 0xd1d int3
# ______________________________ >>
#   $ 0xd1e int3
# ______________________________ >>
#   $ 0xd1f int3
# ______________________________ >>
#   $ 0xd20 int3
# ______________________________ >>
#   $ 0xd21 int3
# ______________________________ >>
#   $ 0xd22 int3
# ______________________________ >>
#   $ 0xd23 int3
# ______________________________ >>
#   $ 0xd24 int3
# ______________________________ >>
#   $ 0xd25 int3
# ______________________________ >>
#   $ 0xd26 int3
# ______________________________ >>
#   $ 0xd27 int3
# ______________________________ >>
#   $ 0xd28 int3
# ______________________________ >>
#   $ 0xd29 int3
# ______________________________ >>
#   $ 0xd2a int3
# ______________________________ >>
#   $ 0xd2b int3
# ______________________________ >>
#   $ 0xd2c int3
# ______________________________ >>
#   $ 0xd2d int3
# ______________________________ >>
#   $ 0xd2e int3
# ______________________________ >>
#   $ 0xd2f int3
# ______________________________ >>
#   $ 0xd30 int3
# ______________________________ >>
#   $ 0xd31 int3
# ______________________________ >>
#   $ 0xd32 int3
# ...
#   $ 0x5161 int3
# ______________________________ >>
#   $ 0x5162 int3
# ______________________________ >>
#   $ 0x5163 int3
# ______________________________ >>
#   $ 0x5164 int3
# ______________________________ >>
#   $ 0x5165 int3
# ______________________________ >>
#   $ 0x5166 int3
# ______________________________ >>
#   $ 0x5167 int3
# ______________________________ >>
#   $ 0x5168 int3
# ______________________________ >>
#   $ 0x5169 int3
# ______________________________ >>
#   $ 0x516a int3
# ______________________________ >>
#   $ 0x516b int3
# ______________________________ >>
#   $ 0x516c int3
# ______________________________ >>
#   $ 0x516d int3
# ______________________________ >>
#   $ 0x516e int3
# ______________________________ >>
#   $ 0x516f int3
# ______________________________ >>
#   $ 0x5170 int3
# ______________________________ >>
#   $ 0x5171 int3
# ______________________________ >>
#   $ 0x5172 int3
# ______________________________ >>
#   $ 0x5173 int3
# ______________________________ >>
#   $ 0x5174 int3
# ______________________________ >>
#   $ 0x5175 int3
# ______________________________ >>
#   $ 0x5176 int3
# ______________________________ >>
#   $ 0x5177 int3
# ______________________________ >>
#   $ 0x5178 int3
# ______________________________ >>
#   $ 0x5179 int3
# ______________________________ >>
#   $ 0x517a int3
# ______________________________ >>
#   $ 0x517b int3
# ______________________________ >>
#   $ 0x517c int3
# ______________________________ >>
#   $ 0x517d int3
# ______________________________ >>
#   $ 0x517e int3
# ______________________________ >>
#   $ 0x517f int3
# ______________________________ >>
#   $ 0x5180 int3
# ______________________________ >>
#   $ 0x5181 int3
# ______________________________ >>
#   $ 0x5182 int3
# ______________________________ >>
#   $ 0x5183 int3
# ______________________________ >>
#   $ 0x5184 int3
# ______________________________ >>
#   $ 0x5185 int3
# ______________________________ >>
#   $ 0x5186 int3
# ______________________________ >>
#   $ 0x5187 int3
# ______________________________ >>
#   $ 0x5188 int3
# ______________________________ >>
#   $ 0x5189 int3
# ______________________________ >>
#   $ 0x518a int3
# ______________________________ >>
#   $ 0x518b int3
# ______________________________ >>
#   $ 0x518c int3
# ______________________________ >>
#   $ 0x518d int3
# ______________________________ >>
#   $ 0x518e int3
# ______________________________ >>
#   $ 0x518f int3
# ______________________________ >>
#   $ 0x5190 int3
# ______________________________ >>
#   $ 0x5191 int3
# ______________________________ >>
#   $ 0x5192 int3
# ______________________________ >>
#   $ 0x5193 int3
# ______________________________ >>
#   $ 0x5194 int3
# ______________________________ >>
#   $ 0x5195 int3
# ______________________________ >>
#   $ 0x5196 int3
# ______________________________ >>
#   $ 0x5197 int3
# ______________________________ >>
#   $ 0x5198 int3
# ______________________________ >>
#   $ 0x5199 int3
# ______________________________ >>
#   $ 0x519a int3
# ______________________________ >>
#   $ 0x519b int3
# ______________________________ >>
#   $ 0x519c int3
# ______________________________ >>
#   $ 0x519d int3
# ______________________________ >>
#   $ 0x519e int3
# ______________________________ >>
#   $ 0x519f int3
# ______________________________ >>
#   $ 0x51a0 int3
# ______________________________ >>
#   $ 0x51a1 int3
# ______________________________ >>
#   $ 0x51a2 int3
# ______________________________ >>
#   $ 0x51a3 int3
# ______________________________ >>
#   $ 0x51a4 int3
# ______________________________ >>
#   $ 0x51a5 int3
# ______________________________ >>
#   $ 0x51a6 int3
# ______________________________ >>
#   $ 0x51a7 int3
# ______________________________ >>
#   $ 0x51a8 int3
# ______________________________ >>
#   $ 0x51a9 int3
# ______________________________ >>
#   $ 0x51aa int3
# ______________________________ >>
#   $ 0x51ab int3
# ______________________________ >>
#   $ 0x51ac int3
# ______________________________ >>
#   $ 0x51ad int3
# ______________________________ >>
#   $ 0x51ae int3
# ______________________________ >>
#   $ 0x51af int3
# ______________________________ >>
#   $ 0x51b0 int3
# ______________________________ >>
#   $ 0x51b1 int3
# ______________________________ >>
#   $ 0x51b2 int3
# ______________________________ >>
#   $ 0x51b3 int3
# ______________________________ >>
#   $ 0x51b4 int3
# ______________________________ >>
#   $ 0x51b5 int3
# ______________________________ >>
#   $ 0x51b6 int3
# ______________________________ >>
#   $ 0x51b7 int3
# ______________________________ >>
#   $ 0x51b8 int3
# ______________________________ >>
#   $ 0x51b9 int3
# ______________________________ >>
#   $ 0x51ba int3
# ______________________________ >>
#   $ 0x51bb int3
# ______________________________ >>
#   $ 0x51bc int3
# ______________________________ >>
#   $ 0x51bd int3
# ______________________________ >>
#   $ 0x51be int3
# ______________________________ >>
#   $ 0x51bf int3
# ______________________________ >>
#   $ 0x51c0 int3
# ______________________________ >>
#   $ 0x51c1 int3
# ______________________________ >>
#   $ 0x51c2 int3
# ______________________________ >>
#   $ 0x51c3 int3
# ______________________________ >>
#   $ 0x51c4 int3
# ______________________________ >>
#   $ 0x51c5 int3
# ______________________________ >>
#   $ 0x51c6 int3
# ______________________________ >>
#   $ 0x51c7 int3
# ______________________________ >>
#   $ 0x51c8 int3
# ______________________________ >>
#   $ 0x51c9 int3
# ______________________________ >>
#   $ 0x51ca int3
# ______________________________ >>
#   $ 0x51cb int3
# ______________________________ >>
#   $ 0x51cc int3
# ______________________________ >>
#   $ 0x51cd int3
# ______________________________ >>
#   $ 0x51ce int3
# ______________________________ >>
#   $ 0x51cf int3
# ______________________________ >>
#   $ 0x51d0 int3
# ______________________________ >>
#   $ 0x51d1 int3
# ______________________________ >>
#   $ 0x51d2 int3
# ______________________________ >>
#   $ 0x51d3 int3
# ______________________________ >>
#   $ 0x51d4 int3
# ______________________________ >>
#   $ 0x51d5 int3
# ______________________________ >>
#   $ 0x51d6 int3
# ______________________________ >>
#   $ 0x51d7 int3
# ______________________________ >>
#   $ 0x51d8 int3
# ______________________________ >>
#   $ 0x51d9 int3
# ______________________________ >>
#   $ 0x51da int3
# ______________________________ >>
#   $ 0x51db int3
# ______________________________ >>
#   $ 0x51dc int3
# ______________________________ >>
#   $ 0x51dd int3
# ______________________________ >>
#   $ 0x51de int3
# ______________________________ >>
#   $ 0x51df int3
# ______________________________ >>
#   $ 0x51e0 int3
# ______________________________ >>
#   $ 0x51e1 int3
# ______________________________ >>
#   $ 0x51e2 int3
# ______________________________ >>
#   $ 0x51e3 int3
# ______________________________ >>
#   $ 0x51e4 int3
# ______________________________ >>
#   $ 0x51e5 int3
# ______________________________ >>
#   $ 0x51e6 int3
# ______________________________ >>
#   $ 0x51e7 int3
# ______________________________ >>
#   $ 0x51e8 int3
# ______________________________ >>
#   $ 0x51e9 int3
# ______________________________ >>
#   $ 0x51ea int3
# ______________________________ >>
#   $ 0x51eb int3
# ______________________________ >>
#   $ 0x51ec int3
# ______________________________ >>
#   $ 0x51ed int3
# ______________________________ >>
#   $ 0x51ee int3
# ______________________________ >>
#   $ 0x51ef int3
# ______________________________ >>
#   $ 0x51f0 int3
# ______________________________ >>
#   $ 0x51f1 int3
# ______________________________ >>
#   $ 0x51f2 int3
# ______________________________ >>
#   $ 0x51f3 int3
# ______________________________ >>
#   $ 0x51f4 int3
# ______________________________ >>
#   $ 0x51f5 int3
# ______________________________ >>
#   $ 0x51f6 int3
# ______________________________ >>
#   $ 0x51f7 int3
# ______________________________ >>
#   $ 0x51f8 int3
# ______________________________ >>
#   $ 0x51f9 int3
# ______________________________ >>
#   $ 0x51fa int3
# ______________________________ >>
#   $ 0x51fb int3
# ______________________________ >>
#   $ 0x51fc int3
# ______________________________ >>
#   $ 0x51fd int3
# ______________________________ >>
#   $ 0x51fe int3
# ______________________________ >>
#   $ 0x51ff int3
# ______________________________ >>
#   $ 0x5200 int3
# ______________________________ >>
#   $ 0x5201 int3
# ______________________________ >>
#   $ 0x5202 int3
# ______________________________ >>
#   $ 0x5203 int3
# ______________________________ >>
#   $ 0x5204 int3
# ______________________________ >>
#   $ 0x5205 int3
# ______________________________ >>
#   $ 0x5206 int3
# ______________________________ >>
#   $ 0x5207 int3
# ______________________________ >>
#   $ 0x5208 int3
# ______________________________ >>
#   $ 0x5209 int3
# ______________________________ >>
#   $ 0x520a int3
# ______________________________ >>
#   $ 0x520b int3
# ______________________________ >>
#   $ 0x520c int3
# ______________________________ >>
#   $ 0x520d int3
# ______________________________ >>
#   $ 0x520e int3
# ______________________________ >>
#   $ 0x520f int3
# ______________________________ >>
#   $ 0x5210 int3
# ______________________________ >>
#   $ 0x5211 int3
# ______________________________ >>
#   $ 0x5212 int3
# ______________________________ >>
#   $ 0x5213 int3
# ______________________________ >>
#   $ 0x5214 int3
# ______________________________ >>
#   $ 0x5215 int3
# ______________________________ >>
#   $ 0x5216 int3
# ______________________________ >>
#   $ 0x5217 int3
# ______________________________ >>
#   $ 0x5218 int3
# ______________________________ >>
#   $ 0x5219 int3
# ______________________________ >>
#   $ 0x521a int3
# ______________________________ >>
#   $ 0x521b int3
# ______________________________ >>
#   $ 0x521c int3
# ______________________________ >>
#   $ 0x521d int3
# ______________________________ >>
#   $ 0x521e int3
# ______________________________ >>
#   $ 0x521f int3
# ______________________________ >>
#   $ 0x5220 int3
# ______________________________ >>
#   $ 0x5221 int3
# ______________________________ >>
#   $ 0x5222 int3
# ______________________________ >>
#   $ 0x5223 int3
# ______________________________ >>
#   $ 0x5224 int3
# ______________________________ >>
#   $ 0x5225 int3
# ______________________________ >>
#   $ 0x5226 int3
# ______________________________ >>
#   $ 0x5227 int3
# ______________________________ >>
#   $ 0x5228 int3
# ______________________________ >>
#   $ 0x5229 int3
# ______________________________ >>
#   $ 0x522a int3
# ______________________________ >>
#   $ 0x522b int3
# ______________________________ >>
#   $ 0x522c int3
# ______________________________ >>
#   $ 0x522d int3
# ______________________________ >>
#   $ 0x522e int3
# ______________________________ >>
#   $ 0x522f int3
# ______________________________ >>
#   $ 0x5230 int3
# ______________________________ >>
#   $ 0x5231 int3
# ______________________________ >>
#   $ 0x5232 int3
# ______________________________ >>
#   $ 0x5233 int3
# ______________________________ >>
#   $ 0x5234 int3
# ______________________________ >>
#   $ 0x5235 int3
# ______________________________ >>
#   $ 0x5236 int3
# ______________________________ >>
#   $ 0x5237 int3
# ______________________________ >>
#   $ 0x5238 int3
# ______________________________ >>
#   $ 0x5239 int3
# ______________________________ >>
#   $ 0x523a int3
# ______________________________ >>
#   $ 0x523b int3
# ______________________________ >>
#   $ 0x523c int3
# ______________________________ >>
#   $ 0x523d int3
# ______________________________ >>
#   $ 0x523e int3
# ______________________________ >>
#   $ 0x523f int3
# ______________________________ >>
#   $ 0x5240 int3
# ______________________________ >>
#   $ 0x5241 int3
# ______________________________ >>
#   $ 0x5242 int3
# ______________________________ >>
#   $ 0x5243 int3
# ______________________________ >>
#   $ 0x5244 int3
# ______________________________ >>
#   $ 0x5245 int3
# ______________________________ >>
#   $ 0x5246 int3
# ______________________________ >>
#   $ 0x5247 int3
# ______________________________ >>
#   $ 0x5248 int3
# ______________________________ >>
#   $ 0x5249 int3
# ______________________________ >>
#   $ 0x524a int3
# ______________________________ >>
#   $ 0x524b int3
# ______________________________ >>
#   $ 0x524c int3
# ______________________________ >>
#   $ 0x524d int3
# ______________________________ >>
#   $ 0x524e int3
# ______________________________ >>
#   $ 0x524f int3
# ______________________________ >>
#   $ 0x5250 int3
# ______________________________ >>
#   $ 0x5251 int3
# ______________________________ >>
#   $ 0x5252 int3
# ______________________________ >>
#   $ 0x5253 int3
# ______________________________ >>
#   $ 0x5254 int3
# ______________________________ >>
#   $ 0x5255 int3
# ______________________________ >>
#   $ 0x5256 int3
# ______________________________ >>
#   $ 0x5257 int3
# ______________________________ >>
#   $ 0x5258 int3
# ______________________________ >>
#   $ 0x5259 int3
# ______________________________ >>
#   $ 0x525a int3
# ______________________________ >>
#   $ 0x525b int3
# ______________________________ >>
#   $ 0x525c int3
# ______________________________ >>
#   $ 0x525d int3
# ______________________________ >>
#   $ 0x525e int3
# ______________________________ >>
#   $ 0x525f int3
# ______________________________ >>
#   $ 0x5260 int3
# ______________________________ >>
#   $ 0x5261 int3
# ______________________________ >>
#   $ 0x5262 int3
# ______________________________ >>
#   $ 0x5263 int3
# ______________________________ >>
#   $ 0x5264 int3
# ______________________________ >>
#   $ 0x5265 int3
# ______________________________ >>
#   $ 0x5266 int3
# ______________________________ >>
#   $ 0x5267 int3
# ______________________________ >>
#   $ 0x5268 int3
# ______________________________ >>
#   $ 0x5269 int3
# ______________________________ >>
#   $ 0x526a int3
# ______________________________ >>
#   $ 0x526b int3
# ______________________________ >>
#   $ 0x526c int3
# ______________________________ >>
#   $ 0x526d int3
# ______________________________ >>
#   $ 0x526e int3
# ______________________________ >>
#   $ 0x526f int3
# ______________________________ >>
#   $ 0x5270 int3
# ______________________________ >>
#   $ 0x5271 int3
# ______________________________ >>
#   $ 0x5272 int3
# ______________________________ >>
#   $ 0x5273 int3
# ______________________________ >>
#   $ 0x5274 int3
# ______________________________ >>
#   $ 0x5275 int3
# ______________________________ >>
#   $ 0x5276 int3
# ______________________________ >>
#   $ 0x5277 int3
# ______________________________ >>
#   $ 0x5278 int3
# ______________________________ >>
#   $ 0x5279 int3
# ______________________________ >>
#   $ 0x527a int3
# ______________________________ >>
#   $ 0x527b int3
# ______________________________ >>
#   $ 0x527c int3
# ______________________________ >>
#   $ 0x527d int3
# ______________________________ >>
#   $ 0x527e int3
# ______________________________ >>
#   $ 0x527f int3
# ______________________________ >>
#   $ 0x5280 int3
# ______________________________ >>
#   $ 0x5281 int3
# ______________________________ >>
#   $ 0x5282 int3
# ______________________________ >>
#   $ 0x5283 int3
# ______________________________ >>
#   $ 0x5284 int3
# ______________________________ >>
#   $ 0x5285 int3
# ______________________________ >>
#   $ 0x5286 int3
# ______________________________ >>
#   $ 0x5287 int3
# ______________________________ >>
#   $ 0x5288 int3
# ______________________________ >>
#   $ 0x5289 int3
# ______________________________ >>
#   $ 0x528a int3
# ______________________________ >>
#   $ 0x528b int3
# ______________________________ >>
#   $ 0x528c int3
# ______________________________ >>
#   $ 0x528d int3
# ______________________________ >>
#   $ 0x528e int3
# ______________________________ >>
#   $ 0x528f int3
# ______________________________ >>
#   $ 0x5290 int3
# ______________________________ >>
#   $ 0x5291 int3
# ______________________________ >>
#   $ 0x5292 int3
# ______________________________ >>
#   $ 0x5293 int3
# ______________________________ >>
#   $ 0x5294 int3
# ______________________________ >>
#   $ 0x5295 int3
# ______________________________ >>
#   $ 0x5296 int3
# ______________________________ >>
#   $ 0x5297 int3
# ______________________________ >>
#   $ 0x5298 int3
# ______________________________ >>
#   $ 0x5299 int3
# ______________________________ >>
#   $ 0x529a int3
# ______________________________ >>
#   $ 0x529b int3
# ______________________________ >>
#   $ 0x529c int3
# ______________________________ >>
#   $ 0x529d int3
# ______________________________ >>
#   $ 0x529e int3
# ______________________________ >>
#   $ 0x529f int3
# ______________________________ >>
#   $ 0x52a0 int3
# ______________________________ >>

# %%
print(f"TP: {all_TP}, FP: {all_FP}, FN: {all_FN}, TN: {all_TN}")
# Out:
# TP: 16157, FP: 52766, FN: 0, TN: 113971

# %%
accuracy = (all_TP + all_TN) / (all_TP + all_TN + all_FP + all_FN)
precision = all_TP / (all_TP + all_FP) if (all_TP + all_FP) > 0 else 0
recall = all_TP / (all_TP + all_FN) if (all_TP + all_FN) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1_score:.4f}")
# Out:
# Accuracy: 0.7115
# Precision: 0.2344
# Recall: 1.0000
# F1-score: 0.3798
