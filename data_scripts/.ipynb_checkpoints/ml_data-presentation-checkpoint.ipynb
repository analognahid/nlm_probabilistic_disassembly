# %%
import os,sys, json
import magic, hashlib, os, traceback
import ntpath
from capstone import *
from capstone.x86 import *

import collections
import traceback
from elftools.elf.elffile import ELFFile

# %%
bin_path = '/home/raisul/DATA/x86_O2_d4/'

bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) ][0:10]

ground_truth_path = '/home/raisul/ANALYSED_DATA/objdump_x86_O2_d4/'

# %%
len(bin_files)
# Out:
# 10

# %%
def get_ground_truth(exe_path):
    elf_file_name = os.path.basename(exe_path)
    objdump_file_path = os.path.join(ground_truth_path, elf_file_name) + '.json'
    
    with open(objdump_file_path, "r") as file:
        objdump_data = json.load(file)

    ground_truth_offsets = list(objdump_data["instructions"].keys())
    ground_truth_offsets.remove('meta')
    ground_truth_offsets = [int(i) for i in ground_truth_offsets]

    return ground_truth_offsets

# %%
def linear_sweep(offset_inst , target_offset):
    inst_sequence = []
    max_seq_length = 15

    
    current_offset = target_offset
    for q in range(max_seq_length):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:

                inst_sequence.insert(0, None) 
                inst_sequence.append(None)
                return  inst_sequence
                
            current_offset = current_offset + current_instruction.size
            inst_sequence.append( current_instruction.mnemonic +' '+ current_instruction.op_str )
            # inst_sequence.append( current_instruction)
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                return inst_sequence

    return inst_sequence


for bin_file_path in bin_files:

    ground_truth_offsets = get_ground_truth(bin_file_path)
    print(ground_truth_offsets)
    
    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    print("\n"*5)
    
    with open(bin_file_path, 'rb') as f:
        elffile = ELFFile(f)
        textSection = elffile.get_section_by_name('.text').data()
        text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
        for byte_index in range(len(textSection)):
            
        
            try:    

                instruction = next(md.disasm(textSection[byte_index: ], text_section_offset + byte_index ), None)
                
                # if instruction:
                #     print("0x%x:\t%s\t%s _\t%x" %(instruction.address, instruction.mnemonic, instruction.op_str, instruction.size))
                #     print(instruction.operands[0].type , instruction.operands[0].imm)
                #     # print( dir(instruction.operands[0] ))
          
                # else:
                #     print("0x%x:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                    
                offset_inst[text_section_offset+byte_index] = instruction

            except Exception as e:
                print(traceback.print_exc() )
                print(e)

        
        
        offset_inst = collections.OrderedDict(sorted(offset_inst.items()))

        # print(offset_inst)
        for byte_index in range(len(textSection)):
            inst_seq = linear_sweep(offset_inst ,text_section_offset + byte_index )
            print('\n\n\n','# # '*10)
            print(inst_seq)
# Out:
# [4096, 4100, 4104, 4111, 4114, 4116, 4118, 4122, 4128, 4134, 4140, 4144, 4148, 4153, 4158, 4160, 4164, 4169, 4174, 4176, 4180, 4186, 4192, 4196, 4202, 4208, 4212, 4218, 4224, 4228, 4232, 4236, 4238, 4243, 4250, 4255, 4259, 4262, 4265, 4268, 4271, 4274, 4277, 4280, 4282, 4285, 4290, 4292, 4296, 4297, 4304, 4308, 4310, 4313, 4314, 4317, 4321, 4322, 4323, 4326, 4328, 4335, 4341, 4342, 4352, 4359, 4366, 4369, 4371, 4378, 4381, 4383, 4385, 4392, 4393, 4400, 4407, 4414, 4417, 4420, 4424, 4428, 4431, 4434, 4436, 4443, 4446, 4448, 4450, 4456, 4457, 4464, 4468, 4475, 4477, 4478, 4486, 4489, 4491, 4498, 4503, 4508, 4515, 4516, 4517, 4520, 4521, 4528, 4532, 4540, 4544, 4548, 4552]
#
#
#
#
#
#
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['endbr64 ', 'sub rsp, 8', 'mov rdi, qword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cli ', 'sub rsp, 8', 'mov rdi, qword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub rsp, 8', 'mov rdi, qword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub esp, 8', 'mov rdi, qword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['in al, dx', 'or byte ptr [rax - 0x75], cl', 'jle 0x1094', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or byte ptr [rax - 0x75], cl', 'jle 0x1094', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rdi, qword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov edi, dword ptr [rsi + 8]', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jle 0x1094', 'xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'or byte ptr [rcx], dh', 'shr al, 0xdd', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, eax', 'call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'shr al, 0xdd', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['call 0x1070', 'lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['dec dword ptr [rax - 0x73]', 'xor eax, 0xf6a', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rsi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea esi, [rip + 0xf6a]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, 0xf6a', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['push 0xf', 'add byte ptr [rax], al', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sldt word ptr [rax]', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rdi + 2], bh', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov edi, 2', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add al, byte ptr [rax]', 'add byte ptr [rax], al', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax], al', 'add byte ptr [rbp + 0xf024054], cl', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rbp + 0xf024054], cl', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea edx, [rax + rax*2 + 2]', 'imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'push rsp', 'add cl, byte ptr [rdi]', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add cl, byte ptr [rdi]', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add cl, byte ptr [rdi]', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['imul edx, eax', 'sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'rol byte ptr [rbx - 0x50f0fa16], 1', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub edx, 5', 'imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add eax, 0x83d0af0f', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['imul edx, eax', 'sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'rol byte ptr [rbx - 0x50f0fe16], 1', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub edx, 1', 'imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add dword ptr [rdi], ecx', 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['imul edx, eax', 'add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'scasd eax, dword ptr [rdi]', 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'rol byte ptr [rbx - 0x50f0f83e], 1', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add edx, 7', 'imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret 0xf07']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['imul edx, eax', 'xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'scasd eax, dword ptr [rdi]', 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'sal byte ptr [rcx], 1', 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, eax', 'sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'rol byte ptr [rbx - 0x6117f916], 0xff', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub edx, 6', 'call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['call 0x1060', 'xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'sahf ', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['push qword ptr [rcx]', 'ror byte ptr [rax - 0x7d], 0xc4', 'or bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, eax', 'add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ror byte ptr [rax - 0x7d], 0xc4', 'or bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add rsp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add esp, 8', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax], al', 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['endbr64 ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cli ', 'xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor ebp, ebp', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['in eax, dx', 'mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov r9, rdx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov ecx, edx', 'pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['rcr dword ptr [rsi + 0x48], 1', 'mov edx, esp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['pop rsi', 'mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rdx, rsp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov edx, esp', 'and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['loop 0x1126', 'and esp, 0xfffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['and rsp, 0xfffffffffffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['and esp, 0xfffffff0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['in al, 0xf0', 'push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['push rax', 'push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['push rsp', 'xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor r8d, r8d', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, eax', 'xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sal byte ptr [rcx], 0xc9', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor ecx, ecx', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['leave ', 'lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rdi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea edi, [rip - 0x6f]', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0xffffff91', 'call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'xchg ecx, eax', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['call qword ptr [rip + 0x2ee3]', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['adc eax, 0x2ee3', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jrcxz 0x1121', 'add byte ptr [rax], al', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr cs:[rax], al', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add ah, dh', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['hlt ', 'nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop word ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr cs:[rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax + rax]', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test byte ptr [rax], al', 'add byte ptr [rax], al', 'add byte ptr [rax], al', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'add byte ptr [rax - 0x73], cl', 'cmp eax, 0x2f09', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax - 0x73], cl', 'cmp eax, 0x2f09', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x73], cl', 'cmp eax, 0x2f09', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rdi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea edi, [rip + 0x2f09]', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0x2f09', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or dword ptr [rdi], ebp', 'add byte ptr [rax], al', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x73], cl', 'add eax, 0x2f02', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea eax, [rip + 0x2f02]', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add eax, 0x2f02', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add ch, byte ptr [rdi]', 'add byte ptr [rax], al', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax + 0x39], cl', 'clc ', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp rax, rdi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, edi', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['clc ', 'je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1128', 'mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['adc eax, 0xc6058b48', 'add byte ptr cs:[rax], al', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rax, qword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov eax, dword ptr [rip + 0x2ec6]', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add eax, 0x2ec6', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr cs:[rax], al', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x7b], cl', 'sal byte ptr [rcx + rcx - 1], 0xe0', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test rax, rax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test eax, eax', 'je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sal byte ptr [rcx + rcx - 1], 0xe0', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1128', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'or edi, edi', 'loopne 0x1131', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'loopne 0x1131', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add bl, al', 'nop dword ptr [rax]', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add bl, al', 'nop dword ptr [rax]', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax - 0x73], cl', 'cmp eax, 0x2ed9', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x73], cl', 'cmp eax, 0x2ed9', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rdi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea edi, [rip + 0x2ed9]', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0x2ed9', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['fldcw word ptr [rsi]', 'add byte ptr [rax], al', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr cs:[rax], al', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x73], cl', 'xor eax, 0x2ed2', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea rsi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['lea esi, [rip + 0x2ed2]', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xor eax, 0x2ed2', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['shr byte ptr [rsi], cl', 'add byte ptr [rax], al', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr cs:[rax], al', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax + 0x29], cl', 'dec byte ptr [rax - 0x77]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub rsi, rdi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub esi, edi', 'mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'dec byte ptr [rax - 0x77]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rax, rsi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov eax, esi', 'shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['shr rsi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['shr esi, 0x3f', 'sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'out dx, al', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar eax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'clc ', 'add ecx, dword ptr [rax + 1]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add ecx, dword ptr [rax + 1]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add rsi, rax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add esi, eax', 'sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar rsi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar esi, 1', 'je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1168', 'mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['adc al, 0x48', 'mov eax, dword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rax, qword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov eax, dword ptr [rip + 0x2e95]', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add eax, 0x2e95', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['xchg ebp, eax', 'add byte ptr cs:[rax], al', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr cs:[rax], al', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x7b], cl', 'sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test rax, rax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test eax, eax', 'je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1168', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or bh, bh', 'loopne 0x11c9', 'nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['loopne 0x11c9', 'nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], r8b', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'cmp byte ptr [rip + 0x2e95], 0', 'jne 0x11a8', 'push rbp', 'cmp qword ptr [rip + 0x2e72], 0', 'mov rbp, rsp', 'je 0x1197', 'mov rdi, qword ptr [rip + 0x2e76]', 'call 0x1050', 'call 0x1100', 'mov byte ptr [rip + 0x2e6d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'endbr64 ', 'cmp byte ptr [rip + 0x2e95], 0', 'jne 0x11a8', 'push rbp', 'cmp qword ptr [rip + 0x2e72], 0', 'mov rbp, rsp', 'je 0x1197', 'mov rdi, qword ptr [rip + 0x2e76]', 'call 0x1050', 'call 0x1100', 'mov byte ptr [rip + 0x2e6d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2e95], 0', 'jne 0x11a8', 'push rbp', 'cmp qword ptr [rip + 0x2e72], 0', 'mov rbp, rsp', 'je 0x1197', 'mov rdi, qword ptr [rip + 0x2e76]', 'call 0x1050', 'call 0x1100', 'mov byte ptr [rip + 0x2e6d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2e95], 0', 'jne 0x11a8', 'push rbp', 'cmp qword ptr [rip + 0x2e72], 0', 'mov rbp, rsp', 'je 0x1197', 'mov rdi, qword ptr [rip + 0x2e76]', 'call 0x1050', 'call 0x1100', 'mov byte ptr [rip + 0x2e6d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax], al', 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2e95], 0', 'jne 0x11a8', 'push rbp', 'cmp qword ptr [rip + 0x2e72], 0', 'mov rbp, rsp', 'je 0x1197', 'mov rdi, qword ptr [rip + 0x2e76]', 'call 0x1050', 'call 0x1100', 'mov byte ptr [rip + 0x2e6d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ...
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'out dx, al', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar rax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar eax, 3', 'add rsi, rax', 'sar rsi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'clc ', 'add ecx, dword ptr [rax + 1]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add ecx, dword ptr [rax + 1]', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add rsi, rax', 'sar rsi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add esi, eax', 'sar rsi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar rsi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sar esi, 1', 'je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1278', 'mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['adc al, 0x48', 'mov eax, dword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rax, qword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov eax, dword ptr [rip + 0x2d85]', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add eax, 0x2d85', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test dword ptr [rip - 0x7ab80000], ebp', 'sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub eax, 0x85480000', 'sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x7b], cl', 'sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test rax, rax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test eax, eax', 'je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sal byte ptr [rax + rcx - 1], 0xe0', 'nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x1278', 'jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or bh, bh', 'loopne 0x12d9', 'nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jmp rax']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['loopne 0x12d9', 'nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop word ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax + rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], r8b', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax], al', 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['endbr64 ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cli ', 'cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp byte ptr [rip + 0x2d85], 0', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0x2d85', 'add byte ptr [rbp + 0x2b], dh', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['test dword ptr [rip + 0x75000000], ebp', 'sub edx, dword ptr [rbp + 0x48]', 'cmp dword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub eax, 0x75000000', 'sub edx, dword ptr [rbp + 0x48]', 'cmp dword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rbp + 0x2b], dh', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rbp + 0x2b], dh', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jne 0x12b8', 'push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub edx, dword ptr [rbp + 0x48]', 'cmp dword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['push rbp', 'cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp qword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp dword ptr [rip + 0x2d62], 0', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0x2d62', 'add byte ptr [rax - 0x77], cl', 'in eax, 0x74', 'or al, 0x48', 'mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub eax, 0x48000000', 'mov ebp, esp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax - 0x77], cl', 'in eax, 0x74', 'or al, 0x48', 'mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax - 0x77], cl', 'in eax, 0x74', 'or al, 0x48', 'mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rbp, rsp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov ebp, esp', 'je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['in eax, 0x74', 'or al, 0x48', 'mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['je 0x12a7', 'mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['or al, 0x48', 'mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov rdi, qword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov edi, dword ptr [rip + 0x2d66]', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cmp eax, 0x2d66', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub ax, 0', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'sub eax, 0xb9e80000', 'std ', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add al, ch', 'mov ecx, 0xe8fffffd', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['call 0x1060', 'call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'mov ecx, 0xe8fffffd', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'std ', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['call 0x1210', 'mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['inc esi', 'add eax, 0x2d5d', 'add dword ptr [rbp - 0x3d], ebx', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['mov byte ptr [rip + 0x2d5d], 1', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add eax, 0x2d5d', 'add dword ptr [rbp - 0x3d], ebx', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['pop rbp', 'sub eax, 0x5d010000', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['sub eax, 0x5d010000', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add dword ptr [rbp - 0x3d], ebx', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rcx], al', 'pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add dword ptr [rbp - 0x3d], ebx', 'nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['pop rbp', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add bl, al', 'nop dword ptr [rax]', 'endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['ret ']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['nop dword ptr [rax]', 'endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], 0', 'add byte ptr [rax], al', 'endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'add byte ptr [rax], al', 'endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add byte ptr [rax], al', 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['add byte ptr [rax], al', 'endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'add bl, dh', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['endbr64 ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['cli ', 'jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# ['jmp 0x1240']
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, 'ja 0x12c6', None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
#
#
#
#  # # # # # # # # # # # # # # # # # # # #
# [None, None]
