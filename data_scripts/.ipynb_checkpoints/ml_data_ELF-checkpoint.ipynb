# %%
import os,sys, json
import magic, hashlib, os, traceback
import ntpath
from capstone import *
from capstone.x86 import *

import collections
import traceback
import lief

# %%
bin_path = '/home/raisul/DATA/x86_O2_d4' #'/home/raisul/DATA/x86_O2_d4_mingw32_PE' 

bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) ][0:2]

ground_truth_path ='/home/raisul/ANALYSED_DATA/objdump_x86_O2_d4/' # '/home/raisul/ANALYSED_DATA/ghidra_x86_O2_d4_mingw32_PE'

# %%
len(bin_files)
# Out:
# 2

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def get_ground_truth_objdump(exe_path, text_section_offset , text_section_len ):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    objdump_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(objdump_file_path, "r") as file:
        objdump_data = json.load(file)

    ground_truth_offsets = list(objdump_data["instructions"].keys())
    # print(ground_truth_offsets)
    if 'meta' in ground_truth_offsets:
        ground_truth_offsets.remove('meta')
    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()

    
    return ground_truth_offsets

# %%
def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):

    # print('dbug 1',ground_truth_offsets)
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            
            print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                print("# ",j, offset_inst_dict[ground_truth_offsets[j]] , 'inst len:',offset_inst_dict[ground_truth_offsets[j]].size )
            print('\n')
        else:
            print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]] ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            


def linear_sweep(offset_inst , target_offset):
    inst_sequence = []
    max_seq_length = 15

    
    current_offset = target_offset
    for q in range(max_seq_length):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:

                inst_sequence.insert(0, None) 
                inst_sequence.append(None)
                return  inst_sequence
                
            current_offset = current_offset + current_instruction.size
            inst_sequence.append( str(current_instruction.address) +": "+ current_instruction.mnemonic +' '+ current_instruction.op_str )
            # inst_sequence.append( current_instruction)
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                return inst_sequence

    return inst_sequence


for bin_file_path in bin_files:

    # try:
    #     ground_truth_offsets = get_ground_truth(bin_file_path, text_section_offset , len(textSection))
    # except Exception as e:
    #     print("An error occurred:", e)
    # print(ground_truth_offsets)
    
    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    # print("\n"*5)
    

    try:

        # PE
        pe_file = lief.parse(bin_file_path)
        
        # if rheader := pe.rich_header:
        #     print(rheader.key)



        # textSection = elffile.get_section_by_name('.text').data()
        # text_section_offset = elffile.get_section_by_name('.text')['sh_offset']


        text_section = pe_file.get_section(".text")


        # Get the section's offset in the file
        text_section_offset = text_section.pointerto_raw_data
    
        # Get the section's raw binary data
        textSection = bytes(text_section.content)
    



        
        ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))


    
        
    except Exception as e:
        print("An error occurred:", e ,bin_file_path)
    for byte_index in range(len(textSection)):
        
    
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
            #     print(instruction.operands[0].type , instruction.operands[0].imm)
            #     # print( dir(instruction.operands[0] ))
      
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                
            offset_inst[text_section_offset+byte_index] = instruction

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst = collections.OrderedDict(sorted(offset_inst.items()))

    find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)
    
    # print(offset_inst)
    for byte_index in range(len(textSection)):
        inst_seq = linear_sweep(offset_inst ,text_section_offset + byte_index )
        # print('\n','# # '*10)
        # print(inst_seq)
    # print(ground_truth_offsets)
    # print(offset_inst.keys())
    print('\n','# # '*30)
# Out:
# 1028   0x404 <CsInsn 0x404 [488d0df5ff0100]: lea rcx, [rip + 0x1fff5]>  len 7
# 1035   0x40b <CsInsn 0x40b [e870000000]: call 0x480>  len 5
# 1040   0x410 <CsInsn 0x410 [90]: nop >  len 1
# 1041   0x411 <CsInsn 0x411 [33c0]: xor eax, eax>  len 2
# 1043   0x413 <CsInsn 0x413 [4883c428]: add rsp, 0x28>  len 4
# 1047   0x417 <CsInsn 0x417 [c3]: ret >  len 1
# 1048   0x418 <CsInsn 0x418 [cc]: int3 >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  1049 <CsInsn 0x134c [498b0c09]: mov rcx, qword ptr [r9 + rcx]> inst len: 4
# #  1050 <CsInsn 0x1350 [4c63040a]: movsxd r8, dword ptr [rdx + rcx]> inst len: 4
# #  1051 <CsInsn 0x1354 [4d03c1]: add r8, r9> inst len: 3
# #  1052 <CsInsn 0x1357 [4903c0]: add rax, r8> inst len: 3
# #  1053 <CsInsn 0x135a [c3]: ret > inst len: 1
# #  1054 <CsInsn 0x135c [48895c2408]: mov qword ptr [rsp + 8], rbx> inst len: 5
# #  1055 <CsInsn 0x1361 [57]: push rdi> inst len: 1
#
#
# 1056   0x420 <CsInsn 0x420 [488d05991c0200]: lea rax, [rip + 0x21c99]>  len 7
# 1063   0x427 <CsInsn 0x427 [c3]: ret >  len 1
#
# Byte GAP ######  9  Missing bytes:  8
# #  1064 <CsInsn 0x1382 [7422]: je 0x13a6> inst len: 2
# #  1065 <CsInsn 0x1384 [eb13]: jmp 0x1399> inst len: 2
# #  1066 <CsInsn 0x1386 [e831010000]: call 0x14bc> inst len: 5
# #  1067 <CsInsn 0x138b [83783000]: cmp dword ptr [rax + 0x30], 0> inst len: 4
# #  1068 <CsInsn 0x138f [7e08]: jle 0x1399> inst len: 2
# #  1069 <CsInsn 0x1391 [e826010000]: call 0x14bc> inst len: 5
# #  1070 <CsInsn 0x1396 [ff4830]: dec dword ptr [rax + 0x30]> inst len: 3
# #  1071 <CsInsn 0x1399 [488b5c2430]: mov rbx, qword ptr [rsp + 0x30]> inst len: 5
#
#
# 1072   0x430 <CsInsn 0x430 [4c894c2420]: mov qword ptr [rsp + 0x20], r9>  len 5
# 1077   0x435 <CsInsn 0x435 [4c89442418]: mov qword ptr [rsp + 0x18], r8>  len 5
# 1082   0x43a <CsInsn 0x43a [4889542410]: mov qword ptr [rsp + 0x10], rdx>  len 5
# 1087   0x43f <CsInsn 0x43f [48894c2408]: mov qword ptr [rsp + 8], rcx>  len 5
# 1092   0x444 <CsInsn 0x444 [4883ec38]: sub rsp, 0x38>  len 4
# 1096   0x448 <CsInsn 0x448 [e8d3ffffff]: call 0x420>  len 5
# 1101   0x44d <CsInsn 0x44d [488b4c2458]: mov rcx, qword ptr [rsp + 0x58]>  len 5
# 1106   0x452 <CsInsn 0x452 [48894c2420]: mov qword ptr [rsp + 0x20], rcx>  len 5
# 1111   0x457 <CsInsn 0x457 [4c8b4c2450]: mov r9, qword ptr [rsp + 0x50]>  len 5
# 1116   0x45c <CsInsn 0x45c [4c8b442448]: mov r8, qword ptr [rsp + 0x48]>  len 5
# 1121   0x461 <CsInsn 0x461 [488b542440]: mov rdx, qword ptr [rsp + 0x40]>  len 5
# 1126   0x466 <CsInsn 0x466 [488b08]: mov rcx, qword ptr [rax]>  len 3
# 1129   0x469 <CsInsn 0x469 [e882540000]: call 0x58f0>  len 5
# 1134   0x46e <CsInsn 0x46e [4883c438]: add rsp, 0x38>  len 4
# 1138   0x472 <CsInsn 0x472 [c3]: ret >  len 1
# 1139   0x473 <CsInsn 0x473 [cc]: int3 >  len 1
#
# Byte GAP ######  13  Missing bytes:  12
# #  1140 <CsInsn 0x14d5 [cc]: int3 > inst len: 1
# #  1141 <CsInsn 0x14d8 [48895c2408]: mov qword ptr [rsp + 8], rbx> inst len: 5
# #  1142 <CsInsn 0x14dd [4889742410]: mov qword ptr [rsp + 0x10], rsi> inst len: 5
# #  1143 <CsInsn 0x14e2 [57]: push rdi> inst len: 1
# #  1144 <CsInsn 0x14e3 [4883ec20]: sub rsp, 0x20> inst len: 4
# #  1145 <CsInsn 0x14e7 [833da2ef0100ff]: cmp dword ptr [rip + 0x1efa2], -1> inst len: 7
# #  1146 <CsInsn 0x14ee [7507]: jne 0x14f7> inst len: 2
# #  1147 <CsInsn 0x14f0 [33c0]: xor eax, eax> inst len: 2
# #  1148 <CsInsn 0x14f2 [e990000000]: jmp 0x1587> inst len: 5
# #  1149 <CsInsn 0x14f7 [ff15833f0100]: call qword ptr [rip + 0x13f83]> inst len: 6
# #  1150 <CsInsn 0x14fd [8b0d8def0100]: mov ecx, dword ptr [rip + 0x1ef8d]> inst len: 6
# #  1151 <CsInsn 0x1503 [8bf8]: mov edi, eax> inst len: 2
#
#
# 1152   0x480 <CsInsn 0x480 [48894c2408]: mov qword ptr [rsp + 8], rcx>  len 5
# 1157   0x485 <CsInsn 0x485 [4889542410]: mov qword ptr [rsp + 0x10], rdx>  len 5
# 1162   0x48a <CsInsn 0x48a [4c89442418]: mov qword ptr [rsp + 0x18], r8>  len 5
# 1167   0x48f <CsInsn 0x48f [4c894c2420]: mov qword ptr [rsp + 0x20], r9>  len 5
# 1172   0x494 <CsInsn 0x494 [4883ec38]: sub rsp, 0x38>  len 4
# 1176   0x498 <CsInsn 0x498 [488d442448]: lea rax, [rsp + 0x48]>  len 5
# 1181   0x49d <CsInsn 0x49d [4889442428]: mov qword ptr [rsp + 0x28], rax>  len 5
# 1186   0x4a2 <CsInsn 0x4a2 [b901000000]: mov ecx, 1>  len 5
# 1191   0x4a7 <CsInsn 0x4a7 [e814340000]: call 0x38c0>  len 5
# 1196   0x4ac <CsInsn 0x4ac [4c8b4c2428]: mov r9, qword ptr [rsp + 0x28]>  len 5
# 1201   0x4b1 <CsInsn 0x4b1 [4533c0]: xor r8d, r8d>  len 3
# 1204   0x4b4 <CsInsn 0x4b4 [488b542440]: mov rdx, qword ptr [rsp + 0x40]>  len 5
# 1209   0x4b9 <CsInsn 0x4b9 [488bc8]: mov rcx, rax>  len 3
# 1212   0x4bc <CsInsn 0x4bc [e86fffffff]: call 0x430>  len 5
# 1217   0x4c1 <CsInsn 0x4c1 [89442420]: mov dword ptr [rsp + 0x20], eax>  len 4
# 1221   0x4c5 <CsInsn 0x4c5 [48c744242800000000]: mov qword ptr [rsp + 0x28], 0>  len 9
# 1230   0x4ce <CsInsn 0x4ce [8b442420]: mov eax, dword ptr [rsp + 0x20]>  len 4
# 1234   0x4d2 <CsInsn 0x4d2 [4883c438]: add rsp, 0x38>  len 4
# 1238   0x4d6 <CsInsn 0x4d6 [c3]: ret >  len 1
# 1239   0x4d7 <CsInsn 0x4d7 [cc]: int3 >  len 1
# 1240   0x4d8 <CsInsn 0x4d8 [4053]: push rbx>  len 2
# 1242   0x4da <CsInsn 0x4da [4883ec20]: sub rsp, 0x20>  len 4
# 1246   0x4de <CsInsn 0x4de [b901000000]: mov ecx, 1>  len 5
# 1251   0x4e3 <CsInsn 0x4e3 [e8b8560000]: call 0x5ba0>  len 5
# 1256   0x4e8 <CsInsn 0x4e8 [e857050000]: call 0xa44>  len 5
# 1261   0x4ed <CsInsn 0x4ed [8bc8]: mov ecx, eax>  len 2
# 1263   0x4ef <CsInsn 0x4ef [e848620000]: call 0x673c>  len 5
# 1268   0x4f4 <CsInsn 0x4f4 [e83f050000]: call 0xa38>  len 5
# 1273   0x4f9 <CsInsn 0x4f9 [8bd8]: mov ebx, eax>  len 2
# 1275   0x4fb <CsInsn 0x4fb [e800640000]: call 0x6900>  len 5
# 1280   0x500 <CsInsn 0x500 [b901000000]: mov ecx, 1>  len 5
# 1285   0x505 <CsInsn 0x505 [8918]: mov dword ptr [rax], ebx>  len 2
# 1287   0x507 <CsInsn 0x507 [e8b8020000]: call 0x7c4>  len 5
# 1292   0x50c <CsInsn 0x50c [84c0]: test al, al>  len 2
# 1294   0x50e <CsInsn 0x50e [7473]: je 0x583>  len 2
# 1296   0x510 <CsInsn 0x510 [e8a7070000]: call 0xcbc>  len 5
# 1301   0x515 <CsInsn 0x515 [488d0ddc070000]: lea rcx, [rip + 0x7dc]>  len 7
# 1308   0x51c <CsInsn 0x51c [e853040000]: call 0x974>  len 5
# 1313   0x521 <CsInsn 0x521 [e816050000]: call 0xa3c>  len 5
# 1318   0x526 <CsInsn 0x526 [8bc8]: mov ecx, eax>  len 2
# 1320   0x528 <CsInsn 0x528 [e82f590000]: call 0x5e5c>  len 5
# 1325   0x52d <CsInsn 0x52d [85c0]: test eax, eax>  len 2
# 1327   0x52f <CsInsn 0x52f [7552]: jne 0x583>  len 2
# 1329   0x531 <CsInsn 0x531 [e816050000]: call 0xa4c>  len 5
# 1334   0x536 <CsInsn 0x536 [e84d050000]: call 0xa88>  len 5
# 1339   0x53b <CsInsn 0x53b [85c0]: test eax, eax>  len 2
# 1341   0x53d <CsInsn 0x53d [740c]: je 0x54b>  len 2
# 1343   0x53f <CsInsn 0x53f [488d0df2040000]: lea rcx, [rip + 0x4f2]>  len 7
# 1350   0x546 <CsInsn 0x546 [e8c1560000]: call 0x5c0c>  len 5
# 1355   0x54b <CsInsn 0x54b [e810050000]: call 0xa60>  len 5
# 1360   0x550 <CsInsn 0x550 [e80b050000]: call 0xa60>  len 5
# 1365   0x555 <CsInsn 0x555 [e8de040000]: call 0xa38>  len 5
# 1370   0x55a <CsInsn 0x55a [8bc8]: mov ecx, eax>  len 2
# 1372   0x55c <CsInsn 0x55c [e8ff620000]: call 0x6860>  len 5
# 1377   0x561 <CsInsn 0x561 [e8f6040000]: call 0xa5c>  len 5
# 1382   0x566 <CsInsn 0x566 [84c0]: test al, al>  len 2
# 1384   0x568 <CsInsn 0x568 [7405]: je 0x56f>  len 2
# 1386   0x56a <CsInsn 0x56a [e8255e0000]: call 0x6394>  len 5
# 1391   0x56f <CsInsn 0x56f [e8c4040000]: call 0xa38>  len 5
# 1396   0x574 <CsInsn 0x574 [e87b060000]: call 0xbf4>  len 5
# 1401   0x579 <CsInsn 0x579 [85c0]: test eax, eax>  len 2
# 1403   0x57b <CsInsn 0x57b [7506]: jne 0x583>  len 2
# 1405   0x57d <CsInsn 0x57d [4883c420]: add rsp, 0x20>  len 4
# 1409   0x581 <CsInsn 0x581 [5b]: pop rbx>  len 1
# 1410   0x582 <CsInsn 0x582 [c3]: ret >  len 1
# 1411   0x583 <CsInsn 0x583 [b907000000]: mov ecx, 7>  len 5
# 1416   0x588 <CsInsn 0x588 [e81f050000]: call 0xaac>  len 5
# 1421   0x58d <CsInsn 0x58d [cc]: int3 >  len 1
# 1422   0x58e <CsInsn 0x58e [cc]: int3 >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  1423 <CsInsn 0x18ec [ff15ce3b0100]: call qword ptr [rip + 0x13bce]> inst len: 6
#
#
# 1424   0x590 <CsInsn 0x590 [4883ec28]: sub rsp, 0x28>  len 4
# 1428   0x594 <CsInsn 0x594 [e8d3040000]: call 0xa6c>  len 5
# 1433   0x599 <CsInsn 0x599 [33c0]: xor eax, eax>  len 2
# 1435   0x59b <CsInsn 0x59b [4883c428]: add rsp, 0x28>  len 4
# 1439   0x59f <CsInsn 0x59f [c3]: ret >  len 1
# 1440   0x5a0 <CsInsn 0x5a0 [4883ec28]: sub rsp, 0x28>  len 4
# 1444   0x5a4 <CsInsn 0x5a4 [e8a7060000]: call 0xc50>  len 5
# 1449   0x5a9 <CsInsn 0x5a9 [e88a040000]: call 0xa38>  len 5
# 1454   0x5ae <CsInsn 0x5ae [8bc8]: mov ecx, eax>  len 2
# 1456   0x5b0 <CsInsn 0x5b0 [4883c428]: add rsp, 0x28>  len 4
# 1460   0x5b4 <CsInsn 0x5b4 [e91b630000]: jmp 0x68d4>  len 5
# 1465   0x5b9 <CsInsn 0x5b9 [cc]: int3 >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  1466 <CsInsn 0x198b [e82cfbffff]: call 0x14bc> inst len: 5
# #  1467 <CsInsn 0x1990 [488d542458]: lea rdx, [rsp + 0x58]> inst len: 5
#
#
# 1468   0x5bc <CsInsn 0x5bc [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 1473   0x5c1 <CsInsn 0x5c1 [4889742410]: mov qword ptr [rsp + 0x10], rsi>  len 5
# 1478   0x5c6 <CsInsn 0x5c6 [57]: push rdi>  len 1
# 1479   0x5c7 <CsInsn 0x5c7 [4883ec30]: sub rsp, 0x30>  len 4
# 1483   0x5cb <CsInsn 0x5cb [b901000000]: mov ecx, 1>  len 5
# 1488   0x5d0 <CsInsn 0x5d0 [e8b3010000]: call 0x788>  len 5
# 1493   0x5d5 <CsInsn 0x5d5 [84c0]: test al, al>  len 2
# 1495   0x5d7 <CsInsn 0x5d7 [0f8436010000]: je 0x713>  len 6
# 1501   0x5dd <CsInsn 0x5dd [4032f6]: xor sil, sil>  len 3
# 1504   0x5e0 <CsInsn 0x5e0 [4088742420]: mov byte ptr [rsp + 0x20], sil>  len 5
# 1509   0x5e5 <CsInsn 0x5e5 [e862010000]: call 0x74c>  len 5
# 1514   0x5ea <CsInsn 0x5ea [8ad8]: mov bl, al>  len 2
# 1516   0x5ec <CsInsn 0x5ec [8b0d1e090200]: mov ecx, dword ptr [rip + 0x2091e]>  len 6
# 1522   0x5f2 <CsInsn 0x5f2 [83f901]: cmp ecx, 1>  len 3
# 1525   0x5f5 <CsInsn 0x5f5 [0f8423010000]: je 0x71e>  len 6
# 1531   0x5fb <CsInsn 0x5fb [85c9]: test ecx, ecx>  len 2
# 1533   0x5fd <CsInsn 0x5fd [754a]: jne 0x649>  len 2
# 1535   0x5ff <CsInsn 0x5ff [c7050709020001000000]: mov dword ptr [rip + 0x20907], 1>  len 10
# 1545   0x609 <CsInsn 0x609 [488d15d0500100]: lea rdx, [rip + 0x150d0]>  len 7
# 1552   0x610 <CsInsn 0x610 [488d0d91500100]: lea rcx, [rip + 0x15091]>  len 7
# 1559   0x617 <CsInsn 0x617 [e8c45d0000]: call 0x63e0>  len 5
# 1564   0x61c <CsInsn 0x61c [85c0]: test eax, eax>  len 2
# 1566   0x61e <CsInsn 0x61e [740a]: je 0x62a>  len 2
# 1568   0x620 <CsInsn 0x620 [b8ff000000]: mov eax, 0xff>  len 5
# 1573   0x625 <CsInsn 0x625 [e9d9000000]: jmp 0x703>  len 5
# 1578   0x62a <CsInsn 0x62a [488d156f500100]: lea rdx, [rip + 0x1506f]>  len 7
# 1585   0x631 <CsInsn 0x631 [488d0d58500100]: lea rcx, [rip + 0x15058]>  len 7
# 1592   0x638 <CsInsn 0x638 [e85f5d0000]: call 0x639c>  len 5
# 1597   0x63d <CsInsn 0x63d [c705c908020002000000]: mov dword ptr [rip + 0x208c9], 2>  len 10
# 1607   0x647 <CsInsn 0x647 [eb08]: jmp 0x651>  len 2
# 1609   0x649 <CsInsn 0x649 [40b601]: mov sil, 1>  len 3
# 1612   0x64c <CsInsn 0x64c [4088742420]: mov byte ptr [rsp + 0x20], sil>  len 5
# 1617   0x651 <CsInsn 0x651 [8acb]: mov cl, bl>  len 2
# 1619   0x653 <CsInsn 0x653 [e890020000]: call 0x8e8>  len 5
# 1624   0x658 <CsInsn 0x658 [e837040000]: call 0xa94>  len 5
# 1629   0x65d <CsInsn 0x65d [488bd8]: mov rbx, rax>  len 3
# 1632   0x660 <CsInsn 0x660 [48833800]: cmp qword ptr [rax], 0>  len 4
# 1636   0x664 <CsInsn 0x664 [741e]: je 0x684>  len 2
# 1638   0x666 <CsInsn 0x666 [488bc8]: mov rcx, rax>  len 3
# 1641   0x669 <CsInsn 0x669 [e8e2010000]: call 0x850>  len 5
# 1646   0x66e <CsInsn 0x66e [84c0]: test al, al>  len 2
# 1648   0x670 <CsInsn 0x670 [7412]: je 0x684>  len 2
# 1650   0x672 <CsInsn 0x672 [4533c0]: xor r8d, r8d>  len 3
# 1653   0x675 <CsInsn 0x675 [418d5002]: lea edx, [r8 + 2]>  len 4
# 1657   0x679 <CsInsn 0x679 [33c9]: xor ecx, ecx>  len 2
# 1659   0x67b <CsInsn 0x67b [488b03]: mov rax, qword ptr [rbx]>  len 3
# 1662   0x67e <CsInsn 0x67e [ff15e44f0100]: call qword ptr [rip + 0x14fe4]>  len 6
# 1668   0x684 <CsInsn 0x684 [e813040000]: call 0xa9c>  len 5
# 1673   0x689 <CsInsn 0x689 [488bd8]: mov rbx, rax>  len 3
# 1676   0x68c <CsInsn 0x68c [48833800]: cmp qword ptr [rax], 0>  len 4
# 1680   0x690 <CsInsn 0x690 [7414]: je 0x6a6>  len 2
# 1682   0x692 <CsInsn 0x692 [488bc8]: mov rcx, rax>  len 3
# 1685   0x695 <CsInsn 0x695 [e8b6010000]: call 0x850>  len 5
# 1690   0x69a <CsInsn 0x69a [84c0]: test al, al>  len 2
# 1692   0x69c <CsInsn 0x69c [7408]: je 0x6a6>  len 2
# 1694   0x69e <CsInsn 0x69e [488b0b]: mov rcx, qword ptr [rbx]>  len 3
# 1697   0x6a1 <CsInsn 0x6a1 [e84a600000]: call 0x66f0>  len 5
# 1702   0x6a6 <CsInsn 0x6a6 [e8995c0000]: call 0x6344>  len 5
# 1707   0x6ab <CsInsn 0x6ab [488bf8]: mov rdi, rax>  len 3
# 1710   0x6ae <CsInsn 0x6ae [e8f9600000]: call 0x67ac>  len 5
# 1715   0x6b3 <CsInsn 0x6b3 [488b18]: mov rbx, qword ptr [rax]>  len 3
# 1718   0x6b6 <CsInsn 0x6b6 [e8e9600000]: call 0x67a4>  len 5
# 1723   0x6bb <CsInsn 0x6bb [4c8bc7]: mov r8, rdi>  len 3
# 1726   0x6be <CsInsn 0x6be [488bd3]: mov rdx, rbx>  len 3
# 1729   0x6c1 <CsInsn 0x6c1 [8b08]: mov ecx, dword ptr [rax]>  len 2
# 1731   0x6c3 <CsInsn 0x6c3 [e838fdffff]: call 0x400>  len 5
# 1736   0x6c8 <CsInsn 0x6c8 [8bd8]: mov ebx, eax>  len 2
# 1738   0x6ca <CsInsn 0x6ca [e82d050000]: call 0xbfc>  len 5
# 1743   0x6cf <CsInsn 0x6cf [84c0]: test al, al>  len 2
# 1745   0x6d1 <CsInsn 0x6d1 [7455]: je 0x728>  len 2
# 1747   0x6d3 <CsInsn 0x6d3 [4084f6]: test sil, sil>  len 3
# 1750   0x6d6 <CsInsn 0x6d6 [7505]: jne 0x6dd>  len 2
# 1752   0x6d8 <CsInsn 0x6d8 [e8f75f0000]: call 0x66d4>  len 5
# 1757   0x6dd <CsInsn 0x6dd [33d2]: xor edx, edx>  len 2
# 1759   0x6df <CsInsn 0x6df [b101]: mov cl, 1>  len 2
# 1761   0x6e1 <CsInsn 0x6e1 [e826020000]: call 0x90c>  len 5
# 1766   0x6e6 <CsInsn 0x6e6 [8bc3]: mov eax, ebx>  len 2
# 1768   0x6e8 <CsInsn 0x6e8 [eb19]: jmp 0x703>  len 2
#
# Byte GAP ######  27  Missing bytes:  25
# #  1770 <CsInsn 0x1da2 [4833cc]: xor rcx, rsp> inst len: 3
# #  1771 <CsInsn 0x1da5 [e876190100]: call 0x13720> inst len: 5
# #  1772 <CsInsn 0x1daa [4881c4e0000000]: add rsp, 0xe0> inst len: 7
# #  1773 <CsInsn 0x1db1 [5d]: pop rbp> inst len: 1
# #  1774 <CsInsn 0x1db2 [c3]: ret > inst len: 1
# #  1775 <CsInsn 0x1db3 [cc]: int3 > inst len: 1
# #  1776 <CsInsn 0x1db4 [4053]: push rbx> inst len: 2
# #  1777 <CsInsn 0x1db6 [4883ec20]: sub rsp, 0x20> inst len: 4
# #  1778 <CsInsn 0x1dba [488bd9]: mov rbx, rcx> inst len: 3
# #  1779 <CsInsn 0x1dbd [488911]: mov qword ptr [rcx], rdx> inst len: 3
# #  1780 <CsInsn 0x1dc0 [e8f7f6ffff]: call 0x14bc> inst len: 5
# #  1781 <CsInsn 0x1dc5 [483b5858]: cmp rbx, qword ptr [rax + 0x58]> inst len: 4
# #  1782 <CsInsn 0x1dc9 [730b]: jae 0x1dd6> inst len: 2
# #  1783 <CsInsn 0x1dcb [e8ecf6ffff]: call 0x14bc> inst len: 5
# #  1784 <CsInsn 0x1dd0 [488b4858]: mov rcx, qword ptr [rax + 0x58]> inst len: 4
# #  1785 <CsInsn 0x1dd4 [eb02]: jmp 0x1dd8> inst len: 2
# #  1786 <CsInsn 0x1dd6 [33c9]: xor ecx, ecx> inst len: 2
# #  1787 <CsInsn 0x1dd8 [48894b08]: mov qword ptr [rbx + 8], rcx> inst len: 4
# #  1788 <CsInsn 0x1ddc [e8dbf6ffff]: call 0x14bc> inst len: 5
# #  1789 <CsInsn 0x1de1 [48895858]: mov qword ptr [rax + 0x58], rbx> inst len: 4
# #  1790 <CsInsn 0x1de5 [488bc3]: mov rax, rbx> inst len: 3
# #  1791 <CsInsn 0x1de8 [4883c420]: add rsp, 0x20> inst len: 4
# #  1792 <CsInsn 0x1dec [5b]: pop rbx> inst len: 1
# #  1793 <CsInsn 0x1ded [c3]: ret > inst len: 1
# #  1794 <CsInsn 0x1dee [cc]: int3 > inst len: 1
#
#
# 1795   0x703 <CsInsn 0x703 [488b5c2440]: mov rbx, qword ptr [rsp + 0x40]>  len 5
# 1800   0x708 <CsInsn 0x708 [488b742448]: mov rsi, qword ptr [rsp + 0x48]>  len 5
# 1805   0x70d <CsInsn 0x70d [4883c430]: add rsp, 0x30>  len 4
# 1809   0x711 <CsInsn 0x711 [5f]: pop rdi>  len 1
# 1810   0x712 <CsInsn 0x712 [c3]: ret >  len 1
# 1811   0x713 <CsInsn 0x713 [b907000000]: mov ecx, 7>  len 5
# 1816   0x718 <CsInsn 0x718 [e88f030000]: call 0xaac>  len 5
# 1821   0x71d <CsInsn 0x71d [90]: nop >  len 1
# 1822   0x71e <CsInsn 0x71e [b907000000]: mov ecx, 7>  len 5
# 1827   0x723 <CsInsn 0x723 [e884030000]: call 0xaac>  len 5
# 1832   0x728 <CsInsn 0x728 [8bcb]: mov ecx, ebx>  len 2
# 1834   0x72a <CsInsn 0x72a [e801600000]: call 0x6730>  len 5
# 1839   0x72f <CsInsn 0x72f [90]: nop >  len 1
# 1840   0x730 <CsInsn 0x730 [8bcb]: mov ecx, ebx>  len 2
# 1842   0x732 <CsInsn 0x732 [e8ad5f0000]: call 0x66e4>  len 5
# 1847   0x737 <CsInsn 0x737 [90]: nop >  len 1
# 1848   0x738 <CsInsn 0x738 [4883ec28]: sub rsp, 0x28>  len 4
# 1852   0x73c <CsInsn 0x73c [e84b020000]: call 0x98c>  len 5
# 1857   0x741 <CsInsn 0x741 [4883c428]: add rsp, 0x28>  len 4
# 1861   0x745 <CsInsn 0x745 [e972feffff]: jmp 0x5bc>  len 5
# 1866   0x74a <CsInsn 0x74a [cc]: int3 >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  1867 <CsInsn 0x1ee0 [4c8bcf]: mov r9, rdi> inst len: 3
#
#
# 1868   0x74c <CsInsn 0x74c [4883ec28]: sub rsp, 0x28>  len 4
# 1872   0x750 <CsInsn 0x750 [e8ab080000]: call 0x1000>  len 5
# 1877   0x755 <CsInsn 0x755 [85c0]: test eax, eax>  len 2
# 1879   0x757 <CsInsn 0x757 [7421]: je 0x77a>  len 2
# 1881   0x759 <CsInsn 0x759 [65488b042530000000]: mov rax, qword ptr gs:[0x30]>  len 9
# 1890   0x762 <CsInsn 0x762 [488b4808]: mov rcx, qword ptr [rax + 8]>  len 4
# 1894   0x766 <CsInsn 0x766 [eb05]: jmp 0x76d>  len 2
# 1896   0x768 <CsInsn 0x768 [483bc8]: cmp rcx, rax>  len 3
# 1899   0x76b <CsInsn 0x76b [7414]: je 0x781>  len 2
# 1901   0x76d <CsInsn 0x76d [33c0]: xor eax, eax>  len 2
# 1903   0x76f <CsInsn 0x76f [f0480fb10da0070200]: lock cmpxchg qword ptr [rip + 0x207a0], rcx>  len 9
# 1912   0x778 <CsInsn 0x778 [75ee]: jne 0x768>  len 2
# 1914   0x77a <CsInsn 0x77a [32c0]: xor al, al>  len 2
# 1916   0x77c <CsInsn 0x77c [4883c428]: add rsp, 0x28>  len 4
# 1920   0x780 <CsInsn 0x780 [c3]: ret >  len 1
# 1921   0x781 <CsInsn 0x781 [b001]: mov al, 1>  len 2
# 1923   0x783 <CsInsn 0x783 [ebf7]: jmp 0x77c>  len 2
# 1925   0x785 <CsInsn 0x785 [cc]: int3 >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  1926 <CsInsn 0x1fb6 [3b7c0804]: cmp edi, dword ptr [rax + rcx + 4]> inst len: 4
# #  1927 <CsInsn 0x1fba [7e04]: jle 0x1fc0> inst len: 2
#
#
# 1928   0x788 <CsInsn 0x788 [4883ec28]: sub rsp, 0x28>  len 4
# 1932   0x78c <CsInsn 0x78c [85c9]: test ecx, ecx>  len 2
# 1934   0x78e <CsInsn 0x78e [7507]: jne 0x797>  len 2
# 1936   0x790 <CsInsn 0x790 [c6058907020001]: mov byte ptr [rip + 0x20789], 1>  len 7
# 1943   0x797 <CsInsn 0x797 [e898050000]: call 0xd34>  len 5
# 1948   0x79c <CsInsn 0x79c [e8870a0000]: call 0x1228>  len 5
# 1953   0x7a1 <CsInsn 0x7a1 [84c0]: test al, al>  len 2
# 1955   0x7a3 <CsInsn 0x7a3 [7504]: jne 0x7a9>  len 2
# 1957   0x7a5 <CsInsn 0x7a5 [32c0]: xor al, al>  len 2
# 1959   0x7a7 <CsInsn 0x7a7 [eb14]: jmp 0x7bd>  len 2
# 1961   0x7a9 <CsInsn 0x7a9 [e892660000]: call 0x6e40>  len 5
# 1966   0x7ae <CsInsn 0x7ae [84c0]: test al, al>  len 2
# 1968   0x7b0 <CsInsn 0x7b0 [7509]: jne 0x7bb>  len 2
# 1970   0x7b2 <CsInsn 0x7b2 [33c9]: xor ecx, ecx>  len 2
# 1972   0x7b4 <CsInsn 0x7b4 [e8970a0000]: call 0x1250>  len 5
# 1977   0x7b9 <CsInsn 0x7b9 [ebea]: jmp 0x7a5>  len 2
# 1979   0x7bb <CsInsn 0x7bb [b001]: mov al, 1>  len 2
# 1981   0x7bd <CsInsn 0x7bd [4883c428]: add rsp, 0x28>  len 4
# 1985   0x7c1 <CsInsn 0x7c1 [c3]: ret >  len 1
# 1986   0x7c2 <CsInsn 0x7c2 [cc]: int3 >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  1987 <CsInsn 0x2076 [eb06]: jmp 0x207e> inst len: 2
#
#
# 1988   0x7c4 <CsInsn 0x7c4 [4053]: push rbx>  len 2
# 1990   0x7c6 <CsInsn 0x7c6 [4883ec20]: sub rsp, 0x20>  len 4
# 1994   0x7ca <CsInsn 0x7ca [803d5007020000]: cmp byte ptr [rip + 0x20750], 0>  len 7
# 2001   0x7d1 <CsInsn 0x7d1 [8bd9]: mov ebx, ecx>  len 2
# 2003   0x7d3 <CsInsn 0x7d3 [7567]: jne 0x83c>  len 2
# 2005   0x7d5 <CsInsn 0x7d5 [83f901]: cmp ecx, 1>  len 3
# 2008   0x7d8 <CsInsn 0x7d8 [776a]: ja 0x844>  len 2
# 2010   0x7da <CsInsn 0x7da [e821080000]: call 0x1000>  len 5
# 2015   0x7df <CsInsn 0x7df [85c0]: test eax, eax>  len 2
# 2017   0x7e1 <CsInsn 0x7e1 [7428]: je 0x80b>  len 2
# 2019   0x7e3 <CsInsn 0x7e3 [85db]: test ebx, ebx>  len 2
# 2021   0x7e5 <CsInsn 0x7e5 [7524]: jne 0x80b>  len 2
# 2023   0x7e7 <CsInsn 0x7e7 [488d0d3a070200]: lea rcx, [rip + 0x2073a]>  len 7
# 2030   0x7ee <CsInsn 0x7ee [e8b1640000]: call 0x6ca4>  len 5
# 2035   0x7f3 <CsInsn 0x7f3 [85c0]: test eax, eax>  len 2
# 2037   0x7f5 <CsInsn 0x7f5 [7510]: jne 0x807>  len 2
# 2039   0x7f7 <CsInsn 0x7f7 [488d0d42070200]: lea rcx, [rip + 0x20742]>  len 7
# 2046   0x7fe <CsInsn 0x7fe [e8a1640000]: call 0x6ca4>  len 5
# 2051   0x803 <CsInsn 0x803 [85c0]: test eax, eax>  len 2
# 2053   0x805 <CsInsn 0x805 [742e]: je 0x835>  len 2
# 2055   0x807 <CsInsn 0x807 [32c0]: xor al, al>  len 2
# 2057   0x809 <CsInsn 0x809 [eb33]: jmp 0x83e>  len 2
# 2059   0x80b <CsInsn 0x80b [660f6f050d4f0100]: movdqa xmm0, xmmword ptr [rip + 0x14f0d]>  len 8
# 2067   0x813 <CsInsn 0x813 [4883c8ff]: or rax, 0xffffffffffffffff>  len 4
# 2071   0x817 <CsInsn 0x817 [f30f7f0509070200]: movdqu xmmword ptr [rip + 0x20709], xmm0>  len 8
# 2079   0x81f <CsInsn 0x81f [48890512070200]: mov qword ptr [rip + 0x20712], rax>  len 7
# 2086   0x826 <CsInsn 0x826 [f30f7f0512070200]: movdqu xmmword ptr [rip + 0x20712], xmm0>  len 8
# 2094   0x82e <CsInsn 0x82e [4889051b070200]: mov qword ptr [rip + 0x2071b], rax>  len 7
# 2101   0x835 <CsInsn 0x835 [c605e506020001]: mov byte ptr [rip + 0x206e5], 1>  len 7
# 2108   0x83c <CsInsn 0x83c [b001]: mov al, 1>  len 2
# 2110   0x83e <CsInsn 0x83e [4883c420]: add rsp, 0x20>  len 4
# 2114   0x842 <CsInsn 0x842 [5b]: pop rbx>  len 1
# 2115   0x843 <CsInsn 0x843 [c3]: ret >  len 1
# 2116   0x844 <CsInsn 0x844 [b905000000]: mov ecx, 5>  len 5
# 2121   0x849 <CsInsn 0x849 [e85e020000]: call 0xaac>  len 5
# 2126   0x84e <CsInsn 0x84e [cc]: int3 >  len 1
# 2127   0x84f <CsInsn 0x84f [cc]: int3 >  len 1
# 2128   0x850 <CsInsn 0x850 [4883ec18]: sub rsp, 0x18>  len 4
# 2132   0x854 <CsInsn 0x854 [4c8bc1]: mov r8, rcx>  len 3
# 2135   0x857 <CsInsn 0x857 [b84d5a0000]: mov eax, 0x5a4d>  len 5
# 2140   0x85c <CsInsn 0x85c [6639059debffff]: cmp word ptr [rip - 0x1463], ax>  len 7
# 2147   0x863 <CsInsn 0x863 [7578]: jne 0x8dd>  len 2
# 2149   0x865 <CsInsn 0x865 [48630dd0ebffff]: movsxd rcx, dword ptr [rip - 0x1430]>  len 7
# 2156   0x86c <CsInsn 0x86c [488d158debffff]: lea rdx, [rip - 0x1473]>  len 7
# 2163   0x873 <CsInsn 0x873 [4803ca]: add rcx, rdx>  len 3
# 2166   0x876 <CsInsn 0x876 [813950450000]: cmp dword ptr [rcx], 0x4550>  len 6
# 2172   0x87c <CsInsn 0x87c [755f]: jne 0x8dd>  len 2
# 2174   0x87e <CsInsn 0x87e [b80b020000]: mov eax, 0x20b>  len 5
# 2179   0x883 <CsInsn 0x883 [66394118]: cmp word ptr [rcx + 0x18], ax>  len 4
# 2183   0x887 <CsInsn 0x887 [7554]: jne 0x8dd>  len 2
# 2185   0x889 <CsInsn 0x889 [4c2bc2]: sub r8, rdx>  len 3
# 2188   0x88c <CsInsn 0x88c [0fb75114]: movzx edx, word ptr [rcx + 0x14]>  len 4
# 2192   0x890 <CsInsn 0x890 [4883c218]: add rdx, 0x18>  len 4
# 2196   0x894 <CsInsn 0x894 [4803d1]: add rdx, rcx>  len 3
# 2199   0x897 <CsInsn 0x897 [0fb74106]: movzx eax, word ptr [rcx + 6]>  len 4
# 2203   0x89b <CsInsn 0x89b [488d0c80]: lea rcx, [rax + rax*4]>  len 4
# 2207   0x89f <CsInsn 0x89f [4c8d0cca]: lea r9, [rdx + rcx*8]>  len 4
# 2211   0x8a3 <CsInsn 0x8a3 [48891424]: mov qword ptr [rsp], rdx>  len 4
# 2215   0x8a7 <CsInsn 0x8a7 [493bd1]: cmp rdx, r9>  len 3
# 2218   0x8aa <CsInsn 0x8aa [7418]: je 0x8c4>  len 2
# 2220   0x8ac <CsInsn 0x8ac [8b4a0c]: mov ecx, dword ptr [rdx + 0xc]>  len 3
# 2223   0x8af <CsInsn 0x8af [4c3bc1]: cmp r8, rcx>  len 3
# 2226   0x8b2 <CsInsn 0x8b2 [720a]: jb 0x8be>  len 2
# 2228   0x8b4 <CsInsn 0x8b4 [8b4208]: mov eax, dword ptr [rdx + 8]>  len 3
# 2231   0x8b7 <CsInsn 0x8b7 [03c1]: add eax, ecx>  len 2
# 2233   0x8b9 <CsInsn 0x8b9 [4c3bc0]: cmp r8, rax>  len 3
# 2236   0x8bc <CsInsn 0x8bc [7208]: jb 0x8c6>  len 2
# 2238   0x8be <CsInsn 0x8be [4883c228]: add rdx, 0x28>  len 4
# 2242   0x8c2 <CsInsn 0x8c2 [ebdf]: jmp 0x8a3>  len 2
# 2244   0x8c4 <CsInsn 0x8c4 [33d2]: xor edx, edx>  len 2
# 2246   0x8c6 <CsInsn 0x8c6 [4885d2]: test rdx, rdx>  len 3
# 2249   0x8c9 <CsInsn 0x8c9 [7504]: jne 0x8cf>  len 2
# 2251   0x8cb <CsInsn 0x8cb [32c0]: xor al, al>  len 2
# 2253   0x8cd <CsInsn 0x8cd [eb14]: jmp 0x8e3>  len 2
# 2255   0x8cf <CsInsn 0x8cf [837a2400]: cmp dword ptr [rdx + 0x24], 0>  len 4
# 2259   0x8d3 <CsInsn 0x8d3 [7d04]: jge 0x8d9>  len 2
# 2261   0x8d5 <CsInsn 0x8d5 [32c0]: xor al, al>  len 2
# 2263   0x8d7 <CsInsn 0x8d7 [eb0a]: jmp 0x8e3>  len 2
# 2265   0x8d9 <CsInsn 0x8d9 [b001]: mov al, 1>  len 2
# 2267   0x8db <CsInsn 0x8db [eb06]: jmp 0x8e3>  len 2
# 2269   0x8dd <CsInsn 0x8dd [32c0]: xor al, al>  len 2
# 2271   0x8df <CsInsn 0x8df [eb02]: jmp 0x8e3>  len 2
#
# Byte GAP ######  4  Missing bytes:  2
# #  2273 <CsInsn 0x2483 [0f84a9030000]: je 0x2832> inst len: 6
# #  2274 <CsInsn 0x2489 [e82ef0ffff]: call 0x14bc> inst len: 5
#
#
# 2275   0x8e3 <CsInsn 0x8e3 [4883c418]: add rsp, 0x18>  len 4
# 2279   0x8e7 <CsInsn 0x8e7 [c3]: ret >  len 1
# 2280   0x8e8 <CsInsn 0x8e8 [4053]: push rbx>  len 2
# 2282   0x8ea <CsInsn 0x8ea [4883ec20]: sub rsp, 0x20>  len 4
# 2286   0x8ee <CsInsn 0x8ee [8ad9]: mov bl, cl>  len 2
# 2288   0x8f0 <CsInsn 0x8f0 [e80b070000]: call 0x1000>  len 5
# 2293   0x8f5 <CsInsn 0x8f5 [33d2]: xor edx, edx>  len 2
# 2295   0x8f7 <CsInsn 0x8f7 [85c0]: test eax, eax>  len 2
# 2297   0x8f9 <CsInsn 0x8f9 [740b]: je 0x906>  len 2
# 2299   0x8fb <CsInsn 0x8fb [84db]: test bl, bl>  len 2
# 2301   0x8fd <CsInsn 0x8fd [7507]: jne 0x906>  len 2
# 2303   0x8ff <CsInsn 0x8ff [48871512060200]: xchg qword ptr [rip + 0x20612], rdx>  len 7
# 2310   0x906 <CsInsn 0x906 [4883c420]: add rsp, 0x20>  len 4
# 2314   0x90a <CsInsn 0x90a [5b]: pop rbx>  len 1
# 2315   0x90b <CsInsn 0x90b [c3]: ret >  len 1
# 2316   0x90c <CsInsn 0x90c [4053]: push rbx>  len 2
# 2318   0x90e <CsInsn 0x90e [4883ec20]: sub rsp, 0x20>  len 4
# 2322   0x912 <CsInsn 0x912 [803d0706020000]: cmp byte ptr [rip + 0x20607], 0>  len 7
# 2329   0x919 <CsInsn 0x919 [8ad9]: mov bl, cl>  len 2
# 2331   0x91b <CsInsn 0x91b [7404]: je 0x921>  len 2
# 2333   0x91d <CsInsn 0x91d [84d2]: test dl, dl>  len 2
# 2335   0x91f <CsInsn 0x91f [750c]: jne 0x92d>  len 2
# 2337   0x921 <CsInsn 0x921 [e82e650000]: call 0x6e54>  len 5
# 2342   0x926 <CsInsn 0x926 [8acb]: mov cl, bl>  len 2
# 2344   0x928 <CsInsn 0x928 [e823090000]: call 0x1250>  len 5
# 2349   0x92d <CsInsn 0x92d [b001]: mov al, 1>  len 2
# 2351   0x92f <CsInsn 0x92f [4883c420]: add rsp, 0x20>  len 4
# 2355   0x933 <CsInsn 0x933 [5b]: pop rbx>  len 1
# 2356   0x934 <CsInsn 0x934 [c3]: ret >  len 1
# 2357   0x935 <CsInsn 0x935 [cc]: int3 >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  2358 <CsInsn 0x25eb [0f8f1b010000]: jg 0x270c> inst len: 6
# #  2359 <CsInsn 0x25f1 [48034e08]: add rcx, qword ptr [rsi + 8]> inst len: 4
#
#
# 2360   0x938 <CsInsn 0x938 [4053]: push rbx>  len 2
# 2362   0x93a <CsInsn 0x93a [4883ec20]: sub rsp, 0x20>  len 4
# 2366   0x93e <CsInsn 0x93e [48833de2050200ff]: cmp qword ptr [rip + 0x205e2], -1>  len 8
# 2374   0x946 <CsInsn 0x946 [488bd9]: mov rbx, rcx>  len 3
# 2377   0x949 <CsInsn 0x949 [7507]: jne 0x952>  len 2
# 2379   0x94b <CsInsn 0x94b [e800630000]: call 0x6c50>  len 5
# 2384   0x950 <CsInsn 0x950 [eb0f]: jmp 0x961>  len 2
# 2386   0x952 <CsInsn 0x952 [488bd3]: mov rdx, rbx>  len 3
# 2389   0x955 <CsInsn 0x955 [488d0dcc050200]: lea rcx, [rip + 0x205cc]>  len 7
# 2396   0x95c <CsInsn 0x95c [e86b630000]: call 0x6ccc>  len 5
# 2401   0x961 <CsInsn 0x961 [33d2]: xor edx, edx>  len 2
# 2403   0x963 <CsInsn 0x963 [85c0]: test eax, eax>  len 2
# 2405   0x965 <CsInsn 0x965 [480f44d3]: cmove rdx, rbx>  len 4
# 2409   0x969 <CsInsn 0x969 [488bc2]: mov rax, rdx>  len 3
# 2412   0x96c <CsInsn 0x96c [4883c420]: add rsp, 0x20>  len 4
# 2416   0x970 <CsInsn 0x970 [5b]: pop rbx>  len 1
# 2417   0x971 <CsInsn 0x971 [c3]: ret >  len 1
# 2418   0x972 <CsInsn 0x972 [cc]: int3 >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  2419 <CsInsn 0x26de [488b4580]: mov rax, qword ptr [rbp - 0x80]> inst len: 4
#
#
# 2420   0x974 <CsInsn 0x974 [4883ec28]: sub rsp, 0x28>  len 4
# 2424   0x978 <CsInsn 0x978 [e8bbffffff]: call 0x938>  len 5
# 2429   0x97d <CsInsn 0x97d [48f7d8]: neg rax>  len 3
# 2432   0x980 <CsInsn 0x980 [1bc0]: sbb eax, eax>  len 2
# 2434   0x982 <CsInsn 0x982 [f7d8]: neg eax>  len 2
# 2436   0x984 <CsInsn 0x984 [ffc8]: dec eax>  len 2
# 2438   0x986 <CsInsn 0x986 [4883c428]: add rsp, 0x28>  len 4
# 2442   0x98a <CsInsn 0x98a [c3]: ret >  len 1
# 2443   0x98b <CsInsn 0x98b [cc]: int3 >  len 1
# 2444   0x98c <CsInsn 0x98c [48895c2418]: mov qword ptr [rsp + 0x18], rbx>  len 5
# 2449   0x991 <CsInsn 0x991 [55]: push rbp>  len 1
# 2450   0x992 <CsInsn 0x992 [488bec]: mov rbp, rsp>  len 3
# 2453   0x995 <CsInsn 0x995 [4883ec30]: sub rsp, 0x30>  len 4
# 2457   0x999 <CsInsn 0x999 [488b05a0fa0100]: mov rax, qword ptr [rip + 0x1faa0]>  len 7
# 2464   0x9a0 <CsInsn 0x9a0 [48bb32a2df2d992b0000]: movabs rbx, 0x2b992ddfa232>  len 10
# 2474   0x9aa <CsInsn 0x9aa [483bc3]: cmp rax, rbx>  len 3
# 2477   0x9ad <CsInsn 0x9ad [7574]: jne 0xa23>  len 2
# 2479   0x9af <CsInsn 0x9af [4883651000]: and qword ptr [rbp + 0x10], 0>  len 5
# 2484   0x9b4 <CsInsn 0x9b4 [488d4d10]: lea rcx, [rbp + 0x10]>  len 4
# 2488   0x9b8 <CsInsn 0x9b8 [ff155a4a0100]: call qword ptr [rip + 0x14a5a]>  len 6
# 2494   0x9be <CsInsn 0x9be [488b4510]: mov rax, qword ptr [rbp + 0x10]>  len 4
# 2498   0x9c2 <CsInsn 0x9c2 [488945f0]: mov qword ptr [rbp - 0x10], rax>  len 4
# 2502   0x9c6 <CsInsn 0x9c6 [ff15444a0100]: call qword ptr [rip + 0x14a44]>  len 6
# 2508   0x9cc <CsInsn 0x9cc [8bc0]: mov eax, eax>  len 2
# 2510   0x9ce <CsInsn 0x9ce [483145f0]: xor qword ptr [rbp - 0x10], rax>  len 4
# 2514   0x9d2 <CsInsn 0x9d2 [ff15304a0100]: call qword ptr [rip + 0x14a30]>  len 6
# 2520   0x9d8 <CsInsn 0x9d8 [8bc0]: mov eax, eax>  len 2
# 2522   0x9da <CsInsn 0x9da [488d4d18]: lea rcx, [rbp + 0x18]>  len 4
# 2526   0x9de <CsInsn 0x9de [483145f0]: xor qword ptr [rbp - 0x10], rax>  len 4
# 2530   0x9e2 <CsInsn 0x9e2 [ff15184a0100]: call qword ptr [rip + 0x14a18]>  len 6
# 2536   0x9e8 <CsInsn 0x9e8 [8b4518]: mov eax, dword ptr [rbp + 0x18]>  len 3
# 2539   0x9eb <CsInsn 0x9eb [488d4df0]: lea rcx, [rbp - 0x10]>  len 4
# 2543   0x9ef <CsInsn 0x9ef [48c1e020]: shl rax, 0x20>  len 4
# 2547   0x9f3 <CsInsn 0x9f3 [48334518]: xor rax, qword ptr [rbp + 0x18]>  len 4
# 2551   0x9f7 <CsInsn 0x9f7 [483345f0]: xor rax, qword ptr [rbp - 0x10]>  len 4
# 2555   0x9fb <CsInsn 0x9fb [4833c1]: xor rax, rcx>  len 3
# 2558   0x9fe <CsInsn 0x9fe [48b9ffffffffffff0000]: movabs rcx, 0xffffffffffff>  len 10
# 2568   0xa08 <CsInsn 0xa08 [4823c1]: and rax, rcx>  len 3
# 2571   0xa0b <CsInsn 0xa0b [48b933a2df2d992b0000]: movabs rcx, 0x2b992ddfa233>  len 10
# 2581   0xa15 <CsInsn 0xa15 [483bc3]: cmp rax, rbx>  len 3
# 2584   0xa18 <CsInsn 0xa18 [480f44c1]: cmove rax, rcx>  len 4
# 2588   0xa1c <CsInsn 0xa1c [4889051dfa0100]: mov qword ptr [rip + 0x1fa1d], rax>  len 7
# 2595   0xa23 <CsInsn 0xa23 [488b5c2450]: mov rbx, qword ptr [rsp + 0x50]>  len 5
# 2600   0xa28 <CsInsn 0xa28 [48f7d0]: not rax>  len 3
# 2603   0xa2b <CsInsn 0xa2b [4889054efa0100]: mov qword ptr [rip + 0x1fa4e], rax>  len 7
# 2610   0xa32 <CsInsn 0xa32 [4883c430]: add rsp, 0x30>  len 4
# 2614   0xa36 <CsInsn 0xa36 [5d]: pop rbp>  len 1
# 2615   0xa37 <CsInsn 0xa37 [c3]: ret >  len 1
# 2616   0xa38 <CsInsn 0xa38 [33c0]: xor eax, eax>  len 2
# 2618   0xa3a <CsInsn 0xa3a [c3]: ret >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  2619 <CsInsn 0x2a0d [66480f7ec0]: movq rax, xmm0> inst len: 5
#
#
# 2620   0xa3c <CsInsn 0xa3c [b801000000]: mov eax, 1>  len 5
# 2625   0xa41 <CsInsn 0xa41 [c3]: ret >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  2626 <CsInsn 0x2a2c [66480f7ec0]: movq rax, xmm0> inst len: 5
# #  2627 <CsInsn 0x2a31 [48c1e820]: shr rax, 0x20> inst len: 4
#
#
# 2628   0xa44 <CsInsn 0xa44 [b800400000]: mov eax, 0x4000>  len 5
# 2633   0xa49 <CsInsn 0xa49 [c3]: ret >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  2634 <CsInsn 0x2a4a [e8f5f3ffff]: call 0x1e44> inst len: 5
# #  2635 <CsInsn 0x2a4f [4903c4]: add rax, r12> inst len: 3
#
#
# 2636   0xa4c <CsInsn 0xa4c [488d0d0d050200]: lea rcx, [rip + 0x2050d]>  len 7
# 2643   0xa53 <CsInsn 0xa53 [48ff25c6490100]: jmp qword ptr [rip + 0x149c6]>  len 7
#
# Byte GAP ######  9  Missing bytes:  2
# #  2650 <CsInsn 0x2a84 [4c8bcd]: mov r9, rbp> inst len: 3
# #  2651 <CsInsn 0x2a87 [488b942408010000]: mov rdx, qword ptr [rsp + 0x108]> inst len: 8
#
#
# 2652   0xa5c <CsInsn 0xa5c [b001]: mov al, 1>  len 2
# 2654   0xa5e <CsInsn 0xa5e [c3]: ret >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  2655 <CsInsn 0x2a9a [c644245001]: mov byte ptr [rsp + 0x50], 1> inst len: 5
#
#
# 2656   0xa60 <CsInsn 0xa60 [c20000]: ret 0>  len 3
#
# Byte GAP ######  4  Missing bytes:  1
# #  2659 <CsInsn 0x2ab1 [4889442438]: mov qword ptr [rsp + 0x38], rax> inst len: 5
#
#
# 2660   0xa64 <CsInsn 0xa64 [488d0505050200]: lea rax, [rip + 0x20505]>  len 7
# 2667   0xa6b <CsInsn 0xa6b [c3]: ret >  len 1
# 2668   0xa6c <CsInsn 0xa6c [4883ec28]: sub rsp, 0x28>  len 4
# 2672   0xa70 <CsInsn 0xa70 [e8abf9ffff]: call 0x420>  len 5
# 2677   0xa75 <CsInsn 0xa75 [48830824]: or qword ptr [rax], 0x24>  len 4
# 2681   0xa79 <CsInsn 0xa79 [e8e6ffffff]: call 0xa64>  len 5
# 2686   0xa7e <CsInsn 0xa7e [48830802]: or qword ptr [rax], 2>  len 4
# 2690   0xa82 <CsInsn 0xa82 [4883c428]: add rsp, 0x28>  len 4
# 2694   0xa86 <CsInsn 0xa86 [c3]: ret >  len 1
# 2695   0xa87 <CsInsn 0xa87 [cc]: int3 >  len 1
# 2696   0xa88 <CsInsn 0xa88 [33c0]: xor eax, eax>  len 2
# 2698   0xa8a <CsInsn 0xa8a [390584f90100]: cmp dword ptr [rip + 0x1f984], eax>  len 6
# 2704   0xa90 <CsInsn 0xa90 [0f94c0]: sete al>  len 3
# 2707   0xa93 <CsInsn 0xa93 [c3]: ret >  len 1
# 2708   0xa94 <CsInsn 0xa94 [488d053d160200]: lea rax, [rip + 0x2163d]>  len 7
# 2715   0xa9b <CsInsn 0xa9b [c3]: ret >  len 1
# 2716   0xa9c <CsInsn 0xa9c [488d052d160200]: lea rax, [rip + 0x2162d]>  len 7
# 2723   0xaa3 <CsInsn 0xaa3 [c3]: ret >  len 1
# 2724   0xaa4 <CsInsn 0xaa4 [8325cd04020000]: and dword ptr [rip + 0x204cd], 0>  len 7
# 2731   0xaab <CsInsn 0xaab [c3]: ret >  len 1
# 2732   0xaac <CsInsn 0xaac [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 2737   0xab1 <CsInsn 0xab1 [55]: push rbp>  len 1
# 2738   0xab2 <CsInsn 0xab2 [488dac2440fbffff]: lea rbp, [rsp - 0x4c0]>  len 8
# 2746   0xaba <CsInsn 0xaba [4881ecc0050000]: sub rsp, 0x5c0>  len 7
# 2753   0xac1 <CsInsn 0xac1 [8bd9]: mov ebx, ecx>  len 2
# 2755   0xac3 <CsInsn 0xac3 [b917000000]: mov ecx, 0x17>  len 5
# 2760   0xac8 <CsInsn 0xac8 [ff1592490100]: call qword ptr [rip + 0x14992]>  len 6
# 2766   0xace <CsInsn 0xace [85c0]: test eax, eax>  len 2
# 2768   0xad0 <CsInsn 0xad0 [7404]: je 0xad6>  len 2
# 2770   0xad2 <CsInsn 0xad2 [8bcb]: mov ecx, ebx>  len 2
# 2772   0xad4 <CsInsn 0xad4 [cd29]: int 0x29>  len 2
# 2774   0xad6 <CsInsn 0xad6 [b903000000]: mov ecx, 3>  len 5
# 2779   0xadb <CsInsn 0xadb [e8c4ffffff]: call 0xaa4>  len 5
# 2784   0xae0 <CsInsn 0xae0 [33d2]: xor edx, edx>  len 2
# 2786   0xae2 <CsInsn 0xae2 [488d4df0]: lea rcx, [rbp - 0x10]>  len 4
# 2790   0xae6 <CsInsn 0xae6 [41b8d0040000]: mov r8d, 0x4d0>  len 6
# 2796   0xaec <CsInsn 0xaec [e85f320100]: call 0x13d50>  len 5
# 2801   0xaf1 <CsInsn 0xaf1 [488d4df0]: lea rcx, [rbp - 0x10]>  len 4
# 2805   0xaf5 <CsInsn 0xaf5 [ff152d490100]: call qword ptr [rip + 0x1492d]>  len 6
# 2811   0xafb <CsInsn 0xafb [488b9de8000000]: mov rbx, qword ptr [rbp + 0xe8]>  len 7
# 2818   0xb02 <CsInsn 0xb02 [488d95d8040000]: lea rdx, [rbp + 0x4d8]>  len 7
# 2825   0xb09 <CsInsn 0xb09 [488bcb]: mov rcx, rbx>  len 3
# 2828   0xb0c <CsInsn 0xb0c [4533c0]: xor r8d, r8d>  len 3
# 2831   0xb0f <CsInsn 0xb0f [ff151b490100]: call qword ptr [rip + 0x1491b]>  len 6
# 2837   0xb15 <CsInsn 0xb15 [4885c0]: test rax, rax>  len 3
# 2840   0xb18 <CsInsn 0xb18 [743c]: je 0xb56>  len 2
# 2842   0xb1a <CsInsn 0xb1a [488364243800]: and qword ptr [rsp + 0x38], 0>  len 6
# 2848   0xb20 <CsInsn 0xb20 [488d8de0040000]: lea rcx, [rbp + 0x4e0]>  len 7
# 2855   0xb27 <CsInsn 0xb27 [488b95d8040000]: mov rdx, qword ptr [rbp + 0x4d8]>  len 7
# 2862   0xb2e <CsInsn 0xb2e [4c8bc8]: mov r9, rax>  len 3
# 2865   0xb31 <CsInsn 0xb31 [48894c2430]: mov qword ptr [rsp + 0x30], rcx>  len 5
# 2870   0xb36 <CsInsn 0xb36 [4c8bc3]: mov r8, rbx>  len 3
# 2873   0xb39 <CsInsn 0xb39 [488d8de8040000]: lea rcx, [rbp + 0x4e8]>  len 7
# 2880   0xb40 <CsInsn 0xb40 [48894c2428]: mov qword ptr [rsp + 0x28], rcx>  len 5
# 2885   0xb45 <CsInsn 0xb45 [488d4df0]: lea rcx, [rbp - 0x10]>  len 4
# 2889   0xb49 <CsInsn 0xb49 [48894c2420]: mov qword ptr [rsp + 0x20], rcx>  len 5
# 2894   0xb4e <CsInsn 0xb4e [33c9]: xor ecx, ecx>  len 2
# 2896   0xb50 <CsInsn 0xb50 [ff15e2480100]: call qword ptr [rip + 0x148e2]>  len 6
# 2902   0xb56 <CsInsn 0xb56 [488b85c8040000]: mov rax, qword ptr [rbp + 0x4c8]>  len 7
# 2909   0xb5d <CsInsn 0xb5d [488d4c2450]: lea rcx, [rsp + 0x50]>  len 5
# 2914   0xb62 <CsInsn 0xb62 [488985e8000000]: mov qword ptr [rbp + 0xe8], rax>  len 7
# 2921   0xb69 <CsInsn 0xb69 [33d2]: xor edx, edx>  len 2
# 2923   0xb6b <CsInsn 0xb6b [488d85c8040000]: lea rax, [rbp + 0x4c8]>  len 7
# 2930   0xb72 <CsInsn 0xb72 [41b898000000]: mov r8d, 0x98>  len 6
# 2936   0xb78 <CsInsn 0xb78 [4883c008]: add rax, 8>  len 4
# 2940   0xb7c <CsInsn 0xb7c [48898588000000]: mov qword ptr [rbp + 0x88], rax>  len 7
# 2947   0xb83 <CsInsn 0xb83 [e8c8310100]: call 0x13d50>  len 5
# 2952   0xb88 <CsInsn 0xb88 [488b85c8040000]: mov rax, qword ptr [rbp + 0x4c8]>  len 7
# 2959   0xb8f <CsInsn 0xb8f [4889442460]: mov qword ptr [rsp + 0x60], rax>  len 5
# 2964   0xb94 <CsInsn 0xb94 [c744245015000040]: mov dword ptr [rsp + 0x50], 0x40000015>  len 8
# 2972   0xb9c <CsInsn 0xb9c [c744245401000000]: mov dword ptr [rsp + 0x54], 1>  len 8
# 2980   0xba4 <CsInsn 0xba4 [ff1596480100]: call qword ptr [rip + 0x14896]>  len 6
# 2986   0xbaa <CsInsn 0xbaa [8bd8]: mov ebx, eax>  len 2
# 2988   0xbac <CsInsn 0xbac [33c9]: xor ecx, ecx>  len 2
# 2990   0xbae <CsInsn 0xbae [488d442450]: lea rax, [rsp + 0x50]>  len 5
# 2995   0xbb3 <CsInsn 0xbb3 [4889442440]: mov qword ptr [rsp + 0x40], rax>  len 5
# 3000   0xbb8 <CsInsn 0xbb8 [488d45f0]: lea rax, [rbp - 0x10]>  len 4
# 3004   0xbbc <CsInsn 0xbbc [4889442448]: mov qword ptr [rsp + 0x48], rax>  len 5
# 3009   0xbc1 <CsInsn 0xbc1 [ff1589480100]: call qword ptr [rip + 0x14889]>  len 6
# 3015   0xbc7 <CsInsn 0xbc7 [488d4c2440]: lea rcx, [rsp + 0x40]>  len 5
# 3020   0xbcc <CsInsn 0xbcc [ff1576480100]: call qword ptr [rip + 0x14876]>  len 6
# 3026   0xbd2 <CsInsn 0xbd2 [85c0]: test eax, eax>  len 2
# 3028   0xbd4 <CsInsn 0xbd4 [750d]: jne 0xbe3>  len 2
# 3030   0xbd6 <CsInsn 0xbd6 [83fb01]: cmp ebx, 1>  len 3
# 3033   0xbd9 <CsInsn 0xbd9 [7408]: je 0xbe3>  len 2
# 3035   0xbdb <CsInsn 0xbdb [8d4803]: lea ecx, [rax + 3]>  len 3
# 3038   0xbde <CsInsn 0xbde [e8c1feffff]: call 0xaa4>  len 5
# 3043   0xbe3 <CsInsn 0xbe3 [488b9c24d0050000]: mov rbx, qword ptr [rsp + 0x5d0]>  len 8
# 3051   0xbeb <CsInsn 0xbeb [4881c4c0050000]: add rsp, 0x5c0>  len 7
# 3058   0xbf2 <CsInsn 0xbf2 [5d]: pop rbp>  len 1
# 3059   0xbf3 <CsInsn 0xbf3 [c3]: ret >  len 1
# 3060   0xbf4 <CsInsn 0xbf4 [e93ffeffff]: jmp 0xa38>  len 5
#
# Byte GAP ######  8  Missing bytes:  3
# #  3065 <CsInsn 0x3137 [4c896828]: mov qword ptr [rax + 0x28], r13> inst len: 4
# #  3066 <CsInsn 0x313b [488b442430]: mov rax, qword ptr [rsp + 0x30]> inst len: 5
# #  3067 <CsInsn 0x3140 [4863481c]: movsxd rcx, dword ptr [rax + 0x1c]> inst len: 4
#
#
# 3068   0xbfc <CsInsn 0xbfc [4883ec28]: sub rsp, 0x28>  len 4
# 3072   0xc00 <CsInsn 0xc00 [33c9]: xor ecx, ecx>  len 2
# 3074   0xc02 <CsInsn 0xc02 [ff1560480100]: call qword ptr [rip + 0x14860]>  len 6
# 3080   0xc08 <CsInsn 0xc08 [4885c0]: test rax, rax>  len 3
# 3083   0xc0b <CsInsn 0xc0b [7439]: je 0xc46>  len 2
# 3085   0xc0d <CsInsn 0xc0d [b94d5a0000]: mov ecx, 0x5a4d>  len 5
# 3090   0xc12 <CsInsn 0xc12 [663908]: cmp word ptr [rax], cx>  len 3
# 3093   0xc15 <CsInsn 0xc15 [752f]: jne 0xc46>  len 2
# 3095   0xc17 <CsInsn 0xc17 [4863483c]: movsxd rcx, dword ptr [rax + 0x3c]>  len 4
# 3099   0xc1b <CsInsn 0xc1b [4803c8]: add rcx, rax>  len 3
# 3102   0xc1e <CsInsn 0xc1e [813950450000]: cmp dword ptr [rcx], 0x4550>  len 6
# 3108   0xc24 <CsInsn 0xc24 [7520]: jne 0xc46>  len 2
# 3110   0xc26 <CsInsn 0xc26 [b80b020000]: mov eax, 0x20b>  len 5
# 3115   0xc2b <CsInsn 0xc2b [66394118]: cmp word ptr [rcx + 0x18], ax>  len 4
# 3119   0xc2f <CsInsn 0xc2f [7515]: jne 0xc46>  len 2
# 3121   0xc31 <CsInsn 0xc31 [83b9840000000e]: cmp dword ptr [rcx + 0x84], 0xe>  len 7
# 3128   0xc38 <CsInsn 0xc38 [760c]: jbe 0xc46>  len 2
# 3130   0xc3a <CsInsn 0xc3a [83b9f800000000]: cmp dword ptr [rcx + 0xf8], 0>  len 7
# 3137   0xc41 <CsInsn 0xc41 [0f95c0]: setne al>  len 3
# 3140   0xc44 <CsInsn 0xc44 [eb02]: jmp 0xc48>  len 2
# 3142   0xc46 <CsInsn 0xc46 [32c0]: xor al, al>  len 2
# 3144   0xc48 <CsInsn 0xc48 [4883c428]: add rsp, 0x28>  len 4
# 3148   0xc4c <CsInsn 0xc4c [c3]: ret >  len 1
# 3149   0xc4d <CsInsn 0xc4d [cc]: int3 >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# #  3150 <CsInsn 0x324c [0f8e14010000]: jle 0x3366> inst len: 6
# #  3151 <CsInsn 0x3252 [3b7e04]: cmp edi, dword ptr [rsi + 4]> inst len: 3
#
#
# 3152   0xc50 <CsInsn 0xc50 [488d0d09000000]: lea rcx, [rip + 9]>  len 7
# 3159   0xc57 <CsInsn 0xc57 [48ff25f2470100]: jmp qword ptr [rip + 0x147f2]>  len 7
#
# Byte GAP ######  9  Missing bytes:  2
# #  3166 <CsInsn 0x328f [4a8d04f0]: lea rax, [rax + r14*8]> inst len: 4
# #  3167 <CsInsn 0x3293 [48635c0104]: movsxd rbx, dword ptr [rcx + rax + 4]> inst len: 5
#
#
# 3168   0xc60 <CsInsn 0xc60 [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 3173   0xc65 <CsInsn 0xc65 [57]: push rdi>  len 1
# 3174   0xc66 <CsInsn 0xc66 [4883ec20]: sub rsp, 0x20>  len 4
# 3178   0xc6a <CsInsn 0xc6a [488b19]: mov rbx, qword ptr [rcx]>  len 3
# 3181   0xc6d <CsInsn 0xc6d [488bf9]: mov rdi, rcx>  len 3
# 3184   0xc70 <CsInsn 0xc70 [813b63736de0]: cmp dword ptr [rbx], 0xe06d7363>  len 6
# 3190   0xc76 <CsInsn 0xc76 [751c]: jne 0xc94>  len 2
# 3192   0xc78 <CsInsn 0xc78 [837b1804]: cmp dword ptr [rbx + 0x18], 4>  len 4
# 3196   0xc7c <CsInsn 0xc7c [7516]: jne 0xc94>  len 2
# 3198   0xc7e <CsInsn 0xc7e [8b5320]: mov edx, dword ptr [rbx + 0x20]>  len 3
# 3201   0xc81 <CsInsn 0xc81 [8d82e0fa6ce6]: lea eax, [rdx - 0x19930520]>  len 6
# 3207   0xc87 <CsInsn 0xc87 [83f802]: cmp eax, 2>  len 3
# 3210   0xc8a <CsInsn 0xc8a [7615]: jbe 0xca1>  len 2
# 3212   0xc8c <CsInsn 0xc8c [81fa00409901]: cmp edx, 0x1994000>  len 6
# 3218   0xc92 <CsInsn 0xc92 [740d]: je 0xca1>  len 2
# 3220   0xc94 <CsInsn 0xc94 [488b5c2430]: mov rbx, qword ptr [rsp + 0x30]>  len 5
# 3225   0xc99 <CsInsn 0xc99 [33c0]: xor eax, eax>  len 2
# 3227   0xc9b <CsInsn 0xc9b [4883c420]: add rsp, 0x20>  len 4
# 3231   0xc9f <CsInsn 0xc9f [5f]: pop rdi>  len 1
# 3232   0xca0 <CsInsn 0xca0 [c3]: ret >  len 1
# 3233   0xca1 <CsInsn 0xca1 [e81e070000]: call 0x13c4>  len 5
# 3238   0xca6 <CsInsn 0xca6 [488918]: mov qword ptr [rax], rbx>  len 3
# 3241   0xca9 <CsInsn 0xca9 [488b5f08]: mov rbx, qword ptr [rdi + 8]>  len 4
# 3245   0xcad <CsInsn 0xcad [e826070000]: call 0x13d8>  len 5
# 3250   0xcb2 <CsInsn 0xcb2 [488918]: mov qword ptr [rax], rbx>  len 3
# 3253   0xcb5 <CsInsn 0xcb5 [e8d2610000]: call 0x6e8c>  len 5
# 3258   0xcba <CsInsn 0xcba [cc]: int3 >  len 1
# 3259   0xcbb <CsInsn 0xcbb [cc]: int3 >  len 1
# 3260   0xcbc <CsInsn 0xcbc [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 3265   0xcc1 <CsInsn 0xcc1 [57]: push rdi>  len 1
# 3266   0xcc2 <CsInsn 0xcc2 [4883ec20]: sub rsp, 0x20>  len 4
# 3270   0xcc6 <CsInsn 0xcc6 [488d1ddbd30100]: lea rbx, [rip + 0x1d3db]>  len 7
# 3277   0xccd <CsInsn 0xccd [488d3dd4d30100]: lea rdi, [rip + 0x1d3d4]>  len 7
# 3284   0xcd4 <CsInsn 0xcd4 [eb12]: jmp 0xce8>  len 2
# 3286   0xcd6 <CsInsn 0xcd6 [488b03]: mov rax, qword ptr [rbx]>  len 3
# 3289   0xcd9 <CsInsn 0xcd9 [4885c0]: test rax, rax>  len 3
# 3292   0xcdc <CsInsn 0xcdc [7406]: je 0xce4>  len 2
# 3294   0xcde <CsInsn 0xcde [ff1584490100]: call qword ptr [rip + 0x14984]>  len 6
# 3300   0xce4 <CsInsn 0xce4 [4883c308]: add rbx, 8>  len 4
# 3304   0xce8 <CsInsn 0xce8 [483bdf]: cmp rbx, rdi>  len 3
# 3307   0xceb <CsInsn 0xceb [72e9]: jb 0xcd6>  len 2
# 3309   0xced <CsInsn 0xced [488b5c2430]: mov rbx, qword ptr [rsp + 0x30]>  len 5
# 3314   0xcf2 <CsInsn 0xcf2 [4883c420]: add rsp, 0x20>  len 4
# 3318   0xcf6 <CsInsn 0xcf6 [5f]: pop rdi>  len 1
# 3319   0xcf7 <CsInsn 0xcf7 [c3]: ret >  len 1
# 3320   0xcf8 <CsInsn 0xcf8 [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 3325   0xcfd <CsInsn 0xcfd [57]: push rdi>  len 1
# 3326   0xcfe <CsInsn 0xcfe [4883ec20]: sub rsp, 0x20>  len 4
# 3330   0xd02 <CsInsn 0xd02 [488d1dafd30100]: lea rbx, [rip + 0x1d3af]>  len 7
# 3337   0xd09 <CsInsn 0xd09 [488d3da8d30100]: lea rdi, [rip + 0x1d3a8]>  len 7
# 3344   0xd10 <CsInsn 0xd10 [eb12]: jmp 0xd24>  len 2
# 3346   0xd12 <CsInsn 0xd12 [488b03]: mov rax, qword ptr [rbx]>  len 3
# 3349   0xd15 <CsInsn 0xd15 [4885c0]: test rax, rax>  len 3
# 3352   0xd18 <CsInsn 0xd18 [7406]: je 0xd20>  len 2
# 3354   0xd1a <CsInsn 0xd1a [ff1548490100]: call qword ptr [rip + 0x14948]>  len 6
# 3360   0xd20 <CsInsn 0xd20 [4883c308]: add rbx, 8>  len 4
# 3364   0xd24 <CsInsn 0xd24 [483bdf]: cmp rbx, rdi>  len 3
# 3367   0xd27 <CsInsn 0xd27 [72e9]: jb 0xd12>  len 2
# 3369   0xd29 <CsInsn 0xd29 [488b5c2430]: mov rbx, qword ptr [rsp + 0x30]>  len 5
# 3374   0xd2e <CsInsn 0xd2e [4883c420]: add rsp, 0x20>  len 4
# 3378   0xd32 <CsInsn 0xd32 [5f]: pop rdi>  len 1
# 3379   0xd33 <CsInsn 0xd33 [c3]: ret >  len 1
# 3380   0xd34 <CsInsn 0xd34 [48895c2410]: mov qword ptr [rsp + 0x10], rbx>  len 5
# 3385   0xd39 <CsInsn 0xd39 [4889742418]: mov qword ptr [rsp + 0x18], rsi>  len 5
# 3390   0xd3e <CsInsn 0xd3e [55]: push rbp>  len 1
# 3391   0xd3f <CsInsn 0xd3f [57]: push rdi>  len 1
# 3392   0xd40 <CsInsn 0xd40 [4156]: push r14>  len 2
# 3394   0xd42 <CsInsn 0xd42 [488bec]: mov rbp, rsp>  len 3
# 3397   0xd45 <CsInsn 0xd45 [4883ec10]: sub rsp, 0x10>  len 4
# 3401   0xd49 <CsInsn 0xd49 [33c0]: xor eax, eax>  len 2
# 3403   0xd4b <CsInsn 0xd4b [33c9]: xor ecx, ecx>  len 2
# 3405   0xd4d <CsInsn 0xd4d [0fa2]: cpuid >  len 2
# 3407   0xd4f <CsInsn 0xd4f [448bc1]: mov r8d, ecx>  len 3
# 3410   0xd52 <CsInsn 0xd52 [448bd2]: mov r10d, edx>  len 3
# 3413   0xd55 <CsInsn 0xd55 [4181f2696e6549]: xor r10d, 0x49656e69>  len 7
# 3420   0xd5c <CsInsn 0xd5c [4181f06e74656c]: xor r8d, 0x6c65746e>  len 7
# 3427   0xd63 <CsInsn 0xd63 [448bcb]: mov r9d, ebx>  len 3
# 3430   0xd66 <CsInsn 0xd66 [448bf0]: mov r14d, eax>  len 3
# 3433   0xd69 <CsInsn 0xd69 [33c9]: xor ecx, ecx>  len 2
# 3435   0xd6b <CsInsn 0xd6b [b801000000]: mov eax, 1>  len 5
# 3440   0xd70 <CsInsn 0xd70 [0fa2]: cpuid >  len 2
# 3442   0xd72 <CsInsn 0xd72 [450bd0]: or r10d, r8d>  len 3
# 3445   0xd75 <CsInsn 0xd75 [8945f0]: mov dword ptr [rbp - 0x10], eax>  len 3
# 3448   0xd78 <CsInsn 0xd78 [4181f147656e75]: xor r9d, 0x756e6547>  len 7
# 3455   0xd7f <CsInsn 0xd7f [895df4]: mov dword ptr [rbp - 0xc], ebx>  len 3
# 3458   0xd82 <CsInsn 0xd82 [450bd1]: or r10d, r9d>  len 3
# 3461   0xd85 <CsInsn 0xd85 [894df8]: mov dword ptr [rbp - 8], ecx>  len 3
# 3464   0xd88 <CsInsn 0xd88 [8bf9]: mov edi, ecx>  len 2
# 3466   0xd8a <CsInsn 0xd8a [8955fc]: mov dword ptr [rbp - 4], edx>  len 3
# 3469   0xd8d <CsInsn 0xd8d [755b]: jne 0xdea>  len 2
# 3471   0xd8f <CsInsn 0xd8f [48830d99f60100ff]: or qword ptr [rip + 0x1f699], 0xffffffffffffffff>  len 8
# 3479   0xd97 <CsInsn 0xd97 [25f03fff0f]: and eax, 0xfff3ff0>  len 5
# 3484   0xd9c <CsInsn 0xd9c [48c70581f6010000800000]: mov qword ptr [rip + 0x1f681], 0x8000>  len 11
# 3495   0xda7 <CsInsn 0xda7 [3dc0060100]: cmp eax, 0x106c0>  len 5
# 3500   0xdac <CsInsn 0xdac [7428]: je 0xdd6>  len 2
# 3502   0xdae <CsInsn 0xdae [3d60060200]: cmp eax, 0x20660>  len 5
# 3507   0xdb3 <CsInsn 0xdb3 [7421]: je 0xdd6>  len 2
# 3509   0xdb5 <CsInsn 0xdb5 [3d70060200]: cmp eax, 0x20670>  len 5
# 3514   0xdba <CsInsn 0xdba [741a]: je 0xdd6>  len 2
# 3516   0xdbc <CsInsn 0xdbc [05b0f9fcff]: add eax, 0xfffcf9b0>  len 5
# 3521   0xdc1 <CsInsn 0xdc1 [83f820]: cmp eax, 0x20>  len 3
# 3524   0xdc4 <CsInsn 0xdc4 [7724]: ja 0xdea>  len 2
# 3526   0xdc6 <CsInsn 0xdc6 [48b90100010001000000]: movabs rcx, 0x100010001>  len 10
# 3536   0xdd0 <CsInsn 0xdd0 [480fa3c1]: bt rcx, rax>  len 4
# 3540   0xdd4 <CsInsn 0xdd4 [7314]: jae 0xdea>  len 2
# 3542   0xdd6 <CsInsn 0xdd6 [448b05a3010200]: mov r8d, dword ptr [rip + 0x201a3]>  len 7
# 3549   0xddd <CsInsn 0xddd [4183c801]: or r8d, 1>  len 4
# 3553   0xde1 <CsInsn 0xde1 [44890598010200]: mov dword ptr [rip + 0x20198], r8d>  len 7
# 3560   0xde8 <CsInsn 0xde8 [eb07]: jmp 0xdf1>  len 2
# 3562   0xdea <CsInsn 0xdea [448b058f010200]: mov r8d, dword ptr [rip + 0x2018f]>  len 7
# 3569   0xdf1 <CsInsn 0xdf1 [4533c9]: xor r9d, r9d>  len 3
# 3572   0xdf4 <CsInsn 0xdf4 [418bf1]: mov esi, r9d>  len 3
# 3575   0xdf7 <CsInsn 0xdf7 [458bd1]: mov r10d, r9d>  len 3
# 3578   0xdfa <CsInsn 0xdfa [458bd9]: mov r11d, r9d>  len 3
# 3581   0xdfd <CsInsn 0xdfd [4183fe07]: cmp r14d, 7>  len 4
# 3585   0xe01 <CsInsn 0xe01 [7c65]: jl 0xe68>  len 2
# 3587   0xe03 <CsInsn 0xe03 [418d4107]: lea eax, [r9 + 7]>  len 4
# ...
# 22671   0x588f <CsInsn 0x588f [743f]: je 0x58d0>  len 2
# 22673   0x5891 <CsInsn 0x5891 [837e2c2a]: cmp dword ptr [rsi + 0x2c], 0x2a>  len 4
# 22677   0x5895 <CsInsn 0x5895 [7539]: jne 0x58d0>  len 2
# 22679   0x5897 <CsInsn 0x5897 [8b4114]: mov eax, dword ptr [rcx + 0x14]>  len 3
# 22682   0x589a <CsInsn 0x589a [90]: nop >  len 1
# 22683   0x589b <CsInsn 0x589b [c1e80c]: shr eax, 0xc>  len 3
# 22686   0x589e <CsInsn 0x589e [a801]: test al, 1>  len 2
# 22688   0x58a0 <CsInsn 0x58a0 [740a]: je 0x58ac>  len 2
# 22690   0x58a2 <CsInsn 0x58a2 [498b07]: mov rax, qword ptr [r15]>  len 3
# 22693   0x58a5 <CsInsn 0x58a5 [4883780800]: cmp qword ptr [rax + 8], 0>  len 5
# 22698   0x58aa <CsInsn 0x58aa [7415]: je 0x58c1>  len 2
# 22700   0x58ac <CsInsn 0x58ac [498b17]: mov rdx, qword ptr [r15]>  len 3
# 22703   0x58af <CsInsn 0x58af [4c8bc6]: mov r8, rsi>  len 3
# 22706   0x58b2 <CsInsn 0x58b2 [b93f000000]: mov ecx, 0x3f>  len 5
# 22711   0x58b7 <CsInsn 0x58b7 [e8343f0000]: call 0x97f0>  len 5
# 22716   0x58bc <CsInsn 0x58bc [83f8ff]: cmp eax, -1>  len 3
# 22719   0x58bf <CsInsn 0x58bf [7404]: je 0x58c5>  len 2
# 22721   0x58c1 <CsInsn 0x58c1 [ff07]: inc dword ptr [rdi]>  len 2
# 22723   0x58c3 <CsInsn 0x58c3 [eb03]: jmp 0x58c8>  len 2
# 22725   0x58c5 <CsInsn 0x58c5 [830fff]: or dword ptr [rdi], 0xffffffff>  len 3
# 22728   0x58c8 <CsInsn 0x58c8 [49ffc6]: inc r14>  len 3
# 22731   0x58cb <CsInsn 0x58cb [4c3bf5]: cmp r14, rbp>  len 3
# 22734   0x58ce <CsInsn 0x58ce [eb87]: jmp 0x5857>  len 2
# 22736   0x58d0 <CsInsn 0x58d0 [830fff]: or dword ptr [rdi], 0xffffffff>  len 3
# 22739   0x58d3 <CsInsn 0x58d3 [488b6c2448]: mov rbp, qword ptr [rsp + 0x48]>  len 5
# 22744   0x58d8 <CsInsn 0x58d8 [48895e2c]: mov qword ptr [rsi + 0x2c], rbx>  len 4
# 22748   0x58dc <CsInsn 0x58dc [488b5c2440]: mov rbx, qword ptr [rsp + 0x40]>  len 5
# 22753   0x58e1 <CsInsn 0x58e1 [488b742450]: mov rsi, qword ptr [rsp + 0x50]>  len 5
# 22758   0x58e6 <CsInsn 0x58e6 [4883c420]: add rsp, 0x20>  len 4
# 22762   0x58ea <CsInsn 0x58ea [415f]: pop r15>  len 2
# 22764   0x58ec <CsInsn 0x58ec [415e]: pop r14>  len 2
# 22766   0x58ee <CsInsn 0x58ee [5f]: pop rdi>  len 1
# 22767   0x58ef <CsInsn 0x58ef [c3]: ret >  len 1
# 22768   0x58f0 <CsInsn 0x58f0 [4055]: push rbp>  len 2
# 22770   0x58f2 <CsInsn 0x58f2 [53]: push rbx>  len 1
# 22771   0x58f3 <CsInsn 0x58f3 [57]: push rdi>  len 1
# 22772   0x58f4 <CsInsn 0x58f4 [488d6c24c1]: lea rbp, [rsp - 0x3f]>  len 5
# 22777   0x58f9 <CsInsn 0x58f9 [4881ecb0000000]: sub rsp, 0xb0>  len 7
# 22784   0x5900 <CsInsn 0x5900 [488365bf00]: and qword ptr [rbp - 0x41], 0>  len 5
# 22789   0x5905 <CsInsn 0x5905 [c645cf00]: mov byte ptr [rbp - 0x31], 0>  len 4
# 22793   0x5909 <CsInsn 0x5909 [c645e700]: mov byte ptr [rbp - 0x19], 0>  len 4
# 22797   0x590d <CsInsn 0x590d [c645ef00]: mov byte ptr [rbp - 0x11], 0>  len 4
# 22801   0x5911 <CsInsn 0x5911 [c645f700]: mov byte ptr [rbp - 9], 0>  len 4
# 22805   0x5915 <CsInsn 0x5915 [4d85c9]: test r9, r9>  len 3
# 22808   0x5918 <CsInsn 0x5918 [7406]: je 0x5920>  len 2
# 22810   0x591a <CsInsn 0x591a [410f1001]: movups xmm0, xmmword ptr [r9]>  len 4
# 22814   0x591e <CsInsn 0x591e [eb10]: jmp 0x5930>  len 2
# 22816   0x5920 <CsInsn 0x5920 [833d59b9010000]: cmp dword ptr [rip + 0x1b959], 0>  len 7
# 22823   0x5927 <CsInsn 0x5927 [7510]: jne 0x5939>  len 2
# 22825   0x5929 <CsInsn 0x5929 [0f100538ae0100]: movups xmm0, xmmword ptr [rip + 0x1ae38]>  len 7
# 22832   0x5930 <CsInsn 0x5930 [c645e701]: mov byte ptr [rbp - 0x19], 1>  len 4
# 22836   0x5934 <CsInsn 0x5934 [f30f7f45d7]: movdqu xmmword ptr [rbp - 0x29], xmm0>  len 5
# 22841   0x5939 <CsInsn 0x5939 [488b457f]: mov rax, qword ptr [rbp + 0x7f]>  len 4
# 22845   0x593d <CsInsn 0x593d [48894577]: mov qword ptr [rbp + 0x77], rax>  len 4
# 22849   0x5941 <CsInsn 0x5941 [4c89456f]: mov qword ptr [rbp + 0x6f], r8>  len 4
# 22853   0x5945 <CsInsn 0x5945 [4889555f]: mov qword ptr [rbp + 0x5f], rdx>  len 4
# 22857   0x5949 <CsInsn 0x5949 [48894d67]: mov qword ptr [rbp + 0x67], rcx>  len 4
# 22861   0x594d <CsInsn 0x594d [4885d2]: test rdx, rdx>  len 3
# 22864   0x5950 <CsInsn 0x5950 [752e]: jne 0x5980>  len 2
# 22866   0x5952 <CsInsn 0x5952 [488d45bf]: lea rax, [rbp - 0x41]>  len 4
# 22870   0x5956 <CsInsn 0x5956 [c645ef01]: mov byte ptr [rbp - 0x11], 1>  len 4
# 22874   0x595a <CsInsn 0x595a [4889442428]: mov qword ptr [rsp + 0x28], rax>  len 5
# 22879   0x595f <CsInsn 0x595f [4533c9]: xor r9d, r9d>  len 3
# 22882   0x5962 <CsInsn 0x5962 [488364242000]: and qword ptr [rsp + 0x20], 0>  len 6
# 22888   0x5968 <CsInsn 0x5968 [4533c0]: xor r8d, r8d>  len 3
# 22891   0x596b <CsInsn 0x596b [33d2]: xor edx, edx>  len 2
# 22893   0x596d <CsInsn 0x596d [c745eb16000000]: mov dword ptr [rbp - 0x15], 0x16>  len 7
# 22900   0x5974 <CsInsn 0x5974 [33c9]: xor ecx, ecx>  len 2
# 22902   0x5976 <CsInsn 0x5976 [e899190000]: call 0x7314>  len 5
# 22907   0x597b <CsInsn 0x597b [83cfff]: or edi, 0xffffffff>  len 3
# 22910   0x597e <CsInsn 0x597e [eb4c]: jmp 0x59cc>  len 2
# 22912   0x5980 <CsInsn 0x5980 [4d85c0]: test r8, r8>  len 3
# 22915   0x5983 <CsInsn 0x5983 [74cd]: je 0x5952>  len 2
# 22917   0x5985 <CsInsn 0x5985 [488d455f]: lea rax, [rbp + 0x5f]>  len 4
# 22921   0x5989 <CsInsn 0x5989 [488955ff]: mov qword ptr [rbp - 1], rdx>  len 4
# 22925   0x598d <CsInsn 0x598d [4889450f]: mov qword ptr [rbp + 0xf], rax>  len 4
# 22929   0x5991 <CsInsn 0x5991 [4c8d4dff]: lea r9, [rbp - 1]>  len 4
# 22933   0x5995 <CsInsn 0x5995 [488d45bf]: lea rax, [rbp - 0x41]>  len 4
# 22937   0x5999 <CsInsn 0x5999 [48895507]: mov qword ptr [rbp + 7], rdx>  len 4
# 22941   0x599d <CsInsn 0x599d [48894517]: mov qword ptr [rbp + 0x17], rax>  len 4
# 22945   0x59a1 <CsInsn 0x59a1 [4c8d450f]: lea r8, [rbp + 0xf]>  len 4
# 22949   0x59a5 <CsInsn 0x59a5 [488d4567]: lea rax, [rbp + 0x67]>  len 4
# 22953   0x59a9 <CsInsn 0x59a9 [4889451f]: mov qword ptr [rbp + 0x1f], rax>  len 4
# 22957   0x59ad <CsInsn 0x59ad [488d5507]: lea rdx, [rbp + 7]>  len 4
# 22961   0x59b1 <CsInsn 0x59b1 [488d456f]: lea rax, [rbp + 0x6f]>  len 4
# 22965   0x59b5 <CsInsn 0x59b5 [48894527]: mov qword ptr [rbp + 0x27], rax>  len 4
# 22969   0x59b9 <CsInsn 0x59b9 [488d4d7f]: lea rcx, [rbp + 0x7f]>  len 4
# 22973   0x59bd <CsInsn 0x59bd [488d4577]: lea rax, [rbp + 0x77]>  len 4
# 22977   0x59c1 <CsInsn 0x59c1 [4889452f]: mov qword ptr [rbp + 0x2f], rax>  len 4
# 22981   0x59c5 <CsInsn 0x59c5 [e87edfffff]: call 0x3948>  len 5
# 22986   0x59ca <CsInsn 0x59ca [8bf8]: mov edi, eax>  len 2
# 22988   0x59cc <CsInsn 0x59cc [807de702]: cmp byte ptr [rbp - 0x19], 2>  len 4
# 22992   0x59d0 <CsInsn 0x59d0 [750b]: jne 0x59dd>  len 2
# 22994   0x59d2 <CsInsn 0x59d2 [488b4dbf]: mov rcx, qword ptr [rbp - 0x41]>  len 4
# 22998   0x59d6 <CsInsn 0x59d6 [83a1a8030000fd]: and dword ptr [rcx + 0x3a8], 0xfffffffd>  len 7
# 23005   0x59dd <CsInsn 0x59dd [807def00]: cmp byte ptr [rbp - 0x11], 0>  len 4
# 23009   0x59e1 <CsInsn 0x59e1 [740f]: je 0x59f2>  len 2
# 23011   0x59e3 <CsInsn 0x59e3 [8b5deb]: mov ebx, dword ptr [rbp - 0x15]>  len 3
# 23014   0x59e6 <CsInsn 0x59e6 [488d4dbf]: lea rcx, [rbp - 0x41]>  len 4
# 23018   0x59ea <CsInsn 0x59ea [e8d1edffff]: call 0x47c0>  len 5
# 23023   0x59ef <CsInsn 0x59ef [895820]: mov dword ptr [rax + 0x20], ebx>  len 3
# 23026   0x59f2 <CsInsn 0x59f2 [807df700]: cmp byte ptr [rbp - 9], 0>  len 4
# 23030   0x59f6 <CsInsn 0x59f6 [740f]: je 0x5a07>  len 2
# 23032   0x59f8 <CsInsn 0x59f8 [8b5df3]: mov ebx, dword ptr [rbp - 0xd]>  len 3
# 23035   0x59fb <CsInsn 0x59fb [488d4dbf]: lea rcx, [rbp - 0x41]>  len 4
# 23039   0x59ff <CsInsn 0x59ff [e8bcedffff]: call 0x47c0>  len 5
# 23044   0x5a04 <CsInsn 0x5a04 [895824]: mov dword ptr [rax + 0x24], ebx>  len 3
# 23047   0x5a07 <CsInsn 0x5a07 [8bc7]: mov eax, edi>  len 2
# 23049   0x5a09 <CsInsn 0x5a09 [4881c4b0000000]: add rsp, 0xb0>  len 7
# 23056   0x5a10 <CsInsn 0x5a10 [5f]: pop rdi>  len 1
# 23057   0x5a11 <CsInsn 0x5a11 [5b]: pop rbx>  len 1
# 23058   0x5a12 <CsInsn 0x5a12 [5d]: pop rbp>  len 1
# 23059   0x5a13 <CsInsn 0x5a13 [c3]: ret >  len 1
# 23060   0x5a14 <CsInsn 0x5a14 [48895c2408]: mov qword ptr [rsp + 8], rbx>  len 5
# 23065   0x5a19 <CsInsn 0x5a19 [48896c2410]: mov qword ptr [rsp + 0x10], rbp>  len 5
# 23070   0x5a1e <CsInsn 0x5a1e [4889742418]: mov qword ptr [rsp + 0x18], rsi>  len 5
# 23075   0x5a23 <CsInsn 0x5a23 [57]: push rdi>  len 1
# 23076   0x5a24 <CsInsn 0x5a24 [4883ec20]: sub rsp, 0x20>  len 4
# 23080   0x5a28 <CsInsn 0x5a28 [488bf2]: mov rsi, rdx>  len 3
# 23083   0x5a2b <CsInsn 0x5a2b [8bf9]: mov edi, ecx>  len 2
# 23085   0x5a2d <CsInsn 0x5a2d [e81a440000]: call 0x9e4c>  len 5
# 23090   0x5a32 <CsInsn 0x5a32 [4533c9]: xor r9d, r9d>  len 3
# 23093   0x5a35 <CsInsn 0x5a35 [488bd8]: mov rbx, rax>  len 3
# 23096   0x5a38 <CsInsn 0x5a38 [4885c0]: test rax, rax>  len 3
# 23099   0x5a3b <CsInsn 0x5a3b [741f]: je 0x5a5c>  len 2
# 23101   0x5a3d <CsInsn 0x5a3d [488b08]: mov rcx, qword ptr [rax]>  len 3
# 23104   0x5a40 <CsInsn 0x5a40 [488bc1]: mov rax, rcx>  len 3
# 23107   0x5a43 <CsInsn 0x5a43 [4c8d81c0000000]: lea r8, [rcx + 0xc0]>  len 7
# 23114   0x5a4a <CsInsn 0x5a4a [493bc8]: cmp rcx, r8>  len 3
# 23117   0x5a4d <CsInsn 0x5a4d [740d]: je 0x5a5c>  len 2
# 23119   0x5a4f <CsInsn 0x5a4f [3938]: cmp dword ptr [rax], edi>  len 2
# 23121   0x5a51 <CsInsn 0x5a51 [7420]: je 0x5a73>  len 2
# 23123   0x5a53 <CsInsn 0x5a53 [4883c010]: add rax, 0x10>  len 4
# 23127   0x5a57 <CsInsn 0x5a57 [493bc0]: cmp rax, r8>  len 3
# 23130   0x5a5a <CsInsn 0x5a5a [75f3]: jne 0x5a4f>  len 2
# 23132   0x5a5c <CsInsn 0x5a5c [33c0]: xor eax, eax>  len 2
# 23134   0x5a5e <CsInsn 0x5a5e [488b5c2430]: mov rbx, qword ptr [rsp + 0x30]>  len 5
# 23139   0x5a63 <CsInsn 0x5a63 [488b6c2438]: mov rbp, qword ptr [rsp + 0x38]>  len 5
# 23144   0x5a68 <CsInsn 0x5a68 [488b742440]: mov rsi, qword ptr [rsp + 0x40]>  len 5
# 23149   0x5a6d <CsInsn 0x5a6d [4883c420]: add rsp, 0x20>  len 4
# 23153   0x5a71 <CsInsn 0x5a71 [5f]: pop rdi>  len 1
# 23154   0x5a72 <CsInsn 0x5a72 [c3]: ret >  len 1
# 23155   0x5a73 <CsInsn 0x5a73 [4885c0]: test rax, rax>  len 3
# 23158   0x5a76 <CsInsn 0x5a76 [74e4]: je 0x5a5c>  len 2
# 23160   0x5a78 <CsInsn 0x5a78 [4c8b4008]: mov r8, qword ptr [rax + 8]>  len 4
# 23164   0x5a7c <CsInsn 0x5a7c [4d85c0]: test r8, r8>  len 3
# 23167   0x5a7f <CsInsn 0x5a7f [74db]: je 0x5a5c>  len 2
# 23169   0x5a81 <CsInsn 0x5a81 [4983f805]: cmp r8, 5>  len 4
# 23173   0x5a85 <CsInsn 0x5a85 [750a]: jne 0x5a91>  len 2
# 23175   0x5a87 <CsInsn 0x5a87 [4c894808]: mov qword ptr [rax + 8], r9>  len 4
# 23179   0x5a8b <CsInsn 0x5a8b [418d40fc]: lea eax, [r8 - 4]>  len 4
# 23183   0x5a8f <CsInsn 0x5a8f [ebcd]: jmp 0x5a5e>  len 2
# 23185   0x5a91 <CsInsn 0x5a91 [4983f801]: cmp r8, 1>  len 4
# 23189   0x5a95 <CsInsn 0x5a95 [7505]: jne 0x5a9c>  len 2
# 23191   0x5a97 <CsInsn 0x5a97 [83c8ff]: or eax, 0xffffffff>  len 3
# 23194   0x5a9a <CsInsn 0x5a9a [ebc2]: jmp 0x5a5e>  len 2
# 23196   0x5a9c <CsInsn 0x5a9c [488b6b08]: mov rbp, qword ptr [rbx + 8]>  len 4
# 23200   0x5aa0 <CsInsn 0x5aa0 [48897308]: mov qword ptr [rbx + 8], rsi>  len 4
# 23204   0x5aa4 <CsInsn 0x5aa4 [83780408]: cmp dword ptr [rax + 4], 8>  len 4
# 23208   0x5aa8 <CsInsn 0x5aa8 [0f85c4000000]: jne 0x5b72>  len 6
# 23214   0x5aae <CsInsn 0x5aae [4883c130]: add rcx, 0x30>  len 4
# 23218   0x5ab2 <CsInsn 0x5ab2 [488d9190000000]: lea rdx, [rcx + 0x90]>  len 7
# 23225   0x5ab9 <CsInsn 0x5ab9 [eb08]: jmp 0x5ac3>  len 2
# 23227   0x5abb <CsInsn 0x5abb [4c894908]: mov qword ptr [rcx + 8], r9>  len 4
# 23231   0x5abf <CsInsn 0x5abf [4883c110]: add rcx, 0x10>  len 4
# 23235   0x5ac3 <CsInsn 0x5ac3 [483bca]: cmp rcx, rdx>  len 3
# 23238   0x5ac6 <CsInsn 0x5ac6 [75f3]: jne 0x5abb>  len 2
# 23240   0x5ac8 <CsInsn 0x5ac8 [81388d0000c0]: cmp dword ptr [rax], 0xc000008d>  len 6
# 23246   0x5ace <CsInsn 0x5ace [8b7b10]: mov edi, dword ptr [rbx + 0x10]>  len 3
# 23249   0x5ad1 <CsInsn 0x5ad1 [747a]: je 0x5b4d>  len 2
# 23251   0x5ad3 <CsInsn 0x5ad3 [81388e0000c0]: cmp dword ptr [rax], 0xc000008e>  len 6
# 23257   0x5ad9 <CsInsn 0x5ad9 [746b]: je 0x5b46>  len 2
# 23259   0x5adb <CsInsn 0x5adb [81388f0000c0]: cmp dword ptr [rax], 0xc000008f>  len 6
# 23265   0x5ae1 <CsInsn 0x5ae1 [745c]: je 0x5b3f>  len 2
# 23267   0x5ae3 <CsInsn 0x5ae3 [8138900000c0]: cmp dword ptr [rax], 0xc0000090>  len 6
# 23273   0x5ae9 <CsInsn 0x5ae9 [744d]: je 0x5b38>  len 2
# 23275   0x5aeb <CsInsn 0x5aeb [8138910000c0]: cmp dword ptr [rax], 0xc0000091>  len 6
# 23281   0x5af1 <CsInsn 0x5af1 [743e]: je 0x5b31>  len 2
# 23283   0x5af3 <CsInsn 0x5af3 [8138920000c0]: cmp dword ptr [rax], 0xc0000092>  len 6
# 23289   0x5af9 <CsInsn 0x5af9 [742f]: je 0x5b2a>  len 2
# 23291   0x5afb <CsInsn 0x5afb [8138930000c0]: cmp dword ptr [rax], 0xc0000093>  len 6
# 23297   0x5b01 <CsInsn 0x5b01 [7420]: je 0x5b23>  len 2
# 23299   0x5b03 <CsInsn 0x5b03 [8138b40200c0]: cmp dword ptr [rax], 0xc00002b4>  len 6
# 23305   0x5b09 <CsInsn 0x5b09 [7411]: je 0x5b1c>  len 2
# 23307   0x5b0b <CsInsn 0x5b0b [8138b50200c0]: cmp dword ptr [rax], 0xc00002b5>  len 6
# 23313   0x5b11 <CsInsn 0x5b11 [8bd7]: mov edx, edi>  len 2
# 23315   0x5b13 <CsInsn 0x5b13 [7540]: jne 0x5b55>  len 2
# 23317   0x5b15 <CsInsn 0x5b15 [ba8d000000]: mov edx, 0x8d>  len 5
# 23322   0x5b1a <CsInsn 0x5b1a [eb36]: jmp 0x5b52>  len 2
# 23324   0x5b1c <CsInsn 0x5b1c [ba8e000000]: mov edx, 0x8e>  len 5
# 23329   0x5b21 <CsInsn 0x5b21 [eb2f]: jmp 0x5b52>  len 2
# 23331   0x5b23 <CsInsn 0x5b23 [ba85000000]: mov edx, 0x85>  len 5
# 23336   0x5b28 <CsInsn 0x5b28 [eb28]: jmp 0x5b52>  len 2
# 23338   0x5b2a <CsInsn 0x5b2a [ba8a000000]: mov edx, 0x8a>  len 5
# 23343   0x5b2f <CsInsn 0x5b2f [eb21]: jmp 0x5b52>  len 2
# 23345   0x5b31 <CsInsn 0x5b31 [ba84000000]: mov edx, 0x84>  len 5
# 23350   0x5b36 <CsInsn 0x5b36 [eb1a]: jmp 0x5b52>  len 2
# 23352   0x5b38 <CsInsn 0x5b38 [ba81000000]: mov edx, 0x81>  len 5
# 23357   0x5b3d <CsInsn 0x5b3d [eb13]: jmp 0x5b52>  len 2
# 23359   0x5b3f <CsInsn 0x5b3f [ba86000000]: mov edx, 0x86>  len 5
# 23364   0x5b44 <CsInsn 0x5b44 [eb0c]: jmp 0x5b52>  len 2
# 23366   0x5b46 <CsInsn 0x5b46 [ba83000000]: mov edx, 0x83>  len 5
# 23371   0x5b4b <CsInsn 0x5b4b [eb05]: jmp 0x5b52>  len 2
# 23373   0x5b4d <CsInsn 0x5b4d [ba82000000]: mov edx, 0x82>  len 5
# 23378   0x5b52 <CsInsn 0x5b52 [895310]: mov dword ptr [rbx + 0x10], edx>  len 3
# 23381   0x5b55 <CsInsn 0x5b55 [49ba7033d3304f1f9c8b]: movabs r10, 0x8b9c1f4f30d33370>  len 10
# 23391   0x5b5f <CsInsn 0x5b5f [b908000000]: mov ecx, 8>  len 5
# 23396   0x5b64 <CsInsn 0x5b64 [498bc0]: mov rax, r8>  len 3
# 23399   0x5b67 <CsInsn 0x5b67 [ff1503fb0000]: call qword ptr [rip + 0xfb03]>  len 6
# 23405   0x5b6d <CsInsn 0x5b6d [897b10]: mov dword ptr [rbx + 0x10], edi>  len 3
# 23408   0x5b70 <CsInsn 0x5b70 [eb1a]: jmp 0x5b8c>  len 2
# 23410   0x5b72 <CsInsn 0x5b72 [4c894808]: mov qword ptr [rax + 8], r9>  len 4
# 23414   0x5b76 <CsInsn 0x5b76 [49ba7073d7504986c1c6]: movabs r10, 0xc6c1864950d77370>  len 10
# 23424   0x5b80 <CsInsn 0x5b80 [8b4804]: mov ecx, dword ptr [rax + 4]>  len 3
# 23427   0x5b83 <CsInsn 0x5b83 [498bc0]: mov rax, r8>  len 3
# 23430   0x5b86 <CsInsn 0x5b86 [ff15e4fa0000]: call qword ptr [rip + 0xfae4]>  len 6
# 23436   0x5b8c <CsInsn 0x5b8c [48896b08]: mov qword ptr [rbx + 8], rbp>  len 4
# 23440   0x5b90 <CsInsn 0x5b90 [e902ffffff]: jmp 0x5a97>  len 5
# 23445   0x5b95 <CsInsn 0x5b95 [cc]: int3 >  len 1
#
# Byte GAP ######  3  Missing bytes:  2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 122
#     116         print(e)
#     120 offset_inst = collections.OrderedDict(sorted(offset_inst.items()))
# --> 122 find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)
#     124 # print(offset_inst)
#     125 for byte_index in range(len(textSection)):
#
# Cell In[31], line 15, in find_data_in_textsection(ground_truth_offsets, text_section_offset, text_section_len, offset_inst_dict)
#      13     print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
#      14     for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
# ---> 15         print("# ",j, offset_inst_dict[ground_truth_offsets[j]] , 'inst len:',offset_inst_dict[ground_truth_offsets[j]].size )
#      16     print('\n')
#      17 else:
#
# IndexError: list index out of range

# %%
print('test')
# Out:
# test
