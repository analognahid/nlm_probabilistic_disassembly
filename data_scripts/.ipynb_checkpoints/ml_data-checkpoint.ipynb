# %%
import os,sys, json
import magic, hashlib, os, traceback
import ntpath
from capstone import *
from capstone.x86 import *

import collections
import traceback
from elftools.elf.elffile import ELFFile

# %%
bin_path = '/home/raisul/DATA/x86_O2_d4_mingw32_PE/' 

bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) ][0:100]

ground_truth_path = '/home/raisul/ANALYSED_DATA/objdump_x86_O2_d4_mingw32_PE/'

# %%
len(bin_files)
# Out:
# 100

# %%
def get_ground_truth(exe_path, text_section_offset , text_section_len ):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    objdump_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(objdump_file_path, "r") as file:
        objdump_data = json.load(file)

    ground_truth_offsets = list(objdump_data["instructions"].keys())
    ground_truth_offsets.remove('meta')
    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()

    
    return ground_truth_offsets

# %%
def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):

    for i in range(1, len(ground_truth_offsets)):
        gap = ground_truth_offsets[i] - ground_truth_offsets[i-1]

        inst_len = offset_inst_dict[ground_truth_offsets[i-1]].size 
        
        if gap!=inst_len:
            print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  ) 
        else:
            # print('hi')
            pass


def linear_sweep(offset_inst , target_offset):
    inst_sequence = []
    max_seq_length = 15

    
    current_offset = target_offset
    for q in range(max_seq_length):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:

                inst_sequence.insert(0, None) 
                inst_sequence.append(None)
                return  inst_sequence
                
            current_offset = current_offset + current_instruction.size
            inst_sequence.append( str(current_instruction.address) +": "+ current_instruction.mnemonic +' '+ current_instruction.op_str )
            # inst_sequence.append( current_instruction)
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                return inst_sequence

    return inst_sequence


for bin_file_path in bin_files:

    # try:
    #     ground_truth_offsets = get_ground_truth(bin_file_path, text_section_offset , len(textSection))
    # except Exception as e:
    #     print("An error occurred:", e)
    # print(ground_truth_offsets)
    
    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    # print("\n"*5)
    
    with open(bin_file_path, 'rb') as f:

        try:
            elffile = ELFFile(f)
            print('1')
            textSection = elffile.get_section_by_name('.text').data()
            print('2')
            text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
            print('3')
            ground_truth_offsets = get_ground_truth(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
        for byte_index in range(len(textSection)):
            
        
            try:    

                instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
                
                # if instruction:
                #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                #     print(instruction.operands[0].type , instruction.operands[0].imm)
                #     # print( dir(instruction.operands[0] ))
          
                # else:
                #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                    
                offset_inst[text_section_offset+byte_index] = instruction

            except Exception as e:
                print(traceback.print_exc() )
                print(e)

        
        
        offset_inst = collections.OrderedDict(sorted(offset_inst.items()))

        find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)
        
        # print(offset_inst)
        for byte_index in range(len(textSection)):
            inst_seq = linear_sweep(offset_inst ,text_section_offset + byte_index )
            # print('\n','# # '*10)
            # print(inst_seq)
    # print(ground_truth_offsets)
    # print(offset_inst.keys())
    print('\n','# # '*30)
# Out:
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17FA0124001E460435901C56821ED41856004EC076D6C2231480104960D0005392FDC44.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1D7F0EBC37A068090AB8BA300817B8860CC4CF03103FDB4FCEC638685F0A14E860B4AEC.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T12AD0C9C0ACFBBDA284A384E8CB5F2510212FAC1B55FCF911FC6944550F91825DBB576D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1E2F094206C8E1480B457809FBFDA8847371EA447EAD8B870F4DB0334BF8094892E2EDD.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1D101974726E500A4095B072DAC46E8C4BB1EC8B0368DBE8AAC2D557E6592FCA01BD3D0.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1EB51C1464C592453531B2E3AEB97080D46A9DC3361C6FCA575ACF3387F20974E2F9EA2.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C1F0A74099DFE6989B93C1585B0A5933E24ACC2652CCF711F09C357C9FA0D7A51B06C0.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T10201C950F7895A6A53B75237856264CD239CE4B224EDAE22AC1F5B1808308EB51F9441.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C0F096880D596982B133593DAF424814CF9EFC0B39E57762F92E11C26F70D06D6F6E89.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T104E0268690AD8714B1E33210FE4B1DCA1677C51283CD7A21816AA98696E902DC83D64D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1BE900205D5BD14444D238199349680180202A517615C37006C161693EF720B468F735D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T10AE0D8C08DED41D1553391F9669BEA10311D940B762CB822FD4A23A2BF90298D9D71B5.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T11A31ED9A35DB2D342A57A295578F84412378D12320F8BE20F88FDD290F71874C038F6C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T153D07DC6C70CE2462DD311C4C164452CC0EB551052F4D073233F0659CA83090D6F31DA.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T14F815193BEDDB276E2E300409B3049268C69EC0E67A37672B4BD518C221977681B95FD.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1B3F09E83258DC498FA5F5484573D0DC217B4E02096F1B2B2EC2D1AC7B4F1D8423B6249.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T19241DC8619AF7A354357A5399F8C91C85B98D00399EDFC55F84C40B86F00839D3B9BE2.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C711EB002DE020302142F374BFDFFA10A089E437399DEE45756C22628F808F15476EAD.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1E7E0C2914ADB6681829740BE471EA244325DD427B1C8F855FA2DB1514F25A0AAAB170E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1EAE068E3B20AD868B3EB20D193308C01CE96C02267F57AF6FC28464DD055C6905BE7E8.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1BCF024C4592DBD8178B78665C755AC40C2AE9C8332EEBA25FC5C80329F30A0586A1F4C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T13C21D0A35A515B05AC03A03FDBCD500822567422A684EDC9FD3F52111F1240923F5CDB.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F1F0EB8A326EC38066D3E0A4460E8E1DCA130039EBDCEC63D81B6B12700102A436F6EA.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16CE0C0D3D00FE8C7760365505730C1057194E01485F6B83B742113E776E78D591B3688.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16001AB433F1E5878A78F8885523D9E828BB4E020A2F1B5B2E82E55877970E5012B93DC.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1FC119EE053DE75986673F191BE211C44DB48515163ED3885F87D0460677988812777AD.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1D3F04694ADD8A400772BE538604BC8242B0DE467B9ECBF47A148DAADBF8046088F0D9C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T118F0C0E2310CDBB6DB9B8482631304640B5894346877DCB0283E091AB6A3C5212A374E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17CF0E988385B25A0331BF2689A469C48425BC807E6BDF830F89C11545F25704E8B7B44.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1FEF028E8486B1E219DA752CD87974608104E9D77F19CA056F83C40D09F5D311E6C1E7A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1AB41115148AA092F5122D7B46B683296B314600B7D997903BE9F7F807F33C2123F07D9.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1DE4231552C63019011A7D63E6B1F6E44F2ABC01311C9ED41BD2FE2344FB12666BFEBA9.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C52198355DA7C6221133A0B8B3C7685CF20AC41F8228DE04718D9AD07F415296DF8FE6.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16061C24728F3084DD293B42ECB6F504EA868E01B267DE94178AC15E0DF95579BBF03D0.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T136012DC33586D01DA7B3062007384C82BA7CE855C6FD76F9F854015662DAC4951FB745.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1E8016DD4FA4D70313B334E14D22ACD18CBB6D895BEEF6104923DD0525F930E21AE402C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16B21575046D6D1E6200E66395FDBB008A694F43B24AEFD14FC1CA5A11F81CB92B72F8A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C9D023308D9B86D095A785771F52841C110ED807128C7114750D41911F520487597384.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1DFD0C2E2A088E2846CAF8066DB3DC82C02BA8054C160AE23445EE259301008F4593A98.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T144E026E198E5024BA513762AABCF1164F503F93343AC6894744E80D55F904356BFDB8C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T182C02BC4384EC8C44A7A0018550008C0DF08C4071A8C3210F01848033F24C81C0F3FAC.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1D5218BC6689A325D6153B4399FE62900352AF93769C8FC90FC2D52A01F444A0DBF2FD5.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17CC02B01837CC580771304C91E84443109BC401337CE10A53E023CB5CF8B043DDD52D8.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1FDF097B5314D66C4E5AB0487C8358E898F7DEC0234B2B572DCF806B1507292606B8B8A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T195D097804CDDCAC2602308488E81CA305AACC00723CC3611BE0938F24F03013DCDD58D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17DF0A708B9FBB6C06D9370E4D3EB9019713EF44727D82122B20D4051DF90E75B5A2597.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1AFF02E125C9A1A90AD5784391F8A1D042306C02721ECBC11B97D02B5DFC241527BE354.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F8C08C96710ED088B7A38440A5304C400B56C80016FC3AF7C8240746C0808880AAE2E6.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1EC217BD50C8A6552E87B432CDBEB8500CB1AF46731E83260FC1C20A22F7748853F1EAE.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1FE01D1C19E4A2C8D703792A8463ADCA0896CA81FB4B87852F66CC5F8BB3158691D581E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T12421AF473CFB180AA193143FAF5E2849785CE4A7319DED11BEBC4AA17F481BA75B0750.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1152124A56CC91E93186390B8479740C0E1235863132B727C714FB8B94F1ECE38CE6E9C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T188C01280765EBE86BCA78040C0088C68035A91A830D8E850A22C08129A46862A48230E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1B7C012298CAF5750585A815BA90B8474053D68C732AC98F0E14360A36F0494971B368C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T10211A2684C5A47407257587E0FDA06082229C95314D5BE14FF2EA2A14F274625FED78D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T144E0C210478D4691B45371608FD320387616EC1B6194E860797E92DA9F2405C377B683.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1791140C5C49DAE682527493A446F140C45AAD983B1D8EC20B93F208C9F013B1B7EDD6D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T13C21F40C69D4CE7A4821019A95478099B12BBD43796D6460790F53DA4F134F51AFDD68.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F8217BBAF4BE7E093362CD75DD026849A15AD016530A6D72301A0FB1AFC0B653E7B705.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1AF21AA68D7DC43217427B9908F730248388DF461FCAB7C6FDA2C43991696538A0B4A2A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1673121B08D7718428937613A83AF64601912BCA3157AF8F9FCCED248DF5A0CA44F297D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T19431BD03DE26E351B0F77817A54BE18261FEA2EBB0E8C961314D15C06F10AE79AAC0D5.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1761242167FE16A14E213DCBBDD1B9066622CC43250BEFD93729D42F26F914604EF3A88.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1FF21CED07EAE6C9A219691297D134647210AF0F629DEBEE13C4F05B83F0057D71F90A4.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T10CF05552A4CBD848B7A79B40033C4B8519B8D820E4F838F6F83C108BE38781462F8264.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T15FB01287543F7A54FFD345A87A7185930591F010A2A978188C6D594BC590C65C277214.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F9F0E5690A4B36403A0394F94F27B454E856D41311DCED64782D51B0CF656A467F568D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16FF05C4F979870516C17C9951B5E14B8178F907431A5EE32FE3905E38F402906173F8D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T11791611486E925253017627CCF672914B23DD823245EFDE9BD3E76909F8143AB2F2C9B.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T12F117D00EF96137A1023031D47CE99D0635D5437A0BD7954B83B56194F368F617AAFCC.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T19701EE034B5410FC040AC09D0786AE2B60EAD4B32CEC28FF360E60C28F9E51C67F6044.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17F11A051AEDA1F56411B42B90B2EE4C480879827909B292DB82F30351F8FEC27DE4E86.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1B7F08401D2EB01618BD34BAF5ED2D822021BF0371208DAAB6D222190BF0050B73D73E1.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T12DC02B006DDC879340078174210BD0D4019EDD0AB1EC3C63CD0220D70904CDC82FBE48.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T144F0C01F67AC223D785BA4C8471A818D1373B51E160846E6981F356C7DF18F416B1CEE.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T10041A08474FB9C4C91D1987E866BA418B124D0731EBFCD8078DC41B48F98B685EF96E2.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T169C08C880CDA05802A2382648B0940242046C417088CA000FA1E41539F04002B6A2288.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17CE0D88C1809D420DBBB90499B085574D716E683299CE364F01F81921FB840BFA94DA8.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T161E0C24916FB08C2956B91B36FCB65103398C8A76BCDF414BE8DC0A45F4540AB6F6399.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1DFD09E847E69513CE71B014442174DC4DF73D44193BEB1B5D16950BBB441E5C46BF49C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F2310885307ECC8896E25C7ED63B681D6156A03328AEDE4038FEC2741FC09EC66B56F5.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T153C02BC01CEE08875C96F2185F444024810AD40F00CCB000FC2C10121F82044F1B237E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T11BF0DF805AA95EA166A360398F9F5814212DD84B61CC7C11FE0C12858F85829AEE2B1C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1A711C0E12DD66296B057C377010BE454B30FE87103EDB8B1E34565712F098A9B1BAEEE.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T15AF08B5672958B1C24FF842B19276710222BE86240C8B0A2ECE724A2EF579166CF6568.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T116A1F0D1C64D5A01FCB78668EB519E4C1D9FE520E8F9BC92EC6C466C725489320FCB2A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1C751F6216B420B195C032361CADEA8C15669D11331B2B9F9FFAF2A414F12F6D09B7B9D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T188216BEE9F0CCE8260F350B4993349C1824BA83758E89C523F6C57915412C7B7ADEB72.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1B80190DDA82748A52377562EDF4E8C84D78BC04F90ECB200BDAC12868FB115582C9E5D.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T16E2129C8A8EB0DB2617389248F5B40B2A71EC53B01EDF511B86DE54C4F0A022E759AED.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1A8F0E285CAB705C1D4D74126CA8BC4A281CE2C0B123E1C64B12F25645F6C07D64FBF69.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1E7E07DD373CBD448AF97980413744782A775E80096FD3CB2E838015E9282C8385F734C.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T17311E351E4E148D16F239339B71E9397D602A42B154B7417BCEDC21DBF114E463A6880.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1D5B01245C4BE09CBA73B81A45501C72991DCE90C3B4DA431B94490E371D048BBA97005.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T111F0E9655B2CD12C3437C09F8E1444450E58E971A7D2AF9BB93D02C01D6050273ABFAE.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1F0F0213C05CC9160275F508AA9D9D825E73F28EC30DC7283601BE0E62AE2A540B70B8A.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T167E07D85A428C151787750F2E71D4C3482424820E2857CE3545A7722000205B467F3F4.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T1A8318C62F13DE596A8E1C8BFDA1209C1A539F0726EFB3C168402D3BC09F8A1497F1E51.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T178012BD1988A5AE10B3351BB97018014D38C104785DD95BEB85E43995F778D473FEBCE.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# An error occurred: Magic number does not match /home/raisul/DATA/x86_O2_d4_mingw32_PE/T153218B9AA99E4B02207B492F9F7B5420315DE83732C8F612FF2C12454F1115CD6B698E.exe
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
print('test')
# Out:
# test
