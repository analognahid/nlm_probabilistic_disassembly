# %%
import os,sys, json
import magic, hashlib, os, traceback
import ntpath
from capstone import *
from capstone.x86 import *

import collections
import traceback
import lief
from elftools.elf.elffile import ELFFile

# %%
bin_path = '/home/raisul/DATA/temp/x86_O2_d4/' #'/home/raisul/DATA/x86_O2_d4_mingw32_PE' 

bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) ][0:10]

ground_truth_path ='/home/raisul/DATA/temp/ghidra_x86_O2_d4/' # '/home/raisul/ANALYSED_DATA/ghidra_x86_O2_d4_mingw32_PE'

# %%
len(bin_files)
# Out:
# 96

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    print(ground_truth_offsets)
    return ground_truth_offsets



# def get_ground_truth_objdump(exe_path, text_section_offset , text_section_len ):

#     text_sextion_end = text_section_offset + text_section_len
    
#     elf_file_name = os.path.basename(exe_path)
#     objdump_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
#     with open(objdump_file_path, "r") as file:
#         objdump_data = json.load(file)

#     ground_truth_offsets = list(objdump_data["instructions"].keys())
#     # print(ground_truth_offsets)
#     if 'meta' in ground_truth_offsets:
#         ground_truth_offsets.remove('meta')
#     ground_truth_offsets = [int(i) for i in ground_truth_offsets]
#     ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
#     ground_truth_offsets.sort()

    
#     return ground_truth_offsets

# %%
def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):

    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            
            print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                if offset_inst_dict[j]:
                    print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                else:
                    print("# ",j, " invalid ")
            print('\n')
        else:
            print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass


def linear_sweep(offset_inst , target_offset):
    inst_sequence = []
    max_seq_length = 15

    
    current_offset = target_offset
    for q in range(max_seq_length):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:

                inst_sequence.insert(0, None) 
                inst_sequence.append(None)
                return  inst_sequence
                
            current_offset = current_offset + current_instruction.size
            inst_sequence.append( str(current_instruction.address) +": "+ current_instruction.mnemonic +' '+ current_instruction.op_str )
            # inst_sequence.append( current_instruction)
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                return inst_sequence

    return inst_sequence


for bin_file_path in bin_files:

    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    # print("\n"*5)
    

    
    with open(bin_file_path, 'rb') as f:

        try:
            elffile = ELFFile(f)
           
            textSection = elffile.get_section_by_name('.text').data()
        
            text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
          
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)

    for byte_index in range(len(textSection)):
        
    
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                # print(instruction.operands[0].type , instruction.operands[0].imm)
                # print( dir(instruction.operands[0] ))
      
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                
            offset_inst[text_section_offset+byte_index] = instruction

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst = collections.OrderedDict(sorted(offset_inst.items()))

    find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)
    
    # print(offset_inst)
    for byte_index in range(len(textSection)):
        inst_seq = linear_sweep(offset_inst ,text_section_offset + byte_index )
        # print('\n','# # '*10)
        # print(inst_seq)
    # print(ground_truth_offsets)
    # print(offset_inst.keys())
    print('\n','# # '*30)
# Out:
# [4192, 4196, 4197, 4204, 4209, 4211, 4214, 4219, 4224, 4227, 4232, 4234, 4239, 4244, 4246, 4247, 4256, 4260, 4262, 4265, 4266, 4269, 4273, 4274, 4275, 4278, 4280, 4287, 4293, 4304, 4311, 4318, 4321, 4323, 4330, 4333, 4335, 4344, 4352, 4359, 4366, 4369, 4372, 4376, 4380, 4383, 4386, 4388, 4395, 4398, 4400, 4408, 4416, 4420, 4427, 4429, 4430, 4438, 4441, 4443, 4450, 4455, 4460, 4467, 4468, 4472, 4480, 4484, 4496, 4500, 4503, 4505, 4508, 4511, 4514]
# 4196   0x1064 push rbx  len 1
# 4197   0x1065 lea rbx, [rip + 0xf98]  len 7
# 4204   0x106c mov edx, 0x68  len 5
# 4209   0x1071 xor eax, eax  len 2
# 4211   0x1073 mov rsi, rbx  len 3
# 4214   0x1076 mov edi, 2  len 5
# 4219   0x107b call 0x1050  len 5
# 4224   0x1080 mov rsi, rbx  len 3
# 4227   0x1083 mov edx, 0x78  len 5
# 4232   0x1088 xor eax, eax  len 2
# 4234   0x108a mov edi, 2  len 5
# 4239   0x108f call 0x1050  len 5
# 4244   0x1094 xor eax, eax  len 2
# 4246   0x1096 pop rbx  len 1
# 4247   0x1097 <CsInsn 0x1097 [c3]: ret >  len 1
#
# Byte GAP ######  9  Missing bytes:  8
# #  4248 nop dword ptr [rax + rax] inst len: 8
# #  4249  invalid
# #  4250 test byte ptr [rax], al inst len: 2
# #  4251 add byte ptr [rax], al inst len: 2
# #  4252 add byte ptr [rax], al inst len: 2
# #  4253 add byte ptr [rax], al inst len: 2
# #  4254 add byte ptr [rax], al inst len: 2
# #  4255 add bl, dh inst len: 2
#
#
# 4256   0x10a0 endbr64   len 4
# 4260   0x10a4 xor ebp, ebp  len 2
# 4262   0x10a6 mov r9, rdx  len 3
# 4265   0x10a9 pop rsi  len 1
# 4266   0x10aa mov rdx, rsp  len 3
# 4269   0x10ad and rsp, 0xfffffffffffffff0  len 4
# 4273   0x10b1 push rax  len 1
# 4274   0x10b2 push rsp  len 1
# 4275   0x10b3 xor r8d, r8d  len 3
# 4278   0x10b6 xor ecx, ecx  len 2
# 4280   0x10b8 lea rdi, [rip - 0x5f]  len 7
# 4287   0x10bf call qword ptr [rip + 0x2f13]  len 6
# 4293   0x10c5 <CsInsn 0x10c5 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4294 nop word ptr cs:[rax + rax] inst len: 10
# #  4295 nop dword ptr cs:[rax + rax] inst len: 9
# #  4296 nop dword ptr [rax + rax] inst len: 8
# #  4297  invalid
# #  4298 test byte ptr [rax], al inst len: 2
# #  4299 add byte ptr [rax], al inst len: 2
# #  4300 add byte ptr [rax], al inst len: 2
# #  4301 add byte ptr [rax], al inst len: 2
# #  4302 add byte ptr [rax], al inst len: 2
# #  4303 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4304   0x10d0 lea rdi, [rip + 0x2f39]  len 7
# 4311   0x10d7 lea rax, [rip + 0x2f32]  len 7
# 4318   0x10de cmp rax, rdi  len 3
# 4321   0x10e1 je 0x10f8  len 2
# 4323   0x10e3 mov rax, qword ptr [rip + 0x2ef6]  len 7
# 4330   0x10ea test rax, rax  len 3
# 4333   0x10ed je 0x10f8  len 2
# 4335   0x10ef <CsInsn 0x10ef [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4337 nop dword ptr [rax] inst len: 7
# #  4338  invalid
# #  4339 add byte ptr [rax], 0 inst len: 3
# #  4340 add byte ptr [rax], al inst len: 2
# #  4341 add byte ptr [rax], al inst len: 2
# #  4342 add byte ptr [rax], al inst len: 2
# #  4343 add bl, al inst len: 2
#
#
# 4344   0x10f8 <CsInsn 0x10f8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4345 nop dword ptr [rax] inst len: 7
# #  4346  invalid
# #  4347 add byte ptr [rax], 0 inst len: 3
# #  4348 add byte ptr [rax], al inst len: 2
# #  4349 add byte ptr [rax], al inst len: 2
# #  4350 add byte ptr [rax], al inst len: 2
# #  4351 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4352   0x1100 lea rdi, [rip + 0x2f09]  len 7
# 4359   0x1107 lea rsi, [rip + 0x2f02]  len 7
# 4366   0x110e sub rsi, rdi  len 3
# 4369   0x1111 mov rax, rsi  len 3
# 4372   0x1114 shr rsi, 0x3f  len 4
# 4376   0x1118 sar rax, 3  len 4
# 4380   0x111c add rsi, rax  len 3
# 4383   0x111f sar rsi, 1  len 3
# 4386   0x1122 je 0x1138  len 2
# 4388   0x1124 mov rax, qword ptr [rip + 0x2ec5]  len 7
# 4395   0x112b test rax, rax  len 3
# 4398   0x112e je 0x1138  len 2
# 4400   0x1130 <CsInsn 0x1130 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4402 nop word ptr [rax + rax] inst len: 6
# #  4403 nop dword ptr [rax + rax] inst len: 5
# #  4404  invalid
# #  4405 add byte ptr [rax], r8b inst len: 3
# #  4406 add byte ptr [rax], al inst len: 2
# #  4407 add bl, al inst len: 2
#
#
# 4408   0x1138 <CsInsn 0x1138 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4409 nop dword ptr [rax] inst len: 7
# #  4410  invalid
# #  4411 add byte ptr [rax], 0 inst len: 3
# #  4412 add byte ptr [rax], al inst len: 2
# #  4413 add byte ptr [rax], al inst len: 2
# #  4414 add byte ptr [rax], al inst len: 2
# #  4415 add bl, dh inst len: 2
#
#
# 4416   0x1140 endbr64   len 4
# 4420   0x1144 cmp byte ptr [rip + 0x2ec5], 0  len 7
# 4427   0x114b jne 0x1178  len 2
# 4429   0x114d push rbp  len 1
# 4430   0x114e cmp qword ptr [rip + 0x2ea2], 0  len 8
# 4438   0x1156 mov rbp, rsp  len 3
# 4441   0x1159 je 0x1167  len 2
# 4443   0x115b mov rdi, qword ptr [rip + 0x2ea6]  len 7
# 4450   0x1162 call 0x1040  len 5
# 4455   0x1167 call 0x10d0  len 5
# 4460   0x116c mov byte ptr [rip + 0x2e9d], 1  len 7
# 4467   0x1173 pop rbp  len 1
# 4468   0x1174 <CsInsn 0x1174 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4469 nop dword ptr [rax] inst len: 3
# #  4470  invalid
# #  4471 add bl, al inst len: 2
#
#
# 4472   0x1178 <CsInsn 0x1178 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4473 nop dword ptr [rax] inst len: 7
# #  4474  invalid
# #  4475 add byte ptr [rax], 0 inst len: 3
# #  4476 add byte ptr [rax], al inst len: 2
# #  4477 add byte ptr [rax], al inst len: 2
# #  4478 add byte ptr [rax], al inst len: 2
# #  4479 add bl, dh inst len: 2
#
#
# 4480   0x1180 endbr64   len 4
# 4484   0x1184 <CsInsn 0x1184 [e977ffffff]: jmp 0x1100>  len 5
#
# Byte GAP ######  12  Missing bytes:  7
# #  4489 nop dword ptr [rax] inst len: 7
# #  4490  invalid
# #  4491 add byte ptr [rax], 0 inst len: 3
# #  4492 add byte ptr [rax], al inst len: 2
# #  4493 add byte ptr [rax], al inst len: 2
# #  4494 add byte ptr [rax], al inst len: 2
# #  4495 add bl, dh inst len: 2
#
#
# 4496   0x1190 endbr64   len 4
# 4500   0x1194 lea ecx, [rdi - 0x41]  len 3
# 4503   0x1197 mov eax, edi  len 2
# 4505   0x1199 lea edx, [rdi + 0x20]  len 3
# 4508   0x119c cmp ecx, 0x1a  len 3
# 4511   0x119f cmovb eax, edx  len 3
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4256, 4260, 4264, 4271, 4280, 4285, 4287, 4292, 4300, 4305, 4309, 4314, 4321, 4326, 4328, 4330, 4335, 4340, 4349, 4351, 4353, 4357, 4358, 4368, 4372, 4374, 4377, 4378, 4381, 4385, 4386, 4387, 4390, 4392, 4399, 4405, 4416, 4423, 4430, 4433, 4435, 4442, 4445, 4447, 4456, 4464, 4471, 4478, 4481, 4484, 4488, 4492, 4495, 4498, 4500, 4507, 4510, 4512, 4520, 4528, 4532, 4539, 4541, 4542, 4550, 4553, 4555, 4562, 4567, 4572, 4579, 4580, 4584, 4592, 4596, 4608, 4612, 4614, 4616, 4618, 4620, 4626, 4632, 4634, 4637, 4639, 4641, 4644, 4647, 4649, 4651, 4654, 4656, 4658, 4660, 4664, 4666]
# 4260   0x10a4 sub rsp, 0x18  len 4
# 4264   0x10a8 lea rdi, [rip + 0xf55]  len 7
# 4271   0x10af mov rax, qword ptr fs:[0x28]  len 9
# 4280   0x10b8 mov qword ptr [rsp + 8], rax  len 5
# 4285   0x10bd xor eax, eax  len 2
# 4287   0x10bf lea rsi, [rsp + 4]  len 5
# 4292   0x10c4 mov dword ptr [rsp + 4], 0  len 8
# 4300   0x10cc call 0x1090  len 5
# 4305   0x10d1 mov edi, dword ptr [rsp + 4]  len 4
# 4309   0x10d5 call 0x1200  len 5
# 4314   0x10da lea rsi, [rip + 0xf26]  len 7
# 4321   0x10e1 mov edi, 2  len 5
# 4326   0x10e6 mov edx, eax  len 2
# 4328   0x10e8 xor eax, eax  len 2
# 4330   0x10ea call 0x1080  len 5
# 4335   0x10ef mov rax, qword ptr [rsp + 8]  len 5
# 4340   0x10f4 sub rax, qword ptr fs:[0x28]  len 9
# 4349   0x10fd jne 0x1106  len 2
# 4351   0x10ff xor eax, eax  len 2
# 4353   0x1101 add rsp, 0x18  len 4
# 4357   0x1105 ret   len 1
# 4358   0x1106 <CsInsn 0x1106 [e865ffffff]: call 0x1070>  len 5
#
# Byte GAP ######  10  Missing bytes:  5
# #  4363 nop dword ptr [rax + rax] inst len: 5
# #  4364  invalid
# #  4365 add byte ptr [rax], r8b inst len: 3
# #  4366 add byte ptr [rax], al inst len: 2
# #  4367 add bl, dh inst len: 2
#
#
# 4368   0x1110 endbr64   len 4
# 4372   0x1114 xor ebp, ebp  len 2
# 4374   0x1116 mov r9, rdx  len 3
# 4377   0x1119 pop rsi  len 1
# 4378   0x111a mov rdx, rsp  len 3
# 4381   0x111d and rsp, 0xfffffffffffffff0  len 4
# 4385   0x1121 push rax  len 1
# 4386   0x1122 push rsp  len 1
# 4387   0x1123 xor r8d, r8d  len 3
# 4390   0x1126 xor ecx, ecx  len 2
# 4392   0x1128 lea rdi, [rip - 0x8f]  len 7
# 4399   0x112f call qword ptr [rip + 0x2ea3]  len 6
# 4405   0x1135 <CsInsn 0x1135 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4406 nop word ptr cs:[rax + rax] inst len: 10
# #  4407 nop dword ptr cs:[rax + rax] inst len: 9
# #  4408 nop dword ptr [rax + rax] inst len: 8
# #  4409  invalid
# #  4410 test byte ptr [rax], al inst len: 2
# #  4411 add byte ptr [rax], al inst len: 2
# #  4412 add byte ptr [rax], al inst len: 2
# #  4413 add byte ptr [rax], al inst len: 2
# #  4414 add byte ptr [rax], al inst len: 2
# #  4415 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4416   0x1140 lea rdi, [rip + 0x2ec9]  len 7
# 4423   0x1147 lea rax, [rip + 0x2ec2]  len 7
# 4430   0x114e cmp rax, rdi  len 3
# 4433   0x1151 je 0x1168  len 2
# 4435   0x1153 mov rax, qword ptr [rip + 0x2e86]  len 7
# 4442   0x115a test rax, rax  len 3
# 4445   0x115d je 0x1168  len 2
# 4447   0x115f <CsInsn 0x115f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4449 nop dword ptr [rax] inst len: 7
# #  4450  invalid
# #  4451 add byte ptr [rax], 0 inst len: 3
# #  4452 add byte ptr [rax], al inst len: 2
# #  4453 add byte ptr [rax], al inst len: 2
# #  4454 add byte ptr [rax], al inst len: 2
# #  4455 add bl, al inst len: 2
#
#
# 4456   0x1168 <CsInsn 0x1168 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4457 nop dword ptr [rax] inst len: 7
# #  4458  invalid
# #  4459 add byte ptr [rax], 0 inst len: 3
# #  4460 add byte ptr [rax], al inst len: 2
# #  4461 add byte ptr [rax], al inst len: 2
# #  4462 add byte ptr [rax], al inst len: 2
# #  4463 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4464   0x1170 lea rdi, [rip + 0x2e99]  len 7
# 4471   0x1177 lea rsi, [rip + 0x2e92]  len 7
# 4478   0x117e sub rsi, rdi  len 3
# 4481   0x1181 mov rax, rsi  len 3
# 4484   0x1184 shr rsi, 0x3f  len 4
# 4488   0x1188 sar rax, 3  len 4
# 4492   0x118c add rsi, rax  len 3
# 4495   0x118f sar rsi, 1  len 3
# 4498   0x1192 je 0x11a8  len 2
# 4500   0x1194 mov rax, qword ptr [rip + 0x2e55]  len 7
# 4507   0x119b test rax, rax  len 3
# 4510   0x119e je 0x11a8  len 2
# 4512   0x11a0 <CsInsn 0x11a0 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4514 nop word ptr [rax + rax] inst len: 6
# #  4515 nop dword ptr [rax + rax] inst len: 5
# #  4516  invalid
# #  4517 add byte ptr [rax], r8b inst len: 3
# #  4518 add byte ptr [rax], al inst len: 2
# #  4519 add bl, al inst len: 2
#
#
# 4520   0x11a8 <CsInsn 0x11a8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4521 nop dword ptr [rax] inst len: 7
# #  4522  invalid
# #  4523 add byte ptr [rax], 0 inst len: 3
# #  4524 add byte ptr [rax], al inst len: 2
# #  4525 add byte ptr [rax], al inst len: 2
# #  4526 add byte ptr [rax], al inst len: 2
# #  4527 add bl, dh inst len: 2
#
#
# 4528   0x11b0 endbr64   len 4
# 4532   0x11b4 cmp byte ptr [rip + 0x2e55], 0  len 7
# 4539   0x11bb jne 0x11e8  len 2
# 4541   0x11bd push rbp  len 1
# 4542   0x11be cmp qword ptr [rip + 0x2e32], 0  len 8
# 4550   0x11c6 mov rbp, rsp  len 3
# 4553   0x11c9 je 0x11d7  len 2
# 4555   0x11cb mov rdi, qword ptr [rip + 0x2e36]  len 7
# 4562   0x11d2 call 0x1060  len 5
# 4567   0x11d7 call 0x1140  len 5
# 4572   0x11dc mov byte ptr [rip + 0x2e2d], 1  len 7
# 4579   0x11e3 pop rbp  len 1
# 4580   0x11e4 <CsInsn 0x11e4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4581 nop dword ptr [rax] inst len: 3
# #  4582  invalid
# #  4583 add bl, al inst len: 2
#
#
# 4584   0x11e8 <CsInsn 0x11e8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4585 nop dword ptr [rax] inst len: 7
# #  4586  invalid
# #  4587 add byte ptr [rax], 0 inst len: 3
# #  4588 add byte ptr [rax], al inst len: 2
# #  4589 add byte ptr [rax], al inst len: 2
# #  4590 add byte ptr [rax], al inst len: 2
# #  4591 add bl, dh inst len: 2
#
#
# 4592   0x11f0 endbr64   len 4
# 4596   0x11f4 <CsInsn 0x11f4 [e977ffffff]: jmp 0x1170>  len 5
#
# Byte GAP ######  12  Missing bytes:  7
# #  4601 nop dword ptr [rax] inst len: 7
# #  4602  invalid
# #  4603 add byte ptr [rax], 0 inst len: 3
# #  4604 add byte ptr [rax], al inst len: 2
# #  4605 add byte ptr [rax], al inst len: 2
# #  4606 add byte ptr [rax], al inst len: 2
# #  4607 add bl, dh inst len: 2
#
#
# 4608   0x1200 endbr64   len 4
# 4612   0x1204 test edi, edi  len 2
# 4614   0x1206 je 0x1238  len 2
# 4616   0x1208 xor edx, edx  len 2
# 4618   0x120a xor eax, eax  len 2
# 4620   0x120c mov r8d, 0x1f  len 6
# 4626   0x1212 nop word ptr [rax + rax]  len 6
# 4632   0x1218 mov esi, edi  len 2
# 4634   0x121a mov ecx, r8d  len 3
# 4637   0x121d shr edi, 1  len 2
# 4639   0x121f sub ecx, edx  len 2
# 4641   0x1221 and esi, 1  len 3
# 4644   0x1224 add edx, 1  len 3
# 4647   0x1227 shl esi, cl  len 2
# 4649   0x1229 or eax, esi  len 2
# 4651   0x122b cmp edx, 0x1f  len 3
# 4654   0x122e jg 0x123a  len 2
# 4656   0x1230 test edi, edi  len 2
# 4658   0x1232 jne 0x1218  len 2
# 4660   0x1234 <CsInsn 0x1234 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4661 nop dword ptr [rax] inst len: 3
# #  4662  invalid
# #  4663 add byte ptr [rcx], dh inst len: 2
#
#
# 4664   0x1238 xor eax, eax  len 2
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4224, 4228, 4229, 4236, 4241, 4243, 4246, 4253, 4258, 4263, 4266, 4268, 4275, 4280, 4285, 4288, 4293, 4295, 4302, 4307, 4310, 4315, 4317, 4324, 4329, 4336, 4341, 4343, 4344, 4352, 4356, 4358, 4361, 4362, 4365, 4369, 4370, 4371, 4374, 4376, 4383, 4389, 4400, 4407, 4414, 4417, 4419, 4426, 4429, 4431, 4440, 4448, 4455, 4462, 4465, 4468, 4472, 4476, 4479, 4482, 4484, 4491, 4494, 4496, 4504, 4512, 4516, 4523, 4525, 4526, 4534, 4537, 4539, 4546, 4551, 4556, 4563, 4564, 4568, 4576, 4580]
# 4228   0x1084 push rbx  len 1
# 4229   0x1085 lea rbx, [rip + 0xf78]  len 7
# 4236   0x108c mov edi, 2  len 5
# 4241   0x1091 xor eax, eax  len 2
# 4243   0x1093 mov rdx, rbx  len 3
# 4246   0x1096 lea rsi, [rip + 0xf7c]  len 7
# 4253   0x109d call 0x1060  len 5
# 4258   0x10a2 mov ecx, 0x14  len 5
# 4263   0x10a7 mov rdx, rbx  len 3
# 4266   0x10aa xor eax, eax  len 2
# 4268   0x10ac lea rsi, [rip + 0xf6e]  len 7
# 4275   0x10b3 mov edi, 2  len 5
# 4280   0x10b8 call 0x1060  len 5
# 4285   0x10bd mov rdx, rbx  len 3
# 4288   0x10c0 mov edi, 2  len 5
# 4293   0x10c5 xor eax, eax  len 2
# 4295   0x10c7 lea rsi, [rip + 0xf62]  len 7
# 4302   0x10ce call 0x1060  len 5
# 4307   0x10d3 mov rdx, rbx  len 3
# 4310   0x10d6 mov edi, 2  len 5
# 4315   0x10db xor eax, eax  len 2
# 4317   0x10dd lea rsi, [rip + 0xf57]  len 7
# 4324   0x10e4 call 0x1060  len 5
# 4329   0x10e9 mov rdi, qword ptr [rip + 0x2f20]  len 7
# 4336   0x10f0 call 0x1070  len 5
# 4341   0x10f5 xor eax, eax  len 2
# 4343   0x10f7 pop rbx  len 1
# 4344   0x10f8 <CsInsn 0x10f8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4345 nop dword ptr [rax] inst len: 7
# #  4346  invalid
# #  4347 add byte ptr [rax], 0 inst len: 3
# #  4348 add byte ptr [rax], al inst len: 2
# #  4349 add byte ptr [rax], al inst len: 2
# #  4350 add byte ptr [rax], al inst len: 2
# #  4351 add bl, dh inst len: 2
#
#
# 4352   0x1100 endbr64   len 4
# 4356   0x1104 xor ebp, ebp  len 2
# 4358   0x1106 mov r9, rdx  len 3
# 4361   0x1109 pop rsi  len 1
# 4362   0x110a mov rdx, rsp  len 3
# 4365   0x110d and rsp, 0xfffffffffffffff0  len 4
# 4369   0x1111 push rax  len 1
# 4370   0x1112 push rsp  len 1
# 4371   0x1113 xor r8d, r8d  len 3
# 4374   0x1116 xor ecx, ecx  len 2
# 4376   0x1118 lea rdi, [rip - 0x9f]  len 7
# 4383   0x111f call qword ptr [rip + 0x2eb3]  len 6
# 4389   0x1125 <CsInsn 0x1125 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4390 nop word ptr cs:[rax + rax] inst len: 10
# #  4391 nop dword ptr cs:[rax + rax] inst len: 9
# #  4392 nop dword ptr [rax + rax] inst len: 8
# #  4393  invalid
# #  4394 test byte ptr [rax], al inst len: 2
# #  4395 add byte ptr [rax], al inst len: 2
# #  4396 add byte ptr [rax], al inst len: 2
# #  4397 add byte ptr [rax], al inst len: 2
# #  4398 add byte ptr [rax], al inst len: 2
# #  4399 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4400   0x1130 lea rdi, [rip + 0x2ed9]  len 7
# 4407   0x1137 lea rax, [rip + 0x2ed2]  len 7
# 4414   0x113e cmp rax, rdi  len 3
# 4417   0x1141 je 0x1158  len 2
# 4419   0x1143 mov rax, qword ptr [rip + 0x2e96]  len 7
# 4426   0x114a test rax, rax  len 3
# 4429   0x114d je 0x1158  len 2
# 4431   0x114f <CsInsn 0x114f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4433 nop dword ptr [rax] inst len: 7
# #  4434  invalid
# #  4435 add byte ptr [rax], 0 inst len: 3
# #  4436 add byte ptr [rax], al inst len: 2
# #  4437 add byte ptr [rax], al inst len: 2
# #  4438 add byte ptr [rax], al inst len: 2
# #  4439 add bl, al inst len: 2
#
#
# 4440   0x1158 <CsInsn 0x1158 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4441 nop dword ptr [rax] inst len: 7
# #  4442  invalid
# #  4443 add byte ptr [rax], 0 inst len: 3
# #  4444 add byte ptr [rax], al inst len: 2
# #  4445 add byte ptr [rax], al inst len: 2
# #  4446 add byte ptr [rax], al inst len: 2
# #  4447 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4448   0x1160 lea rdi, [rip + 0x2ea9]  len 7
# 4455   0x1167 lea rsi, [rip + 0x2ea2]  len 7
# 4462   0x116e sub rsi, rdi  len 3
# 4465   0x1171 mov rax, rsi  len 3
# 4468   0x1174 shr rsi, 0x3f  len 4
# 4472   0x1178 sar rax, 3  len 4
# 4476   0x117c add rsi, rax  len 3
# 4479   0x117f sar rsi, 1  len 3
# 4482   0x1182 je 0x1198  len 2
# 4484   0x1184 mov rax, qword ptr [rip + 0x2e65]  len 7
# 4491   0x118b test rax, rax  len 3
# 4494   0x118e je 0x1198  len 2
# 4496   0x1190 <CsInsn 0x1190 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4498 nop word ptr [rax + rax] inst len: 6
# #  4499 nop dword ptr [rax + rax] inst len: 5
# #  4500  invalid
# #  4501 add byte ptr [rax], r8b inst len: 3
# #  4502 add byte ptr [rax], al inst len: 2
# #  4503 add bl, al inst len: 2
#
#
# 4504   0x1198 <CsInsn 0x1198 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4505 nop dword ptr [rax] inst len: 7
# #  4506  invalid
# #  4507 add byte ptr [rax], 0 inst len: 3
# #  4508 add byte ptr [rax], al inst len: 2
# #  4509 add byte ptr [rax], al inst len: 2
# #  4510 add byte ptr [rax], al inst len: 2
# #  4511 add bl, dh inst len: 2
#
#
# 4512   0x11a0 endbr64   len 4
# 4516   0x11a4 cmp byte ptr [rip + 0x2e6d], 0  len 7
# 4523   0x11ab jne 0x11d8  len 2
# 4525   0x11ad push rbp  len 1
# 4526   0x11ae cmp qword ptr [rip + 0x2e42], 0  len 8
# 4534   0x11b6 mov rbp, rsp  len 3
# 4537   0x11b9 je 0x11c7  len 2
# 4539   0x11bb mov rdi, qword ptr [rip + 0x2e46]  len 7
# 4546   0x11c2 call 0x1050  len 5
# 4551   0x11c7 call 0x1130  len 5
# 4556   0x11cc mov byte ptr [rip + 0x2e45], 1  len 7
# 4563   0x11d3 pop rbp  len 1
# 4564   0x11d4 <CsInsn 0x11d4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4565 nop dword ptr [rax] inst len: 3
# #  4566  invalid
# #  4567 add bl, al inst len: 2
#
#
# 4568   0x11d8 <CsInsn 0x11d8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4569 nop dword ptr [rax] inst len: 7
# #  4570  invalid
# #  4571 add byte ptr [rax], 0 inst len: 3
# #  4572 add byte ptr [rax], al inst len: 2
# #  4573 add byte ptr [rax], al inst len: 2
# #  4574 add byte ptr [rax], al inst len: 2
# #  4575 add bl, dh inst len: 2
#
#
# 4576   0x11e0 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4192, 4196, 4197, 4204, 4209, 4211, 4214, 4219, 4224, 4227, 4232, 4234, 4239, 4244, 4246, 4247, 4256, 4260, 4262, 4265, 4266, 4269, 4273, 4274, 4275, 4278, 4280, 4287, 4293, 4304, 4311, 4318, 4321, 4323, 4330, 4333, 4335, 4344, 4352, 4359, 4366, 4369, 4372, 4376, 4380, 4383, 4386, 4388, 4395, 4398, 4400, 4408, 4416, 4420, 4427, 4429, 4430, 4438, 4441, 4443, 4450, 4455, 4460, 4467, 4468, 4472, 4480, 4484]
# 4196   0x1064 push rbx  len 1
# 4197   0x1065 lea rbx, [rip + 0xf98]  len 7
# 4204   0x106c mov edx, 0x11  len 5
# 4209   0x1071 xor eax, eax  len 2
# 4211   0x1073 mov rsi, rbx  len 3
# 4214   0x1076 mov edi, 2  len 5
# 4219   0x107b call 0x1050  len 5
# 4224   0x1080 mov rsi, rbx  len 3
# 4227   0x1083 mov edx, 0x5a  len 5
# 4232   0x1088 xor eax, eax  len 2
# 4234   0x108a mov edi, 2  len 5
# 4239   0x108f call 0x1050  len 5
# 4244   0x1094 xor eax, eax  len 2
# 4246   0x1096 pop rbx  len 1
# 4247   0x1097 <CsInsn 0x1097 [c3]: ret >  len 1
#
# Byte GAP ######  9  Missing bytes:  8
# #  4248 nop dword ptr [rax + rax] inst len: 8
# #  4249  invalid
# #  4250 test byte ptr [rax], al inst len: 2
# #  4251 add byte ptr [rax], al inst len: 2
# #  4252 add byte ptr [rax], al inst len: 2
# #  4253 add byte ptr [rax], al inst len: 2
# #  4254 add byte ptr [rax], al inst len: 2
# #  4255 add bl, dh inst len: 2
#
#
# 4256   0x10a0 endbr64   len 4
# 4260   0x10a4 xor ebp, ebp  len 2
# 4262   0x10a6 mov r9, rdx  len 3
# 4265   0x10a9 pop rsi  len 1
# 4266   0x10aa mov rdx, rsp  len 3
# 4269   0x10ad and rsp, 0xfffffffffffffff0  len 4
# 4273   0x10b1 push rax  len 1
# 4274   0x10b2 push rsp  len 1
# 4275   0x10b3 xor r8d, r8d  len 3
# 4278   0x10b6 xor ecx, ecx  len 2
# 4280   0x10b8 lea rdi, [rip - 0x5f]  len 7
# 4287   0x10bf call qword ptr [rip + 0x2f13]  len 6
# 4293   0x10c5 <CsInsn 0x10c5 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4294 nop word ptr cs:[rax + rax] inst len: 10
# #  4295 nop dword ptr cs:[rax + rax] inst len: 9
# #  4296 nop dword ptr [rax + rax] inst len: 8
# #  4297  invalid
# #  4298 test byte ptr [rax], al inst len: 2
# #  4299 add byte ptr [rax], al inst len: 2
# #  4300 add byte ptr [rax], al inst len: 2
# #  4301 add byte ptr [rax], al inst len: 2
# #  4302 add byte ptr [rax], al inst len: 2
# #  4303 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4304   0x10d0 lea rdi, [rip + 0x2f39]  len 7
# 4311   0x10d7 lea rax, [rip + 0x2f32]  len 7
# 4318   0x10de cmp rax, rdi  len 3
# 4321   0x10e1 je 0x10f8  len 2
# 4323   0x10e3 mov rax, qword ptr [rip + 0x2ef6]  len 7
# 4330   0x10ea test rax, rax  len 3
# 4333   0x10ed je 0x10f8  len 2
# 4335   0x10ef <CsInsn 0x10ef [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4337 nop dword ptr [rax] inst len: 7
# #  4338  invalid
# #  4339 add byte ptr [rax], 0 inst len: 3
# #  4340 add byte ptr [rax], al inst len: 2
# #  4341 add byte ptr [rax], al inst len: 2
# #  4342 add byte ptr [rax], al inst len: 2
# #  4343 add bl, al inst len: 2
#
#
# 4344   0x10f8 <CsInsn 0x10f8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4345 nop dword ptr [rax] inst len: 7
# #  4346  invalid
# #  4347 add byte ptr [rax], 0 inst len: 3
# #  4348 add byte ptr [rax], al inst len: 2
# #  4349 add byte ptr [rax], al inst len: 2
# #  4350 add byte ptr [rax], al inst len: 2
# #  4351 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4352   0x1100 lea rdi, [rip + 0x2f09]  len 7
# 4359   0x1107 lea rsi, [rip + 0x2f02]  len 7
# 4366   0x110e sub rsi, rdi  len 3
# 4369   0x1111 mov rax, rsi  len 3
# 4372   0x1114 shr rsi, 0x3f  len 4
# 4376   0x1118 sar rax, 3  len 4
# 4380   0x111c add rsi, rax  len 3
# 4383   0x111f sar rsi, 1  len 3
# 4386   0x1122 je 0x1138  len 2
# 4388   0x1124 mov rax, qword ptr [rip + 0x2ec5]  len 7
# 4395   0x112b test rax, rax  len 3
# 4398   0x112e je 0x1138  len 2
# 4400   0x1130 <CsInsn 0x1130 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4402 nop word ptr [rax + rax] inst len: 6
# #  4403 nop dword ptr [rax + rax] inst len: 5
# #  4404  invalid
# #  4405 add byte ptr [rax], r8b inst len: 3
# #  4406 add byte ptr [rax], al inst len: 2
# #  4407 add bl, al inst len: 2
#
#
# 4408   0x1138 <CsInsn 0x1138 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4409 nop dword ptr [rax] inst len: 7
# #  4410  invalid
# #  4411 add byte ptr [rax], 0 inst len: 3
# #  4412 add byte ptr [rax], al inst len: 2
# #  4413 add byte ptr [rax], al inst len: 2
# #  4414 add byte ptr [rax], al inst len: 2
# #  4415 add bl, dh inst len: 2
#
#
# 4416   0x1140 endbr64   len 4
# 4420   0x1144 cmp byte ptr [rip + 0x2ec5], 0  len 7
# 4427   0x114b jne 0x1178  len 2
# 4429   0x114d push rbp  len 1
# 4430   0x114e cmp qword ptr [rip + 0x2ea2], 0  len 8
# 4438   0x1156 mov rbp, rsp  len 3
# 4441   0x1159 je 0x1167  len 2
# 4443   0x115b mov rdi, qword ptr [rip + 0x2ea6]  len 7
# 4450   0x1162 call 0x1040  len 5
# 4455   0x1167 call 0x10d0  len 5
# 4460   0x116c mov byte ptr [rip + 0x2e9d], 1  len 7
# 4467   0x1173 pop rbp  len 1
# 4468   0x1174 <CsInsn 0x1174 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4469 nop dword ptr [rax] inst len: 3
# #  4470  invalid
# #  4471 add bl, al inst len: 2
#
#
# 4472   0x1178 <CsInsn 0x1178 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4473 nop dword ptr [rax] inst len: 7
# #  4474  invalid
# #  4475 add byte ptr [rax], 0 inst len: 3
# #  4476 add byte ptr [rax], al inst len: 2
# #  4477 add byte ptr [rax], al inst len: 2
# #  4478 add byte ptr [rax], al inst len: 2
# #  4479 add bl, dh inst len: 2
#
#
# 4480   0x1180 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4192, 4196, 4200, 4205, 4207, 4211, 4224, 4228, 4230, 4233, 4234, 4237, 4241, 4242, 4243, 4246, 4248, 4255, 4261, 4272, 4279, 4286, 4289, 4291, 4298, 4301, 4303, 4312, 4320, 4327, 4334, 4337, 4340, 4344, 4348, 4351, 4354, 4356, 4363, 4366, 4368, 4376, 4384, 4388, 4395, 4397, 4398, 4406, 4409, 4411, 4418, 4423, 4428, 4435, 4436, 4440, 4448, 4452]
# 4196   0x1064 sub rsp, 8  len 4
# 4200   0x1068 call 0x1050  len 5
# 4205   0x106d xor eax, eax  len 2
# 4207   0x106f add rsp, 8  len 4
# 4211   0x1073 <CsInsn 0x1073 [c3]: ret >  len 1
#
# Byte GAP ######  13  Missing bytes:  12
# #  4212 nop word ptr cs:[rax + rax] inst len: 10
# #  4213 nop dword ptr cs:[rax + rax] inst len: 9
# #  4214 nop dword ptr [rax + rax] inst len: 8
# #  4215  invalid
# #  4216 test byte ptr [rax], al inst len: 2
# #  4217 add byte ptr [rax], al inst len: 2
# #  4218 add byte ptr [rax], al inst len: 2
# #  4219 add byte ptr [rax], al inst len: 2
# #  4220 add byte ptr [rax], al inst len: 2
# #  4221 add byte ptr [rsi - 0x70], ah inst len: 3
# #  4222 nop  inst len: 2
# #  4223 nop  inst len: 1
#
#
# 4224   0x1080 endbr64   len 4
# 4228   0x1084 xor ebp, ebp  len 2
# 4230   0x1086 mov r9, rdx  len 3
# 4233   0x1089 pop rsi  len 1
# 4234   0x108a mov rdx, rsp  len 3
# 4237   0x108d and rsp, 0xfffffffffffffff0  len 4
# 4241   0x1091 push rax  len 1
# 4242   0x1092 push rsp  len 1
# 4243   0x1093 xor r8d, r8d  len 3
# 4246   0x1096 xor ecx, ecx  len 2
# 4248   0x1098 lea rdi, [rip - 0x3f]  len 7
# 4255   0x109f call qword ptr [rip + 0x2f33]  len 6
# 4261   0x10a5 <CsInsn 0x10a5 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4262 nop word ptr cs:[rax + rax] inst len: 10
# #  4263 nop dword ptr cs:[rax + rax] inst len: 9
# #  4264 nop dword ptr [rax + rax] inst len: 8
# #  4265  invalid
# #  4266 test byte ptr [rax], al inst len: 2
# #  4267 add byte ptr [rax], al inst len: 2
# #  4268 add byte ptr [rax], al inst len: 2
# #  4269 add byte ptr [rax], al inst len: 2
# #  4270 add byte ptr [rax], al inst len: 2
# #  4271 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4272   0x10b0 lea rdi, [rip + 0x2f59]  len 7
# 4279   0x10b7 lea rax, [rip + 0x2f52]  len 7
# 4286   0x10be cmp rax, rdi  len 3
# 4289   0x10c1 je 0x10d8  len 2
# 4291   0x10c3 mov rax, qword ptr [rip + 0x2f16]  len 7
# 4298   0x10ca test rax, rax  len 3
# 4301   0x10cd je 0x10d8  len 2
# 4303   0x10cf <CsInsn 0x10cf [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4305 nop dword ptr [rax] inst len: 7
# #  4306  invalid
# #  4307 add byte ptr [rax], 0 inst len: 3
# #  4308 add byte ptr [rax], al inst len: 2
# #  4309 add byte ptr [rax], al inst len: 2
# #  4310 add byte ptr [rax], al inst len: 2
# #  4311 add bl, al inst len: 2
#
#
# 4312   0x10d8 <CsInsn 0x10d8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4313 nop dword ptr [rax] inst len: 7
# #  4314  invalid
# #  4315 add byte ptr [rax], 0 inst len: 3
# #  4316 add byte ptr [rax], al inst len: 2
# #  4317 add byte ptr [rax], al inst len: 2
# #  4318 add byte ptr [rax], al inst len: 2
# #  4319 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4320   0x10e0 lea rdi, [rip + 0x2f29]  len 7
# 4327   0x10e7 lea rsi, [rip + 0x2f22]  len 7
# 4334   0x10ee sub rsi, rdi  len 3
# 4337   0x10f1 mov rax, rsi  len 3
# 4340   0x10f4 shr rsi, 0x3f  len 4
# 4344   0x10f8 sar rax, 3  len 4
# 4348   0x10fc add rsi, rax  len 3
# 4351   0x10ff sar rsi, 1  len 3
# 4354   0x1102 je 0x1118  len 2
# 4356   0x1104 mov rax, qword ptr [rip + 0x2ee5]  len 7
# 4363   0x110b test rax, rax  len 3
# 4366   0x110e je 0x1118  len 2
# 4368   0x1110 <CsInsn 0x1110 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4370 nop word ptr [rax + rax] inst len: 6
# #  4371 nop dword ptr [rax + rax] inst len: 5
# #  4372  invalid
# #  4373 add byte ptr [rax], r8b inst len: 3
# #  4374 add byte ptr [rax], al inst len: 2
# #  4375 add bl, al inst len: 2
#
#
# 4376   0x1118 <CsInsn 0x1118 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4377 nop dword ptr [rax] inst len: 7
# #  4378  invalid
# #  4379 add byte ptr [rax], 0 inst len: 3
# #  4380 add byte ptr [rax], al inst len: 2
# #  4381 add byte ptr [rax], al inst len: 2
# #  4382 add byte ptr [rax], al inst len: 2
# #  4383 add bl, dh inst len: 2
#
#
# 4384   0x1120 endbr64   len 4
# 4388   0x1124 cmp byte ptr [rip + 0x2ee5], 0  len 7
# 4395   0x112b jne 0x1158  len 2
# 4397   0x112d push rbp  len 1
# 4398   0x112e cmp qword ptr [rip + 0x2ec2], 0  len 8
# 4406   0x1136 mov rbp, rsp  len 3
# 4409   0x1139 je 0x1147  len 2
# 4411   0x113b mov rdi, qword ptr [rip + 0x2ec6]  len 7
# 4418   0x1142 call 0x1040  len 5
# 4423   0x1147 call 0x10b0  len 5
# 4428   0x114c mov byte ptr [rip + 0x2ebd], 1  len 7
# 4435   0x1153 pop rbp  len 1
# 4436   0x1154 <CsInsn 0x1154 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4437 nop dword ptr [rax] inst len: 3
# #  4438  invalid
# #  4439 add bl, al inst len: 2
#
#
# 4440   0x1158 <CsInsn 0x1158 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4441 nop dword ptr [rax] inst len: 7
# #  4442  invalid
# #  4443 add byte ptr [rax], 0 inst len: 3
# #  4444 add byte ptr [rax], al inst len: 2
# #  4445 add byte ptr [rax], al inst len: 2
# #  4446 add byte ptr [rax], al inst len: 2
# #  4447 add bl, dh inst len: 2
#
#
# 4448   0x1160 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4192, 4196, 4200, 4205, 4210, 4212, 4219, 4224, 4229, 4236, 4238, 4243, 4248, 4253, 4260, 4262, 4267, 4272, 4277, 4284, 4286, 4291, 4296, 4298, 4302, 4304, 4308, 4310, 4313, 4314, 4317, 4321, 4322, 4323, 4326, 4328, 4335, 4341, 4352, 4359, 4366, 4369, 4371, 4378, 4381, 4383, 4392, 4400, 4407, 4414, 4417, 4420, 4424, 4428, 4431, 4434, 4436, 4443, 4446, 4448, 4456, 4464, 4468, 4475, 4477, 4478, 4486, 4489, 4491, 4498, 4503, 4508, 4515, 4516, 4520, 4528, 4532]
# 4196   0x1064 sub rsp, 8  len 4
# 4200   0x1068 mov edx, 0xb  len 5
# 4205   0x106d mov edi, 2  len 5
# 4210   0x1072 xor eax, eax  len 2
# 4212   0x1074 lea rsi, [rip + 0xf89]  len 7
# 4219   0x107b call 0x1050  len 5
# 4224   0x1080 mov edx, 0xb  len 5
# 4229   0x1085 lea rsi, [rip + 0xf7e]  len 7
# 4236   0x108c xor eax, eax  len 2
# 4238   0x108e mov edi, 2  len 5
# 4243   0x1093 call 0x1050  len 5
# 4248   0x1098 mov edx, 0xb  len 5
# 4253   0x109d lea rsi, [rip + 0xf6c]  len 7
# 4260   0x10a4 xor eax, eax  len 2
# 4262   0x10a6 mov edi, 2  len 5
# 4267   0x10ab call 0x1050  len 5
# 4272   0x10b0 mov edx, 0xb  len 5
# 4277   0x10b5 lea rsi, [rip + 0xf5a]  len 7
# 4284   0x10bc xor eax, eax  len 2
# 4286   0x10be mov edi, 2  len 5
# 4291   0x10c3 call 0x1050  len 5
# 4296   0x10c8 xor eax, eax  len 2
# 4298   0x10ca add rsp, 8  len 4
# 4302   0x10ce <CsInsn 0x10ce [c3]: ret >  len 1
#
# Byte GAP ######  2  Missing bytes:  1
# #  4303 nop  inst len: 1
#
#
# 4304   0x10d0 endbr64   len 4
# 4308   0x10d4 xor ebp, ebp  len 2
# 4310   0x10d6 mov r9, rdx  len 3
# 4313   0x10d9 pop rsi  len 1
# 4314   0x10da mov rdx, rsp  len 3
# 4317   0x10dd and rsp, 0xfffffffffffffff0  len 4
# 4321   0x10e1 push rax  len 1
# 4322   0x10e2 push rsp  len 1
# 4323   0x10e3 xor r8d, r8d  len 3
# 4326   0x10e6 xor ecx, ecx  len 2
# 4328   0x10e8 lea rdi, [rip - 0x8f]  len 7
# 4335   0x10ef call qword ptr [rip + 0x2ee3]  len 6
# 4341   0x10f5 <CsInsn 0x10f5 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4342 nop word ptr cs:[rax + rax] inst len: 10
# #  4343 nop dword ptr cs:[rax + rax] inst len: 9
# #  4344 nop dword ptr [rax + rax] inst len: 8
# #  4345  invalid
# #  4346 test byte ptr [rax], al inst len: 2
# #  4347 add byte ptr [rax], al inst len: 2
# #  4348 add byte ptr [rax], al inst len: 2
# #  4349 add byte ptr [rax], al inst len: 2
# #  4350 add byte ptr [rax], al inst len: 2
# #  4351 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4352   0x1100 lea rdi, [rip + 0x2f09]  len 7
# 4359   0x1107 lea rax, [rip + 0x2f02]  len 7
# 4366   0x110e cmp rax, rdi  len 3
# 4369   0x1111 je 0x1128  len 2
# 4371   0x1113 mov rax, qword ptr [rip + 0x2ec6]  len 7
# 4378   0x111a test rax, rax  len 3
# 4381   0x111d je 0x1128  len 2
# 4383   0x111f <CsInsn 0x111f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4385 nop dword ptr [rax] inst len: 7
# #  4386  invalid
# #  4387 add byte ptr [rax], 0 inst len: 3
# #  4388 add byte ptr [rax], al inst len: 2
# #  4389 add byte ptr [rax], al inst len: 2
# #  4390 add byte ptr [rax], al inst len: 2
# #  4391 add bl, al inst len: 2
#
#
# 4392   0x1128 <CsInsn 0x1128 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4393 nop dword ptr [rax] inst len: 7
# #  4394  invalid
# #  4395 add byte ptr [rax], 0 inst len: 3
# #  4396 add byte ptr [rax], al inst len: 2
# #  4397 add byte ptr [rax], al inst len: 2
# #  4398 add byte ptr [rax], al inst len: 2
# #  4399 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4400   0x1130 lea rdi, [rip + 0x2ed9]  len 7
# 4407   0x1137 lea rsi, [rip + 0x2ed2]  len 7
# 4414   0x113e sub rsi, rdi  len 3
# 4417   0x1141 mov rax, rsi  len 3
# 4420   0x1144 shr rsi, 0x3f  len 4
# 4424   0x1148 sar rax, 3  len 4
# 4428   0x114c add rsi, rax  len 3
# 4431   0x114f sar rsi, 1  len 3
# 4434   0x1152 je 0x1168  len 2
# 4436   0x1154 mov rax, qword ptr [rip + 0x2e95]  len 7
# 4443   0x115b test rax, rax  len 3
# 4446   0x115e je 0x1168  len 2
# 4448   0x1160 <CsInsn 0x1160 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4450 nop word ptr [rax + rax] inst len: 6
# #  4451 nop dword ptr [rax + rax] inst len: 5
# #  4452  invalid
# #  4453 add byte ptr [rax], r8b inst len: 3
# #  4454 add byte ptr [rax], al inst len: 2
# #  4455 add bl, al inst len: 2
#
#
# 4456   0x1168 <CsInsn 0x1168 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4457 nop dword ptr [rax] inst len: 7
# #  4458  invalid
# #  4459 add byte ptr [rax], 0 inst len: 3
# #  4460 add byte ptr [rax], al inst len: 2
# #  4461 add byte ptr [rax], al inst len: 2
# #  4462 add byte ptr [rax], al inst len: 2
# #  4463 add bl, dh inst len: 2
#
#
# 4464   0x1170 endbr64   len 4
# 4468   0x1174 cmp byte ptr [rip + 0x2e95], 0  len 7
# 4475   0x117b jne 0x11a8  len 2
# 4477   0x117d push rbp  len 1
# 4478   0x117e cmp qword ptr [rip + 0x2e72], 0  len 8
# 4486   0x1186 mov rbp, rsp  len 3
# 4489   0x1189 je 0x1197  len 2
# 4491   0x118b mov rdi, qword ptr [rip + 0x2e76]  len 7
# 4498   0x1192 call 0x1040  len 5
# 4503   0x1197 call 0x1100  len 5
# 4508   0x119c mov byte ptr [rip + 0x2e6d], 1  len 7
# 4515   0x11a3 pop rbp  len 1
# 4516   0x11a4 <CsInsn 0x11a4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4517 nop dword ptr [rax] inst len: 3
# #  4518  invalid
# #  4519 add bl, al inst len: 2
#
#
# 4520   0x11a8 <CsInsn 0x11a8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4521 nop dword ptr [rax] inst len: 7
# #  4522  invalid
# #  4523 add byte ptr [rax], 0 inst len: 3
# #  4524 add byte ptr [rax], al inst len: 2
# #  4525 add byte ptr [rax], al inst len: 2
# #  4526 add byte ptr [rax], al inst len: 2
# #  4527 add bl, dh inst len: 2
#
#
# 4528   0x11b0 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4256, 4260, 4261, 4268, 4273, 4280, 4281, 4285, 4294, 4299, 4301, 4306, 4311, 4314, 4316, 4323, 4328, 4331, 4333, 4337, 4339, 4344, 4346, 4349, 4351, 4353, 4356, 4358, 4361, 4363, 4368, 4376, 4378, 4379, 4381, 4383, 4385, 4388, 4390, 4392, 4397, 4399, 4402, 4404, 4409, 4414, 4417, 4421, 4423, 4425, 4427, 4432, 4441, 4443, 4447, 4449, 4450, 4451, 4452, 4459, 4464, 4466, 4471, 4473, 4480, 4484, 4486, 4489, 4490, 4493, 4497, 4498, 4499, 4502, 4504, 4511, 4517, 4528, 4535, 4542, 4545, 4547, 4554, 4557, 4559, 4568, 4576, 4583, 4590, 4593, 4596, 4600, 4604, 4607, 4610, 4612, 4619, 4622, 4624, 4632, 4640, 4644, 4651, 4653, 4654, 4662, 4665, 4667, 4674, 4679, 4684, 4691, 4692, 4696, 4704, 4708, 4720, 4724, 4726, 4729, 4731, 4733, 4736, 4738, 4741, 4745, 4747, 4752, 4760, 4762, 4763, 4765, 4767, 4769, 4772, 4774, 4776, 4779, 4784, 4787, 4790, 4791, 4797]
# 4260   0x10a4 push rbp  len 1
# 4261   0x10a5 lea rsi, [rip + 0xf5c]  len 7
# 4268   0x10ac mov edi, 2  len 5
# 4273   0x10b1 lea rbp, [rip + 0xf74]  len 7
# 4280   0x10b8 push rbx  len 1
# 4281   0x10b9 sub rsp, 0x18  len 4
# 4285   0x10bd mov rax, qword ptr fs:[0x28]  len 9
# 4294   0x10c6 mov qword ptr [rsp + 8], rax  len 5
# 4299   0x10cb xor eax, eax  len 2
# 4301   0x10cd call 0x1080  len 5
# 4306   0x10d2 lea rdx, [rsp + 4]  len 5
# 4311   0x10d7 mov rsi, rsp  len 3
# 4314   0x10da xor eax, eax  len 2
# 4316   0x10dc lea rdi, [rip + 0xf44]  len 7
# 4323   0x10e3 call 0x1090  len 5
# 4328   0x10e8 mov ebx, dword ptr [rsp]  len 3
# 4331   0x10eb xor edi, edi  len 2
# 4333   0x10ed cmp ebx, dword ptr [rsp + 4]  len 4
# 4337   0x10f1 jg 0x1164  len 2
# 4339   0x10f3 nop dword ptr [rax + rax]  len 5
# 4344   0x10f8 mov esi, ebx  len 2
# 4346   0x10fa shr esi, 0x1f  len 3
# 4349   0x10fd add esi, ebx  len 2
# 4351   0x10ff sar esi, 1  len 2
# 4353   0x1101 cmp ebx, 3  len 3
# 4356   0x1104 jle 0x1128  len 2
# 4358   0x1106 test bl, 1  len 3
# 4361   0x1109 je 0x113e  len 2
# 4363   0x110b mov ecx, 2  len 5
# 4368   0x1110 <CsInsn 0x1110 [eb0f]: jmp 0x1121>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4370 nop word ptr [rax + rax] inst len: 6
# #  4371 nop dword ptr [rax + rax] inst len: 5
# #  4372  invalid
# #  4373 add byte ptr [rax], r8b inst len: 3
# #  4374 add byte ptr [rax], al inst len: 2
# #  4375 add byte ptr [rcx - 0x6086628], cl inst len: 6
#
#
# 4376   0x1118 mov eax, ebx  len 2
# 4378   0x111a cdq   len 1
# 4379   0x111b idiv ecx  len 2
# 4381   0x111d test edx, edx  len 2
# 4383   0x111f je 0x113e  len 2
# 4385   0x1121 add ecx, 1  len 3
# 4388   0x1124 cmp ecx, esi  len 2
# 4390   0x1126 jle 0x1118  len 2
# 4392   0x1128 mov edi, 2  len 5
# 4397   0x112d mov edx, ebx  len 2
# 4399   0x112f mov rsi, rbp  len 3
# 4402   0x1132 xor eax, eax  len 2
# 4404   0x1134 call 0x1080  len 5
# 4409   0x1139 mov edi, 1  len 5
# 4414   0x113e add ebx, 1  len 3
# 4417   0x1141 cmp dword ptr [rsp + 4], ebx  len 4
# 4421   0x1145 jge 0x10f8  len 2
# 4423   0x1147 test edi, edi  len 2
# 4425   0x1149 je 0x1164  len 2
# 4427   0x114b mov rax, qword ptr [rsp + 8]  len 5
# 4432   0x1150 sub rax, qword ptr fs:[0x28]  len 9
# 4441   0x1159 jne 0x1179  len 2
# 4443   0x115b add rsp, 0x18  len 4
# 4447   0x115f xor eax, eax  len 2
# 4449   0x1161 pop rbx  len 1
# 4450   0x1162 pop rbp  len 1
# 4451   0x1163 ret   len 1
# 4452   0x1164 lea rsi, [rip + 0xec5]  len 7
# 4459   0x116b mov edi, 2  len 5
# 4464   0x1170 xor eax, eax  len 2
# 4466   0x1172 call 0x1080  len 5
# 4471   0x1177 jmp 0x114b  len 2
# 4473   0x1179 <CsInsn 0x1179 [e8f2feffff]: call 0x1070>  len 5
#
# Byte GAP ######  7  Missing bytes:  2
# #  4478 nop  inst len: 2
# #  4479 nop  inst len: 1
#
#
# 4480   0x1180 endbr64   len 4
# 4484   0x1184 xor ebp, ebp  len 2
# 4486   0x1186 mov r9, rdx  len 3
# 4489   0x1189 pop rsi  len 1
# 4490   0x118a mov rdx, rsp  len 3
# 4493   0x118d and rsp, 0xfffffffffffffff0  len 4
# 4497   0x1191 push rax  len 1
# 4498   0x1192 push rsp  len 1
# 4499   0x1193 xor r8d, r8d  len 3
# 4502   0x1196 xor ecx, ecx  len 2
# 4504   0x1198 lea rdi, [rip - 0xff]  len 7
# 4511   0x119f call qword ptr [rip + 0x2e33]  len 6
# 4517   0x11a5 <CsInsn 0x11a5 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4518 nop word ptr cs:[rax + rax] inst len: 10
# #  4519 nop dword ptr cs:[rax + rax] inst len: 9
# #  4520 nop dword ptr [rax + rax] inst len: 8
# #  4521  invalid
# #  4522 test byte ptr [rax], al inst len: 2
# #  4523 add byte ptr [rax], al inst len: 2
# #  4524 add byte ptr [rax], al inst len: 2
# #  4525 add byte ptr [rax], al inst len: 2
# #  4526 add byte ptr [rax], al inst len: 2
# #  4527 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4528   0x11b0 lea rdi, [rip + 0x2e59]  len 7
# 4535   0x11b7 lea rax, [rip + 0x2e52]  len 7
# 4542   0x11be cmp rax, rdi  len 3
# 4545   0x11c1 je 0x11d8  len 2
# 4547   0x11c3 mov rax, qword ptr [rip + 0x2e16]  len 7
# 4554   0x11ca test rax, rax  len 3
# 4557   0x11cd je 0x11d8  len 2
# 4559   0x11cf <CsInsn 0x11cf [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4561 nop dword ptr [rax] inst len: 7
# #  4562  invalid
# #  4563 add byte ptr [rax], 0 inst len: 3
# #  4564 add byte ptr [rax], al inst len: 2
# #  4565 add byte ptr [rax], al inst len: 2
# #  4566 add byte ptr [rax], al inst len: 2
# #  4567 add bl, al inst len: 2
#
#
# 4568   0x11d8 <CsInsn 0x11d8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4569 nop dword ptr [rax] inst len: 7
# #  4570  invalid
# #  4571 add byte ptr [rax], 0 inst len: 3
# #  4572 add byte ptr [rax], al inst len: 2
# #  4573 add byte ptr [rax], al inst len: 2
# #  4574 add byte ptr [rax], al inst len: 2
# #  4575 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4576   0x11e0 lea rdi, [rip + 0x2e29]  len 7
# 4583   0x11e7 lea rsi, [rip + 0x2e22]  len 7
# 4590   0x11ee sub rsi, rdi  len 3
# 4593   0x11f1 mov rax, rsi  len 3
# 4596   0x11f4 shr rsi, 0x3f  len 4
# 4600   0x11f8 sar rax, 3  len 4
# 4604   0x11fc add rsi, rax  len 3
# 4607   0x11ff sar rsi, 1  len 3
# 4610   0x1202 je 0x1218  len 2
# 4612   0x1204 mov rax, qword ptr [rip + 0x2de5]  len 7
# 4619   0x120b test rax, rax  len 3
# 4622   0x120e je 0x1218  len 2
# 4624   0x1210 <CsInsn 0x1210 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4626 nop word ptr [rax + rax] inst len: 6
# #  4627 nop dword ptr [rax + rax] inst len: 5
# #  4628  invalid
# #  4629 add byte ptr [rax], r8b inst len: 3
# #  4630 add byte ptr [rax], al inst len: 2
# #  4631 add bl, al inst len: 2
#
#
# 4632   0x1218 <CsInsn 0x1218 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4633 nop dword ptr [rax] inst len: 7
# #  4634  invalid
# #  4635 add byte ptr [rax], 0 inst len: 3
# #  4636 add byte ptr [rax], al inst len: 2
# #  4637 add byte ptr [rax], al inst len: 2
# #  4638 add byte ptr [rax], al inst len: 2
# #  4639 add bl, dh inst len: 2
#
#
# 4640   0x1220 endbr64   len 4
# 4644   0x1224 cmp byte ptr [rip + 0x2de5], 0  len 7
# 4651   0x122b jne 0x1258  len 2
# 4653   0x122d push rbp  len 1
# 4654   0x122e cmp qword ptr [rip + 0x2dc2], 0  len 8
# 4662   0x1236 mov rbp, rsp  len 3
# 4665   0x1239 je 0x1247  len 2
# 4667   0x123b mov rdi, qword ptr [rip + 0x2dc6]  len 7
# 4674   0x1242 call 0x1060  len 5
# 4679   0x1247 call 0x11b0  len 5
# 4684   0x124c mov byte ptr [rip + 0x2dbd], 1  len 7
# 4691   0x1253 pop rbp  len 1
# 4692   0x1254 <CsInsn 0x1254 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4693 nop dword ptr [rax] inst len: 3
# #  4694  invalid
# #  4695 add bl, al inst len: 2
#
#
# 4696   0x1258 <CsInsn 0x1258 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4697 nop dword ptr [rax] inst len: 7
# #  4698  invalid
# #  4699 add byte ptr [rax], 0 inst len: 3
# #  4700 add byte ptr [rax], al inst len: 2
# #  4701 add byte ptr [rax], al inst len: 2
# #  4702 add byte ptr [rax], al inst len: 2
# #  4703 add bl, dh inst len: 2
#
#
# 4704   0x1260 endbr64   len 4
# 4708   0x1264 <CsInsn 0x1264 [e977ffffff]: jmp 0x11e0>  len 5
#
# Byte GAP ######  12  Missing bytes:  7
# #  4713 nop dword ptr [rax] inst len: 7
# #  4714  invalid
# #  4715 add byte ptr [rax], 0 inst len: 3
# #  4716 add byte ptr [rax], al inst len: 2
# #  4717 add byte ptr [rax], al inst len: 2
# #  4718 add byte ptr [rax], al inst len: 2
# #  4719 add bl, dh inst len: 2
#
#
# 4720   0x1270 endbr64   len 4
# 4724   0x1274 mov esi, edi  len 2
# 4726   0x1276 shr esi, 0x1f  len 3
# 4729   0x1279 add esi, edi  len 2
# 4731   0x127b sar esi, 1  len 2
# 4733   0x127d cmp edi, 3  len 3
# 4736   0x1280 jle 0x12b7  len 2
# 4738   0x1282 mov r8d, edi  len 3
# 4741   0x1285 and r8d, 1  len 4
# 4745   0x1289 je 0x12a8  len 2
# 4747   0x128b mov ecx, 2  len 5
# 4752   0x1290 <CsInsn 0x1290 [eb0f]: jmp 0x12a1>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4754 nop word ptr [rax + rax] inst len: 6
# #  4755 nop dword ptr [rax + rax] inst len: 5
# #  4756  invalid
# #  4757 add byte ptr [rax], r8b inst len: 3
# #  4758 add byte ptr [rax], al inst len: 2
# #  4759 add byte ptr [rcx - 0x6086608], cl inst len: 6
#
#
# 4760   0x1298 mov eax, edi  len 2
# 4762   0x129a cdq   len 1
# 4763   0x129b idiv ecx  len 2
# 4765   0x129d test edx, edx  len 2
# 4767   0x129f je 0x12b0  len 2
# 4769   0x12a1 add ecx, 1  len 3
# 4772   0x12a4 cmp ecx, esi  len 2
# 4774   0x12a6 jle 0x1298  len 2
# 4776   0x12a8 mov eax, r8d  len 3
# 4779   0x12ab <CsInsn 0x12ab [c3]: ret >  len 1
#
# Byte GAP ######  5  Missing bytes:  4
# #  4780 nop dword ptr [rax] inst len: 4
# #  4781  invalid
# #  4782 add byte ptr [rbp + 0x31], al inst len: 4
# #  4783 add byte ptr [rbp + 0x31], al inst len: 3
#
#
# 4784   0x12b0 xor r8d, r8d  len 3
# 4787   0x12b3 mov eax, r8d  len 3
# 4790   0x12b6 ret   len 1
# 4791   0x12b7 mov r8d, 1  len 6
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4256, 4260, 4264, 4271, 4276, 4285, 4290, 4292, 4297, 4302, 4309, 4311, 4316, 4321, 4324, 4331, 4333, 4336, 4340, 4342, 4345, 4347, 4349, 4351, 4353, 4355, 4357, 4359, 4361, 4368, 4370, 4373, 4375, 4382, 4385, 4389, 4391, 4394, 4396, 4398, 4400, 4402, 4404, 4406, 4408, 4410, 4412, 4414, 4421, 4426, 4431, 4436, 4445, 4447, 4449, 4453, 4454, 4464, 4468, 4470, 4473, 4474, 4477, 4481, 4482, 4483, 4486, 4488, 4495, 4501, 4512, 4519, 4526, 4529, 4531, 4538, 4541, 4543, 4552, 4560, 4567, 4574, 4577, 4580, 4584, 4588, 4591, 4594, 4596, 4603, 4606, 4608, 4616, 4624, 4628, 4635, 4637, 4638, 4646, 4649, 4651, 4658, 4663, 4668, 4675, 4676, 4680, 4688, 4692, 4704, 4708, 4711, 4713, 4720, 4723, 4727, 4729, 4732, 4734, 4736, 4738, 4740, 4742, 4744, 4746, 4748, 4752, 4754, 4757, 4759, 4766, 4769, 4773, 4775, 4778, 4780, 4782, 4784, 4786, 4788, 4790, 4792, 4794, 4796]
# 4260   0x10a4 sub rsp, 0x18  len 4
# 4264   0x10a8 lea rsi, [rip + 0xf59]  len 7
# 4271   0x10af mov edi, 2  len 5
# 4276   0x10b4 mov rax, qword ptr fs:[0x28]  len 9
# 4285   0x10bd mov qword ptr [rsp + 8], rax  len 5
# 4290   0x10c2 xor eax, eax  len 2
# 4292   0x10c4 call 0x1080  len 5
# 4297   0x10c9 lea rsi, [rsp + 4]  len 5
# 4302   0x10ce lea rdi, [rip + 0xf52]  len 7
# 4309   0x10d5 xor eax, eax  len 2
# 4311   0x10d7 call 0x1090  len 5
# 4316   0x10dc movsxd rax, dword ptr [rsp + 4]  len 5
# 4321   0x10e1 mov rsi, rax  len 3
# 4324   0x10e4 imul rax, rax, 0x66666667  len 7
# 4331   0x10eb mov edx, esi  len 2
# 4333   0x10ed sar edx, 0x1f  len 3
# 4336   0x10f0 sar rax, 0x22  len 4
# 4340   0x10f4 sub eax, edx  len 2
# 4342   0x10f6 lea ecx, [rax + rax*4]  len 3
# 4345   0x10f9 mov edx, eax  len 2
# 4347   0x10fb mov eax, esi  len 2
# 4349   0x10fd add ecx, ecx  len 2
# 4351   0x10ff sub eax, ecx  len 2
# 4353   0x1101 mov edi, eax  len 2
# 4355   0x1103 or edi, edx  len 2
# 4357   0x1105 je 0x113a  len 2
# 4359   0x1107 xor edi, edi  len 2
# 4361   0x1109 nop dword ptr [rax]  len 7
# 4368   0x1110 add edi, eax  len 2
# 4370   0x1112 movsxd rax, edx  len 3
# 4373   0x1115 mov ecx, edx  len 2
# 4375   0x1117 imul rax, rax, 0x66666667  len 7
# 4382   0x111e sar ecx, 0x1f  len 3
# 4385   0x1121 sar rax, 0x22  len 4
# 4389   0x1125 sub eax, ecx  len 2
# 4391   0x1127 lea esi, [rax + rax*4]  len 3
# 4394   0x112a mov ecx, eax  len 2
# 4396   0x112c mov eax, edx  len 2
# 4398   0x112e add esi, esi  len 2
# 4400   0x1130 mov edx, ecx  len 2
# 4402   0x1132 sub eax, esi  len 2
# 4404   0x1134 mov esi, eax  len 2
# 4406   0x1136 or esi, ecx  len 2
# 4408   0x1138 jne 0x1110  len 2
# 4410   0x113a mov edx, edi  len 2
# 4412   0x113c xor eax, eax  len 2
# 4414   0x113e lea rsi, [rip + 0xee5]  len 7
# 4421   0x1145 mov edi, 2  len 5
# 4426   0x114a call 0x1080  len 5
# 4431   0x114f mov rax, qword ptr [rsp + 8]  len 5
# 4436   0x1154 sub rax, qword ptr fs:[0x28]  len 9
# 4445   0x115d jne 0x1166  len 2
# 4447   0x115f xor eax, eax  len 2
# 4449   0x1161 add rsp, 0x18  len 4
# 4453   0x1165 ret   len 1
# 4454   0x1166 <CsInsn 0x1166 [e805ffffff]: call 0x1070>  len 5
#
# ...
# 4421   0x1145 <CsInsn 0x1145 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4422 nop word ptr cs:[rax + rax] inst len: 10
# #  4423 nop dword ptr cs:[rax + rax] inst len: 9
# #  4424 nop dword ptr [rax + rax] inst len: 8
# #  4425  invalid
# #  4426 test byte ptr [rax], al inst len: 2
# #  4427 add byte ptr [rax], al inst len: 2
# #  4428 add byte ptr [rax], al inst len: 2
# #  4429 add byte ptr [rax], al inst len: 2
# #  4430 add byte ptr [rax], al inst len: 2
# #  4431 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4432   0x1150 lea rdi, [rip + 0x2eb9]  len 7
# 4439   0x1157 lea rax, [rip + 0x2eb2]  len 7
# 4446   0x115e cmp rax, rdi  len 3
# 4449   0x1161 je 0x1178  len 2
# 4451   0x1163 mov rax, qword ptr [rip + 0x2e76]  len 7
# 4458   0x116a test rax, rax  len 3
# 4461   0x116d je 0x1178  len 2
# 4463   0x116f <CsInsn 0x116f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4465 nop dword ptr [rax] inst len: 7
# #  4466  invalid
# #  4467 add byte ptr [rax], 0 inst len: 3
# #  4468 add byte ptr [rax], al inst len: 2
# #  4469 add byte ptr [rax], al inst len: 2
# #  4470 add byte ptr [rax], al inst len: 2
# #  4471 add bl, al inst len: 2
#
#
# 4472   0x1178 <CsInsn 0x1178 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4473 nop dword ptr [rax] inst len: 7
# #  4474  invalid
# #  4475 add byte ptr [rax], 0 inst len: 3
# #  4476 add byte ptr [rax], al inst len: 2
# #  4477 add byte ptr [rax], al inst len: 2
# #  4478 add byte ptr [rax], al inst len: 2
# #  4479 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4480   0x1180 lea rdi, [rip + 0x2e89]  len 7
# 4487   0x1187 lea rsi, [rip + 0x2e82]  len 7
# 4494   0x118e sub rsi, rdi  len 3
# 4497   0x1191 mov rax, rsi  len 3
# 4500   0x1194 shr rsi, 0x3f  len 4
# 4504   0x1198 sar rax, 3  len 4
# 4508   0x119c add rsi, rax  len 3
# 4511   0x119f sar rsi, 1  len 3
# 4514   0x11a2 je 0x11b8  len 2
# 4516   0x11a4 mov rax, qword ptr [rip + 0x2e45]  len 7
# 4523   0x11ab test rax, rax  len 3
# 4526   0x11ae je 0x11b8  len 2
# 4528   0x11b0 <CsInsn 0x11b0 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4530 nop word ptr [rax + rax] inst len: 6
# #  4531 nop dword ptr [rax + rax] inst len: 5
# #  4532  invalid
# #  4533 add byte ptr [rax], r8b inst len: 3
# #  4534 add byte ptr [rax], al inst len: 2
# #  4535 add bl, al inst len: 2
#
#
# 4536   0x11b8 <CsInsn 0x11b8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4537 nop dword ptr [rax] inst len: 7
# #  4538  invalid
# #  4539 add byte ptr [rax], 0 inst len: 3
# #  4540 add byte ptr [rax], al inst len: 2
# #  4541 add byte ptr [rax], al inst len: 2
# #  4542 add byte ptr [rax], al inst len: 2
# #  4543 add bl, dh inst len: 2
#
#
# 4544   0x11c0 endbr64   len 4
# 4548   0x11c4 cmp byte ptr [rip + 0x2e45], 0  len 7
# 4555   0x11cb jne 0x11f8  len 2
# 4557   0x11cd push rbp  len 1
# 4558   0x11ce cmp qword ptr [rip + 0x2e22], 0  len 8
# 4566   0x11d6 mov rbp, rsp  len 3
# 4569   0x11d9 je 0x11e7  len 2
# 4571   0x11db mov rdi, qword ptr [rip + 0x2e26]  len 7
# 4578   0x11e2 call 0x1060  len 5
# 4583   0x11e7 call 0x1150  len 5
# 4588   0x11ec mov byte ptr [rip + 0x2e1d], 1  len 7
# 4595   0x11f3 pop rbp  len 1
# 4596   0x11f4 <CsInsn 0x11f4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4597 nop dword ptr [rax] inst len: 3
# #  4598  invalid
# #  4599 add bl, al inst len: 2
#
#
# 4600   0x11f8 <CsInsn 0x11f8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4601 nop dword ptr [rax] inst len: 7
# #  4602  invalid
# #  4603 add byte ptr [rax], 0 inst len: 3
# #  4604 add byte ptr [rax], al inst len: 2
# #  4605 add byte ptr [rax], al inst len: 2
# #  4606 add byte ptr [rax], al inst len: 2
# #  4607 add bl, dh inst len: 2
#
#
# 4608   0x1200 endbr64   len 4
# 4612   0x1204 <CsInsn 0x1204 [e977ffffff]: jmp 0x1180>  len 5
#
# Byte GAP ######  12  Missing bytes:  7
# #  4617 nop dword ptr [rax] inst len: 7
# #  4618  invalid
# #  4619 add byte ptr [rax], 0 inst len: 3
# #  4620 add byte ptr [rax], al inst len: 2
# #  4621 add byte ptr [rax], al inst len: 2
# #  4622 add byte ptr [rax], al inst len: 2
# #  4623 add bl, dh inst len: 2
#
#
# 4624   0x1210 endbr64   len 4
# 4628   0x1214 lea edx, [rdi + rsi]  len 3
# 4631   0x1217 xor eax, eax  len 2
# 4633   0x1219 lea rsi, [rip + 0xdfa]  len 7
# 4640   0x1220 mov edi, 2  len 5
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4224, 4228, 4232, 4239, 4244, 4246, 4248, 4251, 4256, 4259, 4264, 4271, 4276, 4279, 4281, 4283, 4290, 4294, 4296, 4301, 4306, 4312, 4319, 4324, 4329, 4331, 4335, 4336, 4340, 4342, 4345, 4346, 4349, 4353, 4354, 4355, 4358, 4360, 4367, 4373, 4384, 4391, 4398, 4401, 4403, 4410, 4413, 4415, 4424, 4432, 4439, 4446, 4449, 4452, 4456, 4460, 4463, 4466, 4468, 4475, 4478, 4480, 4488, 4496, 4500, 4507, 4509, 4510, 4518, 4521, 4523, 4530, 4535, 4540, 4547, 4548, 4552, 4560, 4564]
# 4228   0x1084 sub rsp, 8  len 4
# 4232   0x1088 mov rdi, qword ptr [rip + 0x2f91]  len 7
# 4239   0x108f call 0x1070  len 5
# 4244   0x1094 cmp al, 0xa  len 2
# 4246   0x1096 je 0x10d8  len 2
# 4248   0x1098 movsx edi, al  len 3
# 4251   0x109b <CsInsn 0x109b [eb1e]: jmp 0x10bb>  len 2
#
# Byte GAP ######  5  Missing bytes:  3
# #  4253 nop dword ptr [rax] inst len: 3
# #  4254  invalid
# #  4255 add byte ptr [rbx - 0x4717fe39], al inst len: 6
#
#
# 4256   0x10a0 add edi, 1  len 3
# 4259   0x10a3 call 0x1060  len 5
# 4264   0x10a8 mov rdi, qword ptr [rip + 0x2f71]  len 7
# 4271   0x10af call 0x1070  len 5
# 4276   0x10b4 movsx edi, al  len 3
# 4279   0x10b7 cmp al, 0xa  len 2
# 4281   0x10b9 je 0x10d8  len 2
# 4283   0x10bb mov rsi, qword ptr [rip + 0x2f4e]  len 7
# 4290   0x10c2 cmp dil, 0x20  len 4
# 4294   0x10c6 jne 0x10a0  len 2
# 4296   0x10c8 mov edi, 0x20  len 5
# 4301   0x10cd call 0x1060  len 5
# 4306   0x10d2 <CsInsn 0x10d2 [ebd4]: jmp 0x10a8>  len 2
#
# Byte GAP ######  6  Missing bytes:  4
# #  4308 nop dword ptr [rax] inst len: 4
# #  4309  invalid
# #  4310 add byte ptr [rax - 0x75], cl inst len: 4
# #  4311 add byte ptr [rax - 0x75], cl inst len: 3
#
#
# 4312   0x10d8 mov rsi, qword ptr [rip + 0x2f31]  len 7
# 4319   0x10df mov edi, 0xa  len 5
# 4324   0x10e4 call 0x1060  len 5
# 4329   0x10e9 xor eax, eax  len 2
# 4331   0x10eb add rsp, 8  len 4
# 4335   0x10ef ret   len 1
# 4336   0x10f0 endbr64   len 4
# 4340   0x10f4 xor ebp, ebp  len 2
# 4342   0x10f6 mov r9, rdx  len 3
# 4345   0x10f9 pop rsi  len 1
# 4346   0x10fa mov rdx, rsp  len 3
# 4349   0x10fd and rsp, 0xfffffffffffffff0  len 4
# 4353   0x1101 push rax  len 1
# 4354   0x1102 push rsp  len 1
# 4355   0x1103 xor r8d, r8d  len 3
# 4358   0x1106 xor ecx, ecx  len 2
# 4360   0x1108 lea rdi, [rip - 0x8f]  len 7
# 4367   0x110f call qword ptr [rip + 0x2ec3]  len 6
# 4373   0x1115 <CsInsn 0x1115 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4374 nop word ptr cs:[rax + rax] inst len: 10
# #  4375 nop dword ptr cs:[rax + rax] inst len: 9
# #  4376 nop dword ptr [rax + rax] inst len: 8
# #  4377  invalid
# #  4378 test byte ptr [rax], al inst len: 2
# #  4379 add byte ptr [rax], al inst len: 2
# #  4380 add byte ptr [rax], al inst len: 2
# #  4381 add byte ptr [rax], al inst len: 2
# #  4382 add byte ptr [rax], al inst len: 2
# #  4383 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4384   0x1120 lea rdi, [rip + 0x2ee9]  len 7
# 4391   0x1127 lea rax, [rip + 0x2ee2]  len 7
# 4398   0x112e cmp rax, rdi  len 3
# 4401   0x1131 je 0x1148  len 2
# 4403   0x1133 mov rax, qword ptr [rip + 0x2ea6]  len 7
# 4410   0x113a test rax, rax  len 3
# 4413   0x113d je 0x1148  len 2
# 4415   0x113f <CsInsn 0x113f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4417 nop dword ptr [rax] inst len: 7
# #  4418  invalid
# #  4419 add byte ptr [rax], 0 inst len: 3
# #  4420 add byte ptr [rax], al inst len: 2
# #  4421 add byte ptr [rax], al inst len: 2
# #  4422 add byte ptr [rax], al inst len: 2
# #  4423 add bl, al inst len: 2
#
#
# 4424   0x1148 <CsInsn 0x1148 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4425 nop dword ptr [rax] inst len: 7
# #  4426  invalid
# #  4427 add byte ptr [rax], 0 inst len: 3
# #  4428 add byte ptr [rax], al inst len: 2
# #  4429 add byte ptr [rax], al inst len: 2
# #  4430 add byte ptr [rax], al inst len: 2
# #  4431 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4432   0x1150 lea rdi, [rip + 0x2eb9]  len 7
# 4439   0x1157 lea rsi, [rip + 0x2eb2]  len 7
# 4446   0x115e sub rsi, rdi  len 3
# 4449   0x1161 mov rax, rsi  len 3
# 4452   0x1164 shr rsi, 0x3f  len 4
# 4456   0x1168 sar rax, 3  len 4
# 4460   0x116c add rsi, rax  len 3
# 4463   0x116f sar rsi, 1  len 3
# 4466   0x1172 je 0x1188  len 2
# 4468   0x1174 mov rax, qword ptr [rip + 0x2e75]  len 7
# 4475   0x117b test rax, rax  len 3
# 4478   0x117e je 0x1188  len 2
# 4480   0x1180 <CsInsn 0x1180 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4482 nop word ptr [rax + rax] inst len: 6
# #  4483 nop dword ptr [rax + rax] inst len: 5
# #  4484  invalid
# #  4485 add byte ptr [rax], r8b inst len: 3
# #  4486 add byte ptr [rax], al inst len: 2
# #  4487 add bl, al inst len: 2
#
#
# 4488   0x1188 <CsInsn 0x1188 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4489 nop dword ptr [rax] inst len: 7
# #  4490  invalid
# #  4491 add byte ptr [rax], 0 inst len: 3
# #  4492 add byte ptr [rax], al inst len: 2
# #  4493 add byte ptr [rax], al inst len: 2
# #  4494 add byte ptr [rax], al inst len: 2
# #  4495 add bl, dh inst len: 2
#
#
# 4496   0x1190 endbr64   len 4
# 4500   0x1194 cmp byte ptr [rip + 0x2e8d], 0  len 7
# 4507   0x119b jne 0x11c8  len 2
# 4509   0x119d push rbp  len 1
# 4510   0x119e cmp qword ptr [rip + 0x2e52], 0  len 8
# 4518   0x11a6 mov rbp, rsp  len 3
# 4521   0x11a9 je 0x11b7  len 2
# 4523   0x11ab mov rdi, qword ptr [rip + 0x2e56]  len 7
# 4530   0x11b2 call 0x1050  len 5
# 4535   0x11b7 call 0x1120  len 5
# 4540   0x11bc mov byte ptr [rip + 0x2e65], 1  len 7
# 4547   0x11c3 pop rbp  len 1
# 4548   0x11c4 <CsInsn 0x11c4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4549 nop dword ptr [rax] inst len: 3
# #  4550  invalid
# #  4551 add bl, al inst len: 2
#
#
# 4552   0x11c8 <CsInsn 0x11c8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4553 nop dword ptr [rax] inst len: 7
# #  4554  invalid
# #  4555 add byte ptr [rax], 0 inst len: 3
# #  4556 add byte ptr [rax], al inst len: 2
# #  4557 add byte ptr [rax], al inst len: 2
# #  4558 add byte ptr [rax], al inst len: 2
# #  4559 add bl, dh inst len: 2
#
#
# 4560   0x11d0 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# [4256, 4260, 4264, 4271, 4276, 4285, 4290, 4292, 4297, 4302, 4309, 4311, 4316, 4321, 4326, 4334, 4340, 4347, 4351, 4356, 4361, 4370, 4372, 4374, 4378, 4379, 4384, 4388, 4390, 4393, 4394, 4397, 4401, 4402, 4403, 4406, 4408, 4415, 4421, 4432, 4439, 4446, 4449, 4451, 4458, 4461, 4463, 4472, 4480, 4487, 4494, 4497, 4500, 4504, 4508, 4511, 4514, 4516, 4523, 4526, 4528, 4536, 4544, 4548, 4555, 4557, 4558, 4566, 4569, 4571, 4578, 4583, 4588, 4595, 4596, 4600, 4608, 4612]
# 4260   0x10a4 sub rsp, 0x18  len 4
# 4264   0x10a8 lea rsi, [rip + 0xf59]  len 7
# 4271   0x10af mov edi, 2  len 5
# 4276   0x10b4 mov rax, qword ptr fs:[0x28]  len 9
# 4285   0x10bd mov qword ptr [rsp + 8], rax  len 5
# 4290   0x10c2 xor eax, eax  len 2
# 4292   0x10c4 call 0x1080  len 5
# 4297   0x10c9 lea rsi, [rsp + 4]  len 5
# 4302   0x10ce lea rdi, [rip + 0xf45]  len 7
# 4309   0x10d5 xor eax, eax  len 2
# 4311   0x10d7 call 0x1090  len 5
# 4316   0x10dc mov edi, 2  len 5
# 4321   0x10e1 mov eax, 1  len 5
# 4326   0x10e6 movss xmm0, dword ptr [rip + 0xf16]  len 8
# 4334   0x10ee mulss xmm0, dword ptr [rsp + 4]  len 6
# 4340   0x10f4 lea rsi, [rip + 0xf22]  len 7
# 4347   0x10fb cvtss2sd xmm0, xmm0  len 4
# 4351   0x10ff call 0x1080  len 5
# 4356   0x1104 mov rax, qword ptr [rsp + 8]  len 5
# 4361   0x1109 sub rax, qword ptr fs:[0x28]  len 9
# 4370   0x1112 jne 0x111b  len 2
# 4372   0x1114 xor eax, eax  len 2
# 4374   0x1116 add rsp, 0x18  len 4
# 4378   0x111a ret   len 1
# 4379   0x111b call 0x1070  len 5
# 4384   0x1120 endbr64   len 4
# 4388   0x1124 xor ebp, ebp  len 2
# 4390   0x1126 mov r9, rdx  len 3
# 4393   0x1129 pop rsi  len 1
# 4394   0x112a mov rdx, rsp  len 3
# 4397   0x112d and rsp, 0xfffffffffffffff0  len 4
# 4401   0x1131 push rax  len 1
# 4402   0x1132 push rsp  len 1
# 4403   0x1133 xor r8d, r8d  len 3
# 4406   0x1136 xor ecx, ecx  len 2
# 4408   0x1138 lea rdi, [rip - 0x9f]  len 7
# 4415   0x113f call qword ptr [rip + 0x2e93]  len 6
# 4421   0x1145 <CsInsn 0x1145 [f4]: hlt >  len 1
#
# Byte GAP ######  11  Missing bytes:  10
# #  4422 nop word ptr cs:[rax + rax] inst len: 10
# #  4423 nop dword ptr cs:[rax + rax] inst len: 9
# #  4424 nop dword ptr [rax + rax] inst len: 8
# #  4425  invalid
# #  4426 test byte ptr [rax], al inst len: 2
# #  4427 add byte ptr [rax], al inst len: 2
# #  4428 add byte ptr [rax], al inst len: 2
# #  4429 add byte ptr [rax], al inst len: 2
# #  4430 add byte ptr [rax], al inst len: 2
# #  4431 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4432   0x1150 lea rdi, [rip + 0x2eb9]  len 7
# 4439   0x1157 lea rax, [rip + 0x2eb2]  len 7
# 4446   0x115e cmp rax, rdi  len 3
# 4449   0x1161 je 0x1178  len 2
# 4451   0x1163 mov rax, qword ptr [rip + 0x2e76]  len 7
# 4458   0x116a test rax, rax  len 3
# 4461   0x116d je 0x1178  len 2
# 4463   0x116f <CsInsn 0x116f [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  9  Missing bytes:  7
# #  4465 nop dword ptr [rax] inst len: 7
# #  4466  invalid
# #  4467 add byte ptr [rax], 0 inst len: 3
# #  4468 add byte ptr [rax], al inst len: 2
# #  4469 add byte ptr [rax], al inst len: 2
# #  4470 add byte ptr [rax], al inst len: 2
# #  4471 add bl, al inst len: 2
#
#
# 4472   0x1178 <CsInsn 0x1178 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4473 nop dword ptr [rax] inst len: 7
# #  4474  invalid
# #  4475 add byte ptr [rax], 0 inst len: 3
# #  4476 add byte ptr [rax], al inst len: 2
# #  4477 add byte ptr [rax], al inst len: 2
# #  4478 add byte ptr [rax], al inst len: 2
# #  4479 add byte ptr [rax - 0x73], cl inst len: 3
#
#
# 4480   0x1180 lea rdi, [rip + 0x2e89]  len 7
# 4487   0x1187 lea rsi, [rip + 0x2e82]  len 7
# 4494   0x118e sub rsi, rdi  len 3
# 4497   0x1191 mov rax, rsi  len 3
# 4500   0x1194 shr rsi, 0x3f  len 4
# 4504   0x1198 sar rax, 3  len 4
# 4508   0x119c add rsi, rax  len 3
# 4511   0x119f sar rsi, 1  len 3
# 4514   0x11a2 je 0x11b8  len 2
# 4516   0x11a4 mov rax, qword ptr [rip + 0x2e45]  len 7
# 4523   0x11ab test rax, rax  len 3
# 4526   0x11ae je 0x11b8  len 2
# 4528   0x11b0 <CsInsn 0x11b0 [ffe0]: jmp rax>  len 2
#
# Byte GAP ######  8  Missing bytes:  6
# #  4530 nop word ptr [rax + rax] inst len: 6
# #  4531 nop dword ptr [rax + rax] inst len: 5
# #  4532  invalid
# #  4533 add byte ptr [rax], r8b inst len: 3
# #  4534 add byte ptr [rax], al inst len: 2
# #  4535 add bl, al inst len: 2
#
#
# 4536   0x11b8 <CsInsn 0x11b8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4537 nop dword ptr [rax] inst len: 7
# #  4538  invalid
# #  4539 add byte ptr [rax], 0 inst len: 3
# #  4540 add byte ptr [rax], al inst len: 2
# #  4541 add byte ptr [rax], al inst len: 2
# #  4542 add byte ptr [rax], al inst len: 2
# #  4543 add bl, dh inst len: 2
#
#
# 4544   0x11c0 endbr64   len 4
# 4548   0x11c4 cmp byte ptr [rip + 0x2e45], 0  len 7
# 4555   0x11cb jne 0x11f8  len 2
# 4557   0x11cd push rbp  len 1
# 4558   0x11ce cmp qword ptr [rip + 0x2e22], 0  len 8
# 4566   0x11d6 mov rbp, rsp  len 3
# 4569   0x11d9 je 0x11e7  len 2
# 4571   0x11db mov rdi, qword ptr [rip + 0x2e26]  len 7
# 4578   0x11e2 call 0x1060  len 5
# 4583   0x11e7 call 0x1150  len 5
# 4588   0x11ec mov byte ptr [rip + 0x2e1d], 1  len 7
# 4595   0x11f3 pop rbp  len 1
# 4596   0x11f4 <CsInsn 0x11f4 [c3]: ret >  len 1
#
# Byte GAP ######  4  Missing bytes:  3
# #  4597 nop dword ptr [rax] inst len: 3
# #  4598  invalid
# #  4599 add bl, al inst len: 2
#
#
# 4600   0x11f8 <CsInsn 0x11f8 [c3]: ret >  len 1
#
# Byte GAP ######  8  Missing bytes:  7
# #  4601 nop dword ptr [rax] inst len: 7
# #  4602  invalid
# #  4603 add byte ptr [rax], 0 inst len: 3
# #  4604 add byte ptr [rax], al inst len: 2
# #  4605 add byte ptr [rax], al inst len: 2
# #  4606 add byte ptr [rax], al inst len: 2
# #  4607 add bl, dh inst len: 2
#
#
# 4608   0x1200 endbr64   len 4
#
#  # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
print('test')
