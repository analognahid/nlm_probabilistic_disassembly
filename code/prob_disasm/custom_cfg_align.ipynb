# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd
from collections import defaultdict

# %%
MAX_ITERATIONS = 10000  # Prevent infinite looping

# %%
# BIN_FILE_TYPE = 'PE' #or ELF
# bin_path = '/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
# bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")]
# ground_truth_path ='/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  


BIN_FILE_TYPE = 'ELF'
bin_path = '/home/raisul/DATA/x86_O2_d4/' #/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [f for f in os.listdir(bin_path) ]
ground_truth_path ='/home/raisul/ANALYSED_DATA/ghidra_x86_O2_d4/'

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
for bin_file_path in bin_files[1:2]:#[1:1000]:

    if BIN_FILE_TYPE == "ELF":
        bin_file_path = os.path.join(bin_path , bin_file_path)
    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    
    with open(bin_file_path, 'rb') as f:

        
        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":

                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            # if len(ground_truth_offsets)<5000:
            #     print(len(ground_truth_offsets))
            #     continue
            # else:
            #     print('found')
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue

    inst_sizes = {}
    for byte_index in range(len(textSection)):
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            offset_inst[text_section_offset+byte_index] = instruction
            inst_sizes [text_section_offset+byte_index] = instruction.size if instruction else None
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                
                
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )



                    

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))

    DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)


    code_boundary = text_section_offset+len(textSection)
    break

disasm  = offset_inst_dict

# %%
min_offset, max_offset = list(disasm.keys())[0] , list(disasm.keys())[-1] 
print(min_offset, max_offset )
# Out:
# 4256 5291

# %%
# CONTROL_GROUPS = {
#     CS_GRP_JUMP,
#     CS_GRP_CALL,
#     CS_GRP_RET,
#     CS_GRP_IRET,
# }

# for key,val in disasm.items():
#     # print(val.groups)
#     if val == None:
#         continue
#     for group in val.groups:
#         if group in CONTROL_GROUPS:
#             print(f"0x{val.address:x}: {val.mnemonic} {val.op_str}")

# %%
# CONTROL_GROUPS ={"CALL", "COND_BR", "UNCOND_BR", "RET"}
CONTROL_GROUPS = {
    CS_GRP_JUMP,
    CS_GRP_CALL,
    CS_GRP_RET,
    CS_GRP_IRET,
}
BRANCH_GROUPS = {
    CS_GRP_CALL,       # Function call instruction
    CS_GRP_JUMP       # Conditional and unconditional branches
}

def _compute_destinations(disasm):
    """ Compute successor addresses (CFG) and ensure function epilogues are correctly identified. """
    dests, preds = {}, defaultdict(list)
    last_offset = list(disasm.keys())[-1]
    first_offset = list(disasm.keys())[0]

    for offset, details in disasm.items():
        if details==None:
            continue
        inst_str = details.mnemonic +' ' + details.op_str
        next_offset = offset + details.size



        if not set(details.groups) & CONTROL_GROUPS:
            # Default fallthrough for non-control flow instructions
            if next_offset <= last_offset:
                dests[offset] = [next_offset]
                # preds[next_offset].append(offset)
            else:
                dests[offset] = []
        else: #control instruction
            #unconditional jump
            if details.id == X86_INS_JMP and details.operands and details.operands[0].type == CS_OP_IMM:
                 # Unconditional jump
                op_value = details.operands[0].imm
                if op_value>=first_offset and op_value<=last_offset:
                    dests[offset] = [op_value]
                    # preds[op_value].append(offset)
            
            # elif "COND_BR" in details.groups or "CALL" in details.groups:
            elif (CS_GRP_JUMP in details.groups or CS_GRP_CALL in details.groups) :
                if details.operands and details.operands[0].type == CS_OP_IMM:
                    jump_target = details.operands[0].imm
    
                    if next_offset<=last_offset:
                        dests[offset] = [next_offset]
                        # preds[next_offset].append(offset)
                                     
                    if jump_target>=first_offset and jump_target<=last_offset and jump_target!=next_offset:
                        if offset in dests:
                            dests[offset].append(jump_target)
                        else:
                            dests[offset] = [jump_target]
        
            else:
                # print('>>>>>  ',offset, ' : ' ,inst_str)
                dests[offset] = None

        if offset in dests:
            if dests[offset] is not None:
                for target in dests[offset]:
                    preds[target].append(offset)

    return dests, preds

cfg, preds = _compute_destinations(disasm)
cfg = dict(sorted(cfg.items()))
preds = dict(sorted(preds.items()))

# def has_duplicates(lst):
#     return len(lst) != len(set(lst))

# for offset ,inst in disasm.items():
#     if inst:
#         print(offset," : ", hex(offset), ' ' ,inst.mnemonic +' ' + inst.op_str , '   ',inst.size)
#         if offset in cfg:
#             print('cfg ',cfg[offset])
#         if offset in preds:
#             print('pred ',preds[offset])

# %%
def _compute_occlusion(disasm):
    """ Identify overlapping instructions and remove """
    occlusion = defaultdict(list)
    valid_instructions = set()

    for offset, details in disasm.items():
        if details!= None:
            for i in range(offset + 1, offset + details.size):
                occlusion[i].append(offset)

    # fix nahid
    covered = set()
    for offset in sorted(disasm.keys()):
        if disasm[offset] is None:
            continue
        if offset in covered:
            # print(f"Skipping {offset} due to occlusion")
            continue  # Skip if another instruction already claimed this byte

        valid_instructions.add(offset)
        for i in range(offset, offset + disasm[offset].size):
            covered.add(i)  # Mark all bytes of this instruction as covered

    # print(f"Final valid instructions after occlusion: {sorted(valid_instructions)}")
    return occlusion, valid_instructions
occlusion_space, valid_instructions =_compute_occlusion(disasm)

# %%
# valid_instructions

# %%
# ALL_RD_CFG = {}


                
# def get_recursive_descent_cfg(disasm):
#     debug = False
#     global ALL_RD_CFG

#     for offset in disasm:
#         if debug:
#             print('\n-------------------------------------------------------\n')
#         RD_CFG = []
#         current = offset
#         while True:

#             print('current: ',current)

#             #prevent cycle
#             if current in RD_CFG:
#                 break
#             #out of bound
#             if current not in disasm:
#                 break
#             #current invalid
#             if disasm[current] is None:
#                 break
#             #return
#             if disasm[current].mnemonic in ["ret"]:
#                 break
            

                
#             #non control instruction
#             if len(set(disasm[current].groups) & CONTROL_GROUPS) ==0: 


#                 next =  current + disasm[current].size 


#             #control instruction
#             else:
#                 #jumps of calls with target
#                 if len(set(disasm[current].groups) & BRANCH_GROUPS): 
#                     if current in cfg:
#                         next = cfg[current][0]
#                     #tidi find better soltn
#                     else:
#                         next =  current + disasm[current].size 
#                 #indirect control flow
#                 else:
#                     next =  current + disasm[current].size 

#             if next not in disasm:
#                 break
#             RD_CFG.append(next)
#             current = next 
            
#         #save         
#         ALL_RD_CFG [offset] = RD_CFG





# get_recursive_descent_cfg(disasm)

# %%
ALL_RD_CFG = {}


                
def get_recursive_descent_cfg(disasm):
    debug = False
    global ALL_RD_CFG

    for offset in disasm:
        if debug:
            print('\n-------------------------------------------------------\n')
        RD_CFG = []
        current = offset
        while True:

            print('current: ',current)

            #prevent cycle
            if current in RD_CFG:
                break
            #out of bound
            if current not in disasm:
                break
            #current invalid
            if disasm[current] is None:
                break
            #return
            # if disasm[current].mnemonic in ["ret"]:
            #     break
            

            next =  current + disasm[current].size 


            if next not in disasm:
                break
            RD_CFG.append(next)
            current = next 
            
        #save         
        ALL_RD_CFG [offset] = RD_CFG





get_recursive_descent_cfg(disasm)
# Out:
# current:  4256
# current:  4260
# current:  4257
# current:  4258
# current:  4259
# current:  4260
# current:  4260
# current:  4261
# current:  4261
# current:  4266
# current:  4262
# current:  4264
# current:  4263
# current:  4265
# current:  4264
# current:  4266
# current:  4265
# current:  4268
# current:  4266
# current:  4273
# current:  4267
# current:  4273
# current:  4268
# current:  4269
# current:  4269
# current:  4271
# current:  4270
# current:  4272
# current:  4271
# current:  4273
# current:  4272
# current:  4275
# current:  4273
# current:  4281
# current:  4274
# current:  4281
# current:  4275
# current:  4276
# current:  4276
# current:  4281
# current:  4277
# current:  4279
# current:  4278
# current:  4281
# current:  4279
# current:  4281
# current:  4280
# current:  4284
# current:  4281
# current:  4290
# current:  4282
# current:  4290
# current:  4283
# current:  4290
# current:  4284
# current:  4286
# current:  4285
# current:  4290
# current:  4286
# current:  4288
# current:  4287
# current:  4289
# current:  4288
# current:  4290
# current:  4289
# current:  4292
# current:  4290
# current:  4298
# current:  4291
# current:  4298
# current:  4292
# current:  4295
# current:  4293
# current:  4295
# current:  4294
# current:  4296
# current:  4295
# current:  4297
# current:  4296
# current:  4298
# current:  4297
# current:  4299
# current:  4298
# current:  4300
# current:  4299
# current:  4303
# current:  4300
# current:  4307
# current:  4301
# current:  4307
# current:  4302
# current:  4307
# current:  4303
# current:  4304
# current:  4304
# current:  4307
# current:  4305
# current:  4307
# current:  4306
# current:  4309
# current:  4307
# current:  4315
# current:  4308
# current:  4315
# current:  4309
# current:  4310
# current:  4310
# current:  4312
# current:  4311
# current:  4312
# current:  4312
# current:  4314
# current:  4313
# current:  4315
# current:  4314
# current:  4316
# current:  4315
# current:  4323
# current:  5234
# current:  5236
# current:  5235
# current:  5237
# current:  5236
# current:  5238
# current:  5237
# current:  5240
# current:  5238
# current:  5243
# current:  5239
# current:  5244
# current:  5240
# current:  5241
# current:  5241
# current:  5242
# current:  5244
# current:  5243
# current:  5245
# current:  5244
# current:  5251
# current:  5245
# current:  5247
# current:  5246
# current:  5247
# current:  5254
# current:  5248
# current:  5254
# current:  5249
# current:  5254
# current:  5250
# current:  5251
# current:  5251
# current:  5253
# current:  5252
# current:  5254
# current:  5253
# current:  5259
# current:  5254
# current:  5259
# current:  5255
# current:  5257
# current:  5256
# current:  5258
# current:  5257
# current:  5259
# current:  5258
# current:  5260
# current:  5259
# current:  5264
# current:  5260
# current:  5262
# current:  5261
# current:  5262
# current:  5262
# current:  5263
# current:  5269
# current:  5264
# current:  5266
# current:  5265
# current:  5266
# current:  5266
# current:  5268
# current:  5267
# current:  5268
# current:  5268
# current:  5270
# current:  5269
# current:  5270
# current:  5270
# current:  5280
# current:  5271
# current:  5280
# current:  5272
# current:  5280
# current:  5273
# current:  5274
# current:  5276
# current:  5275
# current:  5277
# current:  5276
# current:  5278
# current:  5277
# current:  5279
# current:  5278
# current:  5280
# current:  5279
# current:  5285
# current:  5280
# current:  5285
# current:  5281
# current:  5283
# current:  5282
# current:  5284
# current:  5283
# current:  5285
# current:  5284
# current:  5286
# current:  5285
# current:  5290
# current:  5286
# current:  5287
# current:  5288
# current:  5288
# current:  5289
# current:  5290
# current:  5291

# %%
ALL_RD_PRED ={}
def get_recursive_preds(disasm):
    global ALL_RD_PRED

    #todo fix nahid
    for offset in disasm:
        ALL_RD_PRED[offset] = []

    for offset in disasm:
        for target in ALL_RD_CFG[offset] :
            if target in disasm: #last byte
                if target not in ALL_RD_PRED[target] :
                    ALL_RD_PRED[target].append(offset)

get_recursive_preds(disasm)

# %%
H_list = {}

res, data_prob,  = {}, {}
cfg, preds

min_offset, max_offset
BOTTOM = None

for offset in range(min_offset, max_offset + 1):

        if disasm[offset] is  None:
            data_prob[offset] =  1.0
        # elif offset in valid_instructions:
        #     data_prob[offset] =  0.9
        else:
            data_prob[offset] = BOTTOM

        H_list[offset] = []

# %%
NEAR_JUMP = 0.00001525902  # (2^32 - 1)^-1
REL_JUMP = 0.00392156862  # (2^16 - 1)^-1
DEF_USE = 1/16
def _hint_one(offset, disasm):

    """ Implements Control Flow Convergence hint. """
    debug = False

    if offset not in preds:
        return

    branches = [prev for prev in preds[offset] if set(disasm[prev].groups) & BRANCH_GROUPS]

    if disasm[offset]:
        if debug:
            print( '#  ' if offset in ground_truth_offsets else '   ', \
                  ' $ ' if len(set(disasm[offset].groups) & BRANCH_GROUPS) else '   ', \
                  ' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)

    if len(branches)<2:
        return

    if debug:
        print(branches)
    for branch in branches:
        # H[branch].add(("1rel" if disasm[branch].size == 2 else "1near", offset))

        jump_len = disasm[branch].operands[0].imm - (disasm[branch].address + disasm[branch].size)
        
        if -128 <= jump_len <= 127:
            H_list[branch].append( REL_JUMP )
            H_list[offset].append( REL_JUMP) 
        else:
            H_list[branch].append( NEAR_JUMP)
            H_list[offset].append( NEAR_JUMP )
        if debug:
            print('$$$ len', jump_len)
        


def _hint_two(offset, disasm):

    """ Implements Control Flow Crossing hint. """
    debug = False
    
    if debug:
        # print( '#' if offset in ground_truth_offsets else ' ',' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)
        print( '#  ' if offset in ground_truth_offsets else '   ', \
              ' $ ' if len(set(disasm[offset].groups) & BRANCH_GROUPS) else '   ', \
              ' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)
    inst2_offset = offset
    if not CS_GRP_JUMP in disasm[inst2_offset].groups: #inst2 have to be a control one
        return
    
    
    inst2_size   = disasm[inst2_offset].size
    inst3_offset =  inst2_offset + inst2_size

    if inst3_offset not in preds: #inst 3 has to be a target of inst1
        return

    inst3_preds_list = preds[inst3_offset]

    if inst2_offset in inst3_preds_list:
        inst3_preds_list.remove(inst2_offset)

    for inst1_offset in inst3_preds_list:
        if CS_GRP_JUMP in disasm[inst1_offset].groups: #ins1 has to be a control flow instruction

            inst1_jump_len = disasm[inst1_offset].operands[0].imm - (disasm[inst1_offset].address + disasm[inst1_offset].size)
            inst2_jump_len = disasm[inst2_offset].operands[0].imm - (disasm[inst2_offset].address + disasm[inst2_offset].size)

            

            if -128 <= inst1_jump_len <= 127:  
                hint_type_inst1 = NEAR_JUMP
            else:
                hint_type_inst1 = REL_JUMP

            if -128 <= inst2_jump_len <= 127:  
                hint_type_inst2 = NEAR_JUMP
            else:
                hint_type_inst2 = REL_JUMP

            H_list[inst1_offset].append( hint_type_inst1 )
            H_list[inst3_offset].append( hint_type_inst1 )
            H_list[inst2_offset].append( hint_type_inst2 )


            if debug:
                print('inst1: ', inst1_offset , 'inst2: ',inst2_offset, 'inst3: ',inst3_offset)
                for o in [inst1_offset , inst2_offset, inst3_offset]:
                    if o not in ground_truth_offsets:
                            print('# # # '*10 ,o)
        
        




def _hint_three(offset, disasm):

    """ Implements Register Define-Use Relation hint. """

    debug = True
    # if offset not in ground_truth_offsets:
    #     return

    
    if debug:
        print('\n\n')
        print( '#' if offset in ground_truth_offsets else ' ',' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)

        regs_read, regs_write = disasm[offset].regs_access()
        current_reads = set(disasm[offset].reg_name(r) for r in regs_read)
        current_writes = set(disasm[offset].reg_name(r) for r in regs_write)
        
        print('read'    , current_reads   )
        print('writes'  , current_writes  )
        
        # print('           current read: ',disasm[offset].regs_read , \
        #       [disasm[offset].reg_name(r) for r in disasm[offset].regs_read ] ,  \
        #       [md.reg_name(r) for r in disasm[offset].regs_read ]) #if md.reg_name(r) not in ('eflags', 'rflags')]
        # print('           current WRITE: ',  [disasm[offset].reg_name(r) for r in disasm[offset].regs_write] ) #if md.reg_name(r) not in ('eflags', 'rflags')]

    
    
    
    if offset not in preds:
        return
    
    for prev in preds[offset]:
        if debug:
            print('           prev: write: ',prev, [disasm[offset].reg_name(r) for r in disasm[prev].regs_write]) # if disasm[offset].reg_name(r) not in ('eflags', 'rflags')])

        prev_reg_write = set([ r for r in disasm[prev].regs_write  if disasm[offset].reg_name(r) not in ('eflags', 'rflags')] )
        
        curr_reg_read = set( [ r for r in disasm[offset].regs_read if disasm[offset].reg_name(r) not in ('eflags', 'rflags')])
        
        if prev_reg_write & curr_reg_read:
            H_list[prev].append(DEF_USE)
            H_list[offset].append(DEF_USE)
            
            if debug:
                print("           ----> ", prev)





for offset in disasm:
    # if offset>1200:
    #     break
    if disasm[offset] is None:
        continue

    _hint_one(offset, disasm)
    _hint_two(offset, disasm)
    _hint_three(offset, disasm)
# Out:
# #   4256  :  0x10a0   endbr64    4
# read set()
# writes set()
#
#
#
#     4259  :  0x10a3   cli    1
# read set()
# writes set()
#
#
#
# #   4260  :  0x10a4   push rbx   1
# read {'rbx', 'rsp'}
# writes {'rsp'}
#            prev: write:  4256 []
#            prev: write:  4259 []
#
#
#
# #   4261  :  0x10a5   mov esi, 0x10   5
# read set()
# writes {'esi'}
#            prev: write:  4260 ['rsp']
#
#
#
#     4262  :  0x10a6   adc byte ptr [rax], al   2
# read {'al', 'rflags', 'rax'}
# writes {'rflags'}
#
#
#
#     4263  :  0x10a7   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4264  :  0x10a8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4262 ['rflags']
#
#
#
#     4265  :  0x10a9   add byte ptr [rax - 0x7f], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4263 ['rflags']
#
#
#
# #   4266  :  0x10aa   sub rsp, 0xe0   7
# read {'rsp'}
# writes {'rflags', 'rsp'}
#            prev: write:  4261 []
#            prev: write:  4264 ['rflags']
#
#
#
#     4267  :  0x10ab   sub esp, 0xe0   6
# read {'esp'}
# writes {'rflags', 'esp'}
#
#
#
#     4268  :  0x10ac   in al, dx   1
# read {'dx'}
# writes {'al'}
#            prev: write:  4265 ['rflags']
#
#
#
#     4269  :  0x10ad   loopne 0x10af   2
# read {'rflags', 'rcx'}
# writes {'rcx'}
#            prev: write:  4268 ['al']
#
#
#
#     4270  :  0x10ae   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4271  :  0x10af   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4269 ['rcx']
#
#
#
#     4272  :  0x10b0   add byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#            prev: write:  4270 ['rflags']
#
#
#
# #   4273  :  0x10b1   movdqa xmm0, xmmword ptr [rip + 0xf77]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4266 ['rflags']
#            prev: write:  4267 ['rflags']
#            prev: write:  4271 ['rflags']
#
#
#
#     4274  :  0x10b2   movq mm0, qword ptr [rip + 0xf77]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4275  :  0x10b3   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4272 ['rflags']
#
#
#
#     4276  :  0x10b4   add eax, 0xf77   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4275 ['esi']
#
#
#
#     4277  :  0x10b5   ja 0x10c6   2
# read {'rflags'}
# writes set()
#
#
#
#     4278  :  0x10b6   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4279  :  0x10b7   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4280  :  0x10b8   add byte ptr [rax + rcx*2 - 0x75], ah   4
# read {'ah', 'rcx', 'rax'}
# writes {'rflags'}
#
#
#
# #   4281  :  0x10b9   mov rax, qword ptr fs:[0x28]   9
# read {'fs'}
# writes {'rax'}
#            prev: write:  4273 []
#            prev: write:  4274 []
#            prev: write:  4276 ['rflags']
#            prev: write:  4278 []
#            prev: write:  4279 ['rflags']
#
#
#
#     4282  :  0x10ba   mov rax, qword ptr [0x28]   8
# read set()
# writes {'rax'}
#
#
#
#     4283  :  0x10bb   mov eax, dword ptr [0x28]   7
# read set()
# writes {'eax'}
#
#
#
#     4284  :  0x10bc   add al, 0x25   2
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4280 ['rflags']
#
#
#
#     4285  :  0x10bd   and eax, 0x28   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4286  :  0x10be   sub byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4284 ['rflags']
#
#
#
#     4287  :  0x10bf   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4288  :  0x10c0   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4286 ['rflags']
#
#
#
#     4289  :  0x10c1   add byte ptr [rax - 0x77], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4287 ['rflags']
#
#
#
# #   4290  :  0x10c2   mov qword ptr [rsp + 0xd8], rax   8
# read {'rsp', 'rax'}
# writes set()
#            prev: write:  4281 []
#            prev: write:  4282 []
#            prev: write:  4283 []
#            prev: write:  4285 ['rflags']
#            prev: write:  4288 ['rflags']
#
#
#
#     4291  :  0x10c3   mov dword ptr [rsp + 0xd8], eax   7
# read {'eax', 'rsp'}
# writes set()
#
#
#
#     4292  :  0x10c4   test byte ptr [rax + rbx*8], ah   3
# read {'rbx', 'rax'}
# writes set()
#            prev: write:  4289 ['rflags']
#
#
#
#     4293  :  0x10c5   and al, 0xd8   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4294  :  0x10c6   fadd dword ptr [rax]   2
# read {'rax'}
# writes {'fpsw'}
#            prev: write:  4277 []
#
#
#
#     4295  :  0x10c7   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4292 []
#            prev: write:  4293 ['rflags']
#
#
#
#     4296  :  0x10c8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4294 ['fpsw']
#
#
#
#     4297  :  0x10c9   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  4295 ['rflags']
#
#
#
# #   4298  :  0x10ca   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4290 []
#            prev: write:  4291 []
#            prev: write:  4296 ['rflags']
#
#
#
#     4299  :  0x10cb   ror byte ptr [rax - 0x75], 5   4
# read {'rax'}
# writes {'rflags'}
#            prev: write:  4297 ['rflags']
#
#
#
# #   4300  :  0x10cc   mov rax, qword ptr [rip + 0xffd]   7
# read {'rip'}
# writes {'rax'}
#            prev: write:  4298 ['rflags']
#
#
#
#     4301  :  0x10cd   mov eax, dword ptr [rip + 0xffd]   6
# read {'rip'}
# writes {'eax'}
#
#
#
#     4302  :  0x10ce   add eax, 0xffd   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4303  :  0x10cf   std    1
# read set()
# writes {'rflags'}
#            prev: write:  4299 ['rflags']
#
#
#
#     4304  :  0x10d0   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#            prev: write:  4303 ['rflags']
#
#
#
#     4305  :  0x10d1   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4306  :  0x10d2   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4307  :  0x10d3   lea rbx, [rsp + 0x90]   8
# read {'rsp'}
# writes {'rbx'}
#            prev: write:  4300 []
#            prev: write:  4301 []
#            prev: write:  4302 ['rflags']
#            prev: write:  4304 []
#            prev: write:  4305 ['rflags']
#
#
#
#     4308  :  0x10d4   lea ebx, [rsp + 0x90]   7
# read {'rsp'}
# writes {'ebx'}
#
#
#
#     4309  :  0x10d5   pushfq    1
# read {'rflags', 'rsp'}
# writes {'rsp'}
#            prev: write:  4306 ['rflags']
#
#
#
#     4310  :  0x10d6   and al, 0x90   2
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4309 ['rsp']
#
#
#
#     4311  :  0x10d7   nop    1
# read set()
# writes set()
#
#
#
#     4312  :  0x10d8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4310 ['rflags']
#            prev: write:  4311 []
#
#
#
#     4313  :  0x10d9   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4314  :  0x10da   add bh, al   2
# read {'al', 'bh'}
# writes {'rflags', 'bh'}
#            prev: write:  4312 ['rflags']
#
#
#
# #   4315  :  0x10db   mov dword ptr [rsp + 0x18], 0xffffffa2   8
# read {'rsp'}
# writes set()
#            prev: write:  4307 []
#            prev: write:  4308 []
#            prev: write:  4313 ['rflags']
#
#
#
#     4316  :  0x10dc   and al, 0x18   3
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4314 ['rflags']
#
#
#
#     4317  :  0x10dd   and al, 0x18   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4318  :  0x10de   sbb byte ptr [rdx + 0xfffffff], ah   6
# read {'ah', 'rflags', 'rdx'}
# writes {'rflags'}
#
#
#
#     4319  :  0x10df   movabs byte ptr [0x902484290fffffff], al   9
# read {'al'}
# writes set()
#            prev: write:  4316 ['rflags']
#            prev: write:  4317 ['rflags']
#
#
#
#     4322  :  0x10e2   dec dword ptr [rdi]   2
# read {'rdi'}
# writes {'rflags'}
#
#
#
# #   4323  :  0x10e3   movaps xmmword ptr [rsp + 0x90], xmm0   8
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4315 []
#
#
#
#     4324  :  0x10e4   sub dword ptr [rsp + 0x90], eax   7
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4318 ['rflags']
#            prev: write:  4322 ['rflags']
#
#
#
#     4325  :  0x10e5   test byte ptr [rax + rdx*4], ah   3
# read {'rdx', 'rax'}
# writes set()
#
#
#
#     4326  :  0x10e6   and al, 0x90   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4327  :  0x10e7   nop    1
# read set()
# writes set()
#
#
#
#     4328  :  0x10e8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4319 []
#            prev: write:  4325 []
#            prev: write:  4326 ['rflags']
#            prev: write:  4327 []
#
#
#
#     4329  :  0x10e9   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4330  :  0x10ea   add byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#            prev: write:  4328 ['rflags']
#
#
#
# #   4331  :  0x10eb   movdqa xmm0, xmmword ptr [rip + 0xf4d]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4323 []
#            prev: write:  4324 ['rflags']
#            prev: write:  4329 ['rflags']
#
#
#
#     4332  :  0x10ec   movq mm0, qword ptr [rip + 0xf4d]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4333  :  0x10ed   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4330 ['rflags']
#
#
#
#     4334  :  0x10ee   add eax, 0xf4d   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4333 ['esi']
#
#
#
#     4335  :  0x10ef   sldt word ptr [r8]   4
# read {'r8'}
# writes set()
#
#
#
#     4336  :  0x10f0   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4337  :  0x10f1   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4338  :  0x10f2   add byte ptr [rax - 0x77], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4339  :  0x10f3   mov rdi, rbx   3
# read {'rbx'}
# writes {'rdi'}
#            prev: write:  4331 []
#            prev: write:  4332 []
#            prev: write:  4334 ['rflags']
#            prev: write:  4335 []
#            prev: write:  4336 []
#            prev: write:  4337 ['rflags']
#
#
#
#     4340  :  0x10f4   mov edi, ebx   2
# read {'ebx'}
# writes {'edi'}
#
#
#
#     4341  :  0x10f5   fisttp word ptr [rax - 0x77]   3
# read {'rax'}
# writes {'fpsw'}
#            prev: write:  4338 ['rflags']
#
#
#
# #   4342  :  0x10f6   mov qword ptr [rsp + 0x10], rax   5
# read {'rsp', 'rax'}
# writes set()
#            prev: write:  4339 []
#            prev: write:  4340 []
#
#
#
#     4343  :  0x10f7   mov dword ptr [rsp + 0x10], eax   4
# read {'eax', 'rsp'}
# writes set()
#
#
#
#     4344  :  0x10f8   and al, 0x10   3
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4341 ['fpsw']
#
#
#
#     4345  :  0x10f9   and al, 0x10   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4346  :  0x10fa   adc byte ptr [rax - 0x75], cl   3
# read {'cl', 'rflags', 'rax'}
# writes {'rflags'}
#
#
#
# #   4347  :  0x10fb   mov rax, qword ptr [rip + 0xfd6]   7
# read {'rip'}
# writes {'rax'}
#            prev: write:  4342 []
#            prev: write:  4343 []
#            prev: write:  4344 ['rflags']
#            prev: write:  4345 ['rflags']
#
#
#
#     4348  :  0x10fc   mov eax, dword ptr [rip + 0xfd6]   6
# read {'rip'}
# writes {'eax'}
#
#
#
#     4349  :  0x10fd   add eax, 0xfd6   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4346 ['rflags']
#
#
#
#     4351  :  0x10ff   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4352  :  0x1100   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4353  :  0x1101   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4354  :  0x1102   movaps xmmword ptr [rsp + 0xa0], xmm0   8
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4347 []
#            prev: write:  4348 []
#            prev: write:  4349 ['rflags']
#            prev: write:  4351 []
#            prev: write:  4352 ['rflags']
#
#
#
#     4355  :  0x1103   sub dword ptr [rsp + 0xa0], eax   7
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4353 ['rflags']
#
#
#
#     4356  :  0x1104   test byte ptr [rax + riz*4], ah   3
# read {'riz', 'rax'}
# writes set()
#
#
#
#     4357  :  0x1105   and al, 0xa0   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4358  :  0x1106   movabs al, byte ptr [0x3e056f0f66000000]   9
# read set()
# writes {'al'}
#
#
#
#     4359  :  0x1107   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4356 []
#            prev: write:  4357 ['rflags']
#
#
#
#     4360  :  0x1108   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4361  :  0x1109   add byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#            prev: write:  4359 ['rflags']
#
#
#
# #   4362  :  0x110a   movdqa xmm0, xmmword ptr [rip + 0xf3e]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4354 []
#            prev: write:  4355 ['rflags']
#            prev: write:  4360 ['rflags']
#
#
#
#     4363  :  0x110b   movq mm0, qword ptr [rip + 0xf3e]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4364  :  0x110c   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4361 ['rflags']
#
#
#
#     4365  :  0x110d   add eax, 0xf3e   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4364 ['esi']
#
#
#
#     4366  :  0x110e   sldt word ptr ds:[rax]   4
# read {'ds', 'rax'}
# writes set()
#
#
#
#     4367  :  0x110f   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#            prev: write:  4358 []
#
#
#
#     4368  :  0x1110   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4369  :  0x1111   add byte ptr [rax - 0x77], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4370  :  0x1112   mov qword ptr [rsp + 0x80], rax   8
# read {'rsp', 'rax'}
# writes set()
#            prev: write:  4362 []
#            prev: write:  4363 []
#            prev: write:  4365 ['rflags']
#            prev: write:  4366 []
#            prev: write:  4367 []
#            prev: write:  4368 ['rflags']
#
#
#
#     4371  :  0x1113   mov dword ptr [rsp + 0x80], eax   7
# read {'eax', 'rsp'}
# writes set()
#
#
#
#     4372  :  0x1114   test byte ptr [rax + rax*4], ah   3
# read {'rax'}
# writes set()
#            prev: write:  4369 ['rflags']
#
#
#
#     4373  :  0x1115   and al, 0x80   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4374  :  0x1116   add byte ptr [rax], 0   3
# read {'rax'}
# writes {'rflags'}
#
#
#
#     4375  :  0x1117   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4372 []
#            prev: write:  4373 ['rflags']
#
#
#
#     4376  :  0x1118   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4377  :  0x1119   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#            prev: write:  4374 ['rflags']
#            prev: write:  4375 ['rflags']
#
#
#
# #   4378  :  0x111a   movaps xmmword ptr [rsp + 0xb0], xmm0   8
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4370 []
#            prev: write:  4371 []
#            prev: write:  4376 ['rflags']
#
#
#
#     4379  :  0x111b   sub dword ptr [rsp + 0xb0], eax   7
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4377 ['rflags']
#
#
#
#     4380  :  0x111c   test byte ptr [rax + rsi*4], ah   3
# read {'rsi', 'rax'}
# writes set()
#
#
#
#     4381  :  0x111d   and al, 0xb0   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4382  :  0x111e   mov al, 0   2
# read set()
# writes {'al'}
#
#
#
#     4383  :  0x111f   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4380 []
#            prev: write:  4381 ['rflags']
#
#
#
#     4384  :  0x1120   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4382 []
#
#
#
#     4385  :  0x1121   add byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#            prev: write:  4383 ['rflags']
#
#
#
# #   4386  :  0x1122   movdqa xmm0, xmmword ptr [rip + 0xf36]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4378 []
#            prev: write:  4379 ['rflags']
#            prev: write:  4384 ['rflags']
#
#
#
#     4387  :  0x1123   movq mm0, qword ptr [rip + 0xf36]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4388  :  0x1124   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4385 ['rflags']
#
#
#
#     4389  :  0x1125   add eax, 0xf36   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4388 ['esi']
#
#
#
#     4390  :  0x1126   sldt word ptr ss:[rax]   4
# read {'ss', 'rax'}
# writes set()
#
#
#
#     4391  :  0x1127   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4392  :  0x1128   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4393  :  0x1129   add bh, al   2
# read {'al', 'bh'}
# writes {'rflags', 'bh'}
#
#
#
# #   4394  :  0x112a   mov dword ptr [rsp + 0x40], 1   8
# read {'rsp'}
# writes set()
#            prev: write:  4386 []
#            prev: write:  4387 []
#            prev: write:  4389 ['rflags']
#            prev: write:  4390 []
#            prev: write:  4391 []
#            prev: write:  4392 ['rflags']
#
#
#
#     4395  :  0x112b   and al, 0x40   3
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4393 ['rflags']
#
#
#
#     4396  :  0x112c   and al, 0x40   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4397  :  0x112d   add dword ptr [rax], eax   3
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4398  :  0x112e   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#            prev: write:  4395 ['rflags']
#            prev: write:  4396 ['rflags']
#
#
#
#     4399  :  0x112f   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4400  :  0x1130   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4397 ['rflags']
#            prev: write:  4398 ['rflags']
#
#
#
#     4401  :  0x1131   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#            prev: write:  4399 ['rflags']
#
#
#
# #   4402  :  0x1132   movaps xmmword ptr [rsp + 0xc0], xmm0   8
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4394 []
#            prev: write:  4400 ['rflags']
#
#
#
#     4403  :  0x1133   sub dword ptr [rsp + 0xc0], eax   7
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4401 ['rflags']
#
#
#
#     4404  :  0x1134   test byte ptr [rax + rax*8], ah   3
# read {'rax'}
# writes set()
#
#
#
#     4405  :  0x1135   and al, 0xc0   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4406  :  0x1136   rol byte ptr [rax], 0   3
# read {'rax'}
# writes {'rflags'}
#
#
#
#     4407  :  0x1137   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4404 []
#            prev: write:  4405 ['rflags']
#
#
#
#     4408  :  0x1138   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4409  :  0x1139   add byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#            prev: write:  4406 ['rflags']
#            prev: write:  4407 ['rflags']
#
#
#
# #   4410  :  0x113a   movdqa xmm0, xmmword ptr [rip + 0xf2e]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4402 []
#            prev: write:  4403 ['rflags']
#            prev: write:  4408 ['rflags']
#
#
#
#     4411  :  0x113b   movq mm0, qword ptr [rip + 0xf2e]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4412  :  0x113c   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4409 ['rflags']
#
#
#
#     4413  :  0x113d   add eax, 0xf2e   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4412 ['esi']
#
#
#
#     4414  :  0x113e   sldt word ptr cs:[rax]   4
# read {'cs', 'rax'}
# writes set()
#
#
#
#     4415  :  0x113f   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4416  :  0x1140   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4417  :  0x1141   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4418  :  0x1142   movaps xmmword ptr [rsp], xmm0   4
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4410 []
#            prev: write:  4411 []
#            prev: write:  4413 ['rflags']
#            prev: write:  4414 []
#            prev: write:  4415 []
#            prev: write:  4416 ['rflags']
#
#
#
#     4419  :  0x1143   sub dword ptr [rsp], eax   3
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4417 ['rflags']
#
#
#
#     4420  :  0x1144   add al, 0x24   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4421  :  0x1145   and al, 0x66   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
# #   4422  :  0x1146   movdqa xmm0, xmmword ptr [rip + 0xf32]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4418 []
#            prev: write:  4419 ['rflags']
#            prev: write:  4420 ['rflags']
#
#
#
#     4423  :  0x1147   movq mm0, qword ptr [rip + 0xf32]   7
# read {'rip'}
# writes {'mm0'}
#            prev: write:  4421 ['rflags']
#
#
#
#     4424  :  0x1148   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#
#
#
#     4425  :  0x1149   add eax, 0xf32   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4424 ['esi']
#
#
#
#     4426  :  0x114a   xor cl, byte ptr [rdi]   2
# read {'cl', 'rdi'}
# writes {'cl', 'rflags'}
#
#
#
#     4427  :  0x114b   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4428  :  0x114c   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4426 ['rflags']
#
#
#
#     4429  :  0x114d   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4430  :  0x114e   movaps xmmword ptr [rsp + 0x50], xmm0   5
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4422 []
#            prev: write:  4423 []
#            prev: write:  4425 ['rflags']
#            prev: write:  4427 []
#            prev: write:  4428 ['rflags']
#
#
#
#     4431  :  0x114f   sub dword ptr [rsp + 0x50], eax   4
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4429 ['rflags']
#
#
#
#     4432  :  0x1150   and al, 0x50   3
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4433  :  0x1151   and al, 0x50   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4434  :  0x1152   push rax   1
# read {'rsp', 'rax'}
# writes {'rsp'}
#
#
#
# #   4435  :  0x1153   movdqa xmm0, xmmword ptr [rip + 0xf35]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4430 []
#            prev: write:  4431 ['rflags']
#            prev: write:  4432 ['rflags']
#            prev: write:  4433 ['rflags']
#            prev: write:  4434 ['rsp']
#
#
#
#     4436  :  0x1154   movq mm0, qword ptr [rip + 0xf35]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4437  :  0x1155   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#
#
#
#     4438  :  0x1156   add eax, 0xf35   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4437 ['esi']
#
#
#
#     4439  :  0x1157   xor eax, 0xf00000f   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4440  :  0x1158   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4441  :  0x1159   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4442  :  0x115a   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4443  :  0x115b   movaps xmmword ptr [rsp + 0x60], xmm0   5
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4435 []
#            prev: write:  4436 []
#            prev: write:  4438 ['rflags']
#            prev: write:  4440 []
#            prev: write:  4441 ['rflags']
#
#
#
#     4444  :  0x115c   sub dword ptr [rsp + 0x60], eax   4
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4439 ['rflags']
#            prev: write:  4442 ['rflags']
#
#
#
#     4445  :  0x115d   and al, 0x60   3
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4446  :  0x115e   and al, 0x60   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
# #   4448  :  0x1160   movdqa xmm0, xmmword ptr [rip + 0xf38]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4443 []
#            prev: write:  4444 ['rflags']
#            prev: write:  4445 ['rflags']
#            prev: write:  4446 ['rflags']
#
#
#
#     4449  :  0x1161   movq mm0, qword ptr [rip + 0xf38]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4450  :  0x1162   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#
#
#
#     4451  :  0x1163   add eax, 0xf38   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4450 ['esi']
#
#
#
#     4452  :  0x1164   cmp byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
#     4453  :  0x1165   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4454  :  0x1166   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4452 ['rflags']
#
#
#
#     4455  :  0x1167   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4456  :  0x1168   movaps xmmword ptr [rsp + 0x70], xmm0   5
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4448 []
#            prev: write:  4449 []
#            prev: write:  4451 ['rflags']
#            prev: write:  4453 []
#            prev: write:  4454 ['rflags']
#
#
#
#     4457  :  0x1169   sub dword ptr [rsp + 0x70], eax   4
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4455 ['rflags']
#
#
#
#     4458  :  0x116a   and al, 0x70   3
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4459  :  0x116b   and al, 0x70   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4460  :  0x116c   jo 0x11d4   2
# read {'rflags'}
# writes set()
#
#
#
# #   4461  :  0x116d   movdqa xmm0, xmmword ptr [rip + 0xf3b]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4456 []
#            prev: write:  4457 ['rflags']
#            prev: write:  4458 ['rflags']
#            prev: write:  4459 ['rflags']
#
#
#
#     4462  :  0x116e   movq mm0, qword ptr [rip + 0xf3b]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4463  :  0x116f   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#
#
#
#     4464  :  0x1170   add eax, 0xf3b   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4463 ['esi']
#
#
#
#     4465  :  0x1171   cmp ecx, dword ptr [rdi]   2
# read {'rdi', 'ecx'}
# writes {'rflags'}
#
#
#
#     4466  :  0x1172   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4467  :  0x1173   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4465 ['rflags']
#
#
#
#     4468  :  0x1174   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4469  :  0x1175   movaps xmmword ptr [rsp + 0x20], xmm0   5
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4461 []
#            prev: write:  4462 []
#            prev: write:  4464 ['rflags']
#            prev: write:  4466 []
#            prev: write:  4467 ['rflags']
#
#
#
#     4470  :  0x1176   sub dword ptr [rsp + 0x20], eax   4
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4468 ['rflags']
#
#
#
#     4471  :  0x1177   and al, 0x20   3
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4472  :  0x1178   and al, 0x20   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4473  :  0x1179   and byte ptr [rsi + 0xf], ah   3
# read {'rsi', 'ah'}
# writes {'rflags'}
#
#
#
# #   4474  :  0x117a   movdqa xmm0, xmmword ptr [rip + 0xf3e]   8
# read {'rip'}
# writes {'xmm0'}
#            prev: write:  4469 []
#            prev: write:  4470 ['rflags']
#            prev: write:  4471 ['rflags']
#            prev: write:  4472 ['rflags']
#
#
#
#     4475  :  0x117b   movq mm0, qword ptr [rip + 0xf3e]   7
# read {'rip'}
# writes {'mm0'}
#
#
#
#     4476  :  0x117c   outsd dx, dword ptr [rsi]   1
# read {'esi', 'dx', 'rflags', 'rsi'}
# writes {'esi'}
#            prev: write:  4473 ['rflags']
#
#
#
#     4477  :  0x117d   add eax, 0xf3e   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4476 ['esi']
#
#
#
#     4478  :  0x117e   sldt word ptr ds:[rax]   4
# read {'ds', 'rax'}
# writes set()
#
#
#
#     4479  :  0x117f   sldt word ptr [rax]   3
# read {'rax'}
# writes set()
#
#
#
#     4480  :  0x1180   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4481  :  0x1181   add byte ptr [rdi], cl   2
# read {'cl', 'rdi'}
# writes {'rflags'}
#
#
#
# #   4482  :  0x1182   movaps xmmword ptr [rsp + 0x30], xmm0   5
# read {'xmm0', 'rsp'}
# writes set()
#            prev: write:  4474 []
#            prev: write:  4475 []
#            prev: write:  4477 ['rflags']
#            prev: write:  4478 []
#            prev: write:  4479 []
#            prev: write:  4480 ['rflags']
#
#
#
#     4483  :  0x1183   sub dword ptr [rsp + 0x30], eax   4
# read {'eax', 'rsp'}
# writes {'rflags'}
#            prev: write:  4481 ['rflags']
#
#
#
#     4484  :  0x1184   and al, 0x30   3
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4485  :  0x1185   and al, 0x30   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4486  :  0x1186   xor al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#
#
#
# #   4487  :  0x1187   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4482 []
#            prev: write:  4483 ['rflags']
#            prev: write:  4484 ['rflags']
#            prev: write:  4485 ['rflags']
#
#
#
#     4488  :  0x1188   hlt    1
# read set()
# writes set()
#            prev: write:  4486 ['rflags']
#
#
#
#     4489  :  0x1189   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#            prev: write:  4488 []
#
#
#
#     4490  :  0x118a   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4491  :  0x118b   add byte ptr [rax - 0x77], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4489 ['rflags']
#
#
#
# #   4492  :  0x118c   mov rdi, rsp   3
# read {'rsp'}
# writes {'rdi'}
#            prev: write:  4487 ['rsp']
#            prev: write:  4490 ['rflags']
#
#
#
#     4493  :  0x118d   mov edi, esp   2
# read {'esp'}
# writes {'edi'}
#
#
#
#     4494  :  0x118e   out 0xbe, eax   2
# read {'eax'}
# writes set()
#            prev: write:  4491 ['rflags']
#
#
#
# #   4495  :  0x118f   mov esi, 7   5
# read set()
# writes {'esi'}
#            prev: write:  4492 []
#            prev: write:  4493 []
#
#
#
#     4497  :  0x1191   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4498  :  0x1192   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4499  :  0x1193   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  4497 ['rflags']
#
#
#
# #   4500  :  0x1194   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4495 []
#            prev: write:  4498 ['rflags']
#
#
#
#     4501  :  0x1195   out 1, eax   2
# read {'eax'}
# writes set()
#            prev: write:  4499 ['rflags']
#
#
#
#     4502  :  0x1196   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4503  :  0x1197   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4501 []
#
#
#
#     4504  :  0x1198   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4502 ['rflags']
#
#
#
# #   4505  :  0x1199   lea rdi, [rsp + 0x50]   5
# read {'rsp'}
# writes {'rdi'}
#            prev: write:  4500 ['rsp']
#            prev: write:  4503 ['rflags']
#
#
#
#     4506  :  0x119a   lea edi, [rsp + 0x50]   4
# read {'rsp'}
# writes {'edi'}
#
#
#
#     4507  :  0x119b   jl 0x11c1   2
# read {'rflags'}
# writes set()
#            prev: write:  4504 ['rflags']
#
#
#
#     4508  :  0x119c   and al, 0x50   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4509  :  0x119d   push rax   1
# read {'rsp', 'rax'}
# writes {'rsp'}
#
#
#
# #   4510  :  0x119e   mov esi, 0xe   5
# read set()
# writes {'esi'}
#            prev: write:  4505 []
#            prev: write:  4506 []
#            prev: write:  4508 ['rflags']
#            prev: write:  4509 ['rsp']
#
#
#
#     4512  :  0x11a0   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4513  :  0x11a1   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4514  :  0x11a2   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  4512 ['rflags']
#
#
#
# #   4515  :  0x11a3   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4510 []
#            prev: write:  4513 ['rflags']
#
#
#
#     4516  :  0x11a4   fadd dword ptr [rcx]   2
# read {'rcx'}
# writes {'fpsw'}
#            prev: write:  4514 ['rflags']
#
#
#
#     4517  :  0x11a5   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4518  :  0x11a6   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4516 ['fpsw']
#
#
#
#     4519  :  0x11a7   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4517 ['rflags']
#
#
#
# #   4520  :  0x11a8   lea rdi, [rsp + 0x20]   5
# read {'rsp'}
# writes {'rdi'}
#            prev: write:  4515 ['rsp']
#            prev: write:  4518 ['rflags']
#
#
#
#     4521  :  0x11a9   lea edi, [rsp + 0x20]   4
# read {'rsp'}
# writes {'edi'}
#
#
#
#     4522  :  0x11aa   jl 0x11d0   2
# read {'rflags'}
# writes set()
#            prev: write:  4519 ['rflags']
#
#
#
#     4523  :  0x11ab   and al, 0x20   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4524  :  0x11ac   and byte ptr [rsi + 9], bh   6
# read {'rsi', 'bh'}
# writes {'rflags'}
#
#
#
# #   4525  :  0x11ad   mov esi, 9   5
# read set()
# writes {'esi'}
#            prev: write:  4520 []
#            prev: write:  4521 []
#            prev: write:  4523 ['rflags']
#
#
#
#     4526  :  0x11ae   or dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4527  :  0x11af   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4528  :  0x11b0   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4526 ['rflags']
#
#
#
#     4529  :  0x11b1   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  4527 ['rflags']
#
#
#
# #   4530  :  0x11b2   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4524 ['rflags']
#            prev: write:  4525 []
#            prev: write:  4528 ['rflags']
#
#
#
#     4531  :  0x11b3   leave    1
# read {'rbp', 'rsp'}
# writes {'rbp', 'rsp'}
#            prev: write:  4529 ['rflags']
#
#
#
#     4532  :  0x11b4   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#            prev: write:  4531 ['rbp', 'rsp']
#
#
#
#     4533  :  0x11b5   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4534  :  0x11b6   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  4532 ['rflags']
#
#
#
# #   4535  :  0x11b7   xor esi, esi   2
# read {'esi'}
# writes {'esi', 'rflags'}
#            prev: write:  4530 ['rsp']
#            prev: write:  4533 ['rflags']
#
#
#
#     4536  :  0x11b8   div byte ptr [rcx]   2
# read {'ax', 'rcx'}
# writes {'al', 'rflags', 'ah'}
#            prev: write:  4534 ['rflags']
#
#
#
# #   4537  :  0x11b9   xor edi, edi   2
# read {'edi'}
# writes {'rflags', 'edi'}
#            prev: write:  4535 ['rflags']
#
#
#
# #   4539  :  0x11bb   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4537 ['rflags']
#
#
#
#     4540  :  0x11bc   rol byte ptr [rcx], 0   3
# read {'rcx'}
# writes {'rflags'}
#
#
#
#     4541  :  0x11bd   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4542  :  0x11be   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4543  :  0x11bf   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  4540 ['rflags']
#            prev: write:  4541 ['rflags']
#
#
#
# #   4544  :  0x11c0   xor esi, esi   2
# read {'esi'}
# writes {'esi', 'rflags'}
#            prev: write:  4539 ['rsp']
#            prev: write:  4542 ['rflags']
#
#
#
#     4545  :  0x11c1   test byte ptr [rax - 0x77], -0x21   4
# read {'rax'}
# writes set()
#            prev: write:  4507 []
#            prev: write:  4543 ['rflags']
#
#
#
# #   4546  :  0x11c2   mov rdi, rbx   3
# read {'rbx'}
# writes {'rdi'}
#            prev: write:  4544 ['rflags']
#
#
#
#     4547  :  0x11c3   mov edi, ebx   2
# read {'ebx'}
# writes {'edi'}
#
#
#
#     4548  :  0x11c4   fucompi st(0)   2
# read {'st(0)'}
# writes {'fpsw', 'rflags'}
#
#
#
# #   4549  :  0x11c5   call 0x1380   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4545 []
#            prev: write:  4546 []
#            prev: write:  4547 []
#
#
#
#     4550  :  0x11c6   mov dh, 1   2
# read set()
# writes {'dh'}
#            prev: write:  4548 ['rflags', 'fpsw']
#
#
#
#     4551  :  0x11c7   add dword ptr [rax], eax   2
# read {'eax', 'rax'}
# writes {'rflags'}
#
#
#
#     4552  :  0x11c8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4550 []
#
#
#
#     4553  :  0x11c9   add byte ptr [rax - 0x75], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4551 ['rflags']
#
#
#
# #   4554  :  0x11ca   mov rax, qword ptr [rsp + 0xd8]   8
# read {'rsp'}
# writes {'rax'}
#            prev: write:  4549 ['rsp']
#            prev: write:  4552 ['rflags']
#
#
#
#     4555  :  0x11cb   mov eax, dword ptr [rsp + 0xd8]   7
# read {'rsp'}
# writes {'eax'}
#
#
#
#     4556  :  0x11cc   test byte ptr [rax + rbx*8], ah   3
# read {'rbx', 'rax'}
# writes set()
#            prev: write:  4553 ['rflags']
#
#
#
#     4557  :  0x11cd   and al, 0xd8   2
# read {'al'}
# writes {'al', 'rflags'}
#
#
#
#     4558  :  0x11ce   fadd dword ptr [rax]   2
# read {'rax'}
# writes {'fpsw'}
#
#
#
#     4559  :  0x11cf   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4556 []
#            prev: write:  4557 ['rflags']
#
#
#
#     4560  :  0x11d0   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4522 []
#            prev: write:  4558 ['fpsw']
#
#
#
#     4561  :  0x11d1   add byte ptr [rax + rcx*2 + 0x2b], ah   4
# read {'ah', 'rcx', 'rax'}
# writes {'rflags'}
#            prev: write:  4559 ['rflags']
#
#
#
# #   4562  :  0x11d2   sub rax, qword ptr fs:[0x28]   9
# read {'fs', 'rax'}
# writes {'rflags', 'rax'}
#            prev: write:  4554 []
#            prev: write:  4555 []
#            prev: write:  4560 ['rflags']
#
#
#
#     4563  :  0x11d3   sub rax, qword ptr [0x28]   8
# read {'rax'}
# writes {'rflags', 'rax'}
#
#
#
#     4564  :  0x11d4   sub eax, dword ptr [0x28]   7
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4460 []
#
#
#
#     4565  :  0x11d5   add al, 0x25   2
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  4561 ['rflags']
#
#
#
#     4566  :  0x11d6   and eax, 0x28   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4567  :  0x11d7   sub byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4565 ['rflags']
#
#
#
#     4568  :  0x11d8   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4569  :  0x11d9   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4567 ['rflags']
#
#
#
#     4570  :  0x11da   add byte ptr [rbp + 0xb], dh   3
# read {'rbp', 'dh'}
# writes {'rflags'}
#            prev: write:  4568 ['rflags']
#
#
#
# #   4571  :  0x11db   jne 0x11e8   2
# read {'rflags'}
# writes set()
#            prev: write:  4562 ['rflags']
#            prev: write:  4563 ['rflags']
#            prev: write:  4564 ['rflags']
#            prev: write:  4566 ['rflags']
#            prev: write:  4569 ['rflags']
#
#
#
#     4572  :  0x11dc   or ecx, dword ptr [rax - 0x7f]   3
# read {'ecx', 'rax'}
# writes {'rflags', 'ecx'}
#
#
#
# #   4573  :  0x11dd   add rsp, 0xe0   7
# read {'rsp'}
# writes {'rflags', 'rsp'}
#            prev: write:  4570 ['rflags']
#
#
#
#     4574  :  0x11de   add esp, 0xe0   6
# read {'esp'}
# writes {'rflags', 'esp'}
#
#
#
#     4576  :  0x11e0   loopne 0x11e2   2
# read {'rflags', 'rcx'}
# writes {'rcx'}
#
#
#
#     4577  :  0x11e1   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4578  :  0x11e2   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4576 ['rcx']
#
#
#
#     4579  :  0x11e3   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  4577 ['rflags']
#
#
#
# #   4580  :  0x11e4   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4573 ['rflags']
#            prev: write:  4574 ['rflags']
#            prev: write:  4578 ['rflags']
#
#
#
#     4581  :  0x11e5   rcr byte ptr [rbx - 0x3d], 0xe8   4
# read {'rbx'}
# writes {'rflags'}
#            prev: write:  4579 ['rflags']
#
#
#
# #   4582  :  0x11e6   pop rbx   1
# read {'rsp'}
# writes {'rbx', 'rsp'}
#            prev: write:  4580 ['rflags']
#
#
#
# #   4583  :  0x11e7   ret    1
# read {'rsp'}
# writes {'rsp'}
#            prev: write:  4582 ['rsp']
#            ---->  4582
#
#
#
# #   4584  :  0x11e8   call 0x1080   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4571 []
#
#
#
#     4585  :  0x11e9   xchg ebx, eax   1
# read {'eax', 'ebx'}
# writes {'eax', 'ebx'}
#            prev: write:  4581 ['rflags']
#
#
#
#     4588  :  0x11ec   dec dword ptr [rdi]   2
# read {'rdi'}
# writes {'rflags'}
#
#
#
#     4589  :  0x11ed   nop dword ptr [rax]   3
# read {'rax'}
# writes set()
#            prev: write:  4584 ['rsp']
#
#
#
#     4591  :  0x11ef   add bl, dh   2
# read {'bl', 'dh'}
# writes {'bl', 'rflags'}
#
#
#
# #   4592  :  0x11f0   endbr64    4
# read set()
# writes set()
#            prev: write:  4589 []
#
#
#
#     4595  :  0x11f3   cli    1
# read set()
# writes set()
#
#
#
# #   4596  :  0x11f4   xor ebp, ebp   2
# read {'ebp'}
# writes {'ebp', 'rflags'}
#            prev: write:  4592 []
#            prev: write:  4595 []
#
#
#
#     4597  :  0x11f5   in eax, dx   1
# read {'dx'}
# writes {'eax'}
#
#
#
# #   4598  :  0x11f6   mov r9, rdx   3
# read {'rdx'}
# writes {'r9'}
#            prev: write:  4596 ['rflags']
#            prev: write:  4597 ['eax']
#
#
#
#     4599  :  0x11f7   mov ecx, edx   2
# read {'edx'}
# writes {'ecx'}
#
#
#
#     4600  :  0x11f8   rcr dword ptr [rsi + 0x48], 1   3
# read {'rsi'}
# writes {'rflags'}
#
#
#
# #   4601  :  0x11f9   pop rsi   1
# read {'rsp'}
# writes {'rsi', 'rsp'}
#            prev: write:  4598 []
#            prev: write:  4599 []
#
#
#
# #   4602  :  0x11fa   mov rdx, rsp   3
# read {'rsp'}
# writes {'rdx'}
#            prev: write:  4601 ['rsp']
#
#
#
#     4603  :  0x11fb   mov edx, esp   2
# read {'esp'}
# writes {'edx'}
#            prev: write:  4600 ['rflags']
#
#
#
#     4604  :  0x11fc   loop 0x1246   2
# read {'rcx'}
# writes {'rcx'}
#
#
#
# #   4605  :  0x11fd   and rsp, 0xfffffffffffffff0   4
# read {'rsp'}
# writes {'rflags', 'rsp'}
#            prev: write:  4602 []
#            prev: write:  4603 []
#
#
#
#     4606  :  0x11fe   and esp, 0xfffffff0   3
# read {'esp'}
# writes {'rflags', 'esp'}
#            prev: write:  4604 ['rcx']
#
#
#
#     4607  :  0x11ff   in al, 0xf0   2
# read set()
# writes {'al'}
#
#
#
# #   4609  :  0x1201   push rax   1
# read {'rsp', 'rax'}
# writes {'rsp'}
#            prev: write:  4605 ['rflags']
#            prev: write:  4606 ['rflags']
#            prev: write:  4607 ['al']
#
#
#
# #   4610  :  0x1202   push rsp   1
# read {'rsp'}
# writes {'rsp'}
#            prev: write:  4609 ['rsp']
#            ---->  4609
#
#
#
# #   4611  :  0x1203   xor r8d, r8d   3
# read {'r8d'}
# writes {'rflags', 'r8d'}
#            prev: write:  4610 ['rsp']
#
#
#
#     4612  :  0x1204   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4613  :  0x1205   sal byte ptr [rcx], 0xc9   3
# read {'rcx'}
# writes {'rflags'}
#
#
#
# #   4614  :  0x1206   xor ecx, ecx   2
# read {'ecx'}
# writes {'rflags', 'ecx'}
#            prev: write:  4611 ['rflags']
#            prev: write:  4612 ['rflags']
#
#
#
#     4615  :  0x1207   leave    1
# read {'rbp', 'rsp'}
# writes {'rbp', 'rsp'}
#
#
#
# #   4616  :  0x1208   lea rdi, [rip - 0x16f]   7
# read {'rip'}
# writes {'rdi'}
#            prev: write:  4613 ['rflags']
#            prev: write:  4614 ['rflags']
#            prev: write:  4615 ['rbp', 'rsp']
#
#
#
#     4617  :  0x1209   lea edi, [rip - 0x16f]   6
# read {'rip'}
# writes {'edi'}
#
#
#
#     4618  :  0x120a   cmp eax, 0xfffffe91   5
# read {'eax'}
# writes {'rflags'}
#
#
#
#     4619  :  0x120b   xchg ecx, eax   1
# read {'eax', 'ecx'}
# writes {'eax', 'ecx'}
#
#
#
# #   4623  :  0x120f   call qword ptr [rip + 0x2dc3]   6
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  4616 []
#            prev: write:  4617 []
#            prev: write:  4618 ['rflags']
#
#
#
#     4624  :  0x1210   adc eax, 0x2dc3   5
# read {'eax', 'rflags'}
# writes {'eax', 'rflags'}
#
#
#
#     4625  :  0x1211   ret    1
# read {'rsp'}
# writes {'rsp'}
#
#
#
#     4626  :  0x1212   sub eax, 0x66f40000   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4627  :  0x1213   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4628  :  0x1214   add ah, dh   2
# read {'ah', 'dh'}
# writes {'rflags', 'ah'}
#
#
#
# #   4629  :  0x1215   hlt    1
# read set()
# writes set()
#            prev: write:  4624 ['rflags']
#            prev: write:  4627 ['rflags']
#
#
#
#     4630  :  0x1216   nop word ptr cs:[rax + rax]   10
# read {'cs', 'rax'}
# writes set()
#            prev: write:  4628 ['rflags']
#            prev: write:  4629 []
#
#
#
#     4631  :  0x1217   nop dword ptr cs:[rax + rax]   9
# read {'cs', 'rax'}
# writes set()
#            prev: write:  4626 ['rflags']
#
#
#
#     4632  :  0x1218   nop dword ptr [rax + rax]   8
# read {'rax'}
# writes set()
#
#
#
#     4634  :  0x121a   test byte ptr [rax], al   2
# read {'rax'}
# writes set()
#
#
#
#     4635  :  0x121b   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4636  :  0x121c   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4634 []
#
#
#
#     4637  :  0x121d   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4635 ['rflags']
#
#
#
#     4638  :  0x121e   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4636 ['rflags']
#
#
#
#     4639  :  0x121f   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#            prev: write:  4637 ['rflags']
#
#
#
# #   4640  :  0x1220   lea rdi, [rip + 0x2de9]   7
# read {'rip'}
# writes {'rdi'}
#            prev: write:  4630 []
#            prev: write:  4631 []
#            prev: write:  4632 []
#            prev: write:  4638 ['rflags']
#            prev: write:  4791 ['rsp']
#
#
#
#     4641  :  0x1221   lea edi, [rip + 0x2de9]   6
# read {'rip'}
# writes {'edi'}
#
#
#
#     4642  :  0x1222   cmp eax, 0x2de9   5
# read {'eax'}
# writes {'rflags'}
#            prev: write:  4639 ['rflags']
#
#
#
#     4643  :  0x1223   jmp 0x48001255   5
# read set()
# writes set()
#
#
#
#     4644  :  0x1224   sub eax, 0x8d480000   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4645  :  0x1225   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4646  :  0x1226   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4647  :  0x1227   lea rax, [rip + 0x2de2]   7
# read {'rip'}
# writes {'rax'}
#            prev: write:  4640 []
#            prev: write:  4641 []
#            prev: write:  4642 ['rflags']
#            prev: write:  4645 ['rflags']
#
#
#
#     4648  :  0x1228   lea eax, [rip + 0x2de2]   6
# read {'rip'}
# writes {'eax'}
#
#
#
#     4649  :  0x1229   add eax, 0x2de2   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4644 ['rflags']
#            prev: write:  4646 ['rflags']
#
#
#
#     4650  :  0x122a   loop 0x1259   2
# read {'rcx'}
# writes {'rcx'}
#
#
#
#     4651  :  0x122b   sub eax, 0x39480000   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4652  :  0x122c   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  4650 ['rcx']
#
#
#
#     4653  :  0x122d   add byte ptr [rax + 0x39], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4654  :  0x122e   cmp rax, rdi   3
# read {'rdi', 'rax'}
# writes {'rflags'}
#            prev: write:  4647 []
#            prev: write:  4648 []
#            prev: write:  4649 ['rflags']
#            prev: write:  4652 ['rflags']
#
#
#
#     4655  :  0x122f   cmp eax, edi   2
# read {'eax', 'edi'}
# writes {'rflags'}
#
#
#
#     4656  :  0x1230   clc    1
# read set()
# writes {'rflags'}
#            prev: write:  4651 ['rflags']
#            prev: write:  4653 ['rflags']
#
#
#
# #   4657  :  0x1231   je 0x1248   2
# read {'rflags'}
# writes set()
#            prev: write:  4654 ['rflags']
#            prev: write:  4655 ['rflags']
#            prev: write:  4656 ['rflags']
#
#
#
#     4658  :  0x1232   adc eax, 0xa6058b48   5
# read {'eax', 'rflags'}
# writes {'eax', 'rflags'}
#
#
#
# #   4659  :  0x1233   mov rax, qword ptr [rip + 0x2da6]   7
# read {'rip'}
# writes {'rax'}
#
#
#
#     4660  :  0x1234   mov eax, dword ptr [rip + 0x2da6]   6
# read {'rip'}
# writes {'eax'}
#
#
#
#     4661  :  0x1235   add eax, 0x2da6   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     4662  :  0x1236   cmpsb byte ptr [rsi], byte ptr [rdi]   1
# read {'rdi', 'rsi', 'rflags'}
# writes {'rdi', 'rsi', 'rflags'}
#
#
#
#     4663  :  0x1237   sub eax, 0x85480000   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  4658 ['rflags']
#            prev: write:  4662 ['rdi', 'rsi', 'rflags']
#
#
#
#     4664  :  0x1238   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     4665  :  0x1239   add byte ptr [rax - 0x7b], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   4666  :  0x123a   test rax, rax   3
# read {'rax'}
# writes {'rflags'}
#            prev: write:  4659 []
#            prev: write:  4660 []
#            prev: write:  4661 ['rflags']
#            prev: write:  4664 ['rflags']
#
#
#
#     4667  :  0x123b   test eax, eax   2
# read {'eax'}
# writes {'rflags'}
#
#
#
#     4668  :  0x123c   sal byte ptr [rcx + rcx - 1], 0xe0   5
# read {'rcx'}
# writes {'rflags'}
# ...
#
#
#
# #   5138  :  0x1412   jne 0x13e0   2
# read {'rflags'}
# writes set()
#            prev: write:  5135 ['rflags']
#            prev: write:  5136 ['rflags']
#            prev: write:  5137 ['rflags']
#
#
#
#     5139  :  0x1413   int3    1
# read set()
# writes set()
#            prev: write:  5133 []
#
#
#
# #   5140  :  0x1414   mov edi, 0x7d   5
# read set()
# writes {'edi'}
#            prev: write:  5139 []
#
#
#
#     5141  :  0x1415   jge 0x1417   2
# read {'rflags'}
# writes set()
#
#
#
#     5142  :  0x1416   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5143  :  0x1417   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5144  :  0x1418   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  5142 ['rflags']
#
#
#
# #   5145  :  0x1419   call 0x1070   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5140 []
#            prev: write:  5143 ['rflags']
#
#
#
#     5146  :  0x141a   push rdx   1
# read {'rsp', 'rdx'}
# writes {'rsp'}
#            prev: write:  5144 ['rflags']
#
#
#
#     5147  :  0x141b   cld    1
# read set()
# writes {'rflags'}
#            prev: write:  5146 ['rsp']
#
#
#
#     5149  :  0x141d   dec dword ptr [rcx + 0x358d48ea]   6
# read {'rcx'}
# writes {'rflags'}
#
#
#
# #   5150  :  0x141e   mov edx, ebp   2
# read {'ebp'}
# writes {'edx'}
#            prev: write:  5145 ['rsp']
#
#
#
# #   5152  :  0x1420   lea rsi, [rip + 0xbf0]   7
# read {'rip'}
# writes {'rsi'}
#            prev: write:  5150 []
#
#
#
#     5153  :  0x1421   lea esi, [rip + 0xbf0]   6
# read {'rip'}
# writes {'esi'}
#
#
#
#     5154  :  0x1422   xor eax, 0xbf0   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     5155  :  0x1423   lock or eax, dword ptr [rax]   3
# read {'eax', 'rax'}
# writes {'eax', 'rflags'}
#            prev: write:  5149 ['rflags']
#
#
#
#     5156  :  0x1424   or eax, dword ptr [rax]   2
# read {'eax', 'rax'}
# writes {'eax', 'rflags'}
#
#
#
#     5157  :  0x1425   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5158  :  0x1426   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  5155 ['rflags']
#            prev: write:  5156 ['rflags']
#
#
#
# #   5159  :  0x1427   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  5152 []
#            prev: write:  5153 []
#            prev: write:  5154 ['rflags']
#            prev: write:  5157 ['rflags']
#
#
#
#     5160  :  0x1428   sar byte ptr [rdi + 2], 0xe8   7
# read {'rdi'}
# writes {'rflags'}
#            prev: write:  5158 ['rflags']
#
#
#
# #   5161  :  0x1429   mov edi, 2   5
# read set()
# writes {'edi'}
#            prev: write:  5159 ['rflags']
#
#
#
#     5162  :  0x142a   add al, byte ptr [rax]   2
# read {'al', 'rax'}
# writes {'al', 'rflags'}
#
#
#
#     5163  :  0x142b   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5164  :  0x142c   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5162 ['rflags']
#
#
#
#     5165  :  0x142d   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  5163 ['rflags']
#
#
#
# #   5166  :  0x142e   call 0x1090   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5161 []
#            prev: write:  5164 ['rflags']
#
#
#
#     5167  :  0x142f   pop rbp   1
# read {'rsp'}
# writes {'rbp', 'rsp'}
#            prev: write:  5160 ['rflags']
#            prev: write:  5165 ['rflags']
#
#
#
#     5168  :  0x1430   cld    1
# read set()
# writes {'rflags'}
#            prev: write:  5167 ['rsp']
#
#
#
#     5170  :  0x1432   dec dword ptr [rcx - 0x2076b712]   6
# read {'rcx'}
# writes {'rflags'}
#
#
#
# #   5171  :  0x1433   mov esi, ebp   2
# read {'ebp'}
# writes {'esi'}
#            prev: write:  5166 ['rsp']
#            prev: write:  5268 []
#
#
#
#     5172  :  0x1434   out dx, al   1
# read {'al', 'dx'}
# writes set()
#
#
#
# #   5173  :  0x1435   mov rdi, rbx   3
# read {'rbx'}
# writes {'rdi'}
#            prev: write:  5171 []
#            prev: write:  5172 []
#
#
#
#     5174  :  0x1436   mov edi, ebx   2
# read {'ebx'}
# writes {'edi'}
#
#
#
#     5175  :  0x1437   fucompi st(0)   2
# read {'st(0)'}
# writes {'fpsw', 'rflags'}
#
#
#
# #   5176  :  0x1438   call 0x12e0   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5170 ['rflags']
#            prev: write:  5173 []
#            prev: write:  5174 []
#
#
#
#     5177  :  0x1439   movabs dword ptr [0xc48348c589fffffe], eax   9
# read {'eax'}
# writes set()
#            prev: write:  5175 ['rflags', 'fpsw']
#
#
#
#     5180  :  0x143c   dec dword ptr [rcx - 0x3b7cb73b]   6
# read {'rcx'}
# writes {'rflags'}
#
#
#
# #   5181  :  0x143d   mov ebp, eax   2
# read {'eax'}
# writes {'ebp'}
#            prev: write:  5176 ['rsp']
#
#
#
# #   5183  :  0x143f   add rsp, 8   4
# read {'rsp'}
# writes {'rflags', 'rsp'}
#            prev: write:  5181 []
#            prev: write:  5266 []
#
#
#
#     5184  :  0x1440   add esp, 8   3
# read {'esp'}
# writes {'rflags', 'esp'}
#
#
#
#     5186  :  0x1442   or byte ptr [rcx + 0x358d48ea], cl   6
# read {'cl', 'rcx'}
# writes {'rflags'}
#            prev: write:  5177 []
#            prev: write:  5180 ['rflags']
#
#
#
# #   5187  :  0x1443   mov edx, ebp   2
# read {'ebp'}
# writes {'edx'}
#            prev: write:  5183 ['rflags']
#            prev: write:  5184 ['rflags']
#
#
#
# #   5189  :  0x1445   lea rsi, [rip + 0xbd6]   7
# read {'rip'}
# writes {'rsi'}
#            prev: write:  5187 []
#
#
#
#     5190  :  0x1446   lea esi, [rip + 0xbd6]   6
# read {'rip'}
# writes {'esi'}
#
#
#
#     5191  :  0x1447   xor eax, 0xbd6   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     5193  :  0x1449   or eax, dword ptr [rax]   2
# read {'eax', 'rax'}
# writes {'eax', 'rflags'}
#
#
#
#     5194  :  0x144a   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5195  :  0x144b   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  5193 ['rflags']
#
#
#
# #   5196  :  0x144c   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  5189 []
#            prev: write:  5190 []
#            prev: write:  5191 ['rflags']
#            prev: write:  5194 ['rflags']
#
#
#
#     5197  :  0x144d   rcr byte ptr [rbx - 0x41], 2   4
# read {'rbx'}
# writes {'rflags'}
#            prev: write:  5195 ['rflags']
#
#
#
# #   5198  :  0x144e   pop rbx   1
# read {'rsp'}
# writes {'rbx', 'rsp'}
#            prev: write:  5196 ['rflags']
#
#
#
# #   5199  :  0x144f   mov edi, 2   5
# read set()
# writes {'edi'}
#            prev: write:  5198 ['rsp']
#
#
#
#     5200  :  0x1450   add al, byte ptr [rax]   2
# read {'al', 'rax'}
# writes {'al', 'rflags'}
#
#
#
#     5201  :  0x1451   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5197 ['rflags']
#
#
#
#     5202  :  0x1452   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5200 ['rflags']
#
#
#
#     5203  :  0x1453   add byte ptr [rbp + 0x41], bl   3
# read {'rbp', 'bl'}
# writes {'rflags'}
#            prev: write:  5201 ['rflags']
#
#
#
# #   5204  :  0x1454   pop rbp   1
# read {'rsp'}
# writes {'rbp', 'rsp'}
#            prev: write:  5199 []
#            prev: write:  5202 ['rflags']
#
#
#
# #   5205  :  0x1455   pop r12   2
# read {'rsp'}
# writes {'rsp', 'r12'}
#            prev: write:  5204 ['rsp']
#            ---->  5204
#
#
#
#     5206  :  0x1456   pop rsp   1
# read {'rsp'}
# writes {'rsp'}
#            prev: write:  5203 ['rflags']
#
#
#
# #   5207  :  0x1457   pop r13   2
# read {'rsp'}
# writes {'rsp', 'r13'}
#            prev: write:  5205 ['rsp']
#            ---->  5205
#            prev: write:  5206 ['rsp']
#            ---->  5206
#
#
#
#     5208  :  0x1458   pop rbp   1
# read {'rsp'}
# writes {'rbp', 'rsp'}
#
#
#
# #   5209  :  0x1459   pop r14   2
# read {'rsp'}
# writes {'rsp', 'r14'}
#            prev: write:  5207 ['rsp']
#            ---->  5207
#            prev: write:  5208 ['rsp']
#            ---->  5208
#
#
#
#     5210  :  0x145a   pop rsi   1
# read {'rsp'}
# writes {'rsi', 'rsp'}
#
#
#
# #   5211  :  0x145b   pop r15   2
# read {'rsp'}
# writes {'rsp', 'r15'}
#            prev: write:  5209 ['rsp']
#            ---->  5209
#            prev: write:  5210 ['rsp']
#            ---->  5210
#
#
#
#     5212  :  0x145c   pop rdi   1
# read {'rsp'}
# writes {'rdi', 'rsp'}
#
#
#
# #   5213  :  0x145d   jmp 0x1090   5
# read set()
# writes set()
#            prev: write:  5211 ['rsp']
#            prev: write:  5212 ['rsp']
#
#
#
#     5214  :  0x145e   cld    2
# read set()
# writes {'rflags'}
#
#
#
#     5215  :  0x145f   cld    1
# read set()
# writes {'rflags'}
#
#
#
#     5217  :  0x1461   jmp qword ptr [rsi + 0xf]   3
# read {'rsi'}
# writes set()
#
#
#
#     5218  :  0x1462   nop word ptr [rax + rax]   6
# read {'rax'}
# writes set()
#
#
#
#     5219  :  0x1463   nop dword ptr [rax + rax]   5
# read {'rax'}
# writes set()
#
#
#
#     5221  :  0x1465   add byte ptr [rax], r8b   3
# read {'r8b', 'rax'}
# writes {'rflags'}
#
#
#
#     5222  :  0x1466   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5223  :  0x1467   add byte ptr [rax - 0x73], cl   3
# read {'cl', 'rax'}
# writes {'rflags'}
#
#
#
# #   5224  :  0x1468   lea rsi, [rip + 0xb9d]   7
# read {'rip'}
# writes {'rsi'}
#            prev: write:  5037 []
#            prev: write:  5218 []
#            prev: write:  5219 []
#            prev: write:  5221 ['rflags']
#            prev: write:  5222 ['rflags']
#
#
#
#     5225  :  0x1469   lea esi, [rip + 0xb9d]   6
# read {'rip'}
# writes {'esi'}
#
#
#
#     5226  :  0x146a   xor eax, 0xb9d   5
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  5223 ['rflags']
#
#
#
#     5227  :  0x146b   popfq    1
# read {'rsp'}
# writes {'rflags', 'rsp'}
#
#
#
#     5228  :  0x146c   or eax, dword ptr [rax]   2
# read {'eax', 'rax'}
# writes {'eax', 'rflags'}
#            prev: write:  5227 ['rsp', 'rflags']
#
#
#
#     5229  :  0x146d   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5230  :  0x146e   add byte ptr [rdi + 2], bh   6
# read {'rdi', 'bh'}
# writes {'rflags'}
#            prev: write:  5228 ['rflags']
#
#
#
# #   5231  :  0x146f   mov edi, 2   5
# read set()
# writes {'edi'}
#            prev: write:  5224 []
#            prev: write:  5225 []
#            prev: write:  5226 ['rflags']
#            prev: write:  5229 ['rflags']
#
#
#
#     5232  :  0x1470   add al, byte ptr [rax]   2
# read {'al', 'rax'}
# writes {'al', 'rflags'}
#
#
#
#     5233  :  0x1471   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5234  :  0x1472   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5232 ['rflags']
#
#
#
#     5235  :  0x1473   add byte ptr [rcx], dh   2
# read {'rcx', 'dh'}
# writes {'rflags'}
#            prev: write:  5233 ['rflags']
#
#
#
# #   5236  :  0x1474   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  5230 ['rflags']
#            prev: write:  5231 []
#            prev: write:  5234 ['rflags']
#
#
#
#     5237  :  0x1475   shr al, 0x15   3
# read {'al'}
# writes {'al', 'rflags'}
#            prev: write:  5235 ['rflags']
#
#
#
# #   5238  :  0x1476   call 0x1090   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5236 ['rflags']
#
#
#
#     5239  :  0x1477   adc eax, 0x31fffffc   5
# read {'eax', 'rflags'}
# writes {'eax', 'rflags'}
#
#
#
#     5240  :  0x1478   cld    1
# read set()
# writes {'rflags'}
#            prev: write:  5237 ['rflags']
#
#
#
#     5242  :  0x147a   push qword ptr [rcx]   2
# read {'rcx', 'rsp'}
# writes {'rsp'}
#
#
#
# #   5243  :  0x147b   xor eax, eax   2
# read {'eax'}
# writes {'eax', 'rflags'}
#            prev: write:  5238 ['rsp']
#            prev: write:  5290 []
#
#
#
#     5244  :  0x147c   ror byte ptr [rcx + 0x358d48ea], 0x91   7
# read {'rcx'}
# writes {'rflags'}
#            prev: write:  5239 ['rflags']
#            prev: write:  5242 ['rsp']
#
#
#
# #   5245  :  0x147d   mov edx, ebp   2
# read {'ebp'}
# writes {'edx'}
#            prev: write:  5243 ['rflags']
#
#
#
# #   5247  :  0x147f   lea rsi, [rip + 0xb91]   7
# read {'rip'}
# writes {'rsi'}
#            prev: write:  5245 []
#
#
#
#     5248  :  0x1480   lea esi, [rip + 0xb91]   6
# read {'rip'}
# writes {'esi'}
#
#
#
#     5249  :  0x1481   xor eax, 0xb91   5
# read {'eax'}
# writes {'eax', 'rflags'}
#
#
#
#     5250  :  0x1482   xchg ecx, eax   1
# read {'eax', 'ecx'}
# writes {'eax', 'ecx'}
#
#
#
#     5251  :  0x1483   or eax, dword ptr [rax]   2
# read {'eax', 'rax'}
# writes {'eax', 'rflags'}
#            prev: write:  5244 ['rflags']
#            prev: write:  5250 []
#
#
#
#     5252  :  0x1484   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5253  :  0x1485   add byte ptr [rdi + 2], bh   6
# read {'rdi', 'bh'}
# writes {'rflags'}
#            prev: write:  5251 ['rflags']
#
#
#
# #   5254  :  0x1486   mov edi, 2   5
# read set()
# writes {'edi'}
#            prev: write:  5247 []
#            prev: write:  5248 []
#            prev: write:  5249 ['rflags']
#            prev: write:  5252 ['rflags']
#
#
#
#     5255  :  0x1487   add al, byte ptr [rax]   2
# read {'al', 'rax'}
# writes {'al', 'rflags'}
#
#
#
#     5256  :  0x1488   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5257  :  0x1489   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5255 ['rflags']
#
#
#
#     5258  :  0x148a   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  5256 ['rflags']
#
#
#
# #   5259  :  0x148b   call 0x1090   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5253 ['rflags']
#            prev: write:  5254 []
#            prev: write:  5257 ['rflags']
#
#
#
#     5260  :  0x148c   add ah, bh   2
# read {'ah', 'bh'}
# writes {'rflags', 'ah'}
#            prev: write:  5258 ['rflags']
#
#
#
#     5261  :  0x148d   cld    1
# read set()
# writes {'rflags'}
#
#
#
#     5263  :  0x148f   inc dword ptr [rbp - 0x14548b13]   6
# read {'rbp'}
# writes {'rflags'}
#
#
#
# #   5264  :  0x1490   test ebp, ebp   2
# read {'ebp'}
# writes {'rflags'}
#            prev: write:  5259 ['rsp']
#
#
#
#     5265  :  0x1491   in eax, dx   1
# read {'dx'}
# writes {'eax'}
#
#
#
# #   5266  :  0x1492   je 0x143f   2
# read {'rflags'}
# writes set()
#            prev: write:  5264 ['rflags']
#            prev: write:  5265 ['eax']
#
#
#
#     5267  :  0x1493   stosd dword ptr [rdi], eax   1
# read {'rdi', 'eax', 'rflags'}
# writes {'rdi'}
#
#
#
# #   5268  :  0x1494   jmp 0x1433   2
# read set()
# writes set()
#            prev: write:  5267 ['rdi']
#
#
#
#     5269  :  0x1495   popfq    1
# read {'rsp'}
# writes {'rflags', 'rsp'}
#            prev: write:  5263 ['rflags']
#
#
#
#     5270  :  0x1496   nop word ptr cs:[rax + rax]   10
# read {'cs', 'rax'}
# writes set()
#            prev: write:  5269 ['rsp', 'rflags']
#
#
#
#     5271  :  0x1497   nop dword ptr cs:[rax + rax]   9
# read {'cs', 'rax'}
# writes set()
#
#
#
#     5272  :  0x1498   nop dword ptr [rax + rax]   8
# read {'rax'}
# writes set()
#
#
#
#     5274  :  0x149a   test byte ptr [rax], al   2
# read {'rax'}
# writes set()
#
#
#
#     5275  :  0x149b   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5276  :  0x149c   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5274 []
#
#
#
#     5277  :  0x149d   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5275 ['rflags']
#
#
#
#     5278  :  0x149e   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#            prev: write:  5276 ['rflags']
#
#
#
#     5279  :  0x149f   add byte ptr [rdi + 0x7d], bh   6
# read {'rdi', 'bh'}
# writes {'rflags'}
#            prev: write:  5277 ['rflags']
#
#
#
# #   5280  :  0x14a0   mov edi, 0x7d   5
# read set()
# writes {'edi'}
#            prev: write:  5055 []
#            prev: write:  5270 []
#            prev: write:  5271 []
#            prev: write:  5272 []
#            prev: write:  5278 ['rflags']
#
#
#
#     5281  :  0x14a1   jge 0x14a3   2
# read {'rflags'}
# writes set()
#
#
#
#     5282  :  0x14a2   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5283  :  0x14a3   add byte ptr [rax], al   2
# read {'al', 'rax'}
# writes {'rflags'}
#
#
#
#     5284  :  0x14a4   add al, ch   2
# read {'al', 'ch'}
# writes {'al', 'rflags'}
#            prev: write:  5282 ['rflags']
#
#
#
# #   5285  :  0x14a5   call 0x1070   5
# read {'rip', 'rsp'}
# writes {'rsp'}
#            prev: write:  5279 ['rflags']
#            prev: write:  5280 []
#            prev: write:  5283 ['rflags']
#
#
#
#     5287  :  0x14a7   sti    1
# read set()
# writes set()
#
#
#
# #   5290  :  0x14aa   jmp 0x147b   2
# read set()
# writes set()
#            prev: write:  5285 ['rsp']
#
#
#
#     5291  :  0x14ab   iretd    1
# read set()
# writes set()

# %%
H={}
def update_H():
    """ MATH determined from https://www.cs.purdue.edu/homes/zhan3299/res/ICSE19.pdf
    """
    global H
    for offset in H_list:
        
        prod = 1.0
        if len(H_list[offset])>0:
            for hint in H_list[offset]:
                prod = prod * hint
            H[offset] = prod
        else:
            H[offset] = BOTTOM
update_H()

# %%
RH = {}

for offset, inst in disasm.items():
    RH[offset] = set()

import math
def safe_product(numbers):
    res = None
    if len(numbers)==1:
        res =  numbers[0]
    else:
        log_sum = sum(math.log(x) for x in numbers)
        res = math.exp(log_sum)
    if res == 0:
        return 2.2250738585072014e-307
    return res
    

def calc_data_prob(offset):
    global RH
    d=1.0
    factors = []
    for rh in RH[offset]:
        factors.append(H[rh])
    if len(factors):
        d = safe_product(factors)
    return d


def _forward_propagation(disasm, data_prob, cfg):
    """ Iterative analyais to find instructions that lead to bad assembly.
        Outside of control flow, this is guarenteed to be data

        attempting to write ~line 10 algorithm 1 of https://www.cs.purdue.edu/homes/zhan3299/res/ICSE19.pdf
    """
    global RH
    debug = False
    fixed_point = True
    for offset, inst in disasm.items():
        if data_prob[offset] == 1.0:
            # Already know instruction is data
            continue
        if disasm[offset] is None:
            continue

        # line 13-15
        # update this instructions probability
        if H[offset] and offset not in RH[offset]:
            RH[offset].add(offset)
            
            # data_prob[offset] = 1.0
            data_prob[offset] = calc_data_prob(offset)
            # for h in RH[offset]:
            #     data_prob[offset] *= H[h]
                
            if 0 in data_prob.values():
                print('here1')
                return
        #line 16-20
        for n in ALL_RD_CFG[offset]:
            diff = set(RH[offset]) - set(RH[n])
            if len(diff):
                RH[n] = RH[n] | diff
                data_prob[n] = calc_data_prob(n)
                
                if n<offset:
                    fixed_point = False
    return fixed_point

# old_RH = RH.copy()
# _forward_propagation(disasm, data_prob, cfg)
# for i in RH:
#     if len(RH[i] - old_RH[i]):
#         print(RH[i] - old_RH[i])

# %%
import builtins
def _adjust_occlusion_probs(disasm, data_prob, occlusion_space):
    """ attempting to write ~line 22 algorithm 1 of https://www.cs.purdue.edu/homes/zhan3299/res/ICSE19.pdf

        Struggled with which probabilities should be adjusted and whether that is a global change
        or incremental


    """
    for offset, detail in disasm.items():
        if not data_prob[offset] == BOTTOM:
            # Only update if data probability is unknown
            continue

        
        # Find probability of being data for each overlapping instruction
        occluded_probs = []
        for j in occlusion_space[offset]:
            if data_prob[j] == BOTTOM : #todo nahid hack to prevent zero data prob
                continue
            occluded_probs.append(data_prob[j])

        print('here', offset)
        if len(occluded_probs)==0:
            # If not overlapping instructions, leave probability as is
            continue
        print('here2', offset , occluded_probs)
        # Step II. In lines 22-24, the algorithm traverses all the addresses
        # and performs local propagation of probabilities within occlusion space of individual instructions. Particularly, for each
        # address i, it finds its occluded peer j that has the minimal
        # probability (i.e., the most likely instruction). The likelihood
        # of i being data is hence computed as 1 − D[j] (line 24).
        new_occluded_prob = 1 - builtins.min(occluded_probs) # nahid fix*0.9
        print(data_prob[offset] , new_occluded_prob)
        if new_occluded_prob==0:
            data_prob[offset] = 0.1 #2.2250738585072014e-307
            print('occlud' ,offset)
        else:
            data_prob[offset] = new_occluded_prob 
        
        # if (data_prob[offset] ) ==0:
        #     print(1 - builtins.min(occluded_probs) , builtins.min(occluded_probs) ,occluded_probs)
        #     print('zero zero')
        # print("adjusting {} to {}".format(offset, data_prob[offset])) #todo uncomment

# here 5083
# here 5084
# here 5085
# here 5086
# here 5087
# here 5088
# here 5089
# here 5090
# here 5091
# here 5092
# here 5093
# here 5094
# here 5095
# here 5096
# here 5097
# here 5098
# here 5099
# here 5100
# here 5101
# here 5102
# here 5103
# here 5104
# here 5106
# here 5107
# here 5108
# here 5110
# here 5111
# here 5112
# here 5113
# here 5114
# here 5115
# here 5116
# here 5117
# here 5118
# here 5119
# here 5120
# here 5121
# here 5122
# here 5123
# here 5124
# here 5125
# here 5126
# here 5127
# here 5128
# here 5130
# here 5131
# here 5132
# here 5133
# here 5134
# here 5135
# here 5136
# here 5137
# here 5138
# here 5139
# here 5140
# here 5141
# here 5142
# here 5143
# here 5144
# here 5145
# here 5146
# here 5147
# here 5149
# here 5150
# here 5152
# here 5153
# here 5154
# here 5155
# here 5156
# here 5157
# here 5158
# here 5159
# here 5160
# here 5161
# here 5162
# here 5163
# here 5164
# here 5165
# here 5166
# here 5167
# here 5168
# here 5170
# here 5171
# here 5172
# here 5173
# here 5174
# here 5175
# here 5176
# here 5177
# here 5180
# here 5181
# here 5183
# here 5184
# here 5186
# here 5187
# here 5189
# here 5190
# here 5191
# here 5193
# here 5194
# here 5195
# here 5196
# here 5197
# here 5198
# here 5199
# here 5200
# here 5201
# here 5202
# here 5203
# here 5204
# here 5205
# here 5206
# here 5207
# here 5208
# here 5209
# here 5210
# here 5211
# here 5212
# here 5213
# here 5214
# here 5215
# here 5217
# here 5218
# here 5219
# here 5221
# here 5222
# here 5223
# here 5224
# here 5225
# here 5226
# here 5227
# here 5228
# here 5229
# here 5230
# here 5231
# here 5232
# here 5233
# here 5234
# here 5235
# here 5236
# here 5237
# here 5238
# here 5239
# here 5240
# here 5242
# here 5243
# here 5244
# here 5245
# here 5247
# here 5248
# here 5249
# here 5250
# here 5251
# here 5252
# here 5253
# here 5254
# here 5255
# here 5256
# here 5257
# here 5258
# here 5259
# here 5260
# here 5261
# here 5263
# here 5264
# here 5265
# here 5266
# here 5267
# here 5268
# here 5269
# here 5270
# here 5271
# here 5272
# here 5274
# here 5275
# here 5276
# here 5277
# here 5278
# here 5279
# here 5280
# here 5281
# here 5282
# here 5283
# here 5284
# here 5285
# here 5287
# here 5290
# here 5291

# %%
# def _back_propagation(disasm):
#     """ Iterative analysis to find instructions that lead to bad assembly.
#         Outside of control flow, this is guaranteed to be data.

#         Attempting to implement ~line 25 of Algorithm 1 from:
#         https://www.cs.purdue.edu/homes/zhan3299/res/ICSE19.pdf
#     """
#     fixed_point = True
#     for i in data_prob.keys():
#         if data_prob[i] == BOTTOM or i not in preds:
#             # Cannot propagate unknown probability or unknown predecessors
#             continue


#         for p in preds[i]:
#             # Updated probability propagation logic


#             if data_prob[p] == BOTTOM or data_prob[p] < data_prob[i]:
#                 data_prob[p] = data_prob[i] 
#                 fixed_point = False  # Mark that we've updated a probability

#                 if p > i:
#                     # Ensure continued processing if new updates occur
#                     fixed_point = False


#     return fixed_point

# %%
def _back_propagation(disasm):
    """ Iterative analysis to find instructions that lead to bad assembly.
        Outside of control flow, this is guaranteed to be data.

        Attempting to implement ~line 25 of Algorithm 1 from:
        https://www.cs.purdue.edu/homes/zhan3299/res/ICSE19.pdf
    """
    fixed_point = True
    for i in data_prob.keys():
        if data_prob[i] == BOTTOM or i not in ALL_RD_PRED:
            # Cannot propagate unknown probability or unknown predecessors
            continue


        for p in ALL_RD_PRED[i]:
            # Updated probability propagation logic


            if data_prob[p] == BOTTOM or data_prob[p] < data_prob[i]:
                data_prob[p] = data_prob[i] 
                fixed_point = False  # Mark that we've updated a probability

                if p > i:
                    # Ensure continued processing if new updates occur
                    fixed_point = False


    return fixed_point

#

# %%
for _ in range(30): #MAX_ITERATIONS
    if _%100==0:
        print('oter',_)

    fixed_point = True
    fixed_point = _forward_propagation(disasm, data_prob, cfg) and fixed_point
    fixed_point = _adjust_occlusion_probs(disasm, data_prob, occlusion_space) and fixed_point
    # fixed_point = _back_propagation(disasm) and fixed_point
    
    if fixed_point is True:
        break
# Out:
# oter 0
# here 4256
# here 4259
# here 4260
# here 4261
# here 4262
# here 4263
# here 4264
# here 4265
# here 4266
# here 4267
# here 4268
# here 4269
# here 4270
# here 4271
# here 4272
# here 4273
# here 4274
# here 4275
# here 4276
# here 4277
# here 4278
# here 4279
# here 4280
# here 4281
# here 4282
# here 4283
# here 4284
# here 4285
# here 4286
# here 4287
# here 4288
# here 4289
# here 4290
# here 4291
# here 4292
# here 4293
# here 4294
# here 4295
# here 4296
# here 4297
# here 4298
# here 4299
# here 4300
# here 4301
# here 4302
# here 4303
# here 4304
# here 4305
# here 4306
# here 4307
# here 4308
# here 4309
# here 4310
# here 4311
# here 4312
# here 4313
# here 4314
# here 4315
# here 4316
# here 4317
# here 4318
# here 4319
# here 4322
# here 4323
# here 4324
# here 4325
# here 4326
# here 4327
# here 4328
# here 4329
# here 4330
# here 4331
# here 4332
# here 4333
# here 4334
# here 4335
# here 4336
# here 4337
# here 4338
# here 4339
# here 4340
# here 4341
# here 4342
# here 4343
# here 4344
# here 4345
# here 4346
# here 4347
# here 4348
# here 4349
# here 4351
# here 4352
# here 4353
# here 4354
# here 4355
# here 4356
# here 4357
# here 4358
# here 4359
# here 4360
# here 4361
# here 4362
# here 4363
# here 4364
# here 4365
# here 4366
# here 4367
# here 4368
# here 4369
# here 4370
# here 4371
# here 4372
# here 4373
# here 4374
# here 4375
# here 4376
# here 4377
# here 4378
# here 4379
# here 4380
# here 4381
# here 4382
# here 4383
# here 4384
# here 4385
# here 4386
# here 4387
# here 4388
# here 4389
# here 4390
# here 4391
# here 4392
# here 4393
# here 4394
# here 4395
# here 4396
# here 4397
# here 4398
# here 4399
# here 4400
# here 4401
# here 4402
# here 4403
# here 4404
# here 4405
# here 4406
# here 4407
# here 4408
# here 4409
# here 4410
# here 4411
# here 4412
# here 4413
# here 4414
# here 4415
# here 4416
# here 4417
# here 4418
# here 4419
# here 4420
# here 4421
# here 4422
# here 4423
# here 4424
# here 4425
# here 4426
# here 4427
# here 4428
# here 4429
# here 4430
# here 4431
# here 4432
# here 4433
# here 4434
# here 4431
# here 4432
# here 4433
# here 4434
# here 4435
# here 4436
# here 4437
# here 4438
# here 4439
# here 4440
# here 4441
# here 4442
# here 4443
# here 4444
# here 4445
# here 4446
# here 4448
# here 4449
# here 4450
# here 4451
# here 4452
# here 4453
# here 4454
# here 4455
# here 4456
# here 4457
# here 4458
# here 4459
# here 4460
# here 4461
# here 4462
# here 4463
# here 4464
# here 4465
# here 4466
# here 4467
# here 4468
# here 4469
# here 4470
# here 4471
# here 4472
# here 4473
# here 4474
# here 4475
# here 4476
# here 4477
# here 4478
# here 4479
# here 4480
# here 4481
# here 4482
# here 4483
# here 4484
# here 4485
# here 4486

# %%
def is_interrupt(instr):
    return instr.mnemonic in {'int', 'int3', 'syscall', 'sysenter', 'iret', 'iretq'}
def is_nop(instr):
    return instr.mnemonic == 'nop'

# %%
P = {}
for offset in disasm:

    if disasm[offset] is None:
        P[offset] = 0
        continue
    if data_prob[offset] ==1.0 or data_prob[offset] is None:
        P[offset] = 0
        continue

    #padding
    if is_interrupt(disasm[offset]) or is_nop(disasm[offset]):
        P[offset] = 0
        continue

    s=1/data_prob[offset]
    
    for j in occlusion_space[offset]:
        s = s + 1/(data_prob[j] if data_prob[j] else 1)#nahid hack
    P[offset] = (1/data_prob[offset]) /s

# %%
predictions = []
for offset, p in P.items():

        if p >.01 :
            predictions.append(offset)
        # else:
        #     print(offset, p)
false_positive = set(predictions) -set (ground_truth_offsets)
false_negative = set (ground_truth_offsets) - set(predictions)
true_positive = set (ground_truth_offsets) & set(predictions)
print('false_positive: ',len(false_positive) , ' false_negative: ',len(false_negative) , ' true_positive: ',len(true_positive), 'total:', len(ground_truth_offsets))
# Out:
# false_positive:  0  false_negative:  39  true_positive:  206 total: 245

# %%
# false_positive:  0  false_negative:  70  true_positive:  175 total: 245

# %%
# for offset in disasm:

#     # try:
#         tok = "   "
#         if offset in false_negative:
#             tok = "N-N"
#         elif offset in false_positive:
#             tok = "x  "
#         if disasm[offset]:
#             print( str(format(P[offset],".15f" )).ljust(10),'  ',str( format(data_prob[offset],".15f" ) ).ljust(10), str(H[offset]).ljust(10) ,str(RH[offset]).ljust(20) ,tok, '#' if offset in ground_truth_offsets else ' ',' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)
#         else:
#             print( str(format(P[offset],".15f" )).ljust(10),'  ',str( format(data_prob[offset],".15f" ) ).ljust(10), str(H[offset]).ljust(10) ,str(RH[offset]).ljust(20) , tok,'   ', offset , ' : '    , 'invalid instruction') 

#     # except Exception as e:
#     #     print(traceback.print_exc() )
#     #     print(e)

# %%
for offset in disasm:

    # try:
        tok = "   "
        if offset in false_negative:
            tok = "N-N"
        elif offset in false_positive:
            tok = "x  "
        if disasm[offset]:
            print( str(format(P[offset],".15f" )).ljust(20),'  ',str( (data_prob[offset] ) ).ljust(20), str(H[offset]).ljust(10) ,str(RH[offset]).ljust(20) ,tok, '#' if offset in ground_truth_offsets else ' ',' ',offset , ' : ', hex(offset),' ',disasm[offset].mnemonic +' ' + disasm[offset].op_str  , ' ' , disasm[offset].size)
        else:
            print( str(format(P[offset],".15f" )).ljust(20),'  ',str( (data_prob[offset]) ).ljust(20), str(H[offset]).ljust(10) ,str(RH[offset]).ljust(20) , tok,'   ', offset , ' : '    , 'invalid instruction') 

    # except Exception as e:
    #     print(traceback.print_exc() )
    #     print(e)
# Out:
# 0.000000000000000       None                 None       set()                N-N #   4256  :  0x10a0   endbr64    4
# 0.000000000000000       1.0                  None       set()                        4257  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4258  :  invalid instruction
# 0.000000000000000       None                 None       set()                        4259  :  0x10a3   cli    1
# 0.000000000000000       None                 None       set()                N-N #   4260  :  0x10a4   push rbx   1
# 0.000000000000000       None                 None       set()                N-N #   4261  :  0x10a5   mov esi, 0x10   5
# 0.000000000000000       None                 None       set()                        4262  :  0x10a6   adc byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4263  :  0x10a7   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4264  :  0x10a8   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4265  :  0x10a9   add byte ptr [rax - 0x7f], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4266  :  0x10aa   sub rsp, 0xe0   7
# 0.000000000000000       None                 None       set()                        4267  :  0x10ab   sub esp, 0xe0   6
# 0.000000000000000       None                 None       set()                        4268  :  0x10ac   in al, dx   1
# 0.000000000000000       None                 None       set()                        4269  :  0x10ad   loopne 0x10af   2
# 0.000000000000000       None                 None       set()                        4270  :  0x10ae   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4271  :  0x10af   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4272  :  0x10b0   add byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4273  :  0x10b1   movdqa xmm0, xmmword ptr [rip + 0xf77]   8
# 0.000000000000000       None                 None       set()                        4274  :  0x10b2   movq mm0, qword ptr [rip + 0xf77]   7
# 0.000000000000000       None                 None       set()                        4275  :  0x10b3   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4276  :  0x10b4   add eax, 0xf77   5
# 0.000000000000000       None                 None       set()                        4277  :  0x10b5   ja 0x10c6   2
# 0.000000000000000       None                 None       set()                        4278  :  0x10b6   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4279  :  0x10b7   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4280  :  0x10b8   add byte ptr [rax + rcx*2 - 0x75], ah   4
# 0.000000000000000       None                 None       set()                N-N #   4281  :  0x10b9   mov rax, qword ptr fs:[0x28]   9
# 0.000000000000000       None                 None       set()                        4282  :  0x10ba   mov rax, qword ptr [0x28]   8
# 0.000000000000000       None                 None       set()                        4283  :  0x10bb   mov eax, dword ptr [0x28]   7
# 0.000000000000000       None                 None       set()                        4284  :  0x10bc   add al, 0x25   2
# 0.000000000000000       None                 None       set()                        4285  :  0x10bd   and eax, 0x28   5
# 0.000000000000000       None                 None       set()                        4286  :  0x10be   sub byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4287  :  0x10bf   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4288  :  0x10c0   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4289  :  0x10c1   add byte ptr [rax - 0x77], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4290  :  0x10c2   mov qword ptr [rsp + 0xd8], rax   8
# 0.000000000000000       None                 None       set()                        4291  :  0x10c3   mov dword ptr [rsp + 0xd8], eax   7
# 0.000000000000000       None                 None       set()                        4292  :  0x10c4   test byte ptr [rax + rbx*8], ah   3
# 0.000000000000000       None                 None       set()                        4293  :  0x10c5   and al, 0xd8   2
# 0.000000000000000       None                 None       set()                        4294  :  0x10c6   fadd dword ptr [rax]   2
# 0.000000000000000       None                 None       set()                        4295  :  0x10c7   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4296  :  0x10c8   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4297  :  0x10c9   add byte ptr [rcx], dh   2
# 0.000000000000000       None                 None       set()                N-N #   4298  :  0x10ca   xor eax, eax   2
# 0.000000000000000       None                 None       set()                        4299  :  0x10cb   ror byte ptr [rax - 0x75], 5   4
# 0.000000000000000       None                 None       set()                N-N #   4300  :  0x10cc   mov rax, qword ptr [rip + 0xffd]   7
# 0.000000000000000       None                 None       set()                        4301  :  0x10cd   mov eax, dword ptr [rip + 0xffd]   6
# 0.000000000000000       None                 None       set()                        4302  :  0x10ce   add eax, 0xffd   5
# 0.000000000000000       None                 None       set()                        4303  :  0x10cf   std    1
# 0.000000000000000       None                 None       set()                        4304  :  0x10d0   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4305  :  0x10d1   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4306  :  0x10d2   add byte ptr [rax - 0x73], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4307  :  0x10d3   lea rbx, [rsp + 0x90]   8
# 0.000000000000000       None                 None       set()                        4308  :  0x10d4   lea ebx, [rsp + 0x90]   7
# 0.000000000000000       None                 None       set()                        4309  :  0x10d5   pushfq    1
# 0.000000000000000       None                 None       set()                        4310  :  0x10d6   and al, 0x90   2
# 0.000000000000000       None                 None       set()                        4311  :  0x10d7   nop    1
# 0.000000000000000       None                 None       set()                        4312  :  0x10d8   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4313  :  0x10d9   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4314  :  0x10da   add bh, al   2
# 0.000000000000000       None                 None       set()                N-N #   4315  :  0x10db   mov dword ptr [rsp + 0x18], 0xffffffa2   8
# 0.000000000000000       None                 None       set()                        4316  :  0x10dc   and al, 0x18   3
# 0.000000000000000       None                 None       set()                        4317  :  0x10dd   and al, 0x18   2
# 0.000000000000000       None                 None       set()                        4318  :  0x10de   sbb byte ptr [rdx + 0xfffffff], ah   6
# 0.000000000000000       None                 None       set()                        4319  :  0x10df   movabs byte ptr [0x902484290fffffff], al   9
# 0.000000000000000       1.0                  None       set()                        4320  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4321  :  invalid instruction
# 0.000000000000000       None                 None       set()                        4322  :  0x10e2   dec dword ptr [rdi]   2
# 0.000000000000000       None                 None       set()                N-N #   4323  :  0x10e3   movaps xmmword ptr [rsp + 0x90], xmm0   8
# 0.000000000000000       None                 None       set()                        4324  :  0x10e4   sub dword ptr [rsp + 0x90], eax   7
# 0.000000000000000       None                 None       set()                        4325  :  0x10e5   test byte ptr [rax + rdx*4], ah   3
# 0.000000000000000       None                 None       set()                        4326  :  0x10e6   and al, 0x90   2
# 0.000000000000000       None                 None       set()                        4327  :  0x10e7   nop    1
# 0.000000000000000       None                 None       set()                        4328  :  0x10e8   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4329  :  0x10e9   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4330  :  0x10ea   add byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4331  :  0x10eb   movdqa xmm0, xmmword ptr [rip + 0xf4d]   8
# 0.000000000000000       None                 None       set()                        4332  :  0x10ec   movq mm0, qword ptr [rip + 0xf4d]   7
# 0.000000000000000       None                 None       set()                        4333  :  0x10ed   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4334  :  0x10ee   add eax, 0xf4d   5
# 0.000000000000000       None                 None       set()                        4335  :  0x10ef   sldt word ptr [r8]   4
# 0.000000000000000       None                 None       set()                        4336  :  0x10f0   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4337  :  0x10f1   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4338  :  0x10f2   add byte ptr [rax - 0x77], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4339  :  0x10f3   mov rdi, rbx   3
# 0.000000000000000       None                 None       set()                        4340  :  0x10f4   mov edi, ebx   2
# 0.000000000000000       None                 None       set()                        4341  :  0x10f5   fisttp word ptr [rax - 0x77]   3
# 0.000000000000000       None                 None       set()                N-N #   4342  :  0x10f6   mov qword ptr [rsp + 0x10], rax   5
# 0.000000000000000       None                 None       set()                        4343  :  0x10f7   mov dword ptr [rsp + 0x10], eax   4
# 0.000000000000000       None                 None       set()                        4344  :  0x10f8   and al, 0x10   3
# 0.000000000000000       None                 None       set()                        4345  :  0x10f9   and al, 0x10   2
# 0.000000000000000       None                 None       set()                        4346  :  0x10fa   adc byte ptr [rax - 0x75], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4347  :  0x10fb   mov rax, qword ptr [rip + 0xfd6]   7
# 0.000000000000000       None                 None       set()                        4348  :  0x10fc   mov eax, dword ptr [rip + 0xfd6]   6
# 0.000000000000000       None                 None       set()                        4349  :  0x10fd   add eax, 0xfd6   5
# 0.000000000000000       1.0                  None       set()                        4350  :  invalid instruction
# 0.000000000000000       None                 None       set()                        4351  :  0x10ff   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4352  :  0x1100   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4353  :  0x1101   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4354  :  0x1102   movaps xmmword ptr [rsp + 0xa0], xmm0   8
# 0.000000000000000       None                 None       set()                        4355  :  0x1103   sub dword ptr [rsp + 0xa0], eax   7
# 0.000000000000000       None                 None       set()                        4356  :  0x1104   test byte ptr [rax + riz*4], ah   3
# 0.000000000000000       None                 None       set()                        4357  :  0x1105   and al, 0xa0   2
# 0.000000000000000       None                 None       set()                        4358  :  0x1106   movabs al, byte ptr [0x3e056f0f66000000]   9
# 0.000000000000000       None                 None       set()                        4359  :  0x1107   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4360  :  0x1108   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4361  :  0x1109   add byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4362  :  0x110a   movdqa xmm0, xmmword ptr [rip + 0xf3e]   8
# 0.000000000000000       None                 None       set()                        4363  :  0x110b   movq mm0, qword ptr [rip + 0xf3e]   7
# 0.000000000000000       None                 None       set()                        4364  :  0x110c   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4365  :  0x110d   add eax, 0xf3e   5
# 0.000000000000000       None                 None       set()                        4366  :  0x110e   sldt word ptr ds:[rax]   4
# 0.000000000000000       None                 None       set()                        4367  :  0x110f   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4368  :  0x1110   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4369  :  0x1111   add byte ptr [rax - 0x77], cl   3
# 0.000000000000000       None                 None       set()                N-N #   4370  :  0x1112   mov qword ptr [rsp + 0x80], rax   8
# 0.000000000000000       None                 None       set()                        4371  :  0x1113   mov dword ptr [rsp + 0x80], eax   7
# 0.000000000000000       None                 None       set()                        4372  :  0x1114   test byte ptr [rax + rax*4], ah   3
# 0.000000000000000       None                 None       set()                        4373  :  0x1115   and al, 0x80   2
# 0.000000000000000       None                 None       set()                        4374  :  0x1116   add byte ptr [rax], 0   3
# 0.000000000000000       None                 None       set()                        4375  :  0x1117   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4376  :  0x1118   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4377  :  0x1119   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4378  :  0x111a   movaps xmmword ptr [rsp + 0xb0], xmm0   8
# 0.000000000000000       None                 None       set()                        4379  :  0x111b   sub dword ptr [rsp + 0xb0], eax   7
# 0.000000000000000       None                 None       set()                        4380  :  0x111c   test byte ptr [rax + rsi*4], ah   3
# 0.000000000000000       None                 None       set()                        4381  :  0x111d   and al, 0xb0   2
# 0.000000000000000       None                 None       set()                        4382  :  0x111e   mov al, 0   2
# 0.000000000000000       None                 None       set()                        4383  :  0x111f   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4384  :  0x1120   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4385  :  0x1121   add byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4386  :  0x1122   movdqa xmm0, xmmword ptr [rip + 0xf36]   8
# 0.000000000000000       None                 None       set()                        4387  :  0x1123   movq mm0, qword ptr [rip + 0xf36]   7
# 0.000000000000000       None                 None       set()                        4388  :  0x1124   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4389  :  0x1125   add eax, 0xf36   5
# 0.000000000000000       None                 None       set()                        4390  :  0x1126   sldt word ptr ss:[rax]   4
# 0.000000000000000       None                 None       set()                        4391  :  0x1127   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4392  :  0x1128   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4393  :  0x1129   add bh, al   2
# 0.000000000000000       None                 None       set()                N-N #   4394  :  0x112a   mov dword ptr [rsp + 0x40], 1   8
# 0.000000000000000       None                 None       set()                        4395  :  0x112b   and al, 0x40   3
# 0.000000000000000       None                 None       set()                        4396  :  0x112c   and al, 0x40   2
# 0.000000000000000       None                 None       set()                        4397  :  0x112d   add dword ptr [rax], eax   3
# 0.000000000000000       None                 None       set()                        4398  :  0x112e   add dword ptr [rax], eax   2
# 0.000000000000000       None                 None       set()                        4399  :  0x112f   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4400  :  0x1130   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4401  :  0x1131   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4402  :  0x1132   movaps xmmword ptr [rsp + 0xc0], xmm0   8
# 0.000000000000000       None                 None       set()                        4403  :  0x1133   sub dword ptr [rsp + 0xc0], eax   7
# 0.000000000000000       None                 None       set()                        4404  :  0x1134   test byte ptr [rax + rax*8], ah   3
# 0.000000000000000       None                 None       set()                        4405  :  0x1135   and al, 0xc0   2
# 0.000000000000000       None                 None       set()                        4406  :  0x1136   rol byte ptr [rax], 0   3
# 0.000000000000000       None                 None       set()                        4407  :  0x1137   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4408  :  0x1138   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4409  :  0x1139   add byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4410  :  0x113a   movdqa xmm0, xmmword ptr [rip + 0xf2e]   8
# 0.000000000000000       None                 None       set()                        4411  :  0x113b   movq mm0, qword ptr [rip + 0xf2e]   7
# 0.000000000000000       None                 None       set()                        4412  :  0x113c   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4413  :  0x113d   add eax, 0xf2e   5
# 0.000000000000000       None                 None       set()                        4414  :  0x113e   sldt word ptr cs:[rax]   4
# 0.000000000000000       None                 None       set()                        4415  :  0x113f   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4416  :  0x1140   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4417  :  0x1141   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4418  :  0x1142   movaps xmmword ptr [rsp], xmm0   4
# 0.000000000000000       None                 None       set()                        4419  :  0x1143   sub dword ptr [rsp], eax   3
# 0.000000000000000       None                 None       set()                        4420  :  0x1144   add al, 0x24   2
# 0.000000000000000       None                 None       set()                        4421  :  0x1145   and al, 0x66   2
# 0.000000000000000       None                 None       set()                N-N #   4422  :  0x1146   movdqa xmm0, xmmword ptr [rip + 0xf32]   8
# 0.000000000000000       None                 None       set()                        4423  :  0x1147   movq mm0, qword ptr [rip + 0xf32]   7
# 0.000000000000000       None                 None       set()                        4424  :  0x1148   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4425  :  0x1149   add eax, 0xf32   5
# 0.000000000000000       None                 None       set()                        4426  :  0x114a   xor cl, byte ptr [rdi]   2
# 0.000000000000000       None                 None       set()                        4427  :  0x114b   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4428  :  0x114c   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4429  :  0x114d   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4430  :  0x114e   movaps xmmword ptr [rsp + 0x50], xmm0   5
# 0.000000000000000       None                 None       set()                        4431  :  0x114f   sub dword ptr [rsp + 0x50], eax   4
# 0.000000000000000       None                 None       set()                        4432  :  0x1150   and al, 0x50   3
# 0.000000000000000       None                 None       set()                        4433  :  0x1151   and al, 0x50   2
# 0.000000000000000       None                 None       set()                        4434  :  0x1152   push rax   1
# 0.000000000000000       None                 None       set()                N-N #   4435  :  0x1153   movdqa xmm0, xmmword ptr [rip + 0xf35]   8
# 0.000000000000000       None                 None       set()                        4436  :  0x1154   movq mm0, qword ptr [rip + 0xf35]   7
# 0.000000000000000       None                 None       set()                        4437  :  0x1155   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4438  :  0x1156   add eax, 0xf35   5
# 0.000000000000000       None                 None       set()                        4439  :  0x1157   xor eax, 0xf00000f   5
# 0.000000000000000       None                 None       set()                        4440  :  0x1158   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4441  :  0x1159   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4442  :  0x115a   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4443  :  0x115b   movaps xmmword ptr [rsp + 0x60], xmm0   5
# 0.000000000000000       None                 None       set()                        4444  :  0x115c   sub dword ptr [rsp + 0x60], eax   4
# 0.000000000000000       None                 None       set()                        4445  :  0x115d   and al, 0x60   3
# 0.000000000000000       None                 None       set()                        4446  :  0x115e   and al, 0x60   2
# 0.000000000000000       1.0                  None       set()                        4447  :  invalid instruction
# 0.000000000000000       None                 None       set()                N-N #   4448  :  0x1160   movdqa xmm0, xmmword ptr [rip + 0xf38]   8
# 0.000000000000000       None                 None       set()                        4449  :  0x1161   movq mm0, qword ptr [rip + 0xf38]   7
# 0.000000000000000       None                 None       set()                        4450  :  0x1162   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4451  :  0x1163   add eax, 0xf38   5
# 0.000000000000000       None                 None       set()                        4452  :  0x1164   cmp byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                        4453  :  0x1165   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4454  :  0x1166   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4455  :  0x1167   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4456  :  0x1168   movaps xmmword ptr [rsp + 0x70], xmm0   5
# 0.000000000000000       None                 None       set()                        4457  :  0x1169   sub dword ptr [rsp + 0x70], eax   4
# 0.000000000000000       None                 None       set()                        4458  :  0x116a   and al, 0x70   3
# 0.000000000000000       None                 None       set()                        4459  :  0x116b   and al, 0x70   2
# 0.000000000000000       None                 None       set()                        4460  :  0x116c   jo 0x11d4   2
# 0.000000000000000       None                 None       set()                N-N #   4461  :  0x116d   movdqa xmm0, xmmword ptr [rip + 0xf3b]   8
# 0.000000000000000       None                 None       set()                        4462  :  0x116e   movq mm0, qword ptr [rip + 0xf3b]   7
# 0.000000000000000       None                 None       set()                        4463  :  0x116f   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4464  :  0x1170   add eax, 0xf3b   5
# 0.000000000000000       None                 None       set()                        4465  :  0x1171   cmp ecx, dword ptr [rdi]   2
# 0.000000000000000       None                 None       set()                        4466  :  0x1172   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4467  :  0x1173   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4468  :  0x1174   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4469  :  0x1175   movaps xmmword ptr [rsp + 0x20], xmm0   5
# 0.000000000000000       None                 None       set()                        4470  :  0x1176   sub dword ptr [rsp + 0x20], eax   4
# 0.000000000000000       None                 None       set()                        4471  :  0x1177   and al, 0x20   3
# 0.000000000000000       None                 None       set()                        4472  :  0x1178   and al, 0x20   2
# 0.000000000000000       None                 None       set()                        4473  :  0x1179   and byte ptr [rsi + 0xf], ah   3
# 0.000000000000000       None                 None       set()                N-N #   4474  :  0x117a   movdqa xmm0, xmmword ptr [rip + 0xf3e]   8
# 0.000000000000000       None                 None       set()                        4475  :  0x117b   movq mm0, qword ptr [rip + 0xf3e]   7
# 0.000000000000000       None                 None       set()                        4476  :  0x117c   outsd dx, dword ptr [rsi]   1
# 0.000000000000000       None                 None       set()                        4477  :  0x117d   add eax, 0xf3e   5
# 0.000000000000000       None                 None       set()                        4478  :  0x117e   sldt word ptr ds:[rax]   4
# 0.000000000000000       None                 None       set()                        4479  :  0x117f   sldt word ptr [rax]   3
# 0.000000000000000       None                 None       set()                        4480  :  0x1180   add byte ptr [rax], al   2
# 0.000000000000000       None                 None       set()                        4481  :  0x1181   add byte ptr [rdi], cl   2
# 0.000000000000000       None                 None       set()                N-N #   4482  :  0x1182   movaps xmmword ptr [rsp + 0x30], xmm0   5
# 0.000000000000000       None                 None       set()                        4483  :  0x1183   sub dword ptr [rsp + 0x30], eax   4
# 0.000000000000000       None                 None       set()                        4484  :  0x1184   and al, 0x30   3
# 0.000000000000000       None                 None       set()                        4485  :  0x1185   and al, 0x30   2
# 0.000000000000000       None                 None       set()                        4486  :  0x1186   xor al, ch   2
# 0.999984741212834       1.525902e-05         1.525902e-05 {4487}                   #   4487  :  0x1187   call 0x1380   5
# 0.000015259020000       0.99998474098        None       set()                        4488  :  0x1188   hlt    1
# 0.000015259020000       0.99998474098        None       set()                        4489  :  0x1189   add dword ptr [rax], eax   2
# 0.000015258787166       0.99998474098        None       set()                        4490  :  0x118a   add byte ptr [rax], al   2
# 0.000015258787166       0.99998474098        None       set()                        4491  :  0x118b   add byte ptr [rax - 0x77], cl   3
# 0.999984740980000       1.525902e-05         None       {4487}                   #   4492  :  0x118c   mov rdi, rsp   3
# 0.000015258787166       0.99998474098        None       set()                        4493  :  0x118d   mov edi, esp   2
# 0.000015258787166       0.99998474098        None       set()                        4494  :  0x118e   out 0xbe, eax   2
# 0.999984740980000       1.525902e-05         None       {4487}                   #   4495  :  0x118f   mov esi, 7   5
# 0.000000000000000       1.0                  None       set()                        4496  :  invalid instruction
# 0.000015259020000       0.99998474098        None       set()                        4497  :  0x1191   add byte ptr [rax], al   2
# 0.000015258787166       0.99998474098        None       set()                        4498  :  0x1192   add byte ptr [rax], al   2
# 0.000015258787166       0.99998474098        None       set()                        4499  :  0x1193   add al, ch   2
# 0.999999999767159       2.328376913604001e-10 1.525902e-05 {4500, 4487}             #   4500  :  0x1194   call 0x1380   5
# 0.000000000232838       0.9999999997671624   None       set()                        4501  :  0x1195   out 1, eax   2
# 0.000000000232838       0.9999999997671624   None       set()                        4502  :  0x1196   add dword ptr [rax], eax   2
# 0.000000000232838       0.9999999997671624   None       set()                        4503  :  0x1197   add byte ptr [rax], al   2
# 0.000000000232838       0.9999999997671624   None       set()                        4504  :  0x1198   add byte ptr [rax - 0x73], cl   3
# 0.999999999767162       2.328376913604001e-10 None       {4500, 4487}             #   4505  :  0x1199   lea rdi, [rsp + 0x50]   5
# 0.000000000232838       0.9999999997671624   None       set()                        4506  :  0x119a   lea edi, [rsp + 0x50]   4
# 0.000000000232838       0.9999999997671624   None       set()                        4507  :  0x119b   jl 0x11c1   2
# 0.000000000232838       0.9999999997671624   None       set()                        4508  :  0x119c   and al, 0x50   2
# 0.000000000232838       0.9999999997671624   None       set()                        4509  :  0x119d   push rax   1
# 1.000000000000000       2.328376913604001e-10 None       {4500, 4487}             #   4510  :  0x119e   mov esi, 0xe   5
# 0.000000000000000       1.0                  None       set()                        4511  :  invalid instruction
# 0.000000000232838       0.9999999997671624   None       set()                        4512  :  0x11a0   add byte ptr [rax], al   2
# 0.000000000232838       0.9999999997671624   None       set()                        4513  :  0x11a1   add byte ptr [rax], al   2
# 0.000000000232838       0.9999999997671624   None       set()                        4514  :  0x11a2   add al, ch   2
# 0.999999999999996       3.55287498922216e-15 1.525902e-05 {4515, 4500, 4487}       #   4515  :  0x11a3   call 0x1380   5
# 0.000000000000004       0.9999999999999964   None       set()                        4516  :  0x11a4   fadd dword ptr [rcx]   2
# 0.000000000000004       0.9999999999999964   None       set()                        4517  :  0x11a5   add dword ptr [rax], eax   2
# 0.000000000000004       0.9999999999999964   None       set()                        4518  :  0x11a6   add byte ptr [rax], al   2
# 0.000000000000004       0.9999999999999964   None       set()                        4519  :  0x11a7   add byte ptr [rax - 0x73], cl   3
# 0.999999999999996       3.55287498922216e-15 None       {4515, 4500, 4487}       #   4520  :  0x11a8   lea rdi, [rsp + 0x20]   5
# 0.000000000000004       0.9999999999999964   None       set()                        4521  :  0x11a9   lea edi, [rsp + 0x20]   4
# 0.000000000000004       0.9999999999999964   None       set()                        4522  :  0x11aa   jl 0x11d0   2
# 0.000000000000004       0.9999999999999964   None       set()                        4523  :  0x11ab   and al, 0x20   2
# 0.000000000000004       0.9999999999999964   None       set()                        4524  :  0x11ac   and byte ptr [rsi + 9], bh   6
# 0.999999999999996       3.55287498922216e-15 None       {4515, 4500, 4487}       #   4525  :  0x11ad   mov esi, 9   5
# 0.000000000000004       0.9999999999999964   None       set()                        4526  :  0x11ae   or dword ptr [rax], eax   2
# 0.000000000000004       0.9999999999999964   None       set()                        4527  :  0x11af   add byte ptr [rax], al   2
# 0.000000000000004       0.9999999999999964   None       set()                        4528  :  0x11b0   add byte ptr [rax], al   2
# 0.000000000000004       0.9999999999999964   None       set()                        4529  :  0x11b1   add al, ch   2
# 1.000000000000000       5.421339051804093e-20 1.525902e-05 {4530, 4515, 4500, 4487}     #   4530  :  0x11b2   call 0x1380   5
# 0.000000000000000       1.0                  None       set()                        4531  :  0x11b3   leave    1
# 0.000000000000000       1.0                  None       set()                        4532  :  0x11b4   add dword ptr [rax], eax   2
# 0.000000000000000       1.0                  None       set()                        4533  :  0x11b5   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4534  :  0x11b6   add byte ptr [rcx], dh   2
# 1.000000000000000       5.421339051804093e-20 None       {4530, 4515, 4500, 4487}     #   4535  :  0x11b7   xor esi, esi   2
# 0.000000000000000       1.0                  None       set()                        4536  :  0x11b8   div byte ptr [rcx]   2
# 1.000000000000000       5.421339051804093e-20 None       {4530, 4515, 4500, 4487}     #   4537  :  0x11b9   xor edi, edi   2
# 0.000000000000000       1.0                  None       set()                        4538  :  invalid instruction
# 1.000000000000000       8.272432101826e-25   1.525902e-05 {4515, 4487, 4530, 4500, 4539}     #   4539  :  0x11bb   call 0x1380   5
# 0.000000000000000       1.0                  None       set()                        4540  :  0x11bc   rol byte ptr [rcx], 0   3
# 0.000000000000000       1.0                  None       set()                        4541  :  0x11bd   add dword ptr [rax], eax   2
# 0.000000000000000       1.0                  None       set()                        4542  :  0x11be   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4543  :  0x11bf   add byte ptr [rcx], dh   2
# 1.000000000000000       8.272432101826e-25   None       {4530, 4515, 4500, 4487, 4539}     #   4544  :  0x11c0   xor esi, esi   2
# 0.000000000000000       1.0                  None       set()                        4545  :  0x11c1   test byte ptr [rax - 0x77], -0x21   4
# 1.000000000000000       8.272432101826e-25   None       {4530, 4515, 4500, 4487, 4539}     #   4546  :  0x11c2   mov rdi, rbx   3
# 0.000000000000000       1.0                  None       set()                        4547  :  0x11c3   mov edi, ebx   2
# 0.000000000000000       1.0                  None       set()                        4548  :  0x11c4   fucompi st(0)   2
# 1.000000000000000       1.2622920689040363e-29 1.525902e-05 {4530, 4515, 4500, 4549, 4487, 4539}     #   4549  :  0x11c5   call 0x1380   5
# 0.000000000000000       1.0                  None       set()                        4550  :  0x11c6   mov dh, 1   2
# 0.000000000000000       1.0                  None       set()                        4551  :  0x11c7   add dword ptr [rax], eax   2
# 0.000000000000000       1.0                  None       set()                        4552  :  0x11c8   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4553  :  0x11c9   add byte ptr [rax - 0x75], cl   3
# 1.000000000000000       1.2622920689040363e-29 None       {4530, 4515, 4500, 4549, 4487, 4539}     #   4554  :  0x11ca   mov rax, qword ptr [rsp + 0xd8]   8
# 0.000000000000000       1.0                  None       set()                        4555  :  0x11cb   mov eax, dword ptr [rsp + 0xd8]   7
# 0.000000000000000       1.0                  None       set()                        4556  :  0x11cc   test byte ptr [rax + rbx*8], ah   3
# 0.000000000000000       1.0                  None       set()                        4557  :  0x11cd   and al, 0xd8   2
# 0.000000000000000       1.0                  None       set()                        4558  :  0x11ce   fadd dword ptr [rax]   2
# 0.000000000000000       1.0                  None       set()                        4559  :  0x11cf   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4560  :  0x11d0   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4561  :  0x11d1   add byte ptr [rax + rcx*2 + 0x2b], ah   4
# 1.000000000000000       1.2622920689040363e-29 None       {4530, 4515, 4500, 4549, 4487, 4539}     #   4562  :  0x11d2   sub rax, qword ptr fs:[0x28]   9
# 0.000000000000000       1.0                  None       set()                        4563  :  0x11d3   sub rax, qword ptr [0x28]   8
# 0.000000000000000       1.0                  None       set()                        4564  :  0x11d4   sub eax, dword ptr [0x28]   7
# 0.000000000000000       1.0                  None       set()                        4565  :  0x11d5   add al, 0x25   2
# 0.000000000000000       1.0                  None       set()                        4566  :  0x11d6   and eax, 0x28   5
# 0.000000000000000       1.0                  None       set()                        4567  :  0x11d7   sub byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4568  :  0x11d8   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4569  :  0x11d9   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4570  :  0x11da   add byte ptr [rbp + 0xb], dh   3
# 1.000000000000000       1.2622920689040363e-29 None       {4530, 4515, 4500, 4549, 4487, 4539}     #   4571  :  0x11db   jne 0x11e8   2
# 0.000000000000000       1.0                  None       set()                        4572  :  0x11dc   or ecx, dword ptr [rax - 0x7f]   3
# 1.000000000000000       1.2622920689040363e-29 None       {4530, 4515, 4500, 4549, 4487, 4539}     #   4573  :  0x11dd   add rsp, 0xe0   7
# 0.000000000000000       1.0                  None       set()                        4574  :  0x11de   add esp, 0xe0   6
# 0.000000000000000       1.0                  None       set()                        4575  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4576  :  0x11e0   loopne 0x11e2   2
# 0.000000000000000       1.0                  None       set()                        4577  :  0x11e1   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4578  :  0x11e2   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        4579  :  0x11e3   add byte ptr [rcx], dh   2
# 1.000000000000000       1.2622920689040363e-29 None       {4530, 4515, 4500, 4549, 4487, 4539}     #   4580  :  0x11e4   xor eax, eax   2
# 0.000000000000000       1.0                  None       set()                        4581  :  0x11e5   rcr byte ptr [rbx - 0x3d], 0xe8   4
# 1.000000000000000       7.889325430650281e-31 0.0625     {4530, 4515, 4500, 4549, 4582, 4487, 4539}     #   4582  :  0x11e6   pop rbx   1
# 1.000000000000000       4.930828394156459e-32 0.0625     {4530, 4515, 4500, 4549, 4582, 4487, 4583, 4539}     #   4583  :  0x11e7   ret    1
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4584  :  0x11e8   call 0x1080   5
# 0.000000000000000       1.0                  None       set()                        4585  :  0x11e9   xchg ebx, eax   1
# 0.000000000000000       1.0                  None       set()                        4586  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4587  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4588  :  0x11ec   dec dword ptr [rdi]   2
# 0.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}         4589  :  0x11ed   nop dword ptr [rax]   3
# 0.000000000000000       1.0                  None       set()                        4590  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4591  :  0x11ef   add bl, dh   2
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4592  :  0x11f0   endbr64    4
# 0.000000000000000       1.0                  None       set()                        4593  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4594  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4595  :  0x11f3   cli    1
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4596  :  0x11f4   xor ebp, ebp   2
# 0.000000000000000       1.0                  None       set()                        4597  :  0x11f5   in eax, dx   1
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4598  :  0x11f6   mov r9, rdx   3
# 0.000000000000000       1.0                  None       set()                        4599  :  0x11f7   mov ecx, edx   2
# 0.000000000000000       1.0                  None       set()                        4600  :  0x11f8   rcr dword ptr [rsi + 0x48], 1   3
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4601  :  0x11f9   pop rsi   1
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4602  :  0x11fa   mov rdx, rsp   3
# 0.000000000000000       1.0                  None       set()                        4603  :  0x11fb   mov edx, esp   2
# 0.000000000000000       1.0                  None       set()                        4604  :  0x11fc   loop 0x1246   2
# 1.000000000000000       4.930828394156459e-32 None       {4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4605  :  0x11fd   and rsp, 0xfffffffffffffff0   4
# 0.000000000000000       1.0                  None       set()                        4606  :  0x11fe   and esp, 0xfffffff0   3
# 0.000000000000000       1.0                  None       set()                        4607  :  0x11ff   in al, 0xf0   2
# 0.000000000000000       1.0                  None       set()                        4608  :  invalid instruction
# 1.000000000000000       3.081767746347764e-33 0.0625     {4609, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4609  :  0x1201   push rax   1
# 1.000000000000000       1.9261048414673654e-34 0.0625     {4609, 4610, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4610  :  0x1202   push rsp   1
# 1.000000000000000       1.9261048414673654e-34 None       {4609, 4610, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4611  :  0x1203   xor r8d, r8d   3
# 0.000000000000000       1.0                  None       set()                        4612  :  0x1204   xor eax, eax   2
# 0.000000000000000       1.0                  None       set()                        4613  :  0x1205   sal byte ptr [rcx], 0xc9   3
# 1.000000000000000       1.9261048414673654e-34 None       {4609, 4610, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4614  :  0x1206   xor ecx, ecx   2
# 0.000000000000000       1.0                  None       set()                        4615  :  0x1207   leave    1
# 1.000000000000000       1.9261048414673654e-34 None       {4609, 4610, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4616  :  0x1208   lea rdi, [rip - 0x16f]   7
# 0.000000000000000       1.0                  None       set()                        4617  :  0x1209   lea edi, [rip - 0x16f]   6
# 0.000000000000000       1.0                  None       set()                        4618  :  0x120a   cmp eax, 0xfffffe91   5
# 0.000000000000000       1.0                  None       set()                        4619  :  0x120b   xchg ecx, eax   1
# 0.000000000000000       1.0                  None       set()                        4620  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4621  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        4622  :  invalid instruction
# 1.000000000000000       1.9261048414673654e-34 None       {4609, 4610, 4515, 4549, 4582, 4487, 4583, 4530, 4500, 4539}     #   4623  :  0x120f   call qword ptr [rip + 0x2dc3]   6
# 0.000000000000000       1.0                  None       set()                        4624  :  0x1210   adc eax, 0x2dc3   5
# ...
# 0.000000000000000       1.0                  None       set()                        5214  :  0x145e   cld    2
# 0.000000000000000       1.0                  None       set()                        5215  :  0x145f   cld    1
# 0.000000000000000       1.0                  None       set()                        5216  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        5217  :  0x1461   jmp qword ptr [rsi + 0xf]   3
# 0.000000000000000       4.057304448442932e-239 None       {4992, 4609, 4610, 4865, 4867, 5126, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5131, 4500, 4515, 4777, 5166, 4657, 4530, 4786, 5171, 4791, 5176, 4539, 4669, 4803, 4804, 4549, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4832, 4960, 4961, 4962, 4963, 4582, 4583, 5211, 4722, 4982, 5110, 4984, 4989, 4734}         5218  :  0x1462   nop word ptr [rax + rax]   6
# 0.000000000000000       1.0                  None       set()                        5219  :  0x1463   nop dword ptr [rax + rax]   5
# 0.000000000000000       1.0                  None       set()                        5220  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        5221  :  0x1465   add byte ptr [rax], r8b   3
# 0.000000000000000       1.0                  None       set()                        5222  :  0x1466   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5223  :  0x1467   add byte ptr [rax - 0x73], cl   3
# 1.000000000000000       4.057304448442932e-239 None       {4992, 4609, 4610, 4865, 4867, 5126, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5131, 4500, 4515, 4777, 5166, 4657, 4530, 4786, 5171, 4791, 5176, 4539, 4669, 4803, 4804, 4549, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4832, 4960, 4961, 4962, 4963, 4582, 4583, 5211, 4722, 4982, 5110, 4984, 4989, 4734}     #   5224  :  0x1468   lea rsi, [rip + 0xb9d]   7
# 0.000000000000000       1.0                  None       set()                        5225  :  0x1469   lea esi, [rip + 0xb9d]   6
# 0.000000000000000       1.0                  None       set()                        5226  :  0x146a   xor eax, 0xb9d   5
# 0.000000000000000       1.0                  None       set()                        5227  :  0x146b   popfq    1
# 0.000000000000000       1.0                  None       set()                        5228  :  0x146c   or eax, dword ptr [rax]   2
# 0.000000000000000       1.0                  None       set()                        5229  :  0x146d   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5230  :  0x146e   add byte ptr [rdi + 2], bh   6
# 1.000000000000000       4.057304448442932e-239 None       {4992, 4609, 4610, 4865, 4867, 5126, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5131, 4500, 4515, 4777, 5166, 4657, 4530, 4786, 5171, 4791, 5176, 4539, 4669, 4803, 4804, 4549, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4832, 4960, 4961, 4962, 4963, 4582, 4583, 5211, 4722, 4982, 5110, 4984, 4989, 4734}     #   5231  :  0x146f   mov edi, 2   5
# 0.000000000000000       1.0                  None       set()                        5232  :  0x1470   add al, byte ptr [rax]   2
# 0.000000000000000       1.0                  None       set()                        5233  :  0x1471   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5234  :  0x1472   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5235  :  0x1473   add byte ptr [rcx], dh   2
# 0.000000000000000       1.0                  None       set()                        5265  :  0x1491   in eax, dx   1
# 1.000000000000000       3.704679996575955e-251 None       {4992, 4609, 4610, 4865, 4867, 5126, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5131, 4500, 4515, 4777, 5166, 4657, 4530, 4786, 5171, 4791, 5176, 4539, 4669, 4803, 4804, 4549, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4832, 4960, 4961, 4962, 4963, 4582, 4583, 5211, 4722, 4982, 5110, 4984, 5238, 5243, 4989, 4734}     #   5266  :  0x1492   je 0x143f   2
# 0.000000000000000       1.0                  None       set()                        5267  :  0x1493   stosd dword ptr [rdi], eax   1
# 1.000000000000000       1.4528156821712607e-253 0.00392156862 {4992, 4609, 4610, 4865, 4867, 5126, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5131, 4500, 5268, 4515, 4777, 5166, 4657, 4530, 4786, 5171, 4791, 5176, 4539, 4669, 4803, 4804, 4549, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4832, 4960, 4961, 4962, 4963, 4582, 4583, 5211, 4722, 4982, 5110, 4984, 5238, 5243, 4989, 4734}     #   5268  :  0x1494   jmp 0x1433   2
# 0.000000000000000       1.0                  None       set()                        5269  :  0x1495   popfq    1
# 0.000000000000000       1.4528156821712607e-253 None       {4609, 4610, 4865, 4867, 5126, 5131, 5166, 4657, 5171, 5176, 4669, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4960, 4961, 4962, 4963, 5211, 4722, 4982, 5238, 4984, 5243, 4989, 4734, 4992, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 4500, 5268, 4515, 4777, 4530, 4786, 4791, 4539, 4803, 4804, 4549, 4832, 4582, 4583, 5110}         5270  :  0x1496   nop word ptr cs:[rax + rax]   10
# 0.000000000000000       1.0                  None       set()                        5271  :  0x1497   nop dword ptr cs:[rax + rax]   9
# 0.000000000000000       1.0                  None       set()                        5272  :  0x1498   nop dword ptr [rax + rax]   8
# 0.000000000000000       1.0                  None       set()                        5273  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        5274  :  0x149a   test byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5275  :  0x149b   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5276  :  0x149c   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5277  :  0x149d   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5278  :  0x149e   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5279  :  0x149f   add byte ptr [rdi + 0x7d], bh   6
# 1.000000000000000       1.4528156821712607e-253 None       {4609, 4610, 4865, 4867, 5126, 5131, 5166, 4657, 5171, 5176, 4669, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4960, 4961, 4962, 4963, 5211, 4722, 4982, 5238, 4984, 5243, 4989, 4734, 4992, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 4500, 5268, 4515, 4777, 4530, 4786, 4791, 4539, 4803, 4804, 4549, 4832, 4582, 4583, 5110}     #   5280  :  0x14a0   mov edi, 0x7d   5
# 0.000000000000000       1.0                  None       set()                        5281  :  0x14a1   jge 0x14a3   2
# 0.000000000000000       1.0                  None       set()                        5282  :  0x14a2   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5283  :  0x14a3   add byte ptr [rax], al   2
# 0.000000000000000       1.0                  None       set()                        5284  :  0x14a4   add al, ch   2
# 1.000000000000000       1.4528156821712607e-253 None       {4609, 4610, 4865, 4867, 5126, 5131, 5166, 4657, 5171, 5176, 4669, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4960, 4961, 4962, 4963, 5211, 4722, 4982, 5238, 4984, 5243, 4989, 4734, 4992, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 4500, 5268, 4515, 4777, 4530, 4786, 4791, 4539, 4803, 4804, 4549, 4832, 4582, 4583, 5110}     #   5285  :  0x14a5   call 0x1070   5
# 0.000000000000000       1.0                  None       set()                        5286  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        5287  :  0x14a7   sti    1
# 0.000000000000000       1.0                  None       set()                        5288  :  invalid instruction
# 0.000000000000000       1.0                  None       set()                        5289  :  invalid instruction
# 1.000000000000000       5.697316389846823e-256 0.00392156862 {4609, 4610, 4865, 4867, 5126, 5131, 5166, 4657, 5171, 5176, 4669, 4680, 4943, 4944, 4946, 5204, 5205, 5206, 5207, 4952, 4953, 4954, 4955, 5208, 5209, 5210, 4959, 4960, 4961, 4962, 4963, 5211, 4722, 4982, 5238, 4984, 5243, 4989, 4734, 4992, 4487, 4744, 5000, 5001, 5002, 5003, 5004, 5005, 5006, 4500, 5268, 4515, 4777, 5290, 4530, 4786, 4791, 4539, 4803, 4804, 4549, 4832, 4582, 4583, 5110}     #   5290  :  0x14aa   jmp 0x147b   2
# 0.000000000000000       1.0                  None       set()                        5291  :  0x14ab   iretd    1

# %%
predictions = list(valid_instructions)
false_positive = set(predictions) -set (ground_truth_offsets)
false_negative = set (ground_truth_offsets) - set(predictions)
true_positive = set (ground_truth_offsets) & set(predictions)
print('false_positive: ',len(false_positive) , ' false_negative: ',len(false_negative) , ' true_positive: ',len(true_positive), 'total:', len(ground_truth_offsets)) 
print(predictions.count(0))
# Out:
# false_positive:  12  false_negative:  1  true_positive:  244 total: 245
# 0

# %%
# ALL_RD_CFG[4266]
