# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
BIN_FILE_TYPE = 'PE' #or ELF
bin_path = '/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")][0:1]
ground_truth_path ='/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'align'

MAX_SEQUENCE_LENGTH = 10

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
SEQUENCES = []
LABELS     = []

for bin_file_path in bin_files:

    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    
    with open(bin_file_path, 'rb') as f:

        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":

                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue

    inst_sizes = {}
    for byte_index in range(len(textSection)):
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            offset_inst[text_section_offset+byte_index] = instruction
            inst_sizes [text_section_offset+byte_index] = instruction.size if instruction else None
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )

            
            

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))

    DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)


    code_boundary = text_section_offset+len(textSection)

    # code_boundary = text_section_offset + 200
    
    boundary_occur_count = {i: 0 for i in range(text_section_offset, code_boundary)}

    short_range=30
    
    
    # for byte_offset in range(text_section_offset, code_boundary):
    #     for byte_offset_2 in range(byte_offset, code_boundary):
    #         if inst_sizes[byte_offset_2]:
    #             if byte_offset_2 + inst_sizes[byte_offset_2] in boundary_occur_count:
    #                 boundary_occur_count [byte_offset_2 + inst_sizes[byte_offset_2] ] +=1
    #                 if byte_offset_2<=byte_offset+short_range:
    #                     boundary_occur_count_short_range[byte_offset_2 + inst_sizes[byte_offset_2] ] +=1


    for byte_offset in range(text_section_offset, code_boundary):
        if byte_offset in offset_inst_dict: #not starting from invalid
            
            current_instruction = offset_inst_dict[byte_offset]
            if current_instruction == None:
                continue
            instruction_end_byte = byte_offset + current_instruction.size
            if instruction_end_byte>=code_boundary:
                break
            for _ in range(short_range):
                
                boundary_occur_count [instruction_end_byte ] +=1
                current_instruction = offset_inst_dict [instruction_end_byte]
                if current_instruction is None:
                    break
                instruction_end_byte += current_instruction.size
                
                if instruction_end_byte>=code_boundary:
                    break

    
    for offset in boundary_occur_count:
        label = 1 if offset in ground_truth_offsets else 0
        print(label,' ',f"{offset:<8}",' : ', f"{boundary_occur_count[offset]:<6} : "    ,offset_inst_dict[offset].mnemonic if offset_inst_dict[offset] else None, offset_inst_dict[offset].op_str if offset_inst_dict[offset] else '' , '         len :',offset_inst_dict[offset].size if offset_inst_dict[offset] else '' )
        # print(label,' ',f"{offset:<8}",' : ', f"{boundary_occur_count[offset]:<6} : "  )

    print('x x '*100)
# Out:
# 0   1024      :  0      :  int3           len : 1
# 0   1025      :  1      :  int3           len : 1
# 0   1026      :  2      :  int3           len : 1
# 0   1027      :  3      :  int3           len : 1
# 0   1028      :  4      :  int3           len : 1
# 1   1029      :  5      :  jmp 0xf4c          len : 5
# 0   1030      :  0      :  or eax, dword ptr [rax]          len : 3
# 0   1031      :  0      :  or eax, dword ptr [rax]          len : 2
# 0   1032      :  0      :  add byte ptr [rax], al          len : 2
# 0   1033      :  2      :  add cl, ch          len : 2
# 1   1034      :  7      :  jmp 0x1dc8          len : 5
# 0   1035      :  3      :  mov ecx, 0xe9000019          len : 5
# 0   1036      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1037      :  0      :  add byte ptr [rax], al          len : 2
# 0   1038      :  1      :  add cl, ch          len : 2
# 1   1039      :  9      :  jmp 0x810          len : 5
# 0   1040      :  6      :  cld           len : 1
# 0   1041      :  7      :  add eax, dword ptr [rax]          len : 2
# 0   1042      :  0      :  add byte ptr [rax], al          len : 2
# 0   1043      :  8      :  add cl, ch          len : 2
# 1   1044      :  11     :  jmp 0x1ed8          len : 5
# 0   1045      :  9      :  mov edi, 0xe900001a          len : 5
# 0   1046      :  0      :  sbb al, byte ptr [rax]          len : 2
# 0   1047      :  0      :  add byte ptr [rax], al          len : 2
# 0   1048      :  1      :  add cl, ch          len : 2
# 1   1049      :  13     :  jmp 0x1568          len : 5
# 0   1050      :  12     :  adc qword ptr [rax], rax          len : 3
# 0   1051      :  0      :  adc dword ptr [rax], eax          len : 2
# 0   1052      :  0      :  add byte ptr [rax], al          len : 2
# 0   1053      :  14     :  add cl, ch          len : 2
# 1   1054      :  15     :  jmp 0x1af8          len : 5
# 0   1055      :  15     :  None           len :
# 0   1056      :  0      :  None           len :
# 0   1057      :  0      :  add byte ptr [rax], al          len : 2
# 0   1058      :  0      :  add cl, ch          len : 2
# 1   1059      :  17     :  jmp 0x2684          len : 5
# 0   1060      :  1      :  pop rsp          len : 1
# 0   1061      :  2      :  and al, byte ptr [rax]          len : 2
# 0   1062      :  0      :  add byte ptr [rax], al          len : 2
# 0   1063      :  3      :  add cl, ch          len : 2
# 1   1064      :  19     :  jmp 0xfe4          len : 5
# 0   1065      :  4      :  mov bh, 0xb          len : 2
# 0   1066      :  0      :  or eax, dword ptr [rax]          len : 2
# 0   1067      :  5      :  add byte ptr [rax], al          len : 2
# 0   1068      :  1      :  add cl, ch          len : 2
# 1   1069      :  26     :  jmp 0x1edc          len : 5
# 0   1070      :  2      :  stosb byte ptr [rdi], al          len : 1
# 0   1071      :  3      :  sbb al, byte ptr [rax]          len : 2
# 0   1072      :  0      :  add byte ptr [rax], al          len : 2
# 0   1073      :  4      :  add cl, ch          len : 2
# 1   1074      :  28     :  jmp 0x1ac4          len : 5
# 0   1075      :  5      :  lea edx, [rsi]          len : 2
# 0   1076      :  0      :  None           len :
# 0   1077      :  6      :  add byte ptr [rax], al          len : 2
# 0   1078      :  0      :  add cl, ch          len : 2
# 1   1079      :  36     :  jmp 0x1ac0          len : 5
# 0   1080      :  1      :  test byte ptr [rsi], dl          len : 2
# 0   1081      :  0      :  None           len :
# 0   1082      :  2      :  add byte ptr [rax], al          len : 2
# 0   1083      :  0      :  add cl, ch          len : 2
# 1   1084      :  40     :  jmp 0x267c          len : 5
# 0   1085      :  1      :  cmp esp, dword ptr [rdx]          len : 2
# 0   1086      :  0      :  and al, byte ptr [rax]          len : 2
# 0   1087      :  2      :  add byte ptr [rax], al          len : 2
# 0   1088      :  1      :  add cl, ch          len : 2
# 1   1089      :  44     :  jmp 0x2690          len : 5
# 0   1090      :  2      :  and al, byte ptr [rax]          len : 3
# 0   1091      :  0      :  and al, byte ptr [rax]          len : 2
# 0   1092      :  0      :  add byte ptr [rax], al          len : 2
# 0   1093      :  4      :  add cl, ch          len : 2
# 1   1094      :  46     :  jmp 0x890          len : 5
# 0   1095      :  5      :  add al, 0          len : 3
# 0   1096      :  0      :  add al, 0          len : 2
# 0   1097      :  0      :  add byte ptr [rax], al          len : 2
# 0   1098      :  7      :  add cl, ch          len : 2
# 1   1099      :  48     :  jmp 0x3880          len : 5
# 0   1100      :  8      :  xor byte ptr [rax + rax], dh          len : 3
# 0   1101      :  0      :  xor al, 0          len : 2
# 0   1102      :  0      :  add byte ptr [rax], al          len : 2
# 0   1103      :  10     :  add cl, ch          len : 2
# 1   1104      :  50     :  jmp 0x18c0          len : 5
# 0   1105      :  11     :  imul edx, dword ptr [rax + rax], 0          len : 4
# 0   1106      :  0      :  adc al, 0          len : 2
# 0   1107      :  0      :  add byte ptr [rax], al          len : 2
# 0   1108      :  1      :  add cl, ch          len : 2
# 1   1109      :  64     :  jmp 0x1aa8          len : 5
# 0   1110      :  2      :  None           len :
# 0   1111      :  0      :  None           len :
# 0   1112      :  0      :  add byte ptr [rax], al          len : 2
# 0   1113      :  0      :  add cl, ch          len : 2
# 1   1114      :  66     :  jmp 0x1ac8          len : 5
# 0   1115      :  1      :  imul edx, dword ptr [rsi], 0x24e90000          len : 6
# 0   1116      :  0      :  None           len :
# 0   1117      :  0      :  add byte ptr [rax], al          len : 2
# 0   1118      :  0      :  add cl, ch          len : 2
# 1   1119      :  68     :  jmp 0x2688          len : 5
# 0   1120      :  1      :  and al, 0x22          len : 2
# 0   1121      :  2      :  and al, byte ptr [rax]          len : 2
# 0   1122      :  2      :  add byte ptr [rax], al          len : 2
# 0   1123      :  3      :  add cl, ch          len : 2
# 1   1124      :  72     :  jmp 0x20bc          len : 5
# 0   1125      :  4      :  push rbx          len : 1
# 0   1126      :  5      :  sbb al, 0          len : 2
# 0   1127      :  0      :  add byte ptr [rax], al          len : 2
# 0   1128      :  6      :  add cl, ch          len : 2
# 1   1129      :  74     :  jmp 0xf40          len : 5
# 0   1130      :  7      :  ror byte ptr [rdx], cl          len : 2
# 0   1131      :  0      :  or al, byte ptr [rax]          len : 2
# 0   1132      :  8      :  add byte ptr [rax], al          len : 2
# 0   1133      :  1      :  add cl, ch          len : 2
# 1   1134      :  84     :  jmp 0x2120          len : 5
# 0   1135      :  2      :  lodsd eax, dword ptr [rsi]          len : 1
# 0   1136      :  3      :  sbb al, 0          len : 2
# 0   1137      :  0      :  add byte ptr [rax], al          len : 2
# 0   1138      :  4      :  add cl, ch          len : 2
# 1   1139      :  86     :  jmp 0x3860          len : 5
# 0   1140      :  5      :  call 0xffffffffe90004ac          len : 5
# 0   1141      :  0      :  xor eax, dword ptr [rax]          len : 2
# 0   1142      :  0      :  add byte ptr [rax], al          len : 2
# 0   1143      :  1      :  add cl, ch          len : 2
# 1   1144      :  88     :  jmp 0xb18          len : 5
# 0   1145      :  8      :  wait           len : 1
# 0   1146      :  9      :  None           len :
# 0   1147      :  0      :  add byte ptr [rax], al          len : 2
# 0   1148      :  0      :  add cl, ch          len : 2
# 1   1149      :  90     :  jmp 0x2680          len : 5
# 0   1150      :  1      :  None           len :
# 0   1151      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1152      :  0      :  add byte ptr [rax], al          len : 2
# 0   1153      :  1      :  add cl, ch          len : 2
# 1   1154      :  92     :  jmp 0x16ec          len : 5
# 0   1155      :  2      :  adc al, byte ptr gs:[rax]          len : 3
# 0   1156      :  0      :  adc al, byte ptr [rax]          len : 2
# 0   1157      :  0      :  add byte ptr [rax], al          len : 2
# 0   1158      :  4      :  add cl, ch          len : 2
# 1   1159      :  93     :  jmp 0x1108          len : 5
# 0   1160      :  5      :  jl 0x496          len : 2
# 0   1161      :  0      :  or al, 0          len : 2
# 0   1162      :  6      :  add byte ptr [rax], al          len : 2
# 0   1163      :  1      :  add cl, ch          len : 2
# 1   1164      :  100    :  jmp 0x268c          len : 5
# 0   1165      :  2      :  sti           len : 1
# 0   1166      :  3      :  and dword ptr [rax], eax          len : 2
# 0   1167      :  0      :  add byte ptr [rax], al          len : 2
# 0   1168      :  4      :  add cl, ch          len : 2
# 1   1169      :  101    :  jmp 0x1dcc          len : 5
# 0   1170      :  5      :  sbb dword ptr ss:[rax], eax          len : 3
# 0   1171      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1172      :  0      :  add byte ptr [rax], al          len : 2
# 0   1173      :  7      :  add cl, ch          len : 2
# 1   1174      :  102    :  jmp 0x1f94          len : 5
# 0   1175      :  8      :  stc           len : 1
# 0   1176      :  9      :  sbb al, byte ptr [rax]          len : 2
# 0   1177      :  0      :  add byte ptr [rax], al          len : 2
# 0   1178      :  10     :  add cl, ch          len : 2
# 1   1179      :  103    :  jmp 0xa60          len : 5
# 0   1180      :  11     :  rol byte ptr [rip + 0x23e90000], 0x19          len : 7
# 0   1181      :  0      :  add eax, 0x23e90000          len : 5
# 0   1182      :  0      :  add byte ptr [rax], al          len : 2
# 0   1183      :  0      :  add cl, ch          len : 2
# 1   1184      :  103    :  jmp 0x1dc8          len : 5
# 0   1185      :  1      :  and ebx, dword ptr [rcx]          len : 2
# 0   1186      :  1      :  sbb dword ptr [rax], eax          len : 2
# 0   1187      :  14     :  add byte ptr [rax], al          len : 2
# 0   1188      :  2      :  add cl, ch          len : 2
# 1   1189      :  117    :  jmp 0x21a4          len : 5
# 0   1190      :  3      :  cli           len : 1
# 0   1191      :  4      :  sbb al, 0          len : 2
# 0   1192      :  0      :  add byte ptr [rax], al          len : 2
# 0   1193      :  5      :  add cl, ch          len : 2
# 1   1194      :  116    :  jmp 0x1af4          len : 5
# 0   1195      :  6      :  None           len :
# 0   1196      :  0      :  None           len :
# 0   1197      :  0      :  add byte ptr [rax], al          len : 2
# 0   1198      :  0      :  add cl, ch          len : 2
# 1   1199      :  114    :  jmp 0x1ee4          len : 5
# 0   1200      :  1      :  xor byte ptr [rdx], bl          len : 2
# 0   1201      :  0      :  sbb al, byte ptr [rax]          len : 2
# 0   1202      :  2      :  add byte ptr [rax], al          len : 2
# 0   1203      :  1      :  add cl, ch          len : 2
# 1   1204      :  114    :  jmp 0xef4          len : 5
# 0   1205      :  2      :  cmp ecx, dword ptr [rdx]          len : 2
# 0   1206      :  0      :  or al, byte ptr [rax]          len : 2
# 0   1207      :  3      :  add byte ptr [rax], al          len : 2
# 0   1208      :  1      :  add cl, ch          len : 2
# 1   1209      :  115    :  jmp 0x188c          len : 5
# 0   1210      :  2      :  None           len :
# 0   1211      :  0      :  adc eax, dword ptr [rax]          len : 2
# 0   1212      :  0      :  add byte ptr [rax], al          len : 2
# 0   1213      :  1      :  add cl, ch          len : 2
# 1   1214      :  113    :  jmp 0x2540          len : 5
# 0   1215      :  2      :  jge 0x4e1          len : 2
# 0   1216      :  0      :  and byte ptr [rax], al          len : 2
# 0   1217      :  3      :  add byte ptr [rax], al          len : 2
# 0   1218      :  1      :  add cl, ch          len : 2
# 1   1219      :  114    :  jmp 0x179c          len : 5
# 0   1220      :  2      :  None           len :
# 0   1221      :  0      :  adc al, byte ptr [rax]          len : 2
# 0   1222      :  0      :  add byte ptr [rax], al          len : 2
# 0   1223      :  1      :  add cl, ch          len : 2
# 1   1224      :  111    :  jmp 0x192c          len : 5
# 0   1225      :  2      :  pop rdi          len : 1
# 0   1226      :  3      :  adc al, 0          len : 2
# 0   1227      :  0      :  add byte ptr [rax], al          len : 2
# 0   1228      :  4      :  add cl, ch          len : 2
# 1   1229      :  107    :  jmp 0xaf4          len : 5
# 0   1230      :  5      :  and al, byte ptr [rsi]          len : 2
# 0   1231      :  0      :  None           len :
# 0   1232      :  6      :  add byte ptr [rax], al          len : 2
# 0   1233      :  0      :  add cl, ch          len : 2
# 1   1234      :  111    :  jmp 0x2684          len : 5
# 0   1235      :  1      :  lodsd eax, dword ptr [rsi]          len : 1
# 0   1236      :  2      :  and dword ptr [rax], eax          len : 2
# 0   1237      :  0      :  add byte ptr [rax], al          len : 2
# 0   1238      :  3      :  add cl, ch          len : 2
# 1   1239      :  109    :  jmp 0x820          len : 5
# 0   1240      :  4      :  add r8d, dword ptr [rax]          len : 3
# 0   1241      :  0      :  add eax, dword ptr [rax]          len : 2
# 0   1242      :  0      :  add byte ptr [rax], al          len : 2
# 0   1243      :  6      :  add cl, ch          len : 2
# 1   1244      :  107    :  jmp 0x1ee0          len : 5
# 0   1245      :  7      :  call ptr [rcx]          len : 2
# 0   1246      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1247      :  8      :  add byte ptr [rax], al          len : 2
# 0   1248      :  1      :  add cl, ch          len : 2
# 1   1249      :  112    :  jmp 0x2688          len : 5
# 0   1250      :  2      :  movabs byte ptr [0x21a1e9000021], al          len : 9
# 0   1251      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1252      :  0      :  add byte ptr [rax], al          len : 2
# 0   1253      :  1      :  add cl, ch          len : 2
# 1   1254      :  110    :  jmp 0x268c          len : 5
# 0   1255      :  2      :  movabs eax, dword ptr [0x15c4e9000021]          len : 9
# 0   1256      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1257      :  0      :  add byte ptr [rax], al          len : 2
# 0   1258      :  1      :  add cl, ch          len : 2
# 1   1259      :  111    :  jmp 0x1ab4          len : 5
# 0   1260      :  2      :  None           len :
# 0   1261      :  0      :  adc eax, 0x8be90000          len : 5
# 0   1262      :  0      :  add byte ptr [rax], al          len : 2
# 0   1263      :  0      :  add cl, ch          len : 2
# 1   1264      :  112    :  jmp 0x2680          len : 5
# 0   1265      :  1      :  mov esp, dword ptr [rcx]          len : 2
# 0   1266      :  1      :  and dword ptr [rax], eax          len : 2
# 0   1267      :  2      :  add byte ptr [rax], al          len : 2
# 0   1268      :  2      :  add cl, ch          len : 2
# 1   1269      :  112    :  jmp 0x9f0          len : 5
# 0   1270      :  3      :  test byte ptr [rax + rax], 0          len : 4
# 0   1271      :  0      :  add al, 0          len : 2
# 0   1272      :  0      :  add byte ptr [rax], al          len : 2
# 0   1273      :  1      :  add cl, ch          len : 2
# 1   1274      :  115    :  jmp 0x1908          len : 5
# 0   1275      :  2      :  or dword ptr [rax + rax], edx          len : 3
# 0   1276      :  0      :  adc al, 0          len : 2
# 0   1277      :  0      :  add byte ptr [rax], al          len : 2
# 0   1278      :  4      :  add cl, ch          len : 2
# 1   1279      :  114    :  jmp 0x1aec          len : 5
# 0   1280      :  5      :  call 0xffffffffe900051a          len : 5
# 0   1281      :  0      :  adc eax, 0x97e90000          len : 5
# 0   1282      :  0      :  add byte ptr [rax], al          len : 2
# 0   1283      :  0      :  add cl, ch          len : 2
# 1   1284      :  113    :  jmp 0xba0          len : 5
# 0   1285      :  7      :  xchg edi, eax          len : 1
# 0   1286      :  9      :  None           len :
# 0   1287      :  0      :  add byte ptr [rax], al          len : 2
# 0   1288      :  0      :  add cl, ch          len : 2
# 1   1289      :  111    :  jmp 0x2074          len : 5
# 0   1290      :  1      :  sbb ax, word ptr [rax]          len : 3
# 0   1291      :  0      :  sbb eax, dword ptr [rax]          len : 2
# 0   1292      :  0      :  add byte ptr [rax], al          len : 2
# 0   1293      :  3      :  add cl, ch          len : 2
# 1   1294      :  109    :  jmp 0x1ab8          len : 5
# 0   1295      :  4      :  movsd dword ptr [rdi], dword ptr [rsi]          len : 1
# 0   1296      :  5      :  adc eax, 0x78e90000          len : 5
# 0   1297      :  0      :  add byte ptr [rax], al          len : 2
# 0   1298      :  0      :  add cl, ch          len : 2
# 1   1299      :  106    :  jmp 0x2690          len : 5
# 0   1300      :  1      :  js 0x537          len : 2
# 0   1301      :  6      :  and dword ptr [rax], eax          len : 2
# 0   1302      :  2      :  add byte ptr [rax], al          len : 2
# 0   1303      :  7      :  add cl, ch          len : 2
# 1   1304      :  106    :  jmp 0x1aac          len : 5
# 0   1305      :  8      :  None           len :
# 0   1306      :  0      :  adc eax, 0x26e90000          len : 5
# 0   1307      :  0      :  add byte ptr [rax], al          len : 2
# 0   1308      :  0      :  add cl, ch          len : 2
# 1   1309      :  103    :  jmp 0x1d48          len : 5
# 0   1310      :  1      :  sbb byte ptr es:[rax], al          len : 3
# 0   1311      :  1      :  sbb byte ptr [rax], al          len : 2
# 0   1312      :  0      :  add byte ptr [rax], al          len : 2
# 0   1313      :  4      :  add cl, ch          len : 2
# 1   1314      :  102    :  jmp 0xfa0          len : 5
# 0   1315      :  5      :  jns 0x52f          len : 2
# 0   1316      :  0      :  or al, byte ptr [rax]          len : 2
# 0   1317      :  6      :  add byte ptr [rax], al          len : 2
# 0   1318      :  1      :  add cl, ch          len : 2
# 1   1319      :  107    :  jmp 0x1e40          len : 5
# 0   1320      :  2      :  adc al, 0x19          len : 2
# 0   1321      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1322      :  3      :  add byte ptr [rax], al          len : 2
# 0   1323      :  1      :  add cl, ch          len : 2
# 1   1324      :  109    :  jmp 0xed8          len : 5
# 0   1325      :  2      :  cmpsd dword ptr [rsi], dword ptr [rdi]          len : 1
# 0   1326      :  3      :  or dword ptr [rax], eax          len : 2
# 0   1327      :  0      :  add byte ptr [rax], al          len : 2
# 0   1328      :  4      :  add cl, ch          len : 2
# 1   1329      :  107    :  jmp 0x1e8c          len : 5
# 0   1330      :  5      :  push rsi          len : 1
# 0   1331      :  6      :  sbb dword ptr [rax], eax          len : 2
# 0   1332      :  0      :  add byte ptr [rax], al          len : 2
# 0   1333      :  7      :  add cl, ch          len : 2
# 1   1334      :  105    :  jmp 0x1b28          len : 5
# 0   1335      :  8      :  in eax, dx          len : 1
# 0   1336      :  9      :  adc eax, 0x74e90000          len : 5
# 0   1337      :  0      :  add byte ptr [rax], al          len : 2
# 0   1338      :  0      :  add cl, ch          len : 2
# 1   1339      :  105    :  jmp 0x1db4          len : 5
# 0   1340      :  1      :  je 0x556          len : 2
# 0   1341      :  10     :  sbb byte ptr [rax], al          len : 2
# 0   1342      :  2      :  add byte ptr [rax], al          len : 2
# 0   1343      :  11     :  add cl, ch          len : 2
# 1   1344      :  105    :  jmp 0x2684          len : 5
# 0   1345      :  12     :  None           len :
# 0   1346      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1347      :  0      :  add byte ptr [rax], al          len : 2
# 0   1348      :  1      :  add cl, ch          len : 2
# 1   1349      :  103    :  jmp 0x2688          len : 5
# 0   1350      :  2      :  and dword ptr ds:[rax], eax          len : 3
# 0   1351      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1352      :  0      :  add byte ptr [rax], al          len : 2
# 0   1353      :  4      :  add cl, ch          len : 2
# 1   1354      :  100    :  jmp 0x2680          len : 5
# 0   1355      :  5      :  xor dword ptr [rcx], esp          len : 2
# 0   1356      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1357      :  6      :  add byte ptr [rax], al          len : 2
# 0   1358      :  1      :  add cl, ch          len : 2
# 1   1359      :  104    :  jmp 0x910          len : 5
# 0   1360      :  2      :  mov esp, 0xe9000003          len : 5
# 0   1361      :  0      :  add eax, dword ptr [rax]          len : 2
# 0   1362      :  0      :  add byte ptr [rax], al          len : 2
# 0   1363      :  1      :  add cl, ch          len : 2
# 1   1364      :  101    :  jmp 0xf88          len : 5
# 0   1365      :  5      :  None           len :
# 0   1366      :  0      :  or al, byte ptr [rax]          len : 2
# 0   1367      :  0      :  add byte ptr [rax], al          len : 2
# 0   1368      :  1      :  add cl, ch          len : 2
# 1   1369      :  99     :  jmp 0x1d4c          len : 5
# 0   1370      :  2      :  out dx, al          len : 1
# 0   1371      :  3      :  None           len :
# 0   1372      :  0      :  add byte ptr [rax], al          len : 2
# 0   1373      :  0      :  add cl, ch          len : 2
# 1   1374      :  97     :  jmp 0x2020          len : 5
# 0   1375      :  1      :  mov ebp, 0xe900001a          len : 5
# 0   1376      :  0      :  sbb al, byte ptr [rax]          len : 2
# 0   1377      :  0      :  add byte ptr [rax], al          len : 2
# 0   1378      :  1      :  add cl, ch          len : 2
# 1   1379      :  95     :  jmp 0x268c          len : 5
# 0   1380      :  4      :  and al, 0x21          len : 2
# 0   1381      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1382      :  5      :  add byte ptr [rax], al          len : 2
# 0   1383      :  1      :  add cl, ch          len : 2
# 1   1384      :  98     :  jmp 0x19d0          len : 5
# 0   1385      :  2      :  None           len :
# 0   1386      :  0      :  adc al, 0          len : 2
# 0   1387      :  0      :  add byte ptr [rax], al          len : 2
# 0   1388      :  1      :  add cl, ch          len : 2
# 1   1389      :  97     :  jmp 0x20c0          len : 5
# 0   1390      :  2      :  sbb r8, qword ptr [rax]          len : 3
# 0   1391      :  0      :  sbb eax, dword ptr [rax]          len : 2
# 0   1392      :  0      :  add byte ptr [rax], al          len : 2
# 0   1393      :  4      :  add cl, ch          len : 2
# 1   1394      :  96     :  jmp 0x267c          len : 5
# 0   1395      :  5      :  add eax, 0xe9000021          len : 5
# 0   1396      :  0      :  and dword ptr [rax], eax          len : 2
# 0   1397      :  0      :  add byte ptr [rax], al          len : 2
# 0   1398      :  1      :  add cl, ch          len : 2
# 1   1399      :  95     :  jmp 0x1b38          len : 5
# 0   1400      :  8      :  mov esp, 0xe9000015          len : 5
# 0   1401      :  0      :  adc eax, 0x5be90000          len : 5
# 0   1402      :  0      :  add byte ptr [rax], al          len : 2
# 0   1403      :  0      :  add cl, ch          len : 2
# 1   1404      :  93     :  jmp 0x1adc          len : 5
# 0   1405      :  10     :  pop rbx          len : 1
# 0   1406      :  12     :  adc eax, 0x66e90000          len : 5
# 0   1407      :  0      :  add byte ptr [rax], al          len : 2
# 0   1408      :  0      :  add cl, ch          len : 2
# 1   1409      :  89     :  jmp 0x10ec          len : 5
# 0   1410      :  1      :  or ax, word ptr [rax]          len : 3
# 0   1411      :  13     :  or eax, dword ptr [rax]          len : 2
# 0   1412      :  0      :  add byte ptr [rax], al          len : 2
# 0   1413      :  16     :  add cl, ch          len : 2
# 1   1414      :  86     :  jmp 0x21c0          len : 5
# 0   1415      :  17     :  xor eax, 0xe900001c          len : 5
# 0   1416      :  0      :  sbb al, 0          len : 2
# 0   1417      :  0      :  add byte ptr [rax], al          len : 2
# 0   1418      :  1      :  add cl, ch          len : 2
# 1   1419      :  85     :  jmp 0x1688          len : 5
# 0   1420      :  20     :  clc           len : 1
# 0   1421      :  21     :  adc byte ptr [rax], al          len : 2
# 0   1422      :  0      :  add byte ptr [rax], al          len : 2
# 0   1423      :  22     :  add cl, ch          len : 2
# 1   1424      :  84     :  jmp 0x1584          len : 5
# 0   1425      :  23     :  out dx, eax          len : 1
# 0   1426      :  24     :  sldt word ptr [rax]          len : 3
# 0   1427      :  0      :  add byte ptr [rax], al          len : 2
# 0   1428      :  0      :  add cl, ch          len : 2
# 1   1429      :  109    :  jmp 0x1b44          len : 5
# 0   1430      :  1      :  stosb byte ptr [rdi], al          len : 1
# 0   1431      :  2      :  adc eax, 0xdde90000          len : 5
# 0   1432      :  0      :  add byte ptr [rax], al          len : 2
# 0   1433      :  0      :  add cl, ch          len : 2
# 1   1434      :  109    :  jmp 0x267c          len : 5
# 0   1435      :  1      :  frstor dword ptr [rax]          len : 2
# 0   1436      :  3      :  and byte ptr [rax], al          len : 2
# 0   1437      :  2      :  add byte ptr [rax], al          len : 2
# 0   1438      :  4      :  add cl, ch          len : 2
# 1   1439      :  111    :  jmp 0x1b04          len : 5
# 0   1440      :  5      :  None           len :
# 0   1441      :  0      :  adc eax, 0xa7e90000          len : 5
# 0   1442      :  0      :  add byte ptr [rax], al          len : 2
# 0   1443      :  0      :  add cl, ch          len : 2
# 1   1444      :  110    :  jmp 0x1b50          len : 5
# 0   1445      :  1      :  cmpsd dword ptr [rsi], dword ptr [rdi]          len : 1
# 0   1446      :  3      :  adc eax, 0x82e90000          len : 5
# 0   1447      :  0      :  add byte ptr [rax], al          len : 2
# 0   1448      :  0      :  add cl, ch          len : 2
# 1   1449      :  107    :  jmp 0x2030          len : 5
# 0   1450      :  1      :  None           len :
# 0   1451      :  4      :  sbb al, byte ptr [rax]          len : 2
# 0   1452      :  0      :  add byte ptr [rax], al          len : 2
# 0   1453      :  5      :  add cl, ch          len : 2
# 1   1454      :  105    :  jmp 0x1f34          len : 5
# 0   1455      :  6      :  sbb dword ptr [rcx], 0x6ce90000          len : 6
# 0   1456      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1457      :  0      :  add byte ptr [rax], al          len : 2
# 0   1458      :  1      :  add cl, ch          len : 2
# 1   1459      :  103    :  jmp 0x1524          len : 5
# 0   1460      :  2      :  insb byte ptr [rdi], dx          len : 1
# 0   1461      :  10     :  sldt word ptr [rax]          len : 3
# 0   1462      :  0      :  add byte ptr [rax], al          len : 2
# 0   1463      :  0      :  add cl, ch          len : 2
# 1   1464      :  112    :  jmp 0x185c          len : 5
# 0   1465      :  1      :  lahf           len : 1
# 0   1466      :  2      :  adc al, byte ptr [rax]          len : 2
# 0   1467      :  0      :  add byte ptr [rax], al          len : 2
# 0   1468      :  3      :  add cl, ch          len : 2
# 1   1469      :  111    :  jmp 0x21c4          len : 5
# 0   1470      :  4      :  add bl, byte ptr [rax + rax]          len : 3
# 0   1471      :  0      :  sbb al, 0          len : 2
# 0   1472      :  0      :  add byte ptr [rax], al          len : 2
# 0   1473      :  6      :  add cl, ch          len : 2
# 1   1474      :  111    :  jmp 0x1b5c          len : 5
# 0   1475      :  7      :  xchg ebp, eax          len : 1
# 0   1476      :  8      :  adc eax, 0x4e90000          len : 5
# 0   1477      :  0      :  add byte ptr [rax], al          len : 2
# 0   1478      :  0      :  add cl, ch          len : 2
# 1   1479      :  111    :  jmp 0x14d0          len : 5
# 0   1480      :  1      :  add al, 0xf          len : 2
# 0   1481      :  9      :  sldt word ptr [rax]          len : 3
# 0   1482      :  2      :  add byte ptr [rax], al          len : 2
# 0   1483      :  0      :  add cl, ch          len : 2
# 1   1484      :  121    :  jmp 0x14dc          len : 5
# 0   1485      :  1      :  or ecx, dword ptr [rdi]          len : 2
# 0   1486      :  0      :  sldt word ptr [rax]          len : 3
# 0   1487      :  2      :  add byte ptr [rax], al          len : 2
# 0   1488      :  0      :  add cl, ch          len : 2
# 1   1489      :  122    :  jmp 0xf6c          len : 5
# 0   1490      :  1      :  xchg esi, eax          len : 1
# 0   1491      :  2      :  or dword ptr [rax], eax          len : 2
# 0   1492      :  0      :  add byte ptr [rax], al          len : 2
# 0   1493      :  3      :  add cl, ch          len : 2
# 1   1494      :  120    :  jmp 0x1f38          len : 5
# 0   1495      :  4      :  pop rbp          len : 1
# 0   1496      :  5      :  sbb dword ptr [rax], eax          len : 2
# 0   1497      :  0      :  add byte ptr [rax], al          len : 2
# 0   1498      :  6      :  add cl, ch          len : 2
# 1   1499      :  119    :  jmp 0x1af0          len : 5
# 0   1500      :  7      :  adc byte ptr [rip + 0x5be90000], dl          len : 6
# 0   1501      :  0      :  adc eax, 0x5be90000          len : 5
# 0   1502      :  0      :  add byte ptr [rax], al          len : 2
# 0   1503      :  0      :  add cl, ch          len : 2
# 1   1504      :  117    :  jmp 0x1d40          len : 5
# 0   1505      :  1      :  pop rbx          len : 1
# 0   1506      :  11     :  None           len :
# 0   1507      :  0      :  add byte ptr [rax], al          len : 2
# 0   1508      :  0      :  add cl, ch          len : 2
# 1   1509      :  116    :  jmp 0x15d4          len : 5
# 0   1510      :  1      :  None           len :
# 0   1511      :  0      :  sldt word ptr [rax]          len : 3
# 0   1512      :  0      :  add byte ptr [rax], al          len : 2
# 0   1513      :  0      :  add cl, ch          len : 2
# 1   1514      :  115    :  jmp 0x16a4          len : 5
# 0   1515      :  1      :  mov ch, 0x10          len : 2
# 0   1516      :  0      :  adc byte ptr [rax], al          len : 2
# 0   1517      :  2      :  add byte ptr [rax], al          len : 2
# 0   1518      :  1      :  add cl, ch          len : 2
# 1   1519      :  113    :  jmp 0x1f08          len : 5
# 0   1520      :  2      :  adc al, 0x19          len : 2
# 0   1521      :  0      :  sbb dword ptr [rax], eax          len : 2
# 0   1522      :  3      :  add byte ptr [rax], al          len : 2
# 0   1523      :  1      :  add cl, ch          len : 2
# 1   1524      :  112    :  jmp 0x1cf8          len : 5
# 0   1525      :  2      :  call qword ptr [rsi]          len : 2
# 0   1526      :  0      :  None           len :
# 0   1527      :  3      :  add byte ptr [rax], al          len : 2
# 0   1528      :  0      :  add cl, ch          len : 2
# 1   1529      :  112    :  jmp 0x15b8          len : 5
# 0   1530      :  1      :  mov edx, 0xe900000f          len : 5
# 0   1531      :  0      :  sldt word ptr [rax]          len : 3
# 0   1532      :  0      :  add byte ptr [rax], al          len : 2
# 0   1533      :  0      :  add cl, ch          len : 2
# 1   1534      :  111    :  jmp 0x11cc          len : 5
# 0   1535      :  3      :  leave           len : 1
# 0   1536      :  4      :  or eax, dword ptr [rax]          len : 2
# 0   1537      :  0      :  add byte ptr [rax], al          len : 2
# 0   1538      :  5      :  add cl, ch          len : 2
# 1   1539      :  109    :  jmp 0x164c          len : 5
# 0   1540      :  6      :  adc byte ptr [rax], r8b          len : 3
# 0   1541      :  0      :  adc byte ptr [rax], al          len : 2
# 0   1542      :  0      :  add byte ptr [rax], al          len : 2
# 0   1543      :  8      :  add ah, cl          len : 2
# 0   1544      :  107    :  int3           len : 1
# 0   1545      :  113    :  int3           len : 1
# 0   1546      :  110    :  int3           len : 1
# 0   1547      :  108    :  int3           len : 1
# 0   1548      :  106    :  int3           len : 1
# 0   1549      :  104    :  int3           len : 1
# 0   1550      :  102    :  int3           len : 1
# 0   1551      :  99     :  int3           len : 1
# 0   1552      :  96     :  int3           len : 1
# 0   1553      :  93     :  int3           len : 1
# 0   1554      :  90     :  int3           len : 1
# 0   1555      :  86     :  int3           len : 1
# 0   1556      :  82     :  int3           len : 1
# 0   1557      :  78     :  int3           len : 1
# 0   1558      :  74     :  int3           len : 1
# 0   1559      :  72     :  int3           len : 1
# 0   1560      :  69     :  int3           len : 1
# 0   1561      :  65     :  int3           len : 1
# 0   1562      :  62     :  int3           len : 1
# 0   1563      :  60     :  int3           len : 1
# 0   1564      :  59     :  int3           len : 1
# 0   1565      :  58     :  int3           len : 1
# 0   1566      :  57     :  int3           len : 1
# 0   1567      :  54     :  int3           len : 1
# 0   1568      :  49     :  int3           len : 1
# 0   1569      :  45     :  int3           len : 1
# 0   1570      :  41     :  int3           len : 1
# 0   1571      :  39     :  int3           len : 1
# 0   1572      :  36     :  int3           len : 1
# 0   1573      :  34     :  int3           len : 1
# 0   1574      :  31     :  int3           len : 1
# 0   1575      :  30     :  int3           len : 1
# 0   1576      :  30     :  int3           len : 1
# 0   1577      :  30     :  int3           len : 1
# 0   1578      :  30     :  int3           len : 1
# 0   1579      :  30     :  int3           len : 1
# 0   1580      :  30     :  int3           len : 1
# 0   1581      :  30     :  int3           len : 1
# 0   1582      :  30     :  int3           len : 1
# 0   1583      :  30     :  int3           len : 1
# 0   1584      :  30     :  int3           len : 1
# 0   1585      :  30     :  int3           len : 1
# 0   1586      :  30     :  int3           len : 1
# 0   1587      :  30     :  int3           len : 1
# 0   1588      :  30     :  int3           len : 1
# 0   1589      :  30     :  int3           len : 1
# 0   1590      :  30     :  int3           len : 1
# 0   1591      :  30     :  int3           len : 1
