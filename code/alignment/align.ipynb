# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
BIN_FILE_TYPE = 'PE' #or ELF
bin_path = '/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")][0:1]
ground_truth_path ='/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'align'

MAX_SEQUENCE_LENGTH = 10

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
SEQUENCES = []
LABELS     = []

for bin_file_path in bin_files:

    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    
    with open(bin_file_path, 'rb') as f:

        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":

                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue

    inst_sizes = {}
    for byte_index in range(len(textSection)):
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            offset_inst[text_section_offset+byte_index] = instruction
            inst_sizes [text_section_offset+byte_index] = instruction.size if instruction else None
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )

            
            

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))

    DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)


    code_boundary = text_section_offset+len(textSection)

    # code_boundary = text_section_offset + 200
    
    boundary_occur_count = {i: 0 for i in range(text_section_offset, code_boundary)}

    short_range=30
    
    for byte_offset in range(text_section_offset, code_boundary):
        if byte_offset in offset_inst_dict: #not starting from invalid
            
            current_instruction = offset_inst_dict[byte_offset]
            if current_instruction == None:
                continue
            instruction_end_byte = byte_offset + current_instruction.size
            if instruction_end_byte>=code_boundary:
                break
            for _ in range(short_range):
                
                boundary_occur_count [instruction_end_byte ] +=1
                current_instruction = offset_inst_dict [instruction_end_byte]
                if current_instruction is None:
                    break
                instruction_end_byte += current_instruction.size
                
                if instruction_end_byte>=code_boundary:
                    break

    
    for offset in boundary_occur_count:
        label = '#' if offset in ground_truth_offsets else ' '
        if offset_inst_dict[offset]:
            inst_str = (offset_inst_dict[offset].mnemonic if offset_inst_dict[offset] else None )+( offset_inst_dict[offset].op_str if offset_inst_dict[offset] else '')
            inst_str = "{:<25}".format(inst_str) 
        else:
            inst_str = None
        print(label,f"{offset:<6}",' : ', f"{boundary_occur_count[offset]:<6} : "    , inst_str, '         len :',offset_inst_dict[offset].size if offset_inst_dict[offset] else '' )
        # print(label,' ',f"{offset:<8}",' : ', f"{boundary_occur_count[offset]:<6} : "  )

    print('x x '*100)
# Out:
#   1024    :  0      :  int3                               len : 1
#   1025    :  1      :  int3                               len : 1
#   1026    :  2      :  int3                               len : 1
#   1027    :  3      :  int3                               len : 1
#   1028    :  4      :  int3                               len : 1
# # 1029    :  5      :  jmp0xf4c                           len : 5
#   1030    :  0      :  oreax, dword ptr [rax]             len : 3
#   1031    :  0      :  oreax, dword ptr [rax]             len : 2
#   1032    :  0      :  addbyte ptr [rax], al              len : 2
#   1033    :  2      :  addcl, ch                          len : 2
# # 1034    :  7      :  jmp0x1dc8                          len : 5
#   1035    :  3      :  movecx, 0xe9000019                 len : 5
#   1036    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1037    :  0      :  addbyte ptr [rax], al              len : 2
#   1038    :  1      :  addcl, ch                          len : 2
# # 1039    :  9      :  jmp0x810                           len : 5
#   1040    :  6      :  cld                                len : 1
#   1041    :  7      :  addeax, dword ptr [rax]            len : 2
#   1042    :  0      :  addbyte ptr [rax], al              len : 2
#   1043    :  8      :  addcl, ch                          len : 2
# # 1044    :  11     :  jmp0x1ed8                          len : 5
#   1045    :  9      :  movedi, 0xe900001a                 len : 5
#   1046    :  0      :  sbbal, byte ptr [rax]              len : 2
#   1047    :  0      :  addbyte ptr [rax], al              len : 2
#   1048    :  1      :  addcl, ch                          len : 2
# # 1049    :  13     :  jmp0x1568                          len : 5
#   1050    :  12     :  adcqword ptr [rax], rax            len : 3
#   1051    :  0      :  adcdword ptr [rax], eax            len : 2
#   1052    :  0      :  addbyte ptr [rax], al              len : 2
#   1053    :  14     :  addcl, ch                          len : 2
# # 1054    :  15     :  jmp0x1af8                          len : 5
#   1055    :  15     :  None          len :
#   1056    :  0      :  None          len :
#   1057    :  0      :  addbyte ptr [rax], al              len : 2
#   1058    :  0      :  addcl, ch                          len : 2
# # 1059    :  17     :  jmp0x2684                          len : 5
#   1060    :  1      :  poprsp                             len : 1
#   1061    :  2      :  andal, byte ptr [rax]              len : 2
#   1062    :  0      :  addbyte ptr [rax], al              len : 2
#   1063    :  3      :  addcl, ch                          len : 2
# # 1064    :  19     :  jmp0xfe4                           len : 5
#   1065    :  4      :  movbh, 0xb                         len : 2
#   1066    :  0      :  oreax, dword ptr [rax]             len : 2
#   1067    :  5      :  addbyte ptr [rax], al              len : 2
#   1068    :  1      :  addcl, ch                          len : 2
# # 1069    :  26     :  jmp0x1edc                          len : 5
#   1070    :  2      :  stosbbyte ptr [rdi], al            len : 1
#   1071    :  3      :  sbbal, byte ptr [rax]              len : 2
#   1072    :  0      :  addbyte ptr [rax], al              len : 2
#   1073    :  4      :  addcl, ch                          len : 2
# # 1074    :  28     :  jmp0x1ac4                          len : 5
#   1075    :  5      :  leaedx, [rsi]                      len : 2
#   1076    :  0      :  None          len :
#   1077    :  6      :  addbyte ptr [rax], al              len : 2
#   1078    :  0      :  addcl, ch                          len : 2
# # 1079    :  36     :  jmp0x1ac0                          len : 5
#   1080    :  1      :  testbyte ptr [rsi], dl             len : 2
#   1081    :  0      :  None          len :
#   1082    :  2      :  addbyte ptr [rax], al              len : 2
#   1083    :  0      :  addcl, ch                          len : 2
# # 1084    :  40     :  jmp0x267c                          len : 5
#   1085    :  1      :  cmpesp, dword ptr [rdx]            len : 2
#   1086    :  0      :  andal, byte ptr [rax]              len : 2
#   1087    :  2      :  addbyte ptr [rax], al              len : 2
#   1088    :  1      :  addcl, ch                          len : 2
# # 1089    :  44     :  jmp0x2690                          len : 5
#   1090    :  2      :  andal, byte ptr [rax]              len : 3
#   1091    :  0      :  andal, byte ptr [rax]              len : 2
#   1092    :  0      :  addbyte ptr [rax], al              len : 2
#   1093    :  4      :  addcl, ch                          len : 2
# # 1094    :  46     :  jmp0x890                           len : 5
#   1095    :  5      :  addal, 0                           len : 3
#   1096    :  0      :  addal, 0                           len : 2
#   1097    :  0      :  addbyte ptr [rax], al              len : 2
#   1098    :  7      :  addcl, ch                          len : 2
# # 1099    :  48     :  jmp0x3880                          len : 5
#   1100    :  8      :  xorbyte ptr [rax + rax], dh          len : 3
#   1101    :  0      :  xoral, 0                           len : 2
#   1102    :  0      :  addbyte ptr [rax], al              len : 2
#   1103    :  10     :  addcl, ch                          len : 2
# # 1104    :  50     :  jmp0x18c0                          len : 5
#   1105    :  11     :  imuledx, dword ptr [rax + rax], 0          len : 4
#   1106    :  0      :  adcal, 0                           len : 2
#   1107    :  0      :  addbyte ptr [rax], al              len : 2
#   1108    :  1      :  addcl, ch                          len : 2
# # 1109    :  64     :  jmp0x1aa8                          len : 5
#   1110    :  2      :  None          len :
#   1111    :  0      :  None          len :
#   1112    :  0      :  addbyte ptr [rax], al              len : 2
#   1113    :  0      :  addcl, ch                          len : 2
# # 1114    :  66     :  jmp0x1ac8                          len : 5
#   1115    :  1      :  imuledx, dword ptr [rsi], 0x24e90000          len : 6
#   1116    :  0      :  None          len :
#   1117    :  0      :  addbyte ptr [rax], al              len : 2
#   1118    :  0      :  addcl, ch                          len : 2
# # 1119    :  68     :  jmp0x2688                          len : 5
#   1120    :  1      :  andal, 0x22                        len : 2
#   1121    :  2      :  andal, byte ptr [rax]              len : 2
#   1122    :  2      :  addbyte ptr [rax], al              len : 2
#   1123    :  3      :  addcl, ch                          len : 2
# # 1124    :  72     :  jmp0x20bc                          len : 5
#   1125    :  4      :  pushrbx                            len : 1
#   1126    :  5      :  sbbal, 0                           len : 2
#   1127    :  0      :  addbyte ptr [rax], al              len : 2
#   1128    :  6      :  addcl, ch                          len : 2
# # 1129    :  74     :  jmp0xf40                           len : 5
#   1130    :  7      :  rorbyte ptr [rdx], cl              len : 2
#   1131    :  0      :  oral, byte ptr [rax]               len : 2
#   1132    :  8      :  addbyte ptr [rax], al              len : 2
#   1133    :  1      :  addcl, ch                          len : 2
# # 1134    :  84     :  jmp0x2120                          len : 5
#   1135    :  2      :  lodsdeax, dword ptr [rsi]          len : 1
#   1136    :  3      :  sbbal, 0                           len : 2
#   1137    :  0      :  addbyte ptr [rax], al              len : 2
#   1138    :  4      :  addcl, ch                          len : 2
# # 1139    :  86     :  jmp0x3860                          len : 5
#   1140    :  5      :  call0xffffffffe90004ac             len : 5
#   1141    :  0      :  xoreax, dword ptr [rax]            len : 2
#   1142    :  0      :  addbyte ptr [rax], al              len : 2
#   1143    :  1      :  addcl, ch                          len : 2
# # 1144    :  88     :  jmp0xb18                           len : 5
#   1145    :  8      :  wait                               len : 1
#   1146    :  9      :  None          len :
#   1147    :  0      :  addbyte ptr [rax], al              len : 2
#   1148    :  0      :  addcl, ch                          len : 2
# # 1149    :  90     :  jmp0x2680                          len : 5
#   1150    :  1      :  None          len :
#   1151    :  0      :  anddword ptr [rax], eax            len : 2
#   1152    :  0      :  addbyte ptr [rax], al              len : 2
#   1153    :  1      :  addcl, ch                          len : 2
# # 1154    :  92     :  jmp0x16ec                          len : 5
#   1155    :  2      :  adcal, byte ptr gs:[rax]           len : 3
#   1156    :  0      :  adcal, byte ptr [rax]              len : 2
#   1157    :  0      :  addbyte ptr [rax], al              len : 2
#   1158    :  4      :  addcl, ch                          len : 2
# # 1159    :  93     :  jmp0x1108                          len : 5
#   1160    :  5      :  jl0x496                            len : 2
#   1161    :  0      :  oral, 0                            len : 2
#   1162    :  6      :  addbyte ptr [rax], al              len : 2
#   1163    :  1      :  addcl, ch                          len : 2
# # 1164    :  100    :  jmp0x268c                          len : 5
#   1165    :  2      :  sti                                len : 1
#   1166    :  3      :  anddword ptr [rax], eax            len : 2
#   1167    :  0      :  addbyte ptr [rax], al              len : 2
#   1168    :  4      :  addcl, ch                          len : 2
# # 1169    :  101    :  jmp0x1dcc                          len : 5
#   1170    :  5      :  sbbdword ptr ss:[rax], eax          len : 3
#   1171    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1172    :  0      :  addbyte ptr [rax], al              len : 2
#   1173    :  7      :  addcl, ch                          len : 2
# # 1174    :  102    :  jmp0x1f94                          len : 5
#   1175    :  8      :  stc                                len : 1
#   1176    :  9      :  sbbal, byte ptr [rax]              len : 2
#   1177    :  0      :  addbyte ptr [rax], al              len : 2
#   1178    :  10     :  addcl, ch                          len : 2
# # 1179    :  103    :  jmp0xa60                           len : 5
#   1180    :  11     :  rolbyte ptr [rip + 0x23e90000], 0x19          len : 7
#   1181    :  0      :  addeax, 0x23e90000                 len : 5
#   1182    :  0      :  addbyte ptr [rax], al              len : 2
#   1183    :  0      :  addcl, ch                          len : 2
# # 1184    :  103    :  jmp0x1dc8                          len : 5
#   1185    :  1      :  andebx, dword ptr [rcx]            len : 2
#   1186    :  1      :  sbbdword ptr [rax], eax            len : 2
#   1187    :  14     :  addbyte ptr [rax], al              len : 2
#   1188    :  2      :  addcl, ch                          len : 2
# # 1189    :  117    :  jmp0x21a4                          len : 5
#   1190    :  3      :  cli                                len : 1
#   1191    :  4      :  sbbal, 0                           len : 2
#   1192    :  0      :  addbyte ptr [rax], al              len : 2
#   1193    :  5      :  addcl, ch                          len : 2
# # 1194    :  116    :  jmp0x1af4                          len : 5
#   1195    :  6      :  None          len :
#   1196    :  0      :  None          len :
#   1197    :  0      :  addbyte ptr [rax], al              len : 2
#   1198    :  0      :  addcl, ch                          len : 2
# # 1199    :  114    :  jmp0x1ee4                          len : 5
#   1200    :  1      :  xorbyte ptr [rdx], bl              len : 2
#   1201    :  0      :  sbbal, byte ptr [rax]              len : 2
#   1202    :  2      :  addbyte ptr [rax], al              len : 2
#   1203    :  1      :  addcl, ch                          len : 2
# # 1204    :  114    :  jmp0xef4                           len : 5
#   1205    :  2      :  cmpecx, dword ptr [rdx]            len : 2
#   1206    :  0      :  oral, byte ptr [rax]               len : 2
#   1207    :  3      :  addbyte ptr [rax], al              len : 2
#   1208    :  1      :  addcl, ch                          len : 2
# # 1209    :  115    :  jmp0x188c                          len : 5
#   1210    :  2      :  None          len :
#   1211    :  0      :  adceax, dword ptr [rax]            len : 2
#   1212    :  0      :  addbyte ptr [rax], al              len : 2
#   1213    :  1      :  addcl, ch                          len : 2
# # 1214    :  113    :  jmp0x2540                          len : 5
#   1215    :  2      :  jge0x4e1                           len : 2
#   1216    :  0      :  andbyte ptr [rax], al              len : 2
#   1217    :  3      :  addbyte ptr [rax], al              len : 2
#   1218    :  1      :  addcl, ch                          len : 2
# # 1219    :  114    :  jmp0x179c                          len : 5
#   1220    :  2      :  None          len :
#   1221    :  0      :  adcal, byte ptr [rax]              len : 2
#   1222    :  0      :  addbyte ptr [rax], al              len : 2
#   1223    :  1      :  addcl, ch                          len : 2
# # 1224    :  111    :  jmp0x192c                          len : 5
#   1225    :  2      :  poprdi                             len : 1
#   1226    :  3      :  adcal, 0                           len : 2
#   1227    :  0      :  addbyte ptr [rax], al              len : 2
#   1228    :  4      :  addcl, ch                          len : 2
# # 1229    :  107    :  jmp0xaf4                           len : 5
#   1230    :  5      :  andal, byte ptr [rsi]              len : 2
#   1231    :  0      :  None          len :
#   1232    :  6      :  addbyte ptr [rax], al              len : 2
#   1233    :  0      :  addcl, ch                          len : 2
# # 1234    :  111    :  jmp0x2684                          len : 5
#   1235    :  1      :  lodsdeax, dword ptr [rsi]          len : 1
#   1236    :  2      :  anddword ptr [rax], eax            len : 2
#   1237    :  0      :  addbyte ptr [rax], al              len : 2
#   1238    :  3      :  addcl, ch                          len : 2
# # 1239    :  109    :  jmp0x820                           len : 5
#   1240    :  4      :  addr8d, dword ptr [rax]            len : 3
#   1241    :  0      :  addeax, dword ptr [rax]            len : 2
#   1242    :  0      :  addbyte ptr [rax], al              len : 2
#   1243    :  6      :  addcl, ch                          len : 2
# # 1244    :  107    :  jmp0x1ee0                          len : 5
#   1245    :  7      :  callptr [rcx]                      len : 2
#   1246    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1247    :  8      :  addbyte ptr [rax], al              len : 2
#   1248    :  1      :  addcl, ch                          len : 2
# # 1249    :  112    :  jmp0x2688                          len : 5
#   1250    :  2      :  movabsbyte ptr [0x21a1e9000021], al          len : 9
#   1251    :  0      :  anddword ptr [rax], eax            len : 2
#   1252    :  0      :  addbyte ptr [rax], al              len : 2
#   1253    :  1      :  addcl, ch                          len : 2
# # 1254    :  110    :  jmp0x268c                          len : 5
#   1255    :  2      :  movabseax, dword ptr [0x15c4e9000021]          len : 9
#   1256    :  0      :  anddword ptr [rax], eax            len : 2
#   1257    :  0      :  addbyte ptr [rax], al              len : 2
#   1258    :  1      :  addcl, ch                          len : 2
# # 1259    :  111    :  jmp0x1ab4                          len : 5
#   1260    :  2      :  None          len :
#   1261    :  0      :  adceax, 0x8be90000                 len : 5
#   1262    :  0      :  addbyte ptr [rax], al              len : 2
#   1263    :  0      :  addcl, ch                          len : 2
# # 1264    :  112    :  jmp0x2680                          len : 5
#   1265    :  1      :  movesp, dword ptr [rcx]            len : 2
#   1266    :  1      :  anddword ptr [rax], eax            len : 2
#   1267    :  2      :  addbyte ptr [rax], al              len : 2
#   1268    :  2      :  addcl, ch                          len : 2
# # 1269    :  112    :  jmp0x9f0                           len : 5
#   1270    :  3      :  testbyte ptr [rax + rax], 0          len : 4
#   1271    :  0      :  addal, 0                           len : 2
#   1272    :  0      :  addbyte ptr [rax], al              len : 2
#   1273    :  1      :  addcl, ch                          len : 2
# # 1274    :  115    :  jmp0x1908                          len : 5
#   1275    :  2      :  ordword ptr [rax + rax], edx          len : 3
#   1276    :  0      :  adcal, 0                           len : 2
#   1277    :  0      :  addbyte ptr [rax], al              len : 2
#   1278    :  4      :  addcl, ch                          len : 2
# # 1279    :  114    :  jmp0x1aec                          len : 5
#   1280    :  5      :  call0xffffffffe900051a             len : 5
#   1281    :  0      :  adceax, 0x97e90000                 len : 5
#   1282    :  0      :  addbyte ptr [rax], al              len : 2
#   1283    :  0      :  addcl, ch                          len : 2
# # 1284    :  113    :  jmp0xba0                           len : 5
#   1285    :  7      :  xchgedi, eax                       len : 1
#   1286    :  9      :  None          len :
#   1287    :  0      :  addbyte ptr [rax], al              len : 2
#   1288    :  0      :  addcl, ch                          len : 2
# # 1289    :  111    :  jmp0x2074                          len : 5
#   1290    :  1      :  sbbax, word ptr [rax]              len : 3
#   1291    :  0      :  sbbeax, dword ptr [rax]            len : 2
#   1292    :  0      :  addbyte ptr [rax], al              len : 2
#   1293    :  3      :  addcl, ch                          len : 2
# # 1294    :  109    :  jmp0x1ab8                          len : 5
#   1295    :  4      :  movsddword ptr [rdi], dword ptr [rsi]          len : 1
#   1296    :  5      :  adceax, 0x78e90000                 len : 5
#   1297    :  0      :  addbyte ptr [rax], al              len : 2
#   1298    :  0      :  addcl, ch                          len : 2
# # 1299    :  106    :  jmp0x2690                          len : 5
#   1300    :  1      :  js0x537                            len : 2
#   1301    :  6      :  anddword ptr [rax], eax            len : 2
#   1302    :  2      :  addbyte ptr [rax], al              len : 2
#   1303    :  7      :  addcl, ch                          len : 2
# # 1304    :  106    :  jmp0x1aac                          len : 5
#   1305    :  8      :  None          len :
#   1306    :  0      :  adceax, 0x26e90000                 len : 5
#   1307    :  0      :  addbyte ptr [rax], al              len : 2
#   1308    :  0      :  addcl, ch                          len : 2
# # 1309    :  103    :  jmp0x1d48                          len : 5
#   1310    :  1      :  sbbbyte ptr es:[rax], al           len : 3
#   1311    :  1      :  sbbbyte ptr [rax], al              len : 2
#   1312    :  0      :  addbyte ptr [rax], al              len : 2
#   1313    :  4      :  addcl, ch                          len : 2
# # 1314    :  102    :  jmp0xfa0                           len : 5
#   1315    :  5      :  jns0x52f                           len : 2
#   1316    :  0      :  oral, byte ptr [rax]               len : 2
#   1317    :  6      :  addbyte ptr [rax], al              len : 2
#   1318    :  1      :  addcl, ch                          len : 2
# # 1319    :  107    :  jmp0x1e40                          len : 5
#   1320    :  2      :  adcal, 0x19                        len : 2
#   1321    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1322    :  3      :  addbyte ptr [rax], al              len : 2
#   1323    :  1      :  addcl, ch                          len : 2
# # 1324    :  109    :  jmp0xed8                           len : 5
#   1325    :  2      :  cmpsddword ptr [rsi], dword ptr [rdi]          len : 1
#   1326    :  3      :  ordword ptr [rax], eax             len : 2
#   1327    :  0      :  addbyte ptr [rax], al              len : 2
#   1328    :  4      :  addcl, ch                          len : 2
# # 1329    :  107    :  jmp0x1e8c                          len : 5
#   1330    :  5      :  pushrsi                            len : 1
#   1331    :  6      :  sbbdword ptr [rax], eax            len : 2
#   1332    :  0      :  addbyte ptr [rax], al              len : 2
#   1333    :  7      :  addcl, ch                          len : 2
# # 1334    :  105    :  jmp0x1b28                          len : 5
#   1335    :  8      :  ineax, dx                          len : 1
#   1336    :  9      :  adceax, 0x74e90000                 len : 5
#   1337    :  0      :  addbyte ptr [rax], al              len : 2
#   1338    :  0      :  addcl, ch                          len : 2
# # 1339    :  105    :  jmp0x1db4                          len : 5
#   1340    :  1      :  je0x556                            len : 2
#   1341    :  10     :  sbbbyte ptr [rax], al              len : 2
#   1342    :  2      :  addbyte ptr [rax], al              len : 2
#   1343    :  11     :  addcl, ch                          len : 2
# # 1344    :  105    :  jmp0x2684                          len : 5
#   1345    :  12     :  None          len :
#   1346    :  0      :  anddword ptr [rax], eax            len : 2
#   1347    :  0      :  addbyte ptr [rax], al              len : 2
#   1348    :  1      :  addcl, ch                          len : 2
# # 1349    :  103    :  jmp0x2688                          len : 5
#   1350    :  2      :  anddword ptr ds:[rax], eax          len : 3
#   1351    :  0      :  anddword ptr [rax], eax            len : 2
#   1352    :  0      :  addbyte ptr [rax], al              len : 2
#   1353    :  4      :  addcl, ch                          len : 2
# # 1354    :  100    :  jmp0x2680                          len : 5
#   1355    :  5      :  xordword ptr [rcx], esp            len : 2
#   1356    :  0      :  anddword ptr [rax], eax            len : 2
#   1357    :  6      :  addbyte ptr [rax], al              len : 2
#   1358    :  1      :  addcl, ch                          len : 2
# # 1359    :  104    :  jmp0x910                           len : 5
#   1360    :  2      :  movesp, 0xe9000003                 len : 5
#   1361    :  0      :  addeax, dword ptr [rax]            len : 2
#   1362    :  0      :  addbyte ptr [rax], al              len : 2
#   1363    :  1      :  addcl, ch                          len : 2
# # 1364    :  101    :  jmp0xf88                           len : 5
#   1365    :  5      :  None          len :
#   1366    :  0      :  oral, byte ptr [rax]               len : 2
#   1367    :  0      :  addbyte ptr [rax], al              len : 2
#   1368    :  1      :  addcl, ch                          len : 2
# # 1369    :  99     :  jmp0x1d4c                          len : 5
#   1370    :  2      :  outdx, al                          len : 1
#   1371    :  3      :  None          len :
#   1372    :  0      :  addbyte ptr [rax], al              len : 2
#   1373    :  0      :  addcl, ch                          len : 2
# # 1374    :  97     :  jmp0x2020                          len : 5
#   1375    :  1      :  movebp, 0xe900001a                 len : 5
#   1376    :  0      :  sbbal, byte ptr [rax]              len : 2
#   1377    :  0      :  addbyte ptr [rax], al              len : 2
#   1378    :  1      :  addcl, ch                          len : 2
# # 1379    :  95     :  jmp0x268c                          len : 5
#   1380    :  4      :  andal, 0x21                        len : 2
#   1381    :  0      :  anddword ptr [rax], eax            len : 2
#   1382    :  5      :  addbyte ptr [rax], al              len : 2
#   1383    :  1      :  addcl, ch                          len : 2
# # 1384    :  98     :  jmp0x19d0                          len : 5
#   1385    :  2      :  None          len :
#   1386    :  0      :  adcal, 0                           len : 2
#   1387    :  0      :  addbyte ptr [rax], al              len : 2
#   1388    :  1      :  addcl, ch                          len : 2
# # 1389    :  97     :  jmp0x20c0                          len : 5
#   1390    :  2      :  sbbr8, qword ptr [rax]             len : 3
#   1391    :  0      :  sbbeax, dword ptr [rax]            len : 2
#   1392    :  0      :  addbyte ptr [rax], al              len : 2
#   1393    :  4      :  addcl, ch                          len : 2
# # 1394    :  96     :  jmp0x267c                          len : 5
#   1395    :  5      :  addeax, 0xe9000021                 len : 5
#   1396    :  0      :  anddword ptr [rax], eax            len : 2
#   1397    :  0      :  addbyte ptr [rax], al              len : 2
#   1398    :  1      :  addcl, ch                          len : 2
# # 1399    :  95     :  jmp0x1b38                          len : 5
#   1400    :  8      :  movesp, 0xe9000015                 len : 5
#   1401    :  0      :  adceax, 0x5be90000                 len : 5
#   1402    :  0      :  addbyte ptr [rax], al              len : 2
#   1403    :  0      :  addcl, ch                          len : 2
# # 1404    :  93     :  jmp0x1adc                          len : 5
#   1405    :  10     :  poprbx                             len : 1
#   1406    :  12     :  adceax, 0x66e90000                 len : 5
#   1407    :  0      :  addbyte ptr [rax], al              len : 2
#   1408    :  0      :  addcl, ch                          len : 2
# # 1409    :  89     :  jmp0x10ec                          len : 5
#   1410    :  1      :  orax, word ptr [rax]               len : 3
#   1411    :  13     :  oreax, dword ptr [rax]             len : 2
#   1412    :  0      :  addbyte ptr [rax], al              len : 2
#   1413    :  16     :  addcl, ch                          len : 2
# # 1414    :  86     :  jmp0x21c0                          len : 5
#   1415    :  17     :  xoreax, 0xe900001c                 len : 5
#   1416    :  0      :  sbbal, 0                           len : 2
#   1417    :  0      :  addbyte ptr [rax], al              len : 2
#   1418    :  1      :  addcl, ch                          len : 2
# # 1419    :  85     :  jmp0x1688                          len : 5
#   1420    :  20     :  clc                                len : 1
#   1421    :  21     :  adcbyte ptr [rax], al              len : 2
#   1422    :  0      :  addbyte ptr [rax], al              len : 2
#   1423    :  22     :  addcl, ch                          len : 2
# # 1424    :  84     :  jmp0x1584                          len : 5
#   1425    :  23     :  outdx, eax                         len : 1
#   1426    :  24     :  sldtword ptr [rax]                 len : 3
#   1427    :  0      :  addbyte ptr [rax], al              len : 2
#   1428    :  0      :  addcl, ch                          len : 2
# # 1429    :  109    :  jmp0x1b44                          len : 5
#   1430    :  1      :  stosbbyte ptr [rdi], al            len : 1
#   1431    :  2      :  adceax, 0xdde90000                 len : 5
#   1432    :  0      :  addbyte ptr [rax], al              len : 2
#   1433    :  0      :  addcl, ch                          len : 2
# # 1434    :  109    :  jmp0x267c                          len : 5
#   1435    :  1      :  frstordword ptr [rax]              len : 2
#   1436    :  3      :  andbyte ptr [rax], al              len : 2
#   1437    :  2      :  addbyte ptr [rax], al              len : 2
#   1438    :  4      :  addcl, ch                          len : 2
# # 1439    :  111    :  jmp0x1b04                          len : 5
#   1440    :  5      :  None          len :
#   1441    :  0      :  adceax, 0xa7e90000                 len : 5
#   1442    :  0      :  addbyte ptr [rax], al              len : 2
#   1443    :  0      :  addcl, ch                          len : 2
# # 1444    :  110    :  jmp0x1b50                          len : 5
#   1445    :  1      :  cmpsddword ptr [rsi], dword ptr [rdi]          len : 1
#   1446    :  3      :  adceax, 0x82e90000                 len : 5
#   1447    :  0      :  addbyte ptr [rax], al              len : 2
#   1448    :  0      :  addcl, ch                          len : 2
# # 1449    :  107    :  jmp0x2030                          len : 5
#   1450    :  1      :  None          len :
#   1451    :  4      :  sbbal, byte ptr [rax]              len : 2
#   1452    :  0      :  addbyte ptr [rax], al              len : 2
#   1453    :  5      :  addcl, ch                          len : 2
# # 1454    :  105    :  jmp0x1f34                          len : 5
#   1455    :  6      :  sbbdword ptr [rcx], 0x6ce90000          len : 6
#   1456    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1457    :  0      :  addbyte ptr [rax], al              len : 2
#   1458    :  1      :  addcl, ch                          len : 2
# # 1459    :  103    :  jmp0x1524                          len : 5
#   1460    :  2      :  insbbyte ptr [rdi], dx             len : 1
#   1461    :  10     :  sldtword ptr [rax]                 len : 3
#   1462    :  0      :  addbyte ptr [rax], al              len : 2
#   1463    :  0      :  addcl, ch                          len : 2
# # 1464    :  112    :  jmp0x185c                          len : 5
#   1465    :  1      :  lahf                               len : 1
#   1466    :  2      :  adcal, byte ptr [rax]              len : 2
#   1467    :  0      :  addbyte ptr [rax], al              len : 2
#   1468    :  3      :  addcl, ch                          len : 2
# # 1469    :  111    :  jmp0x21c4                          len : 5
#   1470    :  4      :  addbl, byte ptr [rax + rax]          len : 3
#   1471    :  0      :  sbbal, 0                           len : 2
#   1472    :  0      :  addbyte ptr [rax], al              len : 2
#   1473    :  6      :  addcl, ch                          len : 2
# # 1474    :  111    :  jmp0x1b5c                          len : 5
#   1475    :  7      :  xchgebp, eax                       len : 1
#   1476    :  8      :  adceax, 0x4e90000                  len : 5
#   1477    :  0      :  addbyte ptr [rax], al              len : 2
#   1478    :  0      :  addcl, ch                          len : 2
# # 1479    :  111    :  jmp0x14d0                          len : 5
#   1480    :  1      :  addal, 0xf                         len : 2
#   1481    :  9      :  sldtword ptr [rax]                 len : 3
#   1482    :  2      :  addbyte ptr [rax], al              len : 2
#   1483    :  0      :  addcl, ch                          len : 2
# # 1484    :  121    :  jmp0x14dc                          len : 5
#   1485    :  1      :  orecx, dword ptr [rdi]             len : 2
#   1486    :  0      :  sldtword ptr [rax]                 len : 3
#   1487    :  2      :  addbyte ptr [rax], al              len : 2
#   1488    :  0      :  addcl, ch                          len : 2
# # 1489    :  122    :  jmp0xf6c                           len : 5
#   1490    :  1      :  xchgesi, eax                       len : 1
#   1491    :  2      :  ordword ptr [rax], eax             len : 2
#   1492    :  0      :  addbyte ptr [rax], al              len : 2
#   1493    :  3      :  addcl, ch                          len : 2
# # 1494    :  120    :  jmp0x1f38                          len : 5
#   1495    :  4      :  poprbp                             len : 1
#   1496    :  5      :  sbbdword ptr [rax], eax            len : 2
#   1497    :  0      :  addbyte ptr [rax], al              len : 2
#   1498    :  6      :  addcl, ch                          len : 2
# # 1499    :  119    :  jmp0x1af0                          len : 5
#   1500    :  7      :  adcbyte ptr [rip + 0x5be90000], dl          len : 6
#   1501    :  0      :  adceax, 0x5be90000                 len : 5
#   1502    :  0      :  addbyte ptr [rax], al              len : 2
#   1503    :  0      :  addcl, ch                          len : 2
# # 1504    :  117    :  jmp0x1d40                          len : 5
#   1505    :  1      :  poprbx                             len : 1
#   1506    :  11     :  None          len :
#   1507    :  0      :  addbyte ptr [rax], al              len : 2
#   1508    :  0      :  addcl, ch                          len : 2
# # 1509    :  116    :  jmp0x15d4                          len : 5
#   1510    :  1      :  None          len :
#   1511    :  0      :  sldtword ptr [rax]                 len : 3
#   1512    :  0      :  addbyte ptr [rax], al              len : 2
#   1513    :  0      :  addcl, ch                          len : 2
# # 1514    :  115    :  jmp0x16a4                          len : 5
#   1515    :  1      :  movch, 0x10                        len : 2
#   1516    :  0      :  adcbyte ptr [rax], al              len : 2
#   1517    :  2      :  addbyte ptr [rax], al              len : 2
#   1518    :  1      :  addcl, ch                          len : 2
# # 1519    :  113    :  jmp0x1f08                          len : 5
#   1520    :  2      :  adcal, 0x19                        len : 2
#   1521    :  0      :  sbbdword ptr [rax], eax            len : 2
#   1522    :  3      :  addbyte ptr [rax], al              len : 2
#   1523    :  1      :  addcl, ch                          len : 2
# # 1524    :  112    :  jmp0x1cf8                          len : 5
#   1525    :  2      :  callqword ptr [rsi]                len : 2
#   1526    :  0      :  None          len :
#   1527    :  3      :  addbyte ptr [rax], al              len : 2
#   1528    :  0      :  addcl, ch                          len : 2
# # 1529    :  112    :  jmp0x15b8                          len : 5
#   1530    :  1      :  movedx, 0xe900000f                 len : 5
#   1531    :  0      :  sldtword ptr [rax]                 len : 3
#   1532    :  0      :  addbyte ptr [rax], al              len : 2
#   1533    :  0      :  addcl, ch                          len : 2
# # 1534    :  111    :  jmp0x11cc                          len : 5
#   1535    :  3      :  leave                              len : 1
#   1536    :  4      :  oreax, dword ptr [rax]             len : 2
#   1537    :  0      :  addbyte ptr [rax], al              len : 2
#   1538    :  5      :  addcl, ch                          len : 2
