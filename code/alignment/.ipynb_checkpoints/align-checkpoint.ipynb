# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
BIN_FILE_TYPE = 'PE' #or ELF
bin_path = '/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")][0:1]
ground_truth_path ='/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'align'

MAX_SEQUENCE_LENGTH = 10

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
SEQUENCES = []
LABELS     = []

for bin_file_path in bin_files:

    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    
    with open(bin_file_path, 'rb') as f:

        try:
            if BIN_FILE_TYPE == "ELF":
                elffile = ELFFile(f)
                textSection = elffile.get_section_by_name('.text').data()
                text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
              
            elif BIN_FILE_TYPE == "PE":

                        
                pe_file = lief.parse(bin_file_path)
                text_section = pe_file.get_section(".text")
                text_section_offset = text_section.pointerto_raw_data
                textSection = bytes(text_section.content)
                
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue

    inst_sizes = {}
    for byte_index in range(len(textSection)):
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            offset_inst[text_section_offset+byte_index] = instruction
            inst_sizes [text_section_offset+byte_index] = instruction.size if instruction else None
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )

            
            

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))

    DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)


    code_boundary = text_section_offset+len(textSection)
    # code_boundary = text_section_offset + 200
    
    boundary_occur_count = {i: 0 for i in range(text_section_offset, code_boundary)}
    for byte_offset in range(text_section_offset, code_boundary):
        for byte_offset_2 in range(byte_offset, code_boundary):
            if inst_sizes[byte_offset_2]:
                if byte_offset_2 + inst_sizes[byte_offset_2] in boundary_occur_count:
                    boundary_occur_count [byte_offset_2 + inst_sizes[byte_offset_2] ] +=1

    for offset in boundary_occur_count:
        label = 1 if offset in ground_truth_offsets else 0
        print(label,' ',f"{offset:<8}",' : ', f"{boundary_occur_count[offset]:<4}" ,offset_inst_dict[offset].mnemonic if offset_inst_dict[offset] else None, offset_inst_dict[offset].op_str if offset_inst_dict[offset] else '' )

    print('x x '*100)
# Out:
# 0   1024      :  0    int3
# 0   1025      :  1    int3
# 0   1026      :  2    int3
# 0   1027      :  3    int3
# 0   1028      :  4    int3
# 1   1029      :  5    jmp 0xf4c
# 0   1030      :  0    or eax, dword ptr [rax]
# 0   1031      :  0    or eax, dword ptr [rax]
# 0   1032      :  0    add byte ptr [rax], al
# 0   1033      :  15   add cl, ch
# 1   1034      :  15   jmp 0x1dc8
# 0   1035      :  10   mov ecx, 0xe9000019
# 0   1036      :  0    sbb dword ptr [rax], eax
# 0   1037      :  0    add byte ptr [rax], al
# 0   1038      :  13   add cl, ch
# 1   1039      :  25   jmp 0x810
# 0   1040      :  27   cld
# 0   1041      :  17   add eax, dword ptr [rax]
# 0   1042      :  0    add byte ptr [rax], al
# 0   1043      :  18   add cl, ch
# 1   1044      :  35   jmp 0x1ed8
# 0   1045      :  20   mov edi, 0xe900001a
# 0   1046      :  0    sbb al, byte ptr [rax]
# 0   1047      :  0    add byte ptr [rax], al
# 0   1048      :  23   add cl, ch
# 1   1049      :  45   jmp 0x1568
# 0   1050      :  47   adc qword ptr [rax], rax
# 0   1051      :  0    adc dword ptr [rax], eax
# 0   1052      :  0    add byte ptr [rax], al
# 0   1053      :  55   add cl, ch
# 1   1054      :  55   jmp 0x1af8
# 0   1055      :  30   None
# 0   1056      :  0    None
# 0   1057      :  0    add byte ptr [rax], al
# 0   1058      :  0    add cl, ch
# 1   1059      :  65   jmp 0x2684
# 0   1060      :  35   pop rsp
# 0   1061      :  37   and al, byte ptr [rax]
# 0   1062      :  0    add byte ptr [rax], al
# 0   1063      :  38   add cl, ch
# 1   1064      :  75   jmp 0xfe4
# 0   1065      :  40   mov bh, 0xb
# 0   1066      :  0    or eax, dword ptr [rax]
# 0   1067      :  42   add byte ptr [rax], al
# 0   1068      :  43   add cl, ch
# 1   1069      :  85   jmp 0x1edc
# 0   1070      :  45   stosb byte ptr [rdi], al
# 0   1071      :  47   sbb al, byte ptr [rax]
# 0   1072      :  0    add byte ptr [rax], al
# 0   1073      :  48   add cl, ch
# 1   1074      :  95   jmp 0x1ac4
# 0   1075      :  50   lea edx, [rsi]
# 0   1076      :  0    None
# 0   1077      :  52   add byte ptr [rax], al
# 0   1078      :  0    add cl, ch
# 1   1079      :  105  jmp 0x1ac0
# 0   1080      :  55   test byte ptr [rsi], dl
# 0   1081      :  0    None
# 0   1082      :  57   add byte ptr [rax], al
# 0   1083      :  0    add cl, ch
# 1   1084      :  115  jmp 0x267c
# 0   1085      :  60   cmp esp, dword ptr [rdx]
# 0   1086      :  0    and al, byte ptr [rax]
# 0   1087      :  62   add byte ptr [rax], al
# 0   1088      :  63   add cl, ch
# 1   1089      :  125  jmp 0x2690
# 0   1090      :  65   and al, byte ptr [rax]
# 0   1091      :  0    and al, byte ptr [rax]
# 0   1092      :  0    add byte ptr [rax], al
# 0   1093      :  135  add cl, ch
# 1   1094      :  135  jmp 0x890
# 0   1095      :  70   add al, 0
# 0   1096      :  0    add al, 0
# 0   1097      :  0    add byte ptr [rax], al
# 0   1098      :  145  add cl, ch
# 1   1099      :  145  jmp 0x3880
# 0   1100      :  75   xor byte ptr [rax + rax], dh
# 0   1101      :  0    xor al, 0
# 0   1102      :  0    add byte ptr [rax], al
# 0   1103      :  155  add cl, ch
# 1   1104      :  155  jmp 0x18c0
# 0   1105      :  80   imul edx, dword ptr [rax + rax], 0
# 0   1106      :  0    adc al, 0
# 0   1107      :  0    add byte ptr [rax], al
# 0   1108      :  83   add cl, ch
# 1   1109      :  247  jmp 0x1aa8
# 0   1110      :  85   None
# 0   1111      :  0    None
# 0   1112      :  0    add byte ptr [rax], al
# 0   1113      :  0    add cl, ch
# 1   1114      :  175  jmp 0x1ac8
# 0   1115      :  90   imul edx, dword ptr [rsi], 0x24e90000
# 0   1116      :  0    None
# 0   1117      :  0    add byte ptr [rax], al
# 0   1118      :  0    add cl, ch
# 1   1119      :  185  jmp 0x2688
# 0   1120      :  95   and al, 0x22
# 0   1121      :  92   and al, byte ptr [rax]
# 0   1122      :  97   add byte ptr [rax], al
# 0   1123      :  98   add cl, ch
# 1   1124      :  195  jmp 0x20bc
# 0   1125      :  100  push rbx
# 0   1126      :  102  sbb al, 0
# 0   1127      :  0    add byte ptr [rax], al
# 0   1128      :  103  add cl, ch
# 1   1129      :  205  jmp 0xf40
# 0   1130      :  105  ror byte ptr [rdx], cl
# 0   1131      :  0    or al, byte ptr [rax]
# 0   1132      :  107  add byte ptr [rax], al
# 0   1133      :  108  add cl, ch
# 1   1134      :  215  jmp 0x2120
# 0   1135      :  110  lodsd eax, dword ptr [rsi]
# 0   1136      :  112  sbb al, 0
# 0   1137      :  0    add byte ptr [rax], al
# 0   1138      :  113  add cl, ch
# 1   1139      :  225  jmp 0x3860
# 0   1140      :  115  call 0xffffffffe90004ac
# 0   1141      :  0    xor eax, dword ptr [rax]
# 0   1142      :  0    add byte ptr [rax], al
# 0   1143      :  118  add cl, ch
# 1   1144      :  235  jmp 0xb18
# 0   1145      :  237  wait
# 0   1146      :  122  None
# 0   1147      :  0    add byte ptr [rax], al
# 0   1148      :  0    add cl, ch
# 1   1149      :  245  jmp 0x2680
# 0   1150      :  125  None
# 0   1151      :  0    and dword ptr [rax], eax
# 0   1152      :  0    add byte ptr [rax], al
# 0   1153      :  128  add cl, ch
# 1   1154      :  255  jmp 0x16ec
# 0   1155      :  130  adc al, byte ptr gs:[rax]
# 0   1156      :  0    adc al, byte ptr [rax]
# 0   1157      :  0    add byte ptr [rax], al
# 0   1158      :  265  add cl, ch
# 1   1159      :  265  jmp 0x1108
# 0   1160      :  135  jl 0x496
# 0   1161      :  0    or al, 0
# 0   1162      :  137  add byte ptr [rax], al
# 0   1163      :  138  add cl, ch
# 1   1164      :  275  jmp 0x268c
# 0   1165      :  140  sti
# 0   1166      :  142  and dword ptr [rax], eax
# 0   1167      :  0    add byte ptr [rax], al
# 0   1168      :  143  add cl, ch
# 1   1169      :  285  jmp 0x1dcc
# 0   1170      :  145  sbb dword ptr ss:[rax], eax
# 0   1171      :  0    sbb dword ptr [rax], eax
# 0   1172      :  0    add byte ptr [rax], al
# 0   1173      :  295  add cl, ch
# 1   1174      :  295  jmp 0x1f94
# 0   1175      :  150  stc
# 0   1176      :  152  sbb al, byte ptr [rax]
# 0   1177      :  0    add byte ptr [rax], al
# 0   1178      :  153  add cl, ch
# 1   1179      :  305  jmp 0xa60
# 0   1180      :  155  rol byte ptr [rip + 0x23e90000], 0x19
# 0   1181      :  0    add eax, 0x23e90000
# 0   1182      :  0    add byte ptr [rax], al
# 0   1183      :  0    add cl, ch
# 1   1184      :  315  jmp 0x1dc8
# 0   1185      :  160  and ebx, dword ptr [rcx]
# 0   1186      :  158  sbb dword ptr [rax], eax
# 0   1187      :  319  add byte ptr [rax], al
# 0   1188      :  163  add cl, ch
# 1   1189      :  325  jmp 0x21a4
# 0   1190      :  165  cli
# 0   1191      :  167  sbb al, 0
# 0   1192      :  0    add byte ptr [rax], al
# 0   1193      :  168  add cl, ch
# 1   1194      :  335  jmp 0x1af4
# 0   1195      :  170  None
# 0   1196      :  0    None
# 0   1197      :  0    add byte ptr [rax], al
# 0   1198      :  0    add cl, ch
# 1   1199      :  345  jmp 0x1ee4
# 0   1200      :  175  xor byte ptr [rdx], bl
# 0   1201      :  0    sbb al, byte ptr [rax]
# 0   1202      :  177  add byte ptr [rax], al
# 0   1203      :  178  add cl, ch
# 1   1204      :  355  jmp 0xef4
# 0   1205      :  180  cmp ecx, dword ptr [rdx]
# 0   1206      :  0    or al, byte ptr [rax]
# 0   1207      :  182  add byte ptr [rax], al
# 0   1208      :  183  add cl, ch
# 1   1209      :  365  jmp 0x188c
# 0   1210      :  185  None
# 0   1211      :  0    adc eax, dword ptr [rax]
# 0   1212      :  0    add byte ptr [rax], al
# 0   1213      :  188  add cl, ch
# 1   1214      :  375  jmp 0x2540
# 0   1215      :  190  jge 0x4e1
# 0   1216      :  0    and byte ptr [rax], al
# 0   1217      :  192  add byte ptr [rax], al
# 0   1218      :  193  add cl, ch
# 1   1219      :  385  jmp 0x179c
# 0   1220      :  195  None
# 0   1221      :  0    adc al, byte ptr [rax]
# 0   1222      :  0    add byte ptr [rax], al
# 0   1223      :  198  add cl, ch
# 1   1224      :  395  jmp 0x192c
# 0   1225      :  200  pop rdi
# 0   1226      :  202  adc al, 0
# 0   1227      :  0    add byte ptr [rax], al
# 0   1228      :  203  add cl, ch
# 1   1229      :  405  jmp 0xaf4
# 0   1230      :  205  and al, byte ptr [rsi]
# 0   1231      :  0    None
# 0   1232      :  207  add byte ptr [rax], al
# 0   1233      :  0    add cl, ch
# 1   1234      :  415  jmp 0x2684
# 0   1235      :  210  lodsd eax, dword ptr [rsi]
# 0   1236      :  212  and dword ptr [rax], eax
# 0   1237      :  0    add byte ptr [rax], al
# 0   1238      :  213  add cl, ch
# 1   1239      :  425  jmp 0x820
# 0   1240      :  215  add r8d, dword ptr [rax]
# 0   1241      :  0    add eax, dword ptr [rax]
# 0   1242      :  0    add byte ptr [rax], al
# 0   1243      :  435  add cl, ch
# 1   1244      :  435  jmp 0x1ee0
# 0   1245      :  220  call ptr [rcx]
# 0   1246      :  0    sbb dword ptr [rax], eax
# 0   1247      :  222  add byte ptr [rax], al
# 0   1248      :  223  add cl, ch
# 1   1249      :  445  jmp 0x2688
# 0   1250      :  225  movabs byte ptr [0x21a1e9000021], al
# 0   1251      :  0    and dword ptr [rax], eax
# 0   1252      :  0    add byte ptr [rax], al
# 0   1253      :  228  add cl, ch
# 1   1254      :  455  jmp 0x268c
# 0   1255      :  230  movabs eax, dword ptr [0x15c4e9000021]
# 0   1256      :  0    and dword ptr [rax], eax
# 0   1257      :  0    add byte ptr [rax], al
# 0   1258      :  233  add cl, ch
# 1   1259      :  692  jmp 0x1ab4
# 0   1260      :  235  None
# 0   1261      :  0    adc eax, 0x8be90000
# 0   1262      :  0    add byte ptr [rax], al
# 0   1263      :  0    add cl, ch
# 1   1264      :  707  jmp 0x2680
# 0   1265      :  240  mov esp, dword ptr [rcx]
# 0   1266      :  238  and dword ptr [rax], eax
# 0   1267      :  242  add byte ptr [rax], al
# 0   1268      :  243  add cl, ch
# 1   1269      :  485  jmp 0x9f0
# 0   1270      :  245  test byte ptr [rax + rax], 0
# 0   1271      :  0    add al, 0
# 0   1272      :  0    add byte ptr [rax], al
# 0   1273      :  248  add cl, ch
# 1   1274      :  742  jmp 0x1908
# 0   1275      :  250  or dword ptr [rax + rax], edx
# 0   1276      :  0    adc al, 0
# 0   1277      :  0    add byte ptr [rax], al
# 0   1278      :  505  add cl, ch
# 1   1279      :  505  jmp 0x1aec
# 0   1280      :  255  call 0xffffffffe900051a
# 0   1281      :  0    adc eax, 0x97e90000
# 0   1282      :  0    add byte ptr [rax], al
# 0   1283      :  0    add cl, ch
# 1   1284      :  515  jmp 0xba0
# 0   1285      :  517  xchg edi, eax
# 0   1286      :  520  None
# 0   1287      :  0    add byte ptr [rax], al
# 0   1288      :  0    add cl, ch
# 1   1289      :  525  jmp 0x2074
# 0   1290      :  265  sbb ax, word ptr [rax]
# 0   1291      :  0    sbb eax, dword ptr [rax]
# 0   1292      :  0    add byte ptr [rax], al
# 0   1293      :  535  add cl, ch
# 1   1294      :  535  jmp 0x1ab8
# 0   1295      :  270  movsd dword ptr [rdi], dword ptr [rsi]
# 0   1296      :  272  adc eax, 0x78e90000
# 0   1297      :  0    add byte ptr [rax], al
# 0   1298      :  0    add cl, ch
# 1   1299      :  545  jmp 0x2690
# 0   1300      :  275  js 0x537
# 0   1301      :  273  and dword ptr [rax], eax
# 0   1302      :  277  add byte ptr [rax], al
# 0   1303      :  278  add cl, ch
# 1   1304      :  555  jmp 0x1aac
# 0   1305      :  280  None
# 0   1306      :  0    adc eax, 0x26e90000
# 0   1307      :  0    add byte ptr [rax], al
# 0   1308      :  0    add cl, ch
# 1   1309      :  565  jmp 0x1d48
# 0   1310      :  285  sbb byte ptr es:[rax], al
# 0   1311      :  283  sbb byte ptr [rax], al
# 0   1312      :  0    add byte ptr [rax], al
# 0   1313      :  575  add cl, ch
# 1   1314      :  575  jmp 0xfa0
# 0   1315      :  290  jns 0x52f
# 0   1316      :  0    or al, byte ptr [rax]
# 0   1317      :  292  add byte ptr [rax], al
# 0   1318      :  293  add cl, ch
# 1   1319      :  585  jmp 0x1e40
# 0   1320      :  295  adc al, 0x19
# 0   1321      :  0    sbb dword ptr [rax], eax
# 0   1322      :  297  add byte ptr [rax], al
# 0   1323      :  298  add cl, ch
# 1   1324      :  595  jmp 0xed8
# 0   1325      :  300  cmpsd dword ptr [rsi], dword ptr [rdi]
# 0   1326      :  302  or dword ptr [rax], eax
# 0   1327      :  0    add byte ptr [rax], al
# 0   1328      :  303  add cl, ch
# 1   1329      :  605  jmp 0x1e8c
# 0   1330      :  305  push rsi
# 0   1331      :  307  sbb dword ptr [rax], eax
# 0   1332      :  0    add byte ptr [rax], al
# 0   1333      :  308  add cl, ch
# 1   1334      :  615  jmp 0x1b28
# 0   1335      :  310  in eax, dx
# 0   1336      :  312  adc eax, 0x74e90000
# 0   1337      :  0    add byte ptr [rax], al
# 0   1338      :  0    add cl, ch
# 1   1339      :  625  jmp 0x1db4
# 0   1340      :  315  je 0x556
# 0   1341      :  313  sbb byte ptr [rax], al
# 0   1342      :  317  add byte ptr [rax], al
# 0   1343      :  318  add cl, ch
# 1   1344      :  635  jmp 0x2684
# 0   1345      :  320  None
# 0   1346      :  0    and dword ptr [rax], eax
# 0   1347      :  0    add byte ptr [rax], al
# 0   1348      :  323  add cl, ch
# 1   1349      :  645  jmp 0x2688
# 0   1350      :  325  and dword ptr ds:[rax], eax
# 0   1351      :  0    and dword ptr [rax], eax
# 0   1352      :  0    add byte ptr [rax], al
# 0   1353      :  655  add cl, ch
# 1   1354      :  655  jmp 0x2680
# 0   1355      :  330  xor dword ptr [rcx], esp
# 0   1356      :  0    and dword ptr [rax], eax
# 0   1357      :  332  add byte ptr [rax], al
# 0   1358      :  333  add cl, ch
# 1   1359      :  665  jmp 0x910
# 0   1360      :  335  mov esp, 0xe9000003
# 0   1361      :  0    add eax, dword ptr [rax]
# 0   1362      :  0    add byte ptr [rax], al
# 0   1363      :  338  add cl, ch
# 1   1364      :  675  jmp 0xf88
# 0   1365      :  677  None
# 0   1366      :  0    or al, byte ptr [rax]
# 0   1367      :  0    add byte ptr [rax], al
# 0   1368      :  343  add cl, ch
# 1   1369      :  685  jmp 0x1d4c
# 0   1370      :  345  out dx, al
# 0   1371      :  347  None
# 0   1372      :  0    add byte ptr [rax], al
# 0   1373      :  0    add cl, ch
# 1   1374      :  695  jmp 0x2020
# 0   1375      :  350  mov ebp, 0xe900001a
# 0   1376      :  0    sbb al, byte ptr [rax]
# 0   1377      :  0    add byte ptr [rax], al
# 0   1378      :  353  add cl, ch
# 1   1379      :  705  jmp 0x268c
# 0   1380      :  707  and al, 0x21
# 0   1381      :  0    and dword ptr [rax], eax
# 0   1382      :  357  add byte ptr [rax], al
# 0   1383      :  358  add cl, ch
# 1   1384      :  715  jmp 0x19d0
# 0   1385      :  360  None
# 0   1386      :  0    adc al, 0
# 0   1387      :  0    add byte ptr [rax], al
# 0   1388      :  363  add cl, ch
# 1   1389      :  725  jmp 0x20c0
# 0   1390      :  365  sbb r8, qword ptr [rax]
# 0   1391      :  0    sbb eax, dword ptr [rax]
# 0   1392      :  0    add byte ptr [rax], al
# 0   1393      :  735  add cl, ch
# 1   1394      :  735  jmp 0x267c
# 0   1395      :  370  add eax, 0xe9000021
# 0   1396      :  0    and dword ptr [rax], eax
# 0   1397      :  0    add byte ptr [rax], al
# 0   1398      :  373  add cl, ch
# 1   1399      :  745  jmp 0x1b38
# 0   1400      :  747  mov esp, 0xe9000015
# 0   1401      :  0    adc eax, 0x5be90000
# 0   1402      :  0    add byte ptr [rax], al
# 0   1403      :  0    add cl, ch
# 1   1404      :  755  jmp 0x1adc
# 0   1405      :  757  pop rbx
# 0   1406      :  760  adc eax, 0x66e90000
# 0   1407      :  0    add byte ptr [rax], al
# 0   1408      :  0    add cl, ch
# 1   1409      :  765  jmp 0x10ec
# 0   1410      :  385  or ax, word ptr [rax]
# 0   1411      :  383  or eax, dword ptr [rax]
# 0   1412      :  0    add byte ptr [rax], al
# 0   1413      :  775  add cl, ch
# 1   1414      :  775  jmp 0x21c0
# 0   1415      :  390  xor eax, 0xe900001c
# 0   1416      :  0    sbb al, 0
# 0   1417      :  0    add byte ptr [rax], al
# 0   1418      :  393  add cl, ch
# 1   1419      :  785  jmp 0x1688
# 0   1420      :  787  clc
# 0   1421      :  397  adc byte ptr [rax], al
# 0   1422      :  0    add byte ptr [rax], al
# 0   1423      :  398  add cl, ch
# 1   1424      :  795  jmp 0x1584
# 0   1425      :  400  out dx, eax
# 0   1426      :  402  sldt word ptr [rax]
# 0   1427      :  0    add byte ptr [rax], al
# 0   1428      :  0    add cl, ch
# 1   1429      :  1208 jmp 0x1b44
# 0   1430      :  405  stosb byte ptr [rdi], al
# 0   1431      :  407  adc eax, 0xdde90000
# 0   1432      :  0    add byte ptr [rax], al
# 0   1433      :  0    add cl, ch
# 1   1434      :  815  jmp 0x267c
# 0   1435      :  410  frstor dword ptr [rax]
# 0   1436      :  408  and byte ptr [rax], al
# 0   1437      :  412  add byte ptr [rax], al
# 0   1438      :  413  add cl, ch
# 1   1439      :  825  jmp 0x1b04
# 0   1440      :  415  None
# 0   1441      :  0    adc eax, 0xa7e90000
# 0   1442      :  0    add byte ptr [rax], al
# 0   1443      :  0    add cl, ch
# 1   1444      :  835  jmp 0x1b50
# 0   1445      :  420  cmpsd dword ptr [rsi], dword ptr [rdi]
# 0   1446      :  840  adc eax, 0x82e90000
# 0   1447      :  0    add byte ptr [rax], al
# 0   1448      :  0    add cl, ch
# 1   1449      :  845  jmp 0x2030
# 0   1450      :  425  None
# 0   1451      :  423  sbb al, byte ptr [rax]
# 0   1452      :  0    add byte ptr [rax], al
# 0   1453      :  428  add cl, ch
# 1   1454      :  855  jmp 0x1f34
# 0   1455      :  430  sbb dword ptr [rcx], 0x6ce90000
# 0   1456      :  0    sbb dword ptr [rax], eax
# 0   1457      :  0    add byte ptr [rax], al
# 0   1458      :  433  add cl, ch
# 1   1459      :  865  jmp 0x1524
# 0   1460      :  435  insb byte ptr [rdi], dx
# 0   1461      :  869  sldt word ptr [rax]
# 0   1462      :  0    add byte ptr [rax], al
# 0   1463      :  0    add cl, ch
# 1   1464      :  1313 jmp 0x185c
# 0   1465      :  440  lahf
# 0   1466      :  442  adc al, byte ptr [rax]
# 0   1467      :  0    add byte ptr [rax], al
# 0   1468      :  443  add cl, ch
# 1   1469      :  885  jmp 0x21c4
# 0   1470      :  445  add bl, byte ptr [rax + rax]
# 0   1471      :  0    sbb al, 0
# 0   1472      :  0    add byte ptr [rax], al
# 0   1473      :  895  add cl, ch
# 1   1474      :  895  jmp 0x1b5c
# 0   1475      :  450  xchg ebp, eax
# 0   1476      :  452  adc eax, 0x4e90000
# 0   1477      :  0    add byte ptr [rax], al
# 0   1478      :  0    add cl, ch
# 1   1479      :  905  jmp 0x14d0
# 0   1480      :  455  add al, 0xf
# 0   1481      :  453  sldt word ptr [rax]
# 0   1482      :  457  add byte ptr [rax], al
# 0   1483      :  0    add cl, ch
# 1   1484      :  1373 jmp 0x14dc
# 0   1485      :  460  or ecx, dword ptr [rdi]
# 0   1486      :  0    sldt word ptr [rax]
# 0   1487      :  462  add byte ptr [rax], al
# 0   1488      :  0    add cl, ch
# 1   1489      :  1388 jmp 0xf6c
# 0   1490      :  465  xchg esi, eax
# 0   1491      :  467  or dword ptr [rax], eax
# 0   1492      :  0    add byte ptr [rax], al
# 0   1493      :  468  add cl, ch
# 1   1494      :  935  jmp 0x1f38
# 0   1495      :  470  pop rbp
# 0   1496      :  472  sbb dword ptr [rax], eax
# 0   1497      :  0    add byte ptr [rax], al
# 0   1498      :  473  add cl, ch
# 1   1499      :  945  jmp 0x1af0
# 0   1500      :  475  adc byte ptr [rip + 0x5be90000], dl
# 0   1501      :  0    adc eax, 0x5be90000
# 0   1502      :  0    add byte ptr [rax], al
# 0   1503      :  0    add cl, ch
# 1   1504      :  955  jmp 0x1d40
# 0   1505      :  480  pop rbx
# 0   1506      :  1437 None
# 0   1507      :  0    add byte ptr [rax], al
# 0   1508      :  0    add cl, ch
# 1   1509      :  965  jmp 0x15d4
# 0   1510      :  485  None
# 0   1511      :  0    sldt word ptr [rax]
# 0   1512      :  0    add byte ptr [rax], al
# 0   1513      :  0    add cl, ch
# 1   1514      :  1463 jmp 0x16a4
# 0   1515      :  490  mov ch, 0x10
# 0   1516      :  0    adc byte ptr [rax], al
# 0   1517      :  492  add byte ptr [rax], al
# 0   1518      :  493  add cl, ch
# 1   1519      :  985  jmp 0x1f08
# 0   1520      :  495  adc al, 0x19
# 0   1521      :  0    sbb dword ptr [rax], eax
# 0   1522      :  497  add byte ptr [rax], al
# 0   1523      :  498  add cl, ch
# 1   1524      :  995  jmp 0x1cf8
# 0   1525      :  500  call qword ptr [rsi]
# 0   1526      :  0    None
# 0   1527      :  502  add byte ptr [rax], al
# 0   1528      :  0    add cl, ch
# 1   1529      :  1005 jmp 0x15b8
# 0   1530      :  505  mov edx, 0xe900000f
# 0   1531      :  0    sldt word ptr [rax]
# 0   1532      :  0    add byte ptr [rax], al
# 0   1533      :  0    add cl, ch
# 1   1534      :  1523 jmp 0x11cc
# 0   1535      :  1017 leave
# 0   1536      :  512  or eax, dword ptr [rax]
# 0   1537      :  0    add byte ptr [rax], al
# 0   1538      :  513  add cl, ch
# 1   1539      :  1025 jmp 0x164c
# 0   1540      :  515  adc byte ptr [rax], r8b
# 0   1541      :  0    adc byte ptr [rax], al
# 0   1542      :  0    add byte ptr [rax], al
# 0   1543      :  1035 add ah, cl
# 0   1544      :  1035 int3
# 0   2083      :  1059 and al, 8
# 0   2084      :  0    or byte ptr [rax - 0x77], cl
# 1   2085      :  3175 mov qword ptr [rsp + 0x10], rbp
# 0   2086      :  0    mov dword ptr [rsp + 0x10], ebp
# 0   2087      :  1061 insb byte ptr [rdi], dx
# 0   2088      :  1064 and al, 0x10
# 0   2089      :  0    adc byte ptr [rax - 0x77], cl
# 1   2090      :  3190 mov qword ptr [rsp + 0x18], rsi
# 0   2091      :  0    mov dword ptr [rsp + 0x18], esi
# 0   2092      :  1066 je 0x852
# 0   2093      :  0    and al, 0x18
# 0   2094      :  1069 sbb byte ptr [rdi + 0x48], dl
# 1   2095      :  3205 push rdi
# 1   2096      :  1072 sub rsp, 0x30
# 0   2097      :  1071 sub esp, 0x30
# 0   2098      :  0    in al, dx
# 0   2099      :  1075 xor byte ptr [rcx - 0x75], cl
# 1   2100      :  2147 mov rbx, r9
# 0   2101      :  0    mov ebx, ecx
# 0   2102      :  1076 None
# 1   2103      :  2155 mov rdi, r8
# 0   2104      :  0    mov edi, eax
# 0   2105      :  0    clc
# 1   2106      :  3243 mov rsi, rdx
# 0   2107      :  0    mov esi, edx
# 0   2108      :  0    mov rbp, rcx
# 1   2109      :  2167 mov rbp, rcx
# 0   2110      :  0    mov ebp, ecx
# 0   2111      :  0    jmp 0xfffffffffffbd32c
# 1   2112      :  3258 call 0x40f
# 0   2113      :  0    retf 0xfffb
# 0   2114      :  0    sti
# 0   2115      :  1091 None
# 0   2116      :  2178 dec dword ptr [rbx + rcx*4 - 0x31]
# 1   2117      :  1089 mov r9, rdi
# 0   2118      :  0    mov ecx, edi
# 0   2119      :  0    iretd
# 1   2120      :  4378 mov qword ptr [rsp + 0x20], rbx
# 0   2121      :  0    mov dword ptr [rsp + 0x20], ebx
# 0   2122      :  0    pop rsp
# 0   2123      :  1099 and al, 0x20
# 0   2124      :  0    and byte ptr [rbx + rcx*4 - 0x3a], cl
# 1   2125      :  3295 mov r8, rsi
# 0   2126      :  0    mov eax, esi
# 0   2127      :  0    None
# 1   2128      :  3306 mov rdx, rbp
# 0   2129      :  0    mov edx, ebp
# 0   2130      :  0    None
# 1   2131      :  2211 mov rcx, qword ptr [rax]
# 0   2132      :  0    mov ecx, dword ptr [rax]
# 0   2133      :  0    or bh, bh
# 1   2134      :  2217 call qword ptr [rip + 0x9f7c]
# 0   2135      :  1110 adc eax, 0x9f7c
# 0   2136      :  0    jl 0x7f9
# 0   2137      :  0    lahf
# 0   2138      :  2227 add byte ptr [rax], al
# 0   2139      :  0    add byte ptr [rax - 0x75], cl
# 1   2140      :  3338 mov rbx, qword ptr [rsp + 0x40]
# 0   2141      :  0    mov ebx, dword ptr [rsp + 0x40]
# 0   2142      :  1116 pop rsp
# 0   2143      :  1119 and al, 0x40
# 0   2144      :  0    mov rbp, qword ptr [rsp + 0x48]
# 1   2145      :  3355 mov rbp, qword ptr [rsp + 0x48]
# 0   2146      :  0    mov ebp, dword ptr [rsp + 0x48]
# 0   2147      :  0    insb byte ptr [rdi], dx
# 0   2148      :  1124 and al, 0x48
# 0   2149      :  0    mov rsi, qword ptr [rsp + 0x50]
# 1   2150      :  4491 mov rsi, qword ptr [rsp + 0x50]
# 0   2151      :  0    mov esi, dword ptr [rsp + 0x50]
# 0   2152      :  0    je 0x88e
# 0   2153      :  0    and al, 0x50
# 0   2154      :  1129 push rax
# 1   2155      :  5642 add rsp, 0x30
# 0   2156      :  0    add esp, 0x30
# 0   2157      :  0    None
# 0   2158      :  0    xor byte ptr [rdi - 0x3d], bl
# 1   2159      :  2265 pop rdi
# 1   2160      :  1136 ret
# 0   2161      :  2272 int3
# 0   2162      :  1138 int3
# 0   2163      :  1139 int3
# 0   2164      :  1140 int3
# 0   2165      :  1141 int3
# 0   2166      :  1142 int3
# 0   2167      :  1143 int3
# 0   2168      :  1144 int3
# 0   2169      :  1145 int3
# 0   2170      :  1146 int3
# 0   2171      :  1147 int3
# 0   2172      :  1148 int3
# 0   2173      :  1149 int3
# 0   2174      :  1150 int3
# 0   2175      :  1151 int3
# 0   2176      :  1152 int3
# 0   2177      :  1153 int3
# 0   2178      :  1154 int3
# 0   2179      :  1155 int3
# 0   2180      :  1156 int3
# 0   2181      :  1157 int3
# 0   2182      :  1158 int3
# 0   2183      :  1159 int3
# 0   2184      :  1160 int3
# 0   2185      :  1161 int3
# 0   2186      :  1162 int3
# 0   2187      :  1163 int3
# 0   2188      :  1164 int3
# 0   2189      :  1165 int3
# 0   2190      :  1166 int3
# 0   2191      :  1167 int3
# 1   2192      :  1168 sub rsp, 0xd8
# 0   2193      :  0    sub esp, 0xd8
# 0   2194      :  0    in al, dx
# 0   2195      :  1171 fadd dword ptr [rax]
# 0   2196      :  0    add byte ptr [rax], al
# 0   2197      :  1172 add byte ptr [rax], al
# 0   2198      :  1173 add byte ptr [rax - 0x75], cl
# 1   2199      :  3513 mov rax, qword ptr [rip + 0x7b62]
# 0   2200      :  0    mov eax, dword ptr [rip + 0x7b62]
# 0   2201      :  1175 add eax, 0x7b62
# 0   2202      :  0    None
# 0   2203      :  0    jnp 0x89d
# 0   2204      :  0    add byte ptr [rax], al
# 0   2205      :  1180 add byte ptr [rax + 0x33], cl
# 1   2206      :  4712 xor rax, rsp
# 0   2207      :  0    xor eax, esp
# 0   2208      :  1182 None
# 1   2209      :  2367 mov qword ptr [rsp + 0xc0], rax
# 0   2210      :  0    mov dword ptr [rsp + 0xc0], eax
# 0   2211      :  0    test byte ptr [rax + rax*8], ah
# 0   2212      :  0    and al, 0xc0
# 0   2213      :  0    rol byte ptr [rax], 0
# 0   2214      :  2377 add byte ptr [rax], al
# 0   2215      :  0    add byte ptr [rax], al
# 0   2216      :  2381 add byte ptr [rax - 0x73], cl
# 1   2217      :  3565 lea rdx, [rsp + 0x20]
# 0   2218      :  0    lea edx, [rsp + 0x20]
# 0   2219      :  1193 push rsp
# 0   2220      :  1196 and al, 0x20
# 0   2221      :  0    and byte ptr [rax - 0x73], cl
# 1   2222      :  3586 lea rcx, [rip + 0x676b]
# 0   2223      :  0    lea ecx, [rip + 0x676b]
# 0   2224      :  1198 or eax, 0x676b
# 0   2225      :  0    imul esp, dword ptr [rdi], 0
# 0   2226      :  0    add byte ptr [eax], al
# 0   2227      :  0    add byte ptr [rax], al
# 0   2228      :  0    add al, ch
# 1   2229      :  7209 call 0x4f5
# 0   2230      :  1205 cmp edi, esp
# 0   2231      :  0    cld
# 0   2232      :  2415 None
# 0   2233      :  0    dec dword ptr [rax - 0x73]
# 1   2234      :  1206 lea rdx, [rsp + 0x52]
# 0   2235      :  0    lea edx, [rsp + 0x52]
# 0   2236      :  1210 push rsp
# 0   2237      :  1213 and al, 0x52
# 0   2238      :  0    push rdx
# 1   2239      :  4852 lea rcx, [rip + 0x676a]
# 0   2240      :  0    lea ecx, [rip + 0x676a]
# 0   2241      :  0    or eax, 0x676a
# 0   2242      :  0    push 0x67
# 0   2243      :  0    add byte ptr [eax], al
# 0   2244      :  1219 add byte ptr [rax], al
# 0   2245      :  0    add al, ch
# 1   2246      :  6092 call 0x4f5
# 0   2247      :  1222 sub bh, ah
# 0   2248      :  0    cld
# 0   2249      :  2449 None
# 0   2250      :  0    dec dword ptr [rax - 0x73]
# 1   2251      :  1223 lea rdx, [rsp + 0x84]
# 0   2252      :  0    lea edx, [rsp + 0x84]
# 0   2253      :  1227 xchg esp, eax
# 0   2254      :  1230 and al, 0x84
# 0   2255      :  0    test byte ptr [rax], al
# 0   2256      :  1231 add byte ptr [rax], al
# 0   2257      :  1232 add byte ptr [rax], al
# 0   2258      :  1233 add byte ptr [rax - 0x73], cl
# 1   2259      :  3691 lea rcx, [rip + 0x6766]
# 0   2260      :  0    lea ecx, [rip + 0x6766]
# 0   2261      :  1235 or eax, 0x6766
# 0   2262      :  0    add byte ptr [eax], al
# 0   2263      :  0    add byte ptr [eax], al
# 0   2264      :  0    add byte ptr [rax], al
# 0   2265      :  0    add al, ch
# 1   2266      :  7431 call 0x4f5
# 0   2267      :  1242 None
# 0   2268      :  0    cld
# 0   2269      :  1245 None
# 0   2270      :  0    dec dword ptr [rax - 0x75]
# 1   2271      :  1243 mov rcx, qword ptr [rsp + 0xc0]
# 0   2272      :  0    mov ecx, dword ptr [rsp + 0xc0]
# 0   2273      :  1247 mov word ptr [rax + rax*8], fs
# 0   2274      :  0    and al, 0xc0
# 0   2275      :  0    rol byte ptr [rax], 0
# 0   2276      :  2501 add byte ptr [rax], al
# 0   2277      :  0    add byte ptr [rax], al
# 0   2278      :  2505 add byte ptr [rax + 0x33], cl
# 1   2279      :  3751 xor rcx, rsp
# 0   2280      :  0    xor ecx, esp
# 0   2281      :  1255 int3
# 1   2282      :  3771 call 0x504
# 0   2283      :  0    adc eax, 0x48fffffc
# 0   2284      :  0    cld
# 0   2285      :  1261 None
# 0   2286      :  0    dec dword ptr [rax - 0x7f]
# 1   2287      :  1259 add rsp, 0xd8
# 0   2288      :  1260 add esp, 0xd8
# 0   2289      :  1263 None
# 0   2290      :  0    fadd dword ptr [rax]
# 0   2291      :  0    add byte ptr [rax], al
# 0   2292      :  1267 add byte ptr [rax], al
# 0   2293      :  1268 add bl, al
# 1   2294      :  3798 ret
# 0   2295      :  2541 int3
# 0   2296      :  1272 int3
# 0   2297      :  1273 int3
# 0   2298      :  1274 int3
# 0   2299      :  1275 int3
# 0   2300      :  1276 int3
# 0   2301      :  1277 int3
# 0   2302      :  1278 int3
# 0   2303      :  1279 int3
# 0   2304      :  1280 int3
# 0   2305      :  1281 int3
# 0   2306      :  1282 int3
# 0   2307      :  1283 int3
# 0   2308      :  1284 int3
# 0   2309      :  1285 int3
# 0   2310      :  1286 int3
# 0   2311      :  1287 int3
# 0   2312      :  1288 int3
# 0   2313      :  1289 int3
# 0   2314      :  1290 int3
# 0   2315      :  1291 int3
# 0   2316      :  1292 int3
# 0   2317      :  1293 int3
# 0   2318      :  1294 int3
# 0   2319      :  1295 int3
# 1   2320      :  1296 sub rsp, 0xd8
# 0   2321      :  0    sub esp, 0xd8
# 0   2322      :  0    in al, dx
# 0   2323      :  1299 fadd dword ptr [rax]
# 0   2324      :  0    add byte ptr [rax], al
# 0   2325      :  1300 add byte ptr [rax], al
# 0   2326      :  1301 add byte ptr [rax - 0x75], cl
# 1   2327      :  3897 mov rax, qword ptr [rip + 0x7ae2]
# 0   2328      :  0    mov eax, dword ptr [rip + 0x7ae2]
# 0   2329      :  1303 add eax, 0x7ae2
# 0   2330      :  0    loop 0x996
# 0   2331      :  0    jp 0x91d
# 0   2332      :  1307 add byte ptr [rax], al
# 0   2333      :  1308 add byte ptr [rax + 0x33], cl
# 1   2334      :  5224 xor rax, rsp
# 0   2335      :  0    xor eax, esp
# 0   2336      :  1310 None
# 1   2337      :  2623 mov qword ptr [rsp + 0xc0], rax
# 0   2338      :  0    mov dword ptr [rsp + 0xc0], eax
# 0   2339      :  0    test byte ptr [rax + rax*8], ah
# 0   2340      :  0    and al, 0xc0
# 0   2341      :  0    rol byte ptr [rax], 0
# 0   2342      :  2633 add byte ptr [rax], al
# 0   2343      :  0    add byte ptr [rax], al
# 0   2344      :  2637 add byte ptr [rax - 0x73], cl
# 1   2345      :  3949 lea rcx, [rip + 0x6680]
# 0   2346      :  0    lea ecx, [rip + 0x6680]
# 0   2347      :  1321 or eax, 0x6680
# 0   2348      :  0    and byte ptr [rsi], 0
# 0   2349      :  0    add byte ptr [rax], al
# 0   2350      :  0    add byte ptr [rax], al
# 0   2351      :  0    add al, ch
# 1   2352      :  7947 call 0x4f5
# 0   2353      :  1328 sar bl, 0xff
# 0   2354      :  0    sti
# 0   2355      :  1331 None
# 0   2356      :  1330 dec dword ptr [rax - 0x73]
# 1   2357      :  1329 lea rcx, [rsp + 0x20]
# 0   2358      :  0    lea ecx, [rsp + 0x20]
# 0   2359      :  1333 and al, 0x20
# 0   2360      :  0    and al, 0x20
# 0   2361      :  0    and al, ch
# 1   2362      :  5342 call 0x25da
# 0   2363      :  1338 wait
# 0   2364      :  1340 sbb al, 0
# 0   2365      :  0    add byte ptr [rax], al
# 0   2366      :  1341 add byte ptr [rax - 0x73], cl
# 1   2367      :  2681 lea rcx, [rip + 0x6692]
# 0   2368      :  0    lea ecx, [rip + 0x6692]
# 0   2369      :  1343 or eax, 0x6692
# 0   2370      :  0    xchg edx, eax
# 0   2371      :  1347 add byte ptr [rax], al
# 0   2372      :  0    add byte ptr [rax], al
# 0   2373      :  0    add al, ch
# 1   2374      :  6732 call 0x4f5
# 0   2375      :  1350 stosb byte ptr [rdi], al
# 0   2376      :  1352 sti
# 0   2377      :  1353 None
# 0   2378      :  0    dec dword ptr [rax - 0x73]
# 1   2379      :  1351 lea rcx, [rsp + 0x52]
# 0   2380      :  0    lea ecx, [rsp + 0x52]
# 0   2381      :  1355 and al, 0x52
# 0   2382      :  0    and al, 0x52
# 0   2383      :  0    push rdx
# 1   2384      :  6790 call 0x25da
# 0   2385      :  0    test dword ptr [rax + rax], ebx
# 0   2386      :  0    sbb al, 0
# 0   2387      :  0    add byte ptr [rax], al
# 0   2388      :  2725 add byte ptr [rax - 0x73], cl
# 1   2389      :  2725 lea rcx, [rip + 0x66a4]
# 0   2390      :  0    lea ecx, [rip + 0x66a4]
# 0   2391      :  1365 or eax, 0x66a4
# 0   2392      :  0    movsb byte ptr [rdi], byte ptr [rsi]
# 0   2393      :  1369 add byte ptr [rax], al
# 0   2394      :  0    add byte ptr [rax], al
# 0   2395      :  0    add al, ch
# 1   2396      :  6842 call 0x4f5
# 0   2397      :  1372 xchg esp, eax
# 0   2398      :  1374 sti
# 0   2399      :  1375 None
# 0   2400      :  0    dec dword ptr [rax - 0x73]
# 1   2401      :  1373 lea rcx, [rsp + 0x84]
# 0   2402      :  0    lea ecx, [rsp + 0x84]
# 0   2403      :  1377 mov word ptr [rsp + rax*4], fs
# 0   2404      :  0    and al, 0x84
# 0   2405      :  0    test byte ptr [rax], al
# 0   2406      :  2761 add byte ptr [rax], al
# 0   2407      :  1382 add byte ptr [rax], al
# 0   2408      :  1383 add al, ch
# 1   2409      :  4141 call 0x25da
# 0   2410      :  1385 insb byte ptr [rdi], dx
# 0   2411      :  1387 sbb al, 0
# 0   2412      :  0    add byte ptr [rax], al
# 0   2413      :  1388 add byte ptr [rax - 0x73], cl
# 1   2414      :  2775 lea rdx, [rsp + 0x20]
# 0   2415      :  0    lea edx, [rsp + 0x20]
# 0   2416      :  1390 push rsp
# ...
# 0   22200     :  21176 int3
# 0   22201     :  21177 int3
# 0   22202     :  21178 int3
# 0   22203     :  21179 int3
# 0   22204     :  21180 int3
# 0   22205     :  21181 int3
# 0   22206     :  21182 int3
# 0   22207     :  21183 int3
# 0   22208     :  21184 int3
# 0   22209     :  21185 int3
# 0   22210     :  21186 int3
# 0   22211     :  21187 int3
# 0   22212     :  21188 int3
# 0   22213     :  21189 int3
# 0   22214     :  21190 int3
# 0   22215     :  21191 int3
# 0   22216     :  21192 int3
# 0   22217     :  21193 int3
# 0   22218     :  21194 int3
# 0   22219     :  21195 int3
# 0   22220     :  21196 int3
# 0   22221     :  21197 int3
# 0   22222     :  21198 int3
# 0   22223     :  21199 int3
# 0   22224     :  21200 int3
# 0   22225     :  21201 int3
# 0   22226     :  21202 int3
