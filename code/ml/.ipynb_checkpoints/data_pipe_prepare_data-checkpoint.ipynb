# %%
from accelerate import Accelerator
import torch

accelerator = Accelerator()
accelerator.state.num_processes = 3  # For 3 GPUs
device = accelerator.device
# device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
import os,sys, json,re
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn

from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words

# %%
bin_path = '/home/raisul/DATA/x86_O2_d4/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) ][0:10000]
ground_truth_path ='/home/raisul/ANALYSED_DATA/ghidra_x86_O2_d4/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'prototype_elf_asis'
MAX_TOKEN_SIZE = 120
MAX_SEQUENCE_LENGTH = 10
VOCAB_SIZE = 500
BATCH_SIZE = 600

# %%
def replace_num_with_word(input_string , replace_dict):
    def num_to_word(match):
        number = int( match.group(0))
        return num2words(replace_dict[number]).replace(' ','').replace('-',"")
    result_string = re.sub(r'\b\d+\b', num_to_word, input_string)
    return result_string



def replace_hex_with_decimal(input_string):
    # Regular expression to find hexadecimal numbers prefixed with "0x" or "0X"
    hex_pattern = r'0[xX][0-9a-fA-F]+'
    
    # Function to convert each found hex number to decimal
    def hex_to_decimal(match):
        hex_value = match.group(0)  # Extract the matched hex number
        decimal_value = str(int(hex_value, 16))  # Convert hex to decimal
        return decimal_value
    # Substitute all hex numbers in the string with their decimal equivalents
    result_string = re.sub(hex_pattern, hex_to_decimal, input_string)
    return result_string

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets

# %%
def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list


SEQUENCES = []
LABELS     = []

for bin_file_path in bin_files:

    
    md = Cs(CS_ARCH_X86, CS_MODE_64)
    md.detail = True
    offset_inst = {}

    
    with open(bin_file_path, 'rb') as f:

        try:
            elffile = ELFFile(f)
           
            textSection = elffile.get_section_by_name('.text').data()
        
            text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
          
            ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
            
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue

    for byte_index in range(len(textSection)):
        try:    

            instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
            offset_inst[text_section_offset+byte_index] = instruction
            
            # if instruction:
            #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
            # else:
            #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                
            

        except Exception as e:
            print(traceback.print_exc() )
            print(e)

    
    
    offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))

    DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)


    
    for byte_offset in range(text_section_offset, text_section_offset+len(textSection)):
        return_value = linear_sweep(offset_inst_dict ,  byte_offset )
        if return_value== None:
            continue
        inst_seq, inst_addresses = return_value 
        ###################################################################
        ## number to words
        disassembly_decimal = replace_hex_with_decimal(inst_seq)

        #num to words all
        numbers = [int(s) for s in re.findall(r'\b\d+\b', disassembly_decimal)]
        numbers = sorted(set(numbers) , reverse=True)
        number_word_dict = {}
        
        for ix,n in enumerate(numbers):
            number_word_dict[n] = len(numbers)-1 -ix

        disassembly_num_to_words = replace_num_with_word(disassembly_decimal , number_word_dict)

        


        
        ###########################################################################
        
        
        SEQUENCES.append(disassembly_num_to_words)
        if byte_offset in ground_truth_offsets:
            LABELS.append(float(1))
        else:
            LABELS.append(float(0))

# %%
print(len(SEQUENCES) , len(LABELS))
print(LABELS.count(0), LABELS.count(1))
# Out:
# 6216 6216
# 4467 1749

# %%
import sys,os

from transformers import BertTokenizer,BertForSequenceClassification

# If using a character-level tokenizer for sequences like DNA/Protein:
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")#BertTokenizer.from_pretrained('bert-base-uncased')

tokenizer = tokenizer.train_new_from_iterator(SEQUENCES, VOCAB_SIZE)


# model = BertForSequenceClassification.from_pretrained(
#     'bert-base-uncased',
#     num_labels=1  
# )

model = BertForSequenceClassification.from_pretrained(
    MODEL_SAVE_PATH +EXPERIMENT_NAME,
    num_labels=1  
)

model.resize_token_embeddings(VOCAB_SIZE)
model.to(device)


optim = AdamW( model.parameters() , lr=1e-5, eps = 1e-6, betas=(0.9,0.98), weight_decay=0.01)
# Out:
# /home/raisul/anaconda3/envs/pytorch/lib/python3.12/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
SEQUENCES[0]
# Out:
# 'five endbr64  ; six sub rsp, two ; seven mov rdi, qword ptr [rsi + two] ; eight xor eax, eax ; nine call four ; ten lea rsi, [rip + three] ; eleven mov edi, zero ; twelve lea edx, [rax + rax*zero + zero] ; thirteen imul edx, eax ; fourteen sub edx, one ; '

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        
    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]

        # Tokenize the 
        tokenized_text = (self.tokenizer(text , max_length= MAX_TOKEN_SIZE,padding='max_length', truncation=True , return_tensors='pt')).to(device)
        
        return tokenized_text, label
        
    def __len__(self):
        return len(self.texts)

# %%
dataset = BinaryDataset(SEQUENCES, LABELS,tokenizer)
train_size = int(0.8 * len(dataset))
validation_size = len(dataset) - train_size

train_dataset  = torch.utils.data.Subset(dataset, range(train_size))
validation_dataset = torch.utils.data.Subset(dataset, range(train_size , len(dataset)))

# train_dataset, validation_dataset = torch.utils.data.random_split(dataset, [train_size, validation_size] , generator=torch.Generator().manual_seed(42))

# %%
len(train_dataset) , len(validation_dataset)
# Out:
# (4972, 1244)

# %%
train_loader      = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE ,shuffle=False) 
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
model, optim, train_loader,validation_loader = accelerator.prepare(model, optim, train_loader,validation_loader)

# %%
def training_loop(model ,data_loop, is_training = False):
    
    prediction_s, ground_truth_s = [], []
    losses = []

    for N,batch in enumerate(data_loop):
        # Forward pass
        if is_training == True:
            optim.zero_grad()
        
        batch_input, batch_labels = batch
        if len(batch_labels)<BATCH_SIZE:
            continue
            
        batch_input_ids= batch_input['input_ids']
        batch_attention_mask=batch_input['attention_mask']
        batch_token_type_ids =batch_input['token_type_ids']
        
        outputs = model(input_ids=batch_input_ids.squeeze(),
                        attention_mask=batch_attention_mask.squeeze(),
                        token_type_ids=batch_token_type_ids.squeeze(),
                        labels=batch_labels.float() )
        
#

        loss = outputs.loss
        losses.append(loss.item())
        
        logits = outputs.logits
        predictions = logits.squeeze()
        # print(logits ,predictions )

        prediction_s.extend(predictions.detach().cpu().numpy().flatten())
        ground_truth_s.extend(batch_labels.detach().cpu().numpy().flatten())


        if is_training == True:
            # loss.backward()
            accelerator.backward(loss)
            optim.step()
        # print relevant info to progress bar
        data_loop.set_description(f'Epoch {ecpoch}')
        data_loop.set_postfix(loss=loss.item())

    # Evaluation Metrics
    mse = mean_squared_error(ground_truth_s, prediction_s)
    rmse = sqrt(mse)
    mae = mean_absolute_error(ground_truth_s, prediction_s)
    r2 = r2_score(ground_truth_s, prediction_s)
    

    metrices = {'MSE':mse ,
                      'RMSE':rmse, 
                      'MAE':mae, 
                      'R²':r2,
                      'loss': (sum(losses) / len(losses))}
    return metrices , prediction_s, ground_truth_s

# %%
EPOCHS = 100


global_metrices = []
v_global_metrices = []


for ecpoch in range(EPOCHS):
    
    train_loop = tqdm(train_loader, leave=True)
    model.train()
    metrices,prediction_s, ground_truth_s  = training_loop(model ,train_loop, is_training = True)
    global_metrices.append(metrices)
    print("Training metrices ",metrices)
     
    with torch.no_grad():
        model.eval()
        validation_loop = tqdm(validation_loader, leave=True)
        v_metrices, v_prediction_s, v_ground_truth_s  = training_loop(model ,validation_loop, is_training = False)


        demo_len =100

        for i in range( int(minimum(demo_len , len(v_prediction_s) ))):
            print('\n')
            print( v_prediction_s[i], v_ground_truth_s[i] )
            print(tokenizer.decode(validation_dataset[i][0].input_ids[0],skip_special_tokens=True).split('[SEP]')[0] )
            
           
        print( 'v_metrices: ',v_metrices )
        v_global_metrices.append(v_metrices)
        
    if accelerator.is_main_process:
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(MODEL_SAVE_PATH + EXPERIMENT_NAME)

        print('SAVING MODEL @ ',MODEL_SAVE_PATH +EXPERIMENT_NAME)
        unwrapped_model.save_pretrained(MODEL_SAVE_PATH +EXPERIMENT_NAME)
        print('saved')
# Out:
# Epoch 0: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:14<00:00,  1.59s/it, loss=0.155]
# Training metrices  {'MSE': np.float64(0.132139387137754), 'RMSE': np.float64(0.36350981711331265), 'MAE': np.float64(0.26985170258616564), 'R²': 0.34153851817876735, 'loss': np.float64(0.13213939405977726)}
# Epoch 0: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  1.95it/s, loss=0.113]
# 0.65318334 1.0
# three xor eax, eax ; four call one ; five add rbp, zero ; six cmp ebx, r12d ; seven jne two ; eight pop rbx ; nine pop rbp ; ten pop r12 ; eleven pop r13 ; twelve pop r14 ;
#
#
# 0.47892863 1.0
# three call one ; four add rbp, zero ; five cmp ebx, r12d ; six jne two ; seven pop rbx ; eight pop rbp ; nine pop r12 ; ten pop r13 ; eleven pop r14 ; twelve ret ;
#
#
# 0.1489995 1.0
# two add rbp, zero ; three cmp ebx, r12d ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# 0.38898426 0.0
# two add ebp, zero ; three cmp ebx, r12d ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# 0.006332808 0.0
# two add al, zero ; three cmp ebx, esp ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# 0.59808385 1.0
# one cmp ebx, r12d ; two jne zero ; three pop rbx ; four pop rbp ; five pop r12 ; six pop r13 ; seven pop r14 ; eight ret ;
#
#
# 0.45608407 0.0
# one cmp ebx, esp ; two jne zero ; three pop rbx ; four pop rbp ; five pop r12 ; six pop r13 ; seven pop r14 ; eight ret ;
#
#
# 0.5730015 1.0
# one jne zero ; two pop rbx ; three pop rbp ; four pop r12 ; five pop r13 ; six pop r14 ; seven ret ;
#
#
# 0.806834 1.0
# zero pop rbx ; one pop rbp ; two pop r12 ; three pop r13 ; four pop r14 ; five ret ;
#
#
# 0.812175 1.0
# zero pop rbp ; one pop r12 ; two pop r13 ; three pop r14 ; four ret ;
#
#
# 0.5026845 1.0
# zero pop r12 ; one pop r13 ; two pop r14 ; three ret ;
#
#
# 0.7686217 0.0
# zero pop rsp ; one pop r13 ; two pop r14 ; three ret ;
#
#
# 0.7300191 1.0
# zero pop r13 ; one pop r14 ; two ret ;
#
#
# 0.5407346 0.0
# zero pop rbp ; one pop r14 ; two ret ;
#
#
# 0.673238 1.0
# zero pop r14 ; one ret ;
#
#
# 0.4313295 0.0
# zero pop rsi ; one ret ;
#
#
# 0.85392714 1.0
# zero ret ;
#
#
# 0.03946571 0.0
# zero nop dword ptr [ rax + rax ] ; one ret ;
#
#
# 0.0051970384 0.0
# zero add byte ptr [ rax ], r8b ; one ret ;
#
#
# 0.0062871324 0.0
# zero add byte ptr [ rax ], al ; one ret ;
#
#
# 0.004265978 0.0
# zero add bl, al ;
#
#
# 0.85392714 1.0
# zero ret ;
#
#
# 0.42863578 1.0
# two endbr64 ; three push rbp ; four lea rdi, [ rip + one ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ;
#
#
# 0.32218802 0.0
# two cli ; three push rbp ; four lea rdi, [ rip + one ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ;
#
#
# 0.7816318 1.0
# three push rbp ; four lea rdi, [ rip + two ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ; twelve lea rbx, [ rbp - one ] ;
#
#
# 0.82510936 1.0
# three lea rdi, [ rip + two ] ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# 0.40869626 0.0
# three lea edi, [ rip + two ] ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# 0.3716051 0.0
# three cmp eax, two ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# 0.006541238 0.0
# two cmp cl, byte ptr [ rdi ] ; three add byte ptr [ rax ], al ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ;
#
#
# 0.0064132633 0.0
# two sldt word ptr [ rax ] ; three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - zero ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - one ] ; eleven sub rsp, one ;
#
#
# 0.0065139215 0.0
# two add byte ptr [ rax ], al ; three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - zero ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - one ] ; eleven sub rsp, one ;
#
#
# 0.006873277 0.0
# four add byte ptr [ rax - three ], cl ; five in eax, zero ; six push rdi ; seven push r14 ; eight lea rsi, [ rbp - one ] ; nine push r13 ; ten push r12 ; eleven push rbx ; twelve lea rbx, [ rbp - two ] ; thirteen sub rsp, two ;
#
#
# 0.5400729 1.0
# three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - one ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - two ] ; eleven sub rsp, two ; twelve mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.40648288 0.0
# three mov ebp, esp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - one ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - two ] ; eleven sub rsp, two ; twelve mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.30863723 0.0
# four in eax, one ; five push rdi ; six push r14 ; seven lea rsi, [ rbp - two ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - three ] ; twelve sub rsp, three ; thirteen mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.43459457 1.0
# four push r15 ; five push r14 ; six lea rsi, [ rbp - two ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - three ] ; eleven sub rsp, three ; twelve mov rax, qword ptr fs : [ zero ] ; thirteen mov qword ptr [ rbp - one ], rax ;
#
#
# 0.38687176 0.0
# four push rdi ; five push r14 ; six lea rsi, [ rbp - two ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - three ] ; eleven sub rsp, three ; twelve mov rax, qword ptr fs : [ zero ] ; thirteen mov qword ptr [ rbp - one ], rax ;
#
#
# 0.39322078 1.0
# four push r14 ; five lea rsi, [ rbp - two ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ zero ] ; twelve mov qword ptr [ rbp - one ], rax ; thirteen xor eax, eax ;
#
#
# 0.16600484 0.0
# four push rsi ; five lea rsi, [ rbp - two ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ zero ] ; twelve mov qword ptr [ rbp - one ], rax ; thirteen xor eax, eax ;
#
#
# 0.053590115 1.0
# five lea rsi, [ rbp - three ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - four ] ; ten sub rsp, four ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.023951277 0.0
# five lea esi, [ rbp - three ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - four ] ; ten sub rsp, four ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.3807859 0.0
# five jne four ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.21780851 0.0
# six mov esp, seventeen ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.38061005 1.0
# five push r13 ; six push r12 ; seven push rbx ; eight lea rbx, [ rbp - three ] ; nine sub rsp, three ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + fifteen ], zero ; fourteen call four ;
#
#
# 0.5529765 0.0
# five push rbp ; six push r12 ; seven push rbx ; eight lea rbx, [ rbp - three ] ; nine sub rsp, three ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + fifteen ], zero ; fourteen call four ;
#
#
# 0.4491945 1.0
# six push r12 ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.59136015 0.0
# six push rsp ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.3265909 1.0
# seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + seventeen ], zero ; fourteen call six ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.22559549 1.0
# eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + eighteen ], zero ; fourteen call seven ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - six ], rbx ; seventeen lea rbx, [ rbp - five ] ;
#
#
# 0.5208045 0.0
# eight lea ebx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + eighteen ], zero ; fourteen call seven ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - six ], rbx ; seventeen lea rbx, [ rbp - five ] ;
#
#
# 0.7340676 0.0
# seven pop rbp ; eight mov eax, eighteen ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + seventeen ], zero ; thirteen call six ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - five ], rbx ; sixteen lea rbx, [ rbp - four ] ;
#
#
# 0.24042003 0.0
# eight mov eax, nineteen ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + eighteen ], zero ; thirteen call seven ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.42854834 1.0
# nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + nineteen ], zero ; fourteen call eight ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - seven ], rbx ; seventeen lea rbx, [ rbp - five ] ; eighteen mov qword ptr [ rbp - six ], rbx ;
#
#
# 0.13851377 0.0
# nine sub esp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + nineteen ], zero ; fourteen call eight ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - seven ], rbx ; seventeen lea rbx, [ rbp - five ] ; eighteen mov qword ptr [ rbp - six ], rbx ;
#
#
# 0.013183713 0.0
# eight in al, dx ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + eighteen ], zero ; thirteen call seven ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.82771826 0.0
# nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.82771826 1.0
# nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.31835485 0.0
# nine mov rax, qword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.05156193 0.0
# nine mov eax, dword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.0055959956 0.0
# seven add al, one ; eight sub byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + seventeen ], zero ; thirteen call six ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - five ], rbx ; sixteen lea rbx, [ rbp - four ] ;
#
#
# 0.2751908 0.0
# nine and eax, one ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.0052007753 0.0
# seven sub byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + seventeen ], zero ; twelve call six ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ;
#
#
# 0.005838664 0.0
# six add byte ptr [ rax ], al ; seven add byte ptr [ rax - four ], cl ; eight enter - seventeen, - zero ; nine add eax, sixteen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call five ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rbp - two ] ;
#
#
# 0.007731911 0.0
# eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + eighteen ], zero ; twelve call seven ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ; seventeen lea rbx, [ rip + six ] ;
#
#
# 0.0061859116 0.0
# seven add byte ptr [ rax - five ], cl ; eight enter - eighteen, - zero ; nine add eax, seventeen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call six ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rbp - two ] ; sixteen mov qword ptr [ rbp - three ], rbx ;
#
#
# 0.2815649 1.0
# nine mov qword ptr [ rbp - two ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# 0.4756388 0.0
# nine mov dword ptr [ rbp - two ], eax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# 0.006049877 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# 0.006049877 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# 0.41088277 1.0
# eight xor eax, eax ; nine mov dword ptr [ rip + eighteen ], zero ; ten call seven ; eleven mov eax, dword ptr [ rbp - two ] ; twelve mov qword ptr [ rbp - five ], rbx ; thirteen lea rbx, [ rbp - three ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rip + six ] ; sixteen lea edx, [ rax - one ] ; seventeen mov dword ptr [ rbp - two ], edx ;
#
#
# 0.51982427 1.0
# eight mov dword ptr [ rip + eighteen ], zero ; nine call seven ; ten mov eax, dword ptr [ rbp - two ] ; eleven mov qword ptr [ rbp - five ], rbx ; twelve lea rbx, [ rbp - three ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rip + six ] ; fifteen lea edx, [ rax - one ] ; sixteen mov dword ptr [ rbp - two ], edx ; seventeen test eax, eax ;
#
#
# 0.0064957235 0.0
# seven add eax, seventeen ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# 0.0054354733 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# 0.005100226 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine call six ; ten mov eax, dword ptr [ rbp - one ] ; eleven mov qword ptr [ rbp - four ], rbx ; twelve lea rbx, [ rbp - two ] ; thirteen mov qword ptr [ rbp - three ], rbx ; fourteen lea rbx, [ rip + five ] ; fifteen lea edx, [ rax - zero ] ; sixteen mov dword ptr [ rbp - one ], edx ;
#
#
# 0.0066642836 0.0
# seven add byte ptr [ rax ], al ; eight call six ; nine mov eax, dword ptr [ rbp - one ] ; ten mov qword ptr [ rbp - four ], rbx ; eleven lea rbx, [ rbp - two ] ; twelve mov qword ptr [ rbp - three ], rbx ; thirteen lea rbx, [ rip + five ] ; fourteen lea edx, [ rax - zero ] ; fifteen mov dword ptr [ rbp - one ], edx ; sixteen test eax, eax ;
#
#
# 0.54142725 1.0
# seven call six ; eight mov eax, dword ptr [ rbp - one ] ; nine mov qword ptr [ rbp - four ], rbx ; ten lea rbx, [ rbp - two ] ; eleven mov qword ptr [ rbp - three ], rbx ; twelve lea rbx, [ rip + five ] ; thirteen lea edx, [ rax - zero ] ; fourteen mov dword ptr [ rbp - one ], edx ; fifteen test eax, eax ; sixteen je seventeen ;
#
#
# 0.025038153 0.0
# five dec dword ptr [ rbx - sixteen ] ; six pop rbp ; seven nop ; eight lea rbx, [ rbp - two ] ; nine mov qword ptr [ rbp - three ], rbx ; ten lea rbx, [ rip + four ] ; eleven lea edx, [ rax - zero ] ; twelve mov dword ptr [ rbp - one ], edx ; thirteen test eax, eax ; fourteen je fifteen ;
#
#
# 0.48427346 1.0
# six mov eax, dword ptr [ rbp - one ] ; seven mov qword ptr [ rbp - four ], rbx ; eight lea rbx, [ rbp - two ] ; nine mov qword ptr [ rbp - three ], rbx ; ten lea rbx, [ rip + five ] ; eleven lea edx, [ rax - zero ] ; twelve mov dword ptr [ rbp - one ], edx ; thirteen test eax, eax ; fourteen je sixteen ; fifteen nop word ptr cs : [ rax + rax ] ;
#
#
# 0.7669145 0.0
# six mov r12d, seventeen ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.07908058 0.0
# six mov esp, seventeen ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.5687394 1.0
# six mov qword ptr [ rbp - four ], rbx ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.49401313 0.0
# six mov dword ptr [ rbp - four ], ebx ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.19260737 0.0
# five pop rbp ; six nop ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + four ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je fifteen ; fourteen nop word ptr cs : [ rax + rax ] ;
#
#
# 0.24311817 0.0
# six nop ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.024235213 1.0
# six lea rbx, [ rbp - two ] ; seven mov qword ptr [ rbp - three ], rbx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.435991 0.0
# six lea ebx, [ rbp - two ] ; seven mov qword ptr [ rbp - three ], rbx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.157823 0.0
# six pop rbp ; seven mov ah, two ; eight mov dword ptr [ rbp - three ], ebx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.49998295 0.0
# six mov ah, two ; seven mov dword ptr [ rbp - three ], ebx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.4176159 1.0
# five mov qword ptr [ rbp - two ], rbx ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.5451728 0.0
# five mov dword ptr [ rbp - two ], ebx ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.14824285 0.0
# five pop rbp ; six cwde ; seven lea rbx, [ rip + four ] ; eight lea edx, [ rax - zero ] ; nine mov dword ptr [ rbp - one ], edx ; ten test eax, eax ; eleven je fifteen ; twelve nop word ptr cs : [ rax + rax ] ; thirteen mov rdx, qword ptr [ rbp - three ] ; fourteen mov rsi, qword ptr [ rbp - two ] ;
#
#
# 0.1037533 0.0
# five cwde ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.13654989 1.0
# five lea rbx, [ rip + four ] ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.49964356 0.0
# five lea ebx, [ rip + four ] ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.34647256 0.0
# five sbb eax, four ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.008106006 0.0
# four add byte ptr [ rax ], al ; five lea edx, [ rax - zero ] ; six mov dword ptr [ rbp - one ], edx ; seven test eax, eax ; eight je fourteen ; nine nop word ptr cs : [ rax + rax ] ; ten mov rdx, qword ptr [ rbp - three ] ; eleven mov rsi, qword ptr [ rbp - two ] ; twelve mov rdi, rbx ; thirteen xor eax, eax ;
#
#
# 0.010326215 0.0
# three add byte ptr [ rbp + thirteen ], cl ; four mov esp, fourteen ; five cmpsb byte ptr [ rsi ], byte ptr [ rdi ] ; six add dword ptr [ rax ], eax ; seven add byte ptr [ rsi + zero ], ah ; eight nop dword ptr [ rax + rax ] ; nine mov rdx, qword ptr [ rbp - two ] ; ten mov rsi, qword ptr [ rbp - one ] ; eleven mov rdi, rbx ; twelve xor eax, eax ;
#
#
# 0.015026243 1.0
# five lea edx, [ rax - zero ] ; six mov dword ptr [ rbp - one ], edx ; seven test eax, eax ; eight je fifteen ; nine nop word ptr cs : [ rax + rax ] ; ten mov rdx, qword ptr [ rbp - four ] ; eleven mov rsi, qword ptr [ rbp - three ] ; twelve mov rdi, rbx ; thirteen xor eax, eax ; fourteen mov qword ptr [ rbp - two ], rsp ;
#
#
# 0.30854076 0.0
# four push rax ; five dec dword ptr [ rcx - fifteen ] ; six je fourteen ; seven nop word ptr cs : [ rax + rax ] ; eight mov rdx, qword ptr [ rbp - two ] ; nine mov rsi, qword ptr [ rbp - one ] ; ten mov rdi, rbx ; eleven xor eax, eax ; twelve mov qword ptr [ rbp - zero ], rsp ; thirteen call three ;
#
#
# 0.39278632 0.0
# five dec dword ptr [ rcx - sixteen ] ; six je fifteen ; seven nop word ptr cs : [ rax + rax ] ; eight mov rdx, qword ptr [ rbp - three ] ; nine mov rsi, qword ptr [ rbp - two ] ; ten mov rdi, rbx ; eleven xor eax, eax ; twelve mov qword ptr [ rbp - one ], rsp ; thirteen call four ; fourteen mov r12d, dword ptr [ rbp - zero ] ;
# v_metrices:  {'MSE': np.float64(0.1390176963689836), 'RMSE': np.float64(0.3728507695700568), 'MAE': np.float64(0.25371459511535555), 'R²': 0.3358939119038987, 'loss': np.float64(0.13901770114898682)}
# [2025-02-22 02:00:30,574] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/raisul/anaconda3/envs/pytorch/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /home/raisul/anaconda3/envs/pytorch/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# SAVING MODEL @  /home/raisul/probabilistic_disassembly/models/prototype_elf_asis
# saved
# Epoch 1: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:14<00:00,  1.61s/it, loss=0.145]
# Training metrices  {'MSE': np.float64(0.10921324207847315), 'RMSE': np.float64(0.3304742684059882), 'MAE': np.float64(0.2223714085223037), 'R²': 0.45578139288231945, 'loss': np.float64(0.10921324696391821)}
# Epoch 1: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  1.94it/s, loss=0.0974]
# 0.7346091 1.0
# three xor eax, eax ; four call one ; five add rbp, zero ; six cmp ebx, r12d ; seven jne two ; eight pop rbx ; nine pop rbp ; ten pop r12 ; eleven pop r13 ; twelve pop r14 ;
#
#
# 0.48467276 1.0
# three call one ; four add rbp, zero ; five cmp ebx, r12d ; six jne two ; seven pop rbx ; eight pop rbp ; nine pop r12 ; ten pop r13 ; eleven pop r14 ; twelve ret ;
#
#
# 0.3022599 1.0
# two add rbp, zero ; three cmp ebx, r12d ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# 0.3403106 0.0
# two add ebp, zero ; three cmp ebx, r12d ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# -0.0040004635 0.0
# two add al, zero ; three cmp ebx, esp ; four jne one ; five pop rbx ; six pop rbp ; seven pop r12 ; eight pop r13 ; nine pop r14 ; ten ret ;
#
#
# 0.73984903 1.0
# one cmp ebx, r12d ; two jne zero ; three pop rbx ; four pop rbp ; five pop r12 ; six pop r13 ; seven pop r14 ; eight ret ;
#
#
# 0.2810823 0.0
# one cmp ebx, esp ; two jne zero ; three pop rbx ; four pop rbp ; five pop r12 ; six pop r13 ; seven pop r14 ; eight ret ;
#
#
# 0.5521046 1.0
# one jne zero ; two pop rbx ; three pop rbp ; four pop r12 ; five pop r13 ; six pop r14 ; seven ret ;
#
#
# 0.8795798 1.0
# zero pop rbx ; one pop rbp ; two pop r12 ; three pop r13 ; four pop r14 ; five ret ;
#
#
# 0.8566104 1.0
# zero pop rbp ; one pop r12 ; two pop r13 ; three pop r14 ; four ret ;
#
#
# 0.7094611 1.0
# zero pop r12 ; one pop r13 ; two pop r14 ; three ret ;
#
#
# 0.8302382 0.0
# zero pop rsp ; one pop r13 ; two pop r14 ; three ret ;
#
#
# 0.79389906 1.0
# zero pop r13 ; one pop r14 ; two ret ;
#
#
# 0.6635309 0.0
# zero pop rbp ; one pop r14 ; two ret ;
#
#
# 0.73950016 1.0
# zero pop r14 ; one ret ;
#
#
# 0.67365026 0.0
# zero pop rsi ; one ret ;
#
#
# 0.88816965 1.0
# zero ret ;
#
#
# -0.0010289317 0.0
# zero nop dword ptr [ rax + rax ] ; one ret ;
#
#
# -0.0053867986 0.0
# zero add byte ptr [ rax ], r8b ; one ret ;
#
#
# -0.0014638482 0.0
# zero add byte ptr [ rax ], al ; one ret ;
#
#
# -0.005690639 0.0
# zero add bl, al ;
#
#
# 0.88816965 1.0
# zero ret ;
#
#
# 0.46881106 1.0
# two endbr64 ; three push rbp ; four lea rdi, [ rip + one ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ;
#
#
# 0.29195276 0.0
# two cli ; three push rbp ; four lea rdi, [ rip + one ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ;
#
#
# 0.79948014 1.0
# three push rbp ; four lea rdi, [ rip + two ] ; five mov rbp, rsp ; six push r15 ; seven push r14 ; eight lea rsi, [ rbp - zero ] ; nine push r13 ; ten push r12 ; eleven push rbx ; twelve lea rbx, [ rbp - one ] ;
#
#
# 0.8728058 1.0
# three lea rdi, [ rip + two ] ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# 0.13800766 0.0
# three lea edi, [ rip + two ] ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# 0.41200015 0.0
# three cmp eax, two ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ; twelve sub rsp, one ;
#
#
# -0.0017531402 0.0
# two cmp cl, byte ptr [ rdi ] ; three add byte ptr [ rax ], al ; four mov rbp, rsp ; five push r15 ; six push r14 ; seven lea rsi, [ rbp - zero ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - one ] ;
#
#
# -0.0015763817 0.0
# two sldt word ptr [ rax ] ; three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - zero ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - one ] ; eleven sub rsp, one ;
#
#
# -0.0018217498 0.0
# two add byte ptr [ rax ], al ; three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - zero ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - one ] ; eleven sub rsp, one ;
#
#
# -0.00032327697 0.0
# four add byte ptr [ rax - three ], cl ; five in eax, zero ; six push rdi ; seven push r14 ; eight lea rsi, [ rbp - one ] ; nine push r13 ; ten push r12 ; eleven push rbx ; twelve lea rbx, [ rbp - two ] ; thirteen sub rsp, two ;
#
#
# 0.5890819 1.0
# three mov rbp, rsp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - one ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - two ] ; eleven sub rsp, two ; twelve mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.2897056 0.0
# three mov ebp, esp ; four push r15 ; five push r14 ; six lea rsi, [ rbp - one ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - two ] ; eleven sub rsp, two ; twelve mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.059227847 0.0
# four in eax, one ; five push rdi ; six push r14 ; seven lea rsi, [ rbp - two ] ; eight push r13 ; nine push r12 ; ten push rbx ; eleven lea rbx, [ rbp - three ] ; twelve sub rsp, three ; thirteen mov rax, qword ptr fs : [ zero ] ;
#
#
# 0.45673293 1.0
# four push r15 ; five push r14 ; six lea rsi, [ rbp - two ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - three ] ; eleven sub rsp, three ; twelve mov rax, qword ptr fs : [ zero ] ; thirteen mov qword ptr [ rbp - one ], rax ;
#
#
# 0.41642883 0.0
# four push rdi ; five push r14 ; six lea rsi, [ rbp - two ] ; seven push r13 ; eight push r12 ; nine push rbx ; ten lea rbx, [ rbp - three ] ; eleven sub rsp, three ; twelve mov rax, qword ptr fs : [ zero ] ; thirteen mov qword ptr [ rbp - one ], rax ;
#
#
# 0.39348373 1.0
# four push r14 ; five lea rsi, [ rbp - two ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ zero ] ; twelve mov qword ptr [ rbp - one ], rax ; thirteen xor eax, eax ;
#
#
# 0.11291963 0.0
# four push rsi ; five lea rsi, [ rbp - two ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ zero ] ; twelve mov qword ptr [ rbp - one ], rax ; thirteen xor eax, eax ;
#
#
# 0.019665547 1.0
# five lea rsi, [ rbp - three ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - four ] ; ten sub rsp, four ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.0046813637 0.0
# five lea esi, [ rbp - three ] ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - four ] ; ten sub rsp, four ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.54383326 0.0
# five jne four ; six push r13 ; seven push r12 ; eight push rbx ; nine lea rbx, [ rbp - three ] ; ten sub rsp, three ; eleven mov rax, qword ptr fs : [ one ] ; twelve mov qword ptr [ rbp - two ], rax ; thirteen xor eax, eax ; fourteen mov dword ptr [ rip + fifteen ], zero ;
#
#
# 0.030979771 0.0
# six mov esp, seventeen ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.3662807 1.0
# five push r13 ; six push r12 ; seven push rbx ; eight lea rbx, [ rbp - three ] ; nine sub rsp, three ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + fifteen ], zero ; fourteen call four ;
#
#
# 0.56278884 0.0
# five push rbp ; six push r12 ; seven push rbx ; eight lea rbx, [ rbp - three ] ; nine sub rsp, three ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + fifteen ], zero ; fourteen call four ;
#
#
# 0.42432085 1.0
# six push r12 ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.627167 0.0
# six push rsp ; seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + sixteen ], zero ; fourteen call five ; fifteen mov eax, dword ptr [ rbp - three ] ;
#
#
# 0.16931893 1.0
# seven push rbx ; eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + seventeen ], zero ; fourteen call six ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.062647514 1.0
# eight lea rbx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + eighteen ], zero ; fourteen call seven ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - six ], rbx ; seventeen lea rbx, [ rbp - five ] ;
#
#
# 0.42730534 0.0
# eight lea ebx, [ rbp - four ] ; nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + eighteen ], zero ; fourteen call seven ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - six ], rbx ; seventeen lea rbx, [ rbp - five ] ;
#
#
# 0.82617086 0.0
# seven pop rbp ; eight mov eax, eighteen ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + seventeen ], zero ; thirteen call six ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - five ], rbx ; sixteen lea rbx, [ rbp - four ] ;
#
#
# 0.06994867 0.0
# eight mov eax, nineteen ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + eighteen ], zero ; thirteen call seven ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.32763615 1.0
# nine sub rsp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + nineteen ], zero ; fourteen call eight ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - seven ], rbx ; seventeen lea rbx, [ rbp - five ] ; eighteen mov qword ptr [ rbp - six ], rbx ;
#
#
# 0.009638039 0.0
# nine sub esp, four ; ten mov rax, qword ptr fs : [ one ] ; eleven mov qword ptr [ rbp - two ], rax ; twelve xor eax, eax ; thirteen mov dword ptr [ rip + nineteen ], zero ; fourteen call eight ; fifteen mov eax, dword ptr [ rbp - three ] ; sixteen mov qword ptr [ rbp - seven ], rbx ; seventeen lea rbx, [ rbp - five ] ; eighteen mov qword ptr [ rbp - six ], rbx ;
#
#
# -0.0045358194 0.0
# eight in al, dx ; nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + eighteen ], zero ; thirteen call seven ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ;
#
#
# 0.8323043 0.0
# nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.8323043 1.0
# nine mov rax, qword ptr fs : [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.32744536 0.0
# nine mov rax, qword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.008474838 0.0
# nine mov eax, dword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# -0.002502461 0.0
# seven add al, one ; eight sub byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + seventeen ], zero ; thirteen call six ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - five ], rbx ; sixteen lea rbx, [ rbp - four ] ;
#
#
# 0.063145675 0.0
# nine and eax, one ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# -0.0027877232 0.0
# seven sub byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + seventeen ], zero ; twelve call six ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ;
#
#
# -0.0019569164 0.0
# six add byte ptr [ rax ], al ; seven add byte ptr [ rax - four ], cl ; eight enter - seventeen, - zero ; nine add eax, sixteen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call five ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rbp - two ] ;
#
#
# -0.0005289577 0.0
# eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + eighteen ], zero ; twelve call seven ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ; seventeen lea rbx, [ rip + six ] ;
#
#
# -0.0018103113 0.0
# seven add byte ptr [ rax - five ], cl ; eight enter - eighteen, - zero ; nine add eax, seventeen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call six ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rbp - two ] ; sixteen mov qword ptr [ rbp - three ], rbx ;
#
#
# 0.23017721 1.0
# nine mov qword ptr [ rbp - two ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# 0.48413718 0.0
# nine mov dword ptr [ rbp - two ], eax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# -0.0031423047 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# -0.0031423047 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# 0.31310174 1.0
# eight xor eax, eax ; nine mov dword ptr [ rip + eighteen ], zero ; ten call seven ; eleven mov eax, dword ptr [ rbp - two ] ; twelve mov qword ptr [ rbp - five ], rbx ; thirteen lea rbx, [ rbp - three ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rip + six ] ; sixteen lea edx, [ rax - one ] ; seventeen mov dword ptr [ rbp - two ], edx ;
#
#
# 0.38417253 1.0
# eight mov dword ptr [ rip + eighteen ], zero ; nine call seven ; ten mov eax, dword ptr [ rbp - two ] ; eleven mov qword ptr [ rbp - five ], rbx ; twelve lea rbx, [ rbp - three ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rip + six ] ; fifteen lea edx, [ rax - one ] ; sixteen mov dword ptr [ rbp - two ], edx ; seventeen test eax, eax ;
#
#
# -0.0016131671 0.0
# seven add eax, seventeen ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# -0.0024767518 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# -0.0023911037 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine call six ; ten mov eax, dword ptr [ rbp - one ] ; eleven mov qword ptr [ rbp - four ], rbx ; twelve lea rbx, [ rbp - two ] ; thirteen mov qword ptr [ rbp - three ], rbx ; fourteen lea rbx, [ rip + five ] ; fifteen lea edx, [ rax - zero ] ; sixteen mov dword ptr [ rbp - one ], edx ;
#
#
# -0.0011454113 0.0
# ...
#
#
# 0.35408372 0.0
# nine mov rax, qword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.009678988 0.0
# nine mov eax, dword ptr [ one ] ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.003376483 0.0
# seven add al, one ; eight sub byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + seventeen ], zero ; thirteen call six ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - five ], rbx ; sixteen lea rbx, [ rbp - four ] ;
#
#
# 0.028651934 0.0
# nine and eax, one ; ten mov qword ptr [ rbp - two ], rax ; eleven xor eax, eax ; twelve mov dword ptr [ rip + nineteen ], zero ; thirteen call eight ; fourteen mov eax, dword ptr [ rbp - three ] ; fifteen mov qword ptr [ rbp - six ], rbx ; sixteen lea rbx, [ rbp - four ] ; seventeen mov qword ptr [ rbp - five ], rbx ; eighteen lea rbx, [ rip + seven ] ;
#
#
# 0.0025458075 0.0
# seven sub byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + seventeen ], zero ; twelve call six ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ;
#
#
# 0.004014152 0.0
# six add byte ptr [ rax ], al ; seven add byte ptr [ rax - four ], cl ; eight enter - seventeen, - zero ; nine add eax, sixteen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call five ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rbp - two ] ;
#
#
# 0.0056700753 0.0
# eight add byte ptr [ rax ], al ; nine mov qword ptr [ rbp - one ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + eighteen ], zero ; twelve call seven ; thirteen mov eax, dword ptr [ rbp - two ] ; fourteen mov qword ptr [ rbp - five ], rbx ; fifteen lea rbx, [ rbp - three ] ; sixteen mov qword ptr [ rbp - four ], rbx ; seventeen lea rbx, [ rip + six ] ;
#
#
# 0.004189538 0.0
# seven add byte ptr [ rax - five ], cl ; eight enter - eighteen, - zero ; nine add eax, seventeen ; ten add byte ptr [ rax ], al ; eleven add byte ptr [ rax ], al ; twelve call six ; thirteen mov eax, dword ptr [ rbp - one ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rbp - two ] ; sixteen mov qword ptr [ rbp - three ], rbx ;
#
#
# 0.2404638 1.0
# nine mov qword ptr [ rbp - two ], rax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# 0.032467417 0.0
# nine mov dword ptr [ rbp - two ], eax ; ten xor eax, eax ; eleven mov dword ptr [ rip + nineteen ], zero ; twelve call eight ; thirteen mov eax, dword ptr [ rbp - three ] ; fourteen mov qword ptr [ rbp - six ], rbx ; fifteen lea rbx, [ rbp - four ] ; sixteen mov qword ptr [ rbp - five ], rbx ; seventeen lea rbx, [ rip + seven ] ; eighteen lea edx, [ rax - one ] ;
#
#
# 0.0032303808 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# 0.0032303808 0.0
# seven enter - eighteen, - zero ; eight add eax, seventeen ; nine add byte ptr [ rax ], al ; ten add byte ptr [ rax ], al ; eleven call six ; twelve mov eax, dword ptr [ rbp - one ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rbp - two ] ; fifteen mov qword ptr [ rbp - three ], rbx ; sixteen lea rbx, [ rip + five ] ;
#
#
# 0.16796875 1.0
# eight xor eax, eax ; nine mov dword ptr [ rip + eighteen ], zero ; ten call seven ; eleven mov eax, dword ptr [ rbp - two ] ; twelve mov qword ptr [ rbp - five ], rbx ; thirteen lea rbx, [ rbp - three ] ; fourteen mov qword ptr [ rbp - four ], rbx ; fifteen lea rbx, [ rip + six ] ; sixteen lea edx, [ rax - one ] ; seventeen mov dword ptr [ rbp - two ], edx ;
#
#
# 0.021294972 1.0
# eight mov dword ptr [ rip + eighteen ], zero ; nine call seven ; ten mov eax, dword ptr [ rbp - two ] ; eleven mov qword ptr [ rbp - five ], rbx ; twelve lea rbx, [ rbp - three ] ; thirteen mov qword ptr [ rbp - four ], rbx ; fourteen lea rbx, [ rip + six ] ; fifteen lea edx, [ rax - one ] ; sixteen mov dword ptr [ rbp - two ], edx ; seventeen test eax, eax ;
#
#
# 0.004336847 0.0
# seven add eax, seventeen ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# 0.003279888 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine add byte ptr [ rax ], al ; ten call six ; eleven mov eax, dword ptr [ rbp - one ] ; twelve mov qword ptr [ rbp - four ], rbx ; thirteen lea rbx, [ rbp - two ] ; fourteen mov qword ptr [ rbp - three ], rbx ; fifteen lea rbx, [ rip + five ] ; sixteen lea edx, [ rax - zero ] ;
#
#
# 0.0031382535 0.0
# seven add byte ptr [ rax ], al ; eight add byte ptr [ rax ], al ; nine call six ; ten mov eax, dword ptr [ rbp - one ] ; eleven mov qword ptr [ rbp - four ], rbx ; twelve lea rbx, [ rbp - two ] ; thirteen mov qword ptr [ rbp - three ], rbx ; fourteen lea rbx, [ rip + five ] ; fifteen lea edx, [ rax - zero ] ; sixteen mov dword ptr [ rbp - one ], edx ;
#
#
# 0.0050555705 0.0
# seven add byte ptr [ rax ], al ; eight call six ; nine mov eax, dword ptr [ rbp - one ] ; ten mov qword ptr [ rbp - four ], rbx ; eleven lea rbx, [ rbp - two ] ; twelve mov qword ptr [ rbp - three ], rbx ; thirteen lea rbx, [ rip + five ] ; fourteen lea edx, [ rax - zero ] ; fifteen mov dword ptr [ rbp - one ], edx ; sixteen test eax, eax ;
#
#
# 0.5627804 1.0
# seven call six ; eight mov eax, dword ptr [ rbp - one ] ; nine mov qword ptr [ rbp - four ], rbx ; ten lea rbx, [ rbp - two ] ; eleven mov qword ptr [ rbp - three ], rbx ; twelve lea rbx, [ rip + five ] ; thirteen lea edx, [ rax - zero ] ; fourteen mov dword ptr [ rbp - one ], edx ; fifteen test eax, eax ; sixteen je seventeen ;
#
#
# 0.0069559626 0.0
# five dec dword ptr [ rbx - sixteen ] ; six pop rbp ; seven nop ; eight lea rbx, [ rbp - two ] ; nine mov qword ptr [ rbp - three ], rbx ; ten lea rbx, [ rip + four ] ; eleven lea edx, [ rax - zero ] ; twelve mov dword ptr [ rbp - one ], edx ; thirteen test eax, eax ; fourteen je fifteen ;
#
#
# 0.025084173 1.0
# six mov eax, dword ptr [ rbp - one ] ; seven mov qword ptr [ rbp - four ], rbx ; eight lea rbx, [ rbp - two ] ; nine mov qword ptr [ rbp - three ], rbx ; ten lea rbx, [ rip + five ] ; eleven lea edx, [ rax - zero ] ; twelve mov dword ptr [ rbp - one ], edx ; thirteen test eax, eax ; fourteen je sixteen ; fifteen nop word ptr cs : [ rax + rax ] ;
#
#
# 0.93628824 0.0
# six mov r12d, seventeen ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.013298712 0.0
# six mov esp, seventeen ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.9283235 1.0
# six mov qword ptr [ rbp - four ], rbx ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.015905865 0.0
# six mov dword ptr [ rbp - four ], ebx ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.25480407 0.0
# five pop rbp ; six nop ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + four ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je fifteen ; fourteen nop word ptr cs : [ rax + rax ] ;
#
#
# 0.04935716 0.0
# six nop ; seven lea rbx, [ rbp - two ] ; eight mov qword ptr [ rbp - three ], rbx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.014571194 1.0
# six lea rbx, [ rbp - two ] ; seven mov qword ptr [ rbp - three ], rbx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.03090723 0.0
# six lea ebx, [ rbp - two ] ; seven mov qword ptr [ rbp - three ], rbx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.039653916 0.0
# six pop rbp ; seven mov ah, two ; eight mov dword ptr [ rbp - three ], ebx ; nine lea rbx, [ rip + five ] ; ten lea edx, [ rax - zero ] ; eleven mov dword ptr [ rbp - one ], edx ; twelve test eax, eax ; thirteen je sixteen ; fourteen nop word ptr cs : [ rax + rax ] ; fifteen mov rdx, qword ptr [ rbp - four ] ;
#
#
# 0.12147433 0.0
# six mov ah, two ; seven mov dword ptr [ rbp - three ], ebx ; eight lea rbx, [ rip + five ] ; nine lea edx, [ rax - zero ] ; ten mov dword ptr [ rbp - one ], edx ; eleven test eax, eax ; twelve je sixteen ; thirteen nop word ptr cs : [ rax + rax ] ; fourteen mov rdx, qword ptr [ rbp - four ] ; fifteen mov rsi, qword ptr [ rbp - three ] ;
#
#
# 0.48385507 1.0
# five mov qword ptr [ rbp - two ], rbx ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.02120775 0.0
# five mov dword ptr [ rbp - two ], ebx ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.24669516 0.0
# five pop rbp ; six cwde ; seven lea rbx, [ rip + four ] ; eight lea edx, [ rax - zero ] ; nine mov dword ptr [ rbp - one ], edx ; ten test eax, eax ; eleven je fifteen ; twelve nop word ptr cs : [ rax + rax ] ; thirteen mov rdx, qword ptr [ rbp - three ] ; fourteen mov rsi, qword ptr [ rbp - two ] ;
#
#
# 0.013813669 0.0
# five cwde ; six lea rbx, [ rip + four ] ; seven lea edx, [ rax - zero ] ; eight mov dword ptr [ rbp - one ], edx ; nine test eax, eax ; ten je fifteen ; eleven nop word ptr cs : [ rax + rax ] ; twelve mov rdx, qword ptr [ rbp - three ] ; thirteen mov rsi, qword ptr [ rbp - two ] ; fourteen mov rdi, rbx ;
#
#
# 0.04815676 1.0
# five lea rbx, [ rip + four ] ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.049194224 0.0
# five lea ebx, [ rip + four ] ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.017388027 0.0
# five sbb eax, four ; six lea edx, [ rax - zero ] ; seven mov dword ptr [ rbp - one ], edx ; eight test eax, eax ; nine je fifteen ; ten nop word ptr cs : [ rax + rax ] ; eleven mov rdx, qword ptr [ rbp - three ] ; twelve mov rsi, qword ptr [ rbp - two ] ; thirteen mov rdi, rbx ; fourteen xor eax, eax ;
#
#
# 0.0060514226 0.0
# four add byte ptr [ rax ], al ; five lea edx, [ rax - zero ] ; six mov dword ptr [ rbp - one ], edx ; seven test eax, eax ; eight je fourteen ; nine nop word ptr cs : [ rax + rax ] ; ten mov rdx, qword ptr [ rbp - three ] ; eleven mov rsi, qword ptr [ rbp - two ] ; twelve mov rdi, rbx ; thirteen xor eax, eax ;
#
#
# 0.0042525157 0.0
# three add byte ptr [ rbp + thirteen ], cl ; four mov esp, fourteen ; five cmpsb byte ptr [ rsi ], byte ptr [ rdi ] ; six add dword ptr [ rax ], eax ; seven add byte ptr [ rsi + zero ], ah ; eight nop dword ptr [ rax + rax ] ; nine mov rdx, qword ptr [ rbp - two ] ; ten mov rsi, qword ptr [ rbp - one ] ; eleven mov rdi, rbx ; twelve xor eax, eax ;
#
#
# 0.011472002 1.0
# five lea edx, [ rax - zero ] ; six mov dword ptr [ rbp - one ], edx ; seven test eax, eax ; eight je fifteen ; nine nop word ptr cs : [ rax + rax ] ; ten mov rdx, qword ptr [ rbp - four ] ; eleven mov rsi, qword ptr [ rbp - three ] ; twelve mov rdi, rbx ; thirteen xor eax, eax ; fourteen mov qword ptr [ rbp - two ], rsp ;
#
#
# 0.91564476 0.0
# four push rax ; five dec dword ptr [ rcx - fifteen ] ; six je fourteen ; seven nop word ptr cs : [ rax + rax ] ; eight mov rdx, qword ptr [ rbp - two ] ; nine mov rsi, qword ptr [ rbp - one ] ; ten mov rdi, rbx ; eleven xor eax, eax ; twelve mov qword ptr [ rbp - zero ], rsp ; thirteen call three ;
#
#
# 0.014486826 0.0
# five dec dword ptr [ rcx - sixteen ] ; six je fifteen ; seven nop word ptr cs : [ rax + rax ] ; eight mov rdx, qword ptr [ rbp - three ] ; nine mov rsi, qword ptr [ rbp - two ] ; ten mov rdi, rbx ; eleven xor eax, eax ; twelve mov qword ptr [ rbp - one ], rsp ; thirteen call four ; fourteen mov r12d, dword ptr [ rbp - zero ] ;
# v_metrices:  {'MSE': np.float64(0.11350101375857893), 'RMSE': np.float64(0.3368991151050696), 'MAE': np.float64(0.17718274843956655), 'R²': 0.4577905100507117, 'loss': np.float64(0.11350102350115776)}
# SAVING MODEL @  /home/raisul/probabilistic_disassembly/models/prototype_elf_asis
# saved
# Epoch 4:  67%|████████████████████████████████████████████████████████████████▋                                | 6/9 [00:11<00:05,  1.87s/it, loss=0.07]

# %%
#jupyter nbconvert --to script data_pipe.ipynb
