# %%
from accelerate import Accelerator
import torch
import multiprocessing as mp
accelerator = Accelerator()
accelerator.state.num_processes = 3  # For 3 GPUs
device = accelerator.device
# device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
import os,sys, json,re, pickle ,threading
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd
from capstone import Cs, CS_ARCH_X86, CS_MODE_64

# %%
BIN_FILE_TYPE = 'PE' #or ELF
bin_path = '/home/raisul/DATA/x86_pe_msvc_O2_static/' #/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")]#[:2]
ground_truth_path ='/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/'#'/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'prototype_pe_small'

MAX_TOKEN_SIZE = 120
MAX_SEQUENCE_LENGTH = 10
VOCAB_SIZE = 500
BATCH_SIZE = 15000
VALIDATION_DISPLAY_SIZE = 100000
MAX_FILE_TO_USE = 30000
MODEL_NAME= "microsoft/MiniLM-L12-H384-uncased"# #bert-base-uncased
pkl_data_save_path = MODEL_SAVE_PATH+'training_data_pe'+str(MAX_FILE_TO_USE)+'.ignore.pkl'

# %%
def make_train_test_split(bin_path):
    bin_files = [ f for f in os.listdir(bin_path) ][0:MAX_FILE_TO_USE] #if f.endswith(".exe")
    temp_dict = {key: sum(ord(c) for c in key) % 10 for key in bin_files}
    # temp_dict = dict(sorted(temp_dict.items(), key=lambda item: item[1]))
    dict_train = {k: v for k, v in temp_dict.items() if 0 <= v <= 7}
    dict_test = {k: v for k, v in temp_dict.items() if 8 <= v <= 9}
    print(len(list(dict_train.items())) ,len(list(dict_test.items())) )
    return list(dict_train.keys()) , list(dict_test.keys())
train_bins , test_bins = make_train_test_split(bin_path)

train_bins = train_bins
test_bins  = test_bins
# Out:
# 23993 6007
# /tmp/ipykernel_189486/1340937240.py:3: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   temp_dict = {key: sum(ord(c) for c in key) % 10 for key in bin_files}

# %%
def replace_num_with_word(input_string , replace_dict):
    def num_to_word(match):
        number = int( match.group(0))
        return num2words(replace_dict[number]).replace(' ','').replace('-',"")
    result_string = re.sub(r'\b\d+\b', num_to_word, input_string)
    return result_string



def replace_hex_with_decimal(input_string):
    # Regular expression to find hexadecimal numbers prefixed with "0x" or "0X"
    hex_pattern = r'0[xX][0-9a-fA-F]+'
    
    # Function to convert each found hex number to decimal
    def hex_to_decimal(match):
        hex_value = match.group(0)  # Extract the matched hex number
        decimal_value = str(int(hex_value, 16))  # Convert hex to decimal
        return decimal_value
    # Substitute all hex numbers in the string with their decimal equivalents
    result_string = re.sub(hex_pattern, hex_to_decimal, input_string)
    return result_string

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
# with open(pkl_data_save_path , 'wb') as f:
#     pickle.dump([train_sequences,train_labels,validation_sequences, validation_labels], f)
with open(pkl_data_save_path, "rb") as f:
    train_sequences,train_labels,validation_sequences, validation_labels = pickle.load(f)

# %%
for j in range(100):
    if True:#'int3' in SEQUENCES[j]: #LABELS[j] :
        print(train_labels[j] , ' > ' , train_sequences[j] ,'\n' )
# Out:
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  two jbe ten ; three cmp edx, eleven ; four je ten ; five mov rbx, qword ptr [rsp + one] ; six xor eax, eax ; seven add rsp, zero ; eight pop rdi ; nine ret  ;
#
# 1.0  >  one sub rax, r8 ; two cmp rdx, rax ; three ja eight ; four mov rax, qword ptr [rip + ten] ; five test rax, rax ; six je eight ; seven call rax ; eight add rsp, zero ; nine ret  ;
#
# 1.0  >  seven mov dword ptr [rbp - five], ebx ; eight mov dword ptr [rbp - four], ecx ; nine mov dword ptr [rbp - two], edx ; ten mov rax, qword ptr [rip + twenty] ; eleven mov ebx, three ; twelve and rax, twentyone ; thirteen mov dword ptr [rip + nineteen], zero ; fourteen mov dword ptr [rip + eighteen], one ; fifteen mov qword ptr [rip + seventeen], rax ; sixteen bt edi, six ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  three call thirteen ; four mov rax, qword ptr [rsp + two] ; five mov qword ptr [rip + nineteen], rax ; six lea rax, [rsp + two] ; seven add rax, one ; eight mov qword ptr [rip + seventeen], rax ; nine mov rax, qword ptr [rip + eighteen] ; ten mov qword ptr [rip + sixteen], rax ; eleven mov dword ptr [rip + fifteen], twenty ; twelve mov dword ptr [rip + fourteen], zero ;
#
# 1.0  >  two cmovne rcx, rdx ; three call one ; four mov rcx, qword ptr [rip + fifteen] ; five test rcx, rcx ; six je twelve ; seven mov rax, qword ptr [rcx + zero] ; eight mov qword ptr [rip + fourteen], rax ; nine call qword ptr [rip + sixteen] ; ten mov rcx, qword ptr [rip + thirteen] ; eleven test rcx, rcx ;
#
# 1.0  >  four jne three ; five mov ecx, one ; six call qword ptr [rip + fifteen] ; seven mov byte ptr [rax], two ; eight mov qword ptr [rax + zero], rsi ; nine mov qword ptr [rdi + zero], rax ; ten mov rdi, rbx ; eleven mov rax, qword ptr [rbx + zero] ; twelve test rax, rax ; thirteen je fourteen ;
#
# 1.0  >  two call qword ptr [rip + seven] ; three mov rbx, qword ptr [rsp + one] ; four add rsp, zero ; five pop rdi ; six ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  three lea rdx, [rip + eight] ; four mov r8, qword ptr [rsp + one] ; five mov rax, qword ptr [r8 + rax*zero] ; six mov qword ptr [rdx + rcx*zero], rax ; seven jmp two ;
#
# 1.0  >  three call two ; four mov al, zero ; five add rsp, one ; six pop rbx ; seven ret  ;
#
# 1.0  >  three sub rsp, zero ; four mov rbx, rcx ; five call qword ptr [rip + fifteen] ; six mov rdi, qword ptr [rbx + two] ; seven lea rdx, [rsp + one] ; eight mov rcx, rdi ; nine xor r8d, r8d ; ten call qword ptr [rip + fourteen] ; eleven test rax, rax ; twelve je thirteen ;
#
# 1.0  >  four test eax, eax ; five je eight ; six mov ecx, zero ; seven int two ; eight lea rcx, [rip + fifteen] ; nine call fourteen ; ten mov rax, qword ptr [rsp + three] ; eleven mov qword ptr [rip + sixteen], rax ; twelve lea rax, [rsp + three] ; thirteen add rax, one ;
#
# 1.0  >  one test rax, rax ; two je four ; three call rax ; four add rsp, zero ; five ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine nop word ptr [rax + rax] ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  three mov rax, qword ptr [rbx] ; four test rax, rax ; five je seven ; six call qword ptr [rip + thirteen] ; seven add rbx, zero ; eight cmp rbx, rdi ; nine jb three ; ten mov rbx, qword ptr [rsp + two] ; eleven add rsp, one ; twelve pop rdi ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  three sub rsp, zero ; four call two ; five call one ; six mov ecx, eax ; seven add rsp, zero ; eight jmp nine ;
#
# 1.0  >  zero ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  two rol byte ptr [rcx + seven], zero ; three mov dl, one ; four add byte ptr [rax], al ; five jmp qword ptr [rip + six] ;
#
# 1.0  >  five cmp word ptr [rcx + two], ax ; six jne twelve ; seven cmp dword ptr [rcx + three], one ; eight jbe twelve ; nine cmp dword ptr [rcx + four], zero ; ten setne al ; eleven jmp thirteen ;
#
# 1.0  >  one mov al, zero ; two ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  four push rax ; five add byte ptr [rbp + one], dh ; six mov dword ptr [rsp + three], zero ; seven cmp dword ptr [rsp + three], two ; eight jbe twelve ; nine mov eax, dword ptr [rsp + three] ; ten dec eax ; eleven mov dword ptr [rsp + three], eax ; twelve mov eax, dword ptr [rsp + three] ; thirteen inc eax ;
#
# 1.0  >  zero ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  four add byte ptr [rax], al ; five cmp r14d, eax ; six jl fourteen ; seven xor ecx, ecx ; eight cpuid  ; nine mov r11d, ebx ; ten mov dword ptr [rbp - three], eax ; eleven mov dword ptr [rbp - two], ebx ; twelve mov dword ptr [rbp - one], ecx ; thirteen mov dword ptr [rbp - zero], edx ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  five sbb byte ptr [rcx - seventeen], cl ; six and al, zero ; seven sub rsp, three ; eight mov ecx, one ; nine call qword ptr [rip + sixteen] ; ten test eax, eax ; eleven je fifteen ; twelve mov eax, dword ptr [rsp + four] ; thirteen mov ecx, eax ; fourteen int two ;
#
# 0.0  >  three int3  ; four int3  ; five int3  ; six push rbx ; seven sub rsp, one ; eight mov ecx, zero ; nine call thirteen ; ten call two ; eleven mov ecx, eax ; twelve call fourteen ;
#
# 1.0  >  three add rcx, rdx ; four cmp dword ptr [rcx], fourteen ; five jne thirteen ; six mov eax, two ; seven cmp word ptr [rcx + one], ax ; eight jne thirteen ; nine sub r8, rdx ; ten movzx edx, word ptr [rcx + zero] ; eleven add rdx, one ; twelve add rdx, rcx ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  one lea rdx, [rip + eleven] ; two sub rax, r8 ; three sub rdx, r8 ; four cmp rax, rdx ; five ja ten ; six mov rax, qword ptr [rip + twelve] ; seven test rax, rax ; eight je ten ; nine call qword ptr [rip + thirteen] ; ten add rsp, zero ;
#
# 1.0  >  three call two ; four mov edi, eax ; five mov dword ptr [rbx], eax ; six movsxd r14, dword ptr [rsi] ; seven lea r15, [rsp + one] ; eight mov edx, dword ptr [r15 + r14*zero] ; nine lea r15, [r15 + r14*zero] ; ten cmp edx, r14d ; eleven jne thirteen ; twelve mov ebx, r14d ;
#
# 0.0  >  five cmp byte ptr [rsp + one], zero ; six jne eight ; seven call fourteen ; eight mov eax, ebx ; nine mov rbx, qword ptr [rsp + three] ; ten mov rsi, qword ptr [rsp + four] ; eleven add rsp, two ; twelve pop rdi ; thirteen ret  ;
#
# 1.0  >  two jne four ; three mov qword ptr [rax + zero], r8 ; four mov qword ptr [r8 + zero], rdx ; five mov rax, rcx ; six mov qword ptr [rdx + one], r8 ; seven ret  ;
#
# 1.0  >  one cmp eax, thirteen ; two je eleven ; three cmp eax, fourteen ; four je eleven ; five cmp eax, fifteen ; six je eleven ; seven add eax, sixteen ; eight cmp eax, zero ; nine ja twelve ; ten movabs rcx, seventeen ;
#
# 1.0  >  five mov dword ptr [rip + seventeen], eighteen ; six mov dword ptr [rip + sixteen], one ; seven cmp dword ptr [rsp + three], zero ; eight jbe twelve ; nine cmp qword ptr [rsp + four], zero ; ten jne twelve ; eleven mov dword ptr [rsp + three], zero ; twelve cmp dword ptr [rsp + three], two ; thirteen jbe fifteen ; fourteen mov eax, dword ptr [rsp + three] ;
#
# 0.0  >  six or byte ptr [rax - four], cl ; seven je sixteen ; eight adc byte ptr [rdi + three], dl ; nine sub esp, two ; ten mov ecx, zero ; eleven call five ; twelve test al, al ; thirteen je seventeen ; fourteen xor sil, sil ; fifteen mov byte ptr [rsp + one], sil ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  one sub rcx, rax ; two xor eax, eax ; three add rcx, -zero ; four cmp rcx, r8 ; five seta al ; six ret  ;
#
# 0.0  >  one adc al, zero ; two add cl, ch ; three and dword ptr [rdx], ecx ; four add byte ptr [rax], al ; five jmp six ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  one ret zero ;
#
# 0.0  >  one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine mov qword ptr [rsp + zero], rbx ; ten push rbp ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  zero je eleven ; one test ebx, ebx ; two jne eleven ; three lea rcx, [rip + thirteen] ; four call twelve ; five test eax, eax ; six jne ten ; seven lea rcx, [rip + fourteen] ; eight call twelve ; nine test eax, eax ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  zero ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  three mov eax, fifteen ; four cmp word ptr [rcx], ax ; five jne thirteen ; six movsxd rax, dword ptr [rcx + one] ; seven add rax, rcx ; eight cmp dword ptr [rax], fourteen ; nine jne thirteen ; ten mov ecx, two ; eleven cmp word ptr [rax + zero], cx ; twelve sete al ;
#
# 1.0  >  three xor r8d, r8d ; four lea edx, [r8 + one] ; five xor ecx, ecx ; six mov rax, qword ptr [rbx] ; seven call qword ptr [rip + fourteen] ; eight call two ; nine mov rbx, rax ; ten cmp qword ptr [rax], zero ; eleven je thirteen ; twelve mov rcx, rax ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  eight mov eax, dword ptr [rip + two] ; nine mov dword ptr [rip + zero], eax ; ten mov eax, dword ptr [rip + four] ; eleven mov dword ptr [rip + three], eax ; twelve lea rax, [rip + six] ; thirteen mov qword ptr [rip + seven], rax ; fourteen mov eax, dword ptr [rip + one] ; fifteen mov dword ptr [rip + five], eax ; sixteen mov eax, eighteen ; seventeen imul r8d ;
#
# 1.0  >  five call qword ptr [rip + seventeen] ; six mov rbx, qword ptr [rbp + two] ; seven lea rdx, [rbp + three] ; eight mov rcx, rbx ; nine xor r8d, r8d ; ten call qword ptr [rip + sixteen] ; eleven test rax, rax ; twelve je fifteen ; thirteen and qword ptr [rsp + one], zero ; fourteen lea rcx, [rbp + four] ;
#
# 1.0  >  two mov ecx, one ; three cmp word ptr [rax + zero], cx ; four sete al ; five ret  ;
#
# 1.0  >  zero je three ; one xor al, al ; two jmp four ;
#
# 1.0  >  zero jmp one ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  five sub rsp, one ; six lea rcx, [rip + seventeen] ; seven call four ; eight lea rdx, [rsp + two] ; nine lea rcx, [rip + sixteen] ; ten call three ; eleven mov edi, dword ptr [rsp + two] ; twelve lea rcx, [rip + fifteen] ; thirteen and edi, zero ; fourteen call four ;
#
# 1.0  >  three jb eight ; four mov eax, dword ptr [r9 + zero] ; five add eax, ecx ; six cmp rdx, rax ; seven jb thirteen ; eight add r9, one ; nine cmp r9, r8 ; ten jne two ; eleven xor eax, eax ; twelve ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  two int3  ; three mov qword ptr [rsp + zero], rbx ; four mov qword ptr [rsp + one], rsi ; five push rbp ; six push rdi ; seven push r14 ; eight mov rbp, rsp ; nine sub rsp, zero ; ten xor eax, eax ; eleven xor ecx, ecx ;
#
# 0.0  >  one adc eax, seven ; two add rsp, zero ; three pop rdi ; four pop rsi ; five pop rbx ; six ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  zero ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ; ten sub rsp, zero ; eleven call two ; twelve call one ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  one xor eax, eax ; two add rsp, zero ; three pop rdi ; four ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  zero ret  ;
#
# 1.0  >  one mov rdx, rbx ; two lea rcx, [rip + twelve] ; three call eleven ; four xor edx, edx ; five test eax, eax ; six cmove rdx, rbx ; seven mov rax, rdx ; eight add rsp, zero ; nine pop rbx ; ten ret  ;
#
# 1.0  >  zero ret  ;
#
# 1.0  >  three mov dword ptr [rip + eighteen], zero ; four mov dword ptr [rip + seventeen], eax ; five test r9b, two ; six je thirteen ; seven or eax, two ; eight mov dword ptr [rip + sixteen], one ; nine mov dword ptr [rip + fifteen], eax ; ten mov ecx, nineteen ; eleven mov rax, qword ptr [rip + fourteen] ; twelve and r9d, ecx ;
#
# 1.0  >  one jmp zero ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  two mov qword ptr [rbp - zero], rax ; three call qword ptr [rip + fourteen] ; four mov eax, eax ; five xor qword ptr [rbp - zero], rax ; six call qword ptr [rip + thirteen] ; seven mov eax, eax ; eight lea rcx, [rbp + one] ; nine xor qword ptr [rbp - zero], rax ; ten call qword ptr [rip + twelve] ; eleven mov eax, dword ptr [rbp + one] ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 1.0  >  zero pop r14 ; one pop rdi ; two pop rbp ; three ret  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;
#
# 0.0  >  zero test byte ptr [rax], al ; one add byte ptr [rax], al ; two add byte ptr [rax], al ; three jmp qword ptr [rip + four] ;
#
# 0.0  >  zero int3  ; one int3  ; two int3  ; three int3  ; four int3  ; five int3  ; six int3  ; seven int3  ; eight int3  ; nine int3  ;

# %%
import sys,os

from transformers import BertTokenizer,BertForSequenceClassification

# If using a character-level tokenizer for sequences like DNA/Protein:

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)#BertTokenizer.from_pretrained('bert-base-uncased')

tokenizer = tokenizer.train_new_from_iterator(train_sequences, VOCAB_SIZE)

TOKENIZER_SAVE_PATH = MODEL_SAVE_PATH + EXPERIMENT_NAME+"/tokenizer"+str(MAX_FILE_TO_USE)
tokenizer.save_pretrained(TOKENIZER_SAVE_PATH)
# Out:
# ('/home/raisul/probabilistic_disassembly/models/prototype_pe_small/tokenizer30000/tokenizer_config.json',
#  '/home/raisul/probabilistic_disassembly/models/prototype_pe_small/tokenizer30000/special_tokens_map.json',
#  '/home/raisul/probabilistic_disassembly/models/prototype_pe_small/tokenizer30000/vocab.txt',
#  '/home/raisul/probabilistic_disassembly/models/prototype_pe_small/tokenizer30000/added_tokens.json',
#  '/home/raisul/probabilistic_disassembly/models/prototype_pe_small/tokenizer30000/tokenizer.json')

# %%
#jupyter nbconvert --to script data_pipe.ipynb
# accelerate launch data_pipe.py > log.txt

# %%
print('done')
# Out:
# done
