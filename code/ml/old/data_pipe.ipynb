# %%
from accelerate import Accelerator
import torch
import multiprocessing as mp
accelerator = Accelerator()
accelerator.state.num_processes = 3  # For 3 GPUs
device = accelerator.device
# device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
import os,sys, json,re, pickle
import magic, hashlib,  traceback ,ntpath, collections ,lief
from capstone import *
from capstone.x86 import *
import torch.nn as nn
import lief
from elftools.elf.elffile import ELFFile
from transformers import AdamW,AutoTokenizer
from tqdm import tqdm  # for our progress bar
from sklearn.metrics import precision_recall_fscore_support , accuracy_score,f1_score, confusion_matrix,mean_squared_error, mean_absolute_error, r2_score
from numpy import *
from num2words import num2words
import pandas as pd

# %%
BIN_FILE_TYPE = 'PE' #or ELF
bin_path = '/home/raisul/DATA/x86_pe_msvc_O2_static/' #/home/raisul/DATA/temp/x86_pe_msvc_O2_static/'
bin_files = [os.path.join(bin_path, f) for f in os.listdir(bin_path) if f.endswith(".exe")]#[:2]
ground_truth_path ='/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/'#'/home/raisul/DATA/temp/ghidra_x86_pe_msvc_O2_debug/'  
MODEL_SAVE_PATH= '/home/raisul/probabilistic_disassembly/models/'
EXPERIMENT_NAME = 'prototype_pe_small'
MAX_TOKEN_SIZE = 120
MAX_SEQUENCE_LENGTH = 10
VOCAB_SIZE = 500
BATCH_SIZE = 500
VALIDATION_DISPLAY_SIZE = 10000

# %%
def make_train_test_split(bin_path):
    bin_files = [ f for f in os.listdir(bin_path) ] #if f.endswith(".exe")
    temp_dict = {key: sum(ord(c) for c in key) % 10 for key in bin_files}
    # temp_dict = dict(sorted(temp_dict.items(), key=lambda item: item[1]))
    dict_train = {k: v for k, v in temp_dict.items() if 0 <= v <= 7}
    dict_test = {k: v for k, v in temp_dict.items() if 8 <= v <= 9}
    print(len(list(dict_train.items())) ,len(list(dict_test.items())) )
    return list(dict_train.keys()) , list(dict_test.keys())
train_bins , test_bins = make_train_test_split(bin_path)
# Out:
# /tmp/ipykernel_981987/1577835804.py:3: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   temp_dict = {key: sum(ord(c) for c in key) % 10 for key in bin_files}
# 388576 96450

# %%
def replace_num_with_word(input_string , replace_dict):
    def num_to_word(match):
        number = int( match.group(0))
        return num2words(replace_dict[number]).replace(' ','').replace('-',"")
    result_string = re.sub(r'\b\d+\b', num_to_word, input_string)
    return result_string



def replace_hex_with_decimal(input_string):
    # Regular expression to find hexadecimal numbers prefixed with "0x" or "0X"
    hex_pattern = r'0[xX][0-9a-fA-F]+'
    
    # Function to convert each found hex number to decimal
    def hex_to_decimal(match):
        hex_value = match.group(0)  # Extract the matched hex number
        decimal_value = str(int(hex_value, 16))  # Convert hex to decimal
        return decimal_value
    # Substitute all hex numbers in the string with their decimal equivalents
    result_string = re.sub(hex_pattern, hex_to_decimal, input_string)
    return result_string

# %%
def get_ground_truth_ghidra(exe_path, text_section_offset , text_section_len):

    text_sextion_end = text_section_offset + text_section_len
    
    elf_file_name = os.path.basename(exe_path)
    ghidra_file_path = os.path.join(ground_truth_path, elf_file_name.split('.')[0]) + '.json'
    
    with open(ghidra_file_path, "r") as file:
        ghidra_data = json.load(file)

    ground_truth_offsets = list(ghidra_data.keys())

    ground_truth_offsets = [int(i) for i in ground_truth_offsets]
    ground_truth_offsets = [x for x in ground_truth_offsets if text_section_offset <= x <= text_sextion_end]
    ground_truth_offsets.sort()
    return ground_truth_offsets



def find_data_in_textsection(ground_truth_offsets , text_section_offset , text_section_len, offset_inst_dict):
    data_offsets = []
    for i in range(1, len(ground_truth_offsets)-1):
        distance = ground_truth_offsets[i+1] - ground_truth_offsets[i]

        inst_len = offset_inst_dict[ground_truth_offsets[i]].size 
        
        if distance!=inst_len:
            # print('offset_ranges[i]: ',ground_truth_offsets[i] , 'offset_ranges[i-1]: ',ground_truth_offsets[i-1], ' inst_len: ',inst_len  )
            # print(ground_truth_offsets[i],' ' ,hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]], ' len',offset_inst_dict[ground_truth_offsets[i]].size )
            # print("\nByte GAP ###### ",distance ,' Missing bytes: ', distance - inst_len)
            
            for j in range( ground_truth_offsets[i] +inst_len , ground_truth_offsets[i+1]  ):
                data_offsets.append(j)
                # if offset_inst_dict[j]:
                #     print("# ",j, offset_inst_dict[j].mnemonic, offset_inst_dict[j].op_str , 'inst len:',offset_inst_dict[j].size )
                # else:
                #     print("# ",j, " invalid ")
            # print('\n')
        else:
            # print(ground_truth_offsets[i],' ', hex(ground_truth_offsets[i]) , offset_inst_dict[ground_truth_offsets[i]].mnemonic,offset_inst_dict[ground_truth_offsets[i]].op_str ,' len',offset_inst_dict[ground_truth_offsets[i]].size)
            pass
    return data_offsets
    

def linear_sweep(offset_inst , target_offset):
    inst_sequence = ''
    address_list = []
    
    current_offset = target_offset
    for q in range(MAX_SEQUENCE_LENGTH):

        if current_offset in offset_inst: #if end of text section
            current_instruction = offset_inst[current_offset]
            if current_instruction is None:
                return  None
                
            current_offset = current_offset + current_instruction.size
            inst_sequence+= str( hex(current_instruction.address)) +" "+ current_instruction.mnemonic +' '+ current_instruction.op_str+ ' ; ' 
            address_list.append(current_instruction.address)
            
            if current_instruction.mnemonic in ["ret", "jmp"]: #break linear sweep
                break
                

    return inst_sequence, address_list

# %%
def create_samples(bin_file_paths):

    
    SEQUENCES = []
    LABELS     = []
    
    for bin_file_path in bin_file_paths:
    
        
        md = Cs(CS_ARCH_X86, CS_MODE_64)
        md.detail = True
        offset_inst = {}
    
        try:
            with open(bin_file_path, 'rb') as f:
    
            
                if BIN_FILE_TYPE == "ELF":
                    elffile = ELFFile(f)
                    textSection = elffile.get_section_by_name('.text').data()
                    text_section_offset = elffile.get_section_by_name('.text')['sh_offset']
                  
                elif BIN_FILE_TYPE == "PE":
    
                            
                    pe_file = lief.parse(bin_file_path)
                    text_section = pe_file.get_section(".text")
                    text_section_offset = text_section.pointerto_raw_data
                    textSection = bytes(text_section.content)
                    
                ground_truth_offsets = get_ground_truth_ghidra(bin_file_path, text_section_offset , len(textSection))
                
        except Exception as e:
            print("An error occurred:", e ,bin_file_path)
            continue
    
        for byte_index in range(len(textSection)):
            try:    
    
                instruction = next(md.disasm(textSection[byte_index: byte_index+15 ], text_section_offset + byte_index ), None)
                offset_inst[text_section_offset+byte_index] = instruction
                
                # if instruction:
                #     print("%d:\t%s\t%s _\t%x" %(int(instruction.address), instruction.mnemonic, instruction.op_str, instruction.size))
                # else:
                #     print("%d:\t%s " % (text_section_offset + byte_index  , 'invalid instruction') )
                    
                
    
            except Exception as e:
                print(traceback.print_exc() )
                print(e)
    
        
        offset_inst_dict = collections.OrderedDict(sorted(offset_inst.items()))
    
        DATA_OFFSETS = find_data_in_textsection(ground_truth_offsets , text_section_offset , len(textSection) , offset_inst)
    
    
        
        for byte_offset in range(text_section_offset, text_section_offset+len(textSection)):
            return_value = linear_sweep(offset_inst_dict ,  byte_offset )
            if return_value== None:
                continue
            inst_seq, inst_addresses = return_value 
            ###################################################################
            ## number to words
            disassembly_decimal = replace_hex_with_decimal(inst_seq)
    
            #num to words all
            numbers = [int(s) for s in re.findall(r'\b\d+\b', disassembly_decimal)]
            numbers = sorted(set(numbers) , reverse=True)
            number_word_dict = {}
            
            for ix,n in enumerate(numbers):
                number_word_dict[n] = len(numbers)-1 -ix
    
            disassembly_num_to_words = replace_num_with_word(disassembly_decimal , number_word_dict)
    
            
    
    
            
            ###########################################################################
            
            
            SEQUENCES.append(os.path.basename(bin_file_path)+"_"+str(byte_offset)+"_"+disassembly_num_to_words ) #os.path.basename(bin_file_path)+"_"+str(byte_offset)+"_"+
            if byte_offset in ground_truth_offsets:
                LABELS.append(float(1))
            else:
                LABELS.append(float(0))
    
    
    
    
    #Downsample 
    data = pd.DataFrame({"text": SEQUENCES, "label": LABELS})
    
    # Split by label
    zeros = data[data["label"] == 0]
    ones = data[data["label"] == 1]
    
    # Downsample zeros to 10%
    zeros_downsampled = zeros.sample(frac=0.1, random_state=42)
    
    # Combine and shuffle
    balanced_data = pd.concat([zeros_downsampled, ones]).sample(frac=1, random_state=42)
    
    # Extract final lists
    SEQUENCES = balanced_data["text"].tolist()
    LABELS = balanced_data["label"].tolist()
    
    print(len(SEQUENCES) , len(LABELS))
    print(LABELS.count(0), LABELS.count(1))
    return SEQUENCES,LABELS
train_bin_paths       = [ os.path.join(os.path.join(bin_path, f),f+'.exe' )  for f in train_bins]
validation_bin_paths  = [ os.path.join(os.path.join(bin_path, f),f+'.exe' )  for f in test_bins ]
train_sequences, train_labels = create_samples(train_bin_paths)
validation_sequences, validation_labels  = create_samples(validation_bin_paths)
print(len(validation_sequences), len(validation_labels) )
# Out:
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dcc7510091c35fcef8be9a3668fabb47.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dcc7510091c35fcef8be9a3668fabb47/dcc7510091c35fcef8be9a3668fabb47.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ff556502c0d51a4d7f46d9408ed320a9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ff556502c0d51a4d7f46d9408ed320a9/ff556502c0d51a4d7f46d9408ed320a9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/efdd514ac042ecd02e68d6e2a5c388d3.json' /home/raisul/DATA/x86_pe_msvc_O2_static/efdd514ac042ecd02e68d6e2a5c388d3/efdd514ac042ecd02e68d6e2a5c388d3.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ca88f171289c397143ce3f16e5ed988f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ca88f171289c397143ce3f16e5ed988f/ca88f171289c397143ce3f16e5ed988f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ec768bdbfb5ade598a230b74d7719d04.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ec768bdbfb5ade598a230b74d7719d04/ec768bdbfb5ade598a230b74d7719d04.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/a1f722cc8c6c361ef964c3b4170acedf.json' /home/raisul/DATA/x86_pe_msvc_O2_static/a1f722cc8c6c361ef964c3b4170acedf/a1f722cc8c6c361ef964c3b4170acedf.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e8364d51cbdfec1a5ae25cd79c660b88.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e8364d51cbdfec1a5ae25cd79c660b88/e8364d51cbdfec1a5ae25cd79c660b88.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ee47d46baf1a8afc260c049ed3e99b67.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ee47d46baf1a8afc260c049ed3e99b67/ee47d46baf1a8afc260c049ed3e99b67.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e2089049de2ed81cb2f1d0370e4b2c55.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e2089049de2ed81cb2f1d0370e4b2c55/e2089049de2ed81cb2f1d0370e4b2c55.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f9637cafbb0ff2cdab081c1972e46107.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f9637cafbb0ff2cdab081c1972e46107/f9637cafbb0ff2cdab081c1972e46107.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d5788d45feae1ca9940e32a98b760dbe.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d5788d45feae1ca9940e32a98b760dbe/d5788d45feae1ca9940e32a98b760dbe.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ebeb0e41410caaae503317288835dce6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ebeb0e41410caaae503317288835dce6/ebeb0e41410caaae503317288835dce6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/da63d9ec1e1c9acb5b95835fcfff1827.json' /home/raisul/DATA/x86_pe_msvc_O2_static/da63d9ec1e1c9acb5b95835fcfff1827/da63d9ec1e1c9acb5b95835fcfff1827.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c9f10edb35933b19661c1dd385c1a807.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c9f10edb35933b19661c1dd385c1a807/c9f10edb35933b19661c1dd385c1a807.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/bfde504a0c5c4593f238cbefed2ee23a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/bfde504a0c5c4593f238cbefed2ee23a/bfde504a0c5c4593f238cbefed2ee23a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e7b4e67e8cc5d8e0c3633e731ae49720.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e7b4e67e8cc5d8e0c3633e731ae49720/e7b4e67e8cc5d8e0c3633e731ae49720.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f7bc603e056f26e146d261f883123c16.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f7bc603e056f26e146d261f883123c16/f7bc603e056f26e146d261f883123c16.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e71e6687a5a5285dfbb41d9a706cee32.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e71e6687a5a5285dfbb41d9a706cee32/e71e6687a5a5285dfbb41d9a706cee32.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c6381a0f288a97380b304d9283145bb7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c6381a0f288a97380b304d9283145bb7/c6381a0f288a97380b304d9283145bb7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e9ac46732bb70f7787160b38bc357af9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e9ac46732bb70f7787160b38bc357af9/e9ac46732bb70f7787160b38bc357af9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e3ad59ae0be38cb96ffa113a78857e13.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e3ad59ae0be38cb96ffa113a78857e13/e3ad59ae0be38cb96ffa113a78857e13.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d16e49bfa16b28b21fb0f64886a45dd9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d16e49bfa16b28b21fb0f64886a45dd9/d16e49bfa16b28b21fb0f64886a45dd9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cfeacf6696a4ebaad1d8a3be2c225fe4.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cfeacf6696a4ebaad1d8a3be2c225fe4/cfeacf6696a4ebaad1d8a3be2c225fe4.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/b63362f2683c36375e07dee7c96f7344.json' /home/raisul/DATA/x86_pe_msvc_O2_static/b63362f2683c36375e07dee7c96f7344/b63362f2683c36375e07dee7c96f7344.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e0991f1917fa4889d523986f42a786c6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e0991f1917fa4889d523986f42a786c6/e0991f1917fa4889d523986f42a786c6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c053cdbb426f7cebc2d0a3315277cade.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c053cdbb426f7cebc2d0a3315277cade/c053cdbb426f7cebc2d0a3315277cade.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f1d4ab4625170344c64d137aed9287d2.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f1d4ab4625170344c64d137aed9287d2/f1d4ab4625170344c64d137aed9287d2.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c48361cc245a7c9eb4d2c039b5219c00.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c48361cc245a7c9eb4d2c039b5219c00/c48361cc245a7c9eb4d2c039b5219c00.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/a1f67cb2dc533e4b8d8a059bf2905f67.json' /home/raisul/DATA/x86_pe_msvc_O2_static/a1f67cb2dc533e4b8d8a059bf2905f67/a1f67cb2dc533e4b8d8a059bf2905f67.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/eebe5c63de0071929d54db36dd4dd924.json' /home/raisul/DATA/x86_pe_msvc_O2_static/eebe5c63de0071929d54db36dd4dd924/eebe5c63de0071929d54db36dd4dd924.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc6555b1190f81b5ebe7705aa143219b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc6555b1190f81b5ebe7705aa143219b/cc6555b1190f81b5ebe7705aa143219b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e9065fd10b7f2b99f5c897d8b5ceacb0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e9065fd10b7f2b99f5c897d8b5ceacb0/e9065fd10b7f2b99f5c897d8b5ceacb0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc81ff9453d18bd093a94499997b9a2c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc81ff9453d18bd093a94499997b9a2c/cc81ff9453d18bd093a94499997b9a2c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d54a5ba82c377b0976ad7512e8a6fa20.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d54a5ba82c377b0976ad7512e8a6fa20/d54a5ba82c377b0976ad7512e8a6fa20.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f92383e4a1c5c06ef8fac4f9da81dace.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f92383e4a1c5c06ef8fac4f9da81dace/f92383e4a1c5c06ef8fac4f9da81dace.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c1fe99cc699ca85baa22ada6c246d701.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c1fe99cc699ca85baa22ada6c246d701/c1fe99cc699ca85baa22ada6c246d701.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e64e25c396aa84f402a236ce61c8e8b6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e64e25c396aa84f402a236ce61c8e8b6/e64e25c396aa84f402a236ce61c8e8b6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ef3c7544fcd1d5ae63851857563d8fe3.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ef3c7544fcd1d5ae63851857563d8fe3/ef3c7544fcd1d5ae63851857563d8fe3.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fdc4094391ee538b86c6472334d2902c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fdc4094391ee538b86c6472334d2902c/fdc4094391ee538b86c6472334d2902c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e77176462ecb0b326561e9db439c49fc.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e77176462ecb0b326561e9db439c49fc/e77176462ecb0b326561e9db439c49fc.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f2012ec911e2824988ebe67c9ea74696.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f2012ec911e2824988ebe67c9ea74696/f2012ec911e2824988ebe67c9ea74696.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e9a262e5f86dd7d2b166affd09d4c849.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e9a262e5f86dd7d2b166affd09d4c849/e9a262e5f86dd7d2b166affd09d4c849.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e24f67a17a161f6fae2a217eb7d31db2.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e24f67a17a161f6fae2a217eb7d31db2/e24f67a17a161f6fae2a217eb7d31db2.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/b0b0af43263a5047a490c970033d4a1a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/b0b0af43263a5047a490c970033d4a1a/b0b0af43263a5047a490c970033d4a1a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d6cd0e3d039af8c3031a611084aa5774.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d6cd0e3d039af8c3031a611084aa5774/d6cd0e3d039af8c3031a611084aa5774.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc02688d38e550e05d55c162ad59f0a5.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc02688d38e550e05d55c162ad59f0a5/cc02688d38e550e05d55c162ad59f0a5.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/a67c6cf58a7ef3c12b96c82e1b9acf72.json' /home/raisul/DATA/x86_pe_msvc_O2_static/a67c6cf58a7ef3c12b96c82e1b9acf72/a67c6cf58a7ef3c12b96c82e1b9acf72.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c06dfc5c92ce8f92e8a52d5932a3dd5f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c06dfc5c92ce8f92e8a52d5932a3dd5f/c06dfc5c92ce8f92e8a52d5932a3dd5f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/efe39d92090a67126a48a182d27a5f38.json' /home/raisul/DATA/x86_pe_msvc_O2_static/efe39d92090a67126a48a182d27a5f38/efe39d92090a67126a48a182d27a5f38.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e24b039da7dd25a48d22026fd5d4aade.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e24b039da7dd25a48d22026fd5d4aade/e24b039da7dd25a48d22026fd5d4aade.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e90d0f135947ddab5fe7b5b32771e36f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e90d0f135947ddab5fe7b5b32771e36f/e90d0f135947ddab5fe7b5b32771e36f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fc2949c0f16fa5cc3303b1551244bb3b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fc2949c0f16fa5cc3303b1551244bb3b/fc2949c0f16fa5cc3303b1551244bb3b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ec3929523ec3fde5bb0444a11ea2f94a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ec3929523ec3fde5bb0444a11ea2f94a/ec3929523ec3fde5bb0444a11ea2f94a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e18c9d593aa93f9533096accf0f23ff4.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e18c9d593aa93f9533096accf0f23ff4/e18c9d593aa93f9533096accf0f23ff4.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f66194b82405cce0db2064505d2233b8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f66194b82405cce0db2064505d2233b8/f66194b82405cce0db2064505d2233b8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f49a8442ab2eab49da7fa493d2ceffe1.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f49a8442ab2eab49da7fa493d2ceffe1/f49a8442ab2eab49da7fa493d2ceffe1.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e1e9bdb011d250112a1b203518efb954.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e1e9bdb011d250112a1b203518efb954/e1e9bdb011d250112a1b203518efb954.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c3185f8bdeb617e32de90405d8d31327.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c3185f8bdeb617e32de90405d8d31327/c3185f8bdeb617e32de90405d8d31327.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e7d2e0038a25c03ddd7c62742d91f0da.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e7d2e0038a25c03ddd7c62742d91f0da/e7d2e0038a25c03ddd7c62742d91f0da.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/8f8c958483304e7c3d856b635073f7a1.json' /home/raisul/DATA/x86_pe_msvc_O2_static/8f8c958483304e7c3d856b635073f7a1/8f8c958483304e7c3d856b635073f7a1.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d77b5277cf0dc8bcf7c95560c185e9c6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d77b5277cf0dc8bcf7c95560c185e9c6/d77b5277cf0dc8bcf7c95560c185e9c6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d2990b0929e0601d40d0d3d281c78663.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d2990b0929e0601d40d0d3d281c78663/d2990b0929e0601d40d0d3d281c78663.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c14b92c07d4a2bc99be689bd6c0f4446.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c14b92c07d4a2bc99be689bd6c0f4446/c14b92c07d4a2bc99be689bd6c0f4446.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f5ce2e7172223951295db06a40526939.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f5ce2e7172223951295db06a40526939/f5ce2e7172223951295db06a40526939.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e99637150263ed7006645a342dbf3106.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e99637150263ed7006645a342dbf3106/e99637150263ed7006645a342dbf3106.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d93c6316f42f028b8e861a0f6d428ccc.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d93c6316f42f028b8e861a0f6d428ccc/d93c6316f42f028b8e861a0f6d428ccc.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c4dd2b1b21d69ac4c0c03c9458597eec.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c4dd2b1b21d69ac4c0c03c9458597eec/c4dd2b1b21d69ac4c0c03c9458597eec.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/8c4c6200d51b0cc7f4099b9ae019ec8b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/8c4c6200d51b0cc7f4099b9ae019ec8b/8c4c6200d51b0cc7f4099b9ae019ec8b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f3d2423312ced15a9498546b933eecb0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f3d2423312ced15a9498546b933eecb0/f3d2423312ced15a9498546b933eecb0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e450c5fd34f72651f0c2eb715d7ed87e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e450c5fd34f72651f0c2eb715d7ed87e/e450c5fd34f72651f0c2eb715d7ed87e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e97770913b29cd315ca7694784de10e4.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e97770913b29cd315ca7694784de10e4/e97770913b29cd315ca7694784de10e4.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f6c9a1fa02817bf79f9cc62719d23697.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f6c9a1fa02817bf79f9cc62719d23697/f6c9a1fa02817bf79f9cc62719d23697.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cbd37cffca97ab27ce8a7129e81c5050.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cbd37cffca97ab27ce8a7129e81c5050/cbd37cffca97ab27ce8a7129e81c5050.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ff2aceb0250da35b685de7b4502540d8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ff2aceb0250da35b685de7b4502540d8/ff2aceb0250da35b685de7b4502540d8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/eee659826954c665be336462ca4253eb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/eee659826954c665be336462ca4253eb/eee659826954c665be336462ca4253eb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c4d35bd4412a4012b8071a77f6679659.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c4d35bd4412a4012b8071a77f6679659/c4d35bd4412a4012b8071a77f6679659.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c6b7789408c8a93aa5d959e327fc5862.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c6b7789408c8a93aa5d959e327fc5862/c6b7789408c8a93aa5d959e327fc5862.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d641cea82f1483c32152fe3643fd8c39.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d641cea82f1483c32152fe3643fd8c39/d641cea82f1483c32152fe3643fd8c39.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c195ade6beb341aec0c509e6a4ac7ee5.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c195ade6beb341aec0c509e6a4ac7ee5/c195ade6beb341aec0c509e6a4ac7ee5.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ed6198968656a26a5edcaf62ef41367a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ed6198968656a26a5edcaf62ef41367a/ed6198968656a26a5edcaf62ef41367a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d906d91053edab2f07d99cb0c657c921.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d906d91053edab2f07d99cb0c657c921/d906d91053edab2f07d99cb0c657c921.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ef2e7c2ae197c4c60b9f8c54bb5af8df.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ef2e7c2ae197c4c60b9f8c54bb5af8df/ef2e7c2ae197c4c60b9f8c54bb5af8df.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ee0fdb53522769cfa079a92233099b07.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ee0fdb53522769cfa079a92233099b07/ee0fdb53522769cfa079a92233099b07.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c8086ff0f7afb912325d66907f88504b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c8086ff0f7afb912325d66907f88504b/c8086ff0f7afb912325d66907f88504b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ed1a7381db8fa18aed74b7e30d99c688.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ed1a7381db8fa18aed74b7e30d99c688/ed1a7381db8fa18aed74b7e30d99c688.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ed48e7db209c53d571ca5fec61aac2d7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ed48e7db209c53d571ca5fec61aac2d7/ed48e7db209c53d571ca5fec61aac2d7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fb2049493df9a7227c109669471d4233.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fb2049493df9a7227c109669471d4233/fb2049493df9a7227c109669471d4233.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f686d76ef1f3a112748f4a418a78e0bf.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f686d76ef1f3a112748f4a418a78e0bf/f686d76ef1f3a112748f4a418a78e0bf.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c608e62d486dbfa58e39145c60611e31.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c608e62d486dbfa58e39145c60611e31/c608e62d486dbfa58e39145c60611e31.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ea924a2d6272c2b4cb50ae088eb6c445.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ea924a2d6272c2b4cb50ae088eb6c445/ea924a2d6272c2b4cb50ae088eb6c445.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c2f505861308a9433995690cf197bcc1.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c2f505861308a9433995690cf197bcc1/c2f505861308a9433995690cf197bcc1.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e255d59a372339ae15cb33bf2c067f7c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e255d59a372339ae15cb33bf2c067f7c/e255d59a372339ae15cb33bf2c067f7c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f1c50a4a9cda8f95c2deca3b74f959ac.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f1c50a4a9cda8f95c2deca3b74f959ac/f1c50a4a9cda8f95c2deca3b74f959ac.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c709a1fca53b58738436a0fc6ed7a43f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c709a1fca53b58738436a0fc6ed7a43f/c709a1fca53b58738436a0fc6ed7a43f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ff3e2e6433afa97f3ac53da97a535e78.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ff3e2e6433afa97f3ac53da97a535e78/ff3e2e6433afa97f3ac53da97a535e78.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ecfe4d9af322de86e5d22569c1859525.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ecfe4d9af322de86e5d22569c1859525/ecfe4d9af322de86e5d22569c1859525.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cd7f049349dd14311902e5ce0dba6535.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cd7f049349dd14311902e5ce0dba6535/cd7f049349dd14311902e5ce0dba6535.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d502887203d837ce4546a1547426335b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d502887203d837ce4546a1547426335b/d502887203d837ce4546a1547426335b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e24644ab4ae2b2617dbe420f5c0e46e7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e24644ab4ae2b2617dbe420f5c0e46e7/e24644ab4ae2b2617dbe420f5c0e46e7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c20d6fa5cdda43e61e5a01bc041829de.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c20d6fa5cdda43e61e5a01bc041829de/c20d6fa5cdda43e61e5a01bc041829de.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/db0a59cd8cf566f6a2322704b192e531.json' /home/raisul/DATA/x86_pe_msvc_O2_static/db0a59cd8cf566f6a2322704b192e531/db0a59cd8cf566f6a2322704b192e531.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cd4a669565ec87c09a86828252d0a6e8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cd4a669565ec87c09a86828252d0a6e8/cd4a669565ec87c09a86828252d0a6e8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dac19c548415e93e552724775115c67f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dac19c548415e93e552724775115c67f/dac19c548415e93e552724775115c67f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e2c4f9bd45cd2e977abb74d8f187e426.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e2c4f9bd45cd2e977abb74d8f187e426/e2c4f9bd45cd2e977abb74d8f187e426.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cec82dd702f310e100cabf28084fc45b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cec82dd702f310e100cabf28084fc45b/cec82dd702f310e100cabf28084fc45b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d7c91b8d42efbdff9b5a7e24d7fb9582.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d7c91b8d42efbdff9b5a7e24d7fb9582/d7c91b8d42efbdff9b5a7e24d7fb9582.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d3b2ef0199c64161ed22eef732f8a13b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d3b2ef0199c64161ed22eef732f8a13b/d3b2ef0199c64161ed22eef732f8a13b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c5d83de08c4bd72b96f8d1c7e1b2cc39.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c5d83de08c4bd72b96f8d1c7e1b2cc39/c5d83de08c4bd72b96f8d1c7e1b2cc39.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc49aa1d555bc0b06f3c035e421a9672.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc49aa1d555bc0b06f3c035e421a9672/cc49aa1d555bc0b06f3c035e421a9672.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f3b18ac8558c6efcc4b4626a734694fa.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f3b18ac8558c6efcc4b4626a734694fa/f3b18ac8558c6efcc4b4626a734694fa.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c29b6195e4ef1e9343a963d3768bd57e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c29b6195e4ef1e9343a963d3768bd57e/c29b6195e4ef1e9343a963d3768bd57e.exe
# An error occurred: [Errno 20] Not a directory: '/home/raisul/DATA/x86_pe_msvc_O2_static/c4d3208fb4f3de1588c8a0c32e87032d.lib/c4d3208fb4f3de1588c8a0c32e87032d.lib.exe' /home/raisul/DATA/x86_pe_msvc_O2_static/c4d3208fb4f3de1588c8a0c32e87032d.lib/c4d3208fb4f3de1588c8a0c32e87032d.lib.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dfc4dd61e4e54abcd93b2ad756b071f9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dfc4dd61e4e54abcd93b2ad756b071f9/dfc4dd61e4e54abcd93b2ad756b071f9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c59b496f80e1b991b99af5d18a687b0e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c59b496f80e1b991b99af5d18a687b0e/c59b496f80e1b991b99af5d18a687b0e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e5a8178704def5400df2b622921c739f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e5a8178704def5400df2b622921c739f/e5a8178704def5400df2b622921c739f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cdab3edaf5aad5100aab987880aaeb66.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cdab3edaf5aad5100aab987880aaeb66/cdab3edaf5aad5100aab987880aaeb66.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ef8ac04a6ee32ce081f7be4ad5148092.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ef8ac04a6ee32ce081f7be4ad5148092/ef8ac04a6ee32ce081f7be4ad5148092.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/de0e125bffbff1c6cfdc23b6bca75724.json' /home/raisul/DATA/x86_pe_msvc_O2_static/de0e125bffbff1c6cfdc23b6bca75724/de0e125bffbff1c6cfdc23b6bca75724.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f9188e36d93012923076ebac905a932b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f9188e36d93012923076ebac905a932b/f9188e36d93012923076ebac905a932b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f52bd930d4862757bcd7b8aad552e262.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f52bd930d4862757bcd7b8aad552e262/f52bd930d4862757bcd7b8aad552e262.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cf2b98d37abd92813ca9a07d983dbd88.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cf2b98d37abd92813ca9a07d983dbd88/cf2b98d37abd92813ca9a07d983dbd88.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cfe01531ddac48d0ced1db42348083e9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cfe01531ddac48d0ced1db42348083e9/cfe01531ddac48d0ced1db42348083e9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c4d5384cbfb8db487c3d0c229d98e6a1.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c4d5384cbfb8db487c3d0c229d98e6a1/c4d5384cbfb8db487c3d0c229d98e6a1.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c22f7ce47ccfb7a38721c7fb77a4779e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c22f7ce47ccfb7a38721c7fb77a4779e/c22f7ce47ccfb7a38721c7fb77a4779e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/b00be46e21aa73997792ccf43548f4ef.json' /home/raisul/DATA/x86_pe_msvc_O2_static/b00be46e21aa73997792ccf43548f4ef/b00be46e21aa73997792ccf43548f4ef.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d2f43403f216803a83b4df683b830da0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d2f43403f216803a83b4df683b830da0/d2f43403f216803a83b4df683b830da0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c55e27664527c7cf70b530ffc8979183.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c55e27664527c7cf70b530ffc8979183/c55e27664527c7cf70b530ffc8979183.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c54836d1cac87391a774031816778a4f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c54836d1cac87391a774031816778a4f/c54836d1cac87391a774031816778a4f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fc4270537a0e1e691ea9882a69332bfb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fc4270537a0e1e691ea9882a69332bfb/fc4270537a0e1e691ea9882a69332bfb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cad2593afbfbe1dd38a65e89d71fc2e4.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cad2593afbfbe1dd38a65e89d71fc2e4/cad2593afbfbe1dd38a65e89d71fc2e4.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d2f19c275a1d4f8ed8a5a191d009992c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d2f19c275a1d4f8ed8a5a191d009992c/d2f19c275a1d4f8ed8a5a191d009992c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ea13b1663858cb366ea8b484c6c08e50.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ea13b1663858cb366ea8b484c6c08e50/ea13b1663858cb366ea8b484c6c08e50.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dc30453c5dd304420862820a7b69d4fa.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dc30453c5dd304420862820a7b69d4fa/dc30453c5dd304420862820a7b69d4fa.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e737f4fc7ef2bad7b08ef22aa93e5771.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e737f4fc7ef2bad7b08ef22aa93e5771/e737f4fc7ef2bad7b08ef22aa93e5771.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f56df9f93cf6ec8ebf4367ae4f538fbb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f56df9f93cf6ec8ebf4367ae4f538fbb/f56df9f93cf6ec8ebf4367ae4f538fbb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c088ec3857bdac00c912128042bbfa39.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c088ec3857bdac00c912128042bbfa39/c088ec3857bdac00c912128042bbfa39.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f00532d3b9f3aa67f7b2895e6148f3b7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f00532d3b9f3aa67f7b2895e6148f3b7/f00532d3b9f3aa67f7b2895e6148f3b7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e42c2384771bd1e708b230f11eb99b4a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e42c2384771bd1e708b230f11eb99b4a/e42c2384771bd1e708b230f11eb99b4a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e5d4e532e086e477c1d622371d323594.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e5d4e532e086e477c1d622371d323594/e5d4e532e086e477c1d622371d323594.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c6b4532ba01a15d9e4e12dc43272a2ba.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c6b4532ba01a15d9e4e12dc43272a2ba/c6b4532ba01a15d9e4e12dc43272a2ba.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d9846c4e5a6e7036f9acfe40d314a1cb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d9846c4e5a6e7036f9acfe40d314a1cb/d9846c4e5a6e7036f9acfe40d314a1cb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e85152239fa103af56a90ee3e9021b6c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e85152239fa103af56a90ee3e9021b6c/e85152239fa103af56a90ee3e9021b6c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c817686b9068a07c414373bb6df787da.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c817686b9068a07c414373bb6df787da/c817686b9068a07c414373bb6df787da.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/df76dc4a38eb83eea3aa5e90e655998e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/df76dc4a38eb83eea3aa5e90e655998e/df76dc4a38eb83eea3aa5e90e655998e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e226545fc39ab841ff31e2e99aeabc7f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e226545fc39ab841ff31e2e99aeabc7f/e226545fc39ab841ff31e2e99aeabc7f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d9b2364be7a0edb8f426de683710373b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d9b2364be7a0edb8f426de683710373b/d9b2364be7a0edb8f426de683710373b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/9f7051380c486e16f02d0eb8ec6510e5.json' /home/raisul/DATA/x86_pe_msvc_O2_static/9f7051380c486e16f02d0eb8ec6510e5/9f7051380c486e16f02d0eb8ec6510e5.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc5aba7dc012031b4a048c469091027a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc5aba7dc012031b4a048c469091027a/cc5aba7dc012031b4a048c469091027a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d36e81aa4842f2ebe48cd452aaf94ac8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d36e81aa4842f2ebe48cd452aaf94ac8/d36e81aa4842f2ebe48cd452aaf94ac8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ed1a6c8cd0283b802e4c2c97dad6e028.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ed1a6c8cd0283b802e4c2c97dad6e028/ed1a6c8cd0283b802e4c2c97dad6e028.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e22318267c109d19351c4383655bdffa.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e22318267c109d19351c4383655bdffa/e22318267c109d19351c4383655bdffa.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/faa6e914b78f6b172717caef8d344718.json' /home/raisul/DATA/x86_pe_msvc_O2_static/faa6e914b78f6b172717caef8d344718/faa6e914b78f6b172717caef8d344718.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e356cb69c4be445739cae88949db9a9c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e356cb69c4be445739cae88949db9a9c/e356cb69c4be445739cae88949db9a9c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f05e6a0b1328e5bc71ed5dbe815fc9e0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f05e6a0b1328e5bc71ed5dbe815fc9e0/f05e6a0b1328e5bc71ed5dbe815fc9e0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f2d2ff9c339c57bb919989cba0dcdf72.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f2d2ff9c339c57bb919989cba0dcdf72/f2d2ff9c339c57bb919989cba0dcdf72.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cd6e9a2147d10451b3bf6a20f3ded1f7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cd6e9a2147d10451b3bf6a20f3ded1f7/cd6e9a2147d10451b3bf6a20f3ded1f7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e6a8652273a70368b7073eb7a02a110c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e6a8652273a70368b7073eb7a02a110c/e6a8652273a70368b7073eb7a02a110c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d499263e60f452cf777f0fd800defe7f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d499263e60f452cf777f0fd800defe7f/d499263e60f452cf777f0fd800defe7f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e201da3c85aef7d24f74ffc7e422acbf.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e201da3c85aef7d24f74ffc7e422acbf/e201da3c85aef7d24f74ffc7e422acbf.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d1a2f90cd9951a85d9f0fa257afea9b6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d1a2f90cd9951a85d9f0fa257afea9b6/d1a2f90cd9951a85d9f0fa257afea9b6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ec64500e3694f8d1bd0fc685154a1f5e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ec64500e3694f8d1bd0fc685154a1f5e/ec64500e3694f8d1bd0fc685154a1f5e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c2bbd89db711bb7c93619b027cb10c82.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c2bbd89db711bb7c93619b027cb10c82/c2bbd89db711bb7c93619b027cb10c82.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d3ab11966d68c4da59d137a91b1ffc23.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d3ab11966d68c4da59d137a91b1ffc23/d3ab11966d68c4da59d137a91b1ffc23.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e32ab589ab6641104105ea7f5b640e3c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e32ab589ab6641104105ea7f5b640e3c/e32ab589ab6641104105ea7f5b640e3c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c8d2a579fe6664ed981210cf5972559c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c8d2a579fe6664ed981210cf5972559c/c8d2a579fe6664ed981210cf5972559c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c5a9c45768040d3070fcc01b260898ec.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c5a9c45768040d3070fcc01b260898ec/c5a9c45768040d3070fcc01b260898ec.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fe54601b792fa9b2966e7cd94d96ad06.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fe54601b792fa9b2966e7cd94d96ad06/fe54601b792fa9b2966e7cd94d96ad06.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fff952fd9fca5d7e2edde0abcacaefa8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fff952fd9fca5d7e2edde0abcacaefa8/fff952fd9fca5d7e2edde0abcacaefa8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c2b83f46bf8f573710326232d29afb53.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c2b83f46bf8f573710326232d29afb53/c2b83f46bf8f573710326232d29afb53.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e9a5c3a4c57d5096c99843018a4fb076.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e9a5c3a4c57d5096c99843018a4fb076/e9a5c3a4c57d5096c99843018a4fb076.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d44cbce8cd7c95333acd16dca17dd9a0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d44cbce8cd7c95333acd16dca17dd9a0/d44cbce8cd7c95333acd16dca17dd9a0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ed7d356b5b495c83e650133a7caca388.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ed7d356b5b495c83e650133a7caca388/ed7d356b5b495c83e650133a7caca388.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f310f060c227b2c30ff30afe7718e961.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f310f060c227b2c30ff30afe7718e961/f310f060c227b2c30ff30afe7718e961.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d4f63289ea71cd49bc63b456345b658b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d4f63289ea71cd49bc63b456345b658b/d4f63289ea71cd49bc63b456345b658b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c3512cc79bc9c45dd55c43c920d0a68b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c3512cc79bc9c45dd55c43c920d0a68b/c3512cc79bc9c45dd55c43c920d0a68b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cc9af93862eb38345cfe746a14fc7855.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cc9af93862eb38345cfe746a14fc7855/cc9af93862eb38345cfe746a14fc7855.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f836cdd20df3b39d27d9157fef0e18da.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f836cdd20df3b39d27d9157fef0e18da/f836cdd20df3b39d27d9157fef0e18da.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/bc409d35408303876ee21146be58a0cb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/bc409d35408303876ee21146be58a0cb/bc409d35408303876ee21146be58a0cb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/b00e33b80e2b4737eaf09c96391e7fdf.json' /home/raisul/DATA/x86_pe_msvc_O2_static/b00e33b80e2b4737eaf09c96391e7fdf/b00e33b80e2b4737eaf09c96391e7fdf.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e07a71b04f99922f350a59606730c4c6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e07a71b04f99922f350a59606730c4c6/e07a71b04f99922f350a59606730c4c6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fecb4d4e8cb81250ecc3fc8b2b777a83.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fecb4d4e8cb81250ecc3fc8b2b777a83/fecb4d4e8cb81250ecc3fc8b2b777a83.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ecc169b044d6d1768f44778635ee5d49.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ecc169b044d6d1768f44778635ee5d49/ecc169b044d6d1768f44778635ee5d49.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ee9a1215b9da5a9143589472c0eab606.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ee9a1215b9da5a9143589472c0eab606/ee9a1215b9da5a9143589472c0eab606.exe
# ...
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f3441324fd0e0d4ce92186b9f6a8055c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f3441324fd0e0d4ce92186b9f6a8055c/f3441324fd0e0d4ce92186b9f6a8055c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f410334e7f2d6e1c1985419dfb9892ff.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f410334e7f2d6e1c1985419dfb9892ff/f410334e7f2d6e1c1985419dfb9892ff.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/de72c8b14e92a3b9865c73cb5269bb05.json' /home/raisul/DATA/x86_pe_msvc_O2_static/de72c8b14e92a3b9865c73cb5269bb05/de72c8b14e92a3b9865c73cb5269bb05.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f6897e0e8f72f7b99d2218d316fe0dc1.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f6897e0e8f72f7b99d2218d316fe0dc1/f6897e0e8f72f7b99d2218d316fe0dc1.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dcbe801aede0911835602cc86403a207.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dcbe801aede0911835602cc86403a207/dcbe801aede0911835602cc86403a207.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c5037eb3105210d8e9b36df31cdbdf1f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c5037eb3105210d8e9b36df31cdbdf1f/c5037eb3105210d8e9b36df31cdbdf1f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e6f728270710cee93902b0b099a9fa68.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e6f728270710cee93902b0b099a9fa68/e6f728270710cee93902b0b099a9fa68.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f22236732744088df983f4198bcdb8d3.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f22236732744088df983f4198bcdb8d3/f22236732744088df983f4198bcdb8d3.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cb16c1312d2a001bedcdb212cf3dafde.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cb16c1312d2a001bedcdb212cf3dafde/cb16c1312d2a001bedcdb212cf3dafde.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f6ab46ea885b8b977f6b1b150caaa345.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f6ab46ea885b8b977f6b1b150caaa345/f6ab46ea885b8b977f6b1b150caaa345.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e12c8fd805a9959d69bae7c2dc919257.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e12c8fd805a9959d69bae7c2dc919257/e12c8fd805a9959d69bae7c2dc919257.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f6443086b92458524631a24f584c8eea.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f6443086b92458524631a24f584c8eea/f6443086b92458524631a24f584c8eea.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c23b57debea29576edf3480ecb22aa03.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c23b57debea29576edf3480ecb22aa03/c23b57debea29576edf3480ecb22aa03.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/efcd708a1751c06144fe294da6deebf5.json' /home/raisul/DATA/x86_pe_msvc_O2_static/efcd708a1751c06144fe294da6deebf5/efcd708a1751c06144fe294da6deebf5.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c73c949e4597303ad9775998ee8f2859.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c73c949e4597303ad9775998ee8f2859/c73c949e4597303ad9775998ee8f2859.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c0f502f89b475debf7e23c00a2e1f859.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c0f502f89b475debf7e23c00a2e1f859/c0f502f89b475debf7e23c00a2e1f859.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c5673641d3b82c841cfbbc6ed27d4b24.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c5673641d3b82c841cfbbc6ed27d4b24/c5673641d3b82c841cfbbc6ed27d4b24.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dbe23a30cc24a9588d09cff252f44223.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dbe23a30cc24a9588d09cff252f44223/dbe23a30cc24a9588d09cff252f44223.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e50e66f74298fcbc13047cd1b76cba9b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e50e66f74298fcbc13047cd1b76cba9b/e50e66f74298fcbc13047cd1b76cba9b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ffe30bce1715bd76d1035a634de242a4.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ffe30bce1715bd76d1035a634de242a4/ffe30bce1715bd76d1035a634de242a4.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fa04f559ca2b2b6b07911436eebe99af.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fa04f559ca2b2b6b07911436eebe99af/fa04f559ca2b2b6b07911436eebe99af.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/a2a5028431ab98b6a94eef6b476a4128.json' /home/raisul/DATA/x86_pe_msvc_O2_static/a2a5028431ab98b6a94eef6b476a4128/a2a5028431ab98b6a94eef6b476a4128.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/deacb51128074b78853e5a7c897aa22d.json' /home/raisul/DATA/x86_pe_msvc_O2_static/deacb51128074b78853e5a7c897aa22d/deacb51128074b78853e5a7c897aa22d.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cd2a6f9524870a9eaf3f75f0af91638b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cd2a6f9524870a9eaf3f75f0af91638b/cd2a6f9524870a9eaf3f75f0af91638b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fce1b7d8ec41bdced0cad16fa0c2e7fe.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fce1b7d8ec41bdced0cad16fa0c2e7fe/fce1b7d8ec41bdced0cad16fa0c2e7fe.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f4c668f52156992b3a01d180c50838e7.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f4c668f52156992b3a01d180c50838e7/f4c668f52156992b3a01d180c50838e7.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f4f954d87dbbf28c2cb6a8489c445cbd.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f4f954d87dbbf28c2cb6a8489c445cbd/f4f954d87dbbf28c2cb6a8489c445cbd.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/cce010b6d89c60d0fbbec3c82b3bbfea.json' /home/raisul/DATA/x86_pe_msvc_O2_static/cce010b6d89c60d0fbbec3c82b3bbfea/cce010b6d89c60d0fbbec3c82b3bbfea.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fe505b41a5bb8532c8283b808351653e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fe505b41a5bb8532c8283b808351653e/fe505b41a5bb8532c8283b808351653e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fec4f31fb04a63b03148351bbb8641c9.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fec4f31fb04a63b03148351bbb8641c9/fec4f31fb04a63b03148351bbb8641c9.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e4ca7f9eb2877adae0cafa9d3e5f5a68.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e4ca7f9eb2877adae0cafa9d3e5f5a68/e4ca7f9eb2877adae0cafa9d3e5f5a68.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d958476ab2a92bf00d074026753943b6.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d958476ab2a92bf00d074026753943b6/d958476ab2a92bf00d074026753943b6.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/da3b394733bffd662be4b412c1c338c8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/da3b394733bffd662be4b412c1c338c8/da3b394733bffd662be4b412c1c338c8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f4d784f2414e79e591ee8c2ccd6c991e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f4d784f2414e79e591ee8c2ccd6c991e/f4d784f2414e79e591ee8c2ccd6c991e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fea56f86039238737d828695960b9bfb.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fea56f86039238737d828695960b9bfb/fea56f86039238737d828695960b9bfb.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f73f725890e7ebc96d2ece0a0fb1b96a.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f73f725890e7ebc96d2ece0a0fb1b96a/f73f725890e7ebc96d2ece0a0fb1b96a.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f489664ca6023557838d374cc9f0b949.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f489664ca6023557838d374cc9f0b949/f489664ca6023557838d374cc9f0b949.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d820942a918d2b91c7722124ec687674.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d820942a918d2b91c7722124ec687674/d820942a918d2b91c7722124ec687674.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f5b7b1c5b9524a7193dfc9bb27b92a22.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f5b7b1c5b9524a7193dfc9bb27b92a22/f5b7b1c5b9524a7193dfc9bb27b92a22.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/eb1f2283fe316d6057e0597baf6ba27e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/eb1f2283fe316d6057e0597baf6ba27e/eb1f2283fe316d6057e0597baf6ba27e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/c7ace3e3ce99f5ac82e671abee702fda.json' /home/raisul/DATA/x86_pe_msvc_O2_static/c7ace3e3ce99f5ac82e671abee702fda/c7ace3e3ce99f5ac82e671abee702fda.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d84a30317aa72f67f4f88779fe4a4c1b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d84a30317aa72f67f4f88779fe4a4c1b/d84a30317aa72f67f4f88779fe4a4c1b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/fec5d23e7a14bc14c58adcf3861f10c3.json' /home/raisul/DATA/x86_pe_msvc_O2_static/fec5d23e7a14bc14c58adcf3861f10c3/fec5d23e7a14bc14c58adcf3861f10c3.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e8ad3f0be1a78d27e46d2e441d080ce8.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e8ad3f0be1a78d27e46d2e441d080ce8/e8ad3f0be1a78d27e46d2e441d080ce8.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d483e291fe2b5fd9c6eb8e83b700148c.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d483e291fe2b5fd9c6eb8e83b700148c/d483e291fe2b5fd9c6eb8e83b700148c.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d8ea056b0d2f3354c34a6998a72a0e81.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d8ea056b0d2f3354c34a6998a72a0e81/d8ea056b0d2f3354c34a6998a72a0e81.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d31e047523773360feb5b20486803b46.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d31e047523773360feb5b20486803b46/d31e047523773360feb5b20486803b46.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/ca564276cada71d04292b6c10b5c5b8d.json' /home/raisul/DATA/x86_pe_msvc_O2_static/ca564276cada71d04292b6c10b5c5b8d/ca564276cada71d04292b6c10b5c5b8d.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f062b06cc685a60d73ac8703e5452e81.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f062b06cc685a60d73ac8703e5452e81/f062b06cc685a60d73ac8703e5452e81.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d2952d7800472f597ef91f843af90e46.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d2952d7800472f597ef91f843af90e46/d2952d7800472f597ef91f843af90e46.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d02f208e2c15eef93417496c6d485b50.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d02f208e2c15eef93417496c6d485b50/d02f208e2c15eef93417496c6d485b50.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e0ad4620935eb6df5df1cbe49417db40.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e0ad4620935eb6df5df1cbe49417db40/e0ad4620935eb6df5df1cbe49417db40.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f41e4ef80baccc592eee462f3be7a326.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f41e4ef80baccc592eee462f3be7a326/f41e4ef80baccc592eee462f3be7a326.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/eefbbfa67911685f70bb9d8f14fdab07.json' /home/raisul/DATA/x86_pe_msvc_O2_static/eefbbfa67911685f70bb9d8f14fdab07/eefbbfa67911685f70bb9d8f14fdab07.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/f70ade31832c652b5b762d5a1715740b.json' /home/raisul/DATA/x86_pe_msvc_O2_static/f70ade31832c652b5b762d5a1715740b/f70ade31832c652b5b762d5a1715740b.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e8e7bc9710e2c74ba650bf94b0be9e4e.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e8e7bc9710e2c74ba650bf94b0be9e4e/e8e7bc9710e2c74ba650bf94b0be9e4e.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/dac6d6c0a9814a0653ef6c02fe1a553f.json' /home/raisul/DATA/x86_pe_msvc_O2_static/dac6d6c0a9814a0653ef6c02fe1a553f/dac6d6c0a9814a0653ef6c02fe1a553f.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/e833129a042aa39e3e60328a347d3fb0.json' /home/raisul/DATA/x86_pe_msvc_O2_static/e833129a042aa39e3e60328a347d3fb0/e833129a042aa39e3e60328a347d3fb0.exe
# An error occurred: [Errno 2] No such file or directory: '/home/raisul/ANALYSED_DATA/ghidra_x86_pe_msvc_O2_static/d3c181eabbecb6f45d46d176b8736626.json' /home/raisul/DATA/x86_pe_msvc_O2_static/d3c181eabbecb6f45d46d176b8736626/d3c181eabbecb6f45d46d176b8736626.exe
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7206f56161b0>>
# Traceback (most recent call last):
#   File "/home/raisul/anaconda3/envs/pytorch/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
pkl_data_save_path = MODEL_SAVE_PATH+'training_data.ignore.pkl'
with open(pkl_data_save_path , 'wb') as f:
    pickle.dump([train_sequences,train_labels,validation_sequences, validation_labels], f)
with open(pkl_data_save_path, "rb") as f:
    train_sequences,train_labels,validation_sequences, validation_labels = pickle.load(f)

# %%
for j in range(100):
    if True:#'int3' in SEQUENCES[j]: #LABELS[j] :
        print(train_labels[j] , ' > ' , train_sequences[j] ,'\n' )

# %%
import sys,os

from transformers import BertTokenizer,BertForSequenceClassification

# If using a character-level tokenizer for sequences like DNA/Protein:
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")#BertTokenizer.from_pretrained('bert-base-uncased')

tokenizer = tokenizer.train_new_from_iterator(train_sequences, VOCAB_SIZE)


# model = BertForSequenceClassification.from_pretrained(
#     'bert-base-uncased',
#     num_labels=1  
# )

model = BertForSequenceClassification.from_pretrained(
    MODEL_SAVE_PATH +EXPERIMENT_NAME,
    num_labels=1  
)

model.resize_token_embeddings(VOCAB_SIZE)
model.to(device)


optim = AdamW( model.parameters() , lr=1e-5, eps = 1e-6, betas=(0.9,0.98), weight_decay=0.01)

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        
    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]

        # Tokenize the 
        tokenized_text = (self.tokenizer(text , max_length= MAX_TOKEN_SIZE,padding='max_length', truncation=True , return_tensors='pt')).to(device)
        
        return tokenized_text, label
        
    def __len__(self):
        return len(self.texts)

# %%
# dataset = BinaryDataset(SEQUENCES, LABELS,tokenizer)
# train_size = int(0.8 * len(dataset))
# validation_size = len(dataset) - train_size

train_dataset  =  BinaryDataset(train_sequences, train_labels,tokenizer)#torch.utils.data.Subset(dataset, range(train_size))
validation_dataset = BinaryDataset(validation_sequences, validation_labels,tokenizer) #torch.utils.data.Subset(dataset, range(train_size , len(dataset)))


# train_dataset, validation_dataset = torch.utils.data.random_split(dataset, [train_size, validation_size] , generator=torch.Generator().manual_seed(42))

# %%
len(train_dataset) , len(validation_dataset)

# %%
train_loader      = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE ,shuffle=False) 
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
model, optim, train_loader,validation_loader = accelerator.prepare(model, optim, train_loader,validation_loader)

# %%
def training_loop(model ,data_loop, is_training = False):
    
    prediction_s, ground_truth_s = [], []
    losses = []

    for N,batch in enumerate(data_loop):
        # Forward pass
        if is_training == True:
            optim.zero_grad()
        
        batch_input, batch_labels = batch
        if len(batch_labels)<BATCH_SIZE:
            continue
            
        batch_input_ids= batch_input['input_ids']
        batch_attention_mask=batch_input['attention_mask']
        batch_token_type_ids =batch_input['token_type_ids']
        
        outputs = model(input_ids=batch_input_ids.squeeze(),
                        attention_mask=batch_attention_mask.squeeze(),
                        token_type_ids=batch_token_type_ids.squeeze(),
                        labels=batch_labels.float() )
        
#

        loss = outputs.loss
        losses.append(loss.item())
        
        logits = outputs.logits
        predictions = logits.squeeze()
        # print(logits ,predictions )

        prediction_s.extend(predictions.detach().cpu().numpy().flatten())
        ground_truth_s.extend(batch_labels.detach().cpu().numpy().flatten())


        if is_training == True:
            # loss.backward()
            accelerator.backward(loss)
            optim.step()
        # print relevant info to progress bar
        data_loop.set_description(f'Epoch {ecpoch}')
        data_loop.set_postfix(loss=loss.item())

    # Evaluation Metrics
    mse = mean_squared_error(ground_truth_s, prediction_s)
    rmse = sqrt(mse)
    mae = mean_absolute_error(ground_truth_s, prediction_s)
    r2 = r2_score(ground_truth_s, prediction_s)
    

    metrices = {'MSE':mse ,
                      'RMSE':rmse, 
                      'MAE':mae, 
                      'R²':r2,
                      'loss': (sum(losses) / len(losses))}
    return metrices , prediction_s, ground_truth_s

# %%
EPOCHS = 100


global_metrices = []
v_global_metrices = []


for ecpoch in range(EPOCHS):
    
    # train_loop = tqdm(train_loader, leave=True)
    # model.train()
    # metrices,prediction_s, ground_truth_s  = training_loop(model ,train_loop, is_training = True)
    # global_metrices.append(metrices)
    # print("Training metrices ",metrices)
     
    with torch.no_grad():
        model.eval()
        validation_loop = tqdm(validation_loader, leave=True)
        v_metrices, v_prediction_s, v_ground_truth_s  = training_loop(model ,validation_loop, is_training = False)


        demo_len =100000
        for i in range(minimum(demo_len , len(v_prediction_s) )):

            print('\n')
            sequence_text = validation_sequences[ i ]
            print( v_prediction_s[i], v_ground_truth_s[i] , '\n' , sequence_text)


           
        print( 'v_metrices: ',v_metrices )
        v_global_metrices.append(v_metrices)
        
    if accelerator.is_main_process:
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(MODEL_SAVE_PATH + EXPERIMENT_NAME)

        print('SAVING MODEL @ ',MODEL_SAVE_PATH +EXPERIMENT_NAME)
        unwrapped_model.save_pretrained(MODEL_SAVE_PATH +EXPERIMENT_NAME)
        print('saved')

# %%
#jupyter nbconvert --to script data_pipe.ipynb
# accelerate launch data_pipe.py > log.txt
